# %% [markdown]
# # Standarization of Datasets
# The following notebook is intended for the standarization of the two Network Reconstruction datasets (the one generated in this reconstruction effort and the one that it is been manually curated). The idea of this notebook is to have the first dataset as back in case something goes bad in the manually curated dataset.

# %%
from google_sheet import GoogleSheet

# %% [markdown]
# ### 1.Generate the two sets of datasets

# %%
#Credential file
KEY_FILE_PATH = 'credentials.json'

# Read data from the Google Sheet (Sheet Names)
sheet_rxns = 'Rxns'
sheet_attributes = 'Attributes'
sheet_boundary = 'BoundaryRxns'
sheet_genes = 'Genes'
sheet_met = 'Metabolites'

# %%
##### ----- Generate datasets from CHO Network Reconstruction + Recon3D_v3 ----- #####

#CHO Network Reconstruction + Recon3D_v3 Google Sheet ID
SPREADSHEET_ID = '1MlBXeHIKw8k8fZyXm-sN__AHTRSunJxar_-bqvukZws'

# Initialize the GoogleSheet object
sheet = GoogleSheet(SPREADSHEET_ID, KEY_FILE_PATH)


rxns_v3 = sheet.read_google_sheet(sheet_rxns)
rxns_attributes_v3 = sheet.read_google_sheet(sheet_attributes)
boundary_rxns_v3 = sheet.read_google_sheet(sheet_boundary)
genes_v3 = sheet.read_google_sheet(sheet_genes)
metabolites_v3 = sheet.read_google_sheet(sheet_met)

# %%
##### ----- Generate datasets from Chinese Hamster Network Reconstruction ----- #####

#CHO Network Reconstruction + Recon3D_v3 Google Sheet ID
SPREADSHEET_ID = '1_bCHi0YbemnalomhVDmeHRJimxcVNI4GK6MoH3JdE8M'

# Initialize the GoogleSheet object
sheet = GoogleSheet(SPREADSHEET_ID, KEY_FILE_PATH)

rxns_mc = sheet.read_google_sheet(sheet_rxns)
rxns_attributes_mc = sheet.read_google_sheet(sheet_attributes)
boundary_rxns_mc = sheet.read_google_sheet(sheet_boundary)
genes_mc = sheet.read_google_sheet(sheet_genes)
metabolites_mc = sheet.read_google_sheet(sheet_met)

# %% [markdown]
# ### 2.Check if the datasets are equal

# %%
### ------- "Rxns Sheet" ------- ####
rxns_equals = rxns_v3.equals(rxns_mc)
print(f'"Rxns" Sheet in both datasets are equal: {rxns_v3.equals(rxns_mc)}')
if not rxns_equals:
    rxns_differences = rxns_v3.compare(rxns_mc)
    rxns_differences['Reaction'] = rxns_v3['Reaction'][rxns_differences.index.to_list()]
    print(rxns_differences)
print('.............................................................')    
rxns_attributes_equals = rxns_attributes_v3.equals(rxns_attributes_mc)    
print(f'"Attributes" Sheet in both datasets are equal: {rxns_attributes_v3.equals(rxns_attributes_mc)}')

### ------- "Attributes Sheet" ------- ####
if not rxns_attributes_equals:
    rxns_attributes_differences = rxns_attributes_v3.compare(rxns_attributes_mc)
    rxns_attributes_differences['Reaction'] = rxns_attributes_v3['Reaction'][rxns_attributes_differences.index.to_list()]
    print(rxns_attributes_differences)
print('.............................................................')      
boundary_rxns_equals = boundary_rxns_v3.equals(boundary_rxns_mc)     
print(f'"BoundaryRxns" Sheet in both datasets are equal: {boundary_rxns_v3.equals(boundary_rxns_mc)}')

### ------- "Boundary Rxns Sheet" ------- ####
if not boundary_rxns_equals:
    boundary_rxns_differences = boundary_rxns_v3.compare(boundary_rxns_mc)
    boundary_rxns_differences['Reaction'] = boundary_rxns_v3['Reaction'][boundary_rxns_differences.index.to_list()]
    print(boundary_rxns_differences)
print('.............................................................') 

### ------- "Genes Sheet" ------- ####
genes_equals = genes_v3.equals(genes_mc) 
print(f'"Genes" Sheet in both datasets are equal: {genes_v3.equals(genes_mc)}')
if not genes_equals:
    genes_differences = genes_v3.compare(genes_mc)
    genes_differences['Gene Entrez ID'] = genes_v3['Gene Entrez ID'][genes_differences.index.to_list()]
    print(genes_differences)
print('.............................................................')  

### ------- "Metabolites Sheet" ------- ####
metabolites_equals = metabolites_v3.equals(metabolites_mc) 
print(f'"Metabolites" Sheet in both datasets are equal: {metabolites_v3.equals(metabolites_mc)}')
if not metabolites_equals:
    metabolites_differences = metabolites_v3.compare(metabolites_mc)
    metabolites_differences['BiGG ID'] = metabolites_v3['BiGG ID'][metabolites_differences.index.to_list()]
    print(metabolites_differences)
# Out:
# "Rxns" Sheet in both datasets are equal: False
#      Curated                                     Reaction Name  \
#         self other                                        self
# 274      NaN   NaN                                         NaN
# 442      NaN   NaN                                         NaN
# 1757           NJT                                         NaN
# 1928           NJT                                         NaN
# 1929           NJT                                         NaN
# 1930           NJT                                         NaN
# 1931           NJT                                         NaN
# 1933           NJT                                         NaN
# 1934           NJT                                         NaN
# 1935           NJT                                         NaN
# 1936           NJT                                         NaN
# 1937           NJT                                         NaN
# 1938           NJT                                         NaN
# 1939           NJT                                         NaN
# 1940           NJT                                         NaN
# 1941           NJT                                         NaN
# 1942           NJT                                         NaN
# 1943           NJT                                         NaN
# 1944           NJT                                         NaN
# 1945           NJT                                         NaN
# 1946           NJT                                         NaN
# 1947           NJT                                         NaN
# 1948           NJT                                         NaN
# 1949           NJT                                         NaN
# 1950           NJT                                         NaN
# 2822     NaN   NaN                                         NaN
# 3010           NJT                                         NaN
# 3059           DMU                                         NaN
# 3060           DMU                                         NaN
# 3061           DMU                                         NaN
# 3062           DMU                                         NaN
# 3063           DMU                                         NaN
# 3064           DMU                                         NaN
# 3065           DMU  Transport by Pcet into Extracellular Space
# 3066           DMU                                         NaN
# 3067           DMU                                         NaN
# 3068           DMU                                         NaN
# 3069           DMU                                         NaN
# 3070           DMU                                         NaN
# 3071           DMU                                         NaN
# 3077     NaN   NaN                                         NaN
# 3078     NaN   NaN                                         NaN
# 3081           DMU                                         NaN
# 3083           DMU                                         NaN
# 3149           NJT                                         NaN
# 3375     NaN   NaN                                         NaN
# 3406     NaN   NaN                                         NaN
# 3407           NJT                                         NaN
# 3889     NaN   NaN                                         NaN
# 8030            LZ                                         NaN
# 8031     NaN   NaN                                         NaN
# 8036     NaN   NaN                                         NaN
# 8284          Than                                         NaN
# 9002     NaN   NaN                                         NaN
# 9003     NaN   NaN                                         NaN
# 9004     NaN   NaN                                         NaN
#
#                                        \
#                                 other
# 274                               NaN
# 442                               NaN
# 1757                              NaN
# 1928                              NaN
# 1929                              NaN
# 1930                              NaN
# 1931                              NaN
# 1933                              NaN
# 1934                              NaN
# 1935                              NaN
# 1936                              NaN
# 1937                              NaN
# 1938                              NaN
# 1939                              NaN
# 1940                              NaN
# 1941                              NaN
# 1942                              NaN
# 1943                              NaN
# 1944                              NaN
# 1945                              NaN
# 1946                              NaN
# 1947                              NaN
# 1948                              NaN
# 1949                              NaN
# 1950                              NaN
# 2822                              NaN
# 3010                              NaN
# 3059                              NaN
# 3060                              NaN
# 3061                              NaN
# 3062                              NaN
# 3063                              NaN
# 3064                              NaN
# 3065  Transport by Pcft into the cell
# 3066                              NaN
# 3067                              NaN
# 3068                              NaN
# 3069                              NaN
# 3070                              NaN
# 3071                              NaN
# 3077                              NaN
# 3078                              NaN
# 3081                              NaN
# 3083                              NaN
# 3149                              NaN
# 3375                              NaN
# 3406                              NaN
# 3407                              NaN
# 3889                              NaN
# 8030                              NaN
# 8031                              NaN
# 8036                              NaN
# 8284                              NaN
# 9002                              NaN
# 9003                              NaN
# 9004                              NaN
#
#                              Reaction Formula  \
#                                          self
# 274                                       NaN
# 442                                       NaN
# 1757                                      NaN
# 1928                                      NaN
# 1929                                      NaN
# 1930                                      NaN
# 1931                                      NaN
# 1933                                      NaN
# 1934                                      NaN
# 1935                                      NaN
# 1936                                      NaN
# 1937                                      NaN
# 1938                                      NaN
# 1939                                      NaN
# 1940                                      NaN
# 1941                                      NaN
# 1942                                      NaN
# 1943                                      NaN
# 1944                                      NaN
# 1945                                      NaN
# 1946                                      NaN
# 1947                                      NaN
# 1948                                      NaN
# 1949                                      NaN
# 1950                                      NaN
# 2822                                      NaN
# 3010                                      NaN
# 3059                                      NaN
# 3060                                      NaN
# 3061                                      NaN
# 3062                                      NaN
# 3063                                      NaN
# 3064                                      NaN
# 3065                                      NaN
# 3066                                      NaN
# 3067      mlthf_e + oh1_c <=> mlthf_c + oh1_e
# 3068                      mlthf_e --> mlthf_c
# 3069                                      NaN
# 3070                                      NaN
# 3071                                      NaN
# 3077                                      NaN
# 3078                                      NaN
# 3081                                      NaN
# 3083                                      NaN
# 3149                                      NaN
# 3375                                      NaN
# 3406                                      NaN
# 3407                                      NaN
# 3889                                      NaN
# 8030                                      NaN
# 8031  3sala_c + 2.0 h_c --> co2_c + hyptaur_c
# 8036                                      NaN
# 8284                                      NaN
# 9002                                      NaN
# 9003                                      NaN
# 9004                                      NaN
#
#                                               Balance status            \
#                                         other           self     other
# 274                                       NaN            NaN       NaN
# 442                                       NaN            NaN       NaN
# 1757                                      NaN            NaN       NaN
# 1928                                      NaN            NaN       NaN
# 1929                                      NaN            NaN       NaN
# 1930                                      NaN            NaN       NaN
# 1931                                      NaN            NaN       NaN
# 1933                                      NaN            NaN       NaN
# 1934                                      NaN            NaN       NaN
# 1935                                      NaN            NaN       NaN
# 1936                                      NaN            NaN       NaN
# 1937                                      NaN            NaN       NaN
# 1938                                      NaN            NaN       NaN
# 1939                                      NaN            NaN       NaN
# 1940                                      NaN            NaN       NaN
# 1941                                      NaN            NaN       NaN
# 1942                                      NaN            NaN       NaN
# 1943                                      NaN            NaN       NaN
# 1944                                      NaN            NaN       NaN
# 1945                                      NaN            NaN       NaN
# 1946                                      NaN            NaN       NaN
# 1947                                      NaN            NaN       NaN
# 1948                                      NaN            NaN       NaN
# 1949                                      NaN            NaN       NaN
# 1950                                      NaN            NaN       NaN
# 2822                                      NaN            NaN       NaN
# 3010                                      NaN            NaN       NaN
# 3059                                      NaN            NaN       NaN
# 3060                                      NaN            NaN       NaN
# 3061                                      NaN            NaN       NaN
# 3062                                      NaN            NaN       NaN
# 3063                                      NaN            NaN       NaN
# 3064                                      NaN            NaN       NaN
# 3065                                      NaN            NaN       NaN
# 3066                                      NaN            NaN       NaN
# 3067  mlthf_e + thmpp_c --> mlthf_c + thmpp_e            NaN       NaN
# 3068                     mlthf_e  --> mlthf_c            NaN       NaN
# 3069                                      NaN            NaN       NaN
# 3070                                      NaN            NaN       NaN
# 3071                                      NaN            NaN       NaN
# 3077                                      NaN            NaN       NaN
# 3078                                      NaN            NaN       NaN
# 3081                                      NaN            NaN       NaN
# 3083                                      NaN            NaN       NaN
# 3149                                      NaN            NaN       NaN
# 3375                                      NaN            NaN       NaN
# 3406                                      NaN            NaN       NaN
# 3407                                      NaN            NaN       NaN
# 3889                                      NaN            NaN       NaN
# 8030                                      NaN            NaN       NaN
# 8031      3sala_c + h_c --> co2_c + hyptaur_c            NaN       NaN
# 8036                                      NaN     UNBALANCED  BALANCED
# 8284                                      NaN            NaN       NaN
# 9002                                      NaN            NaN       NaN
# 9003                                      NaN            NaN       NaN
# 9004                                      NaN            NaN       NaN
#
#      GPR_hef        ...                                          GPR_final  \
#         self other  ...                                              other
# 274      NaN   NaN  ...                                                NaN
# 442      NaN   NaN  ...                                                NaN
# 1757     NaN   NaN  ...                                          100773024
# 1928     NaN   NaN  ...             100761226 or (100761230 and 100765601)
# 1929     NaN   NaN  ...                                                NaN
# 1930     NaN   NaN  ...                                          100759029
# 1931     NaN   NaN  ...                                          100759029
# 1933     NaN   NaN  ...                                          100759029
# 1934    None        ...
# 1935     NaN   NaN  ...                                                NaN
# 1936     NaN   NaN  ...                                          100773024
# 1937     NaN   NaN  ...                                          100773024
# 1938     NaN   NaN  ...
# 1939     NaN   NaN  ...                             100767335 or 100750672
# 1940     NaN   NaN  ...                                                NaN
# 1941     NaN   NaN  ...                                                NaN
# 1942     NaN   NaN  ...                                                NaN
# 1943     NaN   NaN  ...                                                NaN
# 1944     NaN   NaN  ...                100755962 or 100760402 or 100757917
# 1945     NaN   NaN  ...                                                NaN
# 1946     NaN   NaN  ...                             100757051 or 100760402
# 1947     NaN   NaN  ...                                          100760402
# 1948     NaN   NaN  ...                                                NaN
# 1949     NaN   NaN  ...
# 1950     NaN   NaN  ...                                          100760402
# 2822     NaN   NaN  ...                                                NaN
# 3010     NaN   NaN  ...                                          100773024
# 3059     NaN   NaN  ...
# 3060     NaN   NaN  ...                                                NaN
# 3061     NaN   NaN  ...                                                NaN
# 3062     NaN   NaN  ...                                                NaN
# 3063     NaN   NaN  ...                                                NaN
# 3064     NaN   NaN  ...                                                NaN
# 3065     NaN   NaN  ...                                                NaN
# 3066     NaN   NaN  ...  100689208 or 100689220  or 100774121 or 100761503
# 3067     NaN   NaN  ...                                          100689407
# 3068     NaN   NaN  ...                                          100689330
# 3069     NaN   NaN  ...                                                NaN
# 3070     NaN   NaN  ...                                                NaN
# 3071     NaN   NaN  ...                                                NaN
# 3077     NaN   NaN  ...                                                NaN
# 3078     NaN   NaN  ...                                                NaN
# 3081     NaN   NaN  ...                                                NaN
# 3083     NaN   NaN  ...                                                NaN
# 3149     NaN   NaN  ...                                          100773024
# 3375     NaN   NaN  ...                                          100760402
# 3406     NaN   NaN  ...                             100767335 or 100750672
# 3407     NaN   NaN  ...                                                NaN
# 3889     NaN   NaN  ...                                                NaN
# 8030     NaN   NaN  ...                                                NaN
# 8031     NaN   NaN  ...                                                NaN
# 8036     NaN   NaN  ...                                                NaN
# 8284     NaN   NaN  ...                                                NaN
# 9002     NaN   NaN  ...                                                NaN
# 9003     NaN   NaN  ...                                                NaN
# 9004     NaN   NaN  ...                                                NaN
#
#      Conf. Score                                             Curation Notes  \
#             self   other                                               self
# 274                    3
# 442                    3
# 1757         NaN     NaN  ORC1 and ORC2 are both known to transport argi...
# 1928                   2  Abca1 (100761226) known to transport cholester...
# 1929                   2  UniProt suggests endosome rather than lysosome...
# 1930                   2
# 1931                   2
# 1933                   2
# 1934        None       1                                               None
# 1935        None       2                                               None
# 1936                   2  ORC1 and ORC2 are both known to transport citr...
# 1937                   1  PMID:14598172 confirms localization and contai...
# 1938                   1  100767335 maps to 9058 (Human), which is a sol...
# 1939                   2  100767335-slc13a2; 100750672-slc13a3 [3:1 Na:C...
# 1940                   2  (100754900) slc13a5 [4:1 Na:Cit stoichiometry;...
# 1941                   2
# 1942                   2
# 1943                   2
# 1944                   2  (100755962)-Slc26a5; (100760402)-Slc26a6 [stoi...
# 1945                   2
# 1946                   3  (100757051)-Slc26a3 [2Cl:1HCO3 stoichiometry, ...
# 1947                   3  (100760402)-Slc26a6 [1Cl:2HCO3 stoichiometry, ...
# 1948                   2  100757917 maps to 5172 (Human), which is a sol...
# 1949                   1
# 1950                   2
# 2822         NaN     NaN
# 3010                   2  Genes code for the mitochondrial ornithine car...
# 3059                   1
# 3060                   1
# 3061                   1
# 3062                   1
# 3063                   1
# 3064                   1
# 3065                   1
# 3066                   2
# 3067                   1
# 3068                   1
# 3069                   2
# 3070                   2
# 3071                   2
# 3077         NaN     NaN                                                NaN
# 3078                   1                                                NaN
# 3081                   1
# 3083                   2
# 3149                   2  Genes code for the mitochondrial ornithine car...
# 3375         NaN     NaN
# 3406         NaN     NaN                                                NaN
# 3407                   2  100750672 maps to 64849 (Human) and 100767335 ...
# 3889         NaN     NaN
# 8030                   4
# 8031         NaN     NaN                                                NaN
# 8036         NaN     NaN                                                NaN
# 8284              REMOVE
# 9002         NaN     NaN
# 9003                   1
# 9004         NaN     NaN
#
#                                                         References  \
#                                                   other       self
# 274   Characterisation for Mouse, https://www.brenda...
# 442   Characterisation for Mouse, https://www.brenda...
# 1757  Slc25a15 (100773024) annotated as mitochondria...
# 1928  Abca1 (100761226) and Abcg5 (100761230) (toget...
# 1929  Stard3 (100759029) in humans transports from e...
# 1930  Stard3 (100759029) known to transport choleste...
# 1931  Stard3 (100759029) known to transport choleste...
# 1933  Stard3 (100759029) known to transport choleste...
# 1934          No evidence found of a chitin transporter        NaN
# 1935  Slc25a1 (100751442) cis-aconitate transport fo...       None
# 1936  Slc25a15 (100773024) annotated as mitochondria...
# 1937  Slc25a15 (100773024) annotated as mitochondria...        NaN
# 1938  Slc13a2 (100767335) mediates entry of TCA inte...        NaN
# 1939  Slc13a2 (100767335) mediates entry of TCA inte...
# 1940  slc13a5 (100754900) is a transpoter of Na+/TCA...
# 1941  Slc25a1 (100751442) L-malate transport found r...
# 1942  Slc25a1 (100751442) L-malate transport found r...
# 1943  Cftr (100754506) transports Cl- in mice [PMID:...
# 1944  Slc26a5 (100755962) evidence of transport of f...
# 1945  Slc26a6 (100760402), stoichiometry not explici...
# 1946  Slc26a3 (100757051) and  Slc26a6 (100760402)  ...
# 1947  Slc26a6 (100760402) is known to have an associ...
# 1948  Slc26a4 (100757917) (anion exchanger), evidenc...
# 1949  Slc26a6 (100760402) does not have this reactio...
# 1950  Slc26a6 (100760402), stoichiometry not explici...
# 2822  Potential duplicate of CITtam, associated to t...        NaN
# 3010  Slc25a15 (100773024) annotated as mitochondria...
# 3059  Oct3 has been shown to transport histamine in ...
# 3060  phosphatidylinositol derivatives to be transpo...
# 3061  phosphatidylinositol derivatives to be transpo...
# 3062  phosphatidylinositol derivatives to be transpo...
# 3063  phosphatidylinositol derivatives to be transpo...
# 3064  phosphatidylinositol derivatives to be transpo...
# 3065  Slc46a1 proton-driven folate import, not speci...
# 3066  Uptake of 5-methyl-THF and folate is demonstra...
# 3067  recently, folate uptake was demonstrated to be...
# 3068  Uptake of 5-methyl-THF and folate is demonstra...
# 3069         transport consistent with channel function
# 3070        transport consistent with permease function
# 3071  high levels of methylglyoxal found in CHO, mai...
# 3077                                                NaN
# 3078                                                NaN
# 3081  reaction contradicts reports on impermeability...
# 3083  Long-standing controversy, but recent data sug...
# 3149  Slc25a15 (100773024) annotated as mitochondria...
# 3375  Slc26a6 (100760402), stoichiometry not explici...        NaN
# 3406                                                NaN        NaN
# 3407  Slc13a3 (100750672) in mice can transport TCA ...
# 3889  Abcg5 (100761230) (together with Abcg8 (100765...        NaN
# 8030  This gene catalyzes the hydroxylation at C-21 ...
# 8031                                                NaN        NaN
# 8036                                                NaN
# 8284                                Duplcated of G3PD2m        NaN
# 9002                  The reaction is described in Kegg
# 9003             The enzyme is present only in bacteria
# 9004  100752768 is the Acot12 gene in CHO. PMID: 964...
#
#                                                          \
#                                                   other
# 274                   doi: 10.1371/journal.pone.0089938
# 442                   doi: 10.1371/journal.pone.0089938
# 1757                          10.1007/s00726-015-2096-9
# 1928                                10.1038/nature17666
# 1929                            10.15252/embj.201695917
# 1930                             10.1074/jbc.M006279200
# 1931                                10.1194/jlr.M002345
# 1933                                10.1194/jlr.M002345
# 1934                                                NaN
# 1935                      10.1016/s0005-2728(89)80068-4
# 1936                                     PMID: 10417335
# 1937                                                NaN
# 1938                                                NaN
# 1939                           10.1074/jbc.273.33.20972
# 1940                                 10.1042/BJ20031261
# 1941                      10.1016/s0005-2728(89)80068-4
# 1942                      10.1016/s0005-2728(89)80068-4
# 1943                            10.1073/pnas.0902661107
# 1944                          10.1016/j.mam.2012.07.009
# 1945                             10.1073/pnas.141241098
# 1946                              10.1085/jgp.200509392
# 1947                          10.1016/j.mam.2012.07.009
# 1948                               10.1210/en.2004-0048
# 1949                             10.1074/jbc.M202660200
# 1950                             10.1074/jbc.M202660200
# 2822                                                NaN
# 3010                             10.1074/jbc.M302317200
# 3059  DOI 10.1124/dmd.121.000702, DOI: 10.1007/164_2...
# 3060  doi: 10.1242/jcs.211094, DOI: 0.1080/19491034....
# 3061  doi: 10.1242/jcs.211094, DOI: 0.1080/19491034....
# 3062  doi: 10.1242/jcs.211094, DOI: 0.1080/19491034....
# 3063  doi: 10.1242/jcs.211094, DOI: 0.1080/19491034....
# 3064  doi: 10.1242/jcs.211094, DOI: 0.1080/19491034....
# 3065                    DOI: 10.1038/s41586-021-03579-z
# 3066                    DOI: 10.1016/j.drup.2006.09.001
# 3067                     DOI 10.1038/s41421-022-00508-w
# 3068  DOI: 10.1083/jcb.110.3.637, DOI: 10.1016/j.add...
# 3069                       DOI: 10.1016/C2009-0-49595-3
# 3070                    DOI: 10.1152/ajpcell.00137.2009
# 3071  doi 10.1073/pnas.95.10.553, DOI: 10.1016/B978-...
# 3077                             doi:10.1042/BJ20061352
# 3078  doi:10.1016/j.febslet.2006.03.050, doi:10.1016...
# 3081  doi:10.1016/j.febslet.2006.03.050, doi:10.1016...
# 3083                         doi: 10.7554/eLife.33246\n
# 3149                                      PMID:10417335
# 3375                                                NaN
# 3406                                                NaN
# 3407                                      PMID:11287335
# 3889                                                NaN
# 8030                      10.1016/S0960-0760(03)00261-9
# 8031                                                NaN
# 8036                                               None
# 8284                                                NaN
# 9002                   https://www.kegg.jp/entry/R08767
# 9003                   https://www.kegg.jp/entry/R01301
# 9004  https://doi.org/10.1111/j.1432-1033.1976.tb107...
#
#                                           BiGG database           Reaction
#                                                    self other
# 274                                                 NaN   NaN       G3PD2m
# 442                                                 NaN   NaN        r0205
# 1757                                                NaN   NaN        ARGtm
# 1928                                                NaN   NaN    CHSTEROLt
# 1929                                                NaN   NaN   CHSTEROLt1
# 1930                                                NaN   NaN   CHSTEROLt2
# 1931                                                NaN   NaN   CHSTEROLt3
# 1933                                                NaN   NaN  CHSTEROLtrc
# 1934                                                NaN   NaN       CHTNte
# 1935                                                NaN   NaN    CITACONtm
# 1936                                                NaN   NaN      CITRt2m
# 1937                                                NaN   NaN       CITRtm
# 1938                                                NaN   NaN      CITt4_2
# 1939                                                NaN   NaN      CITt4_3
# 1940                                                NaN   NaN      CITt4_4
# 1941                                                NaN   NaN       CITtam
# 1942                                                NaN   NaN       CITtbm
# 1943                                                NaN   NaN     CLCFTRte
# 1944                                                NaN   NaN     CLFORtex
# 1945                                                NaN   NaN    CLFORtex2
# 1946                                                NaN   NaN   CLHCO3tex2
# 1947                                                NaN   NaN     CLHCOtex
# 1948                                                NaN   NaN      CLI2tex
# 1949                                                NaN   NaN     CLOHtex2
# 1950                                                NaN   NaN    CLOXAtex2
# 2822                                                NaN   NaN     HMR_4964
# 3010                                                NaN   NaN        LYStm
# 3059                                                NaN   NaN     MHISTAte
# 3060                                                NaN   NaN   MI13456Ptn
# 3061                                                NaN   NaN    MI1346Ptn
# 3062                                                NaN   NaN      MI14Ptn
# 3063                                                NaN   NaN     MI1P_Dtn
# 3064                                                NaN   NaN     MINOHPtn
# 3065                                                NaN   NaN      MLTHFte
# 3066                                                NaN   NaN     MLTHFte1
# 3067                                                NaN   NaN     MLTHFte2
# 3068                                                NaN   NaN     MLTHFte3
# 3069                                                NaN   NaN       MMAt2e
# 3070                                                NaN   NaN        MMAte
# 3071                                                NaN   NaN      MTHGXLt
# 3077                                                NaN   NaN      NADHtpu
# 3078                                                NaN   NaN      NADHtru
# 3081                                                NaN   NaN      NADPtru
# 3083                                                NaN   NaN        NADtm
# 3149                                                NaN   NaN       ORNt3m
# 3375                                                NaN   NaN    SO4CLtex2
# 3406                                                NaN   NaN     SUCCt4_2
# 3407                                                NaN   NaN     SUCCt4_3
# 3889                                                NaN   NaN        r0924
# 8030                                                NaN   NaN  21HPRGNLONE
# 8031                                                NaN   NaN   3SALACBOXL
# 8036  http://bigg.ucsd.edu/models/iCHOv1/reactions/C...  None    BiGGRxn36
# 8284                                                NaN   NaN     HMR_0482
# 9002                                                NaN   NaN    4HBZCOAFm
# 9003                                                NaN   NaN       4HBZFm
# 9004                                                NaN   NaN       ACOAHi
#
# [56 rows x 27 columns]
# .............................................................
# "Attributes" Sheet in both datasets are equal: False
#      EC Number             Mol wt                Reaction
#           self       other   self      other
# 8030            1.14.14.16         58285.000  21HPRGNLONE
# 8036       NaN         NaN         57266.000    BiGGRxn36
# .............................................................
# "BoundaryRxns" Sheet in both datasets are equal: True
# .............................................................
# "Genes" Sheet in both datasets are equal: False
#                                                GO Terms  \
#                                                    self
# 530   ['GO:0004497', 'GO:0016705', 'GO:0005506', 'GO...
# 1688                                                NaN
#
#                                                         Uniprot ID  \
#                                                   other       self
# 530   ['GO:0004497', 'GO:0016705', 'GO:0005506', 'GO...
# 1688                                                NaN
#
#                   Gene Entrez ID
#             other
# 530          None      100767691
# 1688   A0A8C2MBH4      100752374
# .............................................................
# "Metabolites" Sheet in both datasets are equal: True

# %% [markdown]
# ### 3.Update the v3 dataset with info from the manual curation dataset

# %%
# Update Rxns dataset
rxns_changed = False
if not rxns_equals:
    for index in rxns_differences.index:
        rxns_v3.loc[index].update(rxns_mc.loc[index])
        rxns_changed = True
else:
    print('No need to update "Rxns" Sheet datasets')

# Update Attributes dataset
attributes_changed = False
if not rxns_attributes_equals:
    for index in rxns_attributes_differences.index:
        rxns_attributes_v3.loc[index].update(rxns_attributes_mc.loc[index])
        attributes_changed = True
else:
    print('No need to update "Attributes" Sheet datasets')    

# Update Metabolites dataset
metabolites_changed = False
if not metabolites_equals:
    for index in metabolites_differences.index:
        metabolites_v3.loc[index].update(metabolites_mc.loc[index])
        metabolites_changed = True
else:
    print('No need to update "Metabolites" Sheet datasets')
# Out:
# No need to update "Metabolites" Sheet datasets

# %%
#############################################
#### ----------------------------------- ####
#### ---- Update Rxns Google Sheet ----- ####
#### ----------------------------------- ####
#############################################

#CHO Network Reconstruction + Recon3D_v3 Google Sheet ID
SPREADSHEET_ID = '1MlBXeHIKw8k8fZyXm-sN__AHTRSunJxar_-bqvukZws'

# Initialize the GoogleSheet object
sheet = GoogleSheet(SPREADSHEET_ID, KEY_FILE_PATH)

if rxns_changed:
    sheet.update_google_sheet(sheet_rxns, rxns_v3)
    print("Rxns Sheet updated.")

if attributes_changed:
    sheet.update_google_sheet(sheet_attributes, rxns_attributes_v3)
    print("Attributes Sheet updated.")

if metabolites_changed:
    sheet.update_google_sheet(sheet_met, metabolites_v3)
    print("Metabolites Sheet updated.")
# Out:
# Rxns Sheet updated.
# Attributes Sheet updated.
