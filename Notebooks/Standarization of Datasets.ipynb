# %% [markdown]
# # Standarization of Datasets
# The following notebook is intended for the standarization of the two Network Reconstruction datasets (the one generated in this reconstruction effort and the one that it is been manually curated). The idea of this notebook is to have the first dataset as back in case something goes bad in the manually curated dataset.

# %%
from google_sheet import GoogleSheet

# %% [markdown]
# ### 1.Generate the two sets of datasets

# %%
#Credential file
KEY_FILE_PATH = 'credentials.json'

# Read data from the Google Sheet (Sheet Names)
sheet_rxns = 'Rxns'
sheet_attributes = 'Attributes'
sheet_boundary = 'BoundaryRxns'
sheet_genes = 'Genes'
sheet_met = 'Metabolites'

# %%
##### ----- Generate datasets from CHO Network Reconstruction + Recon3D_v3 ----- #####

#CHO Network Reconstruction + Recon3D_v3 Google Sheet ID
SPREADSHEET_ID = '1MlBXeHIKw8k8fZyXm-sN__AHTRSunJxar_-bqvukZws'

# Initialize the GoogleSheet object
sheet = GoogleSheet(SPREADSHEET_ID, KEY_FILE_PATH)


rxns_v3 = sheet.read_google_sheet(sheet_rxns)
rxns_attributes_v3 = sheet.read_google_sheet(sheet_attributes)
boundary_rxns_v3 = sheet.read_google_sheet(sheet_boundary)
genes_v3 = sheet.read_google_sheet(sheet_genes)
metabolites_v3 = sheet.read_google_sheet(sheet_met)

# %%
##### ----- Generate datasets from Chinese Hamster Network Reconstruction ----- #####

#CHO Network Reconstruction + Recon3D_v3 Google Sheet ID
SPREADSHEET_ID = '1_bCHi0YbemnalomhVDmeHRJimxcVNI4GK6MoH3JdE8M'

# Initialize the GoogleSheet object
sheet = GoogleSheet(SPREADSHEET_ID, KEY_FILE_PATH)

rxns_mc = sheet.read_google_sheet(sheet_rxns)
rxns_attributes_mc = sheet.read_google_sheet(sheet_attributes)
boundary_rxns_mc = sheet.read_google_sheet(sheet_boundary)
genes_mc = sheet.read_google_sheet(sheet_genes)
metabolites_mc = sheet.read_google_sheet(sheet_met)

# %% [markdown]
# ### 2.Check if the datasets are equal

# %%
### ------- "Rxns Sheet" ------- ####
rxns_equals = rxns_v3.equals(rxns_mc)
print(f'"Rxns" Sheet in both datasets are equal: {rxns_v3.equals(rxns_mc)}')
if not rxns_equals:
    rxns_differences = rxns_v3.compare(rxns_mc)
    rxns_differences['Reaction'] = rxns_v3['Reaction'][rxns_differences.index.to_list()]
    print(rxns_differences)
print('.............................................................')    
rxns_attributes_equals = rxns_attributes_v3.equals(rxns_attributes_mc)    
print(f'"Attributes" Sheet in both datasets are equal: {rxns_attributes_v3.equals(rxns_attributes_mc)}')

### ------- "Attributes Sheet" ------- ####
if not rxns_attributes_equals:
    rxns_attributes_differences = rxns_attributes_v3.compare(rxns_attributes_mc)
    rxns_attributes_differences['Reaction'] = rxns_attributes_v3['Reaction'][rxns_attributes_differences.index.to_list()]
    print(rxns_attributes_differences)
print('.............................................................')      
boundary_rxns_equals = boundary_rxns_v3.equals(boundary_rxns_mc)     
print(f'"BoundaryRxns" Sheet in both datasets are equal: {boundary_rxns_v3.equals(boundary_rxns_mc)}')

### ------- "Boundary Rxns Sheet" ------- ####
if not boundary_rxns_equals:
    boundary_rxns_differences = boundary_rxns_v3.compare(boundary_rxns_mc)
    boundary_rxns_differences['Reaction'] = boundary_rxns_v3['Reaction'][boundary_rxns_differences.index.to_list()]
    print(boundary_rxns_differences)
print('.............................................................') 

### ------- "Genes Sheet" ------- ####
genes_equals = genes_v3.equals(genes_mc) 
print(f'"Genes" Sheet in both datasets are equal: {genes_v3.equals(genes_mc)}')
if not genes_equals:
    genes_differences = genes_v3.compare(genes_mc)
    genes_differences['Gene Entrez ID'] = genes_v3['Gene Entrez ID'][genes_differences.index.to_list()]
    print(genes_differences)
print('.............................................................')  

### ------- "Metabolites Sheet" ------- ####
metabolites_equals = metabolites_v3.equals(metabolites_mc) 
print(f'"Metabolites" Sheet in both datasets are equal: {metabolites_v3.equals(metabolites_mc)}')
if not metabolites_equals:
    metabolites_differences = metabolites_v3.compare(metabolites_mc)
    metabolites_differences['BiGG ID'] = metabolites_v3['BiGG ID'][metabolites_differences.index.to_list()]
    print(metabolites_differences)
# Out:
# "Rxns" Sheet in both datasets are equal: False
#        Curated                                             Reaction Formula  \
#           self     other                                               self
# 1588                  AR                                                NaN
# 1589                  AR                                                NaN
# 1676        BP     BP/AR  ala_L_e + cl_e + na1_e --> ala_L_c + cl_c + na1_c
# 1690        BP     BP/AR                                                NaN
# 1691        BP     BP/AR                                                NaN
# ...        ...       ...                                                ...
# 10300                 AR  cl_e + 2.0 na1_e + ser_L_e --> cl_c + 2.0 na1_...
# 10312       PD        AR  cl_e + 2.0 na1_e + thr_L_e --> cl_c + 2.0 na1_...
# 10314                 AR  cl_e + 2.0 na1_e + trp_L_e --> cl_c + 2.0 na1_...
# 10316                 AR  cl_e + 2.0 na1_e + tyr_L_e --> cl_c + 2.0 na1_...
# 10317  SB - PD  SB/PD/AR  cl_e + 2.0 na1_e + val_L_e --> cl_c + 2.0 na1_...
#
#                                                          Balance status        \
#                                                    other           self other
# 1588                                                 NaN            NaN   NaN
# 1589                                                 NaN            NaN   NaN
# 1676   ala_L_e + cl_e + 2.0 na1_e <=> ala_L_c + cl_c ...            NaN   NaN
# 1690                                                 NaN            NaN   NaN
# 1691                                                 NaN            NaN   NaN
# ...                                                  ...            ...   ...
# 10300  cl_e + 2.0 na1_e + ser_L_e <=> cl_c + 2.0 na1_...            NaN   NaN
# 10312  cl_e + 2.0 na1_e + thr_L_e <=> cl_c + 2.0 na1_...            NaN   NaN
# 10314  cl_e + 2.0 na1_e + trp_L_e <=> cl_c + 2.0 na1_...            NaN   NaN
# 10316  cl_e + 2.0 na1_e + tyr_L_e <=> cl_c + 2.0 na1_...            NaN   NaN
# 10317  cl_e + 2.0 na1_e + val_L_e <=> cl_c + 2.0 na1_...            NaN   NaN
#
#       Subsystem            GPR_hef        ...  \
#            self      other    self other  ...
# 1588        NaN        NaN     NaN   NaN  ...
# 1589        NaN        NaN     NaN   NaN  ...
# 1676        NaN        NaN     NaN   NaN  ...
# 1690        NaN        NaN     NaN   NaN  ...
# 1691        NaN        NaN     NaN   NaN  ...
# ...         ...        ...     ...   ...  ...
# 10300  EXCHANGE  TRANSPORT     NaN   NaN  ...
# 10312  EXCHANGE  TRANSPORT     NaN   NaN  ...
# 10314  EXCHANGE  TRANSPORT     NaN   NaN  ...
# 10316  EXCHANGE  TRANSPORT     NaN   NaN  ...
# 10317  EXCHANGE  TRANSPORT     NaN   NaN  ...
#
#                                                GPR_final Conf. Score        \
#                                                    other        self other
# 1588                              100765800 or 100766093                 2
# 1589                              100765800 or 100766093                 2
# 1676   (100762871 and 100772257) or (100762871 and 10...           3     2
# 1690                 100765800 or 100766093 or 100759799           3     2
# 1691                                                 NaN           3     2
# ...                                                  ...         ...   ...
# 10300                                          100751194                 2
# 10312                                                NaN                 2
# 10314                                          100751194                 2
# 10316                                          100751194                 2
# 10317                                                NaN           3     2
#
#                                           Curation Notes  \
#                                                     self
# 1588   100766093 maps to 206358 (SLC36A1), PAT1\n1007...
# 1589   100766093 maps to 206358 (SLC36A1), PAT1\n1007...
# 1676   100762871 maps to SLC6A18\n100772257 maps to c...
# 1690   100766093 maps to 206358 (SLC36A1), PAT1\n1007...
# 1691   100766093 maps to 206358 (SLC36A1), PAT1\n1007...
# ...                                                  ...
# 10300
# 10312
# 10314
# 10316
# 10317  PMID: 18599538 describes the reaction in human...
#
#                                                           \
#                                                    other
# 1588   100766093/SLC36A1/PAT1, 100765800/SLC36A2/PAT2...
# 1589   100766093/SLC36A1/PAT1, 100765800/SLC36A2/PAT2...
# 1676   Reaction modified from [cl_e + X_L_e + na1_e -...
# 1690   100766093/SLC36A1/PAT1, 100765800/SLC36A2/PAT2...
# 1691   100766093/SLC36A1/PAT1, 100765800/SLC36A2/PAT2...
# ...                                                  ...
# 10300  Reaction direction modified because unknown (n...
# 10312  Reaction direction modified because unknown (n...
# 10314  Reaction direction modified because unknown (n...
# 10316  Reaction direction modified because unknown (n...
# 10317  Reaction direction modified because unknown (n...
#
#                              References  \
#                                    self
# 1588
# 1589
# 1676                10.1038/nature05475
# 1690   10.1111/j.1476-5381.2011.01438.x
# 1691   10.1111/j.1476-5381.2011.01438.x
# ...                                 ...
# 10300
# 10312
# 10314
# 10316
# 10317      10.1113/jphysiol.2008.154500
#
#                                                          BiGG database        \
#                                                    other          self other
# 1588           Rhea 28915, PMID: 15058382,PMID: 12809675           NaN   NaN
# 1589   Rhea 28915;PMID: 15058382, PMID: 35513259, PMI...           NaN   NaN
# 1676   Rhea 71311; PubMed:19478081, PubMed:26240152, ...           NaN   NaN
# 1690   PMID: 15058382,PMID: 12809675,  Rhea 29443; 10...           NaN   NaN
# 1691   PMID: 15058382, PMID: 12809675, Rhea 29443; PM...           NaN   NaN
# ...                                                  ...           ...   ...
# 10300  https://www.rhea-db.org/rhea/71315; PubMed:113...           NaN   NaN
# 10312  https://www.rhea-db.org/rhea/71327; PubMed:113...           NaN   NaN
# 10314  https://www.rhea-db.org/rhea/71335; PubMed:113...           NaN   NaN
# 10316  https://www.rhea-db.org/rhea/71339; PubMed:113...           NaN   NaN
# 10317  https://www.rhea-db.org/rhea/71307; PubMed:113...           NaN   NaN
#
#          Reaction
#
# 1588      ABUTt2r
# 1589     ABUTt2rL
# 1676   ALAB0AT3tc
# 1690       ALAt2r
# 1691      ALAt2rL
# ...           ...
# 10300   SERATB0tc
# 10312   THRATB0tc
# 10314   TRPATB0tc
# 10316   TYRATB0tc
# 10317   VALATB0tc
#
# [436 rows x 23 columns]
# .............................................................
# "Attributes" Sheet in both datasets are equal: False
#       Curated                                         Reaction Formula  \
#          self other                                               self
# 1588             AR                                                NaN
# 1589             AR                                                NaN
# 1676             AR  ala_L_e + cl_e + na1_e --> ala_L_c + cl_c + na1_c
# 1690             AR                                                NaN
# 1691             AR                                                NaN
# 2048      NaN   NaN                                                NaN
# 2049      NaN   NaN                                                NaN
# 2409             AR      cl_e + gly_e + na1_e --> cl_c + gly_c + na1_c
# 2425             AR                                                NaN
# 2426             AR                                                NaN
# 2427             AR                                                NaN
# 2428             AR                                                NaN
# 2429             AR                                                NaN
# 2901      NaN   NaN  cl_e + ile_L_e + na1_e --> cl_c + ile_L_c + na1_c
# 2909             AR                ile_L_e + na1_e --> ile_L_c + na1_c
# 2954             AR  cl_e + leu_L_e + na1_e --> cl_c + leu_L_c + na1_c
# 3040             AR  cl_e + met_L_e + na1_e --> cl_c + met_L_c + na1_c
# 3255             AR                                                NaN
# 3256             AR                                                NaN
# 3283             AR                                                NaN
# 3284             AR                                                NaN
# 3355             AR  cl_e + na1_e + ser_L_e --> cl_c + na1_c + ser_L_c
# 3713      NaN   NaN                                                NaN
# 3715      NaN   NaN                                                NaN
# 3716      NaN   NaN                                                NaN
# 3718             AR                na1_e + trp_L_e --> na1_c + trp_L_c
# 3756             AR                                                NaN
# 3797             AR  cl_e + na1_e + val_L_e --> cl_c + na1_c + val_L_c
# 3809             AR                na1_e + val_L_e --> na1_c + val_L_c
# 10129            AR  ala_L_e + cl_e + 2.0 na1_e --> ala_L_c + cl_c ...
# 10133            AR  arg_L_e + cl_e + 2.0 na1_e --> arg_L_c + cl_c ...
# 10135            AR  asn_L_e + cl_e + 2.0 na1_e --> asn_L_c + cl_c ...
# 10136            AR                                                NaN
# 10187            AR  cl_e + cys_L_e + 2.0 na1_e --> cl_c + cys_L_c ...
# 10215            AR  cl_e + gln_L_e + 2.0 na1_e --> cl_c + gln_L_c ...
# 10248            AR  cl_e + ile_L_e + 2.0 na1_e --> cl_c + ile_L_c ...
# 10251            AR  cl_e + leu_L_e + 2.0 na1_e --> cl_c + leu_L_c ...
# 10258            AR  cl_e + lys_L_e + 2.0 na1_e --> cl_c + lys_L_c ...
# 10260            AR  cl_e + met_L_e + 2.0 na1_e --> cl_c + met_L_c ...
# 10279            AR  cl_e + 2.0 na1_e + phe_L_e --> cl_c + 2.0 na1_...
# 10300            AR  cl_e + 2.0 na1_e + ser_L_e --> cl_c + 2.0 na1_...
# 10312            AR  cl_e + 2.0 na1_e + thr_L_e --> cl_c + 2.0 na1_...
# 10314            AR  cl_e + 2.0 na1_e + trp_L_e --> cl_c + 2.0 na1_...
# 10316            AR  cl_e + 2.0 na1_e + tyr_L_e --> cl_c + 2.0 na1_...
# 10317            AR  cl_e + 2.0 na1_e + val_L_e --> cl_c + 2.0 na1_...
#
#                                                          Subsystem             \
#                                                    other      self      other
# 1588                                                 NaN       NaN        NaN
# 1589                                                 NaN       NaN        NaN
# 1676   ala_L_e + cl_e + 2.0 na1_e <=> ala_L_c + cl_c ...       NaN        NaN
# 1690                                                 NaN       NaN        NaN
# 1691                                                 NaN       NaN        NaN
# 2048                                                 NaN       NaN        NaN
# 2049                                                 NaN       NaN        NaN
# 2409   cl_e + gly_e + 2.0 na1_e <=> cl_c + gly_c + 2....       NaN        NaN
# 2425                                                 NaN       NaN        NaN
# 2426                                                 NaN       NaN        NaN
# 2427                                                 NaN       NaN        NaN
# 2428                                                 NaN       NaN        NaN
# 2429                                                 NaN       NaN        NaN
# 2901   cl_e + ile_L_e + 2.0 na1_e <=> cl_c + ile_L_c ...       NaN        NaN
# 2909                 ile_L_e + na1_e <=> ile_L_c + na1_c       NaN        NaN
# 2954   cl_e + leu_L_e + 2.0 na1_e <=> cl_c + leu_L_c ...       NaN        NaN
# 3040   cl_e + met_L_e + 2.0 na1_e <=> cl_c + met_L_c ...       NaN        NaN
# 3255                                                 NaN       NaN        NaN
# 3256                                                 NaN       NaN        NaN
# 3283                                                 NaN       NaN        NaN
# 3284                                                 NaN       NaN        NaN
# 3355   cl_e + 2.0 na1_e + ser_L_e <=> cl_c + 2.0 na1_...       NaN        NaN
# 3713                                                 NaN       NaN        NaN
# 3715                                                 NaN       NaN        NaN
# 3716                                                 NaN       NaN        NaN
# 3718                 na1_e + trp_L_e <=> na1_c + trp_L_c       NaN        NaN
# 3756                                                 NaN       NaN        NaN
# 3797   cl_e + 2.0 na1_e + val_L_e <=> cl_c + 2.0 na1_...       NaN        NaN
# 3809                 na1_e + val_L_e <=> na1_c + val_L_c       NaN        NaN
# 10129  ala_L_e + cl_e + 2.0 na1_e <=> ala_L_c + cl_c ...  EXCHANGE  TRANSPORT
# 10133  arg_L_e + cl_e + 2.0 na1_e <=> arg_L_c + cl_c ...  EXCHANGE  TRANSPORT
# 10135  asn_L_e + cl_e + 2.0 na1_e <=> asn_L_c + cl_c ...  EXCHANGE  TRANSPORT
# 10136                                                NaN  EXCHANGE  TRANSPORT
# 10187  cl_e + cys_L_e + 2.0 na1_e <=> cl_c + cys_L_c ...  EXCHANGE  TRANSPORT
# 10215  cl_e + gln_L_e + 2.0 na1_e <=> cl_c + gln_L_c ...  EXCHANGE  TRANSPORT
# 10248  cl_e + ile_L_e + 2.0 na1_e <=> cl_c + ile_L_c ...  EXCHANGE  TRANSPORT
# 10251  cl_e + leu_L_e + 2.0 na1_e <=> cl_c + leu_L_c ...  EXCHANGE  TRANSPORT
# 10258  cl_e + lys_L_e + 2.0 na1_e <=> cl_c + lys_L_c ...  EXCHANGE  TRANSPORT
# 10260  cl_e + met_L_e + 2.0 na1_e <=> cl_c + met_L_c ...  EXCHANGE  TRANSPORT
# 10279  cl_e + 2.0 na1_e + phe_L_e <=> cl_c + 2.0 na1_...  EXCHANGE  TRANSPORT
# 10300  cl_e + 2.0 na1_e + ser_L_e <=> cl_c + 2.0 na1_...  EXCHANGE  TRANSPORT
# 10312  cl_e + 2.0 na1_e + thr_L_e <=> cl_c + 2.0 na1_...  EXCHANGE  TRANSPORT
# 10314  cl_e + 2.0 na1_e + trp_L_e <=> cl_c + 2.0 na1_...  EXCHANGE  TRANSPORT
# 10316  cl_e + 2.0 na1_e + tyr_L_e <=> cl_c + 2.0 na1_...  EXCHANGE  TRANSPORT
# 10317  cl_e + 2.0 na1_e + val_L_e <=> cl_c + 2.0 na1_...  EXCHANGE  TRANSPORT
#
#       TCDB Number                         Reversible       Lower bound         \
#              self                   other       self other        self  other
# 1588                           2.A.18.8.6        NaN   NaN         NaN    NaN
# 1589                           2.A.18.8.6        NaN   NaN         NaN    NaN
# 1676          NaN                     NaN          0     1           0  -1000
# 1690                           2.A.18.8.6        NaN   NaN         NaN    NaN
# 1691                           2.A.18.8.6        NaN   NaN         NaN    NaN
# 2048                           2.A.18.8.6        NaN   NaN         NaN    NaN
# 2049                           2.A.18.8.6        NaN   NaN         NaN    NaN
# 2409          NaN                     NaN          0     1           0  -1000
# 2425                           2.A.18.8.6        NaN   NaN         NaN    NaN
# 2426                           2.A.18.8.6        NaN   NaN         NaN    NaN
# 2427                              2.A.22         NaN   NaN         NaN    NaN
# 2428                               2.A.22        NaN   NaN         NaN    NaN
# 2429                               2.A.22        NaN   NaN         NaN    NaN
# 2901          NaN                     NaN          0     1           0  -1000
# 2909          NaN                     NaN          0     1           0  -1000
# 2954          NaN                     NaN          0     1           0  -1000
# 3040          NaN                     NaN          0     1           0  -1000
# 3255                           2.A.18.8.6        NaN   NaN         NaN    NaN
# 3256                           2.A.18.8.6        NaN   NaN         NaN    NaN
# 3283                           2.A.18.8.6        NaN   NaN         NaN    NaN
# 3284                           2.A.18.8.6        NaN   NaN         NaN    NaN
# 3355          NaN                     NaN          0     1           0  -1000
# 3713               2.A.1.1.28/2.A.123.1.4        NaN   NaN         NaN    NaN
# 3715               2.A.1.1.28/2.A.123.1.4        NaN   NaN         NaN    NaN
# 3716               2.A.1.1.28/2.A.123.1.4        NaN   NaN         NaN    NaN
# 3718          NaN                     NaN          0     1           0  -1000
# 3756          NaN                     NaN          0     1           0  -1000
# 3797          NaN                     NaN          0     1           0  -1000
# 3809          NaN                     NaN          0     1           0  -1000
# 10129         NaN                     NaN          0     1           0  -1000
# 10133         NaN                     NaN          0     1           0  -1000
# 10135         NaN                     NaN          0     1           0  -1000
# 10136         NaN                     NaN        NaN   NaN         NaN    NaN
# 10187         NaN                     NaN          0     1           0  -1000
# 10215         NaN                     NaN          0     1           0  -1000
# 10248         NaN                     NaN          0     1           0  -1000
# 10251         NaN                     NaN          0     1           0  -1000
# 10258         NaN                     NaN          0     1           0  -1000
# 10260         NaN                     NaN          0     1           0  -1000
# 10279         NaN                     NaN          0     1           0  -1000
# 10300         NaN                     NaN          0     1           0  -1000
# 10312         NaN                     NaN          0     1           0  -1000
# 10314         NaN                     NaN          0     1           0  -1000
# 10316         NaN                     NaN          0     1           0  -1000
# 10317         NaN                     NaN          0     1           0  -1000
#
#           Reaction
#
# 1588       ABUTt2r
# 1589      ABUTt2rL
# 1676    ALAB0AT3tc
# 1690        ALAt2r
# 1691       ALAt2rL
# 2048       DALAt2r
# 2049      DALAt2rL
# 2409    GLYB0AT3tc
# 2425        GLYt2r
# 2426       GLYt2rL
# 2427         GLYt4
# 2428   GLYt7_211_r
# 2429   GLYt7_311_r
# 2901    ILEB0AT3tc
# 2909         ILEt4
# 2954    LEUB0AT3tc
# 3040    METB0AT3tc
# 3255       PRODt2r
# 3256      PRODt2rL
# 3283        PROt2r
# 3284       PROt2rL
# 3355    SERB0AT3tc
# 3713    TRPTHRTYRt
# 3715    TRPTYRTYRt
# 3716    TRPVALASPt
# 3718         TRPt4
# 3756         TYRt4
# 3797    VALB0AT3tc
# 3809         VALt4
# 10129    ALAATB0tc
# 10133    ARGATB0tc
# 10135    ASNATB0tc
# 10136   BALABETAtc
# 10187    CYSATB0tc
# 10215    GLNATB0tc
# 10248    ILEATB0tc
# 10251    LEUATB0tc
# 10258    LYSATB0tc
# 10260    METATB0tc
# 10279    PHEATB0tc
# 10300    SERATB0tc
# 10312    THRATB0tc
# 10314    TRPATB0tc
# 10316    TYRATB0tc
# 10317    VALATB0tc
# .............................................................
# "BoundaryRxns" Sheet in both datasets are equal: True
# .............................................................
# "Genes" Sheet in both datasets are equal: False
#      Gene Description                                Uniprot ID           \
#                  self                          other       self    other
# 10                     monocarboxylate transporter 6              G3GTF6
# 1434              NaN                            NaN              G3HA23
#
#      Gene Entrez ID
#
# 10        100757367
# 1434      100763194
# .............................................................
# "Metabolites" Sheet in both datasets are equal: True

# %% [markdown]
# ### 3.Update the v3 dataset with info from the manual curation dataset

# %%
# Update Rxns dataset
rxns_changed = False
if not rxns_equals:
    for index in rxns_differences.index:
        rxns_v3.loc[index].update(rxns_mc.loc[index])
        rxns_changed = True
else:
    print('No need to update "Rxns" Sheet datasets')

# Update Attributes dataset
attributes_changed = False
if not rxns_attributes_equals:
    for index in rxns_attributes_differences.index:
        rxns_attributes_v3.loc[index].update(rxns_attributes_mc.loc[index])
        attributes_changed = True
else:
    print('No need to update "Attributes" Sheet datasets')    

# Update Metabolites dataset
metabolites_changed = False
if not metabolites_equals:
    for index in metabolites_differences.index:
        metabolites_v3.loc[index].update(metabolites_mc.loc[index])
        metabolites_changed = True
else:
    print('No need to update "Metabolites" Sheet datasets')

# %%
#############################################
#### ----------------------------------- ####
#### ---- Update Rxns Google Sheet ----- ####
#### ----------------------------------- ####
#############################################

#CHO Network Reconstruction + Recon3D_v3 Google Sheet ID
SPREADSHEET_ID = '1MlBXeHIKw8k8fZyXm-sN__AHTRSunJxar_-bqvukZws'

# Initialize the GoogleSheet object
sheet = GoogleSheet(SPREADSHEET_ID, KEY_FILE_PATH)

if rxns_changed:
    sheet.update_google_sheet(sheet_rxns, rxns_v3)
    print("Rxns Sheet updated.")

if attributes_changed:
    sheet.update_google_sheet(sheet_attributes, rxns_attributes_v3)
    print("Attributes Sheet updated.")

if metabolites_changed:
    sheet.update_google_sheet(sheet_met, metabolites_v3)
    print("Metabolites Sheet updated.")
