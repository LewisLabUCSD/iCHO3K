# %% [markdown]
# # Standarization of Datasets
# The following notebook is intended for the standarization of the two Network Reconstruction datasets (the one generated in this reconstruction effort and the one that it is been manually curated). The idea of this notebook is to have the first dataset as back in case something goes bad in the manually curated dataset.

# %%
from google_sheet import GoogleSheet

# %% [markdown]
# ### 1.Generate the two sets of datasets

# %%
#Credential file
KEY_FILE_PATH = 'credentials.json'

# Read data from the Google Sheet (Sheet Names)
sheet_rxns = 'Rxns'
sheet_attributes = 'Attributes'
sheet_boundary = 'BoundaryRxns'
sheet_genes = 'Genes'
sheet_met = 'Metabolites'

# %%
##### ----- Generate datasets from CHO Network Reconstruction + Recon3D_v3 ----- #####

#CHO Network Reconstruction + Recon3D_v3 Google Sheet ID
SPREADSHEET_ID = '1MlBXeHIKw8k8fZyXm-sN__AHTRSunJxar_-bqvukZws'

# Initialize the GoogleSheet object
sheet = GoogleSheet(SPREADSHEET_ID, KEY_FILE_PATH)


rxns_v3 = sheet.read_google_sheet(sheet_rxns)
rxns_attributes_v3 = sheet.read_google_sheet(sheet_attributes)
boundary_rxns_v3 = sheet.read_google_sheet(sheet_boundary)
genes_v3 = sheet.read_google_sheet(sheet_genes)
metabolites_v3 = sheet.read_google_sheet(sheet_met)

# %%
##### ----- Generate datasets from Chinese Hamster Network Reconstruction ----- #####

#CHO Network Reconstruction + Recon3D_v3 Google Sheet ID
SPREADSHEET_ID = '1_bCHi0YbemnalomhVDmeHRJimxcVNI4GK6MoH3JdE8M'

# Initialize the GoogleSheet object
sheet = GoogleSheet(SPREADSHEET_ID, KEY_FILE_PATH)

rxns_mc = sheet.read_google_sheet(sheet_rxns)
rxns_attributes_mc = sheet.read_google_sheet(sheet_attributes)
boundary_rxns_mc = sheet.read_google_sheet(sheet_boundary)
genes_mc = sheet.read_google_sheet(sheet_genes)
metabolites_mc = sheet.read_google_sheet(sheet_met)

# %% [markdown]
# ### 2.Check if the datasets are equal

# %%
### ------- "Rxns Sheet" ------- ####
rxns_equals = rxns_v3.equals(rxns_mc)
print(f'"Rxns" Sheet in both datasets are equal: {rxns_v3.equals(rxns_mc)}')
if not rxns_equals:
    rxns_differences = rxns_v3.compare(rxns_mc)
    rxns_differences['Reaction'] = rxns_v3['Reaction'][rxns_differences.index.to_list()]
    print(rxns_differences)
print('.............................................................')    
rxns_attributes_equals = rxns_attributes_v3.equals(rxns_attributes_mc)    
print(f'"Attributes" Sheet in both datasets are equal: {rxns_attributes_v3.equals(rxns_attributes_mc)}')

### ------- "Attributes Sheet" ------- ####
if not rxns_attributes_equals:
    rxns_attributes_differences = rxns_attributes_v3.compare(rxns_attributes_mc)
    rxns_attributes_differences['Reaction'] = rxns_attributes_v3['Reaction'][rxns_attributes_differences.index.to_list()]
    print(rxns_attributes_differences)
print('.............................................................')      
boundary_rxns_equals = boundary_rxns_v3.equals(boundary_rxns_mc)     
print(f'"BoundaryRxns" Sheet in both datasets are equal: {boundary_rxns_v3.equals(boundary_rxns_mc)}')

### ------- "Boundary Rxns Sheet" ------- ####
if not boundary_rxns_equals:
    boundary_rxns_differences = boundary_rxns_v3.compare(boundary_rxns_mc)
    boundary_rxns_differences['Reaction'] = boundary_rxns_v3['Reaction'][boundary_rxns_differences.index.to_list()]
    print(boundary_rxns_differences)
print('.............................................................') 

### ------- "Genes Sheet" ------- ####
genes_equals = genes_v3.equals(genes_mc) 
print(f'"Genes" Sheet in both datasets are equal: {genes_v3.equals(genes_mc)}')
if not genes_equals:
    genes_differences = genes_v3.compare(genes_mc)
    genes_differences['Gene Entrez ID'] = genes_v3['Gene Entrez ID'][genes_differences.index.to_list()]
    print(genes_differences)
print('.............................................................')  

### ------- "Metabolites Sheet" ------- ####
metabolites_equals = metabolites_v3.equals(metabolites_mc) 
print(f'"Metabolites" Sheet in both datasets are equal: {metabolites_v3.equals(metabolites_mc)}')
if not metabolites_equals:
    metabolites_differences = metabolites_v3.compare(metabolites_mc)
    metabolites_differences['BiGG ID'] = metabolites_v3['BiGG ID'][metabolites_differences.index.to_list()]
    print(metabolites_differences)
# Out:
# "Rxns" Sheet in both datasets are equal: False
#         Curated         GPR_final            Conf. Score        \
#            self   other      self      other        self other
# 1949  Pre-check     NJT       NaN        NaN         NaN   NaN
# 5304                 CO       nan  100767396                 4
# 5305                 CO       NaN        NaN                 4
# 5309                 CO       NaN        NaN                 4
# 6676        NaN     NaN       NaN        NaN         NaN   NaN
# 6677        NaN     NaN       NaN        NaN         NaN   NaN
# 6678        NaN     NaN       NaN        NaN         NaN   NaN
# 6679        NaN     NaN       NaN        NaN         NaN   NaN
# 6680        NaN     NaN       NaN        NaN         NaN   NaN
# 6681        NaN     NaN       NaN        NaN         NaN   NaN
# 6682        NaN     NaN       NaN        NaN         NaN   NaN
# 6683        NaN     NaN       NaN        NaN         NaN   NaN
# 6684        NaN     NaN       NaN        NaN         NaN   NaN
# 6685        NaN     NaN       NaN        NaN         NaN   NaN
# 6686        NaN     NaN       NaN        NaN         NaN   NaN
# 6687        NaN     NaN       NaN        NaN         NaN   NaN
# 6688        NaN     NaN       NaN        NaN         NaN   NaN
# 6689        NaN     NaN       NaN        NaN         NaN   NaN
# 6690        NaN     NaN       NaN        NaN         NaN   NaN
# 6691        NaN     NaN       NaN        NaN         NaN   NaN
# 6692        NaN     NaN       NaN        NaN         NaN   NaN
# 6693        NaN     NaN       NaN        NaN         NaN   NaN
# 6694        NaN     NaN       NaN        NaN         NaN   NaN
# 6695        NaN     NaN       NaN        NaN         NaN   NaN
# 6696        NaN     NaN       NaN        NaN         NaN   NaN
# 8322             CA/AMV       NaN        NaN                 2
# 8323             CA/AMV       NaN        NaN                 3
# 8324             CA/AMV       NaN        NaN                 3
#
#                                          Curation Notes  \
#                                                    self
# 1949
# 5304  Gene is sepiapterin reductase, converting 6-Py...
# 5305  Gene is sepiapterin reductase, converting 6-Py...
# 5309  EC 1.5.1.34 : Coenzyme NAD/NADH for homo sapie...
# 6676
# 6677
# 6678
# 6679
# 6680
# 6681
# 6682
# 6683
# 6684
# 6685
# 6686
# 6687
# 6688
# 6689
# 6690
# 6691
# 6692
# 6693
# 6694
# 6695
# 6696
# 8322
# 8323  PMID:12431977 confirms localization, PMID:9989...
# 8324                                                NaN
#
#                                                          \
#                                                   other
# 1949  No info in literature about this transport (fr...
# 5304  Human homolog of SPR has a Rhea reaction assoc...
# 5305  Human homolog of SPR has a Rhea reaction assoc...
# 5309  Human QDPR has Rhea reaction associated with c...
# 6676    Complete beta oxidation of 9e-tetradecenoyl-CoA
# 6677    Complete beta oxidation of 13z-octadecenoyl-CoA
# 6678    Complete beta oxidation of 9e-octadecenoic acid
# 6679   Complete beta oxidation of (7Z)-octadecenoyl-CoA
# 6680  Complete beta oxidation of 6Z,9Z-octadecadieno...
# 6681  Complete beta oxidation of 9z-eicosenoyl coenz...
# 6682  Complete beta oxidation of 8z,11z-eicosadienoy...
# 6683  Complete beta oxidation of 5z,8z,11z-eicosatri...
# 6684  Complete beta oxidation of 11z-docosenoyl coen...
# 6685      Complete beta oxidation of adrenyl coenzyme a
# 6686  Complete beta oxidation of docosa-4,7,10,13,16...
# 6687  Complete beta oxidation of (11z,14z)-icosadien...
# 6688  Complete beta oxidation of 13z,16z-docosadieno...
# 6689  Complete beta oxidation of 10z,13z,16z-docosat...
# 6690  Complete beta oxidation of (9Z,12Z,15Z-Octadec...
# 6691  Complete beta oxidation of eicosatetranoyl coe...
# 6692   Complete beta oxidation of timnodonyl coenzyme a
# 6693        Complete beta oxidation of clupanodonyl coa
# 6694  Complete beta oxidation of 11z,14z,17z-eicosat...
# 6695  Complete beta oxidation of 13z,16z,19z-docosat...
# 6696  Complete beta oxidation of 10z,13z,16z,19z-doc...
# 8322  Inferred from sequence orthology (https://www....
# 8323  UNIPRO COD: Q61907 (M musculus). Phosphatidyl-...
# 8324                                                NaN
#
#                                              References  \
#                                                    self
# 1949                                                NaN
# 5304
# 5305
# 5309
# 6676                                                NaN
# 6677                                                NaN
# 6678                                                NaN
# 6679                                                NaN
# 6680                                                NaN
# 6681                                                NaN
# 6682                                                NaN
# 6683                                                NaN
# 6684                                                NaN
# 6685                                                NaN
# 6686                                                NaN
# 6687                                                NaN
# 6688                                                NaN
# 6689                                                NaN
# 6690                                                NaN
# 6691                                                NaN
# 6692                                                NaN
# 6693                                                NaN
# 6694                                                NaN
# 6695                                                NaN
# 6696                                                NaN
# 8322                                                NaN
# 8323
# 8324  https://www.rhea-db.org/rhea/32735; https://pu...
#
#                                                           Reaction
#                                                   other
# 1949                                                NaN  CMPACNAtn
# 5304  https://www.rhea-db.org/rhea/32627 https://doi...        SPR
# 5305  https://www.rhea-db.org/rhea/32627 https://doi...       SPRn
# 5309  https://www.rhea-db.org/rhea/17869 https://doi...      r0398
# 6676                                                NaN   HMR_3398
# 6677                                                NaN   HMR_3406
# 6678                                                NaN   HMR_3407
# 6679                                                NaN   HMR_3408
# 6680                                                NaN   HMR_3409
# 6681                                                NaN   HMR_3411
# 6682                                                NaN   HMR_3413
# 6683                                                NaN   HMR_3414
# 6684                                                NaN   HMR_3416
# 6685                                                NaN   HMR_3421
# 6686                                                NaN   HMR_3422
# 6687                                                NaN   HMR_3423
# 6688                                                NaN   HMR_3424
# 6689                                                NaN   HMR_3425
# 6690                                                NaN   HMR_3426
# 6691                                                NaN   HMR_3427
# 6692                                                NaN   HMR_3428
# 6693                                                NaN   HMR_3429
# 6694                                                NaN   HMR_3431
# 6695                                                NaN   HMR_3432
# 6696                                                NaN   HMR_3433
# 8322                                                NaN    RE3511C
# 8323  https://www.rhea-db.org/rhea/32735; https://pu...    RE3511M
# 8324  https://www.rhea-db.org/rhea/32735; https://pu...    RE3511R
# .............................................................
# "Attributes" Sheet in both datasets are equal: True
# .............................................................
# "BoundaryRxns" Sheet in both datasets are equal: True
# .............................................................
# "Genes" Sheet in both datasets are equal: True
# .............................................................
# "Metabolites" Sheet in both datasets are equal: False
#     Curated       Charge         PubChem        \
#        self other   self other      self other
# 297     NaN   NaN    NaN   NaN  91828301   NaN
# 298     NaN   NaN    NaN   NaN  91828301   NaN
# 337            PD           -4       NaN   NaN
# 378     NaN   NaN      0    -4       NaN   NaN
# 379     NaN   NaN      0    -4       NaN   NaN
#
#                                                  Inchi        \
#                                                   self other
# 297  InChI=1S/C37H64N7O18P3S/c1-4-5-6-7-8-9-10-11-1...   NaN
# 298  InChI=1S/C37H64N7O18P3S/c1-4-5-6-7-8-9-10-11-1...   NaN
# 337                                                NaN   NaN
# 378                                                NaN   NaN
# 379                                                NaN   NaN
#
#                                                 SMILES                BiGG ID
#                                                   self other
# 297  CCCCCCCCC=CCCCC(CC(=O)SCCNC(=O)CCNC(=O)C(C(C)(...   NaN  3hoc101_7Zcoa_m
# 298  CCCCCCCCC=CCCCC(CC(=O)SCCNC(=O)CCNC(=O)C(C(C)(...   NaN  3hoc101_7Zcoa_x
# 337                                                NaN   NaN      3houndcoa_m
# 378                                                NaN   NaN   3oc101_7Zcoa_m
# 379                                                NaN   NaN   3oc101_7Zcoa_x

# %% [markdown]
# ### 3.Update the v3 dataset with info from the manual curation dataset

# %%
# Update Rxns dataset
rxns_changed = False
if not rxns_equals:
    for index in rxns_differences.index:
        rxns_v3.loc[index].update(rxns_mc.loc[index])
        rxns_changed = True
else:
    print('No need to update "Rxns" Sheet datasets')

# Update Attributes dataset
attributes_changed = False
if not rxns_attributes_equals:
    for index in rxns_attributes_differences.index:
        rxns_attributes_v3.loc[index].update(rxns_attributes_mc.loc[index])
        attributes_changed = True
else:
    print('No need to update "Attributes" Sheet datasets')    

# Update Metabolites dataset
metabolites_changed = False
if not metabolites_equals:
    for index in metabolites_differences.index:
        metabolites_v3.loc[index].update(metabolites_mc.loc[index])
        metabolites_changed = True
else:
    print('No need to update "Metabolites" Sheet datasets')
# Out:
# No need to update "Attributes" Sheet datasets

# %%
#############################################
#### ----------------------------------- ####
#### ---- Update Rxns Google Sheet ----- ####
#### ----------------------------------- ####
#############################################

#CHO Network Reconstruction + Recon3D_v3 Google Sheet ID
SPREADSHEET_ID = '1MlBXeHIKw8k8fZyXm-sN__AHTRSunJxar_-bqvukZws'

# Initialize the GoogleSheet object
sheet = GoogleSheet(SPREADSHEET_ID, KEY_FILE_PATH)

if rxns_changed:
    sheet.update_google_sheet(sheet_rxns, rxns_v3)
    print("Rxns Sheet updated.")

if attributes_changed:
    sheet.update_google_sheet(sheet_attributes, rxns_attributes_v3)
    print("Attributes Sheet updated.")

if metabolites_changed:
    sheet.update_google_sheet(sheet_met, metabolites_v3)
    print("Metabolites Sheet updated.")
# Out:
# Rxns Sheet updated.
# Metabolites Sheet updated.
