# %% [markdown]
# # Standarization of Datasets
# The following notebook is intended for the standarization of the two Network Reconstruction datasets (the one generated in this reconstruction effort and the one that it is been manually curated). The idea of this notebook is to have the first dataset as back in case something goes bad in the manually curated dataset.

# %%
from google_sheet import GoogleSheet

# %% [markdown]
# ### 1.Generate the two sets of datasets

# %%
#Credential file
KEY_FILE_PATH = 'credentials.json'

# Read data from the Google Sheet (Sheet Names)
sheet_rxns = 'Rxns'
sheet_attributes = 'Attributes'
sheet_boundary = 'BoundaryRxns'
sheet_genes = 'Genes'
sheet_met = 'Metabolites'

# %%
##### ----- Generate datasets from CHO Network Reconstruction + Recon3D_v3 ----- #####

#CHO Network Reconstruction + Recon3D_v3 Google Sheet ID
SPREADSHEET_ID = '1MlBXeHIKw8k8fZyXm-sN__AHTRSunJxar_-bqvukZws'

# Initialize the GoogleSheet object
sheet = GoogleSheet(SPREADSHEET_ID, KEY_FILE_PATH)


rxns_v3 = sheet.read_google_sheet(sheet_rxns)
rxns_attributes_v3 = sheet.read_google_sheet(sheet_attributes)
boundary_rxns_v3 = sheet.read_google_sheet(sheet_boundary)
genes_v3 = sheet.read_google_sheet(sheet_genes)
metabolites_v3 = sheet.read_google_sheet(sheet_met)

# %%
##### ----- Generate datasets from Chinese Hamster Network Reconstruction ----- #####

#CHO Network Reconstruction + Recon3D_v3 Google Sheet ID
SPREADSHEET_ID = '1_bCHi0YbemnalomhVDmeHRJimxcVNI4GK6MoH3JdE8M'

# Initialize the GoogleSheet object
sheet = GoogleSheet(SPREADSHEET_ID, KEY_FILE_PATH)

rxns_mc = sheet.read_google_sheet(sheet_rxns)
rxns_attributes_mc = sheet.read_google_sheet(sheet_attributes)
boundary_rxns_mc = sheet.read_google_sheet(sheet_boundary)
genes_mc = sheet.read_google_sheet(sheet_genes)
metabolites_mc = sheet.read_google_sheet(sheet_met)

# %% [markdown]
# ### 2.Santity Check
# This checks if the Reaction IDs, formulas and subsystems have been changed by the curators, or if the dataset have been reorganized.

# %%
# Function to find differences in four lists
def find_differences(list1, list2, list3, list4):
    return [(i, item1, item2, item3, item4) for i, (item1, item2, item3, item4) 
            in enumerate(zip(list1, list2, list3, list4)) 
            if item1 != item2 or item1 != item3 or item1 != item4]

# Check differences in Reaction IDs
rxns_ID_diff = find_differences(list(rxns_mc['Reaction']), 
                                list(rxns_attributes_mc['Reaction']),
                                list(rxns_v3['Reaction']),
                                list(rxns_attributes_v3['Reaction']))

if not rxns_ID_diff:
    print('Reaction IDs are OK')
    print('------------------------------')
else:
    print('Differences in Reaction IDs at indices:', rxns_ID_diff)
    print('------------------------------')

# Check differences in Reaction Formulas
rxns_ID_diff = find_differences(list(rxns_mc['Reaction Formula']), 
                                list(rxns_attributes_mc['Reaction Formula']),
                                list(rxns_v3['Reaction Formula']),
                                list(rxns_attributes_v3['Reaction Formula']))

if not rxns_ID_diff:
    print('Reaction formulas are OK')
    print('------------------------------')
else:
    print('Differences in Reaction Formulas at indices:', rxns_ID_diff)
    print('------------------------------')

    
# Check differences in Subsystems
rxns_ID_diff = find_differences(list(rxns_mc['Subsystem']), 
                                list(rxns_attributes_mc['Subsystem']),
                                list(rxns_v3['Subsystem']),
                                list(rxns_attributes_v3['Subsystem']))

if not rxns_ID_diff:
    print('Reaction subsystems are OK')
    print('------------------------------')
else:
    print('Differences in Subsystems at indices:', rxns_ID_diff)
    print('------------------------------')
# Out:
# Reaction IDs are OK
# ------------------------------
# Reaction formulas are OK
# ------------------------------
# Reaction subsystems are OK
# ------------------------------

# %% [markdown]
# ### 3.Check if the datasets are equal
# Next step is to check the diferences in all the sheets manupilated by the manual curators in comparison with the back up Google Sheet.

# %%
### ------- "Rxns Sheet" ------- ####
rxns_equals = rxns_v3.equals(rxns_mc)
print(f'"Rxns" Sheet in both datasets are equal: {rxns_v3.equals(rxns_mc)}')
if not rxns_equals:
    rxns_differences = rxns_v3.compare(rxns_mc)
    rxns_differences['Reaction'] = rxns_v3['Reaction'][rxns_differences.index.to_list()]
    print(rxns_differences)
print('.............................................................')    
rxns_attributes_equals = rxns_attributes_v3.equals(rxns_attributes_mc)    
print(f'"Attributes" Sheet in both datasets are equal: {rxns_attributes_v3.equals(rxns_attributes_mc)}')

### ------- "Attributes Sheet" ------- ####
if not rxns_attributes_equals:
    rxns_attributes_differences = rxns_attributes_v3.compare(rxns_attributes_mc)
    rxns_attributes_differences['Reaction'] = rxns_attributes_v3['Reaction'][rxns_attributes_differences.index.to_list()]
    print(rxns_attributes_differences)
print('.............................................................')      
boundary_rxns_equals = boundary_rxns_v3.equals(boundary_rxns_mc)     
print(f'"BoundaryRxns" Sheet in both datasets are equal: {boundary_rxns_v3.equals(boundary_rxns_mc)}')

### ------- "Boundary Rxns Sheet" ------- ####
if not boundary_rxns_equals:
    boundary_rxns_differences = boundary_rxns_v3.compare(boundary_rxns_mc)
    boundary_rxns_differences['Reaction'] = boundary_rxns_v3['Reaction'][boundary_rxns_differences.index.to_list()]
    print(boundary_rxns_differences)
print('.............................................................') 

### ------- "Genes Sheet" ------- ####
genes_equals = genes_v3.equals(genes_mc) 
print(f'"Genes" Sheet in both datasets are equal: {genes_v3.equals(genes_mc)}')
if not genes_equals:
    genes_differences = genes_v3.compare(genes_mc)
    genes_differences['Gene Entrez ID'] = genes_v3['Gene Entrez ID'][genes_differences.index.to_list()]
    print(genes_differences)
print('.............................................................')  

### ------- "Metabolites Sheet" ------- ####
metabolites_equals = metabolites_v3.equals(metabolites_mc) 
print(f'"Metabolites" Sheet in both datasets are equal: {metabolites_v3.equals(metabolites_mc)}')
if not metabolites_equals:
    metabolites_differences = metabolites_v3.compare(metabolites_mc)
    metabolites_differences['BiGG ID'] = metabolites_v3['BiGG ID'][metabolites_differences.index.to_list()]
    print(metabolites_differences)
# Out:
# "Rxns" Sheet in both datasets are equal: False
#                            Curated                     GPR_Recon3D             \
#                               self   other                    self      other
# 40      basic tier 1 (Recon3DRxns)  CA/AMV                     NaN        NaN
# 41      basic tier 1 (Recon3DRxns)  CA/AMV                     NaN        NaN
# 42      basic tier 1 (Recon3DRxns)  CA/AMV                     NaN        NaN
# 43    basic tier 1 (RxnsWithNotes)  CA/AMV                     NaN        NaN
# 45    basic tier 1 (RxnsWithNotes)  CA/AMV                     NaN        NaN
# 46    basic tier 1 (RxnsWithNotes)  CA/AMV                     NaN        NaN
# 59    basic tier 1 (RxnsWithNotes)  CA/AMV                     NaN        NaN
# 60    basic tier 1 (RxnsWithNotes)  CA/AMV                     NaN        NaN
# 61    basic tier 1 (RxnsWithNotes)  CA/AMV                     NaN        NaN
# 63    basic tier 1 (RxnsWithNotes)  CA/AMV                     NaN        NaN
# 64    basic tier 1 (RxnsWithNotes)  CA/AMV                     NaN        NaN
# 65    basic tier 1 (RxnsWithNotes)  CA/AMV                     NaN        NaN
# 68    basic tier 1 (RxnsWithNotes)  CA/AMV                     NaN        NaN
# 70    basic tier 1 (RxnsWithNotes)  CA/AMV                     NaN        NaN
# 71    basic tier 1 (RxnsWithNotes)  CA/AMV                     NaN        NaN
# 75    basic tier 1 (RxnsWithNotes)  CA/AMV                     NaN        NaN
# 76    basic tier 1 (RxnsWithNotes)  CA/AMV                     NaN        NaN
# 77                             NaN     NaN  100765485 or 100765485  100765485
# 78    basic tier 1 (RxnsWithNotes)  CA/AMV                     NaN        NaN
# 79    basic tier 1 (RxnsWithNotes)  CA/AMV                     NaN        NaN
# 80    basic tier 1 (RxnsWithNotes)  CA/AMV                     NaN        NaN
# 83    basic tier 1 (RxnsWithNotes)  CA/AMV                     NaN        NaN
# 84        basic tier 2 (AllRecons)  CA/AMV                     NaN        NaN
# 85    basic tier 1 (RxnsWithNotes)  CA/AMV                     NaN        NaN
# 91    basic tier 1 (RxnsWithNotes)  CA/AMV                     NaN        NaN
# 363       basic tier 2 (AllRecons)      VM                     NaN        NaN
# 366       basic tier 2 (AllRecons)      VM                     NaN        NaN
# 367       basic tier 2 (AllRecons)      VM                     NaN        NaN
# 369       basic tier 2 (AllRecons)      VM                     NaN        NaN
# 371       basic tier 2 (AllRecons)      VM                     NaN        NaN
# 374       basic tier 2 (AllRecons)      VM                     NaN        NaN
# 1499    basic tier 1 (Recon3DRxns)  CA/AMV                     NaN        NaN
# 1502    basic tier 1 (Recon3DRxns)  CA/AMV                     NaN        NaN
# 1539    basic tier 1 (Recon3DRxns)  CA/AMV                     NaN        NaN
# 1802    basic tier 1 (Recon3DRxns)  CA/AMV                     NaN        NaN
# 1804    basic tier 1 (Recon3DRxns)  CA/AMV                     NaN        NaN
# 1808    basic tier 1 (Recon3DRxns)  CA/AMV                     NaN        NaN
# 3763    basic tier 1 (Recon3DRxns)  CA/AMV                     NaN        NaN
# 3765    basic tier 1 (Recon3DRxns)  CA/AMV                     NaN        NaN
# 3767    basic tier 1 (Recon3DRxns)  CA/AMV                     NaN        NaN
# 8625    basic tier 1 (Recon3DRxns)  CA/AMV                     NaN        NaN
# 8723                           NaN     NaN                     NaN        NaN
# 8999    basic tier 1 (Recon3DRxns)  CA/AMV                     NaN        NaN
# 9000    basic tier 1 (Recon3DRxns)  CA/AMV                     NaN        NaN
# 9001    basic tier 1 (Recon3DRxns)  CA/AMV                     NaN        NaN
# 9002    basic tier 1 (Recon3DRxns)  CA/AMV                     NaN        NaN
# 9043    basic tier 1 (Recon3DRxns)  CA/AMV                     NaN        NaN
# 9045    basic tier 1 (Recon3DRxns)  CA/AMV                     NaN        NaN
#
#                                               GPR_final  \
#                                                    self
# 40                                                  NaN
# 41                                                  NaN
# 42                                                  NaN
# 43                                                  NaN
# 45                                                  NaN
# 46                                                  NaN
# 59                                                  NaN
# 60                                                  NaN
# 61                                                  NaN
# 63                                                  NaN
# 64                                                  NaN
# 65                                                  NaN
# 68                                                  NaN
# 70                                                  NaN
# 71                                                  NaN
# 75                                                  NaN
# 76                                                  NaN
# 77                                                  NaN
# 78                                                  NaN
# 79                                                  NaN
# 80                                                  NaN
# 83                                                  NaN
# 84                                                  NaN
# 85                                                  NaN
# 91                                                  NaN
# 363                                                 NaN
# 366                                                 NaN
# 367                                           100762399
# 369                                                 NaN
# 371                                           100689344
# 374                                                 NaN
# 1499  100767558 or 100762480 or 100767558 or 1007675...
# 1502  100767558 or 100762480 or 100767558 or 1007675...
# 1539                             100762480 or 100767558
# 1802                             100762480 or 100767558
# 1804                             100762480 or 100767558
# 1808                             100762480 or 100767558
# 3763                             100762480 or 100767558
# 3765                             100762480 or 100767558
# 3767                             100762480 or 100767558
# 8625                                                NaN
# 8723  100766524 or 100750508 or 100766524 or 1007544...
# 8999                                                NaN
# 9000                                                NaN
# 9001                                                NaN
# 9002                                                NaN
# 9043                             100762480 or 100767558
# 9045                             100762480 or 100767558
#
#                                                         Conf. Score        \
#                                                   other        self other
# 40                                                  NaN                 1
# 41                                                  NaN                 1
# 42                                                  NaN                 1
# 43                                                  NaN        1.75     1
# 45                                                  NaN        1.75     1
# 46                                                  NaN        1.75     1
# 59                                                  NaN        1.75     2
# 60                                                  NaN        1.75     2
# 61                                                  NaN        1.75     1
# 63                                                  NaN        1.75     2
# 64                                                  NaN        1.75     1
# 65                                                  NaN        1.75     2
# 68                                                  NaN        1.75     2
# 70                                                  NaN        1.75     1
# 71                                                  NaN        1.75     1
# 75                                                  NaN        1.75     2
# 76                                                  NaN        1.75     1
# 77                                                  NaN         1.5     1
# 78                                                  NaN        1.75     1
# 79                                                  NaN        1.75     2
# 80                                                  NaN        1.75     2
# 83                                                  NaN        1.75     1
# 84                                                  NaN         1.5     1
# 85                                                  NaN        1.75     2
# 91                                                  NaN        1.75     1
# 363                                                 NaN         1.5     4
# 366                                                 NaN         1.5     4
# 367                                           100763881         1.5     4
# 369                                                 NaN         1.5     4
# 371                              100689344 or 100773203         1.5     3
# 374                                                 NaN         1.5     1
# 1499                100767558 or 100762480 or 100689220                 3
# 1502               100767558 or 100762480  or 100689220                 3
# 1539                100762480 or 100767558 or 100689220                 3
# 1802                100762480 or 100767558 or 100689220                 3
# 1804                100762480 or 100767558 or 100689220                 3
# 1808                100762480 or 100767558 or 100689220                 3
# 3763                100762480 or 100767558 or 100689220                 3
# 3765                100762480 or 100767558 or 100689220                 3
# 3767                100762480 or 100767558 or 100689220                 3
# 8625                                                NaN                 3
# 8723  100766524 or 100750508  or 100754462 or 100765...         NaN   NaN
# 8999                                                NaN                 1
# 9000                                                NaN                 1
# 9001                                                NaN                 1
# 9002                                                NaN                 1
# 9043                100762480 or 100767558 or 100689220                 3
# 9045                100762480 or 100767558 or 100689220                 3
#
#                                          Curation Notes  \
#                                                    self
# 40
# 41
# 42
# 43    PMID:2071588 describe the reaction in human. A...
# 45    see reaction: HPROym\n100767919 and 100751666 ...
# 46    see reaction: HPROxm\n100767919 and 100751666 ...
# 59    100773901 maps to 58510, "similar to proline d...
# 60    Cellular localization in cytosol (https://doi....
# 61                                                  NaN
# 63    100750856: mitochondrial, in vitro FAD respons...
# 64    PMID:12803540 describes two spermine/spermidin...
# 65    PMID:19764817 in the introduction part - good ...
# 68    EC 1.5.1.2 : both coenzymes used in related or...
# 70    PMID:12803540 describes two spermine/spermidin...
# 71                                                  NaN
# 75    PMID:2071588 states that ALDH-E1, E2 and E3 (c...
# 76    PMID:2071588 states that ALDH-E1, E2 and E3 (c...
# 77                                                  NaN
# 78    PMID: 4700449 shows glutamate decarboxylase ha...
# 79                                                  NaN
# 80                                                  NaN
# 83    https://www.genome.jp/entry/R01166, PMID: 3233...
# 84
# 85    PMID: 10319576 localizes the peroxisomal bifun...
# 91    PMID: 2069816 identifies the genes encoding th...
# 363
# 366
# 367
# 369
# 371
# 374
# 1499
# 1502
# 1539
# 1802
# 1804
# 1808
# 3763
# 3765
# 3767
# 8625
# 8723                                                NaN
# 8999
# 9000
# 9001
# 9002
# 9043
# 9045
#
#                                                         References  \
#                                                   other       self
# 40                                        EC:1.14.11.2
# 41                                        EC:1.14.11.2
# 42                                    Sat1, EC 2.3.1.57
# 43     All genes contain the appropriate domains to ...
# 45    see reaction: HPROym\n100767919 and 100751666 ...
# 46    see reaction: HPROxm\n100767919 and 100751666 ...
# 59                                           EC:1.5.5.2
# 60    Cellular localization in cytosol (https://doi....
# 61                                                  NaN        NaN
# 63                                           EC:1.5.5.2
# 64    PMID:12803540 describes two spermine/spermidin...
# 65    PMID:19764817 in the introduction part - good ...
# 68    EC 1.5.1.2 : both coenzymes used in related or...
# 70    PMID:12803540 describes two spermine/spermidin...
# 71                                                  NaN        NaN
# 75    PMID:2071588 states that ALDH-E1, E2 and E3 (c...
# 76    PMID:2071588 states that ALDH-E1, E2 and E3 (c...
# 77                                                  NaN        NaN
# 78                                         EC:4.1.1.15
# 79                                                  NaN
# 80                                                  NaN
# 83       https://www.rhea-db.org/rhea?query=CHEBI:29035
# 84                EC:1.1.1.35, EC:4.2.1.17 , EC:5.3.3.8
# 85    PMID: 10319576 localizes the peroxisomal bifun...
# 91                                       . EC:4.1.1.15
# 363                           PMID: 1780440 human PGM2
# 366                    PMID: 17585908 human ribokinase.
# 367          PMID: 27909055 purified enzyme from humans
# 369           PMID: 6882362 purified enzyme from humans
# 371   PMID: 8549825 human enzyme, PMID: 9524206 mous...
# 374   gene 100770798 (Nudt14) Hydrolyzes UDP-glucose...
# 1499  ID 100762480: Abcb11 ATP binding cassette subf...
# 1502  ID 100762480: Abcb11 ATP binding cassette subf...
# 1539  ID 100762480: Abcb11 ATP binding cassette subf...
# 1802  ID 100762480: Abcb11 ATP binding cassette subf...
# 1804  ID 100762480: Abcb11 ATP binding cassette subf...
# 1808  ID 100762480: Abcb11 ATP binding cassette subf...
# 3763  ID 100762480: Abcb11 ATP binding cassette subf...
# 3765  ID 100762480: Abcb11 ATP binding cassette subf...
# 3767  ID 100762480: Abcb11 ATP binding cassette subf...
# 8625  LOC100766524 cytochrome P450 3A9. (Annotation ...
# 8723                                                NaN        NaN
# 8999  LOC100766524 cytochrome P450 3A9. (Annotation ...
# 9000  LOC100766524 cytochrome P450 3A9. (Annotation ...
# 9001  LOC100766524 cytochrome P450 3A9. (Annotation ...
# 9002  LOC100766524 cytochrome P450 3A9. (Annotation ...
# 9043  ID 100762480: Abcb11 ATP binding cassette subf...
# 9045  ID 100762480: Abcb11 ATP binding cassette subf...
#
#                                                               Reaction
#                                                   other
# 40    PMCID: PMC1216881, https://www.uniprot.org/uni...       HMR_4776
# 41                                      PMCID: PMC99737       HMR_4777
# 42    PMID:2071588 describe the reaction in human., ...       HMR_6929
# 43    PMID:2071588 describe the reaction in human., ...       HMR_6939
# 45    PMID:23024808: PYCRL, localized in the cytosol...         HPROxm
# 46    PMID:23024808: PYCRL, localized in the cytosol...         HPROym
# 59    100773901 maps to 58510, "similar to proline d...          PRO1x
# 60    100773901 maps to 58510, "similar to proline d...         PRO1xm
# 61                                                  NaN     PROAKGOX1r
# 63    100750856: mitochondrial, in vitro FAD respons...         PROD2m
# 64                                       PMID: 10887189        PTRCAT1
# 65                                       PMID: 10887189        PTRCOX1
# 68                                       PMID: 21804562          r0617
# 70                                       PMID: 10887189        RE1234C
# 71                                                  NaN           SAT1
# 75                                       PMID: 21804562          ABUTD
# 76                                       PMID: 10702312         ABUTDm
# 77                                                  NaN        APAT2rm
# 78    PMID: 4700449 shows glutamate decarboxylase ha...         ASP1DC
# 79                                       PMID: 23929341     BAMPPALDOX
# 80                                       PMID: 21804562    BAMPPALDOXm
# 83    https://www.genome.jp/entry/R01166, PMID: 3233...       NBAHH_ir
# 84                                       PMID: 15060085    PRPNCOAHYDm
# 85                                       PMID: 23929341    PRPNCOAHYDx
# 91    PMID: 2069816 identifies the genes encoding th...          GLUDC
# 363                              10.1074/jbc.M706818200          r0570
# 366                       10.1016/j.febslet.2007.06.009            RBK
# 367                             10.1074/jbc.M116.760744          RBK_D
# 369                                   10.1042/bj2110617            RPE
# 371   10.1016/0014-5793(95)01446-2; 10.1016/s0378-11...           TALA
# 374                       10.1016/S0021-9258(18)96092-8         UDPG1P
# 1499  Rhea: 50048: cholate; Rhea 50052: taurocholate...      3DHDCAabc
# 1502  Rhea: 50048: cholate; Rhea 50052: taurocholate...      3DHLCAabc
# 1539  Rhea: 50048: cholate; Rhea 50052: taurocholate...   7KILTCHOLATP
# 1802  Rhea: 50048: cholate; Rhea 50052: taurocholate...      C03990ATP
# 1804  Rhea: 50048: cholate; Rhea 50052: taurocholate...       C04483t1
# 1808  Rhea: 50048: cholate; Rhea 50052: taurocholate...       C05463t1
# 3763  Rhea: 50048: cholate; Rhea 50052: taurocholate...     XOL7AH3ATP
# 3765  Rhea: 50048: cholate; Rhea 50052: taurocholate...    XOL7AONEATP
# 3767  Rhea: 50048: cholate; Rhea 50052: taurocholate...  XOLDIOLONEATP
# 8625  rhea-db.org/rhea/17149. 10.1016/0009-2797(71)9...        RE2474R
# 8723                                                NaN       HMR_2456
# 8999   rhea-db.org/rhea/17149. 10.1016/0009-2797(71)...         3DHCAS
# 9000   rhea-db.org/rhea/17149. 10.1016/0009-2797(71)...       3DHCDCAS
# 9001   rhea-db.org/rhea/17149. 10.1016/0009-2797(71)...        3DHDCAS
# 9002   rhea-db.org/rhea/17149. 10.1016/0009-2797(71)...        3DHLCAS
# 9043  Rhea: 50048: cholate; Rhea 50052: taurocholate...      HC02195te
# 9045  Rhea: 50048: cholate; Rhea 50052: taurocholate...      HC02196te
# .............................................................
# "Attributes" Sheet in both datasets are equal: False
#               EC Number           Reaction
#                    self     other
# 367  2.7.1.16, 2.7.1.47  2.7.1.47    RBK_D
# .............................................................
# "BoundaryRxns" Sheet in both datasets are equal: True
# .............................................................
# "Genes" Sheet in both datasets are equal: True
# .............................................................
# "Metabolites" Sheet in both datasets are equal: False
#      CHEBI          BiGG ID
#       self  other
# 6496        15421  pylald_c
# 6497        15421  pylald_m

# %% [markdown]
# ### 3.Update the v3 dataset with info from the manual curation dataset

# %%
# Update Rxns dataset
rxns_changed = False
if not rxns_equals:
    for index in rxns_differences.index:
        rxns_v3.loc[index].update(rxns_mc.loc[index])
        rxns_changed = True
else:
    print('No need to update "Rxns" Sheet')

# Update Attributes dataset
attributes_changed = False
if not rxns_attributes_equals:
    for index in rxns_attributes_differences.index:
        rxns_attributes_v3.loc[index].update(rxns_attributes_mc.loc[index])
        attributes_changed = True
else:
    print('No need to update "Attributes" Sheet')    

# Update Metabolites dataset
metabolites_changed = False
if not metabolites_equals:
    for index in metabolites_differences.index:
        metabolites_v3.loc[index].update(metabolites_mc.loc[index])
        metabolites_changed = True
else:
    print('No need to update "Metabolites" Sheet')
    
# Update Genes dataset
genes_changed = False
if not genes_equals:
    for index in genes_differences.index:
        genes_v3.loc[index].update(genes_mc.loc[index])
        genes_changed = True
else:
    print('No need to update "Genes" Sheet')
# Out:
# No need to update "Genes" Sheet

# %%
#############################################
#### ----------------------------------- ####
#### ---- Update Rxns Google Sheet ----- ####
#### ----------------------------------- ####
#############################################

#CHO Network Reconstruction + Recon3D_v3 Google Sheet ID
SPREADSHEET_ID = '1MlBXeHIKw8k8fZyXm-sN__AHTRSunJxar_-bqvukZws'

# Initialize the GoogleSheet object
sheet = GoogleSheet(SPREADSHEET_ID, KEY_FILE_PATH)

if rxns_changed:
    sheet.update_google_sheet(sheet_rxns, rxns_v3)
    print("Rxns Sheet updated.")

if attributes_changed:
    sheet.update_google_sheet(sheet_attributes, rxns_attributes_v3)
    print("Attributes Sheet updated.")
    
if genes_changed:
    sheet.update_google_sheet(sheet_genes, genes_v3)
    print("Genes Sheet updated.")

if metabolites_changed:
    sheet.update_google_sheet(sheet_met, metabolites_v3)
    print("Metabolites Sheet updated.")
# Out:
# Rxns Sheet updated.
# Attributes Sheet updated.
# Metabolites Sheet updated.
