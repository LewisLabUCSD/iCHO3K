# %% [markdown]
# # Standarization of Datasets
# The following notebook is intended for the standarization of the two Network Reconstruction datasets (the one generated in this reconstruction effort and the one that it is been manually curated). The idea of this notebook is to have the first dataset as back in case something goes bad in the manually curated dataset.

# %%
from google_sheet import GoogleSheet

# %% [markdown]
# ### 1.Generate the two sets of datasets

# %%
#Credential file
KEY_FILE_PATH = 'credentials.json'

# Read data from the Google Sheet (Sheet Names)
sheet_rxns = 'Rxns'
sheet_attributes = 'Attributes'
sheet_boundary = 'BoundaryRxns'
sheet_genes = 'Genes'
sheet_met = 'Metabolites'

# %%
##### ----- Generate datasets from CHO Network Reconstruction + Recon3D_v3 ----- #####

#CHO Network Reconstruction + Recon3D_v3 Google Sheet ID
SPREADSHEET_ID = '1MlBXeHIKw8k8fZyXm-sN__AHTRSunJxar_-bqvukZws'

# Initialize the GoogleSheet object
sheet = GoogleSheet(SPREADSHEET_ID, KEY_FILE_PATH)


rxns_v3 = sheet.read_google_sheet(sheet_rxns)
rxns_attributes_v3 = sheet.read_google_sheet(sheet_attributes)
boundary_rxns_v3 = sheet.read_google_sheet(sheet_boundary)
genes_v3 = sheet.read_google_sheet(sheet_genes)
metabolites_v3 = sheet.read_google_sheet(sheet_met)

# %%
##### ----- Generate datasets from Chinese Hamster Network Reconstruction ----- #####

#CHO Network Reconstruction + Recon3D_v3 Google Sheet ID
SPREADSHEET_ID = '1_bCHi0YbemnalomhVDmeHRJimxcVNI4GK6MoH3JdE8M'

# Initialize the GoogleSheet object
sheet = GoogleSheet(SPREADSHEET_ID, KEY_FILE_PATH)

rxns_mc = sheet.read_google_sheet(sheet_rxns)
rxns_attributes_mc = sheet.read_google_sheet(sheet_attributes)
boundary_rxns_mc = sheet.read_google_sheet(sheet_boundary)
genes_mc = sheet.read_google_sheet(sheet_genes)
metabolites_mc = sheet.read_google_sheet(sheet_met)

# %% [markdown]
# ### 2.Check if the datasets are equal

# %%
### ------- "Rxns Sheet" ------- ####
rxns_equals = rxns_v3.equals(rxns_mc)
print(f'"Rxns" Sheet in both datasets are equal: {rxns_v3.equals(rxns_mc)}')
if not rxns_equals:
    rxns_differences = rxns_v3.compare(rxns_mc)
    rxns_differences['Reaction'] = rxns_v3['Reaction'][rxns_differences.index.to_list()]
    print(rxns_differences)
print('.............................................................')    
rxns_attributes_equals = rxns_attributes_v3.equals(rxns_attributes_mc)    
print(f'"Attributes" Sheet in both datasets are equal: {rxns_attributes_v3.equals(rxns_attributes_mc)}')

### ------- "Attributes Sheet" ------- ####
if not rxns_attributes_equals:
    rxns_attributes_differences = rxns_attributes_v3.compare(rxns_attributes_mc)
    rxns_attributes_differences['Reaction'] = rxns_attributes_v3['Reaction'][rxns_attributes_differences.index.to_list()]
    print(rxns_attributes_differences)
print('.............................................................')      
boundary_rxns_equals = boundary_rxns_v3.equals(boundary_rxns_mc)     
print(f'"BoundaryRxns" Sheet in both datasets are equal: {boundary_rxns_v3.equals(boundary_rxns_mc)}')

### ------- "Boundary Rxns Sheet" ------- ####
if not boundary_rxns_equals:
    boundary_rxns_differences = boundary_rxns_v3.compare(boundary_rxns_mc)
    boundary_rxns_differences['Reaction'] = boundary_rxns_v3['Reaction'][boundary_rxns_differences.index.to_list()]
    print(boundary_rxns_differences)
print('.............................................................') 

### ------- "Genes Sheet" ------- ####
genes_equals = genes_v3.equals(genes_mc) 
print(f'"Genes" Sheet in both datasets are equal: {genes_v3.equals(genes_mc)}')
if not genes_equals:
    genes_differences = genes_v3.compare(genes_mc)
    genes_differences['Gene Entrez ID'] = genes_v3['Gene Entrez ID'][genes_differences.index.to_list()]
    print(genes_differences)
print('.............................................................')  

### ------- "Metabolites Sheet" ------- ####
metabolites_equals = metabolites_v3.equals(metabolites_mc) 
print(f'"Metabolites" Sheet in both datasets are equal: {metabolites_v3.equals(metabolites_mc)}')
if not metabolites_equals:
    metabolites_differences = metabolites_v3.compare(metabolites_mc)
    metabolites_differences['BiGG ID'] = metabolites_v3['BiGG ID'][metabolites_differences.index.to_list()]
    print(metabolites_differences)
# Out:
# "Rxns" Sheet in both datasets are equal: False
#       Curated       GPR_Recon3D             GPR_final  \
#          self other        self      other       self
# 217              VM         NaN        NaN        nan
# 219              VM         NaN        NaN        NaN
# 4770      NaN   NaN         NaN        NaN  100774298
# 4771      NaN   NaN         NaN        NaN  100774298
# 4937      NaN   NaN         NaN        NaN        NaN
# 4938      NaN   NaN         NaN        NaN        NaN
# 4939      NaN   NaN         NaN        NaN        NaN
# 4940      NaN   NaN         NaN        NaN        NaN
# 4941      NaN   NaN         NaN        NaN        NaN
# 4942      NaN   NaN         NaN        NaN        NaN
# 4943      NaN   NaN         NaN        NaN        NaN
# 4944      NaN   NaN         NaN        NaN        NaN
# 4945      NaN   NaN         NaN        NaN        NaN
# 4946      NaN   NaN         NaN        NaN        NaN
# 4947      NaN   NaN              100758204        NaN
# 4948      NaN   NaN         NaN        NaN        NaN
# 4949      NaN   NaN         NaN        NaN        NaN
# 4950      NaN   NaN         NaN        NaN        NaN
# 4951      NaN   NaN         NaN        NaN        NaN
# 4952      NaN   NaN         NaN        NaN        NaN
# 4953      NaN   NaN         NaN        NaN        NaN
# 4954      NaN   NaN         NaN        NaN        NaN
# 4955      NaN   NaN         NaN        NaN        NaN
# 4956      NaN   NaN         NaN        NaN        NaN
# 4957      NaN   NaN         NaN        NaN        NaN
# 4958      NaN   NaN         NaN        NaN        NaN
# 4959      NaN   NaN         NaN        NaN        NaN
# 4960      NaN   NaN         NaN        NaN        nan
# 4961      NaN   NaN         NaN        NaN        nan
# 10306            TA         NaN        NaN        nan
#
#                                                          Conf. Score        \
#                                                    other        self other
# 217                                            100773325                 4
# 219                                                  NaN                 4
# 4770   100774298, h10599 (be careful here, this is a ...         NaN   NaN
# 4771                                   100774298, h10599         NaN   NaN
# 4937                                                 NaN                 4
# 4938                                                 NaN                 4
# 4939                                                 NaN                 4
# 4940                                                 NaN                 4
# 4941                                                 NaN                 4
# 4942                                                 NaN                 4
# 4943                                                 NaN                 4
# 4944                                                 NaN                 4
# 4945                                                 NaN                 4
# 4946                                                 NaN                 4
# 4947                                                 NaN                 3
# 4948                                                 NaN                 3
# 4949                                                 NaN                 3
# 4950                                                 NaN                 3
# 4951                                                 NaN                 3
# 4952                                                 NaN                 4
# 4953                                                 NaN                 4
# 4954                                                 NaN                 4
# 4955                                                 NaN                 4
# 4956                                                 NaN                 4
# 4957                                                 NaN                 4
# 4958                                                 NaN                 2
# 4959                                                 NaN                 2
# 4960                                           100751684                 2
# 4961                                           100774101                 2
# 10306                                          100751194                 2
#
#                                           Curation Notes  \
#                                                     self
# 217                                                  NaN
# 219    PMID: 14927637 indicates the presence of 2 acy...
# 4770                                                 NaN
# 4771                                                 NaN
# 4937
# 4938
# 4939   According to PMID: 14598172, SLC25A2 and A15 h...
# 4940
# 4941
# 4942
# 4943   According to PMID: 14598172, SLC25A2 has this ...
# 4944
# 4945
# 4946
# 4947
# 4948
# 4949
# 4950
# 4951
# 4952
# 4953
# 4954
# 4955
# 4956
# 4957
# 4958
# 4959
# 4960
# 4961
# 10306
#
#                                                          References  \
#                                                    other       self
# 217                                                  NaN
# 219    PMID: 14927637 indicates the presence of 2 acy...
# 4770                                                 NaN        NaN
# 4771                                                 NaN        NaN
# 4937   Mitochondrial ornithine carrier 2 (ORC2 or Orn...
# 4938   Mitochondrial ornithine carrier 2 (ORC2 or Orn...
# 4939   Mitochondrial ornithine carrier 2 (ORC2 or Orn...
# 4940   Mitochondrial ornithine carrier 2 (ORC2 or Orn...
# 4941   Mitochondrial ornithine carrier 2 (ORC2 or Orn...
# 4942   Mitochondrial ornithine carrier 2 (ORC2 or Orn...
# 4943   Mitochondrial ornithine carrier 2 (ORC2 or Orn...
# 4944   Mitochondrial ornithine carrier 2 (ORC2 or Orn...
# 4945   Mitochondrial ornithine carrier 2 (ORC2 or Orn...
# 4946   Mitochondrial ornithine carrier 2 (ORC2 or Orn...
# 4947   This intronless gene encodes a protein that lo...
# 4948   This intronless gene encodes a protein that lo...
# 4949   Mitochondrial dicarboxylate carrier (DIC; SLC2...
# 4950   Mitochondrial dicarboxylate carrier (DIC; SLC2...
# 4951   Reported to be a deoxynucleotide (enzyme), the...
# 4952   Human mitochondrial carnitine/acyl carnitine c...
# 4953   Human mitochondrial carnitine/acyl carnitine c...
# 4954   Human mitochondrial carnitine/acyl carnitine c...
# 4955   Human mitochondrial carnitine/acyl carnitine c...
# 4956   Human mitochondrial carnitine/acyl carnitine c...
# 4957   Human mitochondrial carnitine/acyl carnitine c...
# 4958        Canicular sulfate:HCO3- antiporter (Slc26a1)        NaN
# 4959   Peroxysomal fatty acyl CoA synthase (ligase) o...        NaN
# 4960   Pyrimidine-preferring nucleoside:Na+ symporter...
# 4961   Purine nucleoside, uridine, and 2'3'dideoxyino...
# 10306  The expression of the gene has not been identi...        NaN
#
#                                                            Reaction
#                                                    other
# 217    10.1016/s0021-9258(19)40033-1 ; 10.1016/S0021-...      ACITL
# 219    10.1016/S0021-9258(18)55898-1; 10.1016/0014-57...      ACODA
# 4770                                                 NaN      r2218
# 4771                                                 NaN      r2219
# 4937                           10.1007/s10534-011-9479-5      r2402
# 4938                           10.1007/s10534-011-9479-5      r2403
# 4939                           10.1007/s10534-011-9479-5      r2404
# 4940                           10.1007/s10534-011-9479-5      r2405
# 4941                           10.1007/s10534-011-9479-5      r2406
# 4942                           10.1007/s10534-011-9479-5      r2407
# 4943                           10.1007/s10534-011-9479-5      r2408
# 4944                           10.1007/s10534-011-9479-5      r2409
# 4945                           10.1007/s10534-011-9479-5      r2410
# 4946                           10.1007/s10534-011-9479-5      r2411
# 4947                             10.1074/jbc.M111.324855      r2412
# 4948                             10.1074/jbc.M111.324855      r2416
# 4949                       10.1016/j.jbiotec.2011.09.014      r2419
# 4950                       10.1016/j.jbiotec.2011.09.014      r2420
# 4951                       10.1016/j.jbiotec.2011.09.014      r2425
# 4952   10.1080/09687680701697476 , 10.1006/bbrc.1998....      r2433
# 4953   10.1080/09687680701697476 , 10.1006/bbrc.1998....      r2434
# 4954   10.1080/09687680701697476 , 10.1006/bbrc.1998....      r2435
# 4955   10.1080/09687680701697476 , 10.1006/bbrc.1998....      r2436
# 4956   10.1080/09687680701697476 , 10.1006/bbrc.1998....      r2437
# 4957   10.1080/09687680701697476 , 10.1006/bbrc.1998....      r2438
# 4958                                                 NaN      r2439
# 4959                                                 NaN      r2444
# 4960                        10.1016/j.bbamem.2020.183247      r2447
# 4961                        10.1016/j.bbamem.2020.183247      r2449
# 10306                                                NaN  ARGATB0tc
# .............................................................
# "Attributes" Sheet in both datasets are equal: True
# .............................................................
# "BoundaryRxns" Sheet in both datasets are equal: True
# .............................................................
# "Genes" Sheet in both datasets are equal: True
# .............................................................
# "Metabolites" Sheet in both datasets are equal: True

# %%
rxns_differences
# Out:
#       Curated       GPR_Recon3D             GPR_final  \
#          self other        self      other       self
# 217              VM         NaN        NaN        nan
# 219              VM         NaN        NaN        NaN
# 4770      NaN   NaN         NaN        NaN  100774298
# 4771      NaN   NaN         NaN        NaN  100774298
# 4937      NaN   NaN         NaN        NaN        NaN
# 4938      NaN   NaN         NaN        NaN        NaN
# 4939      NaN   NaN         NaN        NaN        NaN
# 4940      NaN   NaN         NaN        NaN        NaN
# 4941      NaN   NaN         NaN        NaN        NaN
# 4942      NaN   NaN         NaN        NaN        NaN
# 4943      NaN   NaN         NaN        NaN        NaN
# 4944      NaN   NaN         NaN        NaN        NaN
# 4945      NaN   NaN         NaN        NaN        NaN
# 4946      NaN   NaN         NaN        NaN        NaN
# 4947      NaN   NaN              100758204        NaN
# 4948      NaN   NaN         NaN        NaN        NaN
# 4949      NaN   NaN         NaN        NaN        NaN
# 4950      NaN   NaN         NaN        NaN        NaN
# 4951      NaN   NaN         NaN        NaN        NaN
# 4952      NaN   NaN         NaN        NaN        NaN
# 4953      NaN   NaN         NaN        NaN        NaN
# 4954      NaN   NaN         NaN        NaN        NaN
# 4955      NaN   NaN         NaN        NaN        NaN
# 4956      NaN   NaN         NaN        NaN        NaN
# 4957      NaN   NaN         NaN        NaN        NaN
# 4958      NaN   NaN         NaN        NaN        NaN
# 4959      NaN   NaN         NaN        NaN        NaN
# 4960      NaN   NaN         NaN        NaN        nan
# 4961      NaN   NaN         NaN        NaN        nan
# 10306            TA         NaN        NaN        nan
#
#                                                          Conf. Score        \
#                                                    other        self other
# 217                                            100773325                 4
# 219                                                  NaN                 4
# 4770   100774298, h10599 (be careful here, this is a ...         NaN   NaN
# 4771                                   100774298, h10599         NaN   NaN
# 4937                                                 NaN                 4
# 4938                                                 NaN                 4
# 4939                                                 NaN                 4
# 4940                                                 NaN                 4
# 4941                                                 NaN                 4
# 4942                                                 NaN                 4
# 4943                                                 NaN                 4
# 4944                                                 NaN                 4
# 4945                                                 NaN                 4
# 4946                                                 NaN                 4
# 4947                                                 NaN                 3
# 4948                                                 NaN                 3
# 4949                                                 NaN                 3
# 4950                                                 NaN                 3
# 4951                                                 NaN                 3
# 4952                                                 NaN                 4
# 4953                                                 NaN                 4
# 4954                                                 NaN                 4
# 4955                                                 NaN                 4
# 4956                                                 NaN                 4
# 4957                                                 NaN                 4
# 4958                                                 NaN                 2
# 4959                                                 NaN                 2
# 4960                                           100751684                 2
# 4961                                           100774101                 2
# 10306                                          100751194                 2
#
#                                           Curation Notes  \
#                                                     self
# 217                                                  NaN
# 219    PMID: 14927637 indicates the presence of 2 acy...
# 4770                                                 NaN
# 4771                                                 NaN
# 4937
# 4938
# 4939   According to PMID: 14598172, SLC25A2 and A15 h...
# 4940
# 4941
# 4942
# 4943   According to PMID: 14598172, SLC25A2 has this ...
# 4944
# 4945
# 4946
# 4947
# 4948
# 4949
# 4950
# 4951
# 4952
# 4953
# 4954
# 4955
# 4956
# 4957
# 4958
# 4959
# 4960
# 4961
# 10306
#
#                                                          References  \
#                                                    other       self
# 217                                                  NaN
# 219    PMID: 14927637 indicates the presence of 2 acy...
# 4770                                                 NaN        NaN
# 4771                                                 NaN        NaN
# 4937   Mitochondrial ornithine carrier 2 (ORC2 or Orn...
# 4938   Mitochondrial ornithine carrier 2 (ORC2 or Orn...
# 4939   Mitochondrial ornithine carrier 2 (ORC2 or Orn...
# 4940   Mitochondrial ornithine carrier 2 (ORC2 or Orn...
# 4941   Mitochondrial ornithine carrier 2 (ORC2 or Orn...
# 4942   Mitochondrial ornithine carrier 2 (ORC2 or Orn...
# 4943   Mitochondrial ornithine carrier 2 (ORC2 or Orn...
# 4944   Mitochondrial ornithine carrier 2 (ORC2 or Orn...
# 4945   Mitochondrial ornithine carrier 2 (ORC2 or Orn...
# 4946   Mitochondrial ornithine carrier 2 (ORC2 or Orn...
# 4947   This intronless gene encodes a protein that lo...
# 4948   This intronless gene encodes a protein that lo...
# 4949   Mitochondrial dicarboxylate carrier (DIC; SLC2...
# 4950   Mitochondrial dicarboxylate carrier (DIC; SLC2...
# 4951   Reported to be a deoxynucleotide (enzyme), the...
# 4952   Human mitochondrial carnitine/acyl carnitine c...
# 4953   Human mitochondrial carnitine/acyl carnitine c...
# 4954   Human mitochondrial carnitine/acyl carnitine c...
# 4955   Human mitochondrial carnitine/acyl carnitine c...
# 4956   Human mitochondrial carnitine/acyl carnitine c...
# 4957   Human mitochondrial carnitine/acyl carnitine c...
# 4958        Canicular sulfate:HCO3- antiporter (Slc26a1)        NaN
# 4959   Peroxysomal fatty acyl CoA synthase (ligase) o...        NaN
# 4960   Pyrimidine-preferring nucleoside:Na+ symporter...
# 4961   Purine nucleoside, uridine, and 2'3'dideoxyino...
# 10306  The expression of the gene has not been identi...        NaN
#
#                                                            Reaction
#                                                    other
# 217    10.1016/s0021-9258(19)40033-1 ; 10.1016/S0021-...      ACITL
# 219    10.1016/S0021-9258(18)55898-1; 10.1016/0014-57...      ACODA
# 4770                                                 NaN      r2218
# 4771                                                 NaN      r2219
# 4937                           10.1007/s10534-011-9479-5      r2402
# 4938                           10.1007/s10534-011-9479-5      r2403
# 4939                           10.1007/s10534-011-9479-5      r2404
# 4940                           10.1007/s10534-011-9479-5      r2405
# 4941                           10.1007/s10534-011-9479-5      r2406
# 4942                           10.1007/s10534-011-9479-5      r2407
# 4943                           10.1007/s10534-011-9479-5      r2408
# 4944                           10.1007/s10534-011-9479-5      r2409
# 4945                           10.1007/s10534-011-9479-5      r2410
# 4946                           10.1007/s10534-011-9479-5      r2411
# 4947                             10.1074/jbc.M111.324855      r2412
# 4948                             10.1074/jbc.M111.324855      r2416
# 4949                       10.1016/j.jbiotec.2011.09.014      r2419
# 4950                       10.1016/j.jbiotec.2011.09.014      r2420
# 4951                       10.1016/j.jbiotec.2011.09.014      r2425
# 4952   10.1080/09687680701697476 , 10.1006/bbrc.1998....      r2433
# 4953   10.1080/09687680701697476 , 10.1006/bbrc.1998....      r2434
# 4954   10.1080/09687680701697476 , 10.1006/bbrc.1998....      r2435
# 4955   10.1080/09687680701697476 , 10.1006/bbrc.1998....      r2436
# 4956   10.1080/09687680701697476 , 10.1006/bbrc.1998....      r2437
# 4957   10.1080/09687680701697476 , 10.1006/bbrc.1998....      r2438
# 4958                                                 NaN      r2439
# 4959                                                 NaN      r2444
# 4960                        10.1016/j.bbamem.2020.183247      r2447
# 4961                        10.1016/j.bbamem.2020.183247      r2449
# 10306                                                NaN  ARGATB0tc

# %% [markdown]
# ### 3.Update the v3 dataset with info from the manual curation dataset

# %%
# Update Rxns dataset
rxns_changed = False
if not rxns_equals:
    for index in rxns_differences.index:
        rxns_v3.loc[index].update(rxns_mc.loc[index])
        rxns_changed = True
else:
    print('No need to update "Rxns" Sheet datasets')

# Update Attributes dataset
attributes_changed = False
if not rxns_attributes_equals:
    for index in rxns_attributes_differences.index:
        rxns_attributes_v3.loc[index].update(rxns_attributes_mc.loc[index])
        attributes_changed = True
else:
    print('No need to update "Attributes" Sheet datasets')    

# Update Metabolites dataset
metabolites_changed = False
if not metabolites_equals:
    for index in metabolites_differences.index:
        metabolites_v3.loc[index].update(metabolites_mc.loc[index])
        metabolites_changed = True
else:
    print('No need to update "Metabolites" Sheet datasets')
# Out:
# No need to update "Attributes" Sheet datasets
# No need to update "Metabolites" Sheet datasets

# %%
#############################################
#### ----------------------------------- ####
#### ---- Update Rxns Google Sheet ----- ####
#### ----------------------------------- ####
#############################################

#CHO Network Reconstruction + Recon3D_v3 Google Sheet ID
SPREADSHEET_ID = '1MlBXeHIKw8k8fZyXm-sN__AHTRSunJxar_-bqvukZws'

# Initialize the GoogleSheet object
sheet = GoogleSheet(SPREADSHEET_ID, KEY_FILE_PATH)

if rxns_changed:
    sheet.update_google_sheet(sheet_rxns, rxns_v3)
    print("Rxns Sheet updated.")

if attributes_changed:
    sheet.update_google_sheet(sheet_attributes, rxns_attributes_v3)
    print("Attributes Sheet updated.")

if metabolites_changed:
    sheet.update_google_sheet(sheet_met, metabolites_v3)
    print("Metabolites Sheet updated.")
# Out:
# Rxns Sheet updated.
