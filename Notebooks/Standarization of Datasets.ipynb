# %% [markdown]
# # Standarization of Datasets
# The following notebook is intended for the standarization of the two Network Reconstruction datasets (the one generated in this reconstruction effort and the one that it is been manually curated). The idea of this notebook is to have the first dataset as back in case something goes bad in the manually curated dataset.

# %%
from google_sheet import GoogleSheet

# %% [markdown]
# ### 1.Generate the two sets of datasets

# %%
#Credential file
KEY_FILE_PATH = 'credentials.json'

# Read data from the Google Sheet (Sheet Names)
sheet_rxns = 'Rxns'
sheet_attributes = 'Attributes'
sheet_boundary = 'BoundaryRxns'
sheet_genes = 'Genes'
sheet_met = 'Metabolites'

# %%
##### ----- Generate datasets from CHO Network Reconstruction + Recon3D_v3 ----- #####

#CHO Network Reconstruction + Recon3D_v3 Google Sheet ID
SPREADSHEET_ID = '1MlBXeHIKw8k8fZyXm-sN__AHTRSunJxar_-bqvukZws'

# Initialize the GoogleSheet object
sheet = GoogleSheet(SPREADSHEET_ID, KEY_FILE_PATH)


rxns_v3 = sheet.read_google_sheet(sheet_rxns)
rxns_attributes_v3 = sheet.read_google_sheet(sheet_attributes)
boundary_rxns_v3 = sheet.read_google_sheet(sheet_boundary)
genes_v3 = sheet.read_google_sheet(sheet_genes)
metabolites_v3 = sheet.read_google_sheet(sheet_met)

# %%
##### ----- Generate datasets from Chinese Hamster Network Reconstruction ----- #####

#CHO Network Reconstruction + Recon3D_v3 Google Sheet ID
SPREADSHEET_ID = '1_bCHi0YbemnalomhVDmeHRJimxcVNI4GK6MoH3JdE8M'

# Initialize the GoogleSheet object
sheet = GoogleSheet(SPREADSHEET_ID, KEY_FILE_PATH)

rxns_mc = sheet.read_google_sheet(sheet_rxns)
rxns_attributes_mc = sheet.read_google_sheet(sheet_attributes)
boundary_rxns_mc = sheet.read_google_sheet(sheet_boundary)
genes_mc = sheet.read_google_sheet(sheet_genes)
metabolites_mc = sheet.read_google_sheet(sheet_met)

# %% [markdown]
# ### 2.Check if the datasets are equal

# %%
### ------- "Rxns Sheet" ------- ####
rxns_equals = rxns_v3.equals(rxns_mc)
print(f'"Rxns" Sheet in both datasets are equal: {rxns_v3.equals(rxns_mc)}')
if not rxns_equals:
    rxns_differences = rxns_v3.compare(rxns_mc)
    rxns_differences['Reaction'] = rxns_v3['Reaction'][rxns_differences.index.to_list()]
    print(rxns_differences)
print('.............................................................')    
rxns_attributes_equals = rxns_attributes_v3.equals(rxns_attributes_mc)    
print(f'"Attributes" Sheet in both datasets are equal: {rxns_attributes_v3.equals(rxns_attributes_mc)}')

### ------- "Attributes Sheet" ------- ####
if not rxns_attributes_equals:
    rxns_attributes_differences = rxns_attributes_v3.compare(rxns_attributes_mc)
    rxns_attributes_differences['Reaction'] = rxns_attributes_v3['Reaction'][rxns_attributes_differences.index.to_list()]
    print(rxns_attributes_differences)
print('.............................................................')      
boundary_rxns_equals = boundary_rxns_v3.equals(boundary_rxns_mc)     
print(f'"BoundaryRxns" Sheet in both datasets are equal: {boundary_rxns_v3.equals(boundary_rxns_mc)}')

### ------- "Boundary Rxns Sheet" ------- ####
if not boundary_rxns_equals:
    boundary_rxns_differences = boundary_rxns_v3.compare(boundary_rxns_mc)
    boundary_rxns_differences['Reaction'] = boundary_rxns_v3['Reaction'][boundary_rxns_differences.index.to_list()]
    print(boundary_rxns_differences)
print('.............................................................') 

### ------- "Genes Sheet" ------- ####
genes_equals = genes_v3.equals(genes_mc) 
print(f'"Genes" Sheet in both datasets are equal: {genes_v3.equals(genes_mc)}')
if not genes_equals:
    genes_differences = genes_v3.compare(genes_mc)
    genes_differences['Gene Entrez ID'] = genes_v3['Gene Entrez ID'][genes_differences.index.to_list()]
    print(genes_differences)
print('.............................................................')  

### ------- "Metabolites Sheet" ------- ####
metabolites_equals = metabolites_v3.equals(metabolites_mc) 
print(f'"Metabolites" Sheet in both datasets are equal: {metabolites_v3.equals(metabolites_mc)}')
if not metabolites_equals:
    metabolites_differences = metabolites_v3.compare(metabolites_mc)
    metabolites_differences['BiGG ID'] = metabolites_v3['BiGG ID'][metabolites_differences.index.to_list()]
    print(metabolites_differences)
# Out:
# "Rxns" Sheet in both datasets are equal: False
#      Curated                                             Reaction Formula  \
#         self     other                                               self
# 5017          SCH/ALSA                                                NaN
# 5018          SCH/ALSA                                                NaN
# 5019          SCH/ALSA                                                NaN
# 5021          SCH/ALSA                                                NaN
# 5022          SCH/ALSA                                                NaN
# 5023          SCH/ALSA                                                NaN
# 5024          SCH/ALSA                                                NaN
# 5025          SCH/ALSA                                                NaN
# 5026          SCH/ALSA                                                NaN
# 5027          SCH/ALSA                                                NaN
# 5028          SCH/ALSA                                                NaN
# 5029          SCH/ALSA                                                NaN
# 5030          SCH/ALSA                                                NaN
# 5031          SCH/ALSA                                                NaN
# 5032          SCH/ALSA                                                NaN
# 5033          SCH/ALSA                                                NaN
# 5034          SCH/ALSA                                                NaN
# 5035          SCH/ALSA                                                NaN
# 5036          SCH/ALSA                                                NaN
# 5037          SCH/ALSA                                                NaN
# 5041          SCH/ALSA                                                NaN
# 5043     NaN       NaN                                                NaN
# 5257                CO                                                NaN
# 7730                SB                                                NaN
# 7731                SB                                                NaN
# 7732                SB                                                NaN
# 7733                SB                                                NaN
# 9055                DC  CE6451_c + ascb_L_c <=> CE6467_c + dhdascb_c +...
# 9056                DC  CE6451_c + ascb_L_c <=> CE6466_c + dhdascb_c +...
#
#                                                         GPR_hef       GPR_fou  \
#                                                   other    self other    self
# 5017                                                NaN     NaN   NaN     NaN
# 5018                                                NaN     NaN   NaN     NaN
# 5019                                                NaN     NaN   NaN     NaN
# 5021                                                NaN     NaN   NaN     NaN
# 5022                                                NaN     NaN   NaN     NaN
# 5023                                                NaN     NaN   NaN     NaN
# 5024                                                NaN     NaN   NaN     NaN
# 5025                                                NaN     NaN   NaN     NaN
# 5026                                                NaN    None          None
# 5027                                                NaN     NaN   NaN     NaN
# 5028                                                NaN     NaN   NaN     NaN
# 5029                                                NaN     NaN   NaN     NaN
# 5030                                                NaN     NaN   NaN     NaN
# 5031                                                NaN     NaN   NaN     NaN
# 5032                                                NaN     NaN   NaN     NaN
# 5033                                                NaN     NaN   NaN     NaN
# 5034                                                NaN     NaN   NaN     NaN
# 5035                                                NaN     NaN   NaN     NaN
# 5036                                                NaN     NaN   NaN     NaN
# 5037                                                NaN     NaN   NaN     NaN
# 5041                                                NaN     NaN   NaN     NaN
# 5043                                                NaN     NaN   NaN     NaN
# 5257                                                NaN     NaN   NaN     NaN
# 7730                                                NaN     NaN   NaN     NaN
# 7731                                                NaN     NaN   NaN     NaN
# 7732                                                NaN     NaN   NaN     NaN
# 7733                                                NaN     NaN   NaN     NaN
# 9055  CE6451_c + ascb_L_c + h_c <=> CE6467_c + dhdas...     NaN   NaN     NaN
# 9056  CE6451_c + ascb_L_c + h_c <=> CE6466_c + dhdas...     NaN   NaN     NaN
#
#            GPR_yeo        ... GPR_Recon3D GPR_final  \
#      other    self other  ...       other      self
# 5017   NaN     NaN   NaN  ...         NaN       NaN
# 5018   NaN     NaN   NaN  ...         NaN       NaN
# 5019   NaN     NaN   NaN  ...         NaN       NaN
# 5021   NaN     NaN   NaN  ...         NaN       NaN
# 5022   NaN     NaN   NaN  ...         NaN       NaN
# 5023   NaN     NaN   NaN  ...         NaN       NaN
# 5024   NaN     NaN   NaN  ...         NaN       NaN
# 5025   NaN     NaN   NaN  ...         NaN       NaN
# 5026          None        ...                  None
# 5027   NaN     NaN   NaN  ...         NaN       NaN
# 5028   NaN     NaN   NaN  ...         NaN       NaN
# 5029   NaN     NaN   NaN  ...         NaN       NaN
# 5030   NaN     NaN   NaN  ...         NaN       NaN
# 5031   NaN     NaN   NaN  ...         NaN       NaN
# 5032   NaN     NaN   NaN  ...         NaN       NaN
# 5033   NaN     NaN   NaN  ...         NaN       NaN
# 5034   NaN     NaN   NaN  ...         NaN       NaN
# 5035   NaN     NaN   NaN  ...         NaN       NaN
# 5036   NaN     NaN   NaN  ...         NaN       NaN
# 5037   NaN     NaN   NaN  ...         NaN       NaN
# 5041   NaN     NaN   NaN  ...         NaN       NaN
# 5043   NaN     NaN   NaN  ...         NaN       NaN
# 5257   NaN     NaN   NaN  ...         NaN       NaN
# 7730   NaN     NaN   NaN  ...         NaN       nan
# 7731   NaN     NaN   NaN  ...         NaN       nan
# 7732   NaN     NaN   NaN  ...         NaN       nan
# 7733   NaN     NaN   NaN  ...         NaN       NaN
# 9055   NaN     NaN   NaN  ...         NaN       NaN
# 9056   NaN     NaN   NaN  ...         NaN       NaN
#
#                                                         Conf. Score        \
#                                                   other        self other
# 5017                                                NaN                 3
# 5018                                                NaN                 2
# 5019                                                NaN                 3
# 5021                                                NaN                 1
# 5022                                                NaN                 1
# 5023                                                NaN                 2
# 5024                                                NaN                 2
# 5025                                                NaN                 4
# 5026                                                           None     1
# 5027                                                NaN                 1
# 5028                                                NaN                 1
# 5029                                                NaN                 1
# 5030                                                NaN                 1
# 5031                                                NaN                 2
# 5032                                                NaN                 2
# 5033                                                NaN                 3
# 5034                                                NaN                 3
# 5035                                                NaN        None     3
# 5036                                                NaN        None     3
# 5037                                                NaN        None     3
# 5041                                                NaN                 1
# 5043                                                NaN                 3
# 5257                                                NaN                 4
# 7730                                          100769105                 4
# 7731                100771717 or 100755179 or 100760749                 4
# 7732  100754096 or 100762756 or 100761571 or 1007683...                 3
# 7733                                                NaN                 3
# 9055                                                NaN         NaN   NaN
# 9056                                                NaN         NaN   NaN
#
#                                          Curation Notes  \
#                                                    self
# 5017                                                NaN
# 5018                                                NaN
# 5019                                                NaN
# 5021                                                NaN
# 5022                                                NaN
# 5023                                                NaN
# 5024                                                NaN
# 5025                                                NaN
# 5026                                                NaN
# 5027                                                NaN
# 5028                                                NaN
# 5029                                                NaN
# 5030                                                NaN
# 5031                                                NaN
# 5032                                                NaN
# 5033                                                NaN
# 5034                                                NaN
# 5035                                               None
# 5036                                               None
# 5037                                               None
# 5041                                                NaN
# 5043                                                NaN
# 5257  PMID:15059618 identifies biotinidase colocaliz...
# 7730
# 7731  PMID: 12611890 shows activity for Aldolase A (...
# 7732  100754096, 100768313, 100762756, and 100761571...
# 7733
# 9055                                                NaN
# 9056                                                NaN
#
#                                                         References  \
#                                                   other       self
# 5017                                                NaN
# 5018                                                NaN
# 5019                                                NaN
# 5021                                                NaN        NaN
# 5022                                                NaN
# 5023                                                NaN
# 5024                                                NaN
# 5025                                                NaN
# 5026                                                NaN        NaN
# 5027                                                NaN        NaN
# 5028                                                NaN        NaN
# 5029                                                NaN        NaN
# 5030                                                NaN        NaN
# 5031                                                NaN
# 5032                                                NaN
# 5033                                                NaN        NaN
# 5034                                                NaN
# 5035                                                          None
# 5036                                                          None
# 5037                                                          None
# 5041                                                NaN        NaN
# 5043                                                NaN        NaN
# 5257  100755324 is CHO biotinidase. PMID:15059618 id...
# 7730  PMID: 16086588 describes the reaction in human...
# 7731  PMID: 12611890 and PMID: 15537755 describes th...
# 7732  PMID: 15170386 describes the reaction in human...
# 7733  PMID: 12056818 describes the reaction in human...
# 9055                                                NaN        NaN
# 9056                                                NaN        NaN
#
#                                                           Reaction
#                                                   other
# 5017        https://pubmed.ncbi.nlm.nih.gov/17324376/\r   ACP1_FMN
# 5018  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6...     ASCBOX
# 5019  https://www.sciencedirect.com/science/article/...       BCDO
# 5021                                                NaN     CBL2OR
# 5022                 DOI: 10.1016/s0950-3536(05)80221-5     CBLATm
# 5023      https://www.ncbi.nlm.nih.gov/books/NBK278935/     CYP2R1
# 5024  Suppressive role of regucalcin in liver cell p...     DASCBH
# 5025  Ascorbic acid metabolism and functions: A comp...     DASCBR
# 5026                                                NaN      DHFRx
# 5027                                                NaN   DOGULND1
# 5028                                                NaN   DOGULND2
# 5029                                                NaN   DOGULNO1
# 5030                                                NaN   DOGULNO2
# 5031           https://pubmed.ncbi.nlm.nih.gov/2848456/      FADDP
# 5032           https://pubmed.ncbi.nlm.nih.gov/2848456/    FADDPle
# 5033                                                NaN      FEROc
# 5034  Structure and Mechanism of a Eukaryotic FMN Ad...      FMNAT
# 5035  Cytosolic 10-formyltetrahydrofolate dehydrogen...    FTHFDHm
# 5036  Minireview. Emerging new functions of the glyc...      GAPD2
# 5037  Minireview. Emerging new functions of the glyc...      GAPD3
# 5041                                                NaN  GLNLASEer
# 5043                                                NaN      GTHDH
# 5257        https://doi.org/10.1016/j.ymgme.2003.12.006      BTNDe
# 7730                                  10.1021/bi0503605      F1PGT
# 7731        10.1074/jbc.M209185200, 10.1110/ps.04915904       FBA2
# 7732     10.1042/BJ20040752, 10.1016/j.cell.2006.05.036      FBP26
# 7733                      10.1016/S0006-291X(02)00541-7         FK
# 9055                                                NaN    RE2878C
# 9056                                                NaN    RE2880C
#
# [29 rows x 21 columns]
# .............................................................
# "Attributes" Sheet in both datasets are equal: True
# .............................................................
# "BoundaryRxns" Sheet in both datasets are equal: True
# .............................................................
# "Genes" Sheet in both datasets are equal: True
# .............................................................
# "Metabolites" Sheet in both datasets are equal: False
#      Curated               Formula                 Charge       CHEBI         \
#         self other            self           other   self other  self  other
# 591      NaN   NaN             NaN             NaN           -1   NaN    NaN
# 2428            DC             NaN             NaN    NaN   NaN        53206
# 2429            DC             NaN             NaN    NaN   NaN        53206
# 2430            DC             NaN             NaN           -1        53206
# 2431            DC             NaN             NaN    NaN   NaN        53206
# 4500            DC  C30H52N7O17P3S  C30H48N7O17P3S    NaN   NaN        84847
# 4501            DC             NaN             NaN    NaN   NaN   NaN    NaN
# 4502            DC             NaN             NaN    NaN   NaN   NaN    NaN
# 4503            DC             NaN             NaN    NaN   NaN   NaN    NaN
#
#      INCHI2        ... Charge of the Metabolite Identified CID_ID        \
#        self other  ...                               other   self other
# 591     NaN   NaN  ...                                 NaN    NaN   NaN
# 2428   None        ...                                       None
# 2429   None        ...                                       None
# 2430   None        ...                                       None
# 2431   None        ...                                       None
# 4500    NaN   NaN  ...                                 NaN    NaN   NaN
# 4501    NaN   NaN  ...                                 NaN    NaN   NaN
# 4502    NaN   NaN  ...                                 NaN    NaN   NaN
# 4503    NaN   NaN  ...                                 NaN    NaN   NaN
#
#      PDB (ligand-expo) Experimental Coordinates  File Url       Pub Chem Url  \
#                                                      self other         self
# 591                                                 NaN     NaN          NaN
# 2428                                               None                 None
# 2429                                               None                 None
# 2430                                               None                 None
# 2431                                               None                 None
# 4500                                                NaN     NaN          NaN
# 4501                                                NaN     NaN          NaN
# 4502                                                NaN     NaN          NaN
# 4503                                                NaN     NaN          NaN
#
#            ChEBI Url                                                     \
#      other      self                                              other
# 591    NaN       NaN                                                NaN
# 2428            None  https://www.ebi.ac.uk/chebi/searchId.do?chebiI...
# 2429            None  https://www.ebi.ac.uk/chebi/searchId.do?chebiI...
# 2430            None  https://www.ebi.ac.uk/chebi/searchId.do?chebiI...
# 2431            None  https://www.ebi.ac.uk/chebi/searchId.do?chebiI...
# 4500   NaN       NaN                                                NaN
# 4501   NaN       NaN                                                NaN
# 4502   NaN       NaN                                                NaN
# 4503   NaN       NaN                                                NaN
#
#          BiGG ID
#
# 591     5dglcn_c
# 2428    M00117_c
# 2429    M00117_e
# 2430    M00117_l
# 2431    M00117_r
# 4500  dmhptcoa_m
# 4501  dmhptcrn_c
# 4502  dmhptcrn_e
# 4503  dmhptcrn_m
#
# [9 rows x 25 columns]

# %% [markdown]
# ### 3.Update the v3 dataset with info from the manual curation dataset

# %%
# Update Rxns dataset
rxns_changed = False
if not rxns_equals:
    for index in rxns_differences.index:
        rxns_v3.loc[index].update(rxns_mc.loc[index])
        rxns_changed = True
else:
    print('No need to update "Rxns" Sheet datasets')

# Update Attributes dataset
attributes_changed = False
if not rxns_attributes_equals:
    for index in rxns_attributes_differences.index:
        rxns_attributes_v3.loc[index].update(rxns_attributes_mc.loc[index])
        attributes_changed = True
else:
    print('No need to update "Attributes" Sheet datasets')    

# Update Metabolites dataset
metabolites_changed = False
if not metabolites_equals:
    for index in metabolites_differences.index:
        metabolites_v3.loc[index].update(metabolites_mc.loc[index])
        metabolites_changed = True
else:
    print('No need to update "Metabolites" Sheet datasets')
# Out:
# No need to update "Attributes" Sheet datasets

# %%
#############################################
#### ----------------------------------- ####
#### ---- Update Rxns Google Sheet ----- ####
#### ----------------------------------- ####
#############################################

#CHO Network Reconstruction + Recon3D_v3 Google Sheet ID
SPREADSHEET_ID = '1MlBXeHIKw8k8fZyXm-sN__AHTRSunJxar_-bqvukZws'

# Initialize the GoogleSheet object
sheet = GoogleSheet(SPREADSHEET_ID, KEY_FILE_PATH)

if rxns_changed:
    sheet.update_google_sheet(sheet_rxns, rxns_v3)
    print("Rxns Sheet updated.")

if attributes_changed:
    sheet.update_google_sheet(sheet_attributes, rxns_attributes_v3)
    print("Attributes Sheet updated.")

if metabolites_changed:
    sheet.update_google_sheet(sheet_met, metabolites_v3)
    print("Metabolites Sheet updated.")
# Out:
# Rxns Sheet updated.
# Metabolites Sheet updated.
