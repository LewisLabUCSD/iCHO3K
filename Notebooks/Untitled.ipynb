# %%
import pandas as pd
from cobra.io import read_sbml_model
from cobra.flux_analysis import find_blocked_reactions
from utils import detect_dead_ends

# %%
model = read_sbml_model("/Users/pablodigiusto/Downloads/MODEL1907260015.xml")
# Out:
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-03-24

# %%
for r in model.reactions:
    print(r)
# Out:
# 4NPHSULT: 4nph_c + paps_c --> 4nphsf_c + h_c + pap_c
# FAH1: ddca_c + h_c + nadph_c + o2_c --> h2o_c + nadp_c + whddca_c
# FAH2: h_c + nadph_c + o2_c + ttdca_c --> h2o_c + nadp_c + whttdca_c
# FAH3: h_c + hdca_c + nadph_c + o2_c --> h2o_c + nadp_c + whhdca_c
# P4502C18: antipyrene_c + h_c + nadph_c + 0.5 o2_c --> dmantipyrine_c + meoh_c + nadp_c
# P4502C8: h_c + nadph_c + o2_c + taxol_c --> h2o_c + htaxol_c + nadp_c
# P4502D6: debrisoquine_c + h_c + nadph_c + o2_c --> 4hdebrisoquine_c + h2o_c + nadp_c
# P4502E1: 4nph_c + h_c + nadph_c + o2_c --> 24nph_c + h2o_c + nadp_c
# FAS100ACP: 3.0 h_c + malcoa_c + 2.0 nadph_c + ocACP_c --> co2_c + coa_c + dcaACP_c + h2o_c + 2.0 nadp_c
# FAS140ACP: ddcaACP_c + 3.0 h_c + malcoa_c + 2.0 nadph_c --> co2_c + coa_c + h2o_c + myrsACP_c + 2.0 nadp_c
# FAS160ACP: 3.0 h_c + malcoa_c + myrsACP_c + 2.0 nadph_c --> co2_c + coa_c + h2o_c + 2.0 nadp_c + palmACP_c
# FAS180ACP: 3.0 h_c + malcoa_c + 2.0 nadph_c + palmACP_c --> co2_c + coa_c + h2o_c + 2.0 nadp_c + ocdcaACP_c
# FAS80ACP_L: acACP_c + 9.0 h_c + 3.0 malcoa_c + 6.0 nadph_c --> 3.0 co2_c + 3.0 coa_c + 3.0 h2o_c + 6.0 nadp_c + ocACP_c
# KAS8: accoa_c + 20.0 h_c + 7.0 malcoa_c + 14.0 nadph_c --> 7.0 co2_c + 8.0 coa_c + 6.0 h2o_c + hdca_c + 14.0 nadp_c
# ACCOAC: accoa_c + atp_c + hco3_c --> adp_c + h_c + malcoa_c + pi_c
# BMTer: dolmanp_r + memgacpail_cho_r --> dolp_r + h_r + m2emgacpail_cho_r
# GPIMTer: dolmanp_r + gacpail_cho_r --> dolp_r + h_r + mgacpail_cho_r
# H2MTer: dolmanp_r + mgacpail_cho_r --> dolp_r + h_r + m2gacpail_cho_r
# H3MTer: dolmanp_r + m2gacpail_cho_r --> dolp_r + h_r + m3gacpail_cho_r
# H5MTer: dolmanp_r + emgacpail_cho_r --> dolp_r + h_r + memgacpail_cho_r
# FBA4: xu1p_D_c <=> dhap_c + gcald_c
# GCALDD: gcald_c + h2o_c + nad_c --> glyclt_c + 2.0 h_c + nadh_c
# GLXO1: glx_c + h2o_c + nad_c --> 2.0 h_c + nadh_c + oxa_c
# HPYRR2x: h_c + hpyr_c + nadh_c --> glyc_S_c + nad_c
# HPYRRx: h_c + hpyr_c + nadh_c --> glyc_R_c + nad_c
# BDMT_cho: chito2pdol_c + gdpmann_c --> gdp_c + h_c + mpdol_c
# DOLASNTer: Asn_X_Ser_Thr_r + g3m8mpdol_r --> doldp_r + g3m8masn_r + h_r
# DOLPGT1er: dolglcp_r + m8mpdol_r --> dolp_r + g1m8mpdol_r + h_r
# DOLPGT2er: dolglcp_r + g1m8mpdol_r --> dolp_r + g2m8mpdol_r + h_r
# DOLPGT3er: dolglcp_r + g2m8mpdol_r --> dolp_r + g3m8mpdol_r + h_r
# DOLPMT1er: dolmanp_r + m4mpdol_r --> dolp_r + h_r + m5mpdol_r
# DOLPMT3er: dolmanp_r + m6mpdol_r --> dolp_r + h_r + m7mpdol_r
# M13N4Tg: n2m2masn_g + uacgam_g --> h_g + n3m2masn_g + udp_g
# S26Tg: 2.0 cmpacna_g + l2fn2m2masn_g --> 2.0 cmp_g + 2.0 h_g + s2l2fn2m2masn_g
# ALDD19x: h2o_c + nad_c + pacald_c <=> 2.0 h_c + nadh_c + pac_c
# ALDD19x_P_: h2o_c + nadp_c + pacald_c --> 2.0 h_c + nadph_c + pac_c
# PEAMNO: h2o_c + o2_c + peamn_c --> h2o2_c + nh4_c + pacald_c
# PHETA1: akg_c + phe_L_c <=> glu_L_c + phpyr_c
# 2HBO: 2hb_c + nad_c <=> 2obut_c + h_c + nadh_c
# ACCOAL: atp_c + coa_c + ppa_c --> adp_c + pi_c + ppcoa_c
# ACS2: atp_c + coa_c + ppa_c --> amp_c + ppcoa_c + ppi_c
# PPCOAOm: fad_m + ppcoa_m --> fadh2_m + prpncoa_m
# 2HBt2: 2hb_e + h_e <=> 2hb_c + h_c
# 4HPROLTASCT1: 4hpro_LT_c + ala_L_e + na1_e --> 4hpro_LT_e + ala_L_c + na1_c
# 5ADTSTSTERONEGLCte: 5adtststeroneglc_c + atp_c + h2o_c --> 5adtststeroneglc_e + adp_c + h_c + pi_c
# 5FTHFt2: 5fthf_e + oh1_c <=> 5fthf_c + oh1_e
# ABUTt2r: 4abut_e + h_e <=> 4abut_c + h_c
# ACACt2: acac_e + h_e <=> acac_c + h_c
# ACt2r: ac_e + h_e <=> ac_c + h_c
# ADEt: ade_e <=> ade_c
# ALAASNNaEx: ala_L_e + asn_L_c + na1_e --> ala_L_c + asn_L_e + na1_c
# ALACYSNaEx: ala_L_e + cys_L_c + na1_e --> ala_L_c + cys_L_e + na1_c
# ALAGLNNaEx: ala_L_e + gln_L_c + na1_e --> ala_L_c + gln_L_e + na1_c
# ALASERNaEx: ala_L_e + na1_e + ser_L_c --> ala_L_c + na1_c + ser_L_e
# ALAt2r: ala_L_e + h_e <=> ala_L_c + h_c
# ALAt4: ala_L_e + na1_e --> ala_L_c + na1_c
# ALATHRNaEx: ala_L_e + na1_e + thr_L_c --> ala_L_c + na1_c + thr_L_e
# ARGt5r: arg_L_e <=> arg_L_c
# ASCBt4: ascb_L_e + na1_e <=> ascb_L_c + na1_c
# ASCBt5: ascb_L_e + 2.0 na1_e <=> ascb_L_c + 2.0 na1_c
# ASNALANaEx: ala_L_c + asn_L_e + na1_e --> ala_L_e + asn_L_c + na1_c
# ASNCYSNaEx: asn_L_e + cys_L_c + na1_e --> asn_L_c + cys_L_e + na1_c
# ASNGLNNaEx: asn_L_e + gln_L_c + na1_e --> asn_L_c + gln_L_e + na1_c
# ASNSERNaEx: asn_L_e + na1_e + ser_L_c --> asn_L_c + na1_c + ser_L_e
# ASNt4: asn_L_e + na1_e --> asn_L_c + na1_c
# ASNTHRNaEx: asn_L_e + na1_e + thr_L_c --> asn_L_c + na1_c + thr_L_e
# ASPDt6: asp_D_e + h_e + k_c + 3.0 na1_e --> asp_D_c + h_c + k_e + 3.0 na1_c
# ASPPROASCT1: asp_L_e + na1_e + pro_L_c --> asp_L_c + na1_c + pro_L_e
# BILDGLCURte: atp_c + bildglcur_c + h2o_c --> adp_c + bildglcur_e + h_c + pi_c
# BILGLCURte: atp_c + bilglcur_c + h2o_c --> adp_c + bilglcur_e + h_c + pi_c
# BTNt3: btn_e + na1_e <=> btn_c + na1_c
# BTNt3i: atp_c + btn_e + h2o_c + 2.0 na1_e --> adp_c + btn_c + h_c + 2.0 na1_c + pi_c
# BUTt2r: but_e + h_e <=> but_c + h_c
# CHOLESTle: h2o_e + xolest2_cho_e --> Rtotal_e + chsterol_e + h_e
# CHOLtu: chol_e <=> chol_c
# CLFORtex: cl_e + 2.0 for_c --> cl_c + 2.0 for_e
# CLHCOtex: cl_e + 2.0 hco3_c --> cl_c + 2.0 hco3_e
# CO2t: co2_e <=> co2_c
# CRNt: crn_e <=> crn_c
# CRNtHa: crn_c + h_e --> crn_e + h_c
# CRNtuNa: crn_e + na1_e --> crn_c + na1_c
# CSNt: csn_e <=> csn_c
# CYSALANaEx: ala_L_c + cys_L_e + na1_e --> ala_L_e + cys_L_c + na1_c
# CYSASNNaEx: asn_L_c + cys_L_e + na1_e --> asn_L_e + cys_L_c + na1_c
# CYSGLNNaEx: cys_L_e + gln_L_c + na1_e --> cys_L_c + gln_L_e + na1_c
# CYSSERNaEx: cys_L_e + na1_e + ser_L_c --> cys_L_c + na1_c + ser_L_e
# CYSt4: cys_L_e + na1_e --> cys_L_c + na1_c
# CYStec: cys_L_e <=> cys_L_c
# CYSTGLUex: Lcystin_e + glu_L_c --> Lcystin_c + glu_L_e
# CYSTHRNaEx: cys_L_e + na1_e + thr_L_c --> cys_L_c + na1_c + thr_L_e
# D_LACt2: h_e + lac_D_e <=> h_c + lac_D_c
# DALAt2r: ala_D_e + h_e <=> ala_D_c + h_c
# ESTRADIOLGLCt2: atp_c + estradiolglc_c + h2o_c --> adp_c + estradiolglc_e + h_c + pi_c
# FATP1t: hdca_c + na1_c <=> hdca_e + na1_e
# FATP2t: na1_c + ocdcea_c <=> na1_e + ocdcea_e
# FATP3t: na1_c + ocdca_c <=> na1_e + ocdca_e
# FATP6t: adrn_c + na1_c <=> adrn_e + na1_e
# FATP7t: crvnc_c + na1_c <=> crvnc_e + na1_e
# FATP8t: lgnc_c + na1_c <=> lgnc_e + na1_e
# FATP9t: na1_c + nrvnc_c <=> na1_e + nrvnc_e
# FE2DMT1: fe2_e + h_e --> fe2_c + h_c
# FE3MTP1: fe3_c --> fe3_e
# FRUt1r: fru_e <=> fru_c
# GALt1r: gal_e <=> gal_c
# GLCt1r: glc_D_e <=> glc_D_c
# GLCt4: glc_D_e + na1_e <=> glc_D_c + na1_c
# GLNALANaEx: ala_L_c + gln_L_e + na1_e --> ala_L_e + gln_L_c + na1_c
# GLNASNNaEx: asn_L_c + gln_L_e + na1_e --> asn_L_e + gln_L_c + na1_c
# GLNCYSNaEx: cys_L_c + gln_L_e + na1_e --> cys_L_e + gln_L_c + na1_c
# GLNSERNaEx: gln_L_e + na1_e + ser_L_c --> gln_L_c + na1_c + ser_L_e
# GLNt4: gln_L_e + na1_e --> gln_L_c + na1_c
# GLNTHRNaEx: gln_L_e + na1_e + thr_L_c --> gln_L_c + na1_c + thr_L_e
# GLUPROASCT1: glu_L_e + na1_e + pro_L_c --> glu_L_c + na1_c + pro_L_e
# GLYCt: glyc_c <=> glyc_e
# GLYt2r: gly_e + h_e <=> gly_c + h_c
# GLYt4: gly_e + na1_e --> gly_c + na1_c
# GUAt: gua_e <=> gua_c
# H2Ot: h2o_e <=> h2o_c
# HCO3_NAt: hco3_e + na1_e <=> hco3_c + na1_c
# HDCAtr: hdca_e <=> hdca_c
# HDCEAtr: hdcea_e <=> hdcea_c
# HISt4: his_L_e + na1_e --> his_L_c + na1_c
# HIStiDF: his_L_e <=> his_L_c
# HOMt4: hom_L_e + na1_e --> hom_L_c + na1_c
# ILELAT1tc: ile_L_e + leu_L_c <=> ile_L_c + leu_L_e
# ILEt4: ile_L_e + na1_e --> ile_L_c + na1_c
# ILEtec: ile_L_e <=> ile_L_c
# INSTt2r: h_e + inost_e <=> h_c + inost_c
# KCC2t: cl_e + nh4_e <=> cl_c + nh4_c
# KCCt: cl_e + k_e <=> cl_c + k_c
# L_LACt2r: h_e + lac_L_e <=> h_c + lac_L_c
# LEUt4: leu_L_e + na1_e --> leu_L_c + na1_c
# LEUtec: leu_L_e <=> leu_L_c
# LYSt5r: lys_L_e <=> lys_L_c
# METt4: met_L_e + na1_e --> met_L_c + na1_c
# METtec: met_L_e <=> met_L_c
# NAHCO3_HCLt2: cl_c + h_c + 2.0 hco3_e + na1_e <=> cl_e + h_e + 2.0 hco3_c + na1_c
# NaKt: atp_c + h2o_c + 2.0 k_e + 3.0 na1_c --> adp_c + h_c + 2.0 k_c + 3.0 na1_e + pi_c
# NAt3_1: h_e + na1_c <=> h_c + na1_e
# NAt5: na1_c + nh4_e <=> na1_e + nh4_c
# NKCC2t: 2.0 cl_e + na1_e + nh4_e <=> 2.0 cl_c + na1_c + nh4_c
# NKCCt: 2.0 cl_e + k_e + na1_e <=> 2.0 cl_c + k_c + na1_c
# ORNt: orn_e <=> orn_c
# OXAHCOtex: 2.0 hco3_c + oxa_e --> 2.0 hco3_e + oxa_c
# PEFLIP_cho: atp_c + h2o_c + pe_cho_e --> adp_c + h_c + pe_cho_c + pi_c
# PHEMEt: pheme_e <=> pheme_c
# PHEt4: na1_e + phe_L_e --> na1_c + phe_L_c
# PHEtec: phe_L_e <=> phe_L_c
# PIt8: 1.5 na1_e + pi_e <=> 1.5 na1_c + pi_c
# PIt9: 2.0 na1_e + pi_e <=> 2.0 na1_c + pi_c
# PNTOt1: 2.0 na1_e + pnto_R_e --> 2.0 na1_c + pnto_R_c
# PNTOt5: atp_c + h2o_c + 2.0 na1_e + pnto_R_e --> adp_c + h_c + 2.0 na1_c + pi_c + pnto_R_c
# PRODt2r: h_e + pro_D_e <=> h_c + pro_D_c
# PROSTGE1t: hco3_c + prostge1_e <=> hco3_e + prostge1_c
# PROSTGE2t: hco3_c + prostge2_e <=> hco3_e + prostge2_c
# PROt2r: h_e + pro_L_e <=> h_c + pro_L_c
# PROt4: na1_e + pro_L_e --> na1_c + pro_L_c
# PSFLIP_cho: atp_c + h2o_c + ps_cho_e --> adp_c + h_c + pi_c + ps_cho_c
# PYRt2r: h_e + pyr_e <=> h_c + pyr_c
# r1635: cys_L_e + leu_L_c <=> cys_L_c + leu_L_e
# r1636: cys_L_e + pro_L_c <=> cys_L_c + pro_L_e
# r1637: asn_L_c + cys_L_e <=> asn_L_e + cys_L_c
# r1638: cys_L_e + val_L_c <=> cys_L_c + val_L_e
# r1639: cys_L_e + thr_L_c <=> cys_L_c + thr_L_e
# r1640: cys_L_e + hom_L_c <=> cys_L_c + hom_L_e
# r1641: cys_L_e + ile_L_c <=> cys_L_c + ile_L_e
# r1642: leu_L_e + pro_L_c <=> leu_L_c + pro_L_e
# r1643: asn_L_c + leu_L_e <=> asn_L_e + leu_L_c
# r1645: leu_L_e + thr_L_c <=> leu_L_c + thr_L_e
# r1646: hom_L_c + leu_L_e <=> hom_L_e + leu_L_c
# r1648: asn_L_c + pro_L_e <=> asn_L_e + pro_L_c
# r1649: pro_L_e + val_L_c <=> pro_L_c + val_L_e
# r1650: pro_L_e + thr_L_c <=> pro_L_c + thr_L_e
# r1651: hom_L_c + pro_L_e <=> hom_L_e + pro_L_c
# r1652: ile_L_c + pro_L_e <=> ile_L_e + pro_L_c
# r1653: asn_L_e + val_L_c <=> asn_L_c + val_L_e
# r1654: asn_L_e + thr_L_c <=> asn_L_c + thr_L_e
# r1655: asn_L_e + hom_L_c <=> asn_L_c + hom_L_e
# r1656: asn_L_e + ile_L_c <=> asn_L_c + ile_L_e
# r1657: thr_L_c + val_L_e <=> thr_L_e + val_L_c
# r1658: hom_L_c + val_L_e <=> hom_L_e + val_L_c
# r1659: ile_L_c + val_L_e <=> ile_L_e + val_L_c
# r1660: hom_L_c + thr_L_e <=> hom_L_e + thr_L_c
# r1661: ile_L_c + thr_L_e <=> ile_L_e + thr_L_c
# r1662: hom_L_e + ile_L_c <=> hom_L_c + ile_L_e
# r1664: lys_L_e + orn_c <=> lys_L_c + orn_e
# r1665: his_L_c + lys_L_e <=> his_L_e + lys_L_c
# r1666: citr_L_c + lys_L_e <=> citr_L_e + lys_L_c
# r1667: arg_L_e + orn_c <=> arg_L_c + orn_e
# r1668: arg_L_e + his_L_c <=> arg_L_c + his_L_e
# r1669: arg_L_e + citr_L_c <=> arg_L_c + citr_L_e
# r1670: his_L_c + orn_e <=> his_L_e + orn_c
# r1671: citr_L_c + his_L_e <=> citr_L_e + his_L_c
# r1672: ala_L_c + gly_e + na1_e --> ala_L_e + gly_c + na1_c
# r1673: gln_L_c + gly_e + na1_e --> gln_L_e + gly_c + na1_c
# r1674: gly_e + na1_e + ser_L_c --> gly_c + na1_c + ser_L_e
# r1675: gly_e + met_L_c + na1_e --> gly_c + met_L_e + na1_c
# r1676: gly_e + na1_e + trp_L_c --> gly_c + na1_c + trp_L_e
# r1677: gly_e + na1_e + phe_L_c --> gly_c + na1_c + phe_L_e
# r1678: gly_e + na1_e + tyr_L_c --> gly_c + na1_c + tyr_L_e
# r1679: cys_L_c + gly_e + na1_e --> cys_L_e + gly_c + na1_c
# r1680: gly_e + leu_L_c + na1_e --> gly_c + leu_L_e + na1_c
# r1681: gly_e + na1_e + pro_L_c --> gly_c + na1_c + pro_L_e
# r1682: asn_L_c + gly_e + na1_e --> asn_L_e + gly_c + na1_c
# r1683: gly_e + na1_e + val_L_c --> gly_c + na1_c + val_L_e
# r1684: gly_e + na1_e + thr_L_c --> gly_c + na1_c + thr_L_e
# r1685: gly_e + hom_L_c + na1_e --> gly_c + hom_L_e + na1_c
# r1686: gly_e + ile_L_c + na1_e --> gly_c + ile_L_e + na1_c
# r1687: ala_L_e + gly_c + na1_e --> ala_L_c + gly_e + na1_c
# r1690: ala_L_e + met_L_c + na1_e --> ala_L_c + met_L_e + na1_c
# r1691: ala_L_e + na1_e + trp_L_c --> ala_L_c + na1_c + trp_L_e
# r1692: ala_L_e + na1_e + phe_L_c --> ala_L_c + na1_c + phe_L_e
# r1693: ala_L_e + na1_e + tyr_L_c --> ala_L_c + na1_c + tyr_L_e
# r1695: ala_L_e + leu_L_c + na1_e --> ala_L_c + leu_L_e + na1_c
# r1696: ala_L_e + na1_e + pro_L_c --> ala_L_c + na1_c + pro_L_e
# r1698: ala_L_e + na1_e + val_L_c --> ala_L_c + na1_c + val_L_e
# r1700: ala_L_e + hom_L_c + na1_e --> ala_L_c + hom_L_e + na1_c
# r1701: ala_L_e + ile_L_c + na1_e --> ala_L_c + ile_L_e + na1_c
# r1702: gln_L_e + gly_c + na1_e --> gln_L_c + gly_e + na1_c
# r1705: gln_L_e + met_L_c + na1_e --> gln_L_c + met_L_e + na1_c
# r1706: gln_L_e + na1_e + trp_L_c --> gln_L_c + na1_c + trp_L_e
# r1707: gln_L_e + na1_e + phe_L_c --> gln_L_c + na1_c + phe_L_e
# r1708: gln_L_e + na1_e + tyr_L_c --> gln_L_c + na1_c + tyr_L_e
# r1710: gln_L_e + leu_L_c + na1_e --> gln_L_c + leu_L_e + na1_c
# r1711: gln_L_e + na1_e + pro_L_c --> gln_L_c + na1_c + pro_L_e
# r1713: gln_L_e + na1_e + val_L_c --> gln_L_c + na1_c + val_L_e
# r1715: gln_L_e + hom_L_c + na1_e --> gln_L_c + hom_L_e + na1_c
# r1716: gln_L_e + ile_L_c + na1_e --> gln_L_c + ile_L_e + na1_c
# r1717: gly_c + na1_e + ser_L_e --> gly_e + na1_c + ser_L_c
# r1720: met_L_c + na1_e + ser_L_e --> met_L_e + na1_c + ser_L_c
# r1721: na1_e + ser_L_e + trp_L_c --> na1_c + ser_L_c + trp_L_e
# r1722: na1_e + phe_L_c + ser_L_e --> na1_c + phe_L_e + ser_L_c
# r1723: na1_e + ser_L_e + tyr_L_c --> na1_c + ser_L_c + tyr_L_e
# r1725: leu_L_c + na1_e + ser_L_e --> leu_L_e + na1_c + ser_L_c
# r1726: na1_e + pro_L_c + ser_L_e --> na1_c + pro_L_e + ser_L_c
# r1728: na1_e + ser_L_e + val_L_c --> na1_c + ser_L_c + val_L_e
# r1730: hom_L_c + na1_e + ser_L_e --> hom_L_e + na1_c + ser_L_c
# r1731: ile_L_c + na1_e + ser_L_e --> ile_L_e + na1_c + ser_L_c
# r1732: gly_c + met_L_e + na1_e --> gly_e + met_L_c + na1_c
# r1733: ala_L_c + met_L_e + na1_e --> ala_L_e + met_L_c + na1_c
# r1734: gln_L_c + met_L_e + na1_e --> gln_L_e + met_L_c + na1_c
# r1735: met_L_e + na1_e + ser_L_c --> met_L_c + na1_c + ser_L_e
# r1736: met_L_e + na1_e + trp_L_c --> met_L_c + na1_c + trp_L_e
# r1737: met_L_e + na1_e + phe_L_c --> met_L_c + na1_c + phe_L_e
# r1738: met_L_e + na1_e + tyr_L_c --> met_L_c + na1_c + tyr_L_e
# r1739: cys_L_c + met_L_e + na1_e --> cys_L_e + met_L_c + na1_c
# r1740: leu_L_c + met_L_e + na1_e --> leu_L_e + met_L_c + na1_c
# r1741: met_L_e + na1_e + pro_L_c --> met_L_c + na1_c + pro_L_e
# r1742: asn_L_c + met_L_e + na1_e --> asn_L_e + met_L_c + na1_c
# r1743: met_L_e + na1_e + val_L_c --> met_L_c + na1_c + val_L_e
# r1744: met_L_e + na1_e + thr_L_c --> met_L_c + na1_c + thr_L_e
# r1745: hom_L_c + met_L_e + na1_e --> hom_L_e + met_L_c + na1_c
# r1746: ile_L_c + met_L_e + na1_e --> ile_L_e + met_L_c + na1_c
# r1747: gly_c + na1_e + trp_L_e --> gly_e + na1_c + trp_L_c
# r1748: ala_L_c + na1_e + trp_L_e --> ala_L_e + na1_c + trp_L_c
# r1749: gln_L_c + na1_e + trp_L_e --> gln_L_e + na1_c + trp_L_c
# r1750: na1_e + ser_L_c + trp_L_e --> na1_c + ser_L_e + trp_L_c
# r1751: met_L_c + na1_e + trp_L_e --> met_L_e + na1_c + trp_L_c
# r1752: na1_e + phe_L_c + trp_L_e --> na1_c + phe_L_e + trp_L_c
# r1753: na1_e + trp_L_e + tyr_L_c --> na1_c + trp_L_c + tyr_L_e
# r1754: cys_L_c + na1_e + trp_L_e --> cys_L_e + na1_c + trp_L_c
# r1755: leu_L_c + na1_e + trp_L_e --> leu_L_e + na1_c + trp_L_c
# r1756: na1_e + pro_L_c + trp_L_e --> na1_c + pro_L_e + trp_L_c
# r1757: asn_L_c + na1_e + trp_L_e --> asn_L_e + na1_c + trp_L_c
# r1758: na1_e + trp_L_e + val_L_c --> na1_c + trp_L_c + val_L_e
# r1759: na1_e + thr_L_c + trp_L_e --> na1_c + thr_L_e + trp_L_c
# r1760: hom_L_c + na1_e + trp_L_e --> hom_L_e + na1_c + trp_L_c
# r1761: ile_L_c + na1_e + trp_L_e --> ile_L_e + na1_c + trp_L_c
# r1762: gly_c + na1_e + phe_L_e --> gly_e + na1_c + phe_L_c
# r1763: ala_L_c + na1_e + phe_L_e --> ala_L_e + na1_c + phe_L_c
# r1764: gln_L_c + na1_e + phe_L_e --> gln_L_e + na1_c + phe_L_c
# r1765: na1_e + phe_L_e + ser_L_c --> na1_c + phe_L_c + ser_L_e
# r1766: met_L_c + na1_e + phe_L_e --> met_L_e + na1_c + phe_L_c
# r1767: na1_e + phe_L_e + trp_L_c --> na1_c + phe_L_c + trp_L_e
# r1768: na1_e + phe_L_e + tyr_L_c --> na1_c + phe_L_c + tyr_L_e
# r1769: cys_L_c + na1_e + phe_L_e --> cys_L_e + na1_c + phe_L_c
# r1770: leu_L_c + na1_e + phe_L_e --> leu_L_e + na1_c + phe_L_c
# r1771: na1_e + phe_L_e + pro_L_c --> na1_c + phe_L_c + pro_L_e
# r1772: asn_L_c + na1_e + phe_L_e --> asn_L_e + na1_c + phe_L_c
# r1773: na1_e + phe_L_e + val_L_c --> na1_c + phe_L_c + val_L_e
# r1774: na1_e + phe_L_e + thr_L_c --> na1_c + phe_L_c + thr_L_e
# r1775: hom_L_c + na1_e + phe_L_e --> hom_L_e + na1_c + phe_L_c
# r1776: ile_L_c + na1_e + phe_L_e --> ile_L_e + na1_c + phe_L_c
# r1777: gly_c + na1_e + tyr_L_e --> gly_e + na1_c + tyr_L_c
# r1778: ala_L_c + na1_e + tyr_L_e --> ala_L_e + na1_c + tyr_L_c
# r1779: gln_L_c + na1_e + tyr_L_e --> gln_L_e + na1_c + tyr_L_c
# r1780: na1_e + ser_L_c + tyr_L_e --> na1_c + ser_L_e + tyr_L_c
# r1781: met_L_c + na1_e + tyr_L_e --> met_L_e + na1_c + tyr_L_c
# r1782: na1_e + trp_L_c + tyr_L_e --> na1_c + trp_L_e + tyr_L_c
# r1783: na1_e + phe_L_c + tyr_L_e --> na1_c + phe_L_e + tyr_L_c
# r1784: cys_L_c + na1_e + tyr_L_e --> cys_L_e + na1_c + tyr_L_c
# r1785: leu_L_c + na1_e + tyr_L_e --> leu_L_e + na1_c + tyr_L_c
# r1786: na1_e + pro_L_c + tyr_L_e --> na1_c + pro_L_e + tyr_L_c
# r1787: asn_L_c + na1_e + tyr_L_e --> asn_L_e + na1_c + tyr_L_c
# r1788: na1_e + tyr_L_e + val_L_c --> na1_c + tyr_L_c + val_L_e
# r1789: na1_e + thr_L_c + tyr_L_e --> na1_c + thr_L_e + tyr_L_c
# r1790: hom_L_c + na1_e + tyr_L_e --> hom_L_e + na1_c + tyr_L_c
# r1791: ile_L_c + na1_e + tyr_L_e --> ile_L_e + na1_c + tyr_L_c
# r1792: cys_L_e + gly_c + na1_e --> cys_L_c + gly_e + na1_c
# r1796: cys_L_e + met_L_c + na1_e --> cys_L_c + met_L_e + na1_c
# r1797: cys_L_e + na1_e + trp_L_c --> cys_L_c + na1_c + trp_L_e
# r1798: cys_L_e + na1_e + phe_L_c --> cys_L_c + na1_c + phe_L_e
# r1799: cys_L_e + na1_e + tyr_L_c --> cys_L_c + na1_c + tyr_L_e
# r1800: cys_L_e + leu_L_c + na1_e --> cys_L_c + leu_L_e + na1_c
# r1801: cys_L_e + na1_e + pro_L_c --> cys_L_c + na1_c + pro_L_e
# r1803: cys_L_e + na1_e + val_L_c --> cys_L_c + na1_c + val_L_e
# r1805: cys_L_e + hom_L_c + na1_e --> cys_L_c + hom_L_e + na1_c
# r1806: cys_L_e + ile_L_c + na1_e --> cys_L_c + ile_L_e + na1_c
# r1807: gly_c + leu_L_e + na1_e --> gly_e + leu_L_c + na1_c
# r1808: ala_L_c + leu_L_e + na1_e --> ala_L_e + leu_L_c + na1_c
# r1809: gln_L_c + leu_L_e + na1_e --> gln_L_e + leu_L_c + na1_c
# r1810: leu_L_e + na1_e + ser_L_c --> leu_L_c + na1_c + ser_L_e
# r1811: leu_L_e + met_L_c + na1_e --> leu_L_c + met_L_e + na1_c
# r1812: leu_L_e + na1_e + trp_L_c --> leu_L_c + na1_c + trp_L_e
# r1813: leu_L_e + na1_e + phe_L_c --> leu_L_c + na1_c + phe_L_e
# r1814: leu_L_e + na1_e + tyr_L_c --> leu_L_c + na1_c + tyr_L_e
# r1815: cys_L_c + leu_L_e + na1_e --> cys_L_e + leu_L_c + na1_c
# r1816: leu_L_e + na1_e + pro_L_c --> leu_L_c + na1_c + pro_L_e
# r1817: asn_L_c + leu_L_e + na1_e --> asn_L_e + leu_L_c + na1_c
# r1818: leu_L_e + na1_e + val_L_c --> leu_L_c + na1_c + val_L_e
# r1819: leu_L_e + na1_e + thr_L_c --> leu_L_c + na1_c + thr_L_e
# r1820: hom_L_c + leu_L_e + na1_e --> hom_L_e + leu_L_c + na1_c
# r1821: ile_L_c + leu_L_e + na1_e --> ile_L_e + leu_L_c + na1_c
# r1822: gly_c + na1_e + pro_L_e --> gly_e + na1_c + pro_L_c
# r1823: ala_L_c + na1_e + pro_L_e --> ala_L_e + na1_c + pro_L_c
# r1824: gln_L_c + na1_e + pro_L_e --> gln_L_e + na1_c + pro_L_c
# r1825: na1_e + pro_L_e + ser_L_c --> na1_c + pro_L_c + ser_L_e
# r1826: met_L_c + na1_e + pro_L_e --> met_L_e + na1_c + pro_L_c
# r1827: na1_e + pro_L_e + trp_L_c --> na1_c + pro_L_c + trp_L_e
# r1828: na1_e + phe_L_c + pro_L_e --> na1_c + phe_L_e + pro_L_c
# r1829: na1_e + pro_L_e + tyr_L_c --> na1_c + pro_L_c + tyr_L_e
# r1830: cys_L_c + na1_e + pro_L_e --> cys_L_e + na1_c + pro_L_c
# r1831: leu_L_c + na1_e + pro_L_e --> leu_L_e + na1_c + pro_L_c
# r1832: asn_L_c + na1_e + pro_L_e --> asn_L_e + na1_c + pro_L_c
# r1833: na1_e + pro_L_e + val_L_c --> na1_c + pro_L_c + val_L_e
# r1834: na1_e + pro_L_e + thr_L_c --> na1_c + pro_L_c + thr_L_e
# r1835: hom_L_c + na1_e + pro_L_e --> hom_L_e + na1_c + pro_L_c
# r1836: ile_L_c + na1_e + pro_L_e --> ile_L_e + na1_c + pro_L_c
# r1837: asn_L_e + gly_c + na1_e --> asn_L_c + gly_e + na1_c
# r1841: asn_L_e + met_L_c + na1_e --> asn_L_c + met_L_e + na1_c
# r1842: asn_L_e + na1_e + trp_L_c --> asn_L_c + na1_c + trp_L_e
# r1843: asn_L_e + na1_e + phe_L_c --> asn_L_c + na1_c + phe_L_e
# r1844: asn_L_e + na1_e + tyr_L_c --> asn_L_c + na1_c + tyr_L_e
# r1846: asn_L_e + leu_L_c + na1_e --> asn_L_c + leu_L_e + na1_c
# r1847: asn_L_e + na1_e + pro_L_c --> asn_L_c + na1_c + pro_L_e
# r1848: asn_L_e + na1_e + val_L_c --> asn_L_c + na1_c + val_L_e
# r1850: asn_L_e + hom_L_c + na1_e --> asn_L_c + hom_L_e + na1_c
# r1851: asn_L_e + ile_L_c + na1_e --> asn_L_c + ile_L_e + na1_c
# r1852: gly_c + na1_e + val_L_e --> gly_e + na1_c + val_L_c
# r1853: ala_L_c + na1_e + val_L_e --> ala_L_e + na1_c + val_L_c
# r1854: gln_L_c + na1_e + val_L_e --> gln_L_e + na1_c + val_L_c
# r1855: na1_e + ser_L_c + val_L_e --> na1_c + ser_L_e + val_L_c
# r1856: met_L_c + na1_e + val_L_e --> met_L_e + na1_c + val_L_c
# r1857: na1_e + trp_L_c + val_L_e --> na1_c + trp_L_e + val_L_c
# r1858: na1_e + phe_L_c + val_L_e --> na1_c + phe_L_e + val_L_c
# r1859: na1_e + tyr_L_c + val_L_e --> na1_c + tyr_L_e + val_L_c
# r1860: cys_L_c + na1_e + val_L_e --> cys_L_e + na1_c + val_L_c
# r1861: leu_L_c + na1_e + val_L_e --> leu_L_e + na1_c + val_L_c
# r1862: na1_e + pro_L_c + val_L_e --> na1_c + pro_L_e + val_L_c
# r1863: asn_L_c + na1_e + val_L_e --> asn_L_e + na1_c + val_L_c
# r1864: na1_e + thr_L_c + val_L_e --> na1_c + thr_L_e + val_L_c
# r1865: hom_L_c + na1_e + val_L_e --> hom_L_e + na1_c + val_L_c
# r1866: ile_L_c + na1_e + val_L_e --> ile_L_e + na1_c + val_L_c
# r1867: gly_c + na1_e + thr_L_e --> gly_e + na1_c + thr_L_c
# r1871: met_L_c + na1_e + thr_L_e --> met_L_e + na1_c + thr_L_c
# r1872: na1_e + thr_L_e + trp_L_c --> na1_c + thr_L_c + trp_L_e
# r1873: na1_e + phe_L_c + thr_L_e --> na1_c + phe_L_e + thr_L_c
# r1874: na1_e + thr_L_e + tyr_L_c --> na1_c + thr_L_c + tyr_L_e
# r1876: leu_L_c + na1_e + thr_L_e --> leu_L_e + na1_c + thr_L_c
# r1877: na1_e + pro_L_c + thr_L_e --> na1_c + pro_L_e + thr_L_c
# r1879: na1_e + thr_L_e + val_L_c --> na1_c + thr_L_c + val_L_e
# r1880: hom_L_c + na1_e + thr_L_e --> hom_L_e + na1_c + thr_L_c
# r1881: ile_L_c + na1_e + thr_L_e --> ile_L_e + na1_c + thr_L_c
# r1882: gly_c + hom_L_e + na1_e --> gly_e + hom_L_c + na1_c
# r1883: ala_L_c + hom_L_e + na1_e --> ala_L_e + hom_L_c + na1_c
# r1884: gln_L_c + hom_L_e + na1_e --> gln_L_e + hom_L_c + na1_c
# r1885: hom_L_e + na1_e + ser_L_c --> hom_L_c + na1_c + ser_L_e
# r1886: hom_L_e + met_L_c + na1_e --> hom_L_c + met_L_e + na1_c
# r1887: hom_L_e + na1_e + trp_L_c --> hom_L_c + na1_c + trp_L_e
# r1888: hom_L_e + na1_e + phe_L_c --> hom_L_c + na1_c + phe_L_e
# r1889: hom_L_e + na1_e + tyr_L_c --> hom_L_c + na1_c + tyr_L_e
# r1890: cys_L_c + hom_L_e + na1_e --> cys_L_e + hom_L_c + na1_c
# r1891: hom_L_e + leu_L_c + na1_e --> hom_L_c + leu_L_e + na1_c
# r1892: hom_L_e + na1_e + pro_L_c --> hom_L_c + na1_c + pro_L_e
# r1893: asn_L_c + hom_L_e + na1_e --> asn_L_e + hom_L_c + na1_c
# r1894: hom_L_e + na1_e + val_L_c --> hom_L_c + na1_c + val_L_e
# r1895: hom_L_e + na1_e + thr_L_c --> hom_L_c + na1_c + thr_L_e
# r1896: hom_L_e + ile_L_c + na1_e --> hom_L_c + ile_L_e + na1_c
# r1897: gly_c + ile_L_e + na1_e --> gly_e + ile_L_c + na1_c
# r1898: ala_L_c + ile_L_e + na1_e --> ala_L_e + ile_L_c + na1_c
# r1899: gln_L_c + ile_L_e + na1_e --> gln_L_e + ile_L_c + na1_c
# r1900: ile_L_e + na1_e + ser_L_c --> ile_L_c + na1_c + ser_L_e
# r1901: ile_L_e + met_L_c + na1_e --> ile_L_c + met_L_e + na1_c
# r1902: ile_L_e + na1_e + trp_L_c --> ile_L_c + na1_c + trp_L_e
# r1903: ile_L_e + na1_e + phe_L_c --> ile_L_c + na1_c + phe_L_e
# r1904: ile_L_e + na1_e + tyr_L_c --> ile_L_c + na1_c + tyr_L_e
# r1905: cys_L_c + ile_L_e + na1_e --> cys_L_e + ile_L_c + na1_c
# r1906: ile_L_e + leu_L_c + na1_e --> ile_L_c + leu_L_e + na1_c
# r1907: ile_L_e + na1_e + pro_L_c --> ile_L_c + na1_c + pro_L_e
# r1908: asn_L_c + ile_L_e + na1_e --> asn_L_e + ile_L_c + na1_c
# r1909: ile_L_e + na1_e + val_L_c --> ile_L_c + na1_c + val_L_e
# r1910: ile_L_e + na1_e + thr_L_c --> ile_L_c + na1_c + thr_L_e
# r1911: hom_L_c + ile_L_e + na1_e --> hom_L_e + ile_L_c + na1_c
# r1912: gly_e + lys_L_c + na1_e --> gly_c + lys_L_e + na1_c
# r1913: arg_L_c + gly_e + na1_e --> arg_L_e + gly_c + na1_c
# r1914: gly_e + na1_e + orn_c --> gly_c + na1_c + orn_e
# r1915: gly_e + his_L_c + na1_e --> gly_c + his_L_e + na1_c
# r1916: citr_L_c + gly_e + na1_e --> citr_L_e + gly_c + na1_c
# r1917: ala_L_e + lys_L_c + na1_e --> ala_L_c + lys_L_e + na1_c
# r1918: ala_L_e + arg_L_c + na1_e --> ala_L_c + arg_L_e + na1_c
# r1919: ala_L_e + na1_e + orn_c --> ala_L_c + na1_c + orn_e
# r1920: ala_L_e + his_L_c + na1_e --> ala_L_c + his_L_e + na1_c
# r1921: ala_L_e + citr_L_c + na1_e --> ala_L_c + citr_L_e + na1_c
# r1922: gln_L_e + lys_L_c + na1_e --> gln_L_c + lys_L_e + na1_c
# r1923: arg_L_c + gln_L_e + na1_e --> arg_L_e + gln_L_c + na1_c
# r1924: gln_L_e + na1_e + orn_c --> gln_L_c + na1_c + orn_e
# r1925: gln_L_e + his_L_c + na1_e --> gln_L_c + his_L_e + na1_c
# r1926: citr_L_c + gln_L_e + na1_e --> citr_L_e + gln_L_c + na1_c
# r1928: arg_L_c + na1_e + ser_L_e --> arg_L_e + na1_c + ser_L_c
# r1929: na1_e + orn_c + ser_L_e --> na1_c + orn_e + ser_L_c
# r1930: his_L_c + na1_e + ser_L_e --> his_L_e + na1_c + ser_L_c
# r1931: citr_L_c + na1_e + ser_L_e --> citr_L_e + na1_c + ser_L_c
# r1932: lys_L_c + met_L_e + na1_e --> lys_L_e + met_L_c + na1_c
# r1933: arg_L_c + met_L_e + na1_e --> arg_L_e + met_L_c + na1_c
# r1934: met_L_e + na1_e + orn_c --> met_L_c + na1_c + orn_e
# r1935: his_L_c + met_L_e + na1_e --> his_L_e + met_L_c + na1_c
# r1936: citr_L_c + met_L_e + na1_e --> citr_L_e + met_L_c + na1_c
# r1937: lys_L_c + na1_e + trp_L_e --> lys_L_e + na1_c + trp_L_c
# r1938: arg_L_c + na1_e + trp_L_e --> arg_L_e + na1_c + trp_L_c
# r1939: na1_e + orn_c + trp_L_e --> na1_c + orn_e + trp_L_c
# r1940: his_L_c + na1_e + trp_L_e --> his_L_e + na1_c + trp_L_c
# r1941: citr_L_c + na1_e + trp_L_e --> citr_L_e + na1_c + trp_L_c
# r1942: lys_L_c + na1_e + phe_L_e --> lys_L_e + na1_c + phe_L_c
# r1943: arg_L_c + na1_e + phe_L_e --> arg_L_e + na1_c + phe_L_c
# r1944: na1_e + orn_c + phe_L_e --> na1_c + orn_e + phe_L_c
# r1945: his_L_c + na1_e + phe_L_e --> his_L_e + na1_c + phe_L_c
# r1946: citr_L_c + na1_e + phe_L_e --> citr_L_e + na1_c + phe_L_c
# r1947: lys_L_c + na1_e + tyr_L_e --> lys_L_e + na1_c + tyr_L_c
# r1948: arg_L_c + na1_e + tyr_L_e --> arg_L_e + na1_c + tyr_L_c
# r1949: na1_e + orn_c + tyr_L_e --> na1_c + orn_e + tyr_L_c
# r1950: his_L_c + na1_e + tyr_L_e --> his_L_e + na1_c + tyr_L_c
# r1951: citr_L_c + na1_e + tyr_L_e --> citr_L_e + na1_c + tyr_L_c
# r1952: cys_L_e + lys_L_c + na1_e --> cys_L_c + lys_L_e + na1_c
# r1953: arg_L_c + cys_L_e + na1_e --> arg_L_e + cys_L_c + na1_c
# r1954: cys_L_e + na1_e + orn_c --> cys_L_c + na1_c + orn_e
# r1955: cys_L_e + his_L_c + na1_e --> cys_L_c + his_L_e + na1_c
# r1956: citr_L_c + cys_L_e + na1_e --> citr_L_e + cys_L_c + na1_c
# r1957: leu_L_e + lys_L_c + na1_e --> leu_L_c + lys_L_e + na1_c
# r1958: arg_L_c + leu_L_e + na1_e --> arg_L_e + leu_L_c + na1_c
# r1959: leu_L_e + na1_e + orn_c --> leu_L_c + na1_c + orn_e
# r1960: his_L_c + leu_L_e + na1_e --> his_L_e + leu_L_c + na1_c
# r1961: citr_L_c + leu_L_e + na1_e --> citr_L_e + leu_L_c + na1_c
# r1962: lys_L_c + na1_e + pro_L_e --> lys_L_e + na1_c + pro_L_c
# r1963: arg_L_c + na1_e + pro_L_e --> arg_L_e + na1_c + pro_L_c
# r1964: na1_e + orn_c + pro_L_e --> na1_c + orn_e + pro_L_c
# r1965: his_L_c + na1_e + pro_L_e --> his_L_e + na1_c + pro_L_c
# r1966: citr_L_c + na1_e + pro_L_e --> citr_L_e + na1_c + pro_L_c
# r1967: asn_L_e + lys_L_c + na1_e --> asn_L_c + lys_L_e + na1_c
# r1968: arg_L_c + asn_L_e + na1_e --> arg_L_e + asn_L_c + na1_c
# r1969: asn_L_e + na1_e + orn_c --> asn_L_c + na1_c + orn_e
# r1970: asn_L_e + his_L_c + na1_e --> asn_L_c + his_L_e + na1_c
# r1971: asn_L_e + citr_L_c + na1_e --> asn_L_c + citr_L_e + na1_c
# r1972: lys_L_c + na1_e + val_L_e --> lys_L_e + na1_c + val_L_c
# r1973: arg_L_c + na1_e + val_L_e --> arg_L_e + na1_c + val_L_c
# r1974: na1_e + orn_c + val_L_e --> na1_c + orn_e + val_L_c
# r1975: his_L_c + na1_e + val_L_e --> his_L_e + na1_c + val_L_c
# r1976: citr_L_c + na1_e + val_L_e --> citr_L_e + na1_c + val_L_c
# r1977: lys_L_c + na1_e + thr_L_e --> lys_L_e + na1_c + thr_L_c
# r1978: arg_L_c + na1_e + thr_L_e --> arg_L_e + na1_c + thr_L_c
# r1979: na1_e + orn_c + thr_L_e --> na1_c + orn_e + thr_L_c
# r1980: his_L_c + na1_e + thr_L_e --> his_L_e + na1_c + thr_L_c
# r1981: citr_L_c + na1_e + thr_L_e --> citr_L_e + na1_c + thr_L_c
# r1982: hom_L_e + lys_L_c + na1_e --> hom_L_c + lys_L_e + na1_c
# r1983: arg_L_c + hom_L_e + na1_e --> arg_L_e + hom_L_c + na1_c
# r1984: hom_L_e + na1_e + orn_c --> hom_L_c + na1_c + orn_e
# r1985: his_L_c + hom_L_e + na1_e --> his_L_e + hom_L_c + na1_c
# r1986: citr_L_c + hom_L_e + na1_e --> citr_L_e + hom_L_c + na1_c
# r1987: ile_L_e + lys_L_c + na1_e --> ile_L_c + lys_L_e + na1_c
# r1988: arg_L_c + ile_L_e + na1_e --> arg_L_e + ile_L_c + na1_c
# r1989: ile_L_e + na1_e + orn_c --> ile_L_c + na1_c + orn_e
# r1990: his_L_c + ile_L_e + na1_e --> his_L_e + ile_L_c + na1_c
# r1991: citr_L_c + ile_L_e + na1_e --> citr_L_e + ile_L_c + na1_c
# r1992: gly_c + lys_L_e --> gly_e + lys_L_c
# r1993: ala_L_c + lys_L_e --> ala_L_e + lys_L_c
# r1994: gln_L_c + lys_L_e --> gln_L_e + lys_L_c
# r1995: lys_L_e + ser_L_c --> lys_L_c + ser_L_e
# r1996: lys_L_e + met_L_c --> lys_L_c + met_L_e
# r1997: lys_L_e + trp_L_c --> lys_L_c + trp_L_e
# r1998: lys_L_e + phe_L_c --> lys_L_c + phe_L_e
# r1999: lys_L_e + tyr_L_c --> lys_L_c + tyr_L_e
# r2000: cys_L_c + lys_L_e --> cys_L_e + lys_L_c
# r2001: leu_L_c + lys_L_e --> leu_L_e + lys_L_c
# r2002: lys_L_e + pro_L_c --> lys_L_c + pro_L_e
# r2003: asn_L_c + lys_L_e --> asn_L_e + lys_L_c
# r2004: lys_L_e + val_L_c --> lys_L_c + val_L_e
# r2005: lys_L_e + thr_L_c --> lys_L_c + thr_L_e
# r2006: hom_L_c + lys_L_e --> hom_L_e + lys_L_c
# r2007: ile_L_c + lys_L_e --> ile_L_e + lys_L_c
# r2008: arg_L_e + gly_c --> arg_L_c + gly_e
# r2009: ala_L_c + arg_L_e --> ala_L_e + arg_L_c
# r2010: arg_L_e + gln_L_c --> arg_L_c + gln_L_e
# r2011: arg_L_e + ser_L_c --> arg_L_c + ser_L_e
# r2012: arg_L_e + met_L_c --> arg_L_c + met_L_e
# r2013: arg_L_e + trp_L_c --> arg_L_c + trp_L_e
# r2014: arg_L_e + phe_L_c --> arg_L_c + phe_L_e
# r2015: arg_L_e + tyr_L_c --> arg_L_c + tyr_L_e
# r2016: arg_L_e + cys_L_c --> arg_L_c + cys_L_e
# r2017: arg_L_e + leu_L_c --> arg_L_c + leu_L_e
# r2018: arg_L_e + pro_L_c --> arg_L_c + pro_L_e
# r2019: arg_L_e + asn_L_c --> arg_L_c + asn_L_e
# r2020: arg_L_e + val_L_c --> arg_L_c + val_L_e
# r2021: arg_L_e + thr_L_c --> arg_L_c + thr_L_e
# r2022: arg_L_e + hom_L_c --> arg_L_c + hom_L_e
# r2023: arg_L_e + ile_L_c --> arg_L_c + ile_L_e
# r2024: gly_c + orn_e --> gly_e + orn_c
# r2026: gln_L_c + orn_e --> gln_L_e + orn_c
# r2027: orn_e + ser_L_c --> orn_c + ser_L_e
# r2028: met_L_c + orn_e --> met_L_e + orn_c
# r2029: orn_e + trp_L_c --> orn_c + trp_L_e
# r2030: orn_e + phe_L_c --> orn_c + phe_L_e
# r2031: orn_e + tyr_L_c --> orn_c + tyr_L_e
# r2032: cys_L_c + orn_e --> cys_L_e + orn_c
# r2034: orn_e + pro_L_c --> orn_c + pro_L_e
# r2035: asn_L_c + orn_e --> asn_L_e + orn_c
# r2036: orn_e + val_L_c --> orn_c + val_L_e
# r2037: orn_e + thr_L_c --> orn_c + thr_L_e
# r2038: hom_L_c + orn_e --> hom_L_e + orn_c
# r2039: ile_L_c + orn_e --> ile_L_e + orn_c
# r2040: gly_c + his_L_e --> gly_e + his_L_c
# r2041: ala_L_c + his_L_e --> ala_L_e + his_L_c
# r2042: gln_L_c + his_L_e --> gln_L_e + his_L_c
# r2043: his_L_e + ser_L_c --> his_L_c + ser_L_e
# r2044: his_L_e + met_L_c --> his_L_c + met_L_e
# r2045: his_L_e + trp_L_c --> his_L_c + trp_L_e
# r2046: his_L_e + phe_L_c --> his_L_c + phe_L_e
# r2047: his_L_e + tyr_L_c --> his_L_c + tyr_L_e
# r2048: cys_L_c + his_L_e --> cys_L_e + his_L_c
# r2049: his_L_e + leu_L_c --> his_L_c + leu_L_e
# r2050: his_L_e + pro_L_c --> his_L_c + pro_L_e
# r2051: asn_L_c + his_L_e --> asn_L_e + his_L_c
# r2052: his_L_e + val_L_c --> his_L_c + val_L_e
# r2053: his_L_e + thr_L_c --> his_L_c + thr_L_e
# r2054: his_L_e + hom_L_c --> his_L_c + hom_L_e
# r2055: his_L_e + ile_L_c --> his_L_c + ile_L_e
# r2056: citr_L_e + gly_c --> citr_L_c + gly_e
# r2057: ala_L_c + citr_L_e --> ala_L_e + citr_L_c
# r2058: citr_L_e + gln_L_c --> citr_L_c + gln_L_e
# r2059: citr_L_e + ser_L_c --> citr_L_c + ser_L_e
# r2060: citr_L_e + met_L_c --> citr_L_c + met_L_e
# r2061: citr_L_e + trp_L_c --> citr_L_c + trp_L_e
# r2062: citr_L_e + phe_L_c --> citr_L_c + phe_L_e
# r2063: citr_L_e + tyr_L_c --> citr_L_c + tyr_L_e
# r2064: citr_L_e + cys_L_c --> citr_L_c + cys_L_e
# r2065: citr_L_e + leu_L_c --> citr_L_c + leu_L_e
# r2066: citr_L_e + pro_L_c --> citr_L_c + pro_L_e
# r2067: asn_L_c + citr_L_e --> asn_L_e + citr_L_c
# r2068: citr_L_e + val_L_c --> citr_L_c + val_L_e
# r2069: citr_L_e + thr_L_c --> citr_L_c + thr_L_e
# r2070: citr_L_e + hom_L_c --> citr_L_c + hom_L_e
# r2071: citr_L_e + ile_L_c --> citr_L_c + ile_L_e
# SERALANaEx: ala_L_c + na1_e + ser_L_e --> ala_L_e + na1_c + ser_L_c
# SERASNNaEx: asn_L_c + na1_e + ser_L_e --> asn_L_e + na1_c + ser_L_c
# SERCYSNaEx: cys_L_c + na1_e + ser_L_e --> cys_L_e + na1_c + ser_L_c
# SERGLNNaEx: gln_L_c + na1_e + ser_L_e --> gln_L_e + na1_c + ser_L_c
# SERt4: na1_e + ser_L_e --> na1_c + ser_L_c
# SERTHRNaEx: na1_e + ser_L_e + thr_L_c --> na1_c + ser_L_c + thr_L_e
# SO4CLtex: 2.0 cl_c + so4_e --> 2.0 cl_e + so4_c
# SO4HCOtex: 2.0 hco3_c + so4_e --> 2.0 hco3_e + so4_c
# SO4OXAtex2: oxa_c + 2.0 so4_e --> oxa_e + 2.0 so4_c
# SUCCt4_3: 3.0 na1_e + succ_e <=> 3.0 na1_c + succ_c
# TAUBETAtc: cl_e + 2.0 na1_e + taur_e --> cl_c + 2.0 na1_c + taur_c
# TCHOLAt: hco3_c + tchola_e <=> hco3_e + tchola_c
# THMMPt4: oh1_c + thmmp_e <=> oh1_e + thmmp_c
# THMt3: h_c + thm_e <=> h_e + thm_c
# THMTPt: 3.0 oh1_e + thmtp_c --> 3.0 oh1_c + thmtp_e
# THRALANaEx: ala_L_c + na1_e + thr_L_e --> ala_L_e + na1_c + thr_L_c
# THRASNNaEx: asn_L_c + na1_e + thr_L_e --> asn_L_e + na1_c + thr_L_c
# THRCYSNaEx: cys_L_c + na1_e + thr_L_e --> cys_L_e + na1_c + thr_L_c
# THRGLNNaEx: gln_L_c + na1_e + thr_L_e --> gln_L_e + na1_c + thr_L_c
# THRSERNaEx: na1_e + ser_L_c + thr_L_e --> na1_c + ser_L_e + thr_L_c
# THRt4: na1_e + thr_L_e --> na1_c + thr_L_c
# THYMDt1: thymd_e <=> thymd_c
# THYMt: thym_e <=> thym_c
# TRIODTHYt: hco3_c + triodthy_e <=> hco3_e + triodthy_c
# TRPt4: na1_e + trp_L_e --> na1_c + trp_L_c
# TTDCAtr: ttdca_e <=> ttdca_c
# TYRt4: na1_e + tyr_L_e --> na1_c + tyr_L_c
# URAt: ura_e <=> ura_c
# UREAt: urea_e <=> urea_c
# VALLAT1tc: leu_L_c + val_L_e <=> leu_L_e + val_L_c
# VALt4: na1_e + val_L_e --> na1_c + val_L_c
# VALtec: val_L_e <=> val_L_c
# HCO3E: co2_c + h2o_c <=> h_c + hco3_c
# HCO3Em: co2_m + h2o_m <=> h_m + hco3_m
# P5CRx: 1pyr5c_c + 2.0 h_c + nadh_c --> nad_c + pro_L_c
# DASCBR: dhdascb_c + h_c + nadph_c --> ascb_L_c + nadp_c
# GTHDH: dhdascb_c + 2.0 gthrd_c --> ascb_L_c + gthox_c
# HSD17B42x_cho: dhcholoylcoa_x + h2o_x + nadp_x --> dhocholoylcoa_x + h_x + nadph_x
# HSD17B4x_cho: cholcoads_x + h2o_x + nadp_x --> cholcoaone_x + h_x + nadph_x
# r0743: HC01459_x + nad_x --> cholcoaone_x + h_x + nadh_x
# RE1834C: cholcoa_c + h2o_c --> cholate_c + coa_c + h_c
# RE1835C: dcholcoa_c + h2o_c --> C02528_c + coa_c + h_c
# RE2649M: h2o_m + ppcoa_m --> coa_m + h_m + ppa_m
# ACACT1x: 2.0 accoa_x --> aacoa_x + coa_x
# C3STDH1r: 4mzym_int1_r + nad_r --> 4mzym_int2_r + co2_r + h_r + nadh_r
# C3STKR2r: h_r + nadph_r + zym_int2_r --> nadp_r + zymst_r
# CHOLESACATc: Rtotalcoa_c + chsterol_c --> coa_c + xolest2_cho_c
# HMGLm: hmgcoa_m --> acac_m + accoa_m
# HMGLx: hmgcoa_x --> acac_x + accoa_x
# PNTEH: h2o_c + ptth_c --> cysam_c + pnto_R_c
# DESAT16_2: h_c + nadh_c + o2_c + pmtcoa_c --> 2.0 h2o_c + hdcoa_c + nad_c
# DESAT18_3: h_c + nadh_c + o2_c + stcoa_c --> 2.0 h2o_c + nad_c + odecoa_c
# DESAT18_4: h_c + nadh_c + o2_c + stcoa_c --> 2.0 h2o_c + nad_c + vacccoa_c
# DESAT18_5: h_c + nadh_c + o2_c + stcoa_c --> 2.0 h2o_c + nad_c + od2coa_c
# DESAT20_1: dlnlcgcoa_c + h_c + nadh_c + o2_c --> arachdcoa_c + 2.0 h2o_c + nad_c
# DESAT20_2: eicostetcoa_c + h_c + nadh_c + o2_c --> 2.0 h2o_c + nad_c + tmndnccoa_c
# FAEL183_cho: 3.0 h_c + lnlncgcoa_c + malcoa_c + 2.0 nadph_c --> co2_c + coa_c + dlnlcgcoa_c + h2o_c + 2.0 nadp_c
# FAEL184_cho: 3.0 h_c + malcoa_c + 2.0 nadph_c + strdnccoa_c --> co2_c + coa_c + eicostetcoa_c + h2o_c + 2.0 nadp_c
# FAEL204_cho: arachdcoa_c + 3.0 h_c + malcoa_c + 2.0 nadph_c --> adrncoa_c + co2_c + coa_c + h2o_c + 2.0 nadp_c
# FAEL205_cho: 3.0 h_c + malcoa_c + 2.0 nadph_c + tmndnccoa_c --> clpndcoa_c + co2_c + coa_c + h2o_c + 2.0 nadp_c
# RE0344C: h2o_c + stcoa_c --> coa_c + h_c + ocdca_c
# RE0577C: arachcoa_c + h2o_c --> arach_c + coa_c + h_c
# RE0578C: docoscoa_c + h2o_c --> coa_c + docosac_c + h_c
# RE0579C: h2o_c + lgnccoa_c --> coa_c + h_c + lgnc_c
# RE3241R: h_r + hdcoa_r + malcoa_r --> CE5160_r + co2_r + coa_r
# r0208: gtp_c + h_c + man1p_c --> gdpmann_c + ppi_c
# TRIOK: atp_c + glyald_c --> adp_c + g3p_c + h_c
# UDPG4E: udpg_c <=> udpgal_c
# GLNS: atp_c + glu_L_c + nh4_c --> adp_c + gln_L_c + h_c + pi_c
# GLUN: gln_L_c + h2o_c --> glu_L_c + nh4_c
# r0245: glyc_c + nadp_c <=> glyald_c + h_c + nadph_c
# NACHEX10ly: 2.0 h2o_l + ksi_deg7_l --> 2.0 acgam_l + ksi_deg8_l
# NACHEX11ly: h2o_l + ksi_deg10_l --> acgam_l + ksi_deg11_l
# NACHEX12ly: h2o_l + ksi_deg13_l --> acgam_l + ksi_deg14_l
# NACHEX13ly: h2o_l + ksi_deg16_l --> acgam_l + ksi_deg17_l
# NACHEX14ly: h2o_l + ksi_deg19_l --> acgam_l + ksi_deg20_l
# NACHEX15ly: h2o_l + ksi_deg22_l --> acgam_l + ksi_deg23_l
# NACHEX16ly: h2o_l + ksi_deg25_l --> acgam_l + ksi_deg26_l
# NACHEX17ly: h2o_l + ksi_deg28_l --> acgam_l + ksi_deg29_l
# NACHEX18ly: h2o_l + ksi_deg31_l --> acgam_l + ksi_deg32_l
# NACHEX19ly: h2o_l + ksi_deg34_l --> acgam_l + ksi_deg35_l
# NACHEX20ly: h2o_l + ksi_deg37_l --> acgam_l + ksi_deg38_l
# NACHEX21ly: h2o_l + ksi_deg39_l --> acgam_l + ksi_deg40_l
# NACHEX22ly: h2o_l + ksi_deg41_l --> acgam_l + m2mn_l
# NACHEX23ly: h2o_l + ksii_core2_deg4_l --> acgam_l + ksii_core2_deg5_l
# NACHEX24ly: h2o_l + ksii_core2_deg7_l --> acgam_l + ksii_core2_deg8_l
# NACHEX25ly: h2o_l + ksii_core2_deg9_l --> acgam_l + f1a_l
# NACHEX26ly: 2.0 h2o_l + ksii_core4_deg4_l --> 2.0 acgam_l + ksii_core2_deg5_l
# DOLK: ctp_c + dolichol_c --> cdp_c + dolp_c + h_c
# DOLPMT: dolp_c + gdpmann_c --> dolmanp_c + gdp_c
# DPPS: frdp_c + 7.0 ipdp_c --> decdp_c + 7.0 ppi_c
# F6T2g: gdpfuc_g + nm4masn_g --> fnm4masn_g + gdp_g + h_g
# F6T3g: gdpfuc_g + nm2masn_g --> fnm2masn_g + gdp_g + h_g
# F6T4g: gdpfuc_g + n3m2masn_g --> fn3m2masn_g + gdp_g + h_g
# F6T5g: gdpfuc_g + n4m2masn_g --> fn4m2masn_g + gdp_g + h_g
# F6T6g: gdpfuc_g + n3rm2masn_g --> fn3rm2masn_g + gdp_g + h_g
# G12MT1_cho: gdpmann_c + m2mpdol_c --> gdp_c + h_c + m3mpdol_c
# G12MT2_cho: gdpmann_c + m3mpdol_c --> gdp_c + h_c + m4mpdol_c
# G13MT_cho: gdpmann_c + mpdol_c --> gdp_c + h_c + m1mpdol_c
# G14N10g: ndl4fn4m2masn_g + udpgal_g --> h_g + lndl4fn4m2masn_g + udp_g
# G14N11g: ndl4n4m2masn_g + udpgal_g --> h_g + lndl4n4m2masn_g + udp_g
# G14N12g: ncl4fn4m2masn_g + udpgal_g --> h_g + lncl4fn4m2masn_g + udp_g
# G14N13g: ncl4n4m2masn_g + udpgal_g --> h_g + lncl4n4m2masn_g + udp_g
# G14N14g: nbl4fn4m2masn_g + udpgal_g --> h_g + lnbl4fn4m2masn_g + udp_g
# G14N15g: nbl4n4m2masn_g + udpgal_g --> h_g + lnbl4n4m2masn_g + udp_g
# G14N16g: n2cdl4fn4m2masn_g + 2.0 udpgal_g --> 2.0 h_g + l2n2cdl4fn4m2masn_g + 2.0 udp_g
# G14N17g: n2cdl4n4m2masn_g + 2.0 udpgal_g --> 2.0 h_g + l2n2cdl4n4m2masn_g + 2.0 udp_g
# G14N18g: n2bdl4fn4m2masn_g + 2.0 udpgal_g --> 2.0 h_g + l2n2bdl4fn4m2masn_g + 2.0 udp_g
# G14N19g: n2bdl4n4m2masn_g + 2.0 udpgal_g --> 2.0 h_g + l2n2bdl4n4m2masn_g + 2.0 udp_g
# G14N1g: n2m2masn_g + 2.0 udpgal_g --> 2.0 h_g + l2n2m2masn_g + 2.0 udp_g
# G14N20g: n3l4fn4m2masn_g + 3.0 udpgal_g --> 3.0 h_g + l3n3l4fn4m2masn_g + 3.0 udp_g
# G14N21g: n3l4n4m2masn_g + 3.0 udpgal_g --> 3.0 h_g + l3n3l4n4m2masn_g + 3.0 udp_g
# G14N2g: n3m2masn_g + 3.0 udpgal_g --> 3.0 h_g + l3n3m2masn_g + 3.0 udp_g
# G14N3g: n3rm2masn_g + 3.0 udpgal_g --> 3.0 h_g + l3n3rm2masn_g + 3.0 udp_g
# G14N4g: fn3m2masn_g + 3.0 udpgal_g --> 3.0 h_g + l3fn3m2masn_g + 3.0 udp_g
# G14N5g: fn3rm2masn_g + 3.0 udpgal_g --> 3.0 h_g + l3fn3rm2masn_g + 3.0 udp_g
# G14N6g: fn4m2masn_g + 4.0 udpgal_g --> 4.0 h_g + l4fn4m2masn_g + 4.0 udp_g
# G14N7g: nl3n3m2masn_g + udpgal_g --> h_g + lnl3n3m2masn_g + udp_g
# G14N8g: n4m2masn_g + 4.0 udpgal_g --> 4.0 h_g + l4n4m2masn_g + 4.0 udp_g
# G14N9g: nl3fn3m2masn_g + udpgal_g --> h_g + lnl3fn3m2masn_g + udp_g
# GLCNACT_cho: naglc2p_c + uacgam_c --> chito2pdol_c + h_c + udp_c
# M1316M2g: fnm4masn_g + h2o_g --> fnm2masn_g + 2.0 man_g
# M13N14N3T1g: l3n3m2masn_g + uacgam_g --> h_g + nl3n3m2masn_g + udp_g
# M13N14N3T2g: l3fn3m2masn_g + uacgam_g --> h_g + nl3fn3m2masn_g + udp_g
# M13N14N3T3g: l4n4m2masn_g + uacgam_g --> h_g + nbl4n4m2masn_g + udp_g
# M13N14N3T4g: l4fn4m2masn_g + uacgam_g --> h_g + nbl4fn4m2masn_g + udp_g
# M13N4T1g: fn2m2masn_g + uacgam_g --> fn3m2masn_g + h_g + udp_g
# M13N4T2g: n3rm2masn_g + uacgam_g --> h_g + n4m2masn_g + udp_g
# M13N4T3g: fn3rm2masn_g + uacgam_g --> fn4m2masn_g + h_g + udp_g
# M1613N1614N3T1g: l4n4m2masn_g + 2.0 uacgam_g --> 2.0 h_g + n2bdl4n4m2masn_g + 2.0 udp_g
# M1613N1614N3T2g: l4fn4m2masn_g + 2.0 uacgam_g --> 2.0 h_g + n2bdl4fn4m2masn_g + 2.0 udp_g
# M1613N3xN3T1g: l4n4m2masn_g + 3.0 uacgam_g --> 3.0 h_g + n3l4n4m2masn_g + 3.0 udp_g
# M1613N3xN3T2g: l4fn4m2masn_g + 3.0 uacgam_g --> 3.0 h_g + n3l4fn4m2masn_g + 3.0 udp_g
# M16N1216N3T1g: l4n4m2masn_g + 2.0 uacgam_g --> 2.0 h_g + n2cdl4n4m2masn_g + 2.0 udp_g
# M16N1216N3T2g: l4fn4m2masn_g + 2.0 uacgam_g --> 2.0 h_g + n2cdl4fn4m2masn_g + 2.0 udp_g
# M16N12N3T1g: l4n4m2masn_g + uacgam_g --> h_g + ncl4n4m2masn_g + udp_g
# M16N12N3T2g: l4fn4m2masn_g + uacgam_g --> h_g + ncl4fn4m2masn_g + udp_g
# M16N16N3T1g: l4n4m2masn_g + uacgam_g --> h_g + ndl4n4m2masn_g + udp_g
# M16N16N3T2g: l4fn4m2masn_g + uacgam_g --> h_g + ndl4fn4m2masn_g + udp_g
# M16N6T1g: fn3m2masn_g + uacgam_g --> fn4m2masn_g + h_g + udp_g
# M16N6T2g: n2m2masn_g + uacgam_g --> h_g + n3rm2masn_g + udp_g
# M16N6T3g: fn2m2masn_g + uacgam_g --> fn3rm2masn_g + h_g + udp_g
# M16NT1g: fnm2masn_g + uacgam_g --> fn2m2masn_g + h_g + udp_g
# S23TN10g: 3.0 cmpacna_g + lnl3fn3m2masn_g --> 3.0 cmp_g + 3.0 h_g + s3lnl3fn3m2masn_g
# S23TN11g: 4.0 cmpacna_g + lndl4fn4m2masn_g --> 4.0 cmp_g + 4.0 h_g + s4lndl4fn4m2masn_g
# S23TN12g: 4.0 cmpacna_g + lndl4n4m2masn_g --> 4.0 cmp_g + 4.0 h_g + s4lndl4n4m2masn_g
# S23TN13g: 4.0 cmpacna_g + lncl4fn4m2masn_g --> 4.0 cmp_g + 4.0 h_g + s4lncl4fn4m2masn_g
# S23TN14g: 4.0 cmpacna_g + lncl4n4m2masn_g --> 4.0 cmp_g + 4.0 h_g + s4lncl4n4m2masn_g
# S23TN15g: 4.0 cmpacna_g + lnbl4fn4m2masn_g --> 4.0 cmp_g + 4.0 h_g + s4lnbl4fn4m2masn_g
# S23TN16g: 4.0 cmpacna_g + lnbl4n4m2masn_g --> 4.0 cmp_g + 4.0 h_g + s4lnbl4n4m2masn_g
# S23TN17g: 4.0 cmpacna_g + l2n2cdl4fn4m2masn_g --> 4.0 cmp_g + 4.0 h_g + s4l2n2cdl4fn4m2masn_g
# S23TN18g: 4.0 cmpacna_g + l2n2cdl4n4m2masn_g --> 4.0 cmp_g + 4.0 h_g + s4l2n2cdl4n4m2masn_g
# S23TN19g: 4.0 cmpacna_g + l2n2bdl4fn4m2masn_g --> 4.0 cmp_g + 4.0 h_g + s4l2n2bdl4fn4m2masn_g
# S23TN20g: 4.0 cmpacna_g + l2n2bdl4n4m2masn_g --> 4.0 cmp_g + 4.0 h_g + s4l2n2bdl4n4m2masn_g
# S23TN21g: 4.0 cmpacna_g + l3n3l4fn4m2masn_g --> 4.0 cmp_g + 4.0 h_g + s4l3n3l4fn4m2masn_g
# S23TN22g: 4.0 cmpacna_g + l3n3l4n4m2masn_g --> 4.0 cmp_g + 4.0 h_g + s4l3n3l4n4m2masn_g
# S23TN2g: 2.0 cmpacna_g + l2n2m2masn_g --> 2.0 cmp_g + 2.0 h_g + s2l2n2m2masn_g
# S23TN3g: 3.0 cmpacna_g + l3n3m2masn_g --> 3.0 cmp_g + 3.0 h_g + s3l3n3m2masn_g
# S23TN4g: 3.0 cmpacna_g + l3n3rm2masn_g --> 3.0 cmp_g + 3.0 h_g + s3l3n3rm2masn_g
# S23TN5g: 3.0 cmpacna_g + l3fn3m2masn_g --> 3.0 cmp_g + 3.0 h_g + s3l3fn3m2masn_g
# S23TN6g: 3.0 cmpacna_g + l3fn3rm2masn_g --> 3.0 cmp_g + 3.0 h_g + s3l3fn3rm2masn_g
# S23TN7g: 4.0 cmpacna_g + l4fn4m2masn_g --> 4.0 cmp_g + 4.0 h_g + s4l4fn4m2masn_g
# S23TN8g: 3.0 cmpacna_g + lnl3n3m2masn_g --> 3.0 cmp_g + 3.0 h_g + s3lnl3n3m2masn_g
# S23TN9g: 4.0 cmpacna_g + l4n4m2masn_g --> 4.0 cmp_g + 4.0 h_g + s4l4n4m2masn_g
# DNADDP: dnad_c + h2o_c --> amp_c + 2.0 h_c + nicrnt_c
# NACPRT: atp_c + h2o_c + nac_c + prpp_c <=> adp_c + nicrnt_c + pi_c + ppi_c
# NADDP: h2o_c + nad_c --> amp_c + 2.0 h_c + nmn_c
# NMNS: h_c + ncam_c + prpp_c --> nmn_c + ppi_c
# RNMK: atp_c + rnam_c --> adp_c + h_c + nmn_c
# THD1m: h_c + nadh_m + nadp_m --> h_m + nad_m + nadph_m
# ACGPID_cho: acgpail_cho_c + h2o_c --> ac_c + gpail_cho_c
# GPIAT_cho: gpail_cho_c + pmtcoa_c --> coa_c + gacpail_cho_c
# GPIDA2er_cho: em2emgacpail_prot_cho_r + h2o_r --> dem2emgacpail_prot_cho_r + h_r + hdca_r
# GPIDAer_cho: gpi_prot_cho_r + h2o_r --> dgpi_prot_cho_r + h_r + hdca_r
# H2ETer_cho: mgacpail_cho_r + pe_cho_r --> dag_cho_r + emgacpail_cho_r
# H3ETer_cho: m2gacpail_cho_r + pe_cho_r --> dag_cho_r + memgacpail_cho_r
# H4ETer_cho: m3gacpail_cho_r + pe_cho_r --> dag_cho_r + m2emgacpail_cho_r
# H6_ET2er_cho: em3gacpail_cho_r + pe_cho_r --> dag_cho_r + emem2gacpail_cho_r
# H6_ETer_cho: em3gacpail_cho_r + pe_cho_r --> dag_cho_r + em2emgacpail_cho_r
# H7_ETer_cho: emem2gacpail_cho_r + pe_cho_r --> dag_cho_r + gpi_cho_r
# H7_TAer_cho: em2emgacpail_cho_r + pre_prot_r --> em2emgacpail_prot_cho_r + gpi_sig_r
# H7ET2er_cho: em2emgacpail_cho_r + pe_cho_r --> dag_cho_r + gpi_cho_r
# H8TAer_cho: gpi_cho_r + pre_prot_r --> gpi_prot_cho_r + gpi_sig_r
# PI3PP_cho: h2o_c + pail3p_cho_c --> pail_cho_c + pi_c
# PIACGT_cho: pail_cho_c + uacgam_c --> acgpail_cho_c + h_c + udp_c
# RE1957R: atp_r + pail35p_cho_r --> adp_r + h_r + pail345p_cho_r
# RE2972M: atp_m + pail5p_cho_m --> adp_m + h_m + pail45p_cho_m
# RE2973N: atp_n + pail5p_cho_n <=> adp_n + h_n + pail35p_cho_n
# RE3273C: h2o_c + pail_cho_c --> h_c + inost_c + pa_cho_c
# CTPS2: atp_c + gln_L_c + h2o_c + utp_c --> adp_c + ctp_c + glu_L_c + 2.0 h_c + pi_c
# RE0453N: datp_n + dtdp_n <=> dadp_n + dttp_n
# RE1530M: dgtp_m + duri_m --> dgdp_m + dump_m + h_m
# RE2954C: dtdp_c + h_c + pep_c --> dttp_c + pyr_c
# URIK1: atp_c + uri_c --> adp_c + h_c + ump_c
# CAT: 2.0 h2o2_c --> 2.0 h2o_c + o2_c
# SPODM: 2.0 h_c + 2.0 o2s_c --> h2o2_c + o2_c
# SPODMn: 2.0 h_n + 2.0 o2s_n --> h2o2_n + o2_n
# SPODMx: 2.0 h_x + 2.0 o2s_x --> h2o2_x + o2_x
# URPT: prpp_c + ura_c --> ppi_c + ump_c
# B3GNT35g_cho: acglcgalgbside_cho_g + udpgal_g --> galacglcgalgbside_cho_g + h_g + udp_g
# B3GNT37g_cho: gm2a_cho_g + udpgal_g --> gm1a_cho_g + h_g + udp_g
# DHCRD1_cho: dhcrm_cho_c + nadp_c --> crm_cho_c + h_c + nadph_c
# DHCRD2_cho: dhcrm_cho_c + fad_c --> crm_cho_c + fadh2_c
# GALC_cho: galside_cho_l + h2o_l --> crm_cho_l + gal_l
# GBA_cho: gluside_cho_c + h2o_c --> crm_cho_c + glc_D_c
# GBAl_cho: gluside_cho_l + h2o_l --> crm_cho_l + glc_D_l
# RE2675C: dhcrm_cho_c + h_c + nadh_c + o2_c --> crm_cho_c + 2.0 h2o_c + nad_c
# SBPP1er: h2o_r + sph1p_r --> pi_r + sphgn_r
# SBPP3er: h2o_r + sphs1p_r --> pi_r + sphings_r
# SERPT: h_c + pmtcoa_c + ser_L_c --> 3dsphgn_c + co2_c + coa_c
# SIAT4Bg_cho: cmpacna_g + galgbside_cho_g --> acngalgbside_cho_g + cmp_g + h_g
# SLCBK1: atp_c + sphgn_c --> adp_c + h_c + sph1p_c
# SMPD3l_cho: h2o_l + sphmyln_cho_l --> cholp_l + crm_cho_l + h_l
# SMPD4_cho: h2o_c + spc_cho_c --> cholp_c + h_c + sphings_c
# SMPDE: h2o_c + sphmyln_cho_c --> cholp_c + crm_cho_c + h_c
# SMS_cho: crm_cho_c + pchol_cho_c --> dag_cho_c + sphmyln_cho_c
# SPHK21c: atp_c + sphings_c --> adp_c + h_c + sphs1p_c
# ST3GAL21g_cho: cmpacna_g + ga1_cho_g --> cmp_g + gm1b_cho_g + h_g
# ST3GAL22g_cho: cmpacna_g + gm1_cho_g --> cmp_g + gd1a_cho_g + h_g
# ST3GAL23g_cho: cmpacna_g + gd1b_cho_g --> cmp_g + gt1b_cho_g + h_g
# ST6GALNAC21_cho: acngalgbside_cho_g + cmpacna_g --> acn13acngalgbside_cho_g + cmp_g + h_g
# ST6GALNAC22_cho: acngalgbside_cho_g + cmpacna_g --> acn23acngalgbside_cho_g + cmp_g + h_g
# ST6GALNAC23_cho: cmpacna_g + ga2_cho_g --> cmp_g + gm2a_cho_g + h_g
# ST6GALNAC24_cho: cmpacna_g + gm1a_cho_g --> cmp_g + gd1b2_cho_g + h_g
# ST6GALNAC25_cho: cmpacna_g + gd1a_cho_g --> cmp_g + gt1alpha_cho_g + h_g
# ST6GALNAC27_cho: cmpacna_g + gt1c_cho_g --> cmp_g + gq1c_cho_g + h_g
# ST6GALNAC31_cho: cmpacna_g + gm1b_cho_g --> cmp_g + gd1a_cho_g + h_g
# ST6GALNAC62_cho: cmpacna_g + gt1b_cho_g --> cmp_g + gq1balpha_cho_g + h_g
# UGCG_cho: crm_cho_r + udpg_r --> gluside_cho_r + h_r + udp_r
# UGCGc: crm_cho_c + udpg_c --> gluside_cho_c + h_c + udp_c
# DPMVDc: 5dpmev_c + atp_c --> adp_c + co2_c + ipdp_c + pi_c
# HMGCOARc: 2.0 h_c + hmgcoa_c + 2.0 nadph_c <=> coa_c + mev_R_c + 2.0 nadp_c
# MEVK1c: atp_c + mev_R_c --> 5pmev_c + adp_c + h_c
# PMEVKc: 5pmev_c + atp_c --> 5dpmev_c + adp_c
# DHEASULT: dhea_c + paps_c --> dheas_c + h_c + pap_c
# HSD17B7r: estrone_r + h_r + nadph_r --> estradiol_r + nadp_r
# HSD3B11r: nad_r + prgnlone_r --> h_r + nadh_r + prgstrn_r
# HSD3B12r: dhea_r + nad_r --> andrstndn_r + h_r + nadh_r
# HSD3B13r: 17ahprgnlone_r + nad_r --> 17ahprgstrn_r + h_r + nadh_r
# P45011A1m: chsterol_m + h_m + nadph_m + 2.0 o2_m --> 4mptnl_m + 2.0 h2o_m + nadp_m + prgnlone_m
# P45011B11m: 11docrtstrn_m + h_m + nadph_m + o2_m --> crtstrn_m + h2o_m + nadp_m
# P45011B12m: 11docrtsl_m + h_m + nadph_m + o2_m --> crtsl_m + h2o_m + nadp_m
# P45011B21m: 11docrtstrn_m + h_m + nadph_m + 2.0 o2_m --> aldstrn_m + 2.0 h2o_m + nadp_m
# PRGNLONESULT: paps_c + prgnlone_c --> h_c + pap_c + prgnlones_c
# SR5AR2r: andrstndn_r + h_r + nadph_r --> andrstandn_r + nadp_r
# SR5ARr: h_r + nadph_r + tststerone_r --> 5adtststerone_r + nadp_r
# STS1: dheas_c + h2o_c --> dhea_c + h_c + so4_c
# STS2: estrones_c + h2o_c --> estrone_c + h_c + so4_c
# STS3: chsterols_c + h2o_c --> chsterol_c + h_c + so4_c
# ...
# SARCStm: sarcs_c <=> sarcs_m
# SBCOAACOTx: h2o_x + sbcoa_x --> coa_x + h_x + subeac_x
# SBT_Dtde: sbt_D_c <=> sbt_D_e
# SCP21cx: atp_c + h2o_c + phytcoa_c --> adp_c + h_c + phytcoa_x + pi_c
# SEBACACT: atp_c + coa_c + sebacid_c --> amp_c + ppi_c + sebcoa_c
# SEBACIDTD: sebacid_x <=> sebacid_c
# SEBCOACROT: crn_x + sebcoa_x <=> c10dc_x + coa_x
# SEBCOAPET: h2o_x + sebcoa_x --> coa_x + h_x + sebacid_x
# Ser_Thrtg: Ser_Thr_g <=> Ser_Thr_l
# SERATB0tc: cl_e + 2.0 na1_e + ser_L_e --> cl_c + 2.0 na1_c + ser_L_c
# SERtp: ser_L_c <=> ser_L_x
# SFCYSc: cys_L_c + h_c + so3_c <=> slfcys_c
# SFCYSe: slfcys_c <=> slfcys_e
# SGALSIDEtg_cho: sgalside_cho_c <=> sgalside_cho_g
# SGALSIDEtl_cho: sgalside_cho_c <=> sgalside_cho_l
# SLDt: sl_L_c --> sl_L_e
# SO4tl: so4_l <=> so4_c
# SPC_CHOt: spc_cho_c <=> spc_cho_e
# SPH1Pte: sph1p_c <=> sph1p_e
# SPH1Ptr: sph1p_c <=> sph1p_r
# SPHGNtr: sphgn_r <=> sphgn_c
# SPHINGStl: sphings_c <=> sphings_l
# SPHINGStr: sphings_c <=> sphings_r
# SPHMYLNtg_cho: sphmyln_cho_c <=> sphmyln_cho_g
# SPHMYLNtl_cho: sphmyln_cho_c <=> sphmyln_cho_l
# SPHS1Pte: sphs1p_c <=> sphs1p_e
# SPHS1Ptr: sphs1p_c <=> sphs1p_r
# SPMTDe: spmd_e <=> spmd_c
# SPRMTDe: sprm_e <=> sprm_c
# STCOAtx: stcoa_c <=> stcoa_x
# STCOATxc: atp_c + h2o_c + stcoa_c --> adp_c + h_c + pi_c + stcoa_x
# STRDNCt: strdnc_e <=> strdnc_c
# SUBEACTD: subeac_x <=> subeac_c
# SUBERCACT: c8dc_x <=> c8dc_c
# SUBERCROT: crn_x + sbcoa_x <=> c8dc_x + coa_x
# SUBERICACT: atp_c + coa_c + subeac_c --> amp_c + ppi_c + sbcoa_c
# T4HCINNMFM: 34hpl_m --> T4hcinnm_m + h2o_m
# TAGt_cho: tag_cho_e <=> tag_cho_c
# TAUPAT1c: h_e + taur_e --> h_c + taur_c
# TAURCHAe: taur_c --> taur_e
# TAXOLte: taxol_e <=> taxol_c
# TCHOLAte: tchola_e <=> tchola_c
# TCHOLAtx: tchola_x <=> tchola_c
# TCYNTt: tcynt_c --> tcynt_e
# TCYNTtm: tcynt_m --> tcynt_c
# TDCHOLAte: tdchola_e <=> tdchola_c
# TDCHOLAtx: tdchola_x <=> tdchola_c
# TDP: h2o_c + thmpp_c --> h_c + pi_c + thmmp_c
# TDPm: h2o_m + thmpp_m --> h_m + pi_m + thmmp_m
# TETHEX3COAtx: tethex3coa_c <=> tethex3coa_x
# TETHEX3t: tethex3_e <=> tethex3_c
# TETPENT3COAtx: tetpent3coa_c <=> tetpent3coa_x
# TETPENT3t: tetpent3_e <=> tetpent3_c
# TETPENT6COAtx: tetpent6coa_c <=> tetpent6coa_x
# TETPENT6t: tetpent6_e <=> tetpent6_c
# TETTET6COAtx: tettet6coa_c <=> tettet6coa_x
# TETTET6t: tettet6_e <=> tettet6_c
# THCHOLSTOICtm: thcholstoic_m <=> thcholstoic_x
# THFtl: thf_c <=> thf_l
# THFtm: thf_c <=> thf_m
# THMATPe: atp_c + h2o_c + thm_c --> adp_c + h_c + pi_c + thm_e
# THMMPtm_cho: h2o_m + thmmp_c <=> h2o_c + thmmp_m
# THMP: h2o_c + thmmp_c --> pi_c + thm_c
# THMPPtm_cho: 2.0 h2o_m + thmpp_c --> 2.0 h2o_c + thmpp_m
# THP2Ctp: thp2c_c <=> thp2c_x
# THRATB0tc: cl_e + 2.0 na1_e + thr_L_e --> cl_c + 2.0 na1_c + thr_L_c
# TIGCRNe: c51crn_c --> c51crn_e
# TMDPPK: atp_c + thmpp_c --> adp_c + thmtp_c
# TMNDNCCOAtx: tmndnccoa_c <=> tmndnccoa_x
# TMNDNCt: tmndnc_e <=> tmndnc_c
# TOLBUTAMIDEte: tolbutamide_e <=> tolbutamide_c
# TRIODTHYSUFt: triodthysuf_c --> triodthysuf_e
# TRPATB0tc: cl_e + 2.0 na1_e + trp_L_e --> cl_c + 2.0 na1_c + trp_L_c
# TSTSTERONEGLCtr: tststeroneglc_c <=> tststeroneglc_r
# TSTSTERONESte: tststerones_c <=> tststerones_e
# TSTSTERONEt: tststerone_e <=> tststerone_c
# TSTSTERONEtr: tststerone_r <=> tststerone_c
# TTDCAFATPc: atp_c + coa_c + ttdca_e --> amp_c + ppi_c + tdcoa_c
# TXA2te: txa2_e <=> txa2_c
# TXA2tr: txa2_c <=> txa2_r
# TYMSFt: tymsf_c --> tymsf_e
# TYRATB0tc: cl_e + 2.0 na1_e + tyr_L_e --> cl_c + 2.0 na1_c + tyr_L_c
# UDPACGALtl: udpacgal_c <=> udpacgal_l
# UDPG1P: h2o_c + udpglcur_c --> glcur1p_c + 2.0 h_c + ump_c
# UDPGLCter: udpg_c + ump_r <=> udpg_r + ump_c
# UDPGNP: h2o_c + udpglcur_c --> glcur_c + h_c + udp_c
# UDPtl: udp_c <=> udp_l
# UMPtr: ump_c <=> ump_r
# UNK2_cho: 2kmb_c + gln_L_c + 2.0 h_c --> glu_L_c + met_L_c
# URATEt: urate_c --> urate_e
# URATEtx: urate_x --> urate_c
# Uritn: uri_c <=> uri_n
# UROLACer: glcur_r + h_r <=> glac_r + h2o_r
# VACCt: vacc_e <=> vacc_c
# VALATB0tc: cl_e + 2.0 na1_e + val_L_e --> cl_c + 2.0 na1_c + val_L_c
# VALt5m: val_L_c <=> val_L_m
# VD3: pd3_c <=> vitd3_c
# VITD3t: vitd3_c <=> vitd3_e
# VITD3tm: vitd3_m <=> vitd3_c
# VITEtl: atp_c + avite1_c + h2o_c --> adp_c + avite1_e + h_c + pi_c
# VITKtl: phyQ_c --> phyQ_e
# WHDDCAte: whddca_e <=> whddca_c
# WHHDCAte: whhdca_e <=> whhdca_c
# WHTTDCAte: whttdca_e <=> whttdca_c
# XANtx: xan_c --> xan_x
# XOL27OHtm: xol27oh_r <=> xol27oh_m
# XOL7AH2tm: xol7ah2_c <=> xol7ah2_m
# XOL7AONEtr: xol7aone_c <=> xol7aone_r
# XOLDIOLONEt: xoldiolone_c <=> xoldiolone_r
# XOLEST2te_cho: xolest2_cho_e <=> xolest2_cho_c
# XOLESTte_cho: xolest_cho_e <=> xolest_cho_c
# XOLTRI24tc: xoltri24_r <=> xoltri24_c
# XOLTRI24te: xoltri24_c <=> xoltri24_e
# XOLTRI25tc: xoltri25_r <=> xoltri25_c
# XOLTRI25te: xoltri25_c <=> xoltri25_e
# XOLTRI27tc: xoltri27_r <=> xoltri27_c
# XOLTRI27te: xoltri27_c <=> xoltri27_e
# XOLTRIOLtm: xoltriol_c <=> xoltriol_m
# XYLTD_Dr: nad_c + xylt_c <=> h_c + nadh_c + xylu_D_c
# XYLtly: xyl_D_l --> xyl_D_c
# XYLTt: xylt_e <=> xylt_c
# YVITEt: yvite_e --> yvite_c
# 2AOBUTtm: 2aobut_c <=> 2aobut_m
# CYSAMO_cho: cysam_c + o2_c --> h_c + hyptaur_c
# HSDA: hom_L_c --> 2obut_c + nh4_c
# PGAM1_PhosHydro: h2o_c + pep_c --> pi_c + pyr_c
# PIt2m_2: 2.0 h_c + pi_c --> 2.0 h_m + pi_m
# THR3D: nad_c + thr_L_c --> 2aobut_c + h_c + nadh_c
# gthox_export: gthox_c <=> gthox_e
# peplys_synthesis: lys_L_n --> peplys_n
# SK_Asn_X_Ser_Thr_r_: Asn_X_Ser_Thr_r <=>
# SK_Ser_Thr_g_: Ser_Thr_g <=>
# SK_Tyr_ggn_c_: Tyr_ggn_c <=>
# FAOXC15ATPx: atp_x + coa_x + prist_x --> amp_x + ppi_x + pristcoa_x
# FAOXC16Brx: atp_x + coa_x + phyt_x --> amp_x + phytcoa_x + ppi_x
# LNLNCGCOAtx: lnlncgcoa_x <=> lnlncgcoa_c
# epo_translation: 20.0 ala_L_c + 13.0 arg_L_c + 6.0 asn_L_c + 6.0 asp_L_c + 194.0 atp_c + 5.0 cys_L_c + 7.0 gln_L_c + 13.0 glu_L_c + 12.0 gly_c + 385.0 gtp_c + 194.0 h2o_c + 3.0 his_L_c + 5.0 ile_L_c + 33.0 leu_L_c + 8.0 lys_L_c + 2.0 met_L_c + 4.0 phe_L_c + 11.0 pro_L_c + 12.0 ser_L_c + 11.0 thr_L_c + 5.0 trp_L_c + 4.0 tyr_L_c + 13.0 val_L_c --> adp_c + 193.0 amp_c + epoIm_r + 385.0 gdp_c + 386.0 h_c + 386.0 pi_c + 193.0 ppi_c
# epo_processing: dsT_antigen_g + epoIm_r + h2o_g + 0.0357 s2l2fn2m2masn_g + 0.0063 s2l2n2m2masn_g + 0.08925 s3l3fn3m2masn_g + 0.16575 s3l3fn3rm2masn_g + 0.01575 s3l3n3m2masn_g + 0.02925 s3l3n3rm2masn_g + 0.08925 s3lnl3fn3m2masn_g + 0.01575 s3lnl3n3m2masn_g + 0.08415 s4l2n2bdl4fn4m2masn_g + 0.01485 s4l2n2bdl4n4m2masn_g + 0.3366 s4l2n2cdl4fn4m2masn_g + 0.0594 s4l2n2cdl4n4m2masn_g + 0.11985 s4l3n3l4fn4m2masn_g + 0.02115 s4l3n3l4n4m2masn_g + 0.8109 s4l4fn4m2masn_g + 0.1431 s4l4n4m2masn_g + 0.0816 s4lnbl4fn4m2masn_g + 0.0144 s4lnbl4n4m2masn_g + 0.0816 s4lncl4fn4m2masn_g + 0.0144 s4lncl4n4m2masn_g + 0.65535 s4lndl4fn4m2masn_g + 0.11565 s4lndl4n4m2masn_g --> epo_g + peptide_c
# DM_epo_g_: epo_g -->
# epo_degradation: 26.0 h2o_c + peptide_c --> ala_L_c + cys_L_c + glu_L_c + 3.0 gly_c + his_L_c + 10.0 leu_L_c + met_L_c + 3.0 pro_L_c + 2.0 ser_L_c + 2.0 trp_L_c + 2.0 val_L_c
# igg_hc: 24.0 ala_L_c + 8.0 arg_L_c + 19.0 asn_L_c + 17.0 asp_L_c + 452.0 atp_c + 11.0 cys_L_c + 18.0 gln_L_c + 20.0 glu_L_c + 31.0 gly_c + 900.0 gtp_c + 901.0 h2o_c + 10.0 his_L_c + 7.0 ile_L_c + 32.0 leu_L_c + 36.0 lys_L_c + 5.0 met_L_c + 13.0 phe_L_c + 35.0 pro_L_c + 53.0 ser_L_c + 38.0 thr_L_c + 9.0 trp_L_c + 22.0 tyr_L_c + 43.0 val_L_c --> adp_c + 451.0 amp_c + 900.0 gdp_c + 901.0 h_c + igg_hc_r + 901.0 pi_c + 451.0 ppi_c
# igg_lc: 15.0 ala_L_c + 6.0 arg_L_c + 7.0 asn_L_c + 6.0 asp_L_c + 214.0 atp_c + 5.0 cys_L_c + 12.0 gln_L_c + 11.0 glu_L_c + 13.0 gly_c + 424.0 gtp_c + 425.0 h2o_c + 3.0 his_L_c + 7.0 ile_L_c + 13.0 leu_L_c + 13.0 lys_L_c + met_L_c + 7.0 phe_L_c + 13.0 pro_L_c + 35.0 ser_L_c + 17.0 thr_L_c + 4.0 trp_L_c + 9.0 tyr_L_c + 16.0 val_L_c --> adp_c + 213.0 amp_c + 424.0 gdp_c + 425.0 h_c + igg_lc_r + 425.0 pi_c + 213.0 ppi_c
# igg_formation: 2.0 igg_hc_r + 2.0 igg_lc_r + 2.0 l2fn2m2masn_g --> igg_g
# DM_igg_g_: igg_g -->
# r2095: for_c + pyr_e <=> for_e + pyr_c
# C8CRNt: c8crn_c --> c8crn_m
# MALCRNt: HC10859_c --> HC10859_m
# DM_T_antigen_g_: T_antigen_g -->
# DM_avite1_c_: avite1_c -->
# DM_avite2_c_: avite2_c -->
# DM_bvite_c_: bvite_c -->
# DM_core5_g_: core5_g -->
# DM_core7_g_: core7_g -->
# DM_core8_g_: core8_g -->
# DM_dem2emgacpail_prot_cho_r_: dem2emgacpail_prot_cho_r -->
# DM_dgpi_prot_cho_r_: dgpi_prot_cho_r -->
# DM_dsT_antigen_g_: dsT_antigen_g -->
# DM_dttp_m_: dttp_m -->
# DM_ethamp_r_: ethamp_r -->
# DM_gncore2_g_: gncore2_g -->
# DM_kdn_c_: kdn_c -->
# DM_n5m2masn_g_: n5m2masn_g -->
# DM_sTn_antigen_g_: sTn_antigen_g -->
# DM_sprm_c_: sprm_c -->
# DM_yvite_c_: yvite_c -->
# DM_56iqcrbxlt_c_: 56iqcrbxlt_c -->
# DM_atp_c_: atp_c + h2o_c --> adp_c + h_c + pi_c
# SK_pre_prot_r_: pre_prot_r <=>
# DM_trp_L_c_: trp_L_c -->
# ASAH1_cho: crm_cho_l + h2o_l --> R1_cho_l + sphings_l
# R_group_phosphotase_2: R1_cho_c + atp_c + coa_c --> R1coa_cho_c + amp_c + ppi_c
# RTOTAL2FATPc: R1_cho_e + atp_c + coa_c --> R1coa_cho_c + amp_c + ppi_c
# ARTPLM2: R1coa_cho_c <=> pmtcoa_c
# ARTPLM2m: R1coa_cho_m <=> pmtcoa_m
# ARTCOAL2_cho: R1coa_cho_c + h2o_c --> R1_cho_c + coa_c + h_c
# RTOTAL2CRNt: R1crn_c --> R1crn_m
# RTOTAL2CRNCPT1: R1coa_cho_c + crn_c <=> R1crn_c + coa_c
# RTOTAL2CRNCPT2: R1crn_m + coa_m --> R1coa_cho_m + crn_m
# EX_Rtotal2_e_: R1_cho_e -->
# RTOTAL2t: R1_cho_e <=> R1_cho_c
# AGPAT1_cho: Rtotalcoa_c + alpa_cho_c --> coa_c + pa_cho_c
# LPS3_cho: h2o_c + mag_cho_c --> Rtotal_c + glyc_c + h_c
# PLA2_2_cho: h2o_c + pchol_cho_c --> Rtotal_c + h_c + lpchol_cho_c
# PLA2_2e_cho: h2o_e + pchol_cho_e --> Rtotal_e + h_e + lpchol_cho_e
# RETH1: 9_cis_retfa_c + h2o_c --> Rtotal_c + h_c + retinol_9_cis_c
# RETH1e: 9_cis_retfa_e + h2o_e --> Rtotal_e + h_e + retinol_9_cis_e
# RETH2: 11_cis_retfa_c + h2o_c --> Rtotal_c + h_c + retinol_cis_11_c
# RETH2e: 11_cis_retfa_e + h2o_e --> Rtotal_e + h_e + retinol_cis_11_e
# RETHe: h2o_e + retfa_e --> Rtotal_e + h_e + retinol_e
# SOAT11_cho: Rtotalcoa_c + chsterol_c --> coa_c + xolest_cho_c
# SPHMDAc_cho: h2o_c + sphmyln_cho_c --> Rtotal_SM_c + spc_cho_c
# DSAT_cho: Rtotalcoa_SM_c + sphgn_c --> coa_c + dhcrm_cho_c + h_c
# C20_2coa_hydrol: CE4843_c + h2o_c --> coa_c + eicosadienoate_c + h_c
# C22_2coa_hydrol: CE5154_c + h2o_c --> coa_c + docosadienoate_c + h_c
# C24_2coa_hydrol: CE5158_c + h2o_c --> coa_c + h_c + tetracosadienoate_c
# C20_3coa_hydrol: dlnlcgcoa_c + h2o_c --> coa_c + dlnlcg_c + h_c
# C16_2_transport: c162_7Z_10Zcoa_m <=> c162_7Z_10Zcoa_c
# C16_2coa_hydrol: c162_7Z_10Zcoa_c + h2o_c --> c162_7Z_10Z_c + coa_c + h_c
# C14_1coa_transport: tetdece1coa_m <=> tetdece1coa_c
# C14_1coa_hydrol: h2o_c + tetdece1coa_c --> coa_c + h_c + ttdcea_c
# RE3238C: CE5151_c + h2o_c --> CE2510_c + coa_c + h_c
# RE3239C: CE5155_c + h2o_c --> coa_c + doco13ac_c + h_c
# RE3161C: h_c + lnlccoa_c + malcoa_c --> CE4841_c + co2_c + coa_c
# RE3162C: CE4841_c + h_c + nadph_c <=> CE4840_c + nadp_c
# RE3163C: CE4840_c <=> CE4842_c + h2o_c
# RE3164C: CE4842_c + h_c + nadph_c <=> CE4843_c + nadp_c
# RE0569C: arachcoa_c + h_c + malcoa_c --> CE2250_c + co2_c + coa_c
# RE0570C: CE2250_c + h_c + nadph_c <=> CE2246_c + nadp_c
# RE0571C: CE2246_c <=> CE2242_c + h2o_c
# RE0572C: CE2242_c + h_c + nadph_c <=> docoscoa_c + nadp_c
# RE0573C: docoscoa_c + h_c + malcoa_c --> CE2253_c + co2_c + coa_c
# RE0574C: CE2253_c + h_c + nadph_c <=> CE2249_c + nadp_c
# RE0575C: CE2249_c <=> CE2245_c + h2o_c
# RE0576C: CE2245_c + h_c + nadph_c <=> lgnccoa_c + nadp_c
# C26_0_cond: h_c + lgnccoa_c + malcoa_c --> 3ketoacyl24coa_c + co2_c + coa_c
# C26_0_red: 3ketoacyl24coa_c + h_c + nadph_c <=> 3hydroxyacyl24coa_c + nadp_c
# C26_0_deh: 3hydroxyacyl24coa_c <=> h2o_c + trans2enoyl24coa_c
# C26_0_red2: h_c + nadph_c + trans2enoyl24coa_c <=> hexccoa_c + nadp_c
# C26_1_cond: h_c + malcoa_c + nrvnccoa_c --> 3ketoacyl24_1coa_c + co2_c + coa_c
# C26_1_red: 3ketoacyl24_1coa_c + h_c + nadph_c <=> 3hydroxyacyl24_1coa_c + nadp_c
# C26_1_deh: 3hydroxyacyl24_1coa_c <=> h2o_c + trans2enoyl24_1coa_c
# C26_1_red2: h_c + nadph_c + trans2enoyl24_1coa_c <=> hexacosenoylcoa_c + nadp_c
# C26_1_hydrol: h2o_c + hexacosenoylcoa_c --> coa_c + h_c + hexacosenoate_c
# PLA2_3_cho: h2o_c + pe_cho_c --> Rtotal_LPE2_c + h_c + lpe_cho_c
# LPASE2_cho: h2o_c + lpe_cho_c --> Rtotal_LPE1_c + g3pe_c + h_c
# GPDDA2_cho: g3pe_c + h2o_c --> etha_c + glyc3p_c + h_c
# DHAPA_cho: Rtotalcoa_PCO_c + dhap_c --> adhap_cho_c + coa_c
# DHAPAx_cho: Rtotalcoa_PCO_x + dhap_x --> adhap_cho_x + coa_x
# Rtotalcoa_PCOtm: Rtotalcoa_PCO_c <=> Rtotalcoa_PCO_x
# AGPSx_cho: adhap_cho_x + alkylR1oh_x --> Rtotal_PCO_x + akdhap_cho_x + h_x
# total_PCOtm: Rtotal_PCO_x <=> Rtotal_PCO_c
# R10104: Rtotalcoa_PCO_x + 2.0 h_x + 2.0 nadph_x <=> alkylR1oh_x + coa_x + 2.0 nadp_x
# AGPex_cho: akdhap_cho_c <=> akdhap_cho_x
# AGLPR_cho: akdhap_cho_c + h_c + nadph_c --> akgp_cho_c + nadp_c
# AGLPT_cho: Rtotal_PCO_c + akgp_cho_c + h_c --> ak2gp_cho_c + h2o_c
# AGLPH_cho: ak2gp_cho_c + h2o_c --> ak2g_cho_c + pi_c
# AGLPC_cho: ak2g_cho_c + cdpchol_c --> ak2gchol_cho_c + cmp_c + h2o_c + h_c
# PLA2_cho: ak2gchol_cho_c + h2o_c --> Rtotal_PCO_c + ak2lgchol_cho_c + h_c
# ARTHDCA: hdca_c <=> R1_cho_c
# ARTPLM1: 0.0235 CE5151_c + 0.0018 CE5154_c + 0.0004 CE5155_c + 0.0018 CE5158_c + 0.0116 arachcoa_c + 0.0024 dlnlcgcoa_c + 0.0056 docoscoa_c + 0.0361 hdcoa_c + 0.0011 lgnccoa_c + 0.0004 lnlccoa_c + 0.0007 nrvnccoa_c + 0.7016 odecoa_c + 0.1447 pmtcoa_c + 0.0565 stcoa_c + 0.0118 tdcoa_c <=> Rtotalcoa_c
# Rtotal: 0.0235 CE2510_c + 0.0116 arach_c + 0.0024 dlnlcg_c + 0.0004 doco13ac_c + 0.0056 docosac_c + 0.0018 docosadienoate_c + 0.1447 hdca_c + 0.0361 hdcea_c + 0.0011 lgnc_c + 0.0004 lnlc_c + 0.0007 nrvnc_c + 0.0565 ocdca_c + 0.7016 ocdcea_c + 0.0018 tetracosadienoate_c + 0.0118 ttdca_c <=> Rtotal_c
# Rtotalcoa_SM: 0.0162 CE5158_c + 0.0833 arachcoa_c + 0.0087 dlnlcgcoa_c + 0.3017 docoscoa_c + 0.0188 hdcoa_c + 0.009 hexccoa_c + 0.1185 lgnccoa_c + 0.0757 nrvnccoa_c + 0.3496 pmtcoa_c + 0.0185 tdcoa_c <=> Rtotalcoa_SM_c
# Rtotal_SM: 0.0833 arach_c + 0.0087 dlnlcg_c + 0.3017 docosac_c + 0.3496 hdca_c + 0.0188 hdcea_c + 0.009 hexc_c + 0.1185 lgnc_c + 0.0757 nrvnc_c + 0.0162 tetracosadienoate_c + 0.0185 ttdca_c <=> Rtotal_SM_c
# Rtotal_LPE1: 0.2272 hdca_c + 0.7728 ocdcea_c <=> Rtotal_LPE1_c
# Rtotal_LPE2: 0.047 CE2510_c + 0.0232 arach_c + 0.0048 dlnlcg_c + 0.0008 doco13ac_c + 0.0112 docosac_c + 0.0036 docosadienoate_c + 0.0622 hdca_c + 0.0722 hdcea_c + 0.0022 lgnc_c + 0.0008 lnlc_c + 0.0014 nrvnc_c + 0.113 ocdca_c + 0.6304 ocdcea_c + 0.0036 tetracosadienoate_c + 0.0236 ttdca_c <=> Rtotal_LPE2_c
# Rtotalcoa_PCO: 0.0142 CE5151_c + 0.0011 CE5154_c + 0.0002 CE5155_c + 0.0011 CE5158_c + 0.007 arachcoa_c + 0.0015 dlnlcgcoa_c + 0.0034 docoscoa_c + 0.0219 hdcoa_c + 0.0007 lgnccoa_c + 0.0002 lnlccoa_c + 0.0004 nrvnccoa_c + 0.6825 odecoa_c + 0.2044 pmtcoa_c + 0.0543 stcoa_c + 0.0071 tdcoa_c <=> Rtotalcoa_PCO_c
# Rtotal_PCO: 0.0142 CE2510_c + 0.007 arach_c + 0.0015 dlnlcg_c + 0.0002 doco13ac_c + 0.0034 docosac_c + 0.0011 docosadienoate_c + 0.2044 hdca_c + 0.0219 hdcea_c + 0.0007 lgnc_c + 0.0002 lnlc_c + 0.0004 nrvnc_c + 0.0543 ocdca_c + 0.6825 ocdcea_c + 0.0011 tetracosadienoate_c + 0.0071 ttdca_c <=> Rtotal_PCO_c
# Rtotal3coa_tm: Rtotal3coa_c <=> Rtotal3coa_m
# Rtotalcoa_tm: Rtotalcoa_c <=> Rtotalcoa_m
# biomass_specific: 0.1104 DNA_c + 0.2212 RNA_c + 0.0687 glc_D_c + 0.192 lipid_c + 5.0549 protein_c -->
# lipid_specific: 0.0153 ak2gchol_cho_c + 0.1994 chsterol_c + 0.0083 clpn_cho_c + 0.0085 dag_cho_c + 0.0011 lpe_cho_c + 0.019 pa_cho_c + 0.0121 pail_cho_c + 0.3257 pchol_cho_c + 0.1097 pe_cho_c + 0.0206 pglyc_cho_e + 0.0487 ps_cho_c + 0.2316 sphmyln_cho_c --> lipid_c
# protein_specific: 0.0781 ala_L_c + 0.0636 arg_L_c + 0.0489 asn_L_c + 0.0489 asp_L_c + 1.306 atp_c + 0.0194 cys_L_c + 0.0609 gln_L_c + 0.0609 glu_L_c + 0.0866 gly_c + 2.0 gtp_c + 2.306 h2o_c + 0.0191 his_L_c + 0.0374 ile_L_c + 0.0849 leu_L_c + 0.0716 lys_L_c + 0.019 met_L_c + 0.0342 phe_L_c + 0.056 pro_L_c + 0.0684 ser_L_c + 0.0531 thr_L_c + 0.0083 trp_L_c + 0.029 tyr_L_c + 0.0517 val_L_c --> 0.306 adp_c + amp_c + 2.0 gdp_c + 3.306 h_c + 2.306 pi_c + ppi_c + protein_c
# DNA: 1.372 atp_c + 0.293500001099245 datp_c + 0.206499998900755 dctp_c + 0.206499998900755 dgtp_c + 0.293500001099245 dttp_c + 1.372 h2o_c --> DNA_c + 1.372 adp_c + 1.372 h_c + 1.372 pi_c + ppi_c
# RNA: 0.667900002186051 atp_c + 0.249499999910303 ctp_c + 0.263799999144032 gtp_c + 0.4 h2o_c + 0.218799998759614 utp_c --> RNA_c + 0.4 adp_c + 0.4 h_c + 0.4 pi_c + ppi_c

# %%
model.op
# Out:
# <Model K1par0mMCD at 0x168262c80>

# %%
##### ----- FVA ----- #####
import utils

model.solver = 'gurobi'


for rxn_exchange in model.exchanges:
    rxn_exchange.bounds = (-1000, 1000)
minmax = utils.runMinMax_Single(model, end_rxn_index=None)

##### Print Reactions with the min and max fluxes #####
with open('temp/FVA_Results.txt', 'w') as f:
    for i, j in enumerate(minmax):
        print(model.reactions[i].id, "Min: ",j[0], "Max: ", j[1], file=f)
        
##### Print Blocked Reactions #####
with open('temp/Blocked_Reactions.txt', 'w') as f:
    for i, j in enumerate(minmax):
        if j[0] == 0 and j[1] == 0:
            print(model.reactions[i].id, "Min: ",j[0], "Max: ", j[1], file=f)
# Out:
# 500 reactions analized
# 1000 reactions analized
# 1500 reactions analized
# 2000 reactions analized
# 2500 reactions analized
# 3000 reactions analized
# 3500 reactions analized
# 4000 reactions analized
# 4500 reactions analized
