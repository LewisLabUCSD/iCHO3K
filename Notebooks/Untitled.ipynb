# %%
import os
import pickle
import pandas as pd

import cobra
from cobra.io import load_json_model, read_sbml_model
from cobra.exceptions import Infeasible

# Plotting
import matplotlib.pyplot as plt
import seaborn as sns

# %%
iCHO_WT_P2 = load_json_model('../Data/Context_specific_models/iCHO_WT_P2.json')
iCHO_WT_P4 = load_json_model('../Data/Context_specific_models/iCHO_WT_P4.json')
iCHO_WT_P6 = load_json_model('../Data/Context_specific_models/iCHO_WT_P6.json')
iCHO_WT_P8 = load_json_model('../Data/Context_specific_models/iCHO_WT_P8.json')
iCHO_WT_P12 = load_json_model('../Data/Context_specific_models/iCHO_WT_P12.json')
iCHO_WT_P14 = load_json_model('../Data/Context_specific_models/iCHO_WT_P14.json')
iCHO_ZeLa_P2 = load_json_model('../Data/Context_specific_models/iCHO_ZeLa_P2.json')
iCHO_ZeLa_P4 = load_json_model('../Data/Context_specific_models/iCHO_ZeLa_P4.json')
iCHO_ZeLa_P6 = load_json_model('../Data/Context_specific_models/iCHO_ZeLa_P6.json')
iCHO_ZeLa_P8 = load_json_model('../Data/Context_specific_models/iCHO_ZeLa_P8.json')
iCHO_ZeLa_P12 = load_json_model('../Data/Context_specific_models/iCHO_ZeLa_P12.json')
iCHO_ZeLa_P14 = load_json_model('../Data/Context_specific_models/iCHO_ZeLa_P14.json')
iCHO3595 = load_json_model('iCHO3595.json')
iCHO1766 = read_sbml_model('../Data/Reconciliation/models/iCHOv1_final.xml')
iCHO2291 = read_sbml_model('../Data/Reconciliation/models/iCHO2291.xml')
iCHO2441 = read_sbml_model('../Data/Reconciliation/models/iCHO2441.xml')
# Out:
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-03-04

# %%
models = [iCHO3595, iCHO_WT_P2, iCHO_WT_P4, iCHO_WT_P6, iCHO_WT_P8, iCHO_WT_P12, iCHO_WT_P14,
          iCHO_ZeLa_P2, iCHO_ZeLa_P4, iCHO_ZeLa_P6, iCHO_ZeLa_P8, iCHO_ZeLa_P12, iCHO_ZeLa_P14,
          iCHO1766, iCHO2291, iCHO2441]

# %%
for model in models:
    with model:
        print(f'-------------------------------------------------------')
        print(f'-------------------- {model.id} -------------------------')
        print(f'-------------------------------------------------------')
        print(f'-------------------------------------------------------')
        for rxn in model.reactions:
            if rxn.subsystem == 'PROTEIN DEGRADATION':
                model.reactions.get_by_id(rxn.id).knock_out()
            if rxn.id.startswith('SK_'):
                rxn.bounds = (0,1000)
            if rxn.id.startswith('DM_'):
                rxn.bounds = (0,1000)
            if rxn.id.startswith('EX_') and not rxn.id.startswith('EX_glc_'):
                rxn.bounds = (0,1000)
            if rxn.id == 'EX_glc_e':
                rxn.bounds = (0.00001,1000)
            if rxn.id == 'EX_glc_e_':
                rxn.bounds = (0.00001,1000)
            if rxn.id == 'EX_glc(e)':
                rxn.bounds = (0.00001,1000)
        try:
            model.reactions.GLPASE1.knock_out()
        except:
            print(f'Reaction GLPASE1 not in model {model.id}')
        try:
            model.reactions.MG2er.knock_out()
        except:
            print(f'Reaction MG2er not in model {model.id}')
        try:
            model.reactions.get_by_id('GapFill-R01206').knock_out()
        except:
            print(f'Reaction GapFill-R01206 not in model {model.id}')
        try:
            model.reactions.get_by_id('GAUGE-R00557').knock_out()
        except:
            print(f'Reaction GAUGE-R00557 not in model {model.id}')
        try:
            model.reactions.get_by_id('GAUGE-R00558').knock_out()
        except:
            print(f'Reaction GAUGE-R00558 not in model {model.id}')
        try:
            model.reactions.FNOR.knock_out()
        except:
            print(f'Reaction FNOR not in model {model.id}')
        try:
            model.reactions.GGH.knock_out()
        except:
            print(f'Reaction GGH not in model {model.id}')
        try:
            model.reactions.r0741.knock_out()
        except:
            print(f'Reaction r0741 not in model {model.id}')
        try:
            model.reactions.r1479.knock_out()
        except:
            print(f'Reaction r1479 not in model {model.id}')
        try:
            model.reactions.XOLESTPOOL.knock_out()
        except:
            print(f'Reaction XOLESTPOOL not in model {model.id}')
        solution = model.optimize()
        print(solution)
        #for r,f in solution[abs(solution.fluxes) > 0].items():
        #    reaction = model.reactions.get_by_id(r)
            #if reaction not in iCHO1766.reactions:
        #    print(f'{reaction.id}: {reaction.reaction}//// Flux: {f}')
        print(f'')
        print(f'')

# Check one by one the reactions in the second block, then move to the third block
# Out:
# -------------------------------------------------------
# -------------------- iCHO3595 -------------------------
# -------------------------------------------------------
# -------------------------------------------------------
# <Solution 0.000 at 0x325152a20>
#
#
# -------------------------------------------------------
# -------------------- WT_P2 -------------------------
# -------------------------------------------------------
# -------------------------------------------------------
# Reaction GapFill-R01206 not in model WT_P2
# Reaction XOLESTPOOL not in model WT_P2
# <Solution 0.000 at 0x324eb2cc0>
#
#
# -------------------------------------------------------
# -------------------- WT_P4 -------------------------
# -------------------------------------------------------
# -------------------------------------------------------
# Reaction r0741 not in model WT_P4
# Reaction XOLESTPOOL not in model WT_P4
# <Solution infeasible at 0x324fc4b00>
#
#
# -------------------------------------------------------
# -------------------- WT_P6 -------------------------
# -------------------------------------------------------
# -------------------------------------------------------
# Reaction XOLESTPOOL not in model WT_P6
# <Solution 0.000 at 0x324de9a00>
#
#
# -------------------------------------------------------
# -------------------- WT_P8 -------------------------
# -------------------------------------------------------
# -------------------------------------------------------
# Reaction GLPASE1 not in model WT_P8
# Reaction GapFill-R01206 not in model WT_P8
# Reaction r0741 not in model WT_P8
# Reaction XOLESTPOOL not in model WT_P8
# <Solution infeasible at 0x324d51640>
#
#
# -------------------------------------------------------
# -------------------- WT_P12 -------------------------
# -------------------------------------------------------
# -------------------------------------------------------
# Reaction r0741 not in model WT_P12
# Reaction XOLESTPOOL not in model WT_P12
# <Solution infeasible at 0x338abc2f0>
#
#
# -------------------------------------------------------
# -------------------- WT_P14 -------------------------
# -------------------------------------------------------
# -------------------------------------------------------
# Reaction GapFill-R01206 not in model WT_P14
# Reaction XOLESTPOOL not in model WT_P14
# <Solution 0.000 at 0x324e19400>
#
#
# -------------------------------------------------------
# -------------------- ZeLa_P2 -------------------------
# -------------------------------------------------------
# -------------------------------------------------------
# Reaction XOLESTPOOL not in model ZeLa_P2
# <Solution 0.000 at 0x324aacb00>
#
#
# -------------------------------------------------------
# -------------------- ZeLa_P4 -------------------------
# -------------------------------------------------------
# -------------------------------------------------------
# Reaction XOLESTPOOL not in model ZeLa_P4
# <Solution 0.000 at 0x324d6ec90>
#
#
# -------------------------------------------------------
# -------------------- ZeLa_P6 -------------------------
# -------------------------------------------------------
# -------------------------------------------------------
# Reaction r0741 not in model ZeLa_P6
# Reaction XOLESTPOOL not in model ZeLa_P6
# <Solution infeasible at 0x324a85730>
#
#
# -------------------------------------------------------
# -------------------- ZeLa_P8 -------------------------
# -------------------------------------------------------
# -------------------------------------------------------
# Reaction GapFill-R01206 not in model ZeLa_P8
# Reaction r0741 not in model ZeLa_P8
# Reaction XOLESTPOOL not in model ZeLa_P8
# <Solution infeasible at 0x32e0cfa10>
#
#
# -------------------------------------------------------
# -------------------- ZeLa_P12 -------------------------
# -------------------------------------------------------
# -------------------------------------------------------
# Reaction GapFill-R01206 not in model ZeLa_P12
# Reaction GGH not in model ZeLa_P12
# Reaction r0741 not in model ZeLa_P12
# Reaction XOLESTPOOL not in model ZeLa_P12
# <Solution infeasible at 0x32496a090>
#
#
# -------------------------------------------------------
# -------------------- ZeLa_P14 -------------------------
# -------------------------------------------------------
# -------------------------------------------------------
# Reaction GapFill-R01206 not in model ZeLa_P14
# Reaction XOLESTPOOL not in model ZeLa_P14
# <Solution 0.000 at 0x324d6f800>
#
#
# -------------------------------------------------------
# -------------------- iCHOv1 -------------------------
# -------------------------------------------------------
# -------------------------------------------------------
# Reaction GapFill-R01206 not in model iCHOv1
# Reaction GAUGE-R00557 not in model iCHOv1
# Reaction GAUGE-R00558 not in model iCHOv1
# Reaction FNOR not in model iCHOv1
# Reaction GGH not in model iCHOv1
# Reaction r0741 not in model iCHOv1
# Reaction r1479 not in model iCHOv1
# Reaction XOLESTPOOL not in model iCHOv1
# <Solution infeasible at 0x32e06c7a0>
#
#
# -------------------------------------------------------
# -------------------- iCHO2291 -------------------------
# -------------------------------------------------------
# -------------------------------------------------------
# Reaction GapFill-R01206 not in model iCHO2291
# Reaction GAUGE-R00557 not in model iCHO2291
# Reaction GAUGE-R00558 not in model iCHO2291
# Reaction FNOR not in model iCHO2291
# Reaction r0741 not in model iCHO2291
# Reaction r1479 not in model iCHO2291
# Reaction XOLESTPOOL not in model iCHO2291
# <Solution infeasible at 0x324a86e40>
#
#
# -------------------------------------------------------
# -------------------- iCHO2291 -------------------------
# -------------------------------------------------------
# -------------------------------------------------------
# Reaction GapFill-R01206 not in model iCHO2291
# Reaction GAUGE-R00557 not in model iCHO2291
# Reaction GAUGE-R00558 not in model iCHO2291
# Reaction FNOR not in model iCHO2291
# Reaction r0741 not in model iCHO2291
# Reaction r1479 not in model iCHO2291
# Reaction XOLESTPOOL not in model iCHO2291
# <Solution infeasible at 0x324a858e0>
