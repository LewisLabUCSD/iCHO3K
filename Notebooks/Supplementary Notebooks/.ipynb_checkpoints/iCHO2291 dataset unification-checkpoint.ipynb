# %% [markdown]
# ## Unification of the iCHO2291 datasets
#
# A dataset created from the iCHO2291 xml file and the excell file provided as Supplementary data have been unified  in order to have information from both dataset (i.e. forward and reverse kcat from the excel file and GPR reaction formula from the excell)

# %%
import pandas as pd
import cobra
from cobra.io import read_sbml_model
from tqdm.notebook import tqdm
# Out:
# /Users/pablodigiusto/miniforge3/envs/mncho/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.4
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
# Load iCHO2291 excell file provided as supplementary data
df1 = pd.read_excel('../../Data/Supplementary Data.xlsx', 'Data S2')
df1
# Out:
#                Rxn  GPR Proteins EC Number  Mol wt  kcat_forward  \
# 0     10FTHF5GLUtl  NaN      NaN       NaN     NaN           NaN
# 1     10FTHF5GLUtm  NaN      NaN       NaN     NaN           NaN
# 2     10FTHF6GLUtl  NaN      NaN       NaN     NaN           NaN
# 3     10FTHF6GLUtm  NaN      NaN       NaN     NaN           NaN
# 4     10FTHF7GLUtl  NaN      NaN       NaN     NaN           NaN
# ...            ...  ...      ...       ...     ...           ...
# 6231   RTOTALFATPc  NaN      NaN       NaN     NaN           NaN
# 6232       RTOTALt  NaN      NaN       NaN     NaN           NaN
# 6233      Rtotaltl  NaN      NaN       NaN     NaN           NaN
# 6234      Rtotaltp  NaN      NaN       NaN     NaN           NaN
# 6235   Rtotalcoatx  NaN      NaN       NaN     NaN           NaN
#
#       kcat_backward           Subsystem (iCHO2291)      Subsystem (iCHO1766)
# 0               NaN                      Transport      TRANSPORT, LYSOSOMAL
# 1               NaN                      Transport  TRANSPORT, MITOCHONDRIAL
# 2               NaN                      Transport      TRANSPORT, LYSOSOMAL
# 3               NaN                      Transport  TRANSPORT, MITOCHONDRIAL
# 4               NaN                      Transport      TRANSPORT, LYSOSOMAL
# ...             ...                            ...                       ...
# 6231            NaN  Exchange/demand/sink reaction         R GROUP SYNTHESIS
# 6232            NaN                      Transport  TRANSPORT, EXTRACELLULAR
# 6233            NaN                      Transport      TRANSPORT, LYSOSOMAL
# 6234            NaN                      Transport    TRANSPORT, PEROXISOMAL
# 6235            NaN  Exchange/demand/sink reaction         R GROUP SYNTHESIS
#
# [6236 rows x 9 columns]

# %%
# Read the iCHO2291 model from https://www.ebi.ac.uk/biomodels/ using the cobrapy library
model = read_sbml_model('../Data/models/iCHO2291.xml')

# Create dataframe from the model with the attributes that we are interested in
attributes = []
for reaction in tqdm(model.reactions):
    attributes.append([reaction.id, reaction.name, reaction.reaction, reaction.gpr, 
                       reaction.subsystem, reaction.lower_bound, reaction.upper_bound])

df2 = pd.DataFrame(data=attributes, columns=['Reaction', 'Reaction Name', 'Reaction Formula', 'GPR', 'Subsystem', 'Lower bound', 'Upper bound'])
df2
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[7], line 2
#       1 # Read the iCHO2291 model from https://www.ebi.ac.uk/biomodels/ using the cobrapy library
# ----> 2 model = read_sbml_model('../Data/models/iCHO2291.xml')
#       4 # Create dataframe from the model with the attributes that we are interested in
#       5 attributes = []
#
# File ~/miniforge3/envs/mncho/lib/python3.10/site-packages/cobra/io/sbml.py:460, in read_sbml_model(filename, number, f_replace, **kwargs)
#     458     return _sbml_to_model(doc, number=number, f_replace=f_replace, **kwargs)
#     459 except IOError as e:
# --> 460     raise e
#     462 except Exception as original_error:
#     463     cobra_error = CobraSBMLError(
#     464         "Something went wrong reading the SBML model. Most likely the SBML"
#     465         " model is not valid. Please check that your model is valid using "
#    (...)
#     470         "at https://github.com/opencobra/cobrapy/issues ."
#     471     )
#
# File ~/miniforge3/envs/mncho/lib/python3.10/site-packages/cobra/io/sbml.py:457, in read_sbml_model(filename, number, f_replace, **kwargs)
#     402 """Read SBML model from given filename.
#     403
#     404 If the given filename ends with the suffix ''.gz'' (for example,
#    (...)
#     454 File handles to compressed files are not supported yet.
#     455 """
#     456 try:
# --> 457     doc = _get_doc_from_filename(filename)
#     458     return _sbml_to_model(doc, number=number, f_replace=f_replace, **kwargs)
#     459 except IOError as e:
#
# File ~/miniforge3/envs/mncho/lib/python3.10/site-packages/cobra/io/sbml.py:504, in _get_doc_from_filename(filename)
#     501         doc: libsbml.SBMLDocument = libsbml.readSBMLFromFile(filename)
#     502     else:
#     503         # string representation
# --> 504         raise IOError(
#     505             f"The file with '{filename}' does not exist, "
#     506             f"or is not an SBML string. Provide the path to "
#     507             f"an existing SBML file or a valid SBML string representation:\n"
#     508         )
#     509 elif hasattr(filename, "read"):
#     510     # file handle
#     511     doc: libsbml.SBMLDocument = libsbml.readSBMLFromString(filename.read())
#
# OSError: The file with '../Data/models/iCHO2291.xml' does not exist, or is not an SBML string. Provide the path to an existing SBML file or a valid SBML string representation:

# %% [markdown]
# ### Both dfs has the same amount of reactions but differen info in the columns

# %%
# Unify number of columns
df1.rename(columns = {'Rxn':'Reaction', 'Subsystem (iCHO2291)':'Subsystem'}, inplace = True)
df1 = df1.reindex(columns = df1.columns.tolist() + ['Reaction Name','Reaction Formula','Lower bound','Upper bound'])
df1.drop(columns=['Subsystem (iCHO1766)'])
df2 = df2.reindex(columns = df2.columns.tolist() + ['Proteins','EC Number','Mol wt','kcat_forward','kcat_backward'])


# Unify order of columns
df1 = df1[['Reaction', 'Reaction Name', 'Reaction Formula', 'GPR', 'Subsystem', 'Lower bound', 'Upper bound', 'Proteins','EC Number','Mol wt','kcat_forward','kcat_backward']]
df2 = df2[['Reaction', 'Reaction Name', 'Reaction Formula', 'GPR', 'Subsystem', 'Lower bound', 'Upper bound', 'Proteins','EC Number','Mol wt','kcat_forward','kcat_backward']]

# %%
# Merge both datasets 
iCHO2291 = pd.concat([df2, df1])
iCHO2291 = iCHO2291.reset_index(drop = True)
iCHO2291 = iCHO2291.groupby('Reaction').first()
iCHO2291.rename(columns = {'GPR':'GPR_yeo'}, inplace = True)

iCHO2291.to_excel('../Data/iCHO2291_final.xlsx')

# %%
iCHO2291
# Out:
#                                                Reaction Name  \
# Reaction
# 10FTHF5GLUtl          5-glutamyl-10FTHF transport, lysosomal
# 10FTHF5GLUtm      5-glutamyl-10FTHF transport, mitochondrial
# 10FTHF6GLUtl          6-glutamyl-10FTHF transport, lysosomal
# 10FTHF6GLUtm      6-glutamyl-10FTHF transport, mitochondrial
# 10FTHF7GLUtl          7-glutamyl-10FTHF transport, lysosomal
# ...                                                      ...
# igg_hc                                                igg_hc
# igg_lc                                                igg_lc
# peplys_synthesis                            peplys synthesis
# q10h2tc                  transport of ubiquinol into cytosol
# q10tm              transport of ubiquinone into mitochondria
#
#                                                    Reaction Formula GPR_yeo  \
# Reaction
# 10FTHF5GLUtl                        10fthf5glu[c] --> 10fthf5glu[l]
# 10FTHF5GLUtm                        10fthf5glu[m] --> 10fthf5glu[c]
# 10FTHF6GLUtl                        10fthf6glu[c] --> 10fthf6glu[l]
# 10FTHF6GLUtm                        10fthf6glu[m] --> 10fthf6glu[c]
# 10FTHF7GLUtl                        10fthf7glu[c] --> 10fthf7glu[l]
# ...                                                             ...     ...
# igg_hc            24.0 ala_L[c] + 8.0 arg_L[c] + 19.0 asn_L[c] +...
# igg_lc            15.0 ala_L[c] + 6.0 arg_L[c] + 7.0 asn_L[c] + ...
# peplys_synthesis                             lys_L[n] --> peplys[n]
# q10h2tc                                       q10h2[m] <=> q10h2[c]
# q10tm                                             q10[c] <=> q10[m]
#
#                       Subsystem  Lower bound  Upper bound Proteins EC Number  \
# Reaction
# 10FTHF5GLUtl          Transport          0.0       1000.0     None      None
# 10FTHF5GLUtm          Transport          0.0       1000.0     None      None
# 10FTHF6GLUtl          Transport          0.0       1000.0     None      None
# 10FTHF6GLUtm          Transport          0.0       1000.0     None      None
# 10FTHF7GLUtl          Transport          0.0       1000.0     None      None
# ...                         ...          ...          ...      ...       ...
# igg_hc            Miscellaneous          0.0       1000.0     None      None
# igg_lc            Miscellaneous          0.0       1000.0     None      None
# peplys_synthesis  Miscellaneous          0.0       1000.0     None      None
# q10h2tc               Transport      -1000.0       1000.0     None      None
# q10tm                 Transport      -1000.0       1000.0     None      None
#
#                   Mol wt  kcat_forward  kcat_backward
# Reaction
# 10FTHF5GLUtl         NaN           NaN            NaN
# 10FTHF5GLUtm         NaN           NaN            NaN
# 10FTHF6GLUtl         NaN           NaN            NaN
# 10FTHF6GLUtm         NaN           NaN            NaN
# 10FTHF7GLUtl         NaN           NaN            NaN
# ...                  ...           ...            ...
# igg_hc               NaN           NaN            NaN
# igg_lc               NaN           NaN            NaN
# peplys_synthesis     NaN           NaN            NaN
# q10h2tc              NaN           NaN            NaN
# q10tm                NaN           NaN            NaN
#
# [6236 rows x 11 columns]
