# %% [markdown]
# # Recon 3D CHO GPRs
# ## Description
# This notebook describes the process by which we can mine information from Recon3D to add it to our reconstruction in CHO cells. First we map all the CHO GPRs corresponding to the Recon3D Human GPRs and a dataset containing all the reactions from Recon3D with their corresponding CHO GPRs is generated (1), then a dataset containing reactions from Recon3D that are not present in our reconstruction, along with annotated CHO GPRs, is generated in order to add it to our reconstruction (2).

# %%
import pandas as pd
import numpy as np
from tqdm.notebook import tqdm

import cobra
from cobra.io.mat import load_matlab_model

import gspread
# Out:
# /Users/pablodigiusto/miniforge3/envs/mncho/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.4
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %% [markdown]
# ### 1. Finding CHO orthologs for Human GPRs in Recon3D
# Using the dataset generated in the **Orthologs** notebook, we can map all the CHO genes in the recon 3D dataset GPR column and generate a new column called "CHO GPR"

# %%
#Generate recon3d df from the recon3d supplementary data
df1 = pd.read_excel('../../Data/GPR_Curation/recon3d_gprs.xlsx')
df1
# Out:
#           m_reaction                               m_gene_reaction_rule  \
# 0        11DOCRTSLte                                             5243.1
# 1      11DOCRTSTRNte                                             5243.1
# 2        12DHCHOLabc  8714.3 or 8647.1 or 8714.2 or 8714.1 or 1244.1...
# 3        12DHCHOLabc  8714.3 or 8647.1 or 8714.2 or 8714.1 or 1244.1...
# 4        12DHCHOLabc  8714.3 or 8647.1 or 8714.2 or 8714.1 or 1244.1...
# ...              ...                                                ...
# 22107          r2525                                             8501.1
# 22108          r2526                                             8501.1
# 22109          r2532                                             8501.1
# 22110          r2534                                             8501.1
# 22111          r2535                                             8501.1
#
#                                            m_metabolites  \
# 0      h2o[c];atp[c];h[c];11docrtsl[c];11docrtsl[e];p...
# 1      atp[c];pi[c];11docrtstrn[c];h[c];11docrtstrn[e...
# 2      atp[c];12dhchol[e];12dhchol[c];pi[c];h[c];h2o[...
# 3      atp[c];12dhchol[e];12dhchol[c];pi[c];h[c];h2o[...
# 4      atp[c];12dhchol[e];12dhchol[c];pi[c];h[c];h2o[...
# ...                                                  ...
# 22107                                  gln_L[c];gln_L[e]
# 22108                                  ser_L[e];ser_L[c]
# 22109                                  asn_L[c];asn_L[e]
# 22110                                  thr_L[c];thr_L[e]
# 22111                                  hom_L[e];hom_L[c]
#
#                     m_subsystem   m_gene seq_uniprot  seq_len        seq_file  \
# 0      Transport, extracellular   5243.1    P08183-1   1280.0  P08183-1.fasta
# 1      Transport, extracellular   5243.1    P08183-1   1280.0  P08183-1.fasta
# 2      Transport, extracellular   1244.1    Q92887-1   1545.0  Q92887-1.fasta
# 3      Transport, extracellular   8647.1    O95342-1   1321.0  O95342-1.fasta
# 4      Transport, extracellular  10257.1    O15439-1   1325.0  O15439-1.fasta
# ...                         ...      ...         ...      ...             ...
# 22107  Transport, extracellular   8501.1    O75387-1    559.0  O75387-1.fasta
# 22108  Transport, extracellular   8501.1    O75387-1    559.0  O75387-1.fasta
# 22109  Transport, extracellular   8501.1    O75387-1    559.0  O75387-1.fasta
# 22110  Transport, extracellular   8501.1    O75387-1    559.0  O75387-1.fasta
# 22111  Transport, extracellular   8501.1    O75387-1    559.0  O75387-1.fasta
#
#        seq_num_structures  seq_num_experimental_structures struct_id  \
# 0                    21.0                             21.0    3g61-A
# 1                    21.0                             21.0    3g61-A
# 2                     0.0                              0.0       NaN
# 3                     0.0                              0.0       NaN
# 4                     0.0                              0.0       NaN
# ...                   ...                              ...       ...
# 22107                 2.0                              0.0  H16666-X
# 22108                 2.0                              0.0  H16666-X
# 22109                 2.0                              0.0  H16666-X
# 22110                 2.0                              0.0  H16666-X
# 22111                 2.0                              0.0  H16666-X
#
#       struct_chain_id  struct_chain_seq_coverage  struct_is_experimental  \
# 0                   A                       80.5                     1.0
# 1                   A                       80.5                     1.0
# 2                 NaN                        NaN                     NaN
# 3                 NaN                        NaN                     NaN
# 4                 NaN                        NaN                     NaN
# ...               ...                        ...                     ...
# 22107               X                      100.0                     0.0
# 22108               X                      100.0                     0.0
# 22109               X                      100.0                     0.0
# 22110               X                      100.0                     0.0
# 22111               X                      100.0                     0.0
#
#       struct_pdb  struct_resolution struct_chemicals  \
# 0           3g61               4.35              2J8
# 1           3g61               4.35              2J8
# 2            NaN                NaN              NaN
# 3            NaN                NaN              NaN
# 4            NaN                NaN              NaN
# ...          ...                ...              ...
# 22107        NaN                NaN              NaN
# 22108        NaN                NaN              NaN
# 22109        NaN                NaN              NaN
# 22110        NaN                NaN              NaN
# 22111        NaN                NaN              NaN
#
#                                 struct_file
# 0                          3g61-A_clean.pdb
# 1                          3g61-A_clean.pdb
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
# ...                                     ...
# 22107  NP_003618.1_model1_clean-X_clean.pdb
# 22108  NP_003618.1_model1_clean-X_clean.pdb
# 22109  NP_003618.1_model1_clean-X_clean.pdb
# 22110  NP_003618.1_model1_clean-X_clean.pdb
# 22111  NP_003618.1_model1_clean-X_clean.pdb
#
# [22112 rows x 18 columns]

# %%
#Generate another df from the recon3d model
recon3d_model = load_matlab_model('../../Data/GPR_Curation/Recon3D_301.mat')
recon3d_model
# Out:
# No defined compartments in model Recon3D. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, i, l, m, n, r, x
# <Model Recon3D at 0x16b607c70>

# %%
#Generate another df from the recon3d model
attributes = []
for reaction in tqdm(recon3d_model.reactions):
    attributes.append([reaction.id, reaction.name, reaction.reaction, reaction.gpr, 
                       reaction.subsystem, reaction.lower_bound, reaction.upper_bound])

df2 = pd.DataFrame(data=attributes, columns=['m_reaction', 'Reaction Name', 'm_metabolites', 'm_gene_reaction_rule', 'm_subsystem', 'Lower bound', 'Upper bound'])
df2['m_reaction'] = df2['m_reaction'].str.replace("[", "_")
df2['m_reaction'] = df2['m_reaction'].str.replace("]", "")
df2
# Out:
#   0%|          | 0/13543 [00:00<?, ?it/s]
# /var/folders/_x/tfg8s2ks4n1ftkkwzp5sqjpc0000gn/T/ipykernel_10368/3167771947.py:8: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df2['m_reaction'] = df2['m_reaction'].str.replace("[", "_")
# /var/folders/_x/tfg8s2ks4n1ftkkwzp5sqjpc0000gn/T/ipykernel_10368/3167771947.py:9: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df2['m_reaction'] = df2['m_reaction'].str.replace("]", "")
#          m_reaction                               Reaction Name  \
# 0      10FTHF5GLUtl      5-Glutamyl-10Fthf Transport, Lysosomal
# 1      10FTHF5GLUtm  5-Glutamyl-10Fthf Transport, Mitochondrial
# 2      10FTHF6GLUtl      6-Glutamyl-10Fthf Transport, Lysosomal
# 3      10FTHF6GLUtm  6-Glutamyl-10Fthf Transport, Mitochondrial
# 4      10FTHF7GLUtl      7-Glutamyl-10Fthf Transport, Lysosomal
# ...             ...                                         ...
# 13538    CYOR_u10mi                                  CYOR_u10mi
# 13539          Htmi                                        Htmi
# 13540   NADH2_u10mi                                 NADH2_u10mi
# 13541       CYOOm3i                                     CYOOm3i
# 13542       CYOOm2i                                     CYOOm2i
#
#                                            m_metabolites  \
# 0                        10fthf5glu[c] --> 10fthf5glu[l]
# 1                        10fthf5glu[m] --> 10fthf5glu[c]
# 2                        10fthf6glu[c] --> 10fthf6glu[l]
# 3                        10fthf6glu[m] --> 10fthf6glu[c]
# 4                        10fthf7glu[c] --> 10fthf7glu[l]
# ...                                                  ...
# 13538  2.0 ficytC[m] + 2.0 h[m] + q10h2[m] --> 2.0 fo...
# 13539                                      h[i] --> h[m]
# 13540  5.0 h[m] + nadh[m] + q10[m] --> 4.0 h[i] + nad...
# 13541  4.0 focytC[m] + 7.92 h[m] + o2[m] --> 4.0 ficy...
# 13542  4.0 focytC[m] + 8.0 h[m] + o2[m] --> 4.0 ficyt...
#
#                                     m_gene_reaction_rule  \
# 0
# 1
# 2
# 3
# 4
# ...                                                  ...
# 13538  (7384.1 and 7388.1 and 4519.1 and 29796.2 and ...
# 13539  9016.1 or 7352.2 or 7352.1 or 7351.1 or 9016.2...
# 13540  (4715.1 and 4720.1 and 4719.1 and 4700.1 and 5...
# 13541  1351.1 and 1347.1 and 1329.1 and 1327.1 and 34...
# 13542  (7384.1 and 7388.1 and 4519.1 and 10975.1 and ...
#
#                      m_subsystem  Lower bound  Upper bound
# 0           Transport, lysosomal          0.0       1000.0
# 1       Transport, mitochondrial          0.0       1000.0
# 2           Transport, lysosomal          0.0       1000.0
# 3       Transport, mitochondrial          0.0       1000.0
# 4           Transport, lysosomal          0.0       1000.0
# ...                          ...          ...          ...
# 13538  Oxidative phosphorylation          0.0       1000.0
# 13539   Transport, mitochondrial          0.0       1000.0
# 13540  Oxidative phosphorylation          0.0       1000.0
# 13541  Oxidative phosphorylation          0.0       1000.0
# 13542  Oxidative phosphorylation          0.0       1000.0
#
# [13543 rows x 7 columns]

# %%
# Unify df1 and df2 into one dataset containing all the necesary information
recon3d = pd.concat([df2, df1])
recon3d = recon3d.groupby('m_reaction').first()
recon3d = recon3d.reset_index(drop = False)
recon3d['m_gene_reaction_rule'] = recon3d['m_gene_reaction_rule'].replace(np.nan,'',regex=True)
recon3d
# Out:
#          m_reaction                               Reaction Name  \
# 0      10FTHF5GLUtl      5-Glutamyl-10Fthf Transport, Lysosomal
# 1      10FTHF5GLUtm  5-Glutamyl-10Fthf Transport, Mitochondrial
# 2      10FTHF6GLUtl      6-Glutamyl-10Fthf Transport, Lysosomal
# 3      10FTHF6GLUtm  6-Glutamyl-10Fthf Transport, Mitochondrial
# 4      10FTHF7GLUtl      7-Glutamyl-10Fthf Transport, Lysosomal
# ...             ...                                         ...
# 13538      steroids                         Steroids (from HMR)
# 13539      vitaminA                         Vitamina (from HMR)
# 13540      vitaminD                         Vitamind (from HMR)
# 13541      vitaminE                         Vitamine (from HMR)
# 13542   xenobiotics                      Xenobiotics (from HMR)
#
#                                            m_metabolites m_gene_reaction_rule  \
# 0                        10fthf5glu[c] --> 10fthf5glu[l]
# 1                        10fthf5glu[m] --> 10fthf5glu[c]
# 2                        10fthf6glu[c] --> 10fthf6glu[l]
# 3                        10fthf6glu[m] --> 10fthf6glu[c]
# 4                        10fthf7glu[c] --> 10fthf7glu[l]
# ...                                                  ...                  ...
# 13538  46dhoxquin[c] + 48dhoxquin[c] + C05299[c] + C0...
# 13539  CE1761[c] + CE1761[r] + CE2954[c] + CE2954[r] ...
# 13540  CE2204[c] + CE2204[m] + CE2207[c] + CE2207[m] ...
# 13541                CE1925[c] + CE5854[c] --> M03143[c]
# 13542  M00030[c] + M00031[c] + M00033[c] + M00244[c] ...
#
#                     m_subsystem  Lower bound  Upper bound  m_gene seq_uniprot  \
# 0          Transport, lysosomal          0.0       1000.0     NaN        None
# 1      Transport, mitochondrial          0.0       1000.0     NaN        None
# 2          Transport, lysosomal          0.0       1000.0     NaN        None
# 3      Transport, mitochondrial          0.0       1000.0     NaN        None
# 4          Transport, lysosomal          0.0       1000.0     NaN        None
# ...                         ...          ...          ...     ...         ...
# 13538  Exchange/demand reaction          0.0       1000.0     NaN        None
# 13539  Exchange/demand reaction          0.0       1000.0     NaN        None
# 13540  Exchange/demand reaction          0.0       1000.0     NaN        None
# 13541  Exchange/demand reaction          0.0       1000.0     NaN        None
# 13542  Exchange/demand reaction          0.0       1000.0     NaN        None
#
#        seq_len  ... seq_num_structures  seq_num_experimental_structures  \
# 0          NaN  ...                NaN                              NaN
# 1          NaN  ...                NaN                              NaN
# 2          NaN  ...                NaN                              NaN
# 3          NaN  ...                NaN                              NaN
# 4          NaN  ...                NaN                              NaN
# ...        ...  ...                ...                              ...
# 13538      NaN  ...                NaN                              NaN
# 13539      NaN  ...                NaN                              NaN
# 13540      NaN  ...                NaN                              NaN
# 13541      NaN  ...                NaN                              NaN
# 13542      NaN  ...                NaN                              NaN
#
#        struct_id struct_chain_id struct_chain_seq_coverage  \
# 0           None            None                       NaN
# 1           None            None                       NaN
# 2           None            None                       NaN
# 3           None            None                       NaN
# 4           None            None                       NaN
# ...          ...             ...                       ...
# 13538       None            None                       NaN
# 13539       None            None                       NaN
# 13540       None            None                       NaN
# 13541       None            None                       NaN
# 13542       None            None                       NaN
#
#        struct_is_experimental  struct_pdb struct_resolution  struct_chemicals  \
# 0                         NaN        None               NaN              None
# 1                         NaN        None               NaN              None
# 2                         NaN        None               NaN              None
# 3                         NaN        None               NaN              None
# 4                         NaN        None               NaN              None
# ...                       ...         ...               ...               ...
# 13538                     NaN        None               NaN              None
# 13539                     NaN        None               NaN              None
# 13540                     NaN        None               NaN              None
# 13541                     NaN        None               NaN              None
# 13542                     NaN        None               NaN              None
#
#       struct_file
# 0            None
# 1            None
# 2            None
# 3            None
# 4            None
# ...           ...
# 13538        None
# 13539        None
# 13540        None
# 13541        None
# 13542        None
#
# [13543 rows x 21 columns]

# %%
# Generate orthologs dict from the dataset generated in the Orthologs notebook
orthologs = pd.read_excel('../../Data/GPR_Curation/orthologs.xlsx', dtype=str)
orthologs.fillna('', inplace=True)
orthologs_dict = orthologs.set_index('Human GeneID')['CHO GeneID'].to_dict()
orthologs_dict
# Out:
# {'4535': '3979183',
#  '4536': '3979184',
#  '4512': '3979185',
#  '4513': '3979186',
#  '4509': '3979187',
#  '4508': '3979188',
#  '4514': '3979189',
#  '4537': '3979190',
#  '4539': '3979178',
#  '4538': '3979179',
#  '4540': '3979180',
#  '4541': '3979181',
#  '4519': '3979182',
#  '54859': '100764169',
#  '203523': '100764457',
#  '55813': '100761515',
#  '901': '100753075',
#  '9840': '100754149',
#  '6919': '100768573',
#  '5885': '100750544',
#  '1910': '100762726',
#  '26022': '100762391',
#  '84432': '100768325',
#  '90187': '100771706',
#  '1763': '100761842',
#  '4026': '100753874',
#  '79184': '100753541',
#  '64795': '100766802',
#  '100507003': '100772084',
#  '4841': '100757453',
#  '84311': '100755070',
#  '10864': '100757046',
#  '6857': '100753843',
#  '51268': '100765858',
#  '59272': '100772552',
#  '58516': '100760112',
#  '645104': '100769210',
#  '64857': '100761461',
#  '165904': '100756551',
#  '8722': '100756958',
#  '1896': '100768945',
#  '28959': '100764547',
#  '125115': '100758909',
#  '2188': '103161842',
#  '144809': '113832672',
#  '10873': '100764482',
#  '4037': '100769612',
#  '131118': '100751082',
#  '3748': '100773356',
#  '84062': '100760065',
#  '1411': '107977665',
#  '79365': '100759250',
#  '79165': '100754365',
#  '1361': '100754304',
#  '85865': '100768924',
#  '284467': '100751401',
#  '51023': '100769266',
#  '4838': '100762314',
#  '11005': '100755486',
#  '10911': '100768033',
#  '7702': '100752658',
#  '152503': '100761657',
#  '112724': '100759393',
#  '2826': '100760302',
#  '10656': '103162957',
#  '55282': '100761482',
#  '25984': '103158867',
#  '2780': '100772380',
#  '147906': '',
#  '112476': '100754337',
#  '256329': '100774508',
#  '5992': '100760011',
#  '51024': '100689455',
#  '26013': '100772152',
#  '158046': '113831229',
#  '7392': '100757386',
#  '80864': '100766819',
#  '131965': '100766645',
#  '10747': '100770654',
#  '2175': '100761220',
#  '55577': '100758117',
#  '5710': '103161668',
#  '5741': '113835091',
#  '7369': '100764823',
#  '9045': '100774219',
#  '2535': '100763109',
#  '2658': '100772200',
#  '10239': '100754298',
#  '27012': '103159512',
#  '388389': '100758187',
#  '680': '100763382',
#  '6222': '100752957',
#  '50619': '100757712',
#  '3034': '100753802',
#  '390075': '100772900 103159991',
#  '999': '100758185',
#  '6297': '100774023',
#  '5714': '100764857',
#  '135927': '118239473',
#  '80263': '100770048',
#  '55251': '100765664',
#  '4354': '100755110',
#  '51013': '100757484',
#  '56964': '100761600',
#  '414149': '100752791',
#  '27429': '100760629',
#  '54585': '100760415',
#  '131870': '100769259',
#  '55738': '100759225',
#  '10875': '100760509',
#  '9031': '100760864',
#  '201456': '100750915',
#  '80199': '100772773',
#  '389761': '100759146',
#  '389762': '',
#  '389763': '100772041',
#  '51650': '100774673',
#  '56987': '100769386',
#  '9656': '100756160',
#  '2064': '100759983',
#  '55075': '100753602',
#  '1414': '100772171',
#  '728858': '100755199',
#  '64506': '100759655',
#  '51649': '100761716',
#  '5092': '100767749',
#  '5806': '100754664',
#  '10426': '100760005',
#  '2621': '100751777',
#  '7450': '100750531',
#  '283385': '100752696',
#  '340665': '100755258',
#  '827': '100773921',
#  '4049': '100765068',
#  '11341': '100761463',
#  '64123': '100756599',
#  '83637': '100765539',
#  '6878': '100775090',
#  '5662': '100774898',
#  '1906': '100768493',
#  '141': '100761196',
#  '9873': '100773820',
#  '5104': '100759896',
#  '29993': '100759729',
#  '83447': '100773145',
#  '80213': '100771956',
#  '51567': '100764160',
#  '29097': '100760720',
#  '91584': '100753940',
#  '8859': '100768271',
#  '55957': '100754605',
#  '79665': '100756345',
#  '84705': '100751349',
#  '9958': '100759035',
#  '6059': '100773014',
#  '26051': '100761039',
#  '79931': '100757906',
#  '287': '100757830',
#  '374': '100772017',
#  '8718': '100755530',
#  '5959': '100772460',
#  '83444': '100764793',
#  '3661': '100765676',
#  '26173': '100764130',
#  '6911': '100770940',
#  '11178': '100773219',
#  '205717': '100768025',
#  '55845': '100758338',
#  '92312': '100763489',
#  '11240': '100771538',
#  '84103': '100759564',
#  '63827': '100753507',
#  '1592': '100755549',
#  '8439': '100755374',
#  '7809': '100750920',
#  '6147': '100761992',
#  '56882': '100767648',
#  '84083': '100771558',
#  '9296': '100752884',
#  '8091': '103158819',
#  '5869': '100768837',
#  '254048': '100768627',
#  '100506144': '100760774',
#  '85474': '100761783',
#  '2696': '113837293',
#  '153328': '100756441',
#  '128': '100767929',
#  '3191': '100768344',
#  '11255': '100764853',
#  '113612': '100761779',
#  '116154': '100765892',
#  '22981': '100764839',
#  '211': '100766370',
#  '23234': '100762162',
#  '55670': '100753828',
#  '441869': '100773738',
#  '7087': '100772237',
#  '51691': '100756548',
#  '10634': '100773328',
#  '285527': '100753564',
#  '1081': '100689452',
#  '5184': '100770474',
#  '375616': '100761131',
#  '51279': '100760066',
#  '151903': '100766224',
#  '57110': '100750510',
#  '11035': '100768712',
#  '6150': '100769317',
#  '440145': '100774557',
#  '1982': '100758677',
#  '389320': '100752692',
#  '3746': '100763523',
#  '3700': '100753872',
#  '201562': '100765668',
#  '57136': '100765704',
#  '84933': '103161461',
#  '6538': '100752493',
#  '60509': '100762486',
#  '84173': '100775058',
#  '84264': '100772931',
#  '8787': '100774862',
#  '9111': '100771173',
#  '3201': '100762131',
#  '647286': '103161148',
#  '8288': '100751071',
#  '114770': '100754520',
#  '83723': '100772583',
#  '6199': '100760227',
#  '2852': '100767871',
#  '9354': '100757349',
#  '3859': '100754962',
#  '91746': '100764889',
#  '283897': '100752250',
#  '83853': '100759891',
#  '63904': '100755361',
#  '125963': '100770574',
#  '51479': '100757230',
#  '1687': '100757679',
#  '84913': '100751745',
#  '23474': '100769786',
#  '8448': '100773354',
#  '4311': '100756999',
#  '10268': '100770633',
#  '93': '100755103',
#  '503542': '100754078',
#  '27111': '100763188',
#  '404217': '103159346',
#  '84279': '100770278',
#  '27043': '100775022',
#  '4829': '100773994',
#  '1466': '100764077',
#  '7571': '100759132',
#  '92558': '100759857',
#  '84992': '100752710',
#  '10472': '100751760',
#  '79784': '100770655',
#  '4849': '100765854',
#  '8590': '100754554',
#  '1303': '100752735',
#  '64768': '100755765',
#  '1717': '100771700',
#  '54819': '103159796',
#  '51637': '100769327',
#  '56104': '100757337',
#  '2707': '100765420',
#  '79017': '100774679',
#  '92591': '100753821',
#  '9169': '100754449',
#  '55781': '100758835',
#  '9282': '100768874',
#  '5814': '103160160',
#  '6900': '100753717',
#  '348938': '100761365',
#  '3238': '100752995',
#  '54905': '100768731',
#  '114876': '100754425',
#  '94137': '100753486',
#  '10537': '100769593',
#  '55084': '100774735',
#  '2272': '100755382',
#  '2128': '100763300',
#  '79133': '100770742',
#  '932': '100765384',
#  '83871': '100761520',
#  '6251': '100768150',
#  '118460': '113834673',
#  '26211': '100753820',
#  '135948': '100753820',
#  '275': '100763091',
#  '1183': '100762547',
#  '10086': '',
#  '6545': '100757506',
#  '23064': '100763725',
#  '55346': '100771847',
#  '5213': '100754270',
#  '390063': '100770385',
#  '196403': '100764385',
#  '7458': '100770352',
#  '284427': '100762518',
#  '10973': '100762460',
#  '1070': '100765724',
#  '10975': '100768142',
#  '9173': '100760768',
#  '399694': '100763505',
#  '27436': '100764725',
#  '80835': '100759079',
#  '8874': '100766623',
#  '8905': '100768456',
#  '5578': '100766006',
#  '54487': '118239887',
#  '79324': '100762969',
#  '55501': '100762689',
#  '23016': '100763217',
#  '3053': '100751445',
#  '23190': '100766565',
#  '5629': '100752367',
#  '144132': '100761219',
#  '79971': '100767200',
#  '5745': '100769401',
#  '79192': '100750610',
#  '10743': '100768243',
#  '64216': '100765415',
#  '106481607': '',
#  '692076': '',
#  '64579': '100762108',
#  '1180': '100751277',
#  '83874': '100758877',
#  '3705': '100768438',
#  '3765': '100764245',
#  '85477': '100771193',
#  '50507': '100754626',
#  '3760': '100768536',
#  '283446': '100772352',
#  '767569': '',
#  '143241': '100758376',
#  '441061': '118238400',
#  '4739': '100765156',
#  '401': '113834882',
#  '9812': '100774899',
#  '9301': '',
#  '64783': '100764622',
#  '3589': '100773527',
#  '340351': '100764584',
#  '10382': '100763390',
#  '56953': '100767091',
#  '6338': '100754564',
#  '219771': '100771569',
#  '3786': '103162983',
#  '767563': '',
#  '1787': '100773025',
#  '6870': '100751020',
#  '692223': '',
#  '10682': '100765639',
#  '106480669': '',
#  '441911': '100774280',
#  '107983993': '',
#  '100134938': '100765519',
#  '84258': '100755305',
#  '55270': '100761298',
#  ...}

# %%
# Extract GPR info from Recon3D and swap gene IDs from human to CHO
import re
cho_gpr = []

for row in recon3d['m_gene_reaction_rule']:
    row = str(row)
    if row != "":
        gpr = re.findall('[\d.]*\d+', row)
        new_gpr = row
        for g in gpr:
            human_g = g.split('.')[0]
            try:
                cho_g = orthologs_dict[human_g]
                if cho_g == '':
                    cho_g = f'h{human_g}'
            except:
                cho_g = f'h{human_g}'
            new_gpr = new_gpr.replace(g, cho_g)
    elif row == '':
        new_gpr = ''
        
    cho_gpr.append(new_gpr)

# %%
cho_gpr
# Out:
# ['',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '100682536',
#  '',
#  '',
#  '100682536',
#  '',
#  '',
#  '100767558 or 100762480 or 100767558 or 100767558 or 100689220 or 100766754',
#  '100774298 or 100774298 or 100751085 or 100753765',
#  '100756998 or 100689396',
#  '',
#  '',
#  '',
#  '',
#  '100766524 or 100766524',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '100762926 or 100763954 or 100762635 or 100762635',
#  '100763203 or 100761164 or 100763775',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '100766524 or 100766524',
#  '100766524 or 100766524',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '100755116',
#  '',
#  '100682536',
#  '100682536',
#  '',
#  '',
#  '',
#  '100736552 or 100765055 or 100763971',
#  '',
#  '',
#  '',
#  '',
#  'h54659 or h54600 or h7364',
#  '',
#  '',
#  'h54657 or h7363 or h7364',
#  '',
#  '',
#  '',
#  '',
#  '100766524 or 100766524',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '100767691',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '100751280',
#  '100751280',
#  '',
#  '',
#  '',
#  '',
#  '100760414',
#  '',
#  '100763450 and 100772030 and 100774474',
#  '',
#  '',
#  '100760414',
#  '100760414',
#  '100769224',
#  '100753375',
#  '100756680',
#  '',
#  '(100770347 and h3939) or h160287 or 100751672 or h3939 or 100751672 or 100751959 or 100770347 or h92483',
#  '',
#  'h54659 or h54657',
#  '',
#  '100689220 or 100682536',
#  '100766524 or 100766524 or h1558',
#  '100762826',
#  '',
#  '100689220 or 100682536',
#  '',
#  '100774298 or 100763633',
#  'h54659 or h54657',
#  '',
#  '100689220 or 100682536',
#  '100766524 or 100766524',
#  '',
#  '100689220 or 100682536',
#  '',
#  '100774298 or 100763633',
#  'h92483 or 100751672 or 100751959 or (100770347 and h3939) or h3939 or h160287 or 100770347 or 100751672',
#  '100772122 or 100768407 or 100775004',
#  '100771517 or 113839441 or 100771517 or 100771517 or 100771517',
#  '',
#  '',
#  '',
#  '',
#  'h54659 or h54600 or h7364',
#  '',
#  '',
#  '(100770347 and h3939) or h160287 or 100751672 or h3939 or 100751672 or 100751959 or 100770347 or h92483',
#  '',
#  '',
#  '',
#  '100756399',
#  '',
#  '100775004',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '100770936',
#  '100761641',
#  '',
#  '',
#  '100768407',
#  '(100764862 and 100689437 and 100750352 and 100758466) or (100764862 and 100689437 and 100750352 and 100758466)',
#  '100756680',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '100756399 or 100755815',
#  '100767061 or h127 or (h125 and h124) or 100759210 or (h126 and h124) or 100767929 or 100764101 or (h125 and h126)',
#  '',
#  '100689106',
#  '',
#  '100770626 or 100770626',
#  '100756399 or 100755815',
#  '100768667 and 100689315',
#  '100774015',
#  '100757371 or h222 or 100768227 or 100755596',
#  'h222 or 100755596 or 100757371',
#  '100755596 or 100757371 or 100768227',
#  '100755596 or h222',
#  '',
#  '',
#  '',
#  '100768220',
#  '',
#  '',
#  '100766524',
#  '',
#  '',
#  '100774298 or 100763633',
#  '',
#  '100766524 or 100766524 or h1558 or 100750508',
#  '',
#  '',
#  '',
#  '100765485 or 100765485',
#  '',
#  '',
#  '100765485 or 100765485',
#  '',
#  '',
#  '',
#  '',
#  '100766524',
#  '100766524',
#  '100767558 or 100762480 or 100767558 or 100767558 or 100689220 or 100766754',
#  '100774298 or 100774298 or 100751085 or 100753765',
#  '100756998 or 100689396',
#  '100767558 or 100762480 or 100767558 or 100767558 or 100689220 or 100766754',
#  '100774298 or 100774298 or 100751085 or 100753765',
#  '100756998 or 100689396',
#  '100766524',
#  '100767558 or 100762480 or 100767558 or 100767558 or 100689220',
#  '100774298 or 100774298 or 100751085 or 100753765',
#  '100756998 or 100689396',
#  '100766524',
#  '100767558 or 100762480 or 100767558 or 100767558 or 100689220',
#  '100774298 or 100774298 or 100751085 or 100753765',
#  '100756998 or 100689396',
#  '',
#  '',
#  '100774578',
#  '',
#  '',
#  '(100689199 and 100768055) or (100689199 and 100754698) or (100689199 and 100768055) or (100689199 and 100754698)',
#  '',
#  '',
#  '',
#  '100759566',
#  '100757273',
#  '',
#  '100761641',
#  '',
#  '',
#  '100771517 or 113839441 or 100771517 or 100771517 or 100771517',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'h54659 or h54600 or h7364',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '107979660 or 100769821 or 107979660',
#  '100762826',
#  '',
#  '',
#  '100761742',
#  '',
#  '',
#  '100759780 or 100759780',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '100767527 or 100757947 or 100758239',
#  '100689199 or 100754698 or 103161104 or h30',
#  '',
#  '',
#  '',
#  '100689220 or 100761503 or 100762480',
#  '',
#  '100766524 or (100761725 or 100773614)',
#  '',
#  '100689220 or 100761503 or 100762480',
#  '',
#  '100774298 or 100763633',
#  '100762826',
#  '',
#  '100766524 or 100766524 or h1558 or 100750508',
#  '',
#  '100761742',
#  '100760815 or 100759648',
#  '',
#  '',
#  '100689220 or 100761503 or 100762480',
#  '',
#  '100774298 or 100763633',
#  '',
#  '',
#  '100757371 or 100755596 or h222 or 100768227',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'h222 or 100768227 or 100755596 or 100757371',
#  'h222 or 100768227 or 100755596 or 100757371',
#  '',
#  '100760815 or 100759648',
#  '',
#  '',
#  '100756404 or 100763644 or 100751531 or 100768228',
#  '',
#  '',
#  '',
#  'h1548 or 100765891',
#  '',
#  '',
#  '100756399',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '(100689199 and 100768055) or (100689199 and 100754698) or (100689199 and 100768055) or (100689199 and 100754698)',
#  '',
#  '',
#  '',
#  '(100689199 and 100768055) or (100689199 and 100754698) or (100689199 and 100768055) or (100689199 and 100754698)',
#  '',
#  '100766212 or 100768097',
#  '100751520 or 100765882 or 100757642 or 100765882',
#  '',
#  '100762297',
#  '100762838',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '100760815 or 100759648',
#  '100760815 or 100759648',
#  '100759648 or 100762926 or 100763954 or 100762635 or 100762635 or 100760815',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '100766524 or 100766524 or h1558',
#  '100762826',
#  '',
#  '100689220 or 100682536',
#  '',
#  '100774298 or 100763633',
#  '100766524 or 100766524',
#  '',
#  '',
#  '100689220 or 100682536',
#  '',
#  '100774298 or 100763633',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '100764994 or 100764994',
#  '',
#  '',
#  'h54657 or h7363 or h7364',
#  'h222 or 100768227 or 100755596 or 100757371',
#  '100689351',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '100753375 or 100753375 or 100753375 or 100753375 or 100753375 or 100753375 or 100753375 or 100753375 or 100753375 or 100753375',
#  '',
#  '',
#  '',
#  '',
#  '100766524 or 100766524',
#  '',
#  '',
#  '100760123 and 100772257',
#  '',
#  '',
#  '',
#  '100766524',
#  '',
#  '100689220 or 100761503 or 100762480',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '100766524',
#  '',
#  '100689220 or 100761503 or 100762480',
#  '',
#  '',
#  '',
#  '100689208',
#  '',
#  'h6822 or 100753375',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'h10965 or 100755154 or 100761464 or 100758652',
#  '',
#  '100772970',
#  '100689407 or 100689407',
#  '',
#  '',
#  '100761742',
#  '',
#  '113830655',
#  '100764994 or 100765516 or 100764994 or 100772225',
#  '100755180',
#  '100760815 or 100759648',
#  '',
#  '',
#  '100754402',
#  '100755842 or 100774860',
#  '100761742',
#  '100760815 or 100759648',
#  '',
#  '100689330 or 100689330 or 100689330 or 100689330 or h2352 or 100689330 or 100689330',
#  '100689407 or 100689407',
#  '',
#  '',
#  '',
#  '',
#  'h1559 or 100766524 or h1558 or 100750508',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'h1559 or h1558 or 100750508 or h1557',
#  '',
#  '',
#  '100762826',
#  '',
#  '100766524 or 100766524 or h1558 or 100750508',
#  '',
#  '',
#  '',
#  '100689220 or 100761503 or 100762480',
#  '',
#  '',
#  '100774298 or 100763633',
#  '',
#  '100762826',
#  '',
#  '',
#  '100762826',
#  '',
#  '100766524 or 100766524 or h1558 or 100750508',
#  '',
#  '',
#  '100762826',
#  '',
#  '100766524 or 100766524 or h1558 or 100750508',
#  '',
#  '',
#  '',
#  '100762826',
#  '',
#  '100682536',
#  '',
#  '',
#  '100766524 or 100766524 or h1558 or 100750508',
#  '',
#  '',
#  '',
#  'h1559',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'h1557 or h1558 or h1559',
#  '',
#  '',
#  '100767558 or 100762480 or 100767558 or 100767558 or 100689220 or 100766754',
#  '100774298 or 100774298 or 100751085 or 100753765',
#  '100756998 or 100689396',
#  '100767558 or 100762480 or 100767558 or 100767558 or 100689220 or 100766754',
#  '100774298 or 100774298 or 100751085 or 100753765',
#  '100756998 or 100689396',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '100766524',
#  '',
#  '100689220 or 100761503 or 100762480',
#  '',
#  '100762480 or 100767558 or h85320',
#  '100756998',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '100770462',
#  '100770462',
#  '100771969',
#  '100771969',
#  '100750893',
#  '100762926',
#  '',
#  '',
#  '',
#  '107979660 or 107979660',
#  'h28',
#  'h28',
#  'h28',
#  'h28',
#  'h28',
#  'h28',
#  'h28',
#  'h28',
#  'h28',
#  '100765485 or 100765485',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '100758951',
#  '100766093',
#  '100766093',
#  '100760370 or 100752493 or 100752749 or 100752445',
#  '100770936 or 100758239 or 100765829',
#  'h39',
#  '(100757947 and 100758239) or 100770936',
#  'h39',
#  'h30',
#  'h30',
#  'h30',
#  'h30',
#  'h30',
#  'h30',
#  '100775004 or 100768407',
#  '100775004',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '100762904 or 100762904 or (100762904 and 100753124) or (100762904 and 100753124) or 100762904 or (100753124 and 100762904) or (100762904 and 100753124) or 100762904 or (100762904 and 100753124) or 100762904',
#  '100753124',
#  '100752902 or 100752902',
#  '100769754 or 100772576',
#  '100756415',
#  '',
#  '100756415',
#  '100773997 or 100766923',
#  '100773997 or 100766923',
#  '100758912 or 100766923',
#  '100758912 or 100766923',
#  '100766923 or 100758912',
#  '100766923',
#  '100775004 or 100772122 or 100768407',
#  '100775004',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'h5973',
#  'h64841',
#  '100758117',
#  '100762575',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '100752487',
#  '100752620',
#  '100770679 or 100770679',
#  '',
#  '',
#  '',
#  '100770013',
#  '',
#  '',
#  '',
#  '',
#  'h47 or h47',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'h54600 or h54578 or h54658',
#  '',
#  '',
#  '',
#  '100767558',
#  '100767558',
#  '',
#  '100767558',
#  '100767558',
#  '100753375',
#  '',
#  '',
#  '100767558',
#  '100682536',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '100767837',
#  '100767837',
#  '100764540 or 100768228 or 100751531',
#  '100757887',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '100766828 or 100763159',
#  'h80724 or 100766828 or 100774097 or 100763159 or 100763073 or 270100763159 or 100770943',
#  '100759847',
#  '100763159 or 270100763159',
#  '100752768',
#  '100689199 or 100689199',
#  '100689207',
#  '100765707',
#  '100756122 or 100766024',
#  'h50 or 100766024',
#  '',
#  '100766043',
#  '100766043',
#  'h52 or h52 or h52 or 100763644 or 100751531 or 100768228',
#  '100755796',
#  '100765000',
#  '',
#  '100750893 or 100752902 or 100752902',
#  '100752902 or 100750893 or 100752902',
#  'h438',
#  'h438',
#  '100769754',
#  '',
#  '',
#  '100765891',
#  '100765891',
#  '',
#  '',
#  '',
#  '100762277 or 100758982 or h97 or h97',
#  '',
#  '',
#  '',
#  '100756254',
#  '100756254',
#  '',
#  '100761966',
#  '100767453',
#  '',
#  '100760489 or 100759346 or 100761703 or 100761703 or 100756723',
#  'h205 or h205 or 100756723 or 100756723 or 100756723 or h205',
#  '100761703 or 100761703',
#  '100760312',
#  '100761703 or 100761703',
#  'h262',
#  '100758335 or 100758998',
#  '100768368 or 100767272 or 100770498 or 100768368 or 103162985 or 100773811 or 100756132 or 100764561 or 100768998 or 100751372 or 100765958',
#  '100736551 or 100736551',
#  '',
#  '',
#  '',
#  '100761966 or 100754792',
#  '100751684 or 100751684 or 100758335 or h9153',
#  '100758335',
#  '100767453',
#  '100754792',
#  '',
#  '',
#  '',
#  '100750995',
#  '100761464',
#  '100772118',
#  '100772118',
#  '',
#  '',
#  '100772118',
#  '100766764 or 100766764 or 100766764',
#  '100773187',
#  '',
#  '100765665',
#  '',
#  '',
#  '100770034 or 100770034 or 100770034 or 100767138 or 100762166 or 100770034',
#  '100766757',
#  '100765000 or 100765000',
#  '100755842 or 100774860',
#  '',
#  '',
#  '100762413 or 100764888',
#  '100764888 or 100762413',
#  '100689060 or 100689060',
#  '100689060 or 100689060',
#  '100767083 or 100751825 or 100751825',
#  '',
#  '100769077 or 100766691 or 100762253 or 100751193 or 103160327 or 100760456 or 103160327 or 100773213 or 100766691',
#  '100769077 or 103160327 or 100762253 or 100751193 or 103160327 or 100760456 or 100773213 or 100766691 or 100766691',
#  '100769077 or 103160327 or 100762253 or 100751193 or 103160327 or 100760456 or 100773213 or 100766691 or 100766691',
#  '100769077 or 103160327 or 100762253 or 100751193 or 103160327 or 100760456 or 100773213 or 100766691 or 100766691',
#  '100769077 or 103160327 or 100762253 or 100751193 or 103160327 or 100760456 or 100773213 or 100766691 or 100766691',
#  '100769077 or 103160327 or 100762253 or 100751193 or 103160327 or 100760456 or 100773213 or 100766691 or 100766691',
#  '100769077 or 100766691 or 100762253 or 100751193 or 103160327 or 100760456 or 103160327 or 100766691 or 100773213',
#  '100766691 or 100762253 or 100766691 or 103160327 or 100760456 or 103160327 or 100751193 or 100769077 or 100773213',
#  '100766691 or 100762253 or 100766691 or 103160327 or 100760456 or 103160327 or 100751193 or 100769077 or 100773213',
#  '100762253 or 100766691 or 100760456 or 103160327 or 103160327 or 100751193 or 100773213 or 100766691 or 100769077',
#  '100769077 or 103160327 or 100762253 or 100751193 or 103160327 or 100760456 or 100773213 or 100766691 or 100766691',
#  '100773213 or 100762253 or 103160327 or 100766691 or 100769077 or 103160327 or 100766691 or 100760456 or 100751193',
#  '100762253 or 100766691 or 100760456 or 100773213 or 103160327 or 100751193 or 103160327 or 100766691 or 100769077',
#  '100769077 or 103160327 or 100762253 or 100751193 or 103160327 or 100760456 or 100773213 or 100766691 or 100766691',
#  '100769077 or 103160327 or 100762253 or 100751193 or 103160327 or 100760456 or 100773213 or 100766691 or 100766691',
#  '100769077 or 103160327 or 100762253 or 100751193 or 103160327 or 100760456 or 100773213 or 100766691 or 100766691',
#  '100769077 or 103160327 or 100762253 or 100751193 or 103160327 or 100760456 or 100773213 or 100766691 or 100766691',
#  '100751193 or 100769077 or 100773213 or 103160327 or 100766691 or 103160327 or 100766691 or 100762253 or 100760456',
#  '100771907',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '100752066',
#  '100754963 or 100751939 or 100761743 or 100763383 or 100763383 or 100757875 or 100758206 or 100769688',
#  '',
#  '',
#  '',
#  '100755485',
#  '100756809',
#  '',
#  '100761164',
#  '',
#  '100759906 or 100753688',
#  '100771278',
#  '100689208',
#  '',
#  '100682536',
#  '',
#  'h191 or 100767631 or 100767631',
#  '',
#  '',
#  '',
#  '',
#  '100750552 or 100756663 100756951 100766960 or (100750552 and 100756663 100756951 100766960)',
#  '100750552 or 100756663 100756951 100766960 or (100750552 and 100756663 100756951 100766960)',
#  '100750895',
#  '',
#  'h10606',
#  '100682535 or 100761226 or 100763292 or 100751265 or 100774607',
#  '',
#  '(100764862 and 100689437 and 100750352 and 100758466) or (100764862 and 100689437 and 100750352 and 100758466)',
#  '100770598 or 100766192',
#  '100750672 or 100750672',
#  '',
#  'h1645',
#  'h1109',
#  'h1109',
#  '100770348',
#  '100770348',
#  '',
#  '100761203 or 100760626',
#  '100760826',
#  '',
#  '100760826 or 100766001',
#  '',
#  '100760826 or 100766001',
#  '',
#  '100760826 or 100766001',
#  '100763902',
#  'h11254',
#  '100762871 and 100772257',
#  '100689351 or 100763902',
#  '100769905 and 100689315',
#  '100769905 and 100689315',
#  '100763902',
#  '100689315 and 100769905',
#  '',
#  '100760826 or 100766001',
#  '100769905 and 100689315',
#  '',
#  '100760826 or 100766001',
#  '',
#  '100760826 or 100766001',
#  '100752115',
#  '100770225',
#  '100689351 or 100763902',
#  '100753315 or 100752849 or 100766370 or 100766370',
#  '100760506 or 100768176',
#  '100689351 or 100763902',
#  '100765800 or 100766093',
#  '100766093',
#  '100689188 or 100772617 or h11254 or 100689176 or 100769511 or h55089 or 100771829 or (100762288 and 100772257) or (100762288 and 100772552)',
#  '100767098 or 100754504',
#  '(100689315 and 100760403) or (100768258 and 100689315)',
#  'h124 or 100759210 or 100767061 or (h125 and h124) or (h125 and h126) or 100767929 or h127 or (h126 and h124) or h125 or 100764101 or 100762407 or h126 or 100762407',
#  'h127 or 100762407 or h125 or 100767929 or 100759210 or (h125 and h124) or h124 or 100767061 or 100764101 or (h125 and h126) or (h126 and h124) or 100762407 or h126',
#  '100767061 or h125 or (h125 and h124) or 100767929 or h126 or 100762407 or 100764101 or h127 or h124 or (h126 and h124) or 100762407 or (h125 and h126) or 100759210',
#  'h126 or 100764101 or (h126 and h124) or h127 or 100767061 or 100762407 or (h125 and h124) or 100767929 or h124 or h125 or 100762407 or 100759210 or (h125 and h126)',
#  'h126 or 100764101 or (h126 and h124) or h127 or 100767061 or 100762407 or (h125 and h124) or 100767929 or h124 or h125 or 100762407 or 100759210 or (h125 and h126)',
#  '(h125 and h126) or 100764101 or (h125 and h124) or h127 or 100767061 or 100762407 or h126 or h124 or 100767929 or h125 or h126 or 100762407 or 100759210 or (h126 and h124)',
#  '100689106 or 100689106',
#  '100761706 or 100772304 or h501 or 100772304 or 100758951 or 100757658 or 100772304',
#  '100765516 or 100764994 or 100772225 or 100764994',
#  '100757658',
#  '100757371 or h501 or 100772304 or 100757658 or h222 or 100772304 or 100755596 or 100761706 or 100772304 or 100758951 or 100768227 or 100765516',
#  '100765516 or 100772225',
#  '100758951 or 100755596 or 100757371 or 100772304 or 100772304 or h222 or 100772304 or 100757658 or 100765516',
#  '',
#  '',
#  '100751774 or 100751774 or 100771587 or 100751774',
#  '100751684 or h9153 or 100758335',
#  '100758335',
#  '100766626 or 113830655',
#  '100757046',
#  '',
#  '100764620',
#  '100761707',
#  '100754473 or h246',
#  '100772492',
#  '100772492',
#  '',
#  '',
#  '100689106 or h8574 or 100689106 or 100751272',
#  '100689106 or h8574 or 100689106 or 100751272',
#  '100766524 or 100766524',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '100766524 or 100766524',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '100766524 or 100766524',
#  '',
#  '',
#  '',
#  '100758278 or 100758278',
#  '100758278 or 100758278',
#  '100758278 or 100758278',
#  '100758278 or 100758278',
#  '100689450 or 100758117',
#  '',
#  '',
#  '',
#  '',
#  '100769239 or 100769239 or 100769239',
#  '',
#  '',
#  '100774910 or 100757901 or 100774910 or 100758386 or 100774910',
#  '100751632',
#  '100751632',
#  '',
#  '',
#  '100689315 or h280 or h278 or h276 or h277 or (100765887 and 100759612) or h276 or h279',
#  '100689315 or h280 or h278 or h276 or h277 or (100765887 and 100759612) or h276 or h279',
#  '100750508',
#  '',
#  '100682536',
#  '',
#  '100682536',
#  '100689208',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '100769146 or 100769146 or 100769146',
#  '100765485 or 100765485',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '100689407',
#  '100760815 or 100759648',
#  '',
#  '100689106 or h8574 or 100689106 or 100751272',
#  '',
#  '',
#  '100770034 or 100762166 or 100770034 or 100770034 or 100770034 or 100767138',
#  '100766757',
#  '100765000',
#  '',
#  '100774950 or 100765865',
#  '100765567',
#  '',
#  '100689404 or 100752582',
#  '',
#  '',
#  '',
#  '100760826 or 100766001',
#  '',
#  '100760826 or 100766001',
#  '',
#  '100760826 or 100766001',
#  '',
#  ...]

# %%
# Generate Recon3D dataset with the addition of GPR with CHO genes
recon3d['CHO GPR'] = cho_gpr
recon3d.to_excel('../../Data/GPR_Curation/recon3D_chogprs.xlsx')
recon3d
# Out:
#          m_reaction                               Reaction Name  \
# 0      10FTHF5GLUtl      5-Glutamyl-10Fthf Transport, Lysosomal
# 1      10FTHF5GLUtm  5-Glutamyl-10Fthf Transport, Mitochondrial
# 2      10FTHF6GLUtl      6-Glutamyl-10Fthf Transport, Lysosomal
# 3      10FTHF6GLUtm  6-Glutamyl-10Fthf Transport, Mitochondrial
# 4      10FTHF7GLUtl      7-Glutamyl-10Fthf Transport, Lysosomal
# ...             ...                                         ...
# 13538      steroids                         Steroids (from HMR)
# 13539      vitaminA                         Vitamina (from HMR)
# 13540      vitaminD                         Vitamind (from HMR)
# 13541      vitaminE                         Vitamine (from HMR)
# 13542   xenobiotics                      Xenobiotics (from HMR)
#
#                                            m_metabolites m_gene_reaction_rule  \
# 0                        10fthf5glu[c] --> 10fthf5glu[l]
# 1                        10fthf5glu[m] --> 10fthf5glu[c]
# 2                        10fthf6glu[c] --> 10fthf6glu[l]
# 3                        10fthf6glu[m] --> 10fthf6glu[c]
# 4                        10fthf7glu[c] --> 10fthf7glu[l]
# ...                                                  ...                  ...
# 13538  46dhoxquin[c] + 48dhoxquin[c] + C05299[c] + C0...
# 13539  CE1761[c] + CE1761[r] + CE2954[c] + CE2954[r] ...
# 13540  CE2204[c] + CE2204[m] + CE2207[c] + CE2207[m] ...
# 13541                CE1925[c] + CE5854[c] --> M03143[c]
# 13542  M00030[c] + M00031[c] + M00033[c] + M00244[c] ...
#
#                     m_subsystem  Lower bound  Upper bound  m_gene seq_uniprot  \
# 0          Transport, lysosomal          0.0       1000.0     NaN        None
# 1      Transport, mitochondrial          0.0       1000.0     NaN        None
# 2          Transport, lysosomal          0.0       1000.0     NaN        None
# 3      Transport, mitochondrial          0.0       1000.0     NaN        None
# 4          Transport, lysosomal          0.0       1000.0     NaN        None
# ...                         ...          ...          ...     ...         ...
# 13538  Exchange/demand reaction          0.0       1000.0     NaN        None
# 13539  Exchange/demand reaction          0.0       1000.0     NaN        None
# 13540  Exchange/demand reaction          0.0       1000.0     NaN        None
# 13541  Exchange/demand reaction          0.0       1000.0     NaN        None
# 13542  Exchange/demand reaction          0.0       1000.0     NaN        None
#
#        seq_len  ... seq_num_experimental_structures  struct_id  \
# 0          NaN  ...                             NaN       None
# 1          NaN  ...                             NaN       None
# 2          NaN  ...                             NaN       None
# 3          NaN  ...                             NaN       None
# 4          NaN  ...                             NaN       None
# ...        ...  ...                             ...        ...
# 13538      NaN  ...                             NaN       None
# 13539      NaN  ...                             NaN       None
# 13540      NaN  ...                             NaN       None
# 13541      NaN  ...                             NaN       None
# 13542      NaN  ...                             NaN       None
#
#        struct_chain_id struct_chain_seq_coverage struct_is_experimental  \
# 0                 None                       NaN                    NaN
# 1                 None                       NaN                    NaN
# 2                 None                       NaN                    NaN
# 3                 None                       NaN                    NaN
# 4                 None                       NaN                    NaN
# ...                ...                       ...                    ...
# 13538             None                       NaN                    NaN
# 13539             None                       NaN                    NaN
# 13540             None                       NaN                    NaN
# 13541             None                       NaN                    NaN
# 13542             None                       NaN                    NaN
#
#        struct_pdb  struct_resolution struct_chemicals  struct_file CHO GPR
# 0            None                NaN             None         None
# 1            None                NaN             None         None
# 2            None                NaN             None         None
# 3            None                NaN             None         None
# 4            None                NaN             None         None
# ...           ...                ...              ...          ...     ...
# 13538        None                NaN             None         None
# 13539        None                NaN             None         None
# 13540        None                NaN             None         None
# 13541        None                NaN             None         None
# 13542        None                NaN             None         None
#
# [13543 rows x 22 columns]

# %% [markdown]
# The dataset generated here will then be used in the **Reactions** notebook **Part 6**

# %% [markdown]
# ### 2. Adittion of new reactions from Recon 3D
# Recon3D reactions with mapped CHO GPRs are added to our reconstruction

# %%
# Subset of Recon 3D dataset with information on CHO GPRs
recon3d_cho = recon3d[recon3d['CHO GPR'] != '']
recon3d_cho = recon3d_cho.reset_index(drop=True)

# %%
recon3d_cho['m_metabolites'] = recon3d_cho['m_metabolites'].str.replace("[", "_", regex=True)
recon3d_cho['m_metabolites'] = recon3d_cho['m_metabolites'].str.replace("]", "", regex=True)
recon3d_cho

# %%
#Retreive information from the reactions in our reconstruction in Google Sheets

# give service account details to gspread
sa = gspread.service_account(filename='../credentials.json')

# sa is a gspread client, which can be used for connecting to the sheets
# by using the open method and the sheet name.
cho_recon = sa.open('CHO Network Reconstruction')

# we also need to specify the page name before getting the data. In this case we use the Rxns and Metabolites sheet.
rxns_sheet = cho_recon.worksheet('Rxns')

# We can extract the data using the get_all_records method and create pd DataFrames

# Reactions IDs, names, formulas, GPRs
rxns = pd.DataFrame(rxns_sheet.get_all_records())
del rxns[rxns.columns[0]]
rxns

# %%
# List of all the reactions in our reconstruction
cho_rxns_list = list(rxns['Reaction'])

# List of all the reactions with CHO GPRs in Recon3D 
recon3D_rxns_list = list(recon3d_cho['m_reaction'])

# %%
# List of Recon3D reactions that are in our reconstruction
rxns_in_cho = []

# List of Recon3D reactions that are NOT in our reconstruction
rxns_not_in_cho = []

for rxn in recon3D_rxns_list:
    if rxn in cho_rxns_list:
        rxns_in_cho.append(rxn)
    elif rxn not in cho_rxns_list:
        rxns_not_in_cho.append(rxn)

# %%
# Generation of a dataset containing information about Recon3D reactions that are not in our reconstruction
subset_df = recon3d_cho[recon3d_cho['m_reaction'].isin(rxns_not_in_cho)]
subset_df

# %%
#This dataset contains all the reactions added from Recon 3D

rxns_recon3d_toadd = subset_df[['m_reaction', 'Reaction Name', 'm_metabolites', 'm_subsystem', 'CHO GPR', 'Lower bound', 'Upper bound']]
rxns_recon3d_toadd.to_excel('../../Data/Reconciliation/datasets/rxns_recon3d_toadd.xlsx')
