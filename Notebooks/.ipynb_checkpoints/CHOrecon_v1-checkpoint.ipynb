# %%
import pandas as pd
import numpy as np

# %%
#Read excel files and create the dfs
hefzi_df = pd.read_excel('../Data/iCHOv1_Reconstruction.xlsx', header = 1)
fouladiha_df = pd.read_excel('../Data/10529_2020_3021_MOESM1_ESM.xlsx', 'Supplementary Table 10', header = 1)
yeo_df = pd.read_excel('../Data/Supplementary Data.xlsx', 'Data S2')

# %%
#Standarization of the columns names
fouladiha_df.rename(columns = {'Abbreviation':'Reaction', 'Description':'Reaction Name', 'Reaction':'Reaction Formula'}, inplace = True)
yeo_df.rename(columns = {'Rxn':'Reaction', 'Subsystem (iCHO1766)':'Subsystem'}, inplace = True)

# Addition of tag columns
hefzi_df.insert(loc=0, column='hef', value='X')
hefzi_df.insert(loc=1, column='fou', value=np.nan)
hefzi_df.insert(loc=2, column='yeo', value=np.nan)

fouladiha_df.insert(loc=0, column='hef', value=np.nan)
fouladiha_df.insert(loc=1, column='fou', value='X')
fouladiha_df.insert(loc=2, column='yeo', value=np.nan)

yeo_df.insert(loc=0, column='hef', value=np.nan)
yeo_df.insert(loc=1, column='fou', value=np.nan)
yeo_df.insert(loc=2, column='yeo', value='X')


hefzi_df
# Out:
#      hef  fou  yeo   Reaction  \
# 0      X  NaN  NaN  COKECBESr
# 1      X  NaN  NaN    EGMESTr
# 2      X  NaN  NaN   NMPTRCOX
# 3      X  NaN  NaN      PRO1x
# 4      X  NaN  NaN      DHDDH
# ...   ..  ...  ...        ...
# 3224   X  NaN  NaN     C8CRNt
# 3225   X  NaN  NaN    MALCRNt
# 3226   X  NaN  NaN        NP1
# 3227   X  NaN  NaN   UGT1A10r
# 3228   X  NaN  NaN    PCLYSOX
#
#                                           Reaction Name  \
# 0                       Carboxylesterase (cocaine) (er)
# 1                         ecgonine methyl esterase (ER)
# 2     N-Methylputrescine:oxygen oxidoreductase (deam...
# 3                        L-ProlineNAD+ 5-oxidoreductase
# 4                             Dihydrodiol dehydrogenase
# ...                                                 ...
# 3224       C8:0 acylcarnitine transport to mitochondria
# 3225      Malonyl carnitine transport into mitochondria
# 3226                             nucleotide phosphatase
# 3227  UDP-glucuronosyltransferase 1-10 precursor, mi...
# 3228  Procollagen-lysine 1, 2-oxoglutarate 5-dioxyge...
#
#                             Subsystem  \
# 0                  ALKALOID SYNTHESIS
# 1                  ALKALOID SYNTHESIS
# 2                  ALKALOID SYNTHESIS
# 3     ARGININE AND PROLINE METABOLISM
# 4                      CYP METABOLISM
# ...                               ...
# 3224                CARNITINE SHUTTLE
# 3225                CARNITINE SHUTTLE
# 3226                   NAD METABOLISM
# 3227               STEROID METABOLISM
# 3228                LYSINE METABOLISM
#
#                                        Reaction Formula  \
# 0          coke[r] + h2o[r]  -> bz[r] + egme[r] + h[r]
# 1       h2o[r] + egme[r]  -> h[r] + ecgon[r] + meoh[r]
# 2     nmptrc[c] + o2[c]  -> nh4[c] + 1mpyr[c] + h2o2...
# 3     pro_L[c] + nad[c]  -> 2 h[c] + 1pyr5c[c] + nad...
# 4       nadp[c] + dhnpthld[c]  -> npthld[c] + nadph[c]
# ...                                                 ...
# 3224                             c8crn[c]  -> c8crn[m]
# 3225                         HC10859[c]  -> HC10859[m]
# 3226      h[c] + nac[c] + r1p[c]  -> pi[c] + nicrns[c]
# 3227  2 h[r] + udpglcur[r] + bilirub[r]  <=> udp[r] ...
# 3228  o2[c] + akg[c] + pcollglys[c]  -> co2[c] + suc...
#
#                                                     GPR  \
# 0                            (100756666) or (100767789)
# 1                                           (100771815)
# 2     (100771382) or (100762635) or (100762926) or (...
# 3                                           (100773901)
# 4                                           (100753544)
# ...                                                 ...
# 3224                                        (100765000)
# 3225                                        (100765000)
# 3226                                        (100757729)
# 3227                                        (100755423)
# 3228                         (100762939) or (100763844)
#
#                                          Curation Notes  References
# 0     From the various human carboxylesterases only ...         NaN
# 1     Encoded enzyme (100771815) is an arylacetamide...         NaN
# 2     All encode amine oxidases: AOC1 (100771382); A...         NaN
# 3     100773901 maps to 58510, "similar to proline d...         NaN
# 4     Dimeric dihydrodiol dehydrogenase was found to...         NaN
# ...                                                 ...         ...
# 3224                                                NaN         NaN
# 3225                                                NaN         NaN
# 3226                Homolog to the human gene in Recon1         NaN
# 3227  PMID:7945246 shows mono and di gluconidation o...         NaN
# 3228  PMID: 11130984 describes the presence of the r...         NaN
#
# [3229 rows x 10 columns]

# %%
cols = hefzi_df.columns.to_list()+fouladiha_df.columns.to_list()+yeo_df.columns.to_list()

# Eliminate repetitive values in the 'cols' list
cols = [cols[i] for i in range(len(cols)) if i == cols.index(cols[i])]

cols
# Out:
# ['hef',
#  'fou',
#  'yeo',
#  'Reaction',
#  'Reaction Name',
#  'Subsystem',
#  'Reaction Formula',
#  'GPR',
#  'Curation Notes',
#  'References',
#  'Genes',
#  'Protein',
#  'Reversible',
#  'Lower bound',
#  'Upper bound',
#  'Objective',
#  'Proteins',
#  'EC Number',
#  'Mol wt',
#  'kcat_forward',
#  'kcat_backward',
#  'Subsystem (iCHO2291)']

# %%
def add_col(df):
    '''
    This function adds the remaining columns from the cols list 
    to an existing df that are not contained in such df
    '''
    df.columns
    add_col = []
    for col in cols:
        if col not in df.columns:
            add_col.append(col)
    df = df.reindex(columns = df.columns.tolist() + add_col)
    return df

# %%
# Unify columns for all datasets
hefzi_df = add_col(hefzi_df)
fouladiha_df = add_col(fouladiha_df)
yeo_df = add_col(yeo_df)

hefzi_df
# Out:
#      hef  fou  yeo   Reaction  \
# 0      X  NaN  NaN  COKECBESr
# 1      X  NaN  NaN    EGMESTr
# 2      X  NaN  NaN   NMPTRCOX
# 3      X  NaN  NaN      PRO1x
# 4      X  NaN  NaN      DHDDH
# ...   ..  ...  ...        ...
# 3224   X  NaN  NaN     C8CRNt
# 3225   X  NaN  NaN    MALCRNt
# 3226   X  NaN  NaN        NP1
# 3227   X  NaN  NaN   UGT1A10r
# 3228   X  NaN  NaN    PCLYSOX
#
#                                           Reaction Name  \
# 0                       Carboxylesterase (cocaine) (er)
# 1                         ecgonine methyl esterase (ER)
# 2     N-Methylputrescine:oxygen oxidoreductase (deam...
# 3                        L-ProlineNAD+ 5-oxidoreductase
# 4                             Dihydrodiol dehydrogenase
# ...                                                 ...
# 3224       C8:0 acylcarnitine transport to mitochondria
# 3225      Malonyl carnitine transport into mitochondria
# 3226                             nucleotide phosphatase
# 3227  UDP-glucuronosyltransferase 1-10 precursor, mi...
# 3228  Procollagen-lysine 1, 2-oxoglutarate 5-dioxyge...
#
#                             Subsystem  \
# 0                  ALKALOID SYNTHESIS
# 1                  ALKALOID SYNTHESIS
# 2                  ALKALOID SYNTHESIS
# 3     ARGININE AND PROLINE METABOLISM
# 4                      CYP METABOLISM
# ...                               ...
# 3224                CARNITINE SHUTTLE
# 3225                CARNITINE SHUTTLE
# 3226                   NAD METABOLISM
# 3227               STEROID METABOLISM
# 3228                LYSINE METABOLISM
#
#                                        Reaction Formula  \
# 0          coke[r] + h2o[r]  -> bz[r] + egme[r] + h[r]
# 1       h2o[r] + egme[r]  -> h[r] + ecgon[r] + meoh[r]
# 2     nmptrc[c] + o2[c]  -> nh4[c] + 1mpyr[c] + h2o2...
# 3     pro_L[c] + nad[c]  -> 2 h[c] + 1pyr5c[c] + nad...
# 4       nadp[c] + dhnpthld[c]  -> npthld[c] + nadph[c]
# ...                                                 ...
# 3224                             c8crn[c]  -> c8crn[m]
# 3225                         HC10859[c]  -> HC10859[m]
# 3226      h[c] + nac[c] + r1p[c]  -> pi[c] + nicrns[c]
# 3227  2 h[r] + udpglcur[r] + bilirub[r]  <=> udp[r] ...
# 3228  o2[c] + akg[c] + pcollglys[c]  -> co2[c] + suc...
#
#                                                     GPR  \
# 0                            (100756666) or (100767789)
# 1                                           (100771815)
# 2     (100771382) or (100762635) or (100762926) or (...
# 3                                           (100773901)
# 4                                           (100753544)
# ...                                                 ...
# 3224                                        (100765000)
# 3225                                        (100765000)
# 3226                                        (100757729)
# 3227                                        (100755423)
# 3228                         (100762939) or (100763844)
#
#                                          Curation Notes  References  ...  \
# 0     From the various human carboxylesterases only ...         NaN  ...
# 1     Encoded enzyme (100771815) is an arylacetamide...         NaN  ...
# 2     All encode amine oxidases: AOC1 (100771382); A...         NaN  ...
# 3     100773901 maps to 58510, "similar to proline d...         NaN  ...
# 4     Dimeric dihydrodiol dehydrogenase was found to...         NaN  ...
# ...                                                 ...         ...  ...
# 3224                                                NaN         NaN  ...
# 3225                                                NaN         NaN  ...
# 3226                Homolog to the human gene in Recon1         NaN  ...
# 3227  PMID:7945246 shows mono and di gluconidation o...         NaN  ...
# 3228  PMID: 11130984 describes the presence of the r...         NaN  ...
#
#       Reversible  Lower bound  Upper bound  Objective  Proteins  EC Number  \
# 0            NaN          NaN          NaN        NaN       NaN        NaN
# 1            NaN          NaN          NaN        NaN       NaN        NaN
# 2            NaN          NaN          NaN        NaN       NaN        NaN
# 3            NaN          NaN          NaN        NaN       NaN        NaN
# 4            NaN          NaN          NaN        NaN       NaN        NaN
# ...          ...          ...          ...        ...       ...        ...
# 3224         NaN          NaN          NaN        NaN       NaN        NaN
# 3225         NaN          NaN          NaN        NaN       NaN        NaN
# 3226         NaN          NaN          NaN        NaN       NaN        NaN
# 3227         NaN          NaN          NaN        NaN       NaN        NaN
# 3228         NaN          NaN          NaN        NaN       NaN        NaN
#
#       Mol wt  kcat_forward  kcat_backward  Subsystem (iCHO2291)
# 0        NaN           NaN            NaN                   NaN
# 1        NaN           NaN            NaN                   NaN
# 2        NaN           NaN            NaN                   NaN
# 3        NaN           NaN            NaN                   NaN
# 4        NaN           NaN            NaN                   NaN
# ...      ...           ...            ...                   ...
# 3224     NaN           NaN            NaN                   NaN
# 3225     NaN           NaN            NaN                   NaN
# 3226     NaN           NaN            NaN                   NaN
# 3227     NaN           NaN            NaN                   NaN
# 3228     NaN           NaN            NaN                   NaN
#
# [3229 rows x 22 columns]

# %%
# Reorder columns in all datasets the same way
fouladiha_df = fouladiha_df[['hef', 'fou', 'yeo', 'Reaction', 'Reaction Name', 'Reaction Formula', 'GPR', 'Subsystem', 'Subsystem (iCHO2291)', 'Genes', 'Protein', 'EC Number', 'Mol wt', 'kcat_forward', 'kcat_backward', 'Reversible','Lower bound', 'Upper bound', 'Objective', 'Curation Notes', 'References']]
yeo_df = yeo_df[['hef', 'fou', 'yeo', 'Reaction', 'Reaction Name', 'Reaction Formula', 'GPR', 'Subsystem', 'Subsystem (iCHO2291)', 'Genes', 'Protein', 'EC Number', 'Mol wt', 'kcat_forward', 'kcat_backward', 'Reversible','Lower bound', 'Upper bound', 'Objective', 'Curation Notes', 'References']]
hefzi_df = hefzi_df[['hef', 'fou', 'yeo', 'Reaction', 'Reaction Name', 'Reaction Formula', 'GPR', 'Subsystem', 'Subsystem (iCHO2291)', 'Genes', 'Protein', 'EC Number', 'Mol wt', 'kcat_forward', 'kcat_backward', 'Reversible','Lower bound', 'Upper bound', 'Objective', 'Curation Notes', 'References']]

hefzi_df
# Out:
#      hef  fou  yeo   Reaction  \
# 0      X  NaN  NaN  COKECBESr
# 1      X  NaN  NaN    EGMESTr
# 2      X  NaN  NaN   NMPTRCOX
# 3      X  NaN  NaN      PRO1x
# 4      X  NaN  NaN      DHDDH
# ...   ..  ...  ...        ...
# 3224   X  NaN  NaN     C8CRNt
# 3225   X  NaN  NaN    MALCRNt
# 3226   X  NaN  NaN        NP1
# 3227   X  NaN  NaN   UGT1A10r
# 3228   X  NaN  NaN    PCLYSOX
#
#                                           Reaction Name  \
# 0                       Carboxylesterase (cocaine) (er)
# 1                         ecgonine methyl esterase (ER)
# 2     N-Methylputrescine:oxygen oxidoreductase (deam...
# 3                        L-ProlineNAD+ 5-oxidoreductase
# 4                             Dihydrodiol dehydrogenase
# ...                                                 ...
# 3224       C8:0 acylcarnitine transport to mitochondria
# 3225      Malonyl carnitine transport into mitochondria
# 3226                             nucleotide phosphatase
# 3227  UDP-glucuronosyltransferase 1-10 precursor, mi...
# 3228  Procollagen-lysine 1, 2-oxoglutarate 5-dioxyge...
#
#                                        Reaction Formula  \
# 0          coke[r] + h2o[r]  -> bz[r] + egme[r] + h[r]
# 1       h2o[r] + egme[r]  -> h[r] + ecgon[r] + meoh[r]
# 2     nmptrc[c] + o2[c]  -> nh4[c] + 1mpyr[c] + h2o2...
# 3     pro_L[c] + nad[c]  -> 2 h[c] + 1pyr5c[c] + nad...
# 4       nadp[c] + dhnpthld[c]  -> npthld[c] + nadph[c]
# ...                                                 ...
# 3224                             c8crn[c]  -> c8crn[m]
# 3225                         HC10859[c]  -> HC10859[m]
# 3226      h[c] + nac[c] + r1p[c]  -> pi[c] + nicrns[c]
# 3227  2 h[r] + udpglcur[r] + bilirub[r]  <=> udp[r] ...
# 3228  o2[c] + akg[c] + pcollglys[c]  -> co2[c] + suc...
#
#                                                     GPR  \
# 0                            (100756666) or (100767789)
# 1                                           (100771815)
# 2     (100771382) or (100762635) or (100762926) or (...
# 3                                           (100773901)
# 4                                           (100753544)
# ...                                                 ...
# 3224                                        (100765000)
# 3225                                        (100765000)
# 3226                                        (100757729)
# 3227                                        (100755423)
# 3228                         (100762939) or (100763844)
#
#                             Subsystem  Subsystem (iCHO2291)  Genes  ...  \
# 0                  ALKALOID SYNTHESIS                   NaN    NaN  ...
# 1                  ALKALOID SYNTHESIS                   NaN    NaN  ...
# 2                  ALKALOID SYNTHESIS                   NaN    NaN  ...
# 3     ARGININE AND PROLINE METABOLISM                   NaN    NaN  ...
# 4                      CYP METABOLISM                   NaN    NaN  ...
# ...                               ...                   ...    ...  ...
# 3224                CARNITINE SHUTTLE                   NaN    NaN  ...
# 3225                CARNITINE SHUTTLE                   NaN    NaN  ...
# 3226                   NAD METABOLISM                   NaN    NaN  ...
# 3227               STEROID METABOLISM                   NaN    NaN  ...
# 3228                LYSINE METABOLISM                   NaN    NaN  ...
#
#       EC Number  Mol wt  kcat_forward  kcat_backward  Reversible  Lower bound  \
# 0           NaN     NaN           NaN            NaN         NaN          NaN
# 1           NaN     NaN           NaN            NaN         NaN          NaN
# 2           NaN     NaN           NaN            NaN         NaN          NaN
# 3           NaN     NaN           NaN            NaN         NaN          NaN
# 4           NaN     NaN           NaN            NaN         NaN          NaN
# ...         ...     ...           ...            ...         ...          ...
# 3224        NaN     NaN           NaN            NaN         NaN          NaN
# 3225        NaN     NaN           NaN            NaN         NaN          NaN
# 3226        NaN     NaN           NaN            NaN         NaN          NaN
# 3227        NaN     NaN           NaN            NaN         NaN          NaN
# 3228        NaN     NaN           NaN            NaN         NaN          NaN
#
#       Upper bound  Objective  \
# 0             NaN        NaN
# 1             NaN        NaN
# 2             NaN        NaN
# 3             NaN        NaN
# 4             NaN        NaN
# ...           ...        ...
# 3224          NaN        NaN
# 3225          NaN        NaN
# 3226          NaN        NaN
# 3227          NaN        NaN
# 3228          NaN        NaN
#
#                                          Curation Notes References
# 0     From the various human carboxylesterases only ...        NaN
# 1     Encoded enzyme (100771815) is an arylacetamide...        NaN
# 2     All encode amine oxidases: AOC1 (100771382); A...        NaN
# 3     100773901 maps to 58510, "similar to proline d...        NaN
# 4     Dimeric dihydrodiol dehydrogenase was found to...        NaN
# ...                                                 ...        ...
# 3224                                                NaN        NaN
# 3225                                                NaN        NaN
# 3226                Homolog to the human gene in Recon1        NaN
# 3227  PMID:7945246 shows mono and di gluconidation o...        NaN
# 3228  PMID: 11130984 describes the presence of the r...        NaN
#
# [3229 rows x 21 columns]

# %%
# Merge all the df into a unified df
all_dfs = pd.concat([hefzi_df, fouladiha_df, yeo_df])
all_dfs = all_dfs.reset_index(drop = True)

all_dfs #16901 rows/reactions (many of them repeated)
# Out:
#        hef  fou  yeo     Reaction  \
# 0        X  NaN  NaN    COKECBESr
# 1        X  NaN  NaN      EGMESTr
# 2        X  NaN  NaN     NMPTRCOX
# 3        X  NaN  NaN        PRO1x
# 4        X  NaN  NaN        DHDDH
# ...    ...  ...  ...          ...
# 16896  NaN  NaN    X  RTOTALFATPc
# 16897  NaN  NaN    X      RTOTALt
# 16898  NaN  NaN    X     Rtotaltl
# 16899  NaN  NaN    X     Rtotaltp
# 16900  NaN  NaN    X  Rtotalcoatx
#
#                                            Reaction Name  \
# 0                        Carboxylesterase (cocaine) (er)
# 1                          ecgonine methyl esterase (ER)
# 2      N-Methylputrescine:oxygen oxidoreductase (deam...
# 3                         L-ProlineNAD+ 5-oxidoreductase
# 4                              Dihydrodiol dehydrogenase
# ...                                                  ...
# 16896                                                NaN
# 16897                                                NaN
# 16898                                                NaN
# 16899                                                NaN
# 16900                                                NaN
#
#                                         Reaction Formula  \
# 0           coke[r] + h2o[r]  -> bz[r] + egme[r] + h[r]
# 1        h2o[r] + egme[r]  -> h[r] + ecgon[r] + meoh[r]
# 2      nmptrc[c] + o2[c]  -> nh4[c] + 1mpyr[c] + h2o2...
# 3      pro_L[c] + nad[c]  -> 2 h[c] + 1pyr5c[c] + nad...
# 4        nadp[c] + dhnpthld[c]  -> npthld[c] + nadph[c]
# ...                                                  ...
# 16896                                                NaN
# 16897                                                NaN
# 16898                                                NaN
# 16899                                                NaN
# 16900                                                NaN
#
#                                                      GPR  \
# 0                             (100756666) or (100767789)
# 1                                            (100771815)
# 2      (100771382) or (100762635) or (100762926) or (...
# 3                                            (100773901)
# 4                                            (100753544)
# ...                                                  ...
# 16896                                                NaN
# 16897                                                NaN
# 16898                                                NaN
# 16899                                                NaN
# 16900                                                NaN
#
#                              Subsystem           Subsystem (iCHO2291)  Genes  \
# 0                   ALKALOID SYNTHESIS                            NaN    NaN
# 1                   ALKALOID SYNTHESIS                            NaN    NaN
# 2                   ALKALOID SYNTHESIS                            NaN    NaN
# 3      ARGININE AND PROLINE METABOLISM                            NaN    NaN
# 4                       CYP METABOLISM                            NaN    NaN
# ...                                ...                            ...    ...
# 16896                R GROUP SYNTHESIS  Exchange/demand/sink reaction    NaN
# 16897         TRANSPORT, EXTRACELLULAR                      Transport    NaN
# 16898             TRANSPORT, LYSOSOMAL                      Transport    NaN
# 16899           TRANSPORT, PEROXISOMAL                      Transport    NaN
# 16900                R GROUP SYNTHESIS  Exchange/demand/sink reaction    NaN
#
#        ...  EC Number Mol wt  kcat_forward  kcat_backward  Reversible  \
# 0      ...        NaN    NaN           NaN            NaN         NaN
# 1      ...        NaN    NaN           NaN            NaN         NaN
# 2      ...        NaN    NaN           NaN            NaN         NaN
# 3      ...        NaN    NaN           NaN            NaN         NaN
# 4      ...        NaN    NaN           NaN            NaN         NaN
# ...    ...        ...    ...           ...            ...         ...
# 16896  ...        NaN    NaN           NaN            NaN         NaN
# 16897  ...        NaN    NaN           NaN            NaN         NaN
# 16898  ...        NaN    NaN           NaN            NaN         NaN
# 16899  ...        NaN    NaN           NaN            NaN         NaN
# 16900  ...        NaN    NaN           NaN            NaN         NaN
#
#        Lower bound  Upper bound  Objective  \
# 0              NaN          NaN        NaN
# 1              NaN          NaN        NaN
# 2              NaN          NaN        NaN
# 3              NaN          NaN        NaN
# 4              NaN          NaN        NaN
# ...            ...          ...        ...
# 16896          NaN          NaN        NaN
# 16897          NaN          NaN        NaN
# 16898          NaN          NaN        NaN
# 16899          NaN          NaN        NaN
# 16900          NaN          NaN        NaN
#
#                                           Curation Notes References
# 0      From the various human carboxylesterases only ...        NaN
# 1      Encoded enzyme (100771815) is an arylacetamide...        NaN
# 2      All encode amine oxidases: AOC1 (100771382); A...        NaN
# 3      100773901 maps to 58510, "similar to proline d...        NaN
# 4      Dimeric dihydrodiol dehydrogenase was found to...        NaN
# ...                                                  ...        ...
# 16896                                                NaN        NaN
# 16897                                                NaN        NaN
# 16898                                                NaN        NaN
# 16899                                                NaN        NaN
# 16900                                                NaN        NaN
#
# [16901 rows x 21 columns]

# %%
# Group the entire dataset by reaction name 
all_dfs1 = all_dfs.groupby(['Reaction'], group_keys=True).apply(lambda x: x)

# Save merged datasets as Excel file
all_dfs1.to_excel('../Data/all_dfs1.xlsx')

all_dfs1
# Out:
#                     hef  fou  yeo      Reaction  \
# Reaction
# 10FTHF5GLUtl 6739   NaN    X  NaN  10FTHF5GLUtl
#              10665  NaN  NaN    X  10FTHF5GLUtl
# 10FTHF5GLUtm 6740   NaN    X  NaN  10FTHF5GLUtm
#              10666  NaN  NaN    X  10FTHF5GLUtm
# 10FTHF6GLUtl 6741   NaN    X  NaN  10FTHF6GLUtl
# ...                 ...  ...  ...           ...
# r2069        661      X  NaN  NaN         r2069
# r2070        662      X  NaN  NaN         r2070
# r2071        663      X  NaN  NaN         r2071
# r2404        1887     X  NaN  NaN         r2404
# r2408        1888     X  NaN  NaN         r2408
#
#                                                         Reaction Name  \
# Reaction
# 10FTHF5GLUtl 6739              5-glutamyl-10FTHF transport, lysosomal
#              10665                                                NaN
# 10FTHF5GLUtm 6740          5-glutamyl-10FTHF transport, mitochondrial
#              10666                                                NaN
# 10FTHF6GLUtl 6741              6-glutamyl-10FTHF transport, lysosomal
# ...                                                               ...
# r2069        661    Amino Acid-Polyamine-Organocation (APC) TCDB:2...
# r2070        662    Amino Acid-Polyamine-Organocation (APC) TCDB:2...
# r2071        663    Amino Acid-Polyamine-Organocation (APC) TCDB:2...
# r2404        1887         Mitochondrial Carrier (MC) TCDB:2.A.29.19.1
# r2408        1888         Mitochondrial Carrier (MC) TCDB:2.A.29.19.1
#
#                                                      Reaction Formula  \
# Reaction
# 10FTHF5GLUtl 6739                    10fthf5glu[c]  => 10fthf5glu[l]
#              10665                                                NaN
# 10FTHF5GLUtm 6740                    10fthf5glu[m]  => 10fthf5glu[c]
#              10666                                                NaN
# 10FTHF6GLUtl 6741                    10fthf6glu[c]  => 10fthf6glu[l]
# ...                                                               ...
# r2069        661       thr_L[c] + citr_L[e]  -> thr_L[e] + citr_L[c]
# r2070        662       hom_L[c] + citr_L[e]  -> hom_L[e] + citr_L[c]
# r2071        663       ile_L[c] + citr_L[e]  -> ile_L[e] + citr_L[c]
# r2404        1887   h[c] + arg_L[c] + orn[m]  -> h[m] + orn[c] + a...
# r2408        1888   h[c] + orn[c] + his_L[m]  -> h[m] + his_L[c] +...
#
#                                            GPR                 Subsystem  \
# Reaction
# 10FTHF5GLUtl 6739                          NaN      TRANSPORT, LYSOSOMAL
#              10665                         NaN      TRANSPORT, LYSOSOMAL
# 10FTHF5GLUtm 6740                          NaN  TRANSPORT, MITOCHONDRIAL
#              10666                         NaN  TRANSPORT, MITOCHONDRIAL
# 10FTHF6GLUtl 6741                          NaN      TRANSPORT, LYSOSOMAL
# ...                                        ...                       ...
# r2069        661     (100760403 and 100689315)  TRANSPORT, EXTRACELLULAR
# r2070        662     (100760403 and 100689315)  TRANSPORT, EXTRACELLULAR
# r2071        663     (100760403 and 100689315)  TRANSPORT, EXTRACELLULAR
# r2404        1887   (100773024) or (100758204)  TRANSPORT, MITOCHONDRIAL
# r2408        1888                  (100758204)  TRANSPORT, MITOCHONDRIAL
#
#                    Subsystem (iCHO2291)  Genes  ...  EC Number Mol wt  \
# Reaction                                        ...
# 10FTHF5GLUtl 6739                   NaN    NaN  ...        NaN    NaN
#              10665            Transport    NaN  ...        NaN    NaN
# 10FTHF5GLUtm 6740                   NaN    NaN  ...        NaN    NaN
#              10666            Transport    NaN  ...        NaN    NaN
# 10FTHF6GLUtl 6741                   NaN    NaN  ...        NaN    NaN
# ...                                 ...    ...  ...        ...    ...
# r2069        661                    NaN    NaN  ...        NaN    NaN
# r2070        662                    NaN    NaN  ...        NaN    NaN
# r2071        663                    NaN    NaN  ...        NaN    NaN
# r2404        1887                   NaN    NaN  ...        NaN    NaN
# r2408        1888                   NaN    NaN  ...        NaN    NaN
#
#                     kcat_forward  kcat_backward  Reversible  Lower bound  \
# Reaction
# 10FTHF5GLUtl 6739            NaN            NaN         0.0          0.0
#              10665           NaN            NaN         NaN          NaN
# 10FTHF5GLUtm 6740            NaN            NaN         0.0          0.0
#              10666           NaN            NaN         NaN          NaN
# 10FTHF6GLUtl 6741            NaN            NaN         0.0          0.0
# ...                          ...            ...         ...          ...
# r2069        661             NaN            NaN         NaN          NaN
# r2070        662             NaN            NaN         NaN          NaN
# r2071        663             NaN            NaN         NaN          NaN
# r2404        1887            NaN            NaN         NaN          NaN
# r2408        1888            NaN            NaN         NaN          NaN
#
#                     Upper bound  Objective  \
# Reaction
# 10FTHF5GLUtl 6739        1000.0        0.0
#              10665          NaN        NaN
# 10FTHF5GLUtm 6740        1000.0        0.0
#              10666          NaN        NaN
# 10FTHF6GLUtl 6741        1000.0        0.0
# ...                         ...        ...
# r2069        661            NaN        NaN
# r2070        662            NaN        NaN
# r2071        663            NaN        NaN
# r2404        1887           NaN        NaN
# r2408        1888           NaN        NaN
#
#                                                        Curation Notes  \
# Reaction
# 10FTHF5GLUtl 6739                                                 NaN
#              10665                                                NaN
# 10FTHF5GLUtm 6740                                                 NaN
#              10666                                                NaN
# 10FTHF6GLUtl 6741                                                 NaN
# ...                                                               ...
# r2069        661    100760403 maps to 9057 (SLC7A6), a y+LAT2 tran...
# r2070        662    100760403 maps to 9057 (SLC7A6), a y+LAT2 tran...
# r2071        663    100760403 maps to 9057 (SLC7A6), a y+LAT2 tran...
# r2404        1887   According to PMID: 14598172, SLC25A2 and A15 h...
# r2408        1888   According to PMID: 14598172, SLC25A2 has this ...
#
#                    References
# Reaction
# 10FTHF5GLUtl 6739         NaN
#              10665        NaN
# 10FTHF5GLUtm 6740         NaN
#              10666        NaN
# 10FTHF6GLUtl 6741         NaN
# ...                       ...
# r2069        661          NaN
# r2070        662          NaN
# r2071        663          NaN
# r2404        1887         NaN
# r2408        1888         NaN
#
# [16901 rows x 21 columns]

# %%
#def f(x):
#    d = {}
#    d['EC Number_m'] = x['EC Number'].first()
#    d['a_max'] = x['a'].max()
#    d['b_mean'] = x['b'].mean()
#    d['c_d_prodsum'] = (x['c'] * x['d']).sum()
#    return pd.Series(d, index=['EC Number_m', 'a_max', 'b_mean', 'c_d_prodsum'])

all_dfs2 = all_dfs.groupby('Reaction').first()
all_dfs2.to_excel('../Data/all_dfs2.xlsx')
all_dfs2
# Out:
#                hef   fou   yeo  \
# Reaction
# 10FTHF5GLUtl  None     X     X
# 10FTHF5GLUtm  None     X     X
# 10FTHF6GLUtl  None     X     X
# 10FTHF6GLUtm  None     X     X
# 10FTHF7GLUtl  None     X     X
# ...            ...   ...   ...
# r2069            X  None  None
# r2070            X  None  None
# r2071            X  None  None
# r2404            X  None  None
# r2408            X  None  None
#
#                                                   Reaction Name  \
# Reaction
# 10FTHF5GLUtl             5-glutamyl-10FTHF transport, lysosomal
# 10FTHF5GLUtm         5-glutamyl-10FTHF transport, mitochondrial
# 10FTHF6GLUtl             6-glutamyl-10FTHF transport, lysosomal
# 10FTHF6GLUtm         6-glutamyl-10FTHF transport, mitochondrial
# 10FTHF7GLUtl             7-glutamyl-10FTHF transport, lysosomal
# ...                                                         ...
# r2069         Amino Acid-Polyamine-Organocation (APC) TCDB:2...
# r2070         Amino Acid-Polyamine-Organocation (APC) TCDB:2...
# r2071         Amino Acid-Polyamine-Organocation (APC) TCDB:2...
# r2404               Mitochondrial Carrier (MC) TCDB:2.A.29.19.1
# r2408               Mitochondrial Carrier (MC) TCDB:2.A.29.19.1
#
#                                                Reaction Formula  \
# Reaction
# 10FTHF5GLUtl                   10fthf5glu[c]  => 10fthf5glu[l]
# 10FTHF5GLUtm                   10fthf5glu[m]  => 10fthf5glu[c]
# 10FTHF6GLUtl                   10fthf6glu[c]  => 10fthf6glu[l]
# 10FTHF6GLUtm                   10fthf6glu[m]  => 10fthf6glu[c]
# 10FTHF7GLUtl                   10fthf7glu[c]  => 10fthf7glu[l]
# ...                                                         ...
# r2069            thr_L[c] + citr_L[e]  -> thr_L[e] + citr_L[c]
# r2070            hom_L[c] + citr_L[e]  -> hom_L[e] + citr_L[c]
# r2071            ile_L[c] + citr_L[e]  -> ile_L[e] + citr_L[c]
# r2404         h[c] + arg_L[c] + orn[m]  -> h[m] + orn[c] + a...
# r2408         h[c] + orn[c] + his_L[m]  -> h[m] + his_L[c] +...
#
#                                      GPR                 Subsystem  \
# Reaction
# 10FTHF5GLUtl                        None      TRANSPORT, LYSOSOMAL
# 10FTHF5GLUtm                        None  TRANSPORT, MITOCHONDRIAL
# 10FTHF6GLUtl                        None      TRANSPORT, LYSOSOMAL
# 10FTHF6GLUtm                        None  TRANSPORT, MITOCHONDRIAL
# 10FTHF7GLUtl                        None      TRANSPORT, LYSOSOMAL
# ...                                  ...                       ...
# r2069          (100760403 and 100689315)  TRANSPORT, EXTRACELLULAR
# r2070          (100760403 and 100689315)  TRANSPORT, EXTRACELLULAR
# r2071          (100760403 and 100689315)  TRANSPORT, EXTRACELLULAR
# r2404         (100773024) or (100758204)  TRANSPORT, MITOCHONDRIAL
# r2408                        (100758204)  TRANSPORT, MITOCHONDRIAL
#
#              Subsystem (iCHO2291)  Genes  Protein EC Number  Mol wt  \
# Reaction
# 10FTHF5GLUtl            Transport    NaN      NaN      None     NaN
# 10FTHF5GLUtm            Transport    NaN      NaN      None     NaN
# 10FTHF6GLUtl            Transport    NaN      NaN      None     NaN
# 10FTHF6GLUtm            Transport    NaN      NaN      None     NaN
# 10FTHF7GLUtl            Transport    NaN      NaN      None     NaN
# ...                           ...    ...      ...       ...     ...
# r2069                        None    NaN      NaN      None     NaN
# r2070                        None    NaN      NaN      None     NaN
# r2071                        None    NaN      NaN      None     NaN
# r2404                        None    NaN      NaN      None     NaN
# r2408                        None    NaN      NaN      None     NaN
#
#               kcat_forward  kcat_backward  Reversible  Lower bound  \
# Reaction
# 10FTHF5GLUtl           NaN            NaN         0.0          0.0
# 10FTHF5GLUtm           NaN            NaN         0.0          0.0
# 10FTHF6GLUtl           NaN            NaN         0.0          0.0
# 10FTHF6GLUtm           NaN            NaN         0.0          0.0
# 10FTHF7GLUtl           NaN            NaN         0.0          0.0
# ...                    ...            ...         ...          ...
# r2069                  NaN            NaN         NaN          NaN
# r2070                  NaN            NaN         NaN          NaN
# r2071                  NaN            NaN         NaN          NaN
# r2404                  NaN            NaN         NaN          NaN
# r2408                  NaN            NaN         NaN          NaN
#
#               Upper bound  Objective  \
# Reaction
# 10FTHF5GLUtl       1000.0        0.0
# 10FTHF5GLUtm       1000.0        0.0
# 10FTHF6GLUtl       1000.0        0.0
# 10FTHF6GLUtm       1000.0        0.0
# 10FTHF7GLUtl       1000.0        0.0
# ...                   ...        ...
# r2069                 NaN        NaN
# r2070                 NaN        NaN
# r2071                 NaN        NaN
# r2404                 NaN        NaN
# r2408                 NaN        NaN
#
#                                                  Curation Notes  References
# Reaction
# 10FTHF5GLUtl                                               None         NaN
# 10FTHF5GLUtm                                               None         NaN
# 10FTHF6GLUtl                                               None         NaN
# 10FTHF6GLUtm                                               None         NaN
# 10FTHF7GLUtl                                               None         NaN
# ...                                                         ...         ...
# r2069         100760403 maps to 9057 (SLC7A6), a y+LAT2 tran...         NaN
# r2070         100760403 maps to 9057 (SLC7A6), a y+LAT2 tran...         NaN
# r2071         100760403 maps to 9057 (SLC7A6), a y+LAT2 tran...         NaN
# r2404         According to PMID: 14598172, SLC25A2 and A15 h...         NaN
# r2408         According to PMID: 14598172, SLC25A2 has this ...         NaN
#
# [10810 rows x 20 columns]
