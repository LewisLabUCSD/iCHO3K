# %% [markdown]
# #### Libraries

# %%
import pandas as pd
import numpy as np

from bs4 import BeautifulSoup
from requests_html import HTMLSession

from tqdm.notebook import tqdm

# %%
#Read excel files and create the dfs
camel_df = pd.read_excel('../Data/1-s2.0-S1096717618302258-mmc1.xlsx', header = 1)
hefzi_df = pd.read_excel('../Data/hefzi_final.xlsx')
fouladiha_df = pd.read_excel('../Data/10529_2020_3021_MOESM1_ESM.xlsx', 'Supplementary Table 10', header = 1)
iCHO2291 = pd.read_excel('../Data/iCHO2291_final.xlsx')

# %%
#Standarization of the columns names
camel_df.rename(columns = {'Reaction ID':'Reaction', 'Initial reaction in model':'Reaction Formula', 'Reaction name':'Reaction Name', 'Justification':'Curation Notes'}, inplace = True)
fouladiha_df.rename(columns = {'Abbreviation':'Reaction', 'Description':'Reaction Name', 'Reaction':'Reaction Formula'}, inplace = True)

# Addition of tag columns
camel_df.insert(loc=0, column='cam', value='X')
camel_df.insert(loc=1, column='hef', value=np.nan)
camel_df.insert(loc=2, column='fou', value=np.nan)
camel_df.insert(loc=3, column='yeo', value=np.nan)

hefzi_df.insert(loc=0, column='cam', value=np.nan)
hefzi_df.insert(loc=1, column='hef', value='X')
hefzi_df.insert(loc=2, column='fou', value=np.nan)
hefzi_df.insert(loc=3, column='yeo', value=np.nan)

fouladiha_df.insert(loc=0, column='cam', value=np.nan)
fouladiha_df.insert(loc=1, column='hef', value=np.nan)
fouladiha_df.insert(loc=2, column='fou', value='X')
fouladiha_df.insert(loc=3, column='yeo', value=np.nan)

iCHO2291.insert(loc=0, column='cam', value=np.nan)
iCHO2291.insert(loc=1, column='hef', value=np.nan)
iCHO2291.insert(loc=2, column='fou', value=np.nan)
iCHO2291.insert(loc=3, column='yeo', value='X')


fouladiha_df
# Out:
#       cam  hef fou  yeo     Reaction  \
# 0     NaN  NaN   X  NaN    COKECBESr
# 1     NaN  NaN   X  NaN      EGMESTr
# 2     NaN  NaN   X  NaN     NMPTRCOX
# 3     NaN  NaN   X  NaN        PRO1x
# 4     NaN  NaN   X  NaN        DHDDH
# ...   ...  ...  ..  ...          ...
# 7431  NaN  NaN   X  NaN  SameRxns163
# 7432  NaN  NaN   X  NaN  SameRxns164
# 7433  NaN  NaN   X  NaN  SameRxns165
# 7434  NaN  NaN   X  NaN  SameRxns166
# 7435  NaN  NaN   X  NaN  SameRxns167
#
#                                           Reaction Name  \
# 0                       Carboxylesterase (cocaine) (er)
# 1                         ecgonine methyl esterase (ER)
# 2     N-Methylputrescine:oxygen oxidoreductase (deam...
# 3                        L-ProlineNAD+ 5-oxidoreductase
# 4                             Dihydrodiol dehydrogenase
# ...                                                 ...
# 7431                                        SameRxns163
# 7432                                        SameRxns164
# 7433                                        SameRxns165
# 7434                                        SameRxns166
# 7435                                        SameRxns167
#
#                                        Reaction Formula  \
# 0          coke[r] + h2o[r]  => bz[r] + egme[r] + h[r]
# 1       h2o[r] + egme[r]  => h[r] + ecgon[r] + meoh[r]
# 2     nmptrc[c] + o2[c]  => nh4[c] + 1mpyr[c] + h2o2...
# 3     pro_L[c] + nad[c]  => 2 h[c] + 1pyr5c[c] + nad...
# 4       nadp[c] + dhnpthld[c]  => npthld[c] + nadph[c]
# ...                                                 ...
# 7431                               nadph[c] => nadph[n]
# 7432                                 nadp[n] => nadp[c]
# 7433                                  atp[g] <=> atp[e]
# 7434                           retinol[e] => retinol[r]
# 7435                           cmpacna[g] => cmpacna[c]
#
#                                                     GPR  Genes  Protein  \
# 0                            (100756666) or (100767789)    NaN      NaN
# 1     (100771815) or (100751803) or (100752322) or (...    NaN      NaN
# 2     (100771382) or (100762635) or (100762926) or (...    NaN      NaN
# 3                                           (100773901)    NaN      NaN
# 4                                           (100753544)    NaN      NaN
# ...                                                 ...    ...      ...
# 7431                                                NaN    NaN      NaN
# 7432                                                NaN    NaN      NaN
# 7433                                                NaN    NaN      NaN
# 7434                                                NaN    NaN      NaN
# 7435                                                NaN    NaN      NaN
#
#                              Subsystem  Reversible  Lower bound  Upper bound  \
# 0                   ALKALOID SYNTHESIS           0          0.0         1000
# 1                   ALKALOID SYNTHESIS           0          0.0         1000
# 2                   ALKALOID SYNTHESIS           0          0.0         1000
# 3      ARGININE AND PROLINE METABOLISM           0          0.0         1000
# 4                       CYP METABOLISM           0          0.0         1000
# ...                                ...         ...          ...          ...
# 7431                TRANSPORT, NUCLEAR           0          0.0         1000
# 7432                TRANSPORT, NUCLEAR           0          0.0         1000
# 7433        TRANSPORT, GOLGI APPARATUS           1      -1000.0         1000
# 7434  TRANSPORT, ENDOPLASMIC RETICULAR           0          0.0         1000
# 7435        TRANSPORT, GOLGI APPARATUS           0          0.0         1000
#
#       Objective
# 0             0
# 1             0
# 2             0
# 3             0
# 4             0
# ...         ...
# 7431          0
# 7432          0
# 7433          0
# 7434          0
# 7435          0
#
# [7436 rows x 15 columns]

# %%
cols = hefzi_df.columns.to_list()+fouladiha_df.columns.to_list()+iCHO2291.columns.to_list()+camel_df.columns.to_list()

# Eliminate repetitive values in the 'cols' list
cols = [cols[i] for i in range(len(cols)) if i == cols.index(cols[i])]

cols
# Out:
# ['cam',
#  'hef',
#  'fou',
#  'yeo',
#  'Reaction',
#  'Reaction Name',
#  'Reaction Formula',
#  'GPR',
#  'Subsystem',
#  'Lower bound',
#  'Upper bound',
#  'Curation Notes',
#  'References',
#  'Genes',
#  'Protein',
#  'Reversible',
#  'Objective',
#  'Proteins',
#  'EC Number',
#  'Mol wt',
#  'kcat_forward',
#  'kcat_backward',
#  'Reaction ID Camels Models']

# %%
def add_col(df):
    '''
    This function adds the remaining columns from the cols list 
    to an existing df that are not contained in such df
    '''
    df.columns
    add_col = []
    for col in cols:
        if col not in df.columns:
            add_col.append(col)
    df = df.reindex(columns = df.columns.tolist() + add_col)
    return df

# %%
# Unify columns for all datasets
hefzi_df = add_col(hefzi_df)
fouladiha_df = add_col(fouladiha_df)
iCHO2291 = add_col(iCHO2291)
camel_df = add_col(camel_df)

iCHO2291
# Out:
#       cam  hef  fou yeo          Reaction  \
# 0     NaN  NaN  NaN   X      10FTHF5GLUtl
# 1     NaN  NaN  NaN   X      10FTHF5GLUtm
# 2     NaN  NaN  NaN   X      10FTHF6GLUtl
# 3     NaN  NaN  NaN   X      10FTHF6GLUtm
# 4     NaN  NaN  NaN   X      10FTHF7GLUtl
# ...   ...  ...  ...  ..               ...
# 6231  NaN  NaN  NaN   X            igg_hc
# 6232  NaN  NaN  NaN   X            igg_lc
# 6233  NaN  NaN  NaN   X  peplys_synthesis
# 6234  NaN  NaN  NaN   X           q10h2tc
# 6235  NaN  NaN  NaN   X             q10tm
#
#                                    Reaction Name  \
# 0         5-glutamyl-10FTHF transport, lysosomal
# 1     5-glutamyl-10FTHF transport, mitochondrial
# 2         6-glutamyl-10FTHF transport, lysosomal
# 3     6-glutamyl-10FTHF transport, mitochondrial
# 4         7-glutamyl-10FTHF transport, lysosomal
# ...                                          ...
# 6231                                      igg_hc
# 6232                                      igg_lc
# 6233                            peplys synthesis
# 6234         transport of ubiquinol into cytosol
# 6235   transport of ubiquinone into mitochondria
#
#                                        Reaction Formula  GPR      Subsystem  \
# 0                       10fthf5glu[c] --> 10fthf5glu[l]  NaN      Transport
# 1                       10fthf5glu[m] --> 10fthf5glu[c]  NaN      Transport
# 2                       10fthf6glu[c] --> 10fthf6glu[l]  NaN      Transport
# 3                       10fthf6glu[m] --> 10fthf6glu[c]  NaN      Transport
# 4                       10fthf7glu[c] --> 10fthf7glu[l]  NaN      Transport
# ...                                                 ...  ...            ...
# 6231  24.0 ala_L[c] + 8.0 arg_L[c] + 19.0 asn_L[c] +...  NaN  Miscellaneous
# 6232  15.0 ala_L[c] + 6.0 arg_L[c] + 7.0 asn_L[c] + ...  NaN  Miscellaneous
# 6233                             lys_L[n] --> peplys[n]  NaN  Miscellaneous
# 6234                              q10h2[m] <=> q10h2[c]  NaN      Transport
# 6235                                  q10[c] <=> q10[m]  NaN      Transport
#
#       Lower bound  ...  Mol wt kcat_forward kcat_backward  Curation Notes  \
# 0             0.0  ...     NaN          NaN           NaN             NaN
# 1             0.0  ...     NaN          NaN           NaN             NaN
# 2             0.0  ...     NaN          NaN           NaN             NaN
# 3             0.0  ...     NaN          NaN           NaN             NaN
# 4             0.0  ...     NaN          NaN           NaN             NaN
# ...           ...  ...     ...          ...           ...             ...
# 6231          0.0  ...     NaN          NaN           NaN             NaN
# 6232          0.0  ...     NaN          NaN           NaN             NaN
# 6233          0.0  ...     NaN          NaN           NaN             NaN
# 6234      -1000.0  ...     NaN          NaN           NaN             NaN
# 6235      -1000.0  ...     NaN          NaN           NaN             NaN
#
#       References  Genes  Protein  Reversible  Objective  \
# 0            NaN    NaN      NaN         NaN        NaN
# 1            NaN    NaN      NaN         NaN        NaN
# 2            NaN    NaN      NaN         NaN        NaN
# 3            NaN    NaN      NaN         NaN        NaN
# 4            NaN    NaN      NaN         NaN        NaN
# ...          ...    ...      ...         ...        ...
# 6231         NaN    NaN      NaN         NaN        NaN
# 6232         NaN    NaN      NaN         NaN        NaN
# 6233         NaN    NaN      NaN         NaN        NaN
# 6234         NaN    NaN      NaN         NaN        NaN
# 6235         NaN    NaN      NaN         NaN        NaN
#
#       Reaction ID Camels Models
# 0                           NaN
# 1                           NaN
# 2                           NaN
# 3                           NaN
# 4                           NaN
# ...                         ...
# 6231                        NaN
# 6232                        NaN
# 6233                        NaN
# 6234                        NaN
# 6235                        NaN
#
# [6236 rows x 23 columns]

# %%
# Reorder columns in all datasets the same way
fouladiha_df = fouladiha_df[['cam','hef', 'fou', 'yeo', 'Reaction', 'Reaction Name', 'Reaction Formula', 'GPR', 'Subsystem', 'Genes', 'Protein', 'EC Number', 'Mol wt', 'kcat_forward', 'kcat_backward', 'Reversible','Lower bound', 'Upper bound', 'Objective', 'Curation Notes', 'References', 'Reaction ID Camels Models']]
iCHO2291 = iCHO2291[['cam','hef', 'fou', 'yeo', 'Reaction', 'Reaction Name', 'Reaction Formula', 'GPR', 'Subsystem', 'Genes', 'Protein', 'EC Number', 'Mol wt', 'kcat_forward', 'kcat_backward', 'Reversible','Lower bound', 'Upper bound', 'Objective', 'Curation Notes', 'References', 'Reaction ID Camels Models']]
hefzi_df = hefzi_df[['cam','hef', 'fou', 'yeo', 'Reaction', 'Reaction Name', 'Reaction Formula', 'GPR', 'Subsystem', 'Genes', 'Protein', 'EC Number', 'Mol wt', 'kcat_forward', 'kcat_backward', 'Reversible','Lower bound', 'Upper bound', 'Objective', 'Curation Notes', 'References', 'Reaction ID Camels Models']]
camel_df = camel_df[['cam','hef', 'fou', 'yeo', 'Reaction', 'Reaction Name', 'Reaction Formula', 'GPR', 'Subsystem', 'Genes', 'Protein', 'EC Number', 'Mol wt', 'kcat_forward', 'kcat_backward', 'Reversible','Lower bound', 'Upper bound', 'Objective', 'Curation Notes', 'References', 'Reaction ID Camels Models']]

camel_df['Reaction'] = camel_df['Reaction'].str.strip()

# %%
# Merge all the df into a unified df
all_dfs = pd.concat([camel_df, hefzi_df, fouladiha_df, iCHO2291])
all_dfs = all_dfs.reset_index(drop = True)
all_dfs['Reaction'] = all_dfs['Reaction'].str.replace('_cho', '')

all_dfs #20940 rows/reactions (many of them repeated)
# Out:
#        cam  hef  fou  yeo          Reaction  \
# 0        X  NaN  NaN  NaN            GLCt1r
# 1        X  NaN  NaN  NaN            GLCt2r
# 2        X  NaN  NaN  NaN           GLCt2_2
# 3        X  NaN  NaN  NaN           RE1342C
# 4        X  NaN  NaN  NaN             FRUt4
# ...    ...  ...  ...  ...               ...
# 20935  NaN  NaN  NaN    X            igg_hc
# 20936  NaN  NaN  NaN    X            igg_lc
# 20937  NaN  NaN  NaN    X  peplys_synthesis
# 20938  NaN  NaN  NaN    X           q10h2tc
# 20939  NaN  NaN  NaN    X             q10tm
#
#                                      Reaction Name  \
# 0                      glucose transport (uniport)
# 1        D-glucose transport in via proton symport
# 2        D-glucose transport in via proton symport
# 3                                           RE1342
# 4      D-fructose transport via sodium cotransport
# ...                                            ...
# 20935                                       igg_hc
# 20936                                       igg_lc
# 20937                             peplys synthesis
# 20938          transport of ubiquinol into cytosol
# 20939    transport of ubiquinone into mitochondria
#
#                                         Reaction Formula  GPR      Subsystem  \
# 0                                    glc_D_e --> glc_D_c  NaN            NaN
# 1                        glc_D_e + h_e --> glc_D_c + h_c  NaN            NaN
# 2                glc_D_e + 2.0 h_e --> glc_D_c + 2.0 h_c  NaN            NaN
# 3             nad_c + sbt_D_c --> glc_D_c + h_c + nadh_c  NaN            NaN
# 4                        fru_e + na1_e --> fru_c + na1_c  NaN            NaN
# ...                                                  ...  ...            ...
# 20935  24.0 ala_L[c] + 8.0 arg_L[c] + 19.0 asn_L[c] +...  NaN  Miscellaneous
# 20936  15.0 ala_L[c] + 6.0 arg_L[c] + 7.0 asn_L[c] + ...  NaN  Miscellaneous
# 20937                             lys_L[n] --> peplys[n]  NaN  Miscellaneous
# 20938                              q10h2[m] <=> q10h2[c]  NaN      Transport
# 20939                                  q10[c] <=> q10[m]  NaN      Transport
#
#        Genes  ...  Mol wt kcat_forward  kcat_backward  Reversible  \
# 0        NaN  ...     NaN          NaN            NaN         NaN
# 1        NaN  ...     NaN          NaN            NaN         NaN
# 2        NaN  ...     NaN          NaN            NaN         NaN
# 3        NaN  ...     NaN          NaN            NaN         NaN
# 4        NaN  ...     NaN          NaN            NaN         NaN
# ...      ...  ...     ...          ...            ...         ...
# 20935    NaN  ...     NaN          NaN            NaN         NaN
# 20936    NaN  ...     NaN          NaN            NaN         NaN
# 20937    NaN  ...     NaN          NaN            NaN         NaN
# 20938    NaN  ...     NaN          NaN            NaN         NaN
# 20939    NaN  ...     NaN          NaN            NaN         NaN
#
#        Lower bound  Upper bound  Objective              Curation Notes  \
# 0              0.0          NaN        NaN  Unidrectional transporters
# 1              0.0          NaN        NaN  Unidrectional transporters
# 2              0.0          NaN        NaN  Unidrectional transporters
# 3              0.0          NaN        NaN  Unidrectional transporters
# 4              0.0          NaN        NaN  Unidrectional transporters
# ...            ...          ...        ...                         ...
# 20935          0.0         1000        NaN                         NaN
# 20936          0.0         1000        NaN                         NaN
# 20937          0.0         1000        NaN                         NaN
# 20938      -1000.0         1000        NaN                         NaN
# 20939      -1000.0         1000        NaN                         NaN
#
#        References Reaction ID Camels Models
# 0             NaN                       NaN
# 1             NaN                       NaN
# 2             NaN                       NaN
# 3             NaN                       NaN
# 4             NaN                       NaN
# ...           ...                       ...
# 20935         NaN                       NaN
# 20936         NaN                       NaN
# 20937         NaN                       NaN
# 20938         NaN                       NaN
# 20939         NaN                       NaN
#
# [20940 rows x 22 columns]

# %%
#def f(x):
#    d = {}
#    
#    l = []
#    for x in x['GPR']:
#        l.append(x)
#    
#    if len(set(l)) == 1:
#        print('no')
#    elif len(set(l)) > 1:
#        print(l)
#        print(l)
#        if x == x[x+1]:
#            print(x)
#    d['GPR'] = x['GPR'].apply(lambda x: x if len(x.unique()>1))
#    d['a_max'] = x['a'].max()
#    d['b_mean'] = x['b'].mean()
#    d['c_d_prodsum'] = (x['c'] * x['d']).sum()  
#    return pd.Series(d, index=['GPR'])#, 'a_max', 'b_mean', 'c_d_prodsum'])

# all_dfs1 = all_dfs.groupby(['Reaction'], group_keys=True).apply(lambda x: f(x))
# Out:
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# ['100762926 or 100771382 or 100762635 or 100763954', '(100762926) or (100771382) or (100762635) or (100763954)', '100762926 or 100771382 or 100762635 or 100763954']
# no
# no
# no
# no
# no
# no
# no
# no
# no
# [nan, nan, '100751280 or 100751853 or 100773278']
# [nan, nan, '100751280 or 100751853 or 100773278']
# [nan, nan, '100751280 or 100751853 or 100773278']
# [nan, nan, '100751280 or 100751853 or 100773278']
# no
# no
# no
# no
# no
# no
# ['100751280 and 100751853 and 100773278', '(100751280 and 100751853 and 100773278)', '100751280 or 100751853 or 100773278']
# ['100751280 and 100751853 and 100773278', '(100751280 and 100751853 and 100773278)', '100751280 or 100751853 or 100773278']
# no
# no
# no
# no
# [nan, nan, '100751280 or 100751853 or 100773278']
# [nan, nan, '100763450 or 100772030']
# no
# ['100760414 and 100751853 and 100773278', '(100760414 and 100751853 and 100773278)', '100751280 or 100751853 or 100773278']
# ['100760414 and 100751853 and 100773278', '(100760414 and 100751853 and 100773278)', '100751280 or 100751853 or 100773278']
# ['100769224 or 100768948', '(100769224) or (100768948)', '100769224 or 100768948']
# no
# ['100756680', '(100756680)', '100756680']
# no
# no
# no
# no
# no
# no
# no
# no
# no
# ['100689064 or 100770347 or 100751959 or 100769710 or 100770821 or 100751672', '(100689064) or (100770347) or (100751959) or (100769710) or (100770821) or (100751672)', '100689064 or 100770347 or 100751959 or 100769710 or 100770821 or 100751672']
# no
# no
# no
# ['100768407 or 100775004 or 100772122 or 100756769', '(100768407) or (100775004) or (100772122) or (100756769)', '100768407 or 100775004 or 100772122 or 100756769 or 100752961']
# ['100763623 or 100771517', '(100763623) or (100771517)']
# no
# [nan, nan, '100761641']
# no
# no
# no
# no
# no
# no
# no
# no
# no
# ['(100764862 and 100758466 and 100689437) or (100769436 and 100758466 and 100689437) or (100753689 and 100758466 and 100689437)', '(100764862) and (100758466) and (100689437) or (100769436) and (100758466) and (100689437) or (100753689) and (100758466) and (100689437)']
# no
# ['100756680', '(100756680)', '100756680']
# no
# no
# no
# no
# no
# no
# no
# no
# ['100760081 or 100767633 or 100767929 or 100759594 or 100767061 or 100759210', '(100760081) or (100767633) or (100767929) or (100759594) or (100767061) or (100759210)', '100760081 or 100767633 or 100767929 or 100759594 or 100767061 or 100759210']
# no
# no
# ['100770626', '(100770626)', '100770626']
# no
# ['100774015', '(100774015)', '100774015']
# ['100768227 or 100763332 or 100756470 or 100757371 or 100755596', '(100768227) or (100763332) or (100756470) or (100757371) or (100755596)', '100768227 or 100763332 or 100756470 or 100757371 or 100755596']
# ['100763332 or 100756470 or 100757371 or 100755596', '(100763332) or (100756470) or (100757371) or (100755596)']
# no
# ['100763332 or 100755596 or 100756470 or 100757371 or 100768227', '(100763332) or (100755596) or (100756470) or (100757371) or (100768227)', '100763332 or 100755596 or 100756470 or 100757371 or 100768227']
# ['100763332 or 100755596 or 100756470 or 100757371', '(100763332) or (100755596) or (100756470) or (100757371)']
# no
# no
# ['100768220', '(100768220)', '100768220']
# no
# no
# ['100765485', '(100765485)', '100765485']
# no
# no
# no
# no
# no
# [nan, nan, '100751162']
# [nan, nan, '100751162']
# ['100774578', '(100774578)', '100774578']
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# ['100759566', '(100759566)', '100759566']
# no
# no
# no
# no
# no
# ['100757273', '(100757273)']
# ['100759780', '(100759780)', '100759780']
# no
# no
# ['100763623', '(100763623)', '100763623']
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# ['100769821', '(100769821)', '100769821']
# ['100762838 or 100771752 or 100771070 or 100769821', '(100762838) or (100771752) or (100771070) or (100769821)']
# ['100761742', '(100761742)', '100761742']
# no
# no
# no
# no
# no
# no
# ['100761742', '(100761742)', '100761742']
# ['100760815 or 100759648', '(100760815) or (100759648)', '100760815 or 100759648']
# no
# no
# no
# ['100768227 or 100763332 or 100756470 or 100757371 or 100755596', '(100768227) or (100763332) or (100756470) or (100757371) or (100755596)', '100768227 or 100763332 or 100756470 or 100757371 or 100755596']
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# ['100768227 or 100763332 or 100756470 or 100757371 or 100755596', '(100768227) or (100763332) or (100756470) or (100757371) or (100755596)', '100768227 or 100763332 or 100756470 or 100757371 or 100755596']
# ['100763332 or 100755596 or 100756470 or 100757371', '(100763332) or (100755596) or (100756470) or (100757371)']
# no
# no
# ['100760815 or 100759648', '(100760815) or (100759648)', '100760815 or 100759648']
# no
# ['100756404', '(100756404)', '100756404 or 100757346']
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# ['100766212 or 100768097', '(100766212) or (100768097)', '100766212 or 100768097']
# ['100751520', '(100751520)', '100751520']
# no
# ['100762297', '(100762297)', '100762297']
# ['100762838', '(100762838)', '100762838']
# no
# no
# no
# ['100760815 or 100759648', '(100760815) or (100759648)', '100760815 or 100759648']
# ['100760815 or 100759648', '(100760815) or (100759648)', '100760815 or 100759648']
# ['100762926 or 100771382 or 100762635 or 100759648 or 100760815', '(100762926) or (100771382) or (100762635) or (100759648) or (100760815)', '100762926 or 100771382 or 100762635 or 100759648 or 100760815']
# no
# no
# no
# no
# no
# no
# no
# no
# ['100764994', '(100764994)', '100764994']
# ['100768227 or 100763332 or 100756470 or 100757371 or 100755596', '(100768227) or (100763332) or (100756470) or (100757371) or (100755596)', '100768227 or 100763332 or 100756470 or 100757371 or 100755596']
# ['100768227 or 100763332 or 100756470 or 100757371 or 100755596', '(100768227) or (100763332) or (100756470) or (100757371) or (100755596)']
# no
# no
# ['100689351', '(100689351)', '100689351']
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# ['100769643 or 100764411 or 100759668 or 100759957 or 100773186', '(100769643) or (100764411) or (100759668) or (100759957) or (100773186)', '100769643 or 100764411 or 100759668 or 100759957 or 100773186']
# no
# no
# no
# no
# no
# no
# no
# no
# no
# ['100689208', '(100689208)', '100689208']
# no
# ['100753164 or 100751624 or 100751331 or 100751913', '(100753164) or (100751624) or (100751331) or (100751913)', '100753164 or 100751624 or 100751331 or 100751913']
# no
# no
# no
# [nan, nan, '100757130']
# no
# no
# ['100689407', '(100689407)', '100689407']
# no
# no
# no
# no
# ['100761742', '(100761742)', '100761742']
# no
# ['100759157 or 100760212 or 100765484 or 100765774 or 100760504', '(100759157) or (100760212) or (100765484) or (100765774) or (100760504)', '100759157 or 100760212 or 100765484 or 100765774 or 100760504']
# ['100756509 or 100757658 or 100765516', '(100756509) or (100757658) or (100765516)', '100756509 or 100757658 or 100765516']
# ['100765516 or 100764994 or 100772225 or 100756509 or 100757658 or 100758951', '(100765516) or (100764994) or (100772225) or (100756509) or (100757658) or (100758951)']
# ['100760815 or 100759648', '(100760815) or (100759648)', '100760815 or 100759648']
# ['100754111 or 100754402', '(100754111) or (100754402)', '100754111 or 100754402']
# ['100774860 or 100755842', '(100774860) or (100755842)', '100774860 or 100755842']
# ['100761742', '(100761742)', '100761742']
# ['100760815 or 100759648', '(100760815) or (100759648)', '100760815 or 100759648']
# no
# no
# no
# no
# ['100689330', '(100689330)', '100689330']
# ['100689407', '(100689407)', '100689407']
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# ['100770462', '(100770462)']
# ['100770462', '(100770462)', '100770462']
# ['100771969', '(100771969)', '100771969']
# ['100771969', '(100771969)', '100771969']
# no
# no
# ['100750893', '(100750893)', '100750893']
# no
# ['100762926 or 100762635 or 100759648 or 100760815', '(100762926) or (100762635) or (100759648) or (100760815)', '100762926 or 100759648 or 100759648 or 100760815']
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# ['100756509', '(100756509)', '100756509 or 100770305']
# [nan, '100756509', '(100756509)', '100756509']
# no
# ['100771752', '(100771752)', '100771752']
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# ['100772592', '(100772592)', '100772592']
# ['100772592', '(100772592)', '100772592']
# ['100772592', '(100772592)', '100772592']
# ['100772592', '(100772592)', '100772592']
# ['100772592', '(100772592)', '100772592']
# ['100772592', '(100772592)', '100772592']
# ['100772592', '(100772592)', '100772592']
# ['100772592', '(100772592)', '100772592']
# ['100772592', '(100772592)', '100772592']
# ['100765485', '(100765485)', '100765485']
# no
# no
# ['100758951 or 100761706 or 100768367 or 100768654', '(100758951) or (100761706) or (100768367) or (100768654)', '100758951 or 100761706 or 100768367 or 100768654']
# ['100772225', '(100772225)']
# ['100765800 or 100766093', '(100765800) or (100766093)', '100765800 or 100766093']
# ['100765800 or 100766093', '(100765800) or (100766093)']
# ['100752749 or 100760370 or 100752493 or 100752445', '(100752749) or (100760370) or (100752493) or (100752445)', '100752749 or 100760370 or 100752493 or 100752445']
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# ['100770936', '(100770936)', '100770936 or 103163371']
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# ['100760000', '(100760000)', '100760000 or 103163371']
# ['(100757947 and 100758239) or 100770936', '(100757947 and 100758239) or (100770936)', '(100757947 and 100758239) or 100770936 or 103163371']
# ['100770936', '(100770936)', '100770936 or 103163371']
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# ['100754813 or 100753943', '(100754813) or (100753943)']
# no
# ['100754813 or 100753943', '(100754813) or (100753943)']
# no
# no
# ['100754813 or 100753943', '(100754813) or (100753943)']
# no
# ['100754813 or 100753943', '(100754813) or (100753943)']
# no
# no
# no
# no
# ['100754813 or 100753943', '(100754813) or (100753943)']
# no
# ['100754813 or 100753943', '(100754813) or (100753943)']
# no
# no
# no
# ['100775004 or 100768407 or 100756769 or 100772122', '(100775004) or (100768407) or (100756769) or (100772122)', '100775004 or 100768407 or 100756769 or 100772122 or 100752961']
# ['100775004', '(100775004)', '100775004']
# no
# no
# no
# no
# no
# no
# no
# no
# ['100762904 or 100753124 or 100689225 or (100762904 and 100753124) or (100753124 and 100689225)', '(100762904) or (100753124) or (100689225) or (100762904 and 100753124) or (100753124 and 100689225)', '100762904 and 100753124']
# ['100753124', '(100753124)', '100753124']
# ['100752902', '(100752902)']
# no
# ['100769754 or 100772576', '(100769754) or (100772576)', '100769754 or 100772576']
# ['100756415', '(100756415)', '100756415']
# no
# ['100756415', '(100756415)', '100756415']
# ['100775004 or 100772122 or 100768407', '(100775004) or (100772122) or (100768407)', '100775004 or 100772122 or 100768407']
# ['100775004', '(100775004)', '100775004']
# no
# no
# no
# no
# no
# no
# no
# ['100752083', '(100752083)', '100752083']
# no
# no
# no
# ['100753186', '(100753186) or (100768545)', '100753186']
# ['100761974', '(100761974)', '100761974']
# ['100758117', '(100758117)', '100758117']
# ['100762575', '(100762575)', '100762575']
# no
# no
# no
# no
# no
# no
# no
# no
# ['100752487', '(100752487)', '100752487']
# ['100752620', '(100752620)', '100752620']
# ['100770679', '(100770679)', '100770679']
# ['100770013', '(100770013)', '100770013']
# no
# no
# ['100773325', '(100773325)', '100773325']
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# ['100767837', '(100767837)', '100767837']
# ['100767837', '(100767837)', '100767837']
# no
# ['100764540', '(100764540)', '100764540']
# ['100757887', '(100757887)', '100757887']
# no
# no
# no
# no
# ['100766218', '(100766218)', '100766218']
# no
# no
# no
# no
# no
# no
# no
# no
# no
# ['100766828 or 100774097 or 100763159', '(100766828) or (100774097) or (100763159)', '100766828 or 100774097 or 100763159']
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# ['100774097 or 100763159 or 100766828', '(100774097) or (100763159) or (100766828)', '100774097 or 100763159 or 100766828']
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# ['100759847 or 100763159', '(100759847) or (100763159)', '100759847 or 100763159']
# no
# ['100751213 or 100766828', '(100751213) or (100766828)', '100751213 or 100766828']
# no
# no
# no
# no
# no
# no
# ['100752768', '(100752768)', '100752768']
# no
# ['100689199', '(100689199)']
# no
# ['100689207', '(100689207)', '100689207']
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# ['100765707', '(100765707)', '100765707']
# ['100766024 or 100759203', '(100766024) or (100759203)']
# no
# no
# no
# no
# ['100759203', '(100759203)']
# no
# ['100766043', '(100766043)', '100766043']
# ['100766043', '(100766043)', '100766043']
# ['100773599 or 100763644', '(100773599) or (100763644)', '100773599 or 100763644']
# no
# no
# no
# ['100765000', '(100765000)', '100765000']
# ['100750893 or 100752902', '(100750893) or (100752902)']
# ['100752902 or 100750893', '(100752902) or (100750893)']
# ['100769754', '(100769754)', '100769754']
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# ['100765891', '(100765891)', '100765891']
# ['100765891', '(100765891)', '100765891']
# ['100758982 or 100755378', '(100758982) or (100755378)', '100758982 or 100755378']
# no
# ['100775004', '(100775004)', '100775004']
# ['100775004 or 100768407 or 100756769 or 100772122', '(100775004) or (100768407) or (100756769) or (100772122)', '100775004 or 100768407 or 100756769 or 100772122 or 100752961']
# [nan, nan, '100763738']
# ['100756254', '(100756254)', '100756254']
# ['100756254', '(100756254)', '100756254']
# no
# ['100761966 or 100754792', '(100761966) or (100754792)', '100761966 or 100754792']
# ['100767453', '(100767453)', '100767453']
# no
# ['100758717 or 100759346 or 100761703 or 100760489 or 100767050 or 100752880 or 100774576', '(100758717) or (100759346) or (100761703) or (100760489) or (100767050) or (100752880) or (100774576)', '100758717 or 100759346 or 100761703 or 100760489 or 100767050 or 100752880 or 100774576']
# ['100756723 or 100760312 or 100774512 or 100755987', '(100756723) or (100760312) or (100774512) or (100755987)', '100756723 or 100760312 or 100774512 or 100755987']
# ['100761703 or 100760489 or 100767050', '(100761703) or (100760489) or (100767050)', '100761703 or 100760489 or 100767050']
# ['100760312', '(100760312)', '100760312']
# ['100758717', '(100758717)', '100758717']
# ['100774596', '(100774596)', '100774596 or 100769515']
# ['100764561 or 100773811 or 100770498 or 103158658 or 100768998 or 100765958 or 100768368 or 100756132 or 100751372 or 100767272 or 103162985', '(100764561) or (100773811) or (100770498) or (103158658) or (100768998) or (100765958) or (100768368) or (100756132) or (100751372) or (100767272) or (103162985)', '100764561 or 100773811 or 100770498 or 103158658 or 100768998 or 100765958 or 100768368 or 100756132 or 100751372 or 100767272 or 103162985']
# no
# ['100736551', '(100736551)', '100736551']
# no
# ['100736551', '(100736551)']
# no
# no
# ['100761966 or 100754792', '(100761966) or (100754792)', '100761966 or 100754792']
# ['100751684 or 100774101', '(100751684) or (100774101)', '100751684 or 100774101']
# ['100758335', '(100758335)', '100758335']
# ['100767453', '(100767453)', '100767453']
# ['100754792', '(100754792)', '100754792']
# no
# no
# no
# [nan, nan, '100750995']
# no
# no
# no
# ['100772118', '(100772118)', '100772118']
# ['100772118', '(100772118)', '100772118']
# no
# ['100772118 or 100767531', '(100772118) or (100767531)', '100772118 or 100767531']
# ['100766764', '(100766764) or (100761555)', '100766764']
# ['100773187', '(100773187)', '100773187']
# ['100765665', '(100765665)', '100765665']
# no
# [nan, nan, '100765307']
# no
# ['100767138 or 100770034 or 100762166', '(100767138) or (100770034) or (100762166)', '100767138 or 100770034 or 100762166']
# ['100766757', '(100766757)', '100766757']
# ['100765000', '(100765000)', '100765000']
# ['100755842 or 100774860', '(100755842) or (100774860)', '100755842 or 100774860']
# no
# ['100762413 or 100764888', '(100762413) or (100764888)']
# ['100762413 or 100764888', '(100762413) or (100764888)', '100762413 or 100764888']
# ['100762413 or 100764888', '(100762413) or (100764888)', '100762413 or 100764888']
# ['100689060', '(100689060)', '100689060']
# ['100689060', '(100689060)', '100689060']
# ['100767083 or 100751825', '(100767083) or (100751825)', '100767083 or 100751825']
# no
# ['100766691 or 100769077 or 100762253 or 100760456 or 100751193 or 100773213 or 103161689 or 103160327', '(100766691) or (100769077) or (100762253) or (100760456) or (100751193) or (100773213) or (103161689) or (103160327)', '100766691 or 100769077 or 100762253 or 100760456 or 100751193 or 100773213 or 103161689 or 103160327 or 103159649']
# ['100766691 or 100769077 or 100762253 or 100760456 or 100751193 or 100773213 or 103161689 or 103160327', '(100766691) or (100769077) or (100762253) or (100760456) or (100751193) or (100773213) or (103161689) or (103160327)', '100766691 or 100769077 or 100762253 or 100760456 or 100751193 or 100773213 or 103161689 or 103160327 or 103159649']
# ['100766691 or 100769077 or 100762253 or 100760456 or 100751193 or 100773213 or 103161689 or 103160327', '(100766691) or (100769077) or (100762253) or (100760456) or (100751193) or (100773213) or (103161689) or (103160327)', '100766691 or 100769077 or 100762253 or 100760456 or 100751193 or 100773213 or 103161689 or 103160327 or 103159649']
# ['100766691 or 100769077 or 100762253 or 100760456 or 100751193 or 100773213 or 103161689 or 103160327', '(100766691) or (100769077) or (100762253) or (100760456) or (100751193) or (100773213) or (103161689) or (103160327)', '100766691 or 100769077 or 100762253 or 100760456 or 100751193 or 100773213 or 103161689 or 103160327 or 103159649']
# ['100766691 or 100769077 or 100762253 or 100760456 or 100751193 or 100773213 or 103161689 or 103160327', '(100766691) or (100769077) or (100762253) or (100760456) or (100751193) or (100773213) or (103161689) or (103160327)', '100766691 or 100769077 or 100762253 or 100760456 or 100751193 or 100773213 or 103161689 or 103160327 or 103159649']
# ['100766691 or 100769077 or 100762253 or 100760456 or 100751193 or 100773213 or 103161689 or 103160327', '(100766691) or (100769077) or (100762253) or (100760456) or (100751193) or (100773213) or (103161689) or (103160327)', '100766691 or 100769077 or 100762253 or 100760456 or 100751193 or 100773213 or 103161689 or 103160327 or 103159649']
# ['100766691 or 100769077 or 100762253 or 100760456 or 100751193 or 100773213 or 103161689 or 103160327', '(100766691) or (100769077) or (100762253) or (100760456) or (100751193) or (100773213) or (103161689) or (103160327)', '100766691 or 100769077 or 100762253 or 100760456 or 100751193 or 100773213 or 103161689 or 103160327 or 103159649']
# ['100766691 or 100769077 or 100762253 or 100760456 or 100751193 or 100773213 or 103161689 or 103160327', '(100766691) or (100769077) or (100762253) or (100760456) or (100751193) or (100773213) or (103161689) or (103160327)', '100766691 or 100769077 or 100762253 or 100760456 or 100751193 or 100773213 or 103161689 or 103160327 or 103159649']
# ['100766691 or 100769077 or 100762253 or 100760456 or 100751193 or 100773213 or 103161689 or 103160327', '(100766691) or (100769077) or (100762253) or (100760456) or (100751193) or (100773213) or (103161689) or (103160327)', '100766691 or 100769077 or 100762253 or 100760456 or 100751193 or 100773213 or 103161689 or 103160327 or 103159649']
# ['100766691 or 100769077 or 100762253 or 100760456 or 100751193 or 100773213 or 103161689 or 103160327', '(100766691) or (100769077) or (100762253) or (100760456) or (100751193) or (100773213) or (103161689) or (103160327)', '100766691 or 100769077 or 100762253 or 100760456 or 100751193 or 100773213 or 103161689 or 103160327 or 103159649']
# ['100766691 or 100769077 or 100762253 or 100760456 or 100751193 or 100773213 or 103161689 or 103160327', '(100766691) or (100769077) or (100762253) or (100760456) or (100751193) or (100773213) or (103161689) or (103160327)', '100766691 or 100769077 or 100762253 or 100760456 or 100751193 or 100773213 or 103161689 or 103160327 or 103159649']
# ['100766691 or 100769077 or 100762253 or 100760456 or 100751193 or 100773213 or 103161689 or 103160327', '(100766691) or (100769077) or (100762253) or (100760456) or (100751193) or (100773213) or (103161689) or (103160327)', '100766691 or 100769077 or 100762253 or 100760456 or 100751193 or 100773213 or 103161689 or 103160327 or 103159649']
# ['100766691 or 100769077 or 100762253 or 100760456 or 100751193 or 100773213 or 103161689 or 103160327', '(100766691) or (100769077) or (100762253) or (100760456) or (100751193) or (100773213) or (103161689) or (103160327)', '100766691 or 100769077 or 100762253 or 100760456 or 100751193 or 100773213 or 103161689 or 103160327 or 103159649']
# ['100766691 or 100769077 or 100762253 or 100760456 or 100751193 or 100773213 or 103161689 or 103160327', '(100766691) or (100769077) or (100762253) or (100760456) or (100751193) or (100773213) or (103161689) or (103160327)', '100766691 or 100769077 or 100762253 or 100760456 or 100751193 or 100773213 or 103161689 or 103160327 or 103159649']
# ['100766691 or 100769077 or 100762253 or 100760456 or 100751193 or 100773213 or 103161689 or 103160327', '(100766691) or (100769077) or (100762253) or (100760456) or (100751193) or (100773213) or (103161689) or (103160327)', '100766691 or 100769077 or 100762253 or 100760456 or 100751193 or 100773213 or 103161689 or 103160327 or 103159649']
# ['100766691 or 100769077 or 100762253 or 100760456 or 100751193 or 100773213 or 103161689 or 103160327', '(100766691) or (100769077) or (100762253) or (100760456) or (100751193) or (100773213) or (103161689) or (103160327)', '100766691 or 100769077 or 100762253 or 100760456 or 100751193 or 100773213 or 103161689 or 103160327 or 103159649']
# ['100766691 or 100769077 or 100762253 or 100760456 or 100751193 or 100773213 or 103161689 or 103160327', '(100766691) or (100769077) or (100762253) or (100760456) or (100751193) or (100773213) or (103161689) or (103160327)', '100766691 or 100769077 or 100762253 or 100760456 or 100751193 or 100773213 or 103161689 or 103160327 or 103159649']
# ['100766691 or 100769077 or 100762253 or 100760456 or 100751193 or 100773213 or 103161689 or 103160327', '(100766691) or (100769077) or (100762253) or (100760456) or (100751193) or (100773213) or (103161689) or (103160327)', '100766691 or 100769077 or 100762253 or 100760456 or 100751193 or 100773213 or 103161689 or 103160327 or 103159649']
# ['100771907', '(100771907)', '100771907']
# no
# no
# no
# no
# [nan, nan, '100773070']
# no
# [nan, nan, '100773070']
# no
# no
# [nan, nan, '100758206']
# no
# ['100752066', '(100752066)', '100752066']
# ['100758206 or 100751939 or 100761743 or 100757875 or 100763383', '(100758206) or (100751939) or (100761743) or (100757875) or (100763383)', '100758206 or 100751939 or 100761743 or 100757875 or 100763383 or 100754963']
# no
# [nan, nan, '100755485']
# ['100756809', '(100756809)', '100756809']
# no
# ['100759906 or 100753688', '(100759906) or (100753688)', '100759906 or 100753688']
# ['100771278', '(100771278)', '100771278']
# [nan, nan, '100767825']
# ['100689208', '(100689208)', '100689208']
# no
# ['100750969 or 100767631 or 100754476', '(100750969) or (100767631) or (100754476)', '100750969 or 100767631 or 100754476']
# no
# no
# no
# no
# no
# no
# no
# no
# ['(100756663 or 100756951 or 100766960) or 100750552 or (100750552 and (100756663 or 100756951 or 100766960))', '((100756663 or 100756951 or 100766960)) or (100750552) or (100750552 and (100756663 or 100756951 or 100766960))', '100756663 or 100756951 or 100766960 or 100750552 or 100773287']
# ['(100756663 or 100756951 or 100766960) or 100750552 or (100750552 and (100756663 or 100756951 or 100766960))', '((100756663 or 100756951 or 100766960)) or (100750552) or (100750552 and (100756663 or 100756951 or 100766960))', '100756663 or 100756951 or 100766960 or 100750552 or 100773287']
# no
# no
# no
# ['100750895', '(100750895)', '100750895']
# no
# ['100758991', '(100758991)', '100758991']
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# ['100689437 and 100758466 and (100764862 or 100769436)', '(100689437 and 100758466 and (100764862 or 100769436))']
# no
# no
# no
# no
# no
# ['100770598', '(100770598)', '100770598 or 100766192']
# no
# no
# no
# no
# no
# ['100750672', '(100750672)', '100750672']
# no
# ['100770100', '(100770100) or (100768666)', '100770100']
# ['100770100', '(100770100)', '100770100']
# ['100770100', '(100770100)', '100770100']
# ['100770348', '(100770348)', '100770348']
# ['100770348', '(100770348)', '100770348']
# [nan, nan, '100761203 or 100760626']
# [nan, nan, '100760826']
# ['100763902', '(100763902)', '100763902']
# [nan, nan, '100751194']
# no
# no
# ['100689351 or 100763902', '(100689351) or (100763902)', '100689351 or 100763902']
# ['100689315 and 100769905', '(100689315 and 100769905)', '100689315 and 100769905']
# ['100689315 and 100769905', '(100689315 and 100769905)', '100689315 and 100769905']
# ['100763902', '(100763902)', '100763902']
# ['100689315 and 100769905', '(100689315 and 100769905)', '100689315 and 100769905']
# ['100689315 and 100769905', '(100689315 and 100769905)', '100689315 and 100769905']
# no
# no
# no
# ['100689351 or 100763902', '(100689351) or (100763902)', '100689351 or 100763902']
# ['100753315 or 100752849 or 100766370', '(100753315) or (100752849) or (100766370)', '100753315 or 100752849 or 100766370']
# ['100760506 or 100768176', '(100760506) or (100768176)', '100760506']
# no
# ['100689351 or 100763902', '(100689351) or (100763902)', '100689351 or 100763902']
# no
# no
# no
# no
# no
# ['100765800 or 100766093', '(100765800) or (100766093)', '100765800 or 100766093']
# ['100765800 or 100766093', '(100765800) or (100766093)', '100765800 or 100766093']
# ['100769511 or 100689188 or 100769795 or 100751194 or 100758864 or 100769158 or 100762871 or 100762288', '(100769511) or (100689188) or (100769795) or (100751194) or (100758864) or (100769158) or (100762871) or (100762288)', '100769511 or 100689188 or 100769795 or 100751194 or 100758864 or 100769158 or 100762871 or 100762288 or 100762550']
# ['100767098 or 100754504', '(100767098) or (100754504)', '100767098 or 100754504']
# [nan, nan, '(100689315 and 100760403) or (100689315 and 100768258)']
# ['((100756617 or 100760081 or 100773005) and (100756617 or 100760081 or 100773005)) or 100759210 or 100767633', '((100756617 or 100760081 or 100773005) and (100756617 or 100760081 or 100773005)) or (100759210) or (100767633)', '100767633 or 100756617 or 100760081 or 100767061 or 100759210 or 100767929 or 100764101 or 100773005']
# no
# no
# ['100767633 or 100756617 or 100760081 or 100767061 or 100759210 or 100767929 or 100764101 or 100773005', '(100767633) or (100756617) or (100760081) or (100767061) or (100759210) or (100767929) or (100764101) or (100773005)', '100767633 or 100756617 or 100760081 or 100767061 or 100759210 or 100767929 or 100764101 or 100773005']
# ['100767633 or 100756617 or 100760081 or 100767061 or 100759210 or 100767929 or 100764101 or 100773005', '(100767633) or (100756617) or (100760081) or (100767061) or (100759210) or (100767929) or (100764101) or (100773005)', '100767633 or 100756617 or 100760081 or 100767061 or 100759210 or 100767929 or 100764101 or 100773005']
# ['100767633 or 100756617 or 100760081 or 100767061 or 100759210 or 100767929 or 100764101 or 100773005', '(100767633) or (100756617) or (100760081) or (100767061) or (100759210) or (100767929) or (100764101) or (100773005)', '100767633 or 100756617 or 100760081 or 100767061 or 100759210 or 100767929 or 100764101 or 100773005']
# ['100767633 or 100756617 or 100760081 or 100767061 or 100759210 or 100767929 or 100764101 or 100773005', '(100767633) or (100756617) or (100760081) or (100767061) or (100759210) or (100767929) or (100764101) or (100773005)', '100767633 or 100756617 or 100760081 or 100767061 or 100759210 or 100767929 or 100764101 or 100773005']
# ['100767061 or 100767633 or (100760081 and 100756617) or 100756617 or 100760081', '(100767061) or (100767633) or (100760081 and 100756617) or (100756617) or (100760081)', '100767061 or 100767633 or (100760081 and 100756617) or 100756617 or 100760081']
# ['100689106', '(100689106)', '100689106']
# no
# ['100768227 or 100755596 or 100761706 or 100768654 or 100757658 or 100757371 or 100768367 or 100756509 or 100758951 or 100763332 or 100772304 or 100756470 or 100751303', '(100768227) or (100755596) or (100761706) or (100768654) or (100757658) or (100757371) or (100768367) or (100756509) or (100758951) or (100763332) or (100772304) or (100756470) or (100751303)', '100768227 or 100755596 or 100761706 or 100768654 or 100757658 or 100757371 or 100768367 or 100756509 or 100758951 or 100763332 or 100772304 or 100756470 or 100751303']
# ['100768227 or 100755596 or 100757658 or 100757371 or 100763332 or 100756470', '(100768227) or (100755596) or (100757658) or (100757371) or (100763332) or (100756470)']
# no
# no
# no
# [nan, nan, '100756470 or 100757371 or 100756509 or 100772304 or 100757658 or 100763332 or 100772304 or 100755596 or 100761706 or 100768367 or 100768654 or 100772304 or 100758951 or 100768227']
# ['100765516 or 100772225', '(100765516) or (100772225)', '100765516 or 100772225']
# ['100757658', '(100757658)', '100757658']
# no
# ['100756470 or 100757371 or 100756509 or 100772304 or 100757658 or 100763332 or 100772304 or 100755596 or 100761706 or 100768367 or 100768654 or 100772304 or 100758951 or 100768227', '(100756470) or (100757371) or (100756509) or (100772304) or (100757658) or (100763332) or (100772304) or (100755596) or (100761706) or (100768367) or (100768654) or (100772304) or (100758951) or (100768227)', '100756470 or 100757371 or 100756509 or 100772304 or 100757658 or 100763332 or 100772304 or 100755596 or 100761706 or 100768367 or 100768654 or 100772304 or 100758951 or 100768227']
# ['100765516 or 100772225', '(100765516) or (100772225)', '100765516 or 100772225']
# ['100772304 or 100757371 or 100757658 or 100763332 or 100758951 or 100755596 or 100756470', '(100772304) or (100757371) or (100757658) or (100763332) or (100758951) or (100755596) or (100756470)', '100772304 or 100757371 or 100757658 or 100763332 or 100758951 or 100755596 or 100756470']
# no
# no
# ['100751774 or 100771587 or 100751196', '(100751774) or (100771587) or (100751196)', '100751774 or 100771587 or 100751196 or 103159036 or 100750903']
# no
# ['100764620', '(100764620)', '100764620']
# ['100761707', '(100761707)', '100761707']
# ['100764916 or 100754473', '(100764916) or (100754473)', '100764916 or 100754473']
# ['100772492', '(100772492)', '100772492']
# ['100772492', '(100772492)', '100772492']
# no
# ['100751272', '(100751272)', '100751272']
# ['100751755 or 100751272 or 100689106', '(100751755) or (100751272) or (100689106)', '100751755 or 100751272 or 100689106']
# ['100751755 or 100751272 or 100689106', '(100751755) or (100751272) or (100689106)', '100751755 or 100751272 or 100689106']
# no
# ['100766043', '(100766043)', '100766043']
# no
# no
# no
# no
# no
# ['100758278', '(100758278)', '100758278']
# ['100689450 or 100758117', '(100689450) or (100758117)', '100689450 or 100758117']
# no
# no
# no
# no
# ['100769239', '(100769239)', '100769239']
# no
# no
# no
# no
# no
# ['100774910 or 100757901 or 100758386', '(100774910) or (100757901) or (100758386)', '100774910 or 100757901 or 100758386']
# no
# no
# no
# no
# ['100751632', '(100751632)', '100751632']
# ['100751632', '(100751632)', '100751632']
# no
# [nan, nan, '100765307']
# no
# ['100766318 or 100767001', '(100766318) or (100767001)', '100766318 or 100767001']
# ['100766318 or 100767001', '(100766318) or (100767001)', '100766318 or 100767001']
# no
# no
# ['100689208', '(100689208)', '100689208']
# no
# no
# no
# no
# no
# no
# ['100769146', '(100769146)', '100769146']
# ['100765485', '(100765485)', '100765485']
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# ['100760815 or 100759648', '(100760815) or (100759648)', '100760815 or 100759648']
# no
# ['100689318 or 100751272 or 100757262 or 100758120 or 100689318', '(100689318) or (100751272) or (100757262) or (100758120) or (100689318)', '100689318 or 100751272 or 100757262 or 100758120']
# no
# no
# no
# no
# ['100767138 or 100770034 or 100762166', '(100767138) or (100770034) or (100762166)', '100767138 or 100770034 or 100762166']
# ['100766757', '(100766757)', '100766757']
# ['100765000', '(100765000)', '100765000']
# no
# no
# no
# no
# no
# no
# no
# no
# [nan, nan, '100765567']
# no
# no
# [nan, nan, '100774950 or 100754190 or 100752129 or 100765865']
# no
# no
# no
# ['100765075', '(100765075)', '100754671']
# [nan, nan, '100751194']
# no
# no
# [nan, nan, '100774865']
# no
# no
# ['100689315 and 100760403', '(100689315 and 100760403)', '100689315 and 100760403']
# no
# ['100750727', '(100750727)', '100750727']
# ['100760459', '(100760459)', '100760459']
# no
# ['100756687', '(100756687)', '100756687']
# ['100762274', '(100762274)', '100762274']
# no
# no
# no
# no
# no
# ['100751194', '(100751194)', '100751194']
# ['100689176 or 100772617 or 100771829', '(100689176) or (100772617) or (100771829)', '100689176 or 100772617 or 100771829']
# no
# ['100773024 or 100758204', '(100773024) or (100758204)', '100773024 or 100758204']
# ['100767312', '(100767312)', '100767312']
# ['100754567', '(100754567)', '100754567']
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# ['100771068', '(100771068)', '100771068 or 100765841 or 100773997 or 100758912']
# no
# no
# no
# no
# ['100757803 or 100761922', '(100757803) or (100761922)', '100757803 or 100761922 or 100762656']
# no
# ['100763902', '(100763902)', '100763902']
# [nan, nan, '100751194']
# ['100763902', '(100763902)', '100763902']
# ['100763902', '(100763902)', '100763902']
# ['100754434', '(100754434)', '100754434']
# [nan, '100754434', '(100754434)', '100754434']
# ['100770731 and 100689315', '(100770731 and 100689315)', '100770731 and 100689315']
# ['100760225', '(100760225)', '100760225']
# ['100763902', '(100763902)', '100763902']
# ['100763902 or 100689351', '(100763902) or (100689351)', '100763902 or 100689351']
# no
# no
# no
# no
# no
# ['100769511 or 100689188 or 100769795 or 100751194 or 100758864 or 100769158 or 100762871 or 100762288', '(100769511) or (100689188) or (100769795) or (100751194) or (100758864) or (100769158) or (100762871) or (100762288)', '100769511 or 100689188 or 100769795 or 100751194 or 100758864 or 100769158 or 100762871 or 100762288']
# no
# ['100767098 or 100754504', '(100767098) or (100754504)', '100767098 or 100754504']
# no
# ['100765882 or 100757642', '(100765882) or (100757642)', '100765882 or 100757642']
# ['100689232', '(100689232)', '100689232']
# no
# no
# ['100760895 or 100767052 or 100770833 or 100752285 or 100689464', '(100760895) or (100767052) or (100770833) or (100752285) or (100689464)', '100760895 or 100767052 or 100770833 or 100752285 or 100689464']
# no
# ['100768097 or 100766212', '(100768097) or (100766212)', '100768097 or 100766212']
# ['100769399', '(100769399)', '100769399']
# ['100753207 or 100773063', '(100753207) or (100773063)', '100753207 or 100773063']
# ['100689351', '(100689351)', '100689351']
# ['100762297 or 100750547', '(100762297) or (100750547)', '100762297 or 100750547']
# ['100762838', '(100762838)', '100762838']
# no
# no
# no
# no
# no
# ['100760895 or 100752285 or 100689464 or 100770833 or 100767052', '(100760895) or (100752285) or (100689464) or (100770833) or (100767052)', '100760895 or 100752285 or 100689464 or 100770833 or 100767052']
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# ['100772668 or 100771642 or 100751454 or 100762593 or 100765414', '(100772668) or (100771642) or (100751454) or (100762593) or (100765414)', '100772668 or 100771642 or 100751454 or 100762593 or 100765414']
# ['100772668 or 100771642 or 100751454 or 100762593 or 100765414', '(100772668) or (100771642) or (100751454) or (100762593) or (100765414)', '100772668 or 100771642 or 100751454 or 100762593 or 100765414']
# no
# ['100770431 and 100763024 and (100760824 or 100766108 or 103162776) and 3979188 and 100774535 and (100772366 or 100771114 or 100752739 or 100754380) and 100771541 and 100766302 and 103160361 and (100757815 or 100769978) and 100756936 and 3979187', '(100770431) and (100763024) and (100760824 or 100766108 or 103162776) and (3979188) and (100774535) and (100772366 or 100771114 or 100752739 or 100754380) and (100771541) and (100766302) and (103160361) and (100757815 or 100769978) and (100756936) and (3979187)', '100770431 and 100763024 and 100760824 and 100766108 and 3979188 and 100774535 and (100772366 or 100771114 or 100752739 or 100754380) and 100771541 and 100766302 and 103160361 and (100757815 or 100769978) and 100756936 and 3979187 and 100770122 and 100754752 and 100768179 and 100770018 and 100762406 and 100768179']
# no
# ['((100769769 and 100754687 and 100772184 and 100769759 and 100758035) or (100769769 and 100754687 and 100772184 and 100769759 and 100762360) or (100754687 and 100772184 and 100769759 and 100756648 and 100758035) or (100754687 and 100772184 and 100769759 and 100756648 and 100762360) or (100754687 and 100772184 and 100769759 and 100769769 and 100758035) or (100754687 and 100772184 and 100769759 and 100755303 and 100762360) or (100754687 and 100772184 and 100769759 and 100758035 and 100769769) or (100754687 and 100772184 and 100769759 and 100762360 and 100766909) or (100754687 and 100772184 and 100769759 and 100755303 and 100758035) or (100754687 and 100772184 and 100769759 and 100769769 and 100762360) or (100754687 and 100772184 and 100769759 and 100758035 and 100766909) or (100754687 and 100772184 and 100769759 and 100762360 and 100769769) or (100754687 and 100772184 and 100769759 and 100755303 and 100758035) or (100754687 and 100772184 and 100769759 and 100755303 and 100762360)) and ((100762500 and 100752884 and 100755187 and 100763093 and 100768315 and 100754134 and 100774299 and 100774665) or (100762500 and 100752884 and 100763970 and 100763093 and 100756094 and 100765179 and 100754134 and 100768315) or (100762500 and 100754134 and 100752884 and 100765359 and 100765179 and 100768315 and 100774665 and 100773930) or (100762500 and 100752884 and 100763093 and 100765359 and 100768315 and 100765179 and 100754134 and 100774665) or (100762500 and 100752884 and 100765359 and 100754134 and 100755187 and 100773930 and 100768315 and 100774665) or (100762500 and 100754134 and 100752884 and 100765359 and 100755187 and 100768315 and 100773930 and 100774665) or (100762500 and 100754134 and 100752884 and 100763970 and 100755187 and 100756094 and 100768315 and 100773930) or (100762500 and 100752884 and 100763093 and 100765179 and 100763970 and 100754134 and 100768315 and 100774665) or (100762500 and 100752884 and 100763970 and 100755187 and 100756094 and 100768315 and 100754134 and 100773930) or (100762500 and 100752884 and 100754134 and 100755187 and 100763093 and 100765359 and 100756094 and 100768315) or (100762500 and 100752884 and 100765359 and 100773930 and 100768315 and 100765179 and 100754134 and 100774665) or (100762500 and 100754134 and 100752884 and 100768315 and 100765179 and 100774299 and 100773930 and 100774665) or (100762500 and 100754134 and 100752884 and 100765359 and 100763093 and 100756094 and 100765179 and 100768315) or (100762500 and 100752884 and 100765359 and 100756094 and 100755187 and 100773930 and 100768315 and 100754134) or (100762500 and 100752884 and 100765179 and 100763970 and 100754134 and 100768315 and 100774665 and 100773930) or (100762500 and 100754134 and 100752884 and 100765359 and 100765179 and 100773930 and 100768315 and 100774665) or (100762500 and 100752884 and 100754134 and 100755187 and 100756094 and 100768315 and 100763970 and 100773930) or (100762500 and 100754134 and 100752884 and 100765359 and 100755187 and 100773930 and 100756094 and 100768315) or (100762500 and 100752884 and 100755187 and 100768315 and 100754134 and 100763970 and 100773930 and 100774665) or (100762500 and 100754134 and 100752884 and 100765359 and 100756094 and 100765179 and 100773930 and 100768315) or (100762500 and 100752884 and 100765359 and 100765179 and 100754134 and 100768315 and 100774665 and 100773930) or (100762500 and 100754134 and 100752884 and 100756094 and 100768315 and 100765179 and 100774299 and 100773930) or (100762500 and 100754134 and 100752884 and 100765359 and 100756094 and 100765179 and 100773930 and 100768315) or (100762500 and 100752884 and 100763970 and 100763093 and 100756094 and 100768315 and 100765179 and 100754134) or (100762500 and 100752884 and 100763093 and 100756094 and 100765179 and 100763970 and 100754134 and 100768315) or (100762500 and 100752884 and 100765359 and 100756094 and 100754134 and 100755187 and 100768315 and 100773930) or (100762500 and 100754134 and 100752884 and 100763970 and 10075 ...
# no
# no
# ['100773145 or 100769087 or 100751779 or 100750759 or 100761654', '(100773145) or (100769087) or (100751779) or (100750759) or (100761654)', '100773145 or 100769087 or 100751779 or 100750759 or 100761654']
# no
# no
# [nan, nan, '100769790']
# no
# ['100761822', '(100761822)', '100761822']
# ['100766505', '(100766505)', '100766505 or 100770115']
# ['100754978', '(100754978)']
# no
# no
# ['100756438', '(100756438)', '100756438']
# ['100751197', '(100751197)', '100751197']
# ['100751197', '(100751197)', '100751197']
# ['100751197', '(100751197)', '100751197']
# ['100751197', '(100751197)', '100751197']
# ['100755714', '(100755714)', '100755714']
# ['100761765 or 100766715', '(100761765) or (100766715)', '100761765 or 100766715']
# ['100766691', '(100766691)', '100766691']
# ['100766691', '(100766691)', '100766691']
# ['100689430 or 100689434 or 100689346 or 100689435', '(100689430) or (100689434) or (100689346) or (100689435)', '100689430 or 100689434 or 100689346 or 100689435']
# ['100751197', '(100751197)', '100751197']
# ['100689430 or 100689346 or 100689435', '(100689430) or (100689346) or (100689435)', '100689430 or 100689346 or 100689435']
# ['100751197', '(100751197)', '100751197']
# ['100761765 or 100766715 or 100755714', '(100761765) or (100766715) or (100755714)', '100761765 or 100766715 or 100755714']
# ['100761765 or 100766715 or 100755714', '(100761765) or (100766715) or (100755714) or (100751243) or (100754814) or (100758336) or (100759864) or (100760173) or (100760260) or (100760325) or (100760696) or (100761532) or (100762273) or (100770484) or (100772214) or (100772511) or (100773968) or (103159649) or (107978234)', '100761765 or 100766715 or 100755714']
# no
# no
# no
# ['100774815 or 100760161 or 100764057', '(100774815) or (100760161) or (100764057)', '100774815 or 100760161 or 100764057']
# ['100689430 or 100689434 or 100689346 or 100689435', '(100689430) or (100689434) or (100689346) or (100689435)', '100689430 or 100689434 or 100689346 or 100689435']
# no
# ['100751197', '(100751197)', '100751197']
# ['100773213', '(100773213)', '100773213']
# ['100773213', '(100773213)', '100773213']
# ['100757919', '(100757919)', '100757919']
# ['100756252', '(100756252) or (100756541)']
# ['100756252', '(100756252)']
# ['100756252', '(100756252)']
# ['100756252', '(100756252)']
# ['100752840', '(100752840)', '100752840']
# ['100752840', '(100752840)', '100752840']
# [nan, nan, '100765478']
# no
# ['100760747', '(100760747)', '100760747']
# no
# ['100757658 or 100756509 or 100758951 or 100765516', '(100757658) or (100756509) or (100758951) or (100765516)', '100757658 or 100756509 or 100758951 or 100765516']
# ['100772225 or 100765516', '(100772225) or (100765516)']
# ['100759730', '(100759730)', '100759730']
# ['100760350', '(100760350)', '100760350 or 100774947']
# no
# no
# ['100774340 or 100766065', '(100774340) or (100766065)', '100774340 or 100766065']
# ['100773731', '(100773731)', '100773731']
# no
# ['100756509 or 100758951', '(100756509) or (100758951)', '100756509 or 100758951']
# ['100756509', '(100756509)', '100756509']
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# ['100754773 or 100754488', '(100754773) or (100754488)', '100754773 or 100754488']
# ['100774298', '(100774298)', '100774298']
# no
# ['100689220 or 100689208', '(100689220) or (100689208)', '100689220 or 100689208']
# no
# no
# ['100774298', '(100774298)', '100774298']
# no
# ['100689220 or 100689208', '(100689220) or (100689208)', '100689220 or 100689208']
# no
# ['100768929 or 100751522', '(100768929) or (100751522)', '100768929 or 100751522']
# ['100768929 or 100751522', '(100768929) or (100751522)', '100768929 or 100751522']
# ['100774298', '(100774298)', '100774298']
# no
# no
# no
# no
# ['100768002', '(100768002)', '100768002']
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# ['100774047', '(100774047)', '100774047']
# ['100774047', '(100774047)', '100774047']
# no
# ['100755324', '(100755324)', '100755324']
# ['100755324', '(100755324)', '100755324']
# ['100755324', '(100755324)', '100755324']
# ['100755324', '(100755324)', '100755324']
# ['100752840', '(100752840)', '100752840']
# ['100752840', '(100752840)', '100752840']
# no
# ['100775004', '(100775004)', '100775004']
# ['100775004', '(100775004)', '100775004']
# no
# ['100765026', '(100765026)', '100765026']
# no
# ['100762944', '(100762944)', '100762944']
# no
# no
# no
# no
# no
# ['100775004', '(100775004)', '100775004']
# ['100775004', '(100775004)', '100775004']
# no
# no
# no
# ['103158768 or 103159932', '(103158768) or (103159932)', '103158768 or 103159932']
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# [nan, nan, '100765000']
# [nan, nan, '100767138 or 100762166 or 100770034']
# no
# [nan, nan, '100767138 or 100762166 or 100770034']
# [nan, nan, '100767138 or 100762166 or 100770034']
# [nan, nan, '100767138 or 100762166 or 100770034']
# ['100766362', '(100766362)', '100766362']
# ['100770034 or 100762166 or 100767138', '(100770034) or (100762166) or (100767138)', '100770034 or 100762166 or 100767138']
# ['100766757', '(100766757)', '100766757']
# ['100765000', '(100765000)', '100765000']
# ['100770034 or 100762166 or 100767138', '(100770034) or (100762166) or (100767138)', '100770034 or 100762166 or 100767138']
# ['100770034 or 100762166 or 100767138', '(100770034) or (100762166) or (100767138)', '100770034 or 100762166 or 100767138']
# ['100766757', '(100766757)', '100766757']
# ['100766757', '(100766757)', '100766757']
# ['100765000', '(100765000)', '100765000']
# ['100765000', '(100765000)', '100765000']
# no
# no
# ['100767138 or 100762166 or 100770034', '(100767138) or (100762166) or (100770034)', '100767138 or 100762166 or 100770034']
# ['100766757', '(100766757)', '100766757']
# ['100765000', '(100765000)', '100765000']
# ['100767138 or 100770034 or 100762166', '(100767138) or (100770034) or (100762166)', '100767138 or 100770034 or 100762166']
# ['100766757', '(100766757)', '100766757']
# ['100765000', '(100765000)', '100765000']
# ...
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# [nan, nan]
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# [nan, nan]
# [nan, nan]
# [nan, nan]
# [nan, nan]
# [nan, nan]
# [nan, nan]
# [nan, nan]
# [nan, nan]
# [nan, nan]
# [nan, nan]
# [nan, nan]
# [nan, nan]
# [nan, nan]
# [nan, nan]
# [nan, nan]
# [nan, nan]
# [nan, nan]
# [nan, nan]
# [nan, nan]
# [nan, nan]
# [nan, nan]
# [nan, nan]
# [nan, nan]
# [nan, nan]
# [nan, nan]
# [nan, nan]
# [nan, nan]
# [nan, nan]
# [nan, nan]
# [nan, nan]
# [nan, nan]
# [nan, nan]
# [nan, nan]
# [nan, nan]
# [nan, nan]
# [nan, nan]
# [nan, nan]
# [nan, nan]
# [nan, nan]
# [nan, nan]
# [nan, nan]
# [nan, nan]
# [nan, nan]
# [nan, nan]
# [nan, nan]
# [nan, nan]
# [nan, nan]
# [nan, nan]
# [nan, nan]
# [nan, nan]
# [nan, nan]
# [nan, nan]
# [nan, nan]
# [nan, nan]
# [nan, nan]
# [nan, nan]
# [nan, nan]
# [nan, nan]
# [nan, nan]
# [nan, nan]
# [nan, nan]
# [nan, nan]
# [nan, nan]
# [nan, nan]
# [nan, nan]
# [nan, nan]
# [nan, nan]
# [nan, nan]
# [nan, nan]
# [nan, nan]
# [nan, nan]
# [nan, nan]
# [nan, nan]
# [nan, nan]
# [nan, nan]
# [nan, nan]
# [nan, '100768667 and 100689315']
# [nan, '100768667 and 100689315']
# [nan, '100768667 and 100689315']
# [nan, '100768667 and 100689315']
# [nan, '100768667 and 100689315']
# [nan, '100768667 and 100689315']
# [nan, '100768667 and 100689315']
# [nan, '100768667 and 100689315']
# [nan, '100768667 and 100689315']
# [nan, '100768667 and 100689315']
# [nan, '100768667 and 100689315']
# [nan, '100768667 and 100689315']
# [nan, '100768667 and 100689315']
# [nan, '100768667 and 100689315']
# [nan, '100768667 and 100689315']
# [nan, '100768667 and 100689315']
# [nan, '100768667 and 100689315']
# [nan, '100768667 and 100689315']
# [nan, '100768667 and 100689315']
# [nan, '100768667 and 100689315']
# [nan, '100768667 and 100689315']
# [nan, '100768667 and 100689315']
# [nan, '100768667 and 100689315']
# [nan, '100768667 and 100689315']
# [nan, '100768667 and 100689315']
# [nan, '100768667 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# [nan, '100760403 and 100689315']
# no
# [nan, nan]
# [nan, nan]
# [nan, nan]
# [nan, nan]
# [nan, nan]
# [nan, nan]
# [nan, nan]
# [nan, nan]
# [nan, nan]
# [nan, nan]
# [nan, nan]
# [nan, nan]
# [nan, nan]
# [nan, nan]
# [nan, nan]
# [nan, nan]
# no
# [nan, nan]
# [nan, nan]
# [nan, nan]
# [nan, nan]
# [nan, nan]
# [nan, nan]
# [nan, nan]
# [nan, nan]
# [nan, nan]
# [nan, nan]
# [nan, nan]
# [nan, nan]
# [nan, nan]
# [nan, nan]
# [nan, nan]
# [nan, nan]
# [nan, nan]
# [nan, nan]
# [nan, nan]
# [nan, nan]
# [nan, nan]
# [nan, nan]
# [nan, nan]
# [nan, nan]
# [nan, nan]
# [nan, nan]
# [nan, nan]
# [nan, nan]
# [nan, nan]
# [nan, nan]
# [nan, nan]
# [nan, nan]
# [nan, nan]
# [nan, nan]
# [nan, nan]
# [nan, nan]
# [nan, nan]
# [nan, nan]
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# [nan, nan]
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no

# %%
all_dfs1 = all_dfs.groupby(['Reaction'], group_keys=True).apply(lambda x: x)
all_dfs1
# Out:
#                     cam  hef  fou  yeo      Reaction  \
# Reaction
# 10FTHF5GLUtl 605    NaN    X  NaN  NaN  10FTHF5GLUtl
#              10778  NaN  NaN    X  NaN  10FTHF5GLUtl
#              14704  NaN  NaN  NaN    X  10FTHF5GLUtl
# 10FTHF5GLUtm 606    NaN    X  NaN  NaN  10FTHF5GLUtm
#              10779  NaN  NaN    X  NaN  10FTHF5GLUtm
# ...                 ...  ...  ...  ...           ...
# r2534        7263   NaN    X  NaN  NaN         r2534
# r2535        7264   NaN    X  NaN  NaN         r2535
# r2537        7265   NaN    X  NaN  NaN         r2537
# r2538        7266   NaN    X  NaN  NaN         r2538
# r2539        7267   NaN    X  NaN  NaN         r2539
#
#                                                  Reaction Name  \
# Reaction
# 10FTHF5GLUtl 605        5-glutamyl-10FTHF transport, lysosomal
#              10778      5-glutamyl-10FTHF transport, lysosomal
#              14704      5-glutamyl-10FTHF transport, lysosomal
# 10FTHF5GLUtm 606    5-glutamyl-10FTHF transport, mitochondrial
#              10779  5-glutamyl-10FTHF transport, mitochondrial
# ...                                                        ...
# r2534        7263       Major Facilitator(MFS) TCDB:2.A.1.44.1
# r2535        7264       Major Facilitator(MFS) TCDB:2.A.1.44.1
# r2537        7265                           Utilized transport
# r2538        7266                           Utilized transport
# r2539        7267                Postulated transport reaction
#
#                                                      Reaction Formula  GPR  \
# Reaction
# 10FTHF5GLUtl 605                        10fthf5glu_c --> 10fthf5glu_l  NaN
#              10778                   10fthf5glu[c]  => 10fthf5glu[l]   NaN
#              14704                    10fthf5glu[c] --> 10fthf5glu[l]  NaN
# 10FTHF5GLUtm 606                        10fthf5glu_m --> 10fthf5glu_c  NaN
#              10779                   10fthf5glu[m]  => 10fthf5glu[c]   NaN
# ...                                                               ...  ...
# r2534        7263                                 thr_L_e <=> thr_L_c  NaN
# r2535        7264                                 hom_L_e <=> hom_L_c  NaN
# r2537        7265                         lnlncgcoa_c <=> lnlncgcoa_r  NaN
# r2538        7266                         dlnlcgcoa_c <=> dlnlcgcoa_r  NaN
# r2539        7267   L2aadp6sa_c + L2aadp_m <=> L2aadp6sa_m + L2aadp_c  NaN
#
#                                            Subsystem  Genes  ...  Mol wt  \
# Reaction                                                     ...
# 10FTHF5GLUtl 605                TRANSPORT, LYSOSOMAL    NaN  ...     NaN
#              10778              TRANSPORT, LYSOSOMAL    NaN  ...     NaN
#              14704                         Transport    NaN  ...     NaN
# 10FTHF5GLUtm 606            TRANSPORT, MITOCHONDRIAL    NaN  ...     NaN
#              10779          TRANSPORT, MITOCHONDRIAL    NaN  ...     NaN
# ...                                              ...    ...  ...     ...
# r2534        7263           TRANSPORT, EXTRACELLULAR    NaN  ...     NaN
# r2535        7264           TRANSPORT, EXTRACELLULAR    NaN  ...     NaN
# r2537        7265   TRANSPORT, ENDOPLASMIC RETICULAR    NaN  ...     NaN
# r2538        7266   TRANSPORT, ENDOPLASMIC RETICULAR    NaN  ...     NaN
# r2539        7267           TRANSPORT, MITOCHONDRIAL    NaN  ...     NaN
#
#                    kcat_forward  kcat_backward  Reversible  Lower bound  \
# Reaction
# 10FTHF5GLUtl 605            NaN            NaN         NaN          0.0
#              10778          NaN            NaN         0.0          0.0
#              14704          NaN            NaN         NaN          0.0
# 10FTHF5GLUtm 606            NaN            NaN         NaN          0.0
#              10779          NaN            NaN         0.0          0.0
# ...                         ...            ...         ...          ...
# r2534        7263           NaN            NaN         NaN      -1000.0
# r2535        7264           NaN            NaN         NaN      -1000.0
# r2537        7265           NaN            NaN         NaN      -1000.0
# r2538        7266           NaN            NaN         NaN      -1000.0
# r2539        7267           NaN            NaN         NaN      -1000.0
#
#                     Upper bound  Objective Curation Notes  References  \
# Reaction
# 10FTHF5GLUtl 605         1000.0        NaN            NaN         NaN
#              10778         1000        0.0            NaN         NaN
#              14704         1000        NaN            NaN         NaN
# 10FTHF5GLUtm 606         1000.0        NaN            NaN         NaN
#              10779         1000        0.0            NaN         NaN
# ...                         ...        ...            ...         ...
# r2534        7263        1000.0        NaN            NaN         NaN
# r2535        7264        1000.0        NaN            NaN         NaN
# r2537        7265        1000.0        NaN            NaN         NaN
# r2538        7266        1000.0        NaN            NaN         NaN
# r2539        7267        1000.0        NaN            NaN         NaN
#
#                    Reaction ID Camels Models
# Reaction
# 10FTHF5GLUtl 605                         NaN
#              10778                       NaN
#              14704                       NaN
# 10FTHF5GLUtm 606                         NaN
#              10779                       NaN
# ...                                      ...
# r2534        7263                        NaN
# r2535        7264                        NaN
# r2537        7265                        NaN
# r2538        7266                        NaN
# r2539        7267                        NaN
#
# [20938 rows x 22 columns]

# %%
# Group the entire dataset by reaction name 
all_dfs1 = all_dfs.groupby(['Reaction'], group_keys=True).apply(lambda x: x)

# Save merged datasets as Excel file
all_dfs1.to_excel('../Data/all_dfs1.xlsx')

all_dfs1
# Out:
#                     cam  hef  fou  yeo      Reaction  \
# Reaction
# 10FTHF5GLUtl 605    NaN    X  NaN  NaN  10FTHF5GLUtl
#              10778  NaN  NaN    X  NaN  10FTHF5GLUtl
#              14704  NaN  NaN  NaN    X  10FTHF5GLUtl
# 10FTHF5GLUtm 606    NaN    X  NaN  NaN  10FTHF5GLUtm
#              10779  NaN  NaN    X  NaN  10FTHF5GLUtm
# ...                 ...  ...  ...  ...           ...
# r2534        7263   NaN    X  NaN  NaN         r2534
# r2535        7264   NaN    X  NaN  NaN         r2535
# r2537        7265   NaN    X  NaN  NaN         r2537
# r2538        7266   NaN    X  NaN  NaN         r2538
# r2539        7267   NaN    X  NaN  NaN         r2539
#
#                                                  Reaction Name  \
# Reaction
# 10FTHF5GLUtl 605        5-glutamyl-10FTHF transport, lysosomal
#              10778      5-glutamyl-10FTHF transport, lysosomal
#              14704      5-glutamyl-10FTHF transport, lysosomal
# 10FTHF5GLUtm 606    5-glutamyl-10FTHF transport, mitochondrial
#              10779  5-glutamyl-10FTHF transport, mitochondrial
# ...                                                        ...
# r2534        7263       Major Facilitator(MFS) TCDB:2.A.1.44.1
# r2535        7264       Major Facilitator(MFS) TCDB:2.A.1.44.1
# r2537        7265                           Utilized transport
# r2538        7266                           Utilized transport
# r2539        7267                Postulated transport reaction
#
#                                                      Reaction Formula  GPR  \
# Reaction
# 10FTHF5GLUtl 605                        10fthf5glu_c --> 10fthf5glu_l  NaN
#              10778                   10fthf5glu[c]  => 10fthf5glu[l]   NaN
#              14704                    10fthf5glu[c] --> 10fthf5glu[l]  NaN
# 10FTHF5GLUtm 606                        10fthf5glu_m --> 10fthf5glu_c  NaN
#              10779                   10fthf5glu[m]  => 10fthf5glu[c]   NaN
# ...                                                               ...  ...
# r2534        7263                                 thr_L_e <=> thr_L_c  NaN
# r2535        7264                                 hom_L_e <=> hom_L_c  NaN
# r2537        7265                         lnlncgcoa_c <=> lnlncgcoa_r  NaN
# r2538        7266                         dlnlcgcoa_c <=> dlnlcgcoa_r  NaN
# r2539        7267   L2aadp6sa_c + L2aadp_m <=> L2aadp6sa_m + L2aadp_c  NaN
#
#                                            Subsystem  Genes  ...  Mol wt  \
# Reaction                                                     ...
# 10FTHF5GLUtl 605                TRANSPORT, LYSOSOMAL    NaN  ...     NaN
#              10778              TRANSPORT, LYSOSOMAL    NaN  ...     NaN
#              14704                         Transport    NaN  ...     NaN
# 10FTHF5GLUtm 606            TRANSPORT, MITOCHONDRIAL    NaN  ...     NaN
#              10779          TRANSPORT, MITOCHONDRIAL    NaN  ...     NaN
# ...                                              ...    ...  ...     ...
# r2534        7263           TRANSPORT, EXTRACELLULAR    NaN  ...     NaN
# r2535        7264           TRANSPORT, EXTRACELLULAR    NaN  ...     NaN
# r2537        7265   TRANSPORT, ENDOPLASMIC RETICULAR    NaN  ...     NaN
# r2538        7266   TRANSPORT, ENDOPLASMIC RETICULAR    NaN  ...     NaN
# r2539        7267           TRANSPORT, MITOCHONDRIAL    NaN  ...     NaN
#
#                    kcat_forward  kcat_backward  Reversible  Lower bound  \
# Reaction
# 10FTHF5GLUtl 605            NaN            NaN         NaN          0.0
#              10778          NaN            NaN         0.0          0.0
#              14704          NaN            NaN         NaN          0.0
# 10FTHF5GLUtm 606            NaN            NaN         NaN          0.0
#              10779          NaN            NaN         0.0          0.0
# ...                         ...            ...         ...          ...
# r2534        7263           NaN            NaN         NaN      -1000.0
# r2535        7264           NaN            NaN         NaN      -1000.0
# r2537        7265           NaN            NaN         NaN      -1000.0
# r2538        7266           NaN            NaN         NaN      -1000.0
# r2539        7267           NaN            NaN         NaN      -1000.0
#
#                     Upper bound  Objective Curation Notes  References  \
# Reaction
# 10FTHF5GLUtl 605         1000.0        NaN            NaN         NaN
#              10778         1000        0.0            NaN         NaN
#              14704         1000        NaN            NaN         NaN
# 10FTHF5GLUtm 606         1000.0        NaN            NaN         NaN
#              10779         1000        0.0            NaN         NaN
# ...                         ...        ...            ...         ...
# r2534        7263        1000.0        NaN            NaN         NaN
# r2535        7264        1000.0        NaN            NaN         NaN
# r2537        7265        1000.0        NaN            NaN         NaN
# r2538        7266        1000.0        NaN            NaN         NaN
# r2539        7267        1000.0        NaN            NaN         NaN
#
#                    Reaction ID Camels Models
# Reaction
# 10FTHF5GLUtl 605                         NaN
#              10778                       NaN
#              14704                       NaN
# 10FTHF5GLUtm 606                         NaN
#              10779                       NaN
# ...                                      ...
# r2534        7263                        NaN
# r2535        7264                        NaN
# r2537        7265                        NaN
# r2538        7266                        NaN
# r2539        7267                        NaN
#
# [20938 rows x 22 columns]

# %%
#def f(x):
#    d = {}
#    d['EC Number_m'] = x['EC Number'].first()
#    d['a_max'] = x['a'].max()
#    d['b_mean'] = x['b'].mean()
#    d['c_d_prodsum'] = (x['c'] * x['d']).sum()
#    return pd.Series(d, index=['EC Number_m', 'a_max', 'b_mean', 'c_d_prodsum'])

all_dfs2 = all_dfs.groupby('Reaction').first()
all_dfs2.to_excel('../Data/all_dfs2.xlsx')
all_dfs2

# %%
# this functions are for fetching information from the BiGG database

def get_rxninfo(rxn):

    #download the page
    session = HTMLSession()
    
    response=session.get('http://bigg.ucsd.edu/models/iCHOv1/reactions/'+rxn)
    if response.status_code != 200:
        print('Status code:', response.status_code,f'Failed to fetch info on {rxn} from iCHOv1 model')
        response=session.get('http://bigg.ucsd.edu/universal/reactions/'+rxn)
        if response.status_code != 200:
            print('Status code:', response.status_code,f'Failed to fetch info on {rxn} from BiGG')

    #parse using beautiful soup
    rxn_doc = BeautifulSoup(response.text,'html.parser')

    return rxn_doc


def bigg_attributes(rxn):
    
    '''
    recieves a rxn file from the get_rxninfo function
    and returns Reaction Description, Subsystem
    '''
    if rxn.title.get_text().endswith('iCHOv1'):
        # Reaction description
        rxn_d = rxn.find_all("p")[0].get_text()

        # Reaction formula
        form = rxn.find_all("p")[2].get_text()

        # Subsystem
        subsystem = rxn.find_all("p")[5].get_text()
    else:
        # Reaction description
        rxn_d = rxn.find_all("p")[0].get_text()

        # Reaction formula
        form = rxn.find_all("p")[1].get_text()

        # Subsystem
        subsystem = ''
    
    return rxn_d, form, subsystem

# %%
#all_dfs3 = pd.DataFrame(columns = ['Reactions', 'Reaction Description', 'Reaction Formula', 'Subsystem'])
att = []
for i,r in enumerate(tqdm((all_dfs2.index))):
    try:
        rxn = get_rxninfo(r)
        rxn_d, form, subsystem = bigg_attributes(rxn)
        print(rxn_d, form, subsystem)
        if all_dfs2['Reaction Formula'][i] == None:
            all_dfs2['Reaction Formula'][i] = form
        if all_dfs2['Reaction Name'][i] == None:
            all_dfs2['Reaction Name'][i] = rxn_d
    except:
        print(f'Could not find info for {r}')
        break
        
all_dfs2.to_excel('../Data/all_dfs2.xlsx')

# %%
rxn.find_all("p")

# %%
rxn.find_all("p")[2].get_text()

# %%
rxn.find_all("div", class_="col-lg-8")

# %%
rxn = get_rxninfo('5G2OXPTtx')
print(rxn.title.get_text().endswith('iCHOv1'))

# %%
rxn.find_all("p")[3].get_text()

# %%
for i,r in enumerate(tqdm((all_dfs2.index))):
    if r.endswith('_cho'):
        print(r,i)
        if all_dfs2.index[i-1] == r.split('_')[0]:
            print(all_dfs2.index[i-1],i-1)
        #print(all_dfs2.index[i-1],i-1)
