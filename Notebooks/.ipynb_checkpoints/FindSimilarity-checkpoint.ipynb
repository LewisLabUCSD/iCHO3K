# %%
# List of SMILES
cmps = {}
for line in open('smiles.txt','r'):
    tmp = line.strip().split('\t')
    cmps[tmp[0]] = tmp[1]
cmps
# Out:
# {'ACT-451840': 'CC(C)(C)C1=CC=C(C=C1)S(=O)(=O)NC2=C(C(=NC(=N2)C3=NC=CC=N3)OCCO)OC4=CC=CC=C4OC',
#  'AN10248': 'OBr1OCC2=CC=C(OC3=CN=C(C(O)=O)C=N3)C(C)=C21',
#  'AN13762': 'B1(C2=C(CO1)C=CC(=C2C)OC3=NC=C(N=C3)C(=O)N4CC(C4)(C)O)O',
#  'AN13956': 'OBr1OCC2=CC=C(OC3=CN=C(C(N4CC(C(O)CC)C4)=O)C=N3)C(C)=C21',
#  'Antimycin A': 'CCCCCCC1C(C(OC(=O)C(C(OC1=O)C)NC(=O)C2=C(C(=CC=C2)NC=O)O)C)OC(=O)CC(C)C',
#  'Artemisinin': 'CC1CCC2C(C(=O)OC3C24C1CCC(O3)(OO4)C)C',
#  'Atovaquone': 'OC1=C([C@H]2CC[C@@H](CC2)C2=CC=C(Cl)C=C2)C(=O)C2=CC=CC=C2C1=O',
#  'BCH070': 'C1=CC=C(C=C1)OC2=CC=C(C=C2)NC3=NC(=NC4=CC=CC=C43)C5=CC=C(C=C5)Cl',
#  'BI-2536': 'CCC1C(=O)N(C2=CN=C(N=C2N1C3CCCC3)NC4=C(C=C(C=C4)C(=O)NC5CCN(CC5)C)OC)C',
#  'BMS983970': 'C1CC1CC(C(CCC(F)(F)F)C(=O)NC2C(=O)NC3=C(C=CC=C3F)C(=N2)C4=CC=CC=C4)C(=O)N',
#  'BRD1095': 'COC1=CC=C(NC(=O)N2CCCCN3[C@H](CN)[C@@H]([C@@H]3C2)C2=CC=C(C=C2)C#CC2=CC=CC=C2)C=C1',
#  'BRD3444': 'COC1=CC=C(C=C1)NC(=O)N2CCCCN3C(C2)C(C3CO)C4=CC=C(C=C4)C#CC5=CC=CC=C5',
#  'Bortezomib': 'B(C(CC(C)C)NC(=O)C(CC1=CC=CC=C1)NC(=O)C2=NC=CN=C2)(O)O',
#  'CXP18.6-052': 'O=C(NCCNC([C@H](O)C(C)(C)CO)=O)CCC1=CC=CC=C1',
#  'Cladosporin': 'C[C@H]1CCC[C@H](C[C@H]2CC3=CC(O)=CC(O)=C3C(=O)O2)O1',
#  'DDD01061024': 'CC1=CC=C(C=C1)C1=CC=C(N=C1)C1CNCCO1',
#  'DDD107498': 'C1CCN(C1)CCNC(=O)C2=CC(=NC3=C2C=C(C=C3)F)C4=CC=C(C=C4)CN5CCOCC5',
#  'DSM1': 'CC1=NC2=NC=NN2C(=C1)NC3=CC4=CC=CC=C4C=C3',
#  'DSM265': 'FS(F)(F)(F)(C1=CC=C(NC2=CC(C)=NC3=NC(C(F)(F)C)=NN23)C=C1)F',
#  'DSM267': 'Cc3cc(Nc1ccc(cc1)C(F)(F)F)n2nc(nc2n3)C(C)(F)F',
#  'Desoxyepothilone B': 'CC1CCCC(=CCC(OC(=O)CC(C(C(=O)C(C1O)C)(C)C)O)C(=CC2=CSC(=N2)C)C)C',
#  'MMV009063': 'OC(CNC1CCCCC1)CN1C2=CC=CC=C2C2=CC=CC=C12',
#  'MMV009108': 'CCN(CC)S(=O)(=O)C1=CC=C(C=C1)C1=CSC(NC2=CC(C)=C(C)C=C2)=N1',
#  'MMV010545': 'COc1ccc(cn1)-c1cnc2ccc(NCc3ccc(cc3)S(N)(=O)=O)nn12',
#  'MMV011438': 'COC(=O)c1ccc(cc1)C1N(C(=O)c2ccccc2)c2ccccc2N=C2CC(CC(O)=C12)c1ccc(F)cc1',
#  'MMV011895': 'NC1=CC=C(C=C1)C1=NC2=CC(OC3=CC=C(OC4=CC=C5NC(=NC5=C4)C4=CC=C(N)C=C4)C=C3)=CC=C2N1',
#  'MMV019017': 'COCCNCC(O)CN1C2=CC=C(Cl)C=C2C2=C1C=CC(Cl)=C2',
#  'MMV019066': 'COC1=CC=CC=C1CNC(=O)CCN1C(=O)NC2=C(SC=C2)C1=O',
#  'MMV019313': 'Cn1c2ccccc2c3c(c1=O)cc(s3)C(=O)NCCCN4CCCCCC4',
#  'MMV019662': 'COC1=CC=C(C=C1)N1CCN(CC1)C(CNC(=O)C1CCCCC1)C1=CC=C2OCOC2=C1',
#  'MMV019719': 'COC1=CC=C(C=C1)C1=C(C)SC(NC(=O)CC2=CC=C3OCCOC3=C2)=N1',
#  'MMV019721': 'CCN(CC)S(=O)(=O)c1ccc(Cl)c(c1)C(=O)Nc1ccc2nc(C)sc2c1',
#  'MMV020623': 'Cc1noc(C)c1C(=O)N1CCCC(C1)c1[nH]c2c(C)cccc2c1-c1ccncc1',
#  'MMV020746': 'Cc1ccc(Oc2ncccc2C(=O)Nc2cccc3cccnc23)c(C)c1',
#  'MMV023367': 'NC1=NC=C(C=C1C1=NC2=C(N1)C=C(F)C=C2)C1=CNN=C1',
#  'MMV023388': 'FC(F)(F)c1cccc(c1)C(=O)NC1CCN(C1)c1ccnc2ccccc12',
#  'MMV023949': 'CC(C)(C)c1cc(C(=O)N2CCN(CC2)c2nccnc2C#N)n(Cc2ccccc2)n1',
#  'MMV024038': 'CN(C)S(=O)(=O)C1=CC(=CN=C1N)C1=CC2=C(C=CN=C2C=C1)C1=CC=CC(=C1)S(N)(=O)=O',
#  'MMV024101': 'NS(=O)(=O)c1cncc(c1)-c1ccc2nccc(-c3cn[nH]c3)c2n1.Cl',
#  'MMV024114': 'CC1=CC=C(C=C1)S(=O)(=O)N1C=C(C2=CC(Br)=CN=C12)C1=CC(N)=NC=C1',
#  'MMV026596': 'Cl[H].Cl[H].CNCC1=CC=C2N=C(NC2=C1)C1=COC(CC2=C(OCC(C)C)C=CC(Cl)=C2)=N1',
#  'MMV027634': '[Cl-].CC1=NC2=C(C(=O)N1)C1=C(C=CC(CNC3=CC=C(C=C3)C(=O)CC(CCC(O)=O)C(O)=O)=C1)C=C2',
#  'MMV028038': 'CC(C)C1=CC=CC(=C1)C(NC(=O)C1CC2=C(CN1C(=O)C1=CC=CC(=C1)N1CCOCC1)C=CC=C2)C1CCCC1',
#  'MMV029272': 'ClC1=CC=C(NC(=O)NCC(CCCN2CCC(CC2)C2=CNC3=CC=CC=C23)C2=CC=CC=C2)C=C1Cl',
#  'MMV030084': 'CC(C)(CN)c3nc(c1ccc(Cl)c(O)c1)c(c2ccncc2)[nH]3',
#  'MMV084864': 'O=C(Nc1cnc2ccccc2c1)c1cccc(c1)-n1cnnn1',
#  'MMV084978': 'Clc1ccc(cc1)C(=O)NNC(=O)c2csnn2',
#  'MMV085203': 'COc1ccccc1/N=C/2\\C(=O)c3ccccc3C(=C2N4CCCCC4)O',
#  'MMV1081413': 'CC1=C(CC(N)=O)SC(SC2=C3SC=CC3=NC=N2)=N1',
#  'MMV1091186': 'CC1=C(CC(N)=O)SC(SC2=C3C4=C(CCC4)SC3=NC=N2)=N1',
#  'MMV1427995': 'CC(Sc1nnc(-c2ccc(C)cc2)c(n1)-c1ccc(C)cc1)C(=O)NCC=C',
#  'MMV1432711': 'O=C(Nc1ccccc1Cc1ccccc1)COc1ccc2c(c1)c(=O)c1c([nH]2)cccc1',
#  'MMV1454442': 'CCOC(=O)c1c(C)[nH]c(C(=O)CSc2nnc(C3CC3)n2N)c1C',
#  'MMV1490397': 'CC(c1nn2c(nnc2s1)-c1ccco1)c1ccc(c(F)c1)-c1ccccc1',
#  'MMV1490405': 'CC(C)Cc1ccc(cc1)C(C)c1nn2c(nnc2s1)-c1ccco1',
#  'MMV407834': 'CCOc1ccccc1NC(C)C(=O)Nc1cc(ccc1N1CCOCC1)C(F)(F)F',
#  'MMV665789': 'CC(NCC1=CC=CC=C1)C1=CC(Cl)=CC=C1O',
#  'MMV665794': 'FC(F)(F)C1=CC(NC2=C(NC3=CC(=CC=C3)C(F)(F)F)N=C3C=CC=CC3=N2)=CC=C1',
#  'MMV665852': 'ClC1=CC=C(NC(=O)NC2=CC=C(Cl)C(Cl)=C2)C=C1Cl',
#  'MMV665882': 'OC(CNC1CCCCC1)Cn1c2ccc(I)cc2c2cc(I)ccc12',
#  'MMV665924': 'COC1=CC=C(C=C1)C(=O)C1CC1C1=CC=C(Cl)C=C1',
#  'MMV665928': 'CCC(C)NCC(C1=CC=C(C=C1)Cl)(C2=CC=C(C=C2)Cl)O',
#  'MMV665939': 'FC1=CC=C(C=C1)C(=O)NC1=C(SC=C1)C(=O)NC1CCCCC1',
#  'MMV666080': 'OC1=C2N=CC=CC2=CC=C1C(NC(=O)C1=CC=CC=C1)C1=CC=CC=C1',
#  'MMV667491': 'CN(C)CCCN1C=NC2=C(C1=N)C(C3=C(O2)C4=CC=CC=C4C=C3)C5=CC=C(C=C5)OC',
#  'MMV668311': 'CNc1nc(NCCCN(C)C)c2sc(cc2n1)c3cccc(c3)C(F)(F)F',
#  'MMV668399': 'C(C1CCN(CC1)C1=NC(=NC(=C1)C1=CC=CN=C1)C1=CC=NC=C1)N1CCOCC1',
#  'MMV673482': 'O=C(NC1=CC=CC=C1F)N(CC2)CCC2(CN(C(C)=O)[C@H]3CO)C4=C3NC5=C4C=CC(OC)=C5',
#  'MMV675939': 'FC(F)(F)C1=CC=C(NC2=CC(NC(C3=CC(C(F)(F)F)=CC=C3)=N4)=C4C=N2)N=C1',
# %%
from rdkit import Chem
from rdkit.Chem import AllChem
from rdkit import DataStructs
from rdkit.Chem import MACCSkeys
from rdkit.Chem import MCS
from rdkit.Chem.rdFMCS import FindMCS
from rdkit.Chem import rdFMCS

# %%
def getMWfromSMI(smi):
    mw = Descriptors.ExactMolWt(Chem.MolFromSmiles(smi))
    return mw

# %%
def getCanonical(smiset):
    new_smiset = []
    
    for smi in smiset:
        mol = Chem.MolFromSmiles(smi)
        molsmi = Chem.MolToSmiles(mol,True)
        new_smiset.append(molsmi)
    
    return(new_smiset)

# %%
def getTanimotoSameSet(smiset):
    #smiset = [cmps[smi] for smi in snps['PF3D7_0321900']]
    if len(smiset) == 1:
        return(1)
    mols = [Chem.MolFromSmiles(smi, sanitize=False) for smi in smiset]
    fpset = [Chem.RDKFingerprint(mol) for mol in mols]
    simils = []
    for i in range(len(fpset)):
        for j in range(i+1,len(fpset)):
            score = tanimoto_calc(smiset[i],smiset[j])
            if score >= 0.95:
                simils.append(mol1,mol2,score)
    
    return(sum(simils)/len(simils))

# %%
## Fingerprint generation
# Morgan Fingerprint
# https://www.rdkit.org/docs/GettingStartedInPython.html
def getMorganFingerprint4(ms):
	from rdkit.Chem import rdMolDescriptors
	fp = [rdMolDescriptors.GetMorganFingerprint(x,4,nBits=2048,useFeatures=True) for x in ms]
	
	return fp
	
# ECFP Fingerprint with Features and bit
def getMorganBit(ms):
	from rdkit.Chem import AllChem
	fp = [AllChem.GetMorganFingerprintAsBitVect(x,4,nBits=1048,useFeatures=True) for x in ms]

	return fp

# ECFP Morgan Fingerprint with Features no bit
def getMorgan(ms):
	from rdkit.Chem import AllChem
	fp = [AllChem.GetMorganFingerprint(x,4,useFeatures=True) for x in ms]

# %%
def similarity_calc(smi1, smi2):
    mol1 = Chem.MolFromSMILES(smi1)
    mol2 = Chem.MolFromSMILES(smi2)
    fp1 = Chem.RDKFingerprint(mol1)
    fp2 = Chem.RDKFingerprint(mol2)
    
    #fp1 = getMorgan(mol1)
    #fp2 = getMorgan(mol2)
    
    s = DataStructs.TanimotoSimilarity(fp1,fp2)
    x = 0
    
    s2 = DataStructs.FingerprintSimilarity(fp1,fp2, metric=DataStructs.DiceSimilarity)
    if s2 > s:
        s = s2
    try:
        fps = [MACCSkeys.GenMACCSKeys(mol1),MACCSkeys.GenMACCSKeys(mol2)]
        s2 = DataStructs.FingerprintSimilarity(fps[0],fps[1], metric=DataStructs.DiceSimilarity)
        if s2 > s :
            s = s2
    except:
        x += 1
    s2 = DataStructs.FingerprintSimilarity(fp1,fp2,metric=DataStructs.TanimotoSimilarity)
    if s2 > s:
        s = s2
    try:
        ffp1 = AllChem.GetMorganFingerprint(mol1,4,useFeatures=True)
        ffp2 = AllChem.GetMorganFingerprint(mol2,4,useFeatures=True)
        s2 = DataStructs.DiceSimilarity(ffp1,ffp2)
        if s2 > s:
            s = s2
    except:
        x += 1
    return s

# %% [markdown]
# * Modificar nombre variables -para que sean consistentes entre funciones/entradas
# * Agregar canonizacion de smiles antes de ejecutar funciones
