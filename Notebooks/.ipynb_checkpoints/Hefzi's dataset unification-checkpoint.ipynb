# %% [markdown]
# ## Unification of the datasets provided by Hooman's paper
#
# A dataset created from the iCHOv1 xml file and the excell file provided as Supplementary data have been unified  in order to have information from both dataset (i.e. lower and upper bound from the xml file and notes from the excell)

# %%
import pandas as pd
import cobra
from cobra.io import read_sbml_model
from cobra.util import create_stoichiometric_matrix
from tqdm.notebook import tqdm

# %%
# Load Hefzi's dataset
df1 = pd.read_excel('../Data/iCHOv1_Reconstruction.xlsx', header = 1)
df1
# Out:
#        Reaction                                      Reaction Name  \
# 0     COKECBESr                    Carboxylesterase (cocaine) (er)
# 1       EGMESTr                      ecgonine methyl esterase (ER)
# 2      NMPTRCOX  N-Methylputrescine:oxygen oxidoreductase (deam...
# 3         PRO1x                     L-ProlineNAD+ 5-oxidoreductase
# 4         DHDDH                          Dihydrodiol dehydrogenase
# ...         ...                                                ...
# 3224     C8CRNt       C8:0 acylcarnitine transport to mitochondria
# 3225    MALCRNt      Malonyl carnitine transport into mitochondria
# 3226        NP1                             nucleotide phosphatase
# 3227   UGT1A10r  UDP-glucuronosyltransferase 1-10 precursor, mi...
# 3228    PCLYSOX  Procollagen-lysine 1, 2-oxoglutarate 5-dioxyge...
#
#                             Subsystem  \
# 0                  ALKALOID SYNTHESIS
# 1                  ALKALOID SYNTHESIS
# 2                  ALKALOID SYNTHESIS
# 3     ARGININE AND PROLINE METABOLISM
# 4                      CYP METABOLISM
# ...                               ...
# 3224                CARNITINE SHUTTLE
# 3225                CARNITINE SHUTTLE
# 3226                   NAD METABOLISM
# 3227               STEROID METABOLISM
# 3228                LYSINE METABOLISM
#
#                                        Reaction Formula  \
# 0          coke[r] + h2o[r]  -> bz[r] + egme[r] + h[r]
# 1       h2o[r] + egme[r]  -> h[r] + ecgon[r] + meoh[r]
# 2     nmptrc[c] + o2[c]  -> nh4[c] + 1mpyr[c] + h2o2...
# 3     pro_L[c] + nad[c]  -> 2 h[c] + 1pyr5c[c] + nad...
# 4       nadp[c] + dhnpthld[c]  -> npthld[c] + nadph[c]
# ...                                                 ...
# 3224                             c8crn[c]  -> c8crn[m]
# 3225                         HC10859[c]  -> HC10859[m]
# 3226      h[c] + nac[c] + r1p[c]  -> pi[c] + nicrns[c]
# 3227  2 h[r] + udpglcur[r] + bilirub[r]  <=> udp[r] ...
# 3228  o2[c] + akg[c] + pcollglys[c]  -> co2[c] + suc...
#
#                                                     GPR  \
# 0                            (100756666) or (100767789)
# 1                                           (100771815)
# 2     (100771382) or (100762635) or (100762926) or (...
# 3                                           (100773901)
# 4                                           (100753544)
# ...                                                 ...
# 3224                                        (100765000)
# 3225                                        (100765000)
# 3226                                        (100757729)
# 3227                                        (100755423)
# 3228                         (100762939) or (100763844)
#
#                                          Curation Notes  References
# 0     From the various human carboxylesterases only ...         NaN
# 1     Encoded enzyme (100771815) is an arylacetamide...         NaN
# 2     All encode amine oxidases: AOC1 (100771382); A...         NaN
# 3     100773901 maps to 58510, "similar to proline d...         NaN
# 4     Dimeric dihydrodiol dehydrogenase was found to...         NaN
# ...                                                 ...         ...
# 3224                                                NaN         NaN
# 3225                                                NaN         NaN
# 3226                Homolog to the human gene in Recon1         NaN
# 3227  PMID:7945246 shows mono and di gluconidation o...         NaN
# 3228  PMID: 11130984 describes the presence of the r...         NaN
#
# [3229 rows x 7 columns]

# %%
# Read the model using the cobrapy library
model = read_sbml_model('../Data/iCHOv1_final.xml')

# Create dataframe from the model with the attributes that we are interested in
attributes = []
for reaction in tqdm(model.reactions):
    attributes.append([reaction.id, reaction.name, reaction.reaction, reaction.gpr, 
                       reaction.subsystem, reaction.lower_bound, reaction.upper_bound])

df2 = pd.DataFrame(data=attributes, columns=['Reaction', 'Reaction Name', 'Reaction Formula', 'GPR', 'Subsystem', 'Lower bound', 'Upper bound'])
df2
# Out:
#   0%|          | 0/6663 [00:00<?, ?it/s]
#               Reaction                                      Reaction Name  \
# 0            COKECBESr                    Carboxylesterase (cocaine) (er)
# 1              EGMESTr                      ecgonine methyl esterase (ER)
# 2             NMPTRCOX  N-Methylputrescine:oxygen oxidoreductase (deam...
# 3                PRO1x                     L-ProlineNAD+ 5-oxidoreductase
# 4                DHDDH                          Dihydrodiol dehydrogenase
# ...                ...                                                ...
# 6658        DM_sprm_c_                                         DM_sprm[c]
# 6659       DM_yvite_c_                                        DM_yvite[c]
# 6660  DM_56iqcrbxlt_c_                                   DM_56iqcrbxlt[c]
# 6661         DM_atp_c_                                    ATP maintenance
# 6662    SK_pre_prot_r_                                   sink_pre_prot[r]
#
#                                      Reaction Formula  \
# 0              coke_r + h2o_r --> bz_r + egme_r + h_r
# 1           egme_r + h2o_r --> ecgon_r + h_r + meoh_r
# 2        nmptrc_c + o2_c --> 1mpyr_c + h2o2_c + nh4_c
# 3     nad_c + pro_L_c --> 1pyr5c_c + 2.0 h_c + nadh_c
# 4          dhnpthld_c + nadp_c --> nadph_c + npthld_c
# ...                                               ...
# 6658                                      sprm_c -->
# 6659                                     yvite_c -->
# 6660                                56iqcrbxlt_c -->
# 6661             atp_c + h2o_c --> adp_c + h_c + pi_c
# 6662                                  pre_prot_r <=>
#
#                                                    GPR  \
# 0                               100756666 or 100767789
# 1                                            100771815
# 2     100771382 or 100762635 or 100762926 or 100763954
# 3                                            100773901
# 4                                            100753544
# ...                                                ...
# 6658
# 6659
# 6660
# 6661
# 6662
#
#                             Subsystem  Lower bound  Upper bound
# 0                  ALKALOID SYNTHESIS          0.0       1000.0
# 1                  ALKALOID SYNTHESIS          0.0       1000.0
# 2                  ALKALOID SYNTHESIS          0.0       1000.0
# 3     ARGININE AND PROLINE METABOLISM          0.0       1000.0
# 4                      CYP METABOLISM          0.0       1000.0
# ...                               ...          ...          ...
# 6658                           DEMAND          0.0       1000.0
# 6659                           DEMAND          0.0       1000.0
# 6660                           DEMAND          0.0       1000.0
# 6661                           DEMAND          0.0       1000.0
# 6662                             SINK         -0.1       1000.0
#
# [6663 rows x 7 columns]

# %% [markdown]
# ### df1 has 3229 reactions while df2 contains 6663 reactions

# %%
# Unify number of columns
df1 = df1.reindex(columns = df1.columns.tolist() + ['Lower bound','Upper bound'])
df2 = df2.reindex(columns = df2.columns.tolist() + ['Curation Notes','References'])

# Unify order of columns
df1 = df1[['Reaction', 'Reaction Name', 'Reaction Formula', 'GPR', 'Subsystem', 'Lower bound', 'Upper bound', 'Curation Notes', 'References']]
df2 = df2[['Reaction', 'Reaction Name', 'Reaction Formula', 'GPR', 'Subsystem', 'Lower bound', 'Upper bound', 'Curation Notes', 'References']]

# %%
# Merge both datasets 
hefzi_df = pd.concat([df2, df1])
hefzi_df = hefzi_df.reset_index(drop = True)
hefzi_final = hefzi_df.groupby('Reaction').first()

hefzi_final.to_excel('../Data/hefzi_final.xlsx')

# %%
hefzi_final
# Out:
#                                            Reaction Name  \
# Reaction
# 10FTHF5GLUtl      5-glutamyl-10FTHF transport, lysosomal
# 10FTHF5GLUtm  5-glutamyl-10FTHF transport, mitochondrial
# 10FTHF6GLUtl      6-glutamyl-10FTHF transport, lysosomal
# 10FTHF6GLUtm  6-glutamyl-10FTHF transport, mitochondrial
# 10FTHF7GLUtl      7-glutamyl-10FTHF transport, lysosomal
# ...                                                  ...
# r2534             Major Facilitator(MFS) TCDB:2.A.1.44.1
# r2535             Major Facilitator(MFS) TCDB:2.A.1.44.1
# r2537                                 Utilized transport
# r2538                                 Utilized transport
# r2539                      Postulated transport reaction
#
#                                                Reaction Formula GPR  \
# Reaction
# 10FTHF5GLUtl                      10fthf5glu_c --> 10fthf5glu_l
# 10FTHF5GLUtm                      10fthf5glu_m --> 10fthf5glu_c
# 10FTHF6GLUtl                      10fthf6glu_c --> 10fthf6glu_l
# 10FTHF6GLUtm                      10fthf6glu_m --> 10fthf6glu_c
# 10FTHF7GLUtl                      10fthf7glu_c --> 10fthf7glu_l
# ...                                                         ...  ..
# r2534                                       thr_L_e <=> thr_L_c
# r2535                                       hom_L_e <=> hom_L_c
# r2537                               lnlncgcoa_c <=> lnlncgcoa_r
# r2538                               dlnlcgcoa_c <=> dlnlcgcoa_r
# r2539         L2aadp6sa_c + L2aadp_m <=> L2aadp6sa_m + L2aadp_c
#
#                                      Subsystem  Lower bound  Upper bound  \
# Reaction
# 10FTHF5GLUtl              TRANSPORT, LYSOSOMAL          0.0       1000.0
# 10FTHF5GLUtm          TRANSPORT, MITOCHONDRIAL          0.0       1000.0
# 10FTHF6GLUtl              TRANSPORT, LYSOSOMAL          0.0       1000.0
# 10FTHF6GLUtm          TRANSPORT, MITOCHONDRIAL          0.0       1000.0
# 10FTHF7GLUtl              TRANSPORT, LYSOSOMAL          0.0       1000.0
# ...                                        ...          ...          ...
# r2534                 TRANSPORT, EXTRACELLULAR      -1000.0       1000.0
# r2535                 TRANSPORT, EXTRACELLULAR      -1000.0       1000.0
# r2537         TRANSPORT, ENDOPLASMIC RETICULAR      -1000.0       1000.0
# r2538         TRANSPORT, ENDOPLASMIC RETICULAR      -1000.0       1000.0
# r2539                 TRANSPORT, MITOCHONDRIAL      -1000.0       1000.0
#
#              Curation Notes  References
# Reaction
# 10FTHF5GLUtl           None         NaN
# 10FTHF5GLUtm           None         NaN
# 10FTHF6GLUtl           None         NaN
# 10FTHF6GLUtm           None         NaN
# 10FTHF7GLUtl           None         NaN
# ...                     ...         ...
# r2534                  None         NaN
# r2535                  None         NaN
# r2537                  None         NaN
# r2538                  None         NaN
# r2539                  None         NaN
#
# [6663 rows x 8 columns]

# %%
model
# Out:
# <Model iCHOv1 at 0x132dea9e0>

# %%
# Generate stoichiometric matrix

matrix = create_stoichiometric_matrix(model, array_type = 'DataFrame')
matrix['10FTHF7GLUtl'][matrix['10FTHF7GLUtl'] != 0.0]
# Out:
# 10fthf7glu_l    1.0
# 10fthf7glu_c   -1.0
# Name: 10FTHF7GLUtl, dtype: float64

# %%
#Checking mass balance for each reaction

mb = cobra.manipulation.check_mass_balance(model)

for key in mb:
    print(f'{key} = {mb[key]}')
print(len(mb))
# Out:
# DHDDH: dhnpthld_c + nadp_c --> nadph_c + npthld_c = {'charge': -1.0, 'H': 1.0}
# EPOH: h2o_c + onpthl_c --> dhnpthld_c = {'H': -10.0, 'O': -2.0, 'C': -10.0, 'X': 1.0}
# CHOLESTle: h2o_e + xolest2_cho_e --> Rtotal_e + chsterol_e + h_e = {'R': -1.0}
# DASCBH_cho: dhdascb_c + h2o_c --> 23doguln_c = {'charge': -1.0}
# DASCBR: dhdascb_c + h_c + nadph_c --> ascb_L_c + nadp_c = {'charge': -1.0}
# GTHDH: dhdascb_c + 2.0 gthrd_c --> ascb_L_c + gthox_c = {'charge': -1.0}
# DMARG: dmarg_c + h2o_c <=> citr_L_c + dma_c + h_c = {'charge': 1.0}
# CHOLESACATc: Rtotalcoa_c + chsterol_c --> coa_c + xolest2_cho_c = {'R': 1.0}
# F6T2g: gdpfuc_g + nm4masn_g --> fnm4masn_g + gdp_g + h_g = {'C': -60.0, 'H': -100.0, 'N': -3.0, 'O': -44.0}
# F6T3g: gdpfuc_g + nm2masn_g --> fnm2masn_g + gdp_g + h_g = {'C': -48.0, 'H': -80.0, 'N': -3.0, 'O': -34.0}
# F6T4g: gdpfuc_g + n3m2masn_g --> fn3m2masn_g + gdp_g + h_g = {'C': -64.0, 'H': -106.0, 'N': -5.0, 'O': -44.0}
# F6T5g: gdpfuc_g + n4m2masn_g --> fn4m2masn_g + gdp_g + h_g = {'C': -72.0, 'H': -119.0, 'N': -6.0, 'O': -49.0}
# F6T6g: gdpfuc_g + n3rm2masn_g --> fn3rm2masn_g + gdp_g + h_g = {'C': -6.0, 'H': -10.0, 'O': -4.0}
# G14N10g: ndl4fn4m2masn_g + udpgal_g --> h_g + lndl4fn4m2masn_g + udp_g = {'C': -6.0, 'H': -10.0, 'O': -5.0}
# G14N11g: ndl4n4m2masn_g + udpgal_g --> h_g + lndl4n4m2masn_g + udp_g = {'C': -6.0, 'H': -10.0, 'O': -5.0}
# G14N12g: ncl4fn4m2masn_g + udpgal_g --> h_g + lncl4fn4m2masn_g + udp_g = {'C': -6.0, 'H': -10.0, 'O': -5.0}
# G14N13g: ncl4n4m2masn_g + udpgal_g --> h_g + lncl4n4m2masn_g + udp_g = {'C': -6.0, 'H': -10.0, 'O': -5.0}
# G14N14g: nbl4fn4m2masn_g + udpgal_g --> h_g + lnbl4fn4m2masn_g + udp_g = {'C': -6.0, 'H': -10.0, 'O': -5.0}
# G14N15g: nbl4n4m2masn_g + udpgal_g --> h_g + lnbl4n4m2masn_g + udp_g = {'C': -6.0, 'H': -10.0, 'O': -5.0}
# G14N16g: n2cdl4fn4m2masn_g + 2.0 udpgal_g --> 2.0 h_g + l2n2cdl4fn4m2masn_g + 2.0 udp_g = {'C': -12.0, 'H': -20.0, 'O': -10.0}
# G14N17g: n2cdl4n4m2masn_g + 2.0 udpgal_g --> 2.0 h_g + l2n2cdl4n4m2masn_g + 2.0 udp_g = {'C': -12.0, 'H': -20.0, 'O': -10.0}
# G14N18g: n2bdl4fn4m2masn_g + 2.0 udpgal_g --> 2.0 h_g + l2n2bdl4fn4m2masn_g + 2.0 udp_g = {'C': -12.0, 'H': -20.0, 'O': -10.0}
# G14N19g: n2bdl4n4m2masn_g + 2.0 udpgal_g --> 2.0 h_g + l2n2bdl4n4m2masn_g + 2.0 udp_g = {'C': -12.0, 'H': -20.0, 'O': -10.0}
# G14N1g: n2m2masn_g + 2.0 udpgal_g --> 2.0 h_g + l2n2m2masn_g + 2.0 udp_g = {'C': -62.0, 'H': -103.0, 'N': -4.0, 'O': -45.0}
# G14N20g: n3l4fn4m2masn_g + 3.0 udpgal_g --> 3.0 h_g + l3n3l4fn4m2masn_g + 3.0 udp_g = {'C': -18.0, 'H': -30.0, 'O': -15.0}
# G14N21g: n3l4n4m2masn_g + 3.0 udpgal_g --> 3.0 h_g + l3n3l4n4m2masn_g + 3.0 udp_g = {'C': -18.0, 'H': -30.0, 'O': -15.0}
# G14N2g: n3m2masn_g + 3.0 udpgal_g --> 3.0 h_g + l3n3m2masn_g + 3.0 udp_g = {'C': -76.0, 'H': -126.0, 'N': -5.0, 'O': -55.0}
# G14N3g: n3rm2masn_g + 3.0 udpgal_g --> 3.0 h_g + l3n3rm2masn_g + 3.0 udp_g = {'C': -18.0, 'H': -30.0, 'O': -15.0}
# G14N4g: fn3m2masn_g + 3.0 udpgal_g --> 3.0 h_g + l3fn3m2masn_g + 3.0 udp_g = {'C': -18.0, 'H': -30.0, 'O': -15.0}
# G14N5g: fn3rm2masn_g + 3.0 udpgal_g --> 3.0 h_g + l3fn3rm2masn_g + 3.0 udp_g = {'C': -18.0, 'H': -30.0, 'O': -15.0}
# G14N6g: fn4m2masn_g + 4.0 udpgal_g --> 4.0 h_g + l4fn4m2masn_g + 4.0 udp_g = {'C': -24.0, 'H': -40.0, 'O': -20.0}
# G14N7g: nl3n3m2masn_g + udpgal_g --> h_g + lnl3n3m2masn_g + udp_g = {'C': -6.0, 'H': -10.0, 'O': -5.0}
# G14N8g: n4m2masn_g + 4.0 udpgal_g --> 4.0 h_g + l4n4m2masn_g + 4.0 udp_g = {'C': -90.0, 'H': -149.0, 'N': -6.0, 'O': -65.0}
# G14N9g: nl3fn3m2masn_g + udpgal_g --> h_g + lnl3fn3m2masn_g + udp_g = {'C': -6.0, 'H': -10.0, 'O': -5.0}
# M1316M2g: fnm4masn_g + h2o_g --> fnm2masn_g + 2.0 man_g = {'H': 22.0, 'O': 11.0, 'C': 12.0}
# M13N14N3T1g: l3n3m2masn_g + uacgam_g --> h_g + nl3n3m2masn_g + udp_g = {'C': -8.0, 'H': -13.0, 'N': -1.0, 'O': -5.0}
# M13N14N3T2g: l3fn3m2masn_g + uacgam_g --> h_g + nl3fn3m2masn_g + udp_g = {'C': -8.0, 'H': -13.0, 'N': -1.0, 'O': -5.0}
# M13N14N3T3g: l4n4m2masn_g + uacgam_g --> h_g + nbl4n4m2masn_g + udp_g = {'C': -8.0, 'H': -13.0, 'N': -1.0, 'O': -5.0}
# M13N14N3T4g: l4fn4m2masn_g + uacgam_g --> h_g + nbl4fn4m2masn_g + udp_g = {'C': -8.0, 'H': -13.0, 'N': -1.0, 'O': -5.0}
# M13N4T1g: fn2m2masn_g + uacgam_g --> fn3m2masn_g + h_g + udp_g = {'C': -64.0, 'H': -106.0, 'N': -5.0, 'O': -44.0}
# M13N4T2g: n3rm2masn_g + uacgam_g --> h_g + n4m2masn_g + udp_g = {'C': 58.0, 'H': 96.0, 'N': 5.0, 'O': 40.0}
# M13N4T3g: fn3rm2masn_g + uacgam_g --> fn4m2masn_g + h_g + udp_g = {'C': -8.0, 'H': -13.0, 'N': -1.0, 'O': -5.0}
# M1613N1614N3T1g: l4n4m2masn_g + 2.0 uacgam_g --> 2.0 h_g + n2bdl4n4m2masn_g + 2.0 udp_g = {'C': -16.0, 'H': -26.0, 'N': -2.0, 'O': -10.0}
# M1613N1614N3T2g: l4fn4m2masn_g + 2.0 uacgam_g --> 2.0 h_g + n2bdl4fn4m2masn_g + 2.0 udp_g = {'C': -16.0, 'H': -26.0, 'N': -2.0, 'O': -10.0}
# M1613N3xN3T1g: l4n4m2masn_g + 3.0 uacgam_g --> 3.0 h_g + n3l4n4m2masn_g + 3.0 udp_g = {'C': -24.0, 'H': -39.0, 'N': -3.0, 'O': -15.0}
# M1613N3xN3T2g: l4fn4m2masn_g + 3.0 uacgam_g --> 3.0 h_g + n3l4fn4m2masn_g + 3.0 udp_g = {'C': -24.0, 'H': -39.0, 'N': -3.0, 'O': -15.0}
# M16N1216N3T1g: l4n4m2masn_g + 2.0 uacgam_g --> 2.0 h_g + n2cdl4n4m2masn_g + 2.0 udp_g = {'C': -16.0, 'H': -26.0, 'N': -2.0, 'O': -10.0}
# M16N1216N3T2g: l4fn4m2masn_g + 2.0 uacgam_g --> 2.0 h_g + n2cdl4fn4m2masn_g + 2.0 udp_g = {'C': -16.0, 'H': -26.0, 'N': -2.0, 'O': -10.0}
# M16N12N3T1g: l4n4m2masn_g + uacgam_g --> h_g + ncl4n4m2masn_g + udp_g = {'C': -8.0, 'H': -13.0, 'N': -1.0, 'O': -5.0}
# M16N12N3T2g: l4fn4m2masn_g + uacgam_g --> h_g + ncl4fn4m2masn_g + udp_g = {'C': -8.0, 'H': -13.0, 'N': -1.0, 'O': -5.0}
# M16N16N3T1g: l4n4m2masn_g + uacgam_g --> h_g + ndl4n4m2masn_g + udp_g = {'C': -8.0, 'H': -13.0, 'N': -1.0, 'O': -5.0}
# M16N16N3T2g: l4fn4m2masn_g + uacgam_g --> h_g + ndl4fn4m2masn_g + udp_g = {'C': -8.0, 'H': -13.0, 'N': -1.0, 'O': -5.0}
# M16N6T1g: fn3m2masn_g + uacgam_g --> fn4m2masn_g + h_g + udp_g = {'C': -8.0, 'H': -13.0, 'N': -1.0, 'O': -5.0}
# M16N6T2g: n2m2masn_g + uacgam_g --> h_g + n3rm2masn_g + udp_g = {'C': -58.0, 'H': -96.0, 'N': -5.0, 'O': -40.0}
# M16N6T3g: fn2m2masn_g + uacgam_g --> fn3rm2masn_g + h_g + udp_g = {'C': -64.0, 'H': -106.0, 'N': -5.0, 'O': -44.0}
# M16NT1g: fnm2masn_g + uacgam_g --> fn2m2masn_g + h_g + udp_g = {'C': 48.0, 'H': 80.0, 'N': 3.0, 'O': 34.0}
# S23TN10g: 3.0 cmpacna_g + lnl3fn3m2masn_g --> 3.0 cmp_g + 3.0 h_g + s3lnl3fn3m2masn_g = {'C': -33.0, 'H': -48.0, 'N': -3.0, 'O': -24.0}
# S23TN11g: 4.0 cmpacna_g + lndl4fn4m2masn_g --> 4.0 cmp_g + 4.0 h_g + s4lndl4fn4m2masn_g = {'C': -44.0, 'H': -64.0, 'N': -4.0, 'O': -32.0}
# S23TN12g: 4.0 cmpacna_g + lndl4n4m2masn_g --> 4.0 cmp_g + 4.0 h_g + s4lndl4n4m2masn_g = {'C': -44.0, 'H': -64.0, 'N': -4.0, 'O': -32.0}
# S23TN13g: 4.0 cmpacna_g + lncl4fn4m2masn_g --> 4.0 cmp_g + 4.0 h_g + s4lncl4fn4m2masn_g = {'C': -44.0, 'H': -64.0, 'N': -4.0, 'O': -32.0}
# S23TN14g: 4.0 cmpacna_g + lncl4n4m2masn_g --> 4.0 cmp_g + 4.0 h_g + s4lncl4n4m2masn_g = {'C': -44.0, 'H': -64.0, 'N': -4.0, 'O': -32.0}
# S23TN15g: 4.0 cmpacna_g + lnbl4fn4m2masn_g --> 4.0 cmp_g + 4.0 h_g + s4lnbl4fn4m2masn_g = {'C': -44.0, 'H': -64.0, 'N': -4.0, 'O': -32.0}
# S23TN16g: 4.0 cmpacna_g + lnbl4n4m2masn_g --> 4.0 cmp_g + 4.0 h_g + s4lnbl4n4m2masn_g = {'C': -44.0, 'H': -64.0, 'N': -4.0, 'O': -32.0}
# S23TN17g: 4.0 cmpacna_g + l2n2cdl4fn4m2masn_g --> 4.0 cmp_g + 4.0 h_g + s4l2n2cdl4fn4m2masn_g = {'C': -44.0, 'H': -64.0, 'N': -4.0, 'O': -32.0}
# S23TN18g: 4.0 cmpacna_g + l2n2cdl4n4m2masn_g --> 4.0 cmp_g + 4.0 h_g + s4l2n2cdl4n4m2masn_g = {'C': -44.0, 'H': -64.0, 'N': -4.0, 'O': -32.0}
# S23TN19g: 4.0 cmpacna_g + l2n2bdl4fn4m2masn_g --> 4.0 cmp_g + 4.0 h_g + s4l2n2bdl4fn4m2masn_g = {'C': -44.0, 'H': -64.0, 'N': -4.0, 'O': -32.0}
# S23TN20g: 4.0 cmpacna_g + l2n2bdl4n4m2masn_g --> 4.0 cmp_g + 4.0 h_g + s4l2n2bdl4n4m2masn_g = {'C': -44.0, 'H': -64.0, 'N': -4.0, 'O': -32.0}
# S23TN21g: 4.0 cmpacna_g + l3n3l4fn4m2masn_g --> 4.0 cmp_g + 4.0 h_g + s4l3n3l4fn4m2masn_g = {'C': -44.0, 'H': -64.0, 'N': -4.0, 'O': -32.0}
# S23TN22g: 4.0 cmpacna_g + l3n3l4n4m2masn_g --> 4.0 cmp_g + 4.0 h_g + s4l3n3l4n4m2masn_g = {'C': -44.0, 'H': -64.0, 'N': -4.0, 'O': -32.0}
# S23TN2g: 2.0 cmpacna_g + l2n2m2masn_g --> 2.0 cmp_g + 2.0 h_g + s2l2n2m2masn_g = {'C': 62.0, 'H': 103.0, 'N': 4.0, 'O': 45.0}
# S23TN3g: 3.0 cmpacna_g + l3n3m2masn_g --> 3.0 cmp_g + 3.0 h_g + s3l3n3m2masn_g = {'C': -33.0, 'H': -48.0, 'N': -3.0, 'O': -24.0}
# S23TN4g: 3.0 cmpacna_g + l3n3rm2masn_g --> 3.0 cmp_g + 3.0 h_g + s3l3n3rm2masn_g = {'C': -33.0, 'H': -48.0, 'N': -3.0, 'O': -24.0}
# S23TN5g: 3.0 cmpacna_g + l3fn3m2masn_g --> 3.0 cmp_g + 3.0 h_g + s3l3fn3m2masn_g = {'C': -33.0, 'H': -48.0, 'N': -3.0, 'O': -24.0}
# S23TN6g: 3.0 cmpacna_g + l3fn3rm2masn_g --> 3.0 cmp_g + 3.0 h_g + s3l3fn3rm2masn_g = {'C': -33.0, 'H': -48.0, 'N': -3.0, 'O': -24.0}
# S23TN7g: 4.0 cmpacna_g + l4fn4m2masn_g --> 4.0 cmp_g + 4.0 h_g + s4l4fn4m2masn_g = {'C': -44.0, 'H': -64.0, 'N': -4.0, 'O': -32.0}
# S23TN8g: 3.0 cmpacna_g + lnl3n3m2masn_g --> 3.0 cmp_g + 3.0 h_g + s3lnl3n3m2masn_g = {'C': -33.0, 'H': -48.0, 'N': -3.0, 'O': -24.0}
# S23TN9g: 4.0 cmpacna_g + l4n4m2masn_g --> 4.0 cmp_g + 4.0 h_g + s4l4n4m2masn_g = {'C': -44.0, 'H': -64.0, 'N': -4.0, 'O': -32.0}
# ST3GAL23g_cho: cmpacna_g + gd1b_cho_g --> cmp_g + gt1b_cho_g + h_g = {'F': 1.0, 'U': 1.0, 'L': 2.0}
# RN0020R: C07535_r + h_r + nadph_r + o2_r --> CN0012_r + h2o_r + nadp_r = {'C': -20.0, 'H': -12.0, 'O': -1.0, 'X': 1.0}
# RN0021C: CN0012_c + h2o_c <=> CN0009_c = {'H': -2.0, 'O': -1.0}
# RN0021R: CN0012_r + h2o_r <=> CN0009_r + 2.0 h_r = {'charge': 2.0, 'O': -1.0}
# RN0021X: CN0012_x + h2o_x <=> CN0009_x + 2.0 h_x = {'charge': 2.0, 'O': -1.0}
# RN0022C: C14851_c + h2o_c <=> CN0010_c = {'C': -20.0, 'H': -14.0, 'O': -2.0, 'X': 1.0}
# RN0022R: C14851_r + h2o_r <=> CN0010_r + 2.0 h_r = {'charge': 2.0, 'C': -20.0, 'H': -12.0, 'O': -2.0, 'X': 1.0}
# RN0022X: C14851_x + h2o_x <=> CN0010_x + 2.0 h_x = {'charge': 2.0, 'C': -20.0, 'H': -12.0, 'O': -2.0, 'X': 1.0}
# RN0023C: C14849_c + h2o_c <=> CN0011_c = {'C': -20.0, 'H': -14.0, 'O': -2.0, 'X': 1.0}
# RN0023R: C14849_r + h2o_r <=> CN0011_r + 2.0 h_r = {'charge': 2.0, 'C': -20.0, 'H': -12.0, 'O': -2.0, 'X': 1.0}
# RN0023X: C14849_x + h2o_x <=> CN0011_x + 2.0 h_x = {'charge': 2.0, 'C': -20.0, 'H': -12.0, 'O': -2.0, 'X': 1.0}
# RN0027R: CN0020_r + 3.0 h_r + nadph_r + o2_r --> CN0021_r + h2o_r + nadp_r = {'charge': -2.0, 'C': -20.0, 'H': -18.0, 'O': -1.0, 'X': 1.0}
# RN0028C: CN0021_c + h2o_c <=> CN0022_c = {'H': -2.0, 'O': -1.0}
# RN0028R: CN0021_r + h2o_r <=> CN0022_r = {'H': -2.0, 'O': -1.0}
# RN0028X: CN0021_x + h2o_x <=> CN0022_x = {'H': -2.0, 'O': -1.0}
# RN0029R: CN0022_r + nadph_r + o2_r --> CN0023_r + h2o_r + h_r + nadp_r = {'charge': 2.0, 'H': 2.0, 'O': -1.0}
# RN0030R: CN0016_r + 3.0 h_r + nadph_r + o2_r --> CN0017_r + h2o_r + nadp_r = {'charge': -2.0, 'C': -24.0, 'H': -16.0, 'O': -1.0, 'X': 1.0}
# RN0031C: CN0017_c + h2o_c <=> CN0018_c = {'H': -2.0, 'O': -1.0}
# RN0031R: CN0017_r + h2o_r <=> CN0018_r = {'H': -2.0, 'O': -1.0}
# RN0031X: CN0017_x + h2o_x <=> CN0018_x = {'H': -2.0, 'O': -1.0}
# RN0032R: CN0018_r + nadph_r + o2_r --> CN0019_r + h2o_r + h_r + nadp_r = {'charge': 2.0, 'H': 2.0, 'O': -1.0}
# ARD1_cho: dhmtp_c + o2_c --> 2kmb_c + for_c + 2.0 h_c = {'charge': 1.0}
# ARS_cho: dkmpp_c + h2o_c --> dhmtp_c + pi_c = {'charge': -1.0}
# PCLGALTr: pcollg5hlys_c + udpgal_c --> pcollg5glys_c + udp_c = {'C': -12.0, 'H': -25.0, 'N': -2.0, 'O': -8.0, 'X': 1.0}
# PLYSPSer: Ntmelys_r + h2o_r --> pepslys_r + tmlys_r = {'charge': -2.0, 'C': 6.0, 'H': 8.0, 'O': 1.0, 'N': 2.0}
# TMLYSOX: akg_c + o2_c + tmlys_c --> 3htmelys_c + co2_c + succ_c = {'charge': -1.0}
# RE3111M: C04295_m + h_m + nad_m <=> 5adtststerone_m + nadh_m = {'charge': -2.0}
# RE3111R: C04295_r + h_r + nad_r <=> 5adtststerone_r + nadh_r = {'charge': -2.0}
# FUT32g_cho: acngalacglcgalgluside_cho_g + gdpfuc_g --> fucacngalacglcgalgluside_cho_g + gdp_g + h_g = {'F': 1.0, 'U': 1.0, 'L': 2.0}
# ST3GAL62g_cho: cmpacna_g + galacglcgal14acglcgalgluside_cho_g --> acngalacglcgal14acglcgalgluside_cho_g + cmp_g + h_g = {'F': -1.0, 'U': -1.0, 'L': -2.0}
# PTGFS: prostgh2_c + trdox_c --> prostgf2_c + trdrd_c = {'H': 4.0}
# r0792: 5mthf_c + nad_c <=> 2.0 h_c + mlthf_c + nadh_c = {'charge': 1.0}
# RE3511M: C04308_m + amet_m --> ahcys_m + pchol_cho_m = {'R': 1.0, 'F': 2.0, 'U': 2.0, 'L': 4.0}
# RE3511R: C04308_r + amet_r --> ahcys_r + pchol_cho_r = {'R': 1.0, 'F': 2.0, 'U': 2.0, 'L': 4.0}
# PpGppP: gdp_c + ppi_c <=> gbdp_c + h2o_c = {'charge': 1.0}
# r0432: HC10859_m + coa_m --> crn_m + malcoa_m = {'charge': -1.0, 'X': -1.0, 'C': 10.0, 'H': 16.0, 'N': 1.0, 'O': 6.0}
# RE2722C: galgluside_cho_c + paps_c --> C03405_c + pap_c = {'F': -1.0, 'U': -1.0, 'L': -2.0}
# RE2722G: galgluside_cho_g + paps_g --> C03405_g + pap_g = {'F': -1.0, 'U': -1.0, 'L': -2.0}
# CYOOm3_cho: 4.0 focytC_m + 7.92 h_m + o2_m --> 4.0 ficytC_m + 1.96 h2o_m + 4.0 h_im + 0.02 o2s_m = {'charge': 0.06000000000000007, 'H': 1.2434497875801753e-14, 'O': -3.469446951953614e-17}
# C81_5ZCPTx: c81_5Zcoa_x + crn_x --> c81_5Zcrn_x + coa_x = {'charge': -4.0}
# B3GALT43g_cho: gd2_cho_g + udpgal_g --> gd1b_cho_g + h_g + udp_g = {'F': -1.0, 'U': -1.0, 'L': -2.0}
# METS: 5mthf_c + hcys_L_c --> h_c + met_L_c + thf_c = {'charge': 1.0}
# MTHFR3: 2.0 h_c + mlthf_c + nadph_c --> 5mthf_c + nadp_c = {'charge': -1.0}
# ST3GAL31g_cho: cmpacna_g + galacglcgalgluside_cho_g --> acngalacglcgalgluside_cho_g + cmp_g + h_g = {'F': -1.0, 'U': -1.0, 'L': -2.0}
# BAAT4x_cho: dcholcoa_x + gly_x --> coa_x + dgchol_x = {'charge': -1.0}
# DOPABMO: ascb_L_c + dopa_c + o2_c --> dhdascb_c + h2o_c + nrpphr_c = {'charge': 1.0}
# FE3R2e: ascb_L_e + 2.0 fe3_e --> dhdascb_e + 2.0 fe2_e + 2.0 h_e = {'charge': 1.0}
# EX_HC01610_e_: cpppg1_e -->  = {'charge': 4.0, 'C': -36.0, 'H': -40.0, 'N': -4.0, 'O': -8.0}
# EX_HC02179_e_: wharachd_e -->  = {'charge': 1.0, 'C': -20.0, 'H': -31.0, 'O': -3.0}
# EX_C05965_e_: 12HPET_e -->  = {'charge': 1.0, 'C': -20.0, 'H': -31.0, 'O': -4.0}
# EX_HC02176_e_: ddca_e -->  = {'charge': 1.0, 'C': -12.0, 'H': -23.0, 'O': -2.0}
# ARTFR33_cho: 0.125 coa_m + fadh2_m + vacccoa_c --> 1.125 R3coa_cho_c + fad_m = {'C': -16.875, 'H': -35.125, 'O': 0.125, 'X': 1.125}
# ARTFR43_cho: 0.125 coa_m + fadh2_m + vacccoa_c --> 1.125 R4coa_cho_c + fad_m = {'C': -16.875, 'H': -35.125, 'O': 0.125, 'X': 1.125}
# EX_tdcrn: ttdcrn_e -->  = {'C': -21.0, 'H': -41.0, 'N': -1.0, 'O': -4.0}
# ARTFR51_cho: 0.5 coa_m + lgnccoa_c --> 1.5 R5coa_cho_c = {'C': -22.5, 'H': -47.5, 'O': 0.5, 'X': 1.5}
# AGLPET_cho: ak2g_cho_c + cdpea_c + h_c <=> ak2gpe_cho_c + cmp_c + h2o_c = {'charge': -2.0}
# ARTFR11_cho: pmtcoa_c --> R1coa_cho_c = {'C': -15.0, 'H': -31.0, 'X': 1.0}
# ARTFR12_cho: fadh2_m + hdcoa_c --> R1coa_cho_c + fad_m = {'C': -15.0, 'H': -31.0, 'X': 1.0}
# ARTFR13_cho: tdcoa_c --> 0.875 R1coa_cho_c + 0.125 coa_m = {'C': -13.125, 'H': -26.875, 'O': -0.125, 'X': 0.875}
# ARTFR202_cho: 0.125 coa_m + 2.0 fadh2_m + h_m + lnlncacoa_c + nadph_m --> 1.125 R2coa_cho_c + 2.0 fad_m + nadp_m = {'C': -16.875, 'H': -35.125, 'O': 0.125, 'X': 1.125}
# ARTFR203_cho: 0.125 coa_m + 2.0 fadh2_m + h_m + lnlncgcoa_c + nadph_m --> 1.125 R2coa_cho_c + 2.0 fad_m + nadp_m = {'C': -16.875, 'H': -35.125, 'O': 0.125, 'X': 1.125}
# ARTFR204_cho: 0.125 coa_m + 2.0 fadh2_m + 2.0 h_m + 2.0 nadph_m + strdnccoa_c --> 1.125 R2coa_cho_c + 2.0 fad_m + 2.0 nadp_m = {'C': -16.875, 'H': -35.125, 'O': 0.125, 'X': 1.125}
# ARTFR205_cho: 0.25 coa_m + dlnlcgcoa_c + 2.0 fadh2_m + h_m + nadph_m --> 1.25 R2coa_cho_c + 2.0 fad_m + nadp_m = {'C': -18.75, 'H': -39.25, 'O': 0.25, 'X': 1.25}
# ARTFR206_cho: arachdcoa_c + 0.25 coa_m + 2.0 fadh2_m + 2.0 h_m + 2.0 nadph_m --> 1.25 R2coa_cho_c + 2.0 fad_m + 2.0 nadp_m = {'C': -18.75, 'H': -39.25, 'O': 0.25, 'X': 1.25}
# ARTFR207_cho: arachcoa_c + 0.25 coa_m --> 1.25 R2coa_cho_c = {'C': -18.75, 'H': -39.25, 'O': 0.25, 'X': 1.25}
# ARTFR208_cho: 0.25 coa_m + 3.0 fadh2_m + 2.0 h_m + 2.0 nadph_m + tmndnccoa_c --> 1.25 R2coa_cho_c + 3.0 fad_m + 2.0 nadp_m = {'C': -18.75, 'H': -39.25, 'O': 0.25, 'X': 1.25}
# ARTFR209_cho: adrncoa_c + 0.375 coa_m + 2.0 fadh2_m + 2.0 h_m + 2.0 nadph_m --> 1.375 R2coa_cho_c + 2.0 fad_m + 2.0 nadp_m = {'C': -20.625, 'H': -43.375, 'O': 0.375, 'X': 1.375}
# ARTFR210_cho: 0.125 coa_m + fadh2_m + h_m + lnlccoa_c + nadph_m --> 1.125 R2coa_cho_c + fad_m + nadp_m = {'C': -16.875, 'H': -35.125, 'O': 0.125, 'X': 1.125}
# ARTFR211_cho: clpndcoa_c + 0.375 coa_m + 3.0 fadh2_m + 2.0 h_m + 2.0 nadph_m --> 1.375 R2coa_cho_c + 3.0 fad_m + 2.0 nadp_m = {'C': -20.625, 'H': -43.375, 'O': 0.375, 'X': 1.375}
# ARTFR212_cho: 0.375 coa_m + dcsptn1coa_c + 3.0 fadh2_m + 2.0 h_m + 2.0 nadph_m --> 1.375 R2coa_cho_c + 3.0 fad_m + 2.0 nadp_m = {'C': -20.625, 'H': -43.375, 'O': 0.375, 'X': 1.375}
# ARTFR213_cho: c226coa_c + 0.375 coa_m + 3.0 fadh2_m + 3.0 h_m + 3.0 nadph_m --> 1.375 R2coa_cho_c + 3.0 fad_m + 3.0 nadp_m = {'C': -20.625, 'H': -43.375, 'O': 0.375, 'X': 1.375}
# ARTFR31_cho: 0.125 coa_m + stcoa_c --> 1.125 R3coa_cho_c = {'C': -16.875, 'H': -35.125, 'O': 0.125, 'X': 1.125}
# ARTFR32_cho: 0.125 coa_m + fadh2_m + odecoa_c --> 1.125 R3coa_cho_c + fad_m = {'C': -16.875, 'H': -35.125, 'O': 0.125, 'X': 1.125}
# ARTFR34_cho: 0.125 coa_m + 2.0 fadh2_m + lneldccoa_c --> 1.125 R3coa_cho_c + 2.0 fad_m = {'C': -16.875, 'H': -35.125, 'O': 0.125, 'X': 1.125}
# ARTFR41_cho: fadh2_m + hdcoa_c --> R4coa_cho_c + fad_m = {'C': -15.0, 'H': -31.0, 'X': 1.0}
# ARTFR42_cho: 0.125 coa_m + fadh2_m + odecoa_c --> 1.125 R4coa_cho_c + fad_m = {'C': -16.875, 'H': -35.125, 'O': 0.125, 'X': 1.125}
# ARTFR44_cho: 0.125 coa_m + 2.0 fadh2_m + lneldccoa_c --> 1.125 R4coa_cho_c + 2.0 fad_m = {'C': -16.875, 'H': -35.125, 'O': 0.125, 'X': 1.125}
# ARTFR45_cho: 0.5 coa_m + fadh2_m + nrvnccoa_c --> 1.5 R4coa_cho_c + fad_m = {'C': -22.5, 'H': -47.5, 'O': 0.5, 'X': 1.5}
# ARTFR46_cho: 0.125 coa_m + fadh2_m + od2coa_c --> 1.125 R4coa_cho_c + fad_m = {'C': -16.875, 'H': -35.125, 'O': 0.125, 'X': 1.125}
# ARTFR52_cho: 0.625 coa_m + hexccoa_c --> 1.625 R5coa_cho_c = {'C': -24.375, 'H': -51.625, 'O': 0.625, 'X': 1.625}
# ARTFR53_cho: 0.25 coa_m + eicostetcoa_c + 2.0 fadh2_m + 2.0 h_m + 2.0 nadph_m --> 1.25 R5coa_cho_c + 2.0 fad_m + 2.0 nadp_m = {'C': -18.75, 'H': -39.25, 'O': 0.25, 'X': 1.25}
# ARTFR54_cho: 0.5 coa_m + 3.0 fadh2_m + 2.0 h_m + 2.0 nadph_m + tetpent6coa_c --> 1.5 R5coa_cho_c + 3.0 fad_m + 2.0 nadp_m = {'C': -22.5, 'H': -47.5, 'O': 0.5, 'X': 1.5}
# ARTFR55_cho: 0.5 coa_m + 3.0 fadh2_m + 2.0 h_m + 2.0 nadph_m + tetpent3coa_c --> 1.5 R5coa_cho_c + 3.0 fad_m + 2.0 nadp_m = {'C': -22.5, 'H': -47.5, 'O': 0.5, 'X': 1.5}
# ARTFR56_cho: 0.5 coa_m + 2.0 fadh2_m + 2.0 h_m + 2.0 nadph_m + tettet6coa_c --> 1.5 R5coa_cho_c + 2.0 fad_m + 2.0 nadp_m = {'C': -22.5, 'H': -47.5, 'O': 0.5, 'X': 1.5}
# ARTFR57_cho: 0.5 coa_m + 3.0 fadh2_m + 3.0 h_m + 3.0 nadph_m + tethex3coa_c --> 1.5 R5coa_cho_c + 3.0 fad_m + 3.0 nadp_m = {'C': -22.5, 'H': -47.5, 'O': 0.5, 'X': 1.5}
# ARTFR61_cho: fadh2_m + hdd2coa_c --> R6coa_cho_c + fad_m = {'C': -15.0, 'H': -31.0, 'X': 1.0}
# ARTPLM1: Rtotalcoa_c <=> pmtcoa_c = {'C': 15.0, 'F': -1.0, 'U': -1.0, 'L': -2.0, 'R': -1.0, 'H': 31.0}
# ARTPLM1m: Rtotalcoa_m <=> pmtcoa_m = {'C': 15.0, 'F': -1.0, 'U': -1.0, 'L': -2.0, 'R': -1.0, 'H': 31.0}
# ARTPLM2: Rtotal2coa_c <=> pmtcoa_c = {'C': 15.0, 'F': -1.0, 'U': -1.0, 'L': -2.0, 'R': -2.0, 'H': 31.0}
# ARTPLM2m: Rtotal2coa_m <=> pmtcoa_m = {'C': 15.0, 'F': -1.0, 'U': -1.0, 'L': -2.0, 'R': -2.0, 'H': 31.0}
# ARTPLM3: Rtotal3coa_c <=> pmtcoa_c = {'C': 15.0, 'F': -1.0, 'U': -1.0, 'L': -2.0, 'R': -3.0, 'H': 31.0}
# ARTPLM3m: Rtotal3coa_m <=> pmtcoa_m = {'C': 15.0, 'F': -1.0, 'U': -1.0, 'L': -2.0, 'R': -3.0, 'H': 31.0}
# ASCBOX: ascb_L_c + 2.0 h_c + 2.0 o2s_c --> dhdascb_c + 2.0 h2o2_c = {'charge': 1.0}
# CBL2OR: 2.0 aqcobal_c + h_c + nadh_c --> 2.0 cbl2_c + 2.0 h2o_c + nad_c = {'charge': -2.0}
# DHPR2: 5mthf_c + dhbpt_c --> h_c + mlthf_c + thbpt_c = {'charge': 1.0}
# DM_13_cis_oretn_n_: 13_cis_oretn_n -->  = {'charge': 1.0, 'C': -20.0, 'H': -25.0, 'O': -3.0}
# DM_13_cis_retn_n_: 13_cis_retn_n -->  = {'charge': 1.0, 'C': -20.0, 'H': -27.0, 'O': -2.0}
# DM_Asn_X_Ser_Thr_ly_: Asn_X_Ser_Thr_l -->  = {'X': -1.0, 'H': -1.0}
# DM_datp_m_: datp_m -->  = {'charge': 4.0, 'C': -10.0, 'H': -12.0, 'N': -5.0, 'O': -12.0, 'P': -3.0}
# DM_datp_n_: datp_n -->  = {'charge': 4.0, 'C': -10.0, 'H': -12.0, 'N': -5.0, 'O': -12.0, 'P': -3.0}
# DM_dctp_m_: dctp_m -->  = {'charge': 4.0, 'C': -9.0, 'H': -12.0, 'N': -3.0, 'O': -13.0, 'P': -3.0}
# DM_dctp_n_: dctp_n -->  = {'charge': 4.0, 'C': -9.0, 'H': -12.0, 'N': -3.0, 'O': -13.0, 'P': -3.0}
# DM_dgtp_m_: dgtp_m -->  = {'charge': 4.0, 'C': -10.0, 'H': -12.0, 'N': -5.0, 'O': -13.0, 'P': -3.0}
# DM_dgtp_n_: dgtp_n -->  = {'charge': 4.0, 'C': -10.0, 'H': -12.0, 'N': -5.0, 'O': -13.0, 'P': -3.0}
# DM_dttp_n_: dttp_n -->  = {'charge': 4.0, 'C': -10.0, 'H': -13.0, 'N': -2.0, 'O': -14.0, 'P': -3.0}
# DM_gpi_sig_er_: gpi_sig_r -->  = {'Y': -1.0}
# DM_hretn_n_: hretn_n -->  = {'charge': 1.0, 'C': -20.0, 'H': -27.0, 'O': -3.0}
# DM_oretn_n_: oretn_n -->  = {'charge': 1.0, 'C': -20.0, 'H': -25.0, 'O': -3.0}
# DM_Ser_Gly_Ala_X_Gly_ly_: Ser_Gly_Ala_X_Gly_l -->  = {'H': -1.0, 'X': -1.0}
# DM_Ser_Thr_ly_: Ser_Thr_l -->  = {'H': -1.0, 'X': -1.0}
# EX_10fthf_e_: 10fthf_e -->  = {'charge': 2.0, 'C': -20.0, 'H': -21.0, 'N': -7.0, 'O': -7.0}
# EX_10fthf5glu_e_: 10fthf5glu_e -->  = {'charge': 6.0, 'C': -40.0, 'H': -45.0, 'N': -11.0, 'O': -19.0}
# EX_10fthf6glu_e_: 10fthf6glu_e -->  = {'charge': 7.0, 'C': -45.0, 'H': -51.0, 'N': -12.0, 'O': -22.0}
# EX_10fthf7glu_e_: 10fthf7glu_e -->  = {'charge': 8.0, 'C': -50.0, 'H': -57.0, 'N': -13.0, 'O': -25.0}
# EX_11_cis_retfa_e_: 11_cis_retfa_e -->  = {'C': -21.0, 'H': -29.0, 'O': -2.0, 'F': -1.0, 'U': -1.0, 'L': -2.0, 'R': -2.0}
# EX_13_cis_retnglc_e_: 13_cis_retnglc_e -->  = {'charge': 1.0, 'C': -26.0, 'H': -35.0, 'O': -8.0}
# EX_1glyc_cho_e_: 1glyc_cho_e -->  = {'charge': 1.0, 'C': -7.0, 'H': -13.0, 'O': -9.0, 'P': -1.0, 'F': -1.0, 'U': -1.0, 'L': -2.0, 'R': -1.0}
# EX_1mncam_e_: 1mncam_e -->  = {'charge': -1.0, 'C': -7.0, 'H': -9.0, 'N': -2.0, 'O': -1.0}
# EX_23cump_e_: 23cump_e -->  = {'charge': 1.0, 'C': -9.0, 'H': -10.0, 'N': -2.0, 'O': -8.0, 'P': -1.0}
# EX_2425dhvitd2_e_: 2425dhvitd2_e -->  = {'C': -28.0, 'H': -44.0, 'O': -3.0}
# EX_2425dhvitd3_e_: 2425dhvitd3_e -->  = {'C': -27.0, 'H': -44.0, 'O': -3.0}
# EX_24nph_e_: 24nph_e -->  = {'C': -6.0, 'H': -5.0, 'N': -1.0, 'O': -4.0}
# EX_25hvitd2_e_: 25hvitd2_e -->  = {'C': -28.0, 'H': -44.0, 'O': -2.0}
# EX_25hvitd3_e_: 25hvitd3_e -->  = {'C': -27.0, 'H': -44.0, 'O': -2.0}
# EX_2hb_e_: 2hb_e -->  = {'charge': 1.0, 'C': -4.0, 'H': -7.0, 'O': -3.0}
# EX_2mcit_e_: 2mcit_e -->  = {'charge': 3.0, 'C': -7.0, 'H': -7.0, 'O': -7.0}
# EX_34dhoxpeg_e_: 34dhoxpeg_e -->  = {'C': -8.0, 'H': -10.0, 'O': -4.0}
# EX_34dhphe_e_: 34dhphe_e -->  = {'C': -9.0, 'H': -11.0, 'N': -1.0, 'O': -4.0}
# EX_34hpp: 34hpp_e -->  = {'charge': 1.0, 'C': -9.0, 'H': -7.0, 'O': -4.0}
# EX_35cgmp_e_: 35cgmp_e -->  = {'charge': 1.0, 'C': -10.0, 'H': -11.0, 'N': -5.0, 'O': -7.0, 'P': -1.0}
# EX_3aib_D_e_: 3aib_D_e -->  = {'C': -4.0, 'H': -9.0, 'N': -1.0, 'O': -2.0}
# EX_3aib_e_: 3aib_e -->  = {'C': -4.0, 'H': -9.0, 'N': -1.0, 'O': -2.0}
# EX_3bcrn: 3bcrn_e -->  = {'C': -11.0, 'H': -21.0, 'N': -1.0, 'O': -5.0}
# EX_3ddcrn: 3ddcrn_e -->  = {'C': -19.0, 'H': -37.0, 'N': -1.0, 'O': -5.0}
# EX_3deccrn: 3deccrn_e -->  = {'C': -17.0, 'H': -33.0, 'N': -1.0, 'O': -5.0}
# EX_3hexdcrn: 3hexdcrn_e -->  = {'C': -23.0, 'H': -45.0, 'N': -1.0, 'O': -5.0}
# EX_3mlda_e_: 3mlda_e -->  = {'charge': 1.0, 'C': -6.0, 'H': -7.0, 'N': -2.0, 'O': -2.0}
# EX_3mob_e_: 3mob_e -->  = {'charge': 1.0, 'C': -5.0, 'H': -7.0, 'O': -3.0}
# EX_3mop_e_: 3mop_e -->  = {'charge': 1.0, 'C': -6.0, 'H': -9.0, 'O': -3.0}
# EX_3tdcrn: 3tdcrn_e -->  = {'C': -21.0, 'H': -41.0, 'N': -1.0, 'O': -5.0}
# EX_3ump_e_: 3ump_e -->  = {'charge': 2.0, 'C': -9.0, 'H': -11.0, 'N': -2.0, 'O': -9.0, 'P': -1.0}
# EX_4abut_e_: 4abut_e -->  = {'C': -4.0, 'H': -9.0, 'N': -1.0, 'O': -2.0}
# EX_4abutn_e_: 4abutn_e -->  = {'charge': -1.0, 'C': -4.0, 'H': -10.0, 'N': -1.0, 'O': -1.0}
# EX_4hdebrisoquine_e_: 4hdebrisoquine_e -->  = {'charge': -1.0, 'C': -10.0, 'H': -14.0, 'N': -3.0, 'O': -1.0}
# EX_4hphac_e_: 4hphac_e -->  = {'charge': 1.0, 'C': -8.0, 'H': -7.0, 'O': -3.0}
# EX_4hpro_e_: 4hpro_LT_e -->  = {'C': -5.0, 'H': -9.0, 'N': -1.0, 'O': -3.0}
# EX_4mop_e_: 4mop_e -->  = {'charge': 1.0, 'C': -6.0, 'H': -9.0, 'O': -3.0}
# EX_4mptnl_e_: 4mptnl_e -->  = {'C': -6.0, 'H': -12.0, 'O': -1.0}
# EX_4mtolbutamide_e_: 4mtolbutamide_e -->  = {'C': -12.0, 'H': -18.0, 'N': -2.0, 'O': -4.0, 'S': -1.0}
# EX_4nph_e_: 4nph_e -->  = {'C': -6.0, 'H': -5.0, 'N': -1.0, 'O': -3.0}
# EX_4nphsf_e_: 4nphsf_e -->  = {'charge': 1.0, 'C': -6.0, 'H': -4.0, 'N': -1.0, 'O': -6.0, 'S': -1.0}
# EX_4pyrdx_e_: 4pyrdx_e -->  = {'C': -8.0, 'H': -9.0, 'N': -1.0, 'O': -4.0}
# EX_5adtststerone_e_: 5adtststerone_e -->  = {'C': -19.0, 'H': -30.0, 'O': -2.0}
# EX_5adtststeroneglc_e_: 5adtststeroneglc_e -->  = {'C': -25.0, 'H': -38.0, 'O': -8.0}
# EX_5adtststerones_e_: 5adtststerones_e -->  = {'charge': 1.0, 'C': -19.0, 'H': -29.0, 'O': -5.0, 'S': -1.0}
# EX_5dhf_e_: 5dhf_e -->  = {'charge': 6.0, 'C': -39.0, 'H': -43.0, 'N': -11.0, 'O': -18.0}
# EX_5fthf_e_: 5fthf_e -->  = {'charge': 2.0, 'C': -20.0, 'H': -21.0, 'N': -7.0, 'O': -7.0}
# EX_5homeprazole_e_: 5homeprazole_e -->  = {'C': -17.0, 'H': -19.0, 'N': -3.0, 'O': -4.0, 'S': -1.0}
# EX_5htrp_e_: 5htrp_e -->  = {'C': -11.0, 'H': -12.0, 'N': -2.0, 'O': -3.0}
# EX_5mta_e_: 5mta_e -->  = {'C': -11.0, 'H': -15.0, 'N': -5.0, 'O': -3.0, 'S': -1.0}
# EX_5mthf_e_: 5mthf_e -->  = {'charge': 2.0, 'C': -20.0, 'H': -24.0, 'N': -7.0, 'O': -6.0}
# EX_5oxpro_e_: 5oxpro_e -->  = {'charge': 1.0, 'C': -5.0, 'H': -6.0, 'N': -1.0, 'O': -3.0}
# EX_5thf_e_: 5thf_e -->  = {'charge': 6.0, 'C': -39.0, 'H': -45.0, 'N': -11.0, 'O': -18.0}
# EX_6dhf_e_: 6dhf_e -->  = {'charge': 7.0, 'C': -44.0, 'H': -49.0, 'N': -12.0, 'O': -21.0}
# EX_6htststerone_e_: 6htststerone_e -->  = {'C': -19.0, 'H': -28.0, 'O': -3.0}
# EX_6thf_e_: 6thf_e -->  = {'charge': 7.0, 'C': -44.0, 'H': -51.0, 'N': -12.0, 'O': -21.0}
# EX_7dhf_e_: 7dhf_e -->  = {'charge': 8.0, 'C': -49.0, 'H': -55.0, 'N': -13.0, 'O': -24.0}
# EX_7thf_e_: 7thf_e -->  = {'charge': 8.0, 'C': -49.0, 'H': -57.0, 'N': -13.0, 'O': -24.0}
# EX_9_cis_retfa_e_: 9_cis_retfa_e -->  = {'C': -21.0, 'H': -29.0, 'O': -2.0, 'F': -1.0, 'U': -1.0, 'L': -2.0, 'R': -2.0}
# EX_abt_e_: abt_e -->  = {'C': -5.0, 'H': -12.0, 'O': -5.0}
# EX_ac_e_: ac_e -->  = {'charge': 1.0, 'C': -2.0, 'H': -3.0, 'O': -2.0}
# EX_acac_e_: acac_e -->  = {'charge': 1.0, 'C': -4.0, 'H': -5.0, 'O': -3.0}
# EX_acald_e_: acald_e -->  = {'C': -2.0, 'H': -4.0, 'O': -1.0}
# EX_acetone_e_: acetone_e -->  = {'C': -3.0, 'H': -6.0, 'O': -1.0}
# EX_acgalfucgalacgalfuc12gal14acglcgalgluside_cho_e_: acgalfucgalacgalfuc12gal14acglcgalgluside_cho_e -->  = {'C': -79.0, 'H': -135.0, 'N': -4.0, 'O': -46.0, 'F': -1.0, 'U': -1.0, 'L': -2.0, 'R': -1.0}
# EX_acgalfucgalacgalfucgalacglcgal14acglcgalgluside_cho_e_: acgalfucgalacgalfucgalacglcgal14acglcgalgluside_cho_e -->  = {'C': -93.0, 'H': -158.0, 'N': -5.0, 'O': -56.0, 'F': -1.0, 'U': -1.0, 'L': -2.0, 'R': -1.0}
# EX_acgam_e_: acgam_e -->  = {'C': -8.0, 'H': -15.0, 'N': -1.0, 'O': -6.0}
# EX_ach_e_: ach_e -->  = {'charge': -1.0, 'C': -7.0, 'H': -16.0, 'N': -1.0, 'O': -2.0}
# EX_acmana_e_: acmana_e -->  = {'C': -8.0, 'H': -15.0, 'N': -1.0, 'O': -6.0}
# EX_acn13acngalgbside_cho_e_: acn13acngalgbside_cho_e -->  = {'charge': 2.0, 'C': -73.0, 'H': -121.0, 'N': -4.0, 'O': -44.0, 'F': -1.0, 'U': -1.0, 'L': -2.0, 'R': -1.0}
# EX_acn23acngalgbside_cho_e_: acn23acngalgbside_cho_e -->  = {'charge': 2.0, 'C': -73.0, 'H': -121.0, 'N': -4.0, 'O': -44.0, 'F': -1.0, 'U': -1.0, 'L': -2.0, 'R': -1.0}
# EX_acnacngal14acglcgalgluside_cho_e_: acnacngal14acglcgalgluside_cho_e -->  = {'charge': 2.0, 'C': -67.0, 'H': -111.0, 'N': -4.0, 'O': -39.0, 'F': -1.0, 'U': -1.0, 'L': -2.0, 'R': -1.0}
# EX_acnacngalgbside_cho_e_: acnacngalgbside_cho_e -->  = {'charge': 2.0, 'C': -73.0, 'H': -121.0, 'N': -4.0, 'O': -44.0, 'F': -1.0, 'U': -1.0, 'L': -2.0, 'R': -1.0}
# EX_acngalacglcgal14acglcgalgluside_cho_e_: acngalacglcgal14acglcgalgluside_cho_e -->  = {'charge': 1.0, 'C': -70.0, 'H': -118.0, 'N': -4.0, 'O': -41.0, 'R': -1.0}
# EX_ade_e_: ade_e -->  = {'C': -5.0, 'H': -5.0, 'N': -5.0}
# EX_adn_e_: adn_e -->  = {'C': -10.0, 'H': -13.0, 'N': -5.0, 'O': -4.0}
# EX_adp: adp_e -->  = {'charge': 3.0, 'C': -10.0, 'H': -12.0, 'N': -5.0, 'O': -10.0, 'P': -2.0}
# EX_adpcbl_e_: adocbl_e -->  = {'C': -72.0, 'H': -100.0, 'Co': -1.0, 'N': -18.0, 'O': -17.0, 'P': -1.0}
# EX_adprbp_e_: adprbp_e -->  = {'charge': 4.0, 'C': -15.0, 'H': -20.0, 'N': -5.0, 'O': -17.0, 'P': -3.0}
# EX_adprib_e_: adprib_e -->  = {'charge': 2.0, 'C': -15.0, 'H': -21.0, 'N': -5.0, 'O': -14.0, 'P': -2.0}
# EX_adrn_e_: adrn_e -->  = {'charge': 1.0, 'C': -22.0, 'H': -35.0, 'O': -2.0}
# EX_adrnl_e_: adrnl_e -->  = {'charge': -1.0, 'C': -9.0, 'H': -14.0, 'N': -1.0, 'O': -3.0}
# EX_aflatoxin_e_: aflatoxin_e -->  = {'C': -17.0, 'H': -12.0, 'O': -6.0}
# EX_ahandrostanglc_e_: ahandrostanglc_e -->  = {'C': -25.0, 'H': -38.0, 'O': -8.0}
# EX_ahcys_e_: ahcys_e -->  = {'C': -14.0, 'H': -20.0, 'N': -6.0, 'O': -5.0, 'S': -1.0}
# EX_ahdt_e_: ahdt_e -->  = {'charge': 4.0, 'C': -9.0, 'H': -12.0, 'N': -5.0, 'O': -13.0, 'P': -3.0}
# EX_aicar_e_: aicar_e -->  = {'charge': 2.0, 'C': -9.0, 'H': -13.0, 'N': -4.0, 'O': -8.0, 'P': -1.0}
# EX_ak2lgchol_cho_e_: ak2lgchol_cho_e -->  = {'C': -10.0, 'H': -21.0, 'O': -5.0, 'N': -1.0, 'P': -1.0, 'F': -1.0, 'U': -1.0, 'L': -2.0, 'R': -1.0}
# EX_akg_e_: akg_e -->  = {'charge': 2.0, 'C': -5.0, 'H': -4.0, 'O': -5.0}
# EX_ala_B_e_: ala_B_e -->  = {'C': -3.0, 'H': -7.0, 'N': -1.0, 'O': -2.0}
# EX_ala_D_e_: ala_D_e -->  = {'C': -3.0, 'H': -7.0, 'N': -1.0, 'O': -2.0}
# EX_ala_L_e_: ala_L_e -->  = {'C': -3.0, 'H': -7.0, 'N': -1.0, 'O': -2.0}
# EX_alaala_e_: alaala_e -->  = {'C': -6.0, 'H': -12.0, 'N': -2.0, 'O': -3.0}
# EX_aldstrn_e_: aldstrn_e -->  = {'C': -21.0, 'H': -28.0, 'O': -5.0}
# EX_amp_e_: amp_e -->  = {'charge': 2.0, 'C': -10.0, 'H': -12.0, 'N': -5.0, 'O': -7.0, 'P': -1.0}
# EX_andrstrn_e_: andrstrn_e -->  = {'C': -19.0, 'H': -30.0, 'O': -2.0}
# EX_andrstrnglc_e_: andrstrnglc_e -->  = {'C': -25.0, 'H': -38.0, 'O': -8.0}
# EX_anth_e_: anth_e -->  = {'charge': 1.0, 'C': -7.0, 'H': -6.0, 'N': -1.0, 'O': -2.0}
# EX_antipyrene_e_: antipyrene_e -->  = {'C': -11.0, 'H': -12.0, 'N': -2.0, 'O': -1.0}
# EX_apnnox_e_: apnnox_e -->  = {'C': -10.0, 'H': -16.0, 'O': -1.0}
# EX_appnn_e_: appnn_e -->  = {'C': -10.0, 'H': -16.0}
# EX_aprgstrn_e_: aprgstrn_e -->  = {'C': -21.0, 'H': -32.0, 'O': -2.0}
# EX_aqcobal_e_: aqcobal_e -->  = {'charge': -1.0, 'C': -62.0, 'H': -93.0, 'Co': -1.0, 'N': -13.0, 'O': -15.0, 'P': -1.0}
# EX_arab_L_e_: arab_L_e -->  = {'C': -5.0, 'H': -10.0, 'O': -5.0}
# EX_arach_e_: arach_e -->  = {'charge': 1.0, 'C': -20.0, 'H': -39.0, 'O': -2.0}
# EX_arachcoa_e_: arachcoa_e -->  = {'charge': 4.0, 'C': -41.0, 'H': -70.0, 'N': -7.0, 'O': -17.0, 'P': -3.0, 'S': -1.0}
# EX_arachd_e_: arachd_e -->  = {'charge': 1.0, 'C': -20.0, 'H': -31.0, 'O': -2.0}
# EX_arg_L_e_: arg_L_e <--  = {'charge': -1.0, 'C': -6.0, 'H': -15.0, 'N': -4.0, 'O': -2.0}
# EX_ascb_L_e_: ascb_L_e -->  = {'charge': 1.0, 'C': -6.0, 'H': -7.0, 'O': -6.0}
# EX_asn_L_e_: asn_L_e <--  = {'C': -4.0, 'H': -8.0, 'N': -2.0, 'O': -3.0}
# EX_asp_D_e_: asp_D_e -->  = {'charge': 1.0, 'C': -4.0, 'H': -6.0, 'N': -1.0, 'O': -4.0}
# EX_asp_L_e_: asp_L_e <--  = {'charge': 1.0, 'C': -4.0, 'H': -6.0, 'N': -1.0, 'O': -4.0}
# EX_atp_e_: atp_e -->  = {'charge': 4.0, 'C': -10.0, 'H': -12.0, 'N': -5.0, 'O': -13.0, 'P': -3.0}
# EX_avite1_e_: avite1_e -->  = {'C': -29.0, 'H': -50.0, 'O': -2.0}
# EX_avite2_e_: avite2_e -->  = {'C': -29.0, 'H': -44.0, 'O': -2.0}
# EX_bglc_e_: bglc_e -->  = {'C': -1200000.0, 'H': -2200000.0, 'O': -1100000.0}
# EX_bhb_e_: bhb_e -->  = {'charge': 1.0, 'C': -4.0, 'H': -7.0, 'O': -3.0}
# EX_bildglcur_e_: bildglcur_e -->  = {'charge': 2.0, 'C': -45.0, 'H': -50.0, 'N': -4.0, 'O': -18.0}
# EX_bilglcur_e_: bilglcur_e -->  = {'C': -39.0, 'H': -44.0, 'N': -4.0, 'O': -12.0}
# EX_bilirub_e_: bilirub_e -->  = {'charge': 2.0, 'C': -33.0, 'H': -34.0, 'N': -4.0, 'O': -6.0}
# EX_biocyt_e_: biocyt_e -->  = {'C': -16.0, 'H': -28.0, 'N': -4.0, 'O': -4.0, 'S': -1.0}
# EX_btn_e_: btn_e -->  = {'charge': 1.0, 'C': -10.0, 'H': -15.0, 'N': -2.0, 'O': -3.0, 'S': -1.0}
# EX_but_e_: but_e -->  = {'charge': 1.0, 'C': -4.0, 'H': -7.0, 'O': -2.0}
# EX_bvite_e_: bvite_e -->  = {'C': -28.0, 'H': -48.0, 'O': -2.0}
# EX_bz_e_: bz_e -->  = {'charge': 1.0, 'C': -7.0, 'H': -5.0, 'O': -2.0}
# EX_C02470_e_: C02470_e -->  = {'charge': 1.0, 'C': -10.0, 'H': -6.0, 'N': -1.0, 'O': -4.0}
# EX_C02528_e_: C02528_e -->  = {'charge': 1.0, 'C': -24.0, 'H': -39.0, 'O': -4.0}
# EX_C04849_e_: C04849_e -->  = {'charge': 1.0, 'C': -20.0, 'H': -31.0, 'O': -4.0}
# EX_c10dc: c10dc_e -->  = {'charge': 1.0, 'C': -17.0, 'H': -30.0, 'N': -1.0, 'O': -6.0}
# EX_c4crn: c4crn_e -->  = {'C': -11.0, 'H': -21.0, 'N': -1.0, 'O': -4.0}
# EX_c4dc: c4dc_e -->  = {'charge': 1.0, 'C': -11.0, 'H': -18.0, 'N': -1.0, 'O': -6.0}
# EX_c51crn: c51crn_e -->  = {'C': -12.0, 'H': -21.0, 'N': -1.0, 'O': -4.0}
# EX_c6dc: c6dc_e -->  = {'charge': 1.0, 'C': -13.0, 'H': -22.0, 'N': -1.0, 'O': -6.0}
# EX_c8crn: c8crn_e -->  = {'C': -15.0, 'H': -29.0, 'N': -1.0, 'O': -4.0}
# EX_c8dc: c8dc_e -->  = {'charge': 1.0, 'C': -15.0, 'H': -26.0, 'N': -1.0, 'O': -6.0}
# EX_ca2_e_: ca2_e -->  = {'charge': -2.0, 'Ca': -1.0}
# EX_camp_e_: camp_e -->  = {'charge': 1.0, 'C': -10.0, 'H': -11.0, 'N': -5.0, 'O': -6.0, 'P': -1.0}
# EX_carn_e_: carn_e -->  = {'C': -9.0, 'H': -14.0, 'N': -4.0, 'O': -3.0}
# EX_caro_e_: caro_e -->  = {'C': -40.0, 'H': -56.0}
# EX_carveol_e_: carveol_e -->  = {'C': -10.0, 'H': -16.0, 'O': -1.0}
# EX_cbasp_e_: cbasp_e -->  = {'charge': 2.0, 'C': -5.0, 'H': -6.0, 'N': -2.0, 'O': -5.0}
# EX_cca_d3_e_: cca_d3_e -->  = {'charge': 1.0, 'C': -23.0, 'H': -33.0, 'O': -4.0}
# EX_cdp_e_: cdp_e -->  = {'charge': 3.0, 'C': -9.0, 'H': -12.0, 'N': -3.0, 'O': -11.0, 'P': -2.0}
# EX_CE0074_e_: CE0074_e -->  = {'C': -4.0, 'H': -2.0, 'N': -2.0, 'O': -4.0}
# EX_CE1925_e_: CE1925_e -->  = {'charge': 1.0, 'C': -16.0, 'H': -21.0, 'O': -4.0}
# EX_CE1926_e_: CE1926_e -->  = {'charge': 1.0, 'C': -15.0, 'H': -19.0, 'O': -4.0}
# EX_CE1935_e_: CE1935_e -->  = {'charge': -3.0, 'C': -10.0, 'H': -26.0, 'N': -3.0, 'O': -1.0}
# EX_CE1936_e_: CE1936_e -->  = {'charge': -2.0, 'C': -10.0, 'H': -22.0, 'N': -2.0, 'O': -2.0}
# EX_CE1939_e_: CE1939_e -->  = {'charge': -2.0, 'C': -7.0, 'H': -18.0, 'N': -2.0, 'O': -1.0}
# EX_CE1940_e_: CE1940_e -->  = {'charge': -2.0, 'C': -7.0, 'H': -18.0, 'N': -2.0, 'O': -1.0}
# EX_CE1943_e_: CE1943_e -->  = {'charge': -1.0, 'C': -7.0, 'H': -14.0, 'N': -1.0, 'O': -2.0}
# EX_CE2011_e_: CE2011_e -->  = {'C': -1.0, 'H': -1.0, 'N': -1.0, 'O': -1.0, 'S': -1.0}
# EX_CE2250_e_: CE2250_e -->  = {'charge': 4.0, 'C': -43.0, 'H': -72.0, 'N': -7.0, 'O': -18.0, 'P': -3.0, 'S': -1.0}
# EX_CE2838_e_: CE2838_e -->  = {'C': -54.0, 'H': -92.0, 'O': -46.0}
# EX_CE2839_e_: CE2839_e -->  = {'C': -60.0, 'H': -102.0, 'O': -51.0}
# EX_CE2915_e_: CE2915_e -->  = {'charge': 1.0, 'C': -44.0, 'H': -60.0, 'N': -7.0, 'O': -11.0}
# EX_CE2916_e_: CE2916_e -->  = {'charge': 1.0, 'C': -35.0, 'H': -51.0, 'N': -6.0, 'O': -10.0}
# EX_CE2917_e_: CE2917_e -->  = {'charge': -3.0, 'C': -69.0, 'H': -114.0, 'N': -23.0, 'O': -16.0, 'S': -1.0}
# EX_CE4633_e_: CE4633_e -->  = {'Cl': -1.0, 'H': -1.0, 'O': -1.0}
# EX_CE4722_e_: CE4722_e -->  = {'charge': 1.0, 'C': -38.0, 'H': -49.0, 'N': -6.0, 'O': -10.0}
# EX_CE4723_e_: CE4723_e -->  = {'charge': 1.0, 'C': -29.0, 'H': -40.0, 'N': -5.0, 'O': -9.0}
# EX_CE4724_e_: CE4724_e -->  = {'charge': -3.0, 'C': -60.0, 'H': -105.0, 'N': -22.0, 'O': -15.0, 'S': -1.0}
# EX_CE4881_e_: CE4881_e -->  = {'Cl': -1.0, 'N': -1.0, 'O': -2.0}
# EX_CE5786_e_: CE5786_e -->  = {'charge': -2.0, 'C': -56.0, 'H': -87.0, 'N': -17.0, 'O': -11.0}
# EX_CE5788_e_: CE5788_e -->  = {'charge': -2.0, 'C': -41.0, 'H': -67.0, 'N': -15.0, 'O': -9.0}
# EX_CE5789_e_: CE5789_e -->  = {'charge': -2.0, 'C': -50.0, 'H': -76.0, 'N': -16.0, 'O': -10.0}
# EX_CE5797_e_: CE5797_e -->  = {'C': -32.0, 'H': -51.0, 'N': -5.0, 'O': -7.0}
# EX_CE5798_e_: CE5798_e -->  = {'C': -26.0, 'H': -40.0, 'N': -4.0, 'O': -6.0}
# EX_CE5853_e_: CE5853_e -->  = {'charge': 1.0, 'C': -22.0, 'H': -29.0, 'O': -10.0}
# EX_CE5854_e_: CE5854_e -->  = {'charge': 1.0, 'C': -21.0, 'H': -27.0, 'O': -10.0}
# EX_CE5867_e_: CE5867_e -->  = {'charge': 1.0, 'C': -20.0, 'H': -32.0, 'N': -5.0, 'O': -9.0}
# EX_CE5868_e_: CE5868_e -->  = {'charge': 2.0, 'C': -9.0, 'H': -12.0, 'N': -2.0, 'O': -7.0}
# EX_CE5869_e_: CE5869_e -->  = {'charge': -1.0, 'C': -11.0, 'H': -22.0, 'N': -3.0, 'O': -3.0}
# EX_cgly_e_: cgly_e -->  = {'C': -5.0, 'H': -10.0, 'N': -2.0, 'O': -3.0, 'S': -1.0}
# EX_chol_e_: chol_e -->  = {'charge': -1.0, 'C': -5.0, 'H': -14.0, 'N': -1.0, 'O': -1.0}
# EX_cholate_e_: cholate_e -->  = {'charge': 1.0, 'C': -24.0, 'H': -39.0, 'O': -5.0}
# EX_chsterol_e_: chsterol_e -->  = {'C': -27.0, 'H': -46.0, 'O': -1.0}
# EX_chtn_e_: chtn_e -->  = {'C': -24.0, 'H': -41.0, 'N': -3.0, 'O': -16.0}
# EX_cit_e_: cit_e -->  = {'charge': 3.0, 'C': -6.0, 'H': -5.0, 'O': -7.0}
# EX_citr_L_e_: citr_L_e -->  = {'C': -6.0, 'H': -13.0, 'N': -3.0, 'O': -3.0}
# EX_cl_e_: cl_e -->  = {'charge': 1.0, 'Cl': -1.0}
# EX_CLPND_e_: clpnd_e -->  = {'charge': 1.0, 'C': -22.0, 'H': -33.0, 'O': -2.0}
# EX_cmp_e_: cmp_e -->  = {'charge': 2.0, 'C': -9.0, 'H': -12.0, 'N': -3.0, 'O': -8.0, 'P': -1.0}
# EX_co_e_: co_e -->  = {'C': -1.0, 'O': -1.0}
# EX_co2_e_: co2_e -->  = {'C': -1.0, 'O': -2.0}
# EX_coa_e_: coa_e -->  = {'charge': 4.0, 'C': -21.0, 'H': -32.0, 'N': -7.0, 'O': -16.0, 'P': -3.0, 'S': -1.0}
# EX_coumarin_e_: coumarin_e -->  = {'C': -9.0, 'H': -6.0, 'O': -2.0}
# EX_creat_e_: creat_e -->  = {'C': -4.0, 'H': -9.0, 'N': -3.0, 'O': -2.0}
# EX_crm_cho_e_: crm_cho_e -->  = {'C': -19.0, 'H': -36.0, 'N': -1.0, 'O': -3.0, 'F': -1.0, 'U': -1.0, 'L': -2.0, 'R': -1.0}
# EX_crmp_cho_e_: crmp_cho_e -->  = {'charge': 2.0, 'C': -19.0, 'H': -35.0, 'N': -1.0, 'O': -6.0, 'P': -1.0, 'F': -1.0, 'U': -1.0, 'L': -2.0, 'R': -1.0}
# EX_crn_e_: crn_e -->  = {'C': -7.0, 'H': -15.0, 'N': -1.0, 'O': -3.0}
# EX_crtsl_e_: crtsl_e -->  = {'C': -21.0, 'H': -30.0, 'O': -5.0}
# EX_crtstrn_e_: crtstrn_e -->  = {'C': -21.0, 'H': -30.0, 'O': -4.0}
# EX_crvnc_e_: crvnc_e -->  = {'charge': 1.0, 'C': -22.0, 'H': -31.0, 'O': -2.0}
# EX_csn_e_: csn_e -->  = {'C': -4.0, 'H': -5.0, 'N': -3.0, 'O': -1.0}
# EX_cspg_a_e_: cspg_a_e -->  = {'charge': 5.0, 'C': -45.0, 'H': -66.0, 'N': -2.0, 'O': -45.0, 'S': -3.0, 'X': -1.0}
# EX_cspg_b_e_: cspg_b_e -->  = {'charge': 6.0, 'C': -45.0, 'H': -65.0, 'N': -2.0, 'O': -48.0, 'S': -4.0, 'X': -1.0}
# EX_cspg_c_e_: cspg_c_e -->  = {'charge': 5.0, 'C': -45.0, 'H': -66.0, 'N': -2.0, 'O': -45.0, 'S': -3.0, 'X': -1.0}
# EX_cspg_d_e_: cspg_d_e -->  = {'charge': 7.0, 'C': -45.0, 'H': -64.0, 'N': -2.0, 'O': -51.0, 'S': -5.0, 'X': -1.0}
# EX_cspg_e_e_: cspg_e_e -->  = {'charge': 8.0, 'C': -45.0, 'H': -63.0, 'N': -2.0, 'O': -54.0, 'S': -6.0, 'X': -1.0}
# EX_ctp_e_: ctp_e -->  = {'charge': 4.0, 'C': -9.0, 'H': -12.0, 'N': -3.0, 'O': -14.0, 'P': -3.0}
# EX_cyan_e_: cyan_e -->  = {'C': -1.0, 'H': -1.0, 'N': -1.0}
# EX_cys_L_e_: cys_L_e <--  = {'C': -3.0, 'H': -7.0, 'N': -1.0, 'O': -2.0, 'S': -1.0}
# EX_cysam_e_: cysam_e -->  = {'charge': -1.0, 'C': -2.0, 'H': -8.0, 'N': -1.0, 'S': -1.0}
# EX_cytd_e_: cytd_e -->  = {'C': -9.0, 'H': -13.0, 'N': -3.0, 'O': -5.0}
# EX_dad_2_e_: dad_2_e -->  = {'C': -10.0, 'H': -13.0, 'N': -5.0, 'O': -3.0}
# EX_dag_cho_e_: dag_cho_e -->  = {'C': -5.0, 'H': -6.0, 'O': -5.0, 'F': -2.0, 'U': -2.0, 'L': -4.0, 'R': -3.0}
# EX_dca_e_: dca_e -->  = {'charge': 1.0, 'C': -10.0, 'H': -19.0, 'O': -2.0}
# EX_dchac_e_: dchac_e -->  = {'charge': 1.0, 'C': -24.0, 'H': -39.0, 'O': -4.0}
# EX_dcsptn1_e_: dcsptn1_e -->  = {'charge': 1.0, 'C': -22.0, 'H': -33.0, 'O': -2.0}
# EX_dcyt_e_: dcyt_e -->  = {'C': -9.0, 'H': -13.0, 'N': -3.0, 'O': -4.0}
# EX_debrisoquine_e_: debrisoquine_e -->  = {'charge': -1.0, 'C': -10.0, 'H': -14.0, 'N': -3.0}
# EX_dgchol_e_: dgchol_e -->  = {'charge': 1.0, 'C': -26.0, 'H': -43.0, 'N': -1.0, 'O': -5.0}
# EX_dgmp_e_: dgmp_e -->  = {'charge': 2.0, 'C': -10.0, 'H': -12.0, 'N': -5.0, 'O': -7.0, 'P': -1.0}
# EX_dgsn_e_: dgsn_e -->  = {'C': -10.0, 'H': -13.0, 'N': -5.0, 'O': -4.0}
# EX_dgtp_e_: dgtp_e -->  = {'charge': 4.0, 'C': -10.0, 'H': -12.0, 'N': -5.0, 'O': -13.0, 'P': -3.0}
# EX_dha_e_: dha_e -->  = {'C': -3.0, 'H': -6.0, 'O': -3.0}
# EX_dhap_e_: dhap_e -->  = {'charge': 2.0, 'C': -3.0, 'H': -5.0, 'O': -6.0, 'P': -1.0}
# EX_dhdascb_e_: dhdascb_e -->  = {'C': -6.0, 'H': -5.0, 'O': -6.0}
# EX_dheas_e_: dheas_e -->  = {'charge': 1.0, 'C': -19.0, 'H': -27.0, 'O': -5.0, 'S': -1.0}
# EX_dhf_e_: dhf_e -->  = {'charge': 2.0, 'C': -19.0, 'H': -19.0, 'N': -7.0, 'O': -6.0}
# EX_digalsgalside_cho_e_: digalsgalside_cho_e -->  = {'charge': 1.0, 'C': -31.0, 'H': -55.0, 'N': -1.0, 'O': -16.0, 'S': -1.0, 'F': -1.0, 'U': -1.0, 'L': -2.0, 'R': -1.0}
# EX_din_e_: din_e -->  = {'C': -10.0, 'H': -12.0, 'N': -4.0, 'O': -4.0}
# EX_dlnlcg_e_: dlnlcg_e -->  = {'charge': 1.0, 'C': -20.0, 'H': -33.0, 'O': -2.0}
# EX_dmantipyrine_e_: dmantipyrine_e -->  = {'C': -10.0, 'H': -10.0, 'N': -2.0, 'O': -1.0}
# EX_dmhptcrn_e_: dmhptcrn_e -->  = {'C': -16.0, 'H': -31.0, 'N': -1.0, 'O': -4.0}
# EX_docosac: docosac_e -->  = {'charge': 1.0, 'C': -22.0, 'H': -43.0, 'O': -2.0}
# EX_dopa_e_: dopa_e -->  = {'charge': -1.0, 'C': -8.0, 'H': -12.0, 'N': -1.0, 'O': -2.0}
# EX_dopasf_e_: dopasf_e -->  = {'C': -8.0, 'H': -11.0, 'N': -1.0, 'O': -5.0, 'S': -1.0}
# EX_dpcoa_e_: dpcoa_e -->  = {'charge': 2.0, 'C': -21.0, 'H': -33.0, 'N': -7.0, 'O': -13.0, 'P': -2.0, 'S': -1.0}
# EX_drib_e_: drib_e -->  = {'C': -5.0, 'H': -10.0, 'O': -4.0}
# EX_dtdp_e_: dtdp_e -->  = {'charge': 3.0, 'C': -10.0, 'H': -13.0, 'N': -2.0, 'O': -11.0, 'P': -2.0}
# EX_dtmp_e_: dtmp_e -->  = {'charge': 2.0, 'C': -10.0, 'H': -13.0, 'N': -2.0, 'O': -8.0, 'P': -1.0}
# EX_dttp_e_: dttp_e -->  = {'charge': 4.0, 'C': -10.0, 'H': -13.0, 'N': -2.0, 'O': -14.0, 'P': -3.0}
# EX_duri_e_: duri_e -->  = {'C': -9.0, 'H': -12.0, 'N': -2.0, 'O': -5.0}
# EX_eaflatoxin_e_: eaflatoxin_e -->  = {'C': -17.0, 'H': -12.0, 'O': -7.0}
# EX_ebastine_e_: ebastine_e -->  = {'C': -32.0, 'H': -39.0, 'N': -1.0, 'O': -2.0}
# EX_ebastineoh_e_: ebastineoh_e -->  = {'C': -32.0, 'H': -39.0, 'N': -1.0, 'O': -3.0}
# EX_eicostet_e_: eicostet_e -->  = {'charge': 1.0, 'C': -20.0, 'H': -31.0, 'O': -2.0}
# EX_elaid_e_: elaid_e -->  = {'charge': 1.0, 'C': -18.0, 'H': -33.0, 'O': -2.0}
# EX_estradiol_e_: estradiol_e -->  = {'C': -18.0, 'H': -24.0, 'O': -2.0}
# EX_estradiolglc_e_: estradiolglc_e -->  = {'C': -24.0, 'H': -32.0, 'O': -8.0}
# EX_estriolglc_e_: estriolglc_e -->  = {'C': -24.0, 'H': -32.0, 'O': -9.0}
# EX_estroneglc_e_: estroneglc_e -->  = {'C': -24.0, 'H': -30.0, 'O': -8.0}
# EX_estrones_e_: estrones_e -->  = {'charge': 1.0, 'C': -18.0, 'H': -21.0, 'O': -5.0, 'S': -1.0}
# EX_etoh_e_: etoh_e -->  = {'C': -2.0, 'H': -6.0, 'O': -1.0}
# EX_fad_e_: fad_e -->  = {'charge': 2.0, 'C': -27.0, 'H': -31.0, 'N': -9.0, 'O': -15.0, 'P': -2.0}
# EX_fald_e_: fald_e -->  = {'C': -1.0, 'H': -2.0, 'O': -1.0}
# EX_fe2_e_: fe2_e -->  = {'charge': -2.0, 'Fe': -1.0}
# EX_fe3_e_: fe3_e -->  = {'charge': -3.0, 'Fe': -1.0}
# EX_fmn_e_: fmn_e -->  = {'charge': 2.0, 'C': -17.0, 'H': -19.0, 'N': -4.0, 'O': -9.0, 'P': -1.0}
# EX_fol_e_: fol_e -->  = {'charge': 1.0, 'C': -19.0, 'H': -18.0, 'N': -7.0, 'O': -6.0}
# EX_for_e_: for_e -->  = {'charge': 1.0, 'C': -1.0, 'H': -1.0, 'O': -2.0}
# EX_fru_e_: fru_e -->  = {'C': -6.0, 'H': -12.0, 'O': -6.0}
# EX_fuc_L_e_: fuc_L_e -->  = {'C': -6.0, 'H': -12.0, 'O': -5.0}
# EX_fuc13galacglcgal14acglcgalgluside_cho_e_: fuc13galacglcgal14acglcgalgluside_cho_e -->  = {'C': -65.0, 'H': -112.0, 'N': -3.0, 'O': -37.0, 'F': -1.0, 'U': -1.0, 'L': -2.0, 'R': -1.0}
# EX_fuc14galacglcgalgluside_cho_e_: fuc14galacglcgalgluside_cho_e -->  = {'C': -51.0, 'H': -89.0, 'N': -2.0, 'O': -27.0, 'F': -1.0, 'U': -1.0, 'L': -2.0, 'R': -1.0}
# EX_fucacgalfucgalacglcgalgluside_cho_e_: fucacgalfucgalacglcgalgluside_cho_e -->  = {'C': -65.0, 'H': -112.0, 'N': -3.0, 'O': -36.0, 'F': -1.0, 'U': -1.0, 'L': -2.0, 'R': -1.0}
# EX_fucacngal14acglcgalgluside_cho_e_: fucacngal14acglcgalgluside_cho_e -->  = {'charge': 1.0, 'C': -62.0, 'H': -105.0, 'N': -3.0, 'O': -35.0, 'F': -1.0, 'U': -1.0, 'L': -2.0, 'R': -1.0}
# EX_fucacngalacglcgalgluside_cho_e_: fucacngalacglcgalgluside_cho_e -->  = {'charge': 1.0, 'C': -62.0, 'H': -105.0, 'N': -3.0, 'O': -35.0, 'F': -1.0, 'U': -1.0, 'L': -2.0, 'R': -1.0}
# EX_fucfuc12gal14acglcgalgluside_cho_e_: fucfuc12gal14acglcgalgluside_cho_e -->  = {'C': -57.0, 'H': -99.0, 'N': -2.0, 'O': -31.0, 'F': -1.0, 'U': -1.0, 'L': -2.0, 'R': -1.0}
# EX_fucfuc132galacglcgal14acglcgalgluside_cho_e_: fucfuc132galacglcgal14acglcgalgluside_cho_e -->  = {'C': -71.0, 'H': -122.0, 'N': -3.0, 'O': -41.0, 'F': -1.0, 'U': -1.0, 'L': -2.0, 'R': -1.0}
# EX_fucfucfucgalacglc13galacglcgal14acglcgalgluside_cho_e_: fucfucfucgalacglc13galacglcgal14acglcgalgluside_cho_e -->  = {'C': -91.0, 'H': -155.0, 'N': -4.0, 'O': -55.0, 'F': -1.0, 'U': -1.0, 'L': -2.0, 'R': -1.0}
# EX_fucfucfucgalacglcgal14acglcgalgluside_cho_e_: fucfucfucgalacglcgal14acglcgalgluside_cho_e -->  = {'C': -77.0, 'H': -132.0, 'N': -3.0, 'O': -45.0, 'F': -1.0, 'U': -1.0, 'L': -2.0, 'R': -1.0}
# EX_fucfucgalacglcgalgluside_cho_e_: fucfucgalacglcgalgluside_cho_e -->  = {'C': -57.0, 'H': -99.0, 'N': -2.0, 'O': -31.0, 'F': -1.0, 'U': -1.0, 'L': -2.0, 'R': -1.0}
# EX_fucgal14acglcgalgluside_cho_e_: fucgal14acglcgalgluside_cho_e -->  = {'C': -51.0, 'H': -89.0, 'N': -2.0, 'O': -27.0, 'F': -1.0, 'U': -1.0, 'L': -2.0, 'R': -1.0}
# EX_fucgalfucgalacglcgalgluside_cho_e_: fucgalfucgalacglcgalgluside_cho_e -->  = {'C': -63.0, 'H': -109.0, 'N': -2.0, 'O': -36.0, 'F': -1.0, 'U': -1.0, 'L': -2.0, 'R': -1.0}
# EX_fucgalgbside_cho_e_: fucgalgbside_cho_e -->  = {'C': -57.0, 'H': -99.0, 'N': -2.0, 'O': -32.0, 'F': -1.0, 'U': -1.0, 'L': -2.0, 'R': -1.0}
# EX_g1p_e_: g1p_e -->  = {'charge': 2.0, 'C': -6.0, 'H': -11.0, 'O': -9.0, 'P': -1.0}
# EX_gal_e_: gal_e -->  = {'C': -6.0, 'H': -12.0, 'O': -6.0}
# EX_galacglcgalgbside_cho_e_: galacglcgalgbside_cho_e -->  = {'C': -65.0, 'H': -112.0, 'N': -3.0, 'O': -38.0, 'F': -1.0, 'U': -1.0, 'L': -2.0, 'R': -1.0}
# EX_galfuc12gal14acglcgalgluside_cho_e_: galfuc12gal14acglcgalgluside_cho_e -->  = {'C': -57.0, 'H': -99.0, 'N': -2.0, 'O': -32.0, 'F': -1.0, 'U': -1.0, 'L': -2.0, 'R': -1.0}
# EX_galfucgalacglcgal14acglcgalgluside_cho_e_: galfucgalacglcgal14acglcgalgluside_cho_e -->  = {'C': -71.0, 'H': -122.0, 'N': -3.0, 'O': -42.0, 'F': -1.0, 'U': -1.0, 'L': -2.0, 'R': -1.0}
# EX_galgalfucfucgalacglcgalacglcgal14acglcgalgluside_cho_e_: galgalfucfucgalacglcgalacglcgal14acglcgalgluside_cho_e -->  = {'C': -97.0, 'H': -165.0, 'N': -4.0, 'O': -61.0, 'F': -1.0, 'U': -1.0, 'L': -2.0, 'R': -1.0}
# EX_galgalgalthcrm_cho_e_: galgalgalthcrm_cho_e -->  = {'C': -55.0, 'H': -96.0, 'N': -1.0, 'O': -33.0, 'F': -1.0, 'U': -1.0, 'L': -2.0, 'R': -1.0}
# EX_galside_cho_e_: galside_cho_e -->  = {'C': -25.0, 'H': -46.0, 'N': -1.0, 'O': -8.0, 'F': -1.0, 'U': -1.0, 'L': -2.0, 'R': -1.0}
# EX_gam_e_: gam_e -->  = {'charge': -1.0, 'C': -6.0, 'H': -14.0, 'N': -1.0, 'O': -5.0}
# EX_gbside_cho_e_: gbside_cho_e -->  = {'C': -45.0, 'H': -79.0, 'N': -2.0, 'O': -23.0, 'F': -1.0, 'U': -1.0, 'L': -2.0, 'R': -1.0}
# EX_gchola_e_: gchola_e -->  = {'C': -26.0, 'H': -43.0, 'N': -1.0, 'O': -6.0}
# EX_gd1b2_cho_e_: gd1b2_cho_e -->  = {'charge': 2.0, 'C': -67.0, 'H': -111.0, 'N': -4.0, 'O': -39.0, 'F': -1.0, 'U': -1.0, 'L': -2.0, 'R': -1.0}
# EX_gd1c_cho_e_: gd1c_cho_e -->  = {'charge': 2.0, 'C': -67.0, 'H': -111.0, 'N': -4.0, 'O': -39.0, 'F': -1.0, 'U': -1.0, 'L': -2.0, 'R': -1.0}
# EX_gdp_e_: gdp_e -->  = {'charge': 3.0, 'C': -10.0, 'H': -12.0, 'N': -5.0, 'O': -11.0, 'P': -2.0}
# EX_glc_e_: glc_D_e <--  = {'C': -6.0, 'H': -12.0, 'O': -6.0}
# EX_glcur_e_: glcur_e -->  = {'charge': 1.0, 'C': -6.0, 'H': -9.0, 'O': -7.0}
# EX_glgchlo_e_: glgchlo_e -->  = {'C': -1200026.0, 'H': -2200043.0, 'N': -1.0, 'O': -1100006.0}
# EX_gln_L_e_: gln_L_e <--  = {'C': -5.0, 'H': -10.0, 'N': -2.0, 'O': -3.0}
# EX_gltcho_e_: gltcho_e -->  = {'C': -1200026.0, 'H': -2200045.0, 'N': -1.0, 'O': -1100007.0, 'S': -1.0}
# EX_gltdechol_e_: gltdechol_e -->  = {'charge': 1.0, 'C': -1200026.0, 'H': -2200044.0, 'N': -1.0, 'O': -1100006.0, 'S': -1.0}
# EX_glu_L_e_: glu_L_e -->  = {'charge': 1.0, 'C': -5.0, 'H': -8.0, 'N': -1.0, 'O': -4.0}
# EX_gluala_e_: gluala_e -->  = {'charge': 1.0, 'C': -8.0, 'H': -13.0, 'N': -2.0, 'O': -5.0}
# EX_gly_e_: gly_e -->  = {'C': -2.0, 'H': -5.0, 'N': -1.0, 'O': -2.0}
# EX_glyb_e_: glyb_e -->  = {'C': -5.0, 'H': -11.0, 'N': -1.0, 'O': -2.0}
# EX_glyc_e_: glyc_e -->  = {'C': -3.0, 'H': -8.0, 'O': -3.0}
# ...
# EX_xyl_D_e_: xyl_D_e -->  = {'C': -5.0, 'H': -10.0, 'O': -5.0}
# EX_xylt_e_: xylt_e -->  = {'C': -5.0, 'H': -12.0, 'O': -5.0}
# EX_yvite_e_: yvite_e -->  = {'C': -28.0, 'H': -48.0, 'O': -2.0}
# r0001: ametam_c --> 5mta_c + HC02119_c = {'charge': -2.0, 'C': -3.0, 'H': -9.0, 'N': -1.0, 'X': 1.0}
# r0120: gtp_c + h2o_c + 4.0 h_c --> HC01651_c = {'C': -10.0, 'H': -18.0, 'N': -5.0, 'O': -15.0, 'P': -3.0, 'X': 1.0}
# r0220: HC01668_c + coa_c <=> amp_c + 2.0 h_c + ppcoa_c = {'X': -1.0, 'C': 13.0, 'H': 18.0, 'N': 5.0, 'O': 8.0, 'P': 1.0}
# r0221: HC01668_m + coa_m <=> amp_m + 2.0 h_m + ppcoa_m = {'X': -1.0, 'C': 13.0, 'H': 18.0, 'N': 5.0, 'O': 8.0, 'P': 1.0}
# r0318: atp_c + h_c + ppa_c --> HC01668_c + ppi_c = {'charge': 1.0, 'C': -13.0, 'H': -17.0, 'N': -5.0, 'O': -8.0, 'P': -1.0, 'X': 1.0}
# r0319: atp_m + h_m + ppa_m --> HC01668_m + ppi_m = {'charge': 1.0, 'C': -13.0, 'H': -17.0, 'N': -5.0, 'O': -8.0, 'P': -1.0, 'X': 1.0}
# r0366: ACP_c + h2o_c --> HC01161_c + pan4p_c = {'charge': -1.0, 'H': -2.0, 'O': -1.0, 'R': -1.0, 'X': 1.0}
# r0368: HC01161_c + coa_c --> ACP_c + pap_c = {'charge': -1.0, 'X': -1.0, 'O': 1.0, 'R': 1.0}
# r0380: HC01441_e + h2o_e <=> lcts_e + pi_e = {'charge': -2.0}
# r0430: crn_r + malcoa_r <=> HC10859_r + coa_r = {'charge': 1.0, 'C': -10.0, 'H': -16.0, 'N': -1.0, 'O': -6.0, 'X': 1.0}
# r0431: crn_c + malcoa_c <=> HC10859_c + coa_c = {'charge': 1.0, 'C': -10.0, 'H': -16.0, 'N': -1.0, 'O': -6.0, 'X': 1.0}
# r0433: HC10859_x + coa_x --> crn_x + malcoa_x = {'charge': -1.0, 'X': -1.0, 'C': 10.0, 'H': 16.0, 'N': 1.0, 'O': 6.0}
# r0648: HC00955_e + glu_L_e + h_e <=> HC01577_e + h2o_e = {'C': -9.0, 'H': -13.0, 'N': -3.0, 'O': -5.0, 'X': 1.0}
# r0649: HC00955_e + glu_L_e + h_e <=> HC01700_e + co2_e + h2o_e = {'C': -8.0, 'H': -13.0, 'N': -3.0, 'O': -3.0, 'X': 1.0}
# r0708: ahdt_c + h2o_c + 4.0 h_c <=> HC01710_c = {'C': -9.0, 'H': -18.0, 'N': -5.0, 'O': -14.0, 'P': -3.0, 'X': 1.0}
# r0775: HC01651_c + h2o_c <=> HC01652_c + for_c + 5.0 h_c = {'X': -1.0, 'H': 18.0, 'O': 15.0, 'C': 10.0, 'N': 5.0, 'P': 3.0}
# r0777: HC01652_c + 4.0 h_c <=> HC01710_c = {'C': -9.0, 'H': -18.0, 'N': -5.0, 'O': -14.0, 'P': -3.0, 'X': 1.0}
# r0797: dcholcoa_c + gly_c <=> coa_c + dgchol_c = {'charge': -1.0}
# r0800: 7.0 amet_c + 2.0 h2o_c --> 6.0 HC01797_c + 7.0 ahcys_c + co2_c + 7.0 h_c = {'C': -6.0, 'H': -18.0, 'X': 6.0}
# r1319: atp_c + h2o_c --> HC02111_c + adp_c + pi_c = {'charge': -1.0, 'H': -1.0, 'X': 1.0}
# r1320: atp_m + h2o_m --> HC02111_m + adp_m + pi_m = {'charge': -1.0, 'H': -1.0, 'X': 1.0}
# r1321: nadh_r <=> HC02112_r + nad_r = {'charge': 1.0, 'H': -1.0, 'X': 1.0}
# r1322: nadh_c <=> HC02112_c + nad_c = {'charge': 1.0, 'H': -1.0, 'X': 1.0}
# r1323: nadh_m <=> HC02112_m + nad_m = {'charge': 1.0, 'H': -1.0, 'X': 1.0}
# r1324: nadh_x <=> HC02112_x + nad_x = {'charge': 1.0, 'H': -1.0, 'X': 1.0}
# r1325: nadph_r <=> HC02113_r + nadp_r = {'charge': 1.0, 'H': -1.0, 'X': 1.0}
# r1326: nadph_c <=> HC02113_c + nadp_c = {'charge': 1.0, 'H': -1.0, 'X': 1.0}
# r1327: nadph_m <=> HC02113_m + nadp_m = {'charge': 1.0, 'H': -1.0, 'X': 1.0}
# r1328: nadph_x <=> HC02113_x + nadp_x = {'charge': 1.0, 'H': -1.0, 'X': 1.0}
# r1329: fadh2_c <=> HC02114_c + fad_c = {'H': -2.0, 'X': 1.0}
# r1332: paps_c <=> HC02116_c + pap_c = {'O': -3.0, 'S': -1.0, 'X': 1.0}
# r1382: 6.0 atp_c + 6.0 glu_L_c + 6.0 h2o_c + thf_c --> HC02129_c + 6.0 adp_c + 6.0 pi_c = {'charge': 2.0, 'C': -49.0, 'H': -75.0, 'N': -13.0, 'O': -30.0, 'X': 1.0}
# r1383: HC02129_c --> 6.0 glu_L_c + thf_c = {'charge': -8.0, 'X': -1.0, 'C': 49.0, 'H': 69.0, 'N': 13.0, 'O': 30.0}
# r1391: dxtrn_c --> HC02136_c = {'C': -48.0, 'H': -81.0, 'O': -41.0}
# r1392: HC02136_c + h2o_c --> glc_D_c + glygn3_c = {'H': 81.0, 'O': 41.0, 'C': 48.0}
# r1411: HC02161_e + h2o_e <=> HC02160_e + gal_e = {'H': 10.0, 'O': 5.0, 'C': 6.0}
# r1526: HC02154_c + atp_c + h2o_c --> HC02154_e + adp_c + 2.0 h_c + pi_c = {'charge': 1.0, 'H': 1.0}
# r1531: HC02199_c + atp_c + h2o_c --> HC02199_e + adp_c + 2.0 h_c + pi_c = {'charge': 1.0, 'H': 1.0}
# r1532: HC02200_c + atp_c + h2o_c --> HC02200_e + adp_c + 2.0 h_c + pi_c = {'charge': 1.0, 'H': 1.0}
# r1533: HC02201_c + atp_c + h2o_c --> HC02201_e + adp_c + 2.0 h_c + pi_c = {'charge': 1.0, 'H': 1.0}
# RE1921C: CE5626_c <=> CE5629_c + co2_c + 2.0 h_c = {'charge': 2.0}
# RE2049C: 4hphac_c + no2_c <=> CE1957_c + 2.0 h_c = {'charge': 2.0}
# RE2426C: h2o_c + melatn_c <=> 6hoxmelatn_c + 2.0 h_c = {'charge': 2.0}
# RE2493C: amet_c + cbl2_c --> C06453_c + ahcys_c + 4.0 h_c = {'charge': 2.0}
# RE2594C: C02470_c <=> CE2949_c + h_c = {'charge': 1.0}
# RE2705C: CE7047_c + no2_c <=> CE5986_c = {'charge': 1.0}
# RE2864C: CE6444_c + 2.0 h_c <=> CE6453_c + h2o_c = {'charge': -2.0}
# RE2865C: CE6444_c + 2.0 h_c <=> CE6452_c + h2o_c = {'charge': -2.0}
# RE2866C: CE6445_c + ascb_L_c <=> CE6454_c + dhdascb_c + h2o_c = {'charge': 1.0}
# RE2867C: CE6445_c + ascb_L_c <=> CE6455_c + dhdascb_c + h2o_c = {'charge': 1.0}
# RE2868C: CE6446_c + ascb_L_c <=> CE6456_c + dhdascb_c + h2o_c = {'charge': 1.0}
# RE2869C: CE6446_c + ascb_L_c <=> CE6457_c + dhdascb_c + h2o_c = {'charge': 1.0}
# RE2870C: CE6447_c + ascb_L_c <=> CE6458_c + dhdascb_c + h2o_c = {'charge': 1.0}
# RE2871C: CE6447_c + ascb_L_c <=> CE6459_c + dhdascb_c + h2o_c = {'charge': 1.0}
# RE2872C: CE6448_c + ascb_L_c <=> CE6460_c + dhdascb_c + h2o_c = {'charge': 1.0}
# RE2873C: CE6448_c + ascb_L_c <=> CE6461_c + dhdascb_c + h2o_c = {'charge': 1.0}
# RE2874C: CE6449_c + ascb_L_c <=> CE6462_c + dhdascb_c + h2o_c = {'charge': 1.0}
# RE2875C: CE6449_c + 2.0 h_c <=> CE6463_c + h2o_c = {'charge': -2.0}
# RE2876C: CE6450_c + 2.0 h_c <=> CE6464_c + h2o_c = {'charge': -2.0}
# RE2877C: CE6450_c + 2.0 h_c <=> CE6465_c + h2o_c = {'charge': -2.0}
# RE2878C: CE6451_c + ascb_L_c <=> CE6467_c + dhdascb_c + h2o_c = {'charge': 1.0}
# RE2880C: CE6451_c + ascb_L_c <=> CE6466_c + dhdascb_c + h2o_c = {'charge': 1.0}
# RE2899C: C02147_c + dhdascb_c <=> ascb_L_c + lipoate_c = {'charge': -1.0}
# RE3051C: cpppg1_c <=> C05769_c + 6.0 h_c = {'charge': 6.0}
# RE3111C: C04295_c + h_c + nad_c <=> 5adtststerone_c + nadh_c = {'charge': -2.0}
# RE3263C: CE6316_c <=> CE6317_c + 2.0 h_c = {'charge': 2.0}
# RE3420C: CE6504_c <=> C08261_c + CE2577_c + 3.0 h_c = {'charge': 2.0}
# RE3477C: h2o_r + txa2_r <=> CE1447_c + 2.0 h_c = {'charge': 2.0}
# RE3493C: CE6508_c + 2.0 h_c <=> CE7085_c + h2o_c = {'charge': -2.0}
# RE3511C: C04308_c + amet_c --> ahcys_c + pchol_cho_c = {'R': 1.0, 'F': 2.0, 'U': 2.0, 'L': 4.0}
# RE3535R: 2.0 h_r + prostgd2_r <=> CE6240_r + h2o_r = {'charge': -2.0}
# RE3570C: CE6230_c + 2.0 h_c <=> CE2537_c + h2o_c = {'charge': -2.0}
# RE3636C: CE7047_c + h2o_c <=> CE7101_c + h_c = {'charge': 1.0}
# RN0002N: 5mthf_n + selhcys_n --> h_n + selmeth_n + thf_n = {'charge': 1.0}
# RN0002R: 5mthf_r + selhcys_r --> h_r + selmeth_r + thf_r = {'charge': 1.0}
# RN0013C: adrnl_c --> CE5536_c + 5.0 h_c = {'charge': 4.0}
# RN0014R: nrpphr_r --> CE5538_r + 5.0 h_r = {'charge': 4.0}
# RN0020C: C07535_c + h_c + nadph_c + o2_c --> CN0012_c + h2o_c + nadp_c = {'C': -20.0, 'H': -12.0, 'O': -1.0, 'X': 1.0}
# RN0027C: CN0020_c + 3.0 h_c + nadph_c + o2_c --> CN0021_c + h2o_c + nadp_c = {'charge': -2.0, 'C': -20.0, 'H': -18.0, 'O': -1.0, 'X': 1.0}
# RN0029C: CN0022_c + nadph_c + o2_c --> CN0023_c + h2o_c + h_c + nadp_c = {'charge': 2.0, 'H': 2.0, 'O': -1.0}
# RN0030C: CN0016_c + 3.0 h_c + nadph_c + o2_c --> CN0017_c + h2o_c + nadp_c = {'charge': -2.0, 'C': -24.0, 'H': -16.0, 'O': -1.0, 'X': 1.0}
# RN0032C: CN0018_c + nadph_c + o2_c --> CN0019_c + h2o_c + h_c + nadp_c = {'charge': 2.0, 'H': 2.0, 'O': -1.0}
# RTOT_2_cho: R2coa_cho_c + R4coa_cho_c --> 2.0 Rtotal2coa_c = {'X': -2.0, 'F': 2.0, 'U': 2.0, 'L': 4.0, 'R': 4.0}
# RTOT_3_cho: R1coa_cho_c + R2coa_cho_c --> 2.0 Rtotal3coa_c = {'X': -2.0, 'F': 2.0, 'U': 2.0, 'L': 4.0, 'R': 6.0}
# RTOT1_cho: R1coa_cho_c --> Rtotalcoa_c = {'X': -1.0, 'F': 1.0, 'U': 1.0, 'L': 2.0, 'R': 1.0}
# RTOT2_cho: R2coa_cho_c --> Rtotalcoa_c = {'X': -1.0, 'F': 1.0, 'U': 1.0, 'L': 2.0, 'R': 1.0}
# RTOT3_cho: R3coa_cho_c --> Rtotalcoa_c = {'X': -1.0, 'F': 1.0, 'U': 1.0, 'L': 2.0, 'R': 1.0}
# RTOT4_cho: R4coa_cho_c --> Rtotalcoa_c = {'X': -1.0, 'F': 1.0, 'U': 1.0, 'L': 2.0, 'R': 1.0}
# RTOT5_cho: R5coa_cho_c --> Rtotalcoa_c = {'X': -1.0, 'F': 1.0, 'U': 1.0, 'L': 2.0, 'R': 1.0}
# RTOT6_cho: R6coa_cho_c --> Rtotalcoa_c = {'X': -1.0, 'F': 1.0, 'U': 1.0, 'L': 2.0, 'R': 1.0}
# UNK2_cho: 2kmb_c + gln_L_c + 2.0 h_c --> glu_L_c + met_L_c = {'charge': -2.0}
# peplys_synthesis: lys_L_n --> peplys_n = {'charge': -1.0, 'C': -6.0, 'H': -14.0, 'N': -2.0, 'O': -2.0, 'X': 1.0}
# SK_Asn_X_Ser_Thr_r_: Asn_X_Ser_Thr_r <=>  = {'X': -1.0, 'H': -1.0}
# SK_Ser_Thr_g_: Ser_Thr_g <=>  = {'H': -1.0, 'X': -1.0}
# SK_Tyr_ggn_c_: Tyr_ggn_c <=>  = {'X': -1.0, 'O': -1.0, 'H': -1.0}
# biomass_cho: 0.449091248 ala_L_c + 0.24692711 arg_L_c + 0.208891647 asn_L_c + 0.257573151 asp_L_c + 29.93484474 atp_c + 0.086970857 chsterol_c + 0.006632113 clpn_cho_c + 0.097355132 ctp_c + 0.083083581 cys_L_c + 0.035778189 datp_c + 0.025172729 dctp_c + 0.025172729 dgtp_c + 0.035778189 dttp_c + 0.353206758 gln_L_c + 0.303246063 glu_L_c + 0.476689682 gly_c + 0.025685906 glygn2_c + 0.102935005 gtp_c + 24.74849172 h2o_c + 0.096216462 his_L_c + 0.220171565 ile_L_c + 0.427292446 leu_L_c + 0.387642487 lys_L_c + 0.105583014 met_L_c + 0.001719437 pa_cho_c + 0.018176901 pail_cho_c + 0.130185913 pchol_cho_c + 0.049863661 pe_cho_c + 0.001473803 pglyc_cho_c + 0.186720668 phe_L_c + 0.222059892 pro_L_c + 0.016457464 ps_cho_c + 0.32299952 ser_L_c + 0.02137014 sphmyln_cho_c + 0.010836772 tag_cho_c + 0.255370881 thr_L_c + 0.025172972 trp_L_c + 0.131253338 tyr_L_c + 0.085375963 utp_c + 0.32262571 val_L_c + 0.055982301 xolest_cho_c --> 29.83030991 adp_c + 29.83030991 h_c + 29.83030991 pi_c + 0.512102766 ppi_c = {'charge': 0.49116365099999504, 'C': -37.539152127000136, 'H': -58.56957882599997, 'N': -9.18118928299998, 'O': -14.731935489999927, 'P': -0.7646143110000023, 'F': -0.516163266, 'U': -0.516163266, 'L': -1.032326532, 'R': -0.779814987, 'S': -0.188666595, 'X': -0.08166820699999999}
# C81_5ZCPT2m: c81_5Zcrn_m + coa_m --> c81_5Zcoa_m + crn_m = {'charge': 4.0}
# biomass_cho_producing: 0.56773442 ala_L_c + 0.312161549 arg_L_c + 0.264077687 asn_L_c + 0.325620114 asp_L_c + 29.87198884 atp_c + 0.034769644 chsterol_c + 0.002651419 clpn_cho_c + 0.038816317 ctp_c + 0.105033017 cys_L_c + 0.013363374 datp_c + 0.00940217 dctp_c + 0.00940217 dgtp_c + 0.013363374 dttp_c + 0.446518685 gln_L_c + 0.383359124 glu_L_c + 0.602623946 gly_c + 0.025685906 glygn2_c + 0.04104106 gtp_c + 23.40595158 h2o_c + 0.121635409 his_L_c + 0.27833759 ile_L_c + 0.540176701 leu_L_c + 0.490051817 lys_L_c + 0.133476463 met_L_c + 0.000687405 pa_cho_c + 0.007266852 pail_cho_c + 0.052046375 pchol_cho_c + 0.019934744 pe_cho_c + 0.000589204 pglyc_cho_c + 0.236049468 phe_L_c + 0.280724784 pro_L_c + 0.006579447 ps_cho_c + 0.408331149 ser_L_c + 0.008543462 sphmyln_cho_c + 0.004332379 tag_cho_c + 0.322836037 thr_L_c + 0.031823293 trp_L_c + 0.165928502 tyr_L_c + 0.034040121 utp_c + 0.407858583 val_L_c + 0.022380884 xolest_cho_c --> 29.83030991 adp_c + 29.83030991 h_c + 29.83030991 pi_c + 0.201107511 ppi_c = {'charge': 0.12898655399999737, 'C': -37.03616940599994, 'H': -58.788028608000054, 'N': -9.699122896000034, 'O': -13.19236672699996, 'P': -0.30205785299997606, 'F': -0.206354329, 'U': -0.206354329, 'L': -0.412708658, 'R': -0.31175833099999994, 'S': -0.23850948, 'X': -0.04806679}
# epo_translation: 20.0 ala_L_c + 13.0 arg_L_c + 6.0 asn_L_c + 6.0 asp_L_c + 194.0 atp_c + 5.0 cys_L_c + 7.0 gln_L_c + 13.0 glu_L_c + 12.0 gly_c + 385.0 gtp_c + 194.0 h2o_c + 3.0 his_L_c + 5.0 ile_L_c + 33.0 leu_L_c + 8.0 lys_L_c + 2.0 met_L_c + 4.0 phe_L_c + 11.0 pro_L_c + 12.0 ser_L_c + 11.0 thr_L_c + 5.0 trp_L_c + 4.0 tyr_L_c + 13.0 val_L_c --> adp_c + 193.0 amp_c + epoIm_r + 385.0 gdp_c + 386.0 h_c + 386.0 pi_c + 193.0 ppi_c = {'charge': -195.0, 'C': -956.0, 'H': -1347.0, 'N': -264.0, 'O': -79.0, 'S': -7.0}
# epo_processing: dsT_antigen_g + epoIm_r + h2o_g + 0.0357 s2l2fn2m2masn_g + 0.0063 s2l2n2m2masn_g + 0.08925 s3l3fn3m2masn_g + 0.16575 s3l3fn3rm2masn_g + 0.01575 s3l3n3m2masn_g + 0.02925 s3l3n3rm2masn_g + 0.08925 s3lnl3fn3m2masn_g + 0.01575 s3lnl3n3m2masn_g + 0.08415 s4l2n2bdl4fn4m2masn_g + 0.01485 s4l2n2bdl4n4m2masn_g + 0.3366 s4l2n2cdl4fn4m2masn_g + 0.0594 s4l2n2cdl4n4m2masn_g + 0.11985 s4l3n3l4fn4m2masn_g + 0.02115 s4l3n3l4n4m2masn_g + 0.8109 s4l4fn4m2masn_g + 0.1431 s4l4n4m2masn_g + 0.0816 s4lnbl4fn4m2masn_g + 0.0144 s4lnbl4n4m2masn_g + 0.0816 s4lncl4fn4m2masn_g + 0.0144 s4lncl4n4m2masn_g + 0.65535 s4lndl4fn4m2masn_g + 0.11565 s4lndl4n4m2masn_g --> epo_g + peptide_c = {'charge': 13.511000000000001, 'C': -39.742200000000004, 'H': -64.027, 'N': -3.252, 'O': -29.7048, 'X': -3.9999999999999996}
# epo_degradation: 26.0 h2o_c + peptide_c --> ala_L_c + cys_L_c + glu_L_c + 3.0 gly_c + his_L_c + 10.0 leu_L_c + met_L_c + 3.0 pro_L_c + 2.0 ser_L_c + 2.0 trp_L_c + 2.0 val_L_c = {'charge': -1.0, 'H': 222.0, 'O': 32.0, 'C': 141.0, 'N': 31.0, 'S': 2.0}
# igg_hc: 24.0 ala_L_c + 8.0 arg_L_c + 19.0 asn_L_c + 17.0 asp_L_c + 452.0 atp_c + 11.0 cys_L_c + 18.0 gln_L_c + 20.0 glu_L_c + 31.0 gly_c + 900.0 gtp_c + 901.0 h2o_c + 10.0 his_L_c + 7.0 ile_L_c + 32.0 leu_L_c + 36.0 lys_L_c + 5.0 met_L_c + 13.0 phe_L_c + 35.0 pro_L_c + 53.0 ser_L_c + 38.0 thr_L_c + 9.0 trp_L_c + 22.0 tyr_L_c + 43.0 val_L_c --> adp_c + 451.0 amp_c + 900.0 gdp_c + 901.0 h_c + igg_hc_r + 901.0 pi_c + 451.0 ppi_c = {'charge': -458.0, 'C': -2199.0, 'H': -3849.0, 'N': -577.0, 'O': -675.0, 'S': -16.0}
# igg_lc: 15.0 ala_L_c + 6.0 arg_L_c + 7.0 asn_L_c + 6.0 asp_L_c + 214.0 atp_c + 5.0 cys_L_c + 12.0 gln_L_c + 11.0 glu_L_c + 13.0 gly_c + 424.0 gtp_c + 425.0 h2o_c + 3.0 his_L_c + 7.0 ile_L_c + 13.0 leu_L_c + 13.0 lys_L_c + met_L_c + 7.0 phe_L_c + 13.0 pro_L_c + 35.0 ser_L_c + 17.0 thr_L_c + 4.0 trp_L_c + 9.0 tyr_L_c + 16.0 val_L_c --> adp_c + 213.0 amp_c + 424.0 gdp_c + 425.0 h_c + igg_lc_r + 425.0 pi_c + 213.0 ppi_c = {'charge': -215.0, 'C': -1016.0, 'H': -1790.0, 'N': -273.0, 'O': -327.0, 'S': -6.0}
# igg_formation: 2.0 igg_hc_r + 2.0 igg_lc_r + 2.0 l2fn2m2masn_g --> igg_g = {'C': -136.0, 'H': -226.0, 'N': -8.0, 'O': -98.0, 'X': -2.0}
# PCLYSOX: akg_c + o2_c + pcollglys_c --> co2_c + pcollg5hlys_c + succ_c = {'charge': -1.0, 'C': -1.0, 'N': -1.0, 'R': -2.0}
# DM_T_antigen_g_: T_antigen_g -->  = {'C': -14.0, 'H': -24.0, 'N': -1.0, 'O': -10.0, 'X': -1.0}
# DM_avite1_c_: avite1_c -->  = {'C': -29.0, 'H': -50.0, 'O': -2.0}
# DM_avite2_c_: avite2_c -->  = {'C': -29.0, 'H': -44.0, 'O': -2.0}
# DM_bvite_c_: bvite_c -->  = {'C': -28.0, 'H': -48.0, 'O': -2.0}
# DM_core5_g_: core5_g -->  = {'C': -16.0, 'H': -27.0, 'N': -2.0, 'O': -10.0, 'X': -1.0}
# DM_core7_g_: core7_g -->  = {'C': -16.0, 'H': -27.0, 'N': -2.0, 'O': -10.0, 'X': -1.0}
# DM_core8_g_: core8_g -->  = {'C': -14.0, 'H': -24.0, 'N': -1.0, 'O': -10.0, 'X': -1.0}
# DM_dem2emgacpail_prot_cho_r_: dem2emgacpail_prot_cho_r -->  = {'C': -39.0, 'H': -70.0, 'N': -3.0, 'O': -38.0, 'P': -3.0, 'F': -2.0, 'U': -2.0, 'L': -4.0, 'R': -3.0, 'X': -1.0}
# DM_dgpi_prot_cho_r_: dgpi_prot_cho_r -->  = {'C': -41.0, 'H': -76.0, 'N': -4.0, 'O': -41.0, 'P': -4.0, 'F': -2.0, 'U': -2.0, 'L': -4.0, 'R': -3.0, 'X': -1.0}
# DM_dsT_antigen_g_: dsT_antigen_g -->  = {'charge': 2.0, 'C': -36.0, 'H': -56.0, 'N': -3.0, 'O': -26.0, 'X': -1.0}
# DM_dttp_m_: dttp_m -->  = {'charge': 4.0, 'C': -10.0, 'H': -13.0, 'N': -2.0, 'O': -14.0, 'P': -3.0}
# DM_ethamp_r_: ethamp_r -->  = {'charge': 1.0, 'C': -2.0, 'H': -7.0, 'N': -1.0, 'O': -4.0, 'P': -1.0}
# DM_gncore2_g_: gncore2_g -->  = {'C': -30.0, 'H': -50.0, 'N': -3.0, 'O': -20.0, 'X': -1.0}
# DM_kdn_c_: kdn_c -->  = {'charge': 1.0, 'C': -9.0, 'H': -15.0, 'O': -9.0}
# DM_n5m2masn_g_: n5m2masn_g -->  = {'C': -74.0, 'H': -122.0, 'N': -7.0, 'O': -50.0, 'X': -1.0}
# DM_sTn_antigen_g_: sTn_antigen_g -->  = {'charge': 1.0, 'C': -19.0, 'H': -30.0, 'N': -2.0, 'O': -13.0, 'X': -1.0}
# DM_sprm_c_: sprm_c -->  = {'charge': -4.0, 'C': -10.0, 'H': -30.0, 'N': -4.0}
# DM_yvite_c_: yvite_c -->  = {'C': -28.0, 'H': -48.0, 'O': -2.0}
# DM_56iqcrbxlt_c_: 56iqcrbxlt_c -->  = {'charge': 1.0, 'C': -9.0, 'H': -4.0, 'N': -1.0, 'O': -4.0}
# SK_pre_prot_r_: pre_prot_r <=>  = {'X': -1.0, 'Y': -1.0}
# 909
