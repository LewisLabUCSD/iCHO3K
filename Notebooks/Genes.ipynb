# %% [markdown]
# # Whole Cell Network Reconstruction in CHO Cells
# The following notebook retrieves and updates information in the "Whole Cell Network Reconstruction for CHO Cells" Google Sheet file.

# %% [markdown]
# ### 1. Access and retrieve information from the Google Sheet file through the Google Sheet API
# Using the gspread library we can access the Google Sheet file and create a pandas df to visualize it.

# %%
import gspread
import pandas as pd
import numpy as np
import time
from tqdm.notebook import tqdm

from google_sheet import GoogleSheet
from utils import get_gene_info
# Out:
# /Users/pablodigiusto/miniforge3/envs/mncho/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.4
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
KEY_FILE_PATH = 'credentials.json'
SPREADSHEET_ID = '1MlBXeHIKw8k8fZyXm-sN__AHTRSunJxar_-bqvukZws'

# Initialize the GoogleSheet object
sheet = GoogleSheet(SPREADSHEET_ID, KEY_FILE_PATH)

# Read data from the Google Sheet
sheet_rxns = 'Rxns'
sheet_genes = 'Genes'

rxns = sheet.read_google_sheet(sheet_rxns)
genes = sheet.read_google_sheet(sheet_genes)

# %%
rxns
# Out:
#       Curated        Reaction  \
# 0          PD    10FTHF5GLUtl
# 1          PD    10FTHF5GLUtm
# 2          PD    10FTHF6GLUtl
# 3          PD    10FTHF6GLUtm
# 4          PD    10FTHF7GLUtl
# ...       ...             ...
# 11379    Than       SPHINGStg
# 11380      PD     XOLEST226tl
# 11381      PD  XOLEST226_HSte
# 11382      PD     XOLEST205tl
# 11383      PD  XOLEST205_HSte
#
#                                            Reaction Name  \
# 0                 5-glutamyl-10FTHF transport, lysosomal
# 1             5-glutamyl-10FTHF transport, mitochondrial
# 2                 6-glutamyl-10FTHF transport, lysosomal
# 3             6-glutamyl-10FTHF transport, mitochondrial
# 4                 7-glutamyl-10FTHF transport, lysosomal
# ...                                                  ...
# 11379                Sphingosine Intracellular Transport
# 11380  Intracellular Transport of Cholesteryl Docosah...
# 11381  Transport of Cholesteryl Docosahexanoate, Chol...
# 11382  Intracellular Transport of 1-Timnodnoyl-Choles...
# 11383  Transport of 1-Timnodnoyl-Cholesterol, Cholest...
#
#                         Reaction Formula                   Subsystem GPR_hef  \
# 0          10fthf5glu_c --> 10fthf5glu_l        TRANSPORT, LYSOSOMAL
# 1          10fthf5glu_m --> 10fthf5glu_c    TRANSPORT, MITOCHONDRIAL
# 2          10fthf6glu_c --> 10fthf6glu_l        TRANSPORT, LYSOSOMAL
# 3          10fthf6glu_m --> 10fthf6glu_c    TRANSPORT, MITOCHONDRIAL
# 4          10fthf7glu_c --> 10fthf7glu_l        TRANSPORT, LYSOSOMAL
# ...                                  ...                         ...     ...
# 11379            sphings_c <=> sphings_g  TRANSPORT, GOLGI APPARATUS    None
# 11380  xolest226_hs_c <=> xolest226_hs_l        Transport, lysosomal    None
# 11381  xolest226_hs_e <=> xolest226_hs_c    Transport, extracellular    None
# 11382  xolest205_hs_c <=> xolest205_hs_l        Transport, lysosomal    None
# 11383  xolest205_hs_e <=> xolest205_hs_c    Transport, extracellular    None
#
#       GPR_fou GPR_yeo GPR_Recon3D GPR_final Conf. Score  \
# 0                                                     1
# 1                                                     1
# 2                                                     1
# 3                                                     1
# 4                                                     1
# ...       ...     ...         ...       ...         ...
# 11379    None    None        None      None        None
# 11380    None    None        None      None        None
# 11381    None    None        None      None        None
# 11382    None    None        None      None        None
# 11383    None    None        None      None        None
#
#                                           Curation Notes References
# 0      No information available in the literature abo...       None
# 1      No information available in the literature abo...       None
# 2      No information available in the literature abo...       None
# 3      No information available in the literature abo...       None
# 4      No information available in the literature abo...       None
# ...                                                  ...        ...
# 11379                                               None       None
# 11380                                               None       None
# 11381                                               None       None
# 11382                                               None       None
# 11383                                               None       None
#
# [11384 rows x 13 columns]

# %% [markdown]
# ### 2. Add information to the "Genes" sheet

# %% [markdown]
# Using a list of all the genes included in the dataset we can retrieve information from the NIH database regarding Gene Symbol, Gene Name, Gene Ensembl ID, and mRNA ID and protein ID

# %%
# Generation of gene_list from all the genes in the "Whole Cell Network Reconstruction in CHO Cells" dataset
import re

gene_list = []
for index, row in rxns.iterrows():
    if row['GPR_final'] != '':
        gpr = str(row['GPR_final'])
        num = re.findall(r'\d+', gpr)
        for n in num:
            gene_list.append(n)
        
gene_list = list(set(gene_list))

# %%
gene_list
# Out:
# ['100752960',
#  '100770451',
#  '100757447',
#  '100761807',
#  '100764470',
#  '170685',
#  '107977085',
#  '100752414',
#  '100767265',
#  '103158533',
#  '100760366',
#  '100769119',
#  '100753214',
#  '100755147',
#  '100689330',
#  '100753201',
#  '100770447',
#  '100773432',
#  '103158535',
#  '100761287',
#  '100762873',
#  '100769028',
#  '100774016',
#  '100751275',
#  '100764351',
#  '100754654',
#  '100760370',
#  '100751157',
#  '100758490',
#  '100752162',
#  '100753172',
#  '100761001',
#  '100760805',
#  '100772629',
#  '100689022',
#  '100753680',
#  '100767681',
#  '100769024',
#  '9426',
#  '3100755534',
#  '100770562',
#  '103159036',
#  '100751831',
#  '100773213',
#  '100770177',
#  '100288072',
#  '100759203',
#  '100753866',
#  '100767554',
#  '100773089',
#  '100760870',
#  '100766001',
#  '100764752',
#  '100750766',
#  '100755812',
#  '100752583',
#  '100758565',
#  '100763073',
#  '84265',
#  '100770206',
#  '100756898',
#  '100760429',
#  '100774338',
#  '100764110',
#  '100758873',
#  '100761516',
#  '6259',
#  '100756607',
#  '100770104',
#  '100767615',
#  '100762876',
#  '100763332',
#  '100689232',
#  '100765986',
#  '100764515',
#  '100762893',
#  '100753472',
#  '11128',
#  '100752418',
#  '100752643',
#  '100769158',
#  '765',
#  '100758073',
#  '100755697',
#  '100763102',
#  '100754527',
#  '100758514',
#  '103158732',
#  '100753287',
#  '100758127',
#  '100772054',
#  '100763818',
#  '100772950',
#  '100763558',
#  '100768559',
#  '100769399',
#  '54579',
#  '100774783',
#  '100753881',
#  '100766230',
#  '100774758',
#  '100756272',
#  '103161104',
#  '100757611',
#  '100760810',
#  '100766617',
#  '100758732',
#  '100769145',
#  '100765201',
#  '107977536',
#  '100765129',
#  '100774684',
#  '100763612',
#  '100757719',
#  '100750644',
#  '100773218',
#  '103158725',
#  '100757919',
#  '100752023',
#  '100765792',
#  '100769696',
#  '100760117',
#  '100752744',
#  '100762288',
#  '100765637',
#  '100763494',
#  '64174',
#  '100761447',
#  '64219',
#  '100768191',
#  '100772179',
#  '100760583',
#  '100767396',
#  '412',
#  '56898',
#  '100682536',
#  '100762360',
#  '100762146',
#  '3979184',
#  '100761130',
#  '103164350',
#  '100774317',
#  '100760127',
#  '100759307',
#  '730262',
#  '10134',
#  '100763285',
#  '100760467',
#  '100774047',
#  '100763756',
#  '100764812',
#  '100770957',
#  '100756648',
#  '100766850',
#  '100754432',
#  '100767276',
#  '100750357',
#  '100763413',
#  '873',
#  '100751771',
#  '100762707',
#  '100773025',
#  '100757328',
#  '100760137',
#  '285220',
#  '100773684',
#  '100765813',
#  '100763030',
#  '27338',
#  '100689341',
#  '100750940',
#  '100757931',
#  '100761882',
#  '100774306',
#  '100767856',
#  '100761613',
#  '100764094',
#  '100759687',
#  '100767492',
#  '100757371',
#  '100770744',
#  '100772469',
#  '100689202',
#  '100756246',
#  '100751073',
#  '100689192',
#  '107977040',
#  '440138',
#  '100759237',
#  '100770735',
#  '54659',
#  '100764594',
#  '100766693',
#  '100766715',
#  '100768862',
#  '100774782',
#  '100768951',
#  '501',
#  '100763012',
#  '100755714',
#  '100767354',
#  '100764088',
#  '100759172',
#  '100689437',
#  '100760403',
#  '100771815',
#  '100763640',
#  '100774773',
#  '100770073',
#  '199974',
#  '100774789',
#  '1208100774605',
#  '100761026',
#  '100756755',
#  '100767465',
#  '100773059',
#  '100768220',
#  '100766045',
#  '2169',
#  '100689430',
#  '81888',
#  '100689322',
#  '100761812',
#  ...]

# %%
import time
from urllib.error import HTTPError
from Bio.Entrez.Parser import ValidationError

max_retries = 5  # Set the maximum number of retries

for g in tqdm(gene_list):
    if g not in list(genes['Gene Entrez ID']):
        retry = True
        retries = 0
        while retry:
            try:
                print(g)
                gene_symbol, gene_name, gene_description, picr_ensembl_id, chok1gs_ensembl_id, mRNA_ncbi_id, protein_ncbi_id, go_terms = get_gene_info(g)
                new_row_data = {'Gene Entrez ID': g, 'Gene Symbol': gene_symbol, 'Gene Name': gene_name, 'Gene Description': gene_description,
                                'PICR Ensembl ID': picr_ensembl_id, 'CHOK1GS Ensembl ID': chok1gs_ensembl_id, 'Transcript ID': mRNA_ncbi_id,
                                'Protein ID': protein_ncbi_id, 'GO Terms': go_terms}
                new_row_df = pd.DataFrame(new_row_data, index=[len(genes)])
                genes = pd.concat([genes, new_row_df])
                retry = False
            except ValidationError:
                print(f'Gene {g} not found')
                retry = False
                continue
            except HTTPError:
                retries += 1
                if retries > max_retries:
                    print(f'HTTP Error, reached maximum retries ({max_retries}) for gene {g}')
                    break
                else:
                    print(f'HTTP Error, retrying with gene {g}')
                    time.sleep(1)
# Out:
#   0%|          | 0/3235 [00:00<?, ?it/s]
# 3100755534
# Gene 3100755534 not found
# 12100769644
# Gene 12100769644 not found
# 7100762626
# Gene 7100762626 not found
# 75100768098
# Gene 75100768098 not found
# 33100766715
# Gene 33100766715 not found
# 28100761226
# Gene 28100761226 not found
# 0
# HTTP Error, retrying with gene 0
# 0
# HTTP Error, retrying with gene 0
# 0
# HTTP Error, retrying with gene 0
# 0
# HTTP Error, retrying with gene 0
# 0
# HTTP Error, retrying with gene 0
# 0
# HTTP Error, reached maximum retries (5) for gene 0
# 100763623
# 100757874
# 100759316
# 100762475
# Gene 100762475 does not have PICR Ensembl ID
# 4056
# 100689446
# 100751465
# Gene 100751465 does not have PICR Ensembl ID
# 100757047
# 100689424
# 100765354
# 100750910
# 100768660
# 100756363
# 100759847
# 100769695
# 100771995
# 100759026
# 103159088
# Gene 103159088 does not have PICR Ensembl ID
# 100760125
# 100762088
# 7381
# 100757481
# 100762673
# 5319
# 158584
# 100757928
# 100773612
# 100773003
# 100774095
# HTTP Error, retrying with gene 100774095
# 100774095
# 100750488
# 100760329
# 113830817
# Gene 113830817 does not have PICR Ensembl ID
# 100689237
# 100760863
# 100750844
# Gene 100750844 does not have PICR Ensembl ID
# 100764060
# 100759710
# Gene 100759710 does not have PICR Ensembl ID
# 100768097
# 100770478
# 100763954
# 100769856
# 100760456
# 100765320
# 100765899
# 100755602
# 100758995
# 100774202
# 100763487
# 100753681
# Gene 100753681 does not have PICR Ensembl ID
# 100752124
# 100772560
# 100758489
# 100774164
# 3979189
# Gene 3979189 does not have PICR Ensembl ID
# Gene 3979189 does not have info on human ortholog description
# 100769766
# 100752374
# 113837643
# 54600
# 100756154
# 100771005
# 100760127
# Gene 100760127 does not have PICR Ensembl ID
# 100759307
# 730262
# 10134
# 100763285
# 100760467
# 100774047
# 100764812
# 100756648
# 100754432
# 100750357
# 100763413
# 873
# 100751771
# 100762707
# 100773025
# 100760137
# 285220
# 100773684
# 100765813
# 27338
# 100750940
# 100761613
# 100759687
# 100767492
# 100770744
# 100772469
# 100689202
# 100751073
# 100689192
# 107977040
# Gene 107977040 does not have PICR Ensembl ID
# 440138
# 100770735
# 100764594
# 100766693
# 100766715
# 100768862
# 100774782
# 100768951
# 100763012
# 100755714
# 100767354
# 100759172
# 100760403
# 100774773
# 100770073
# 1208100774605
# Gene 1208100774605 not found
# 100761026
# 100773753
# 100768200
# 100759864
# 100773204
# 100768417
# 100755796
# 100765601
# 100772122
# 85100771815
# Gene 85100771815 not found
# 100754593
# 100773704
# 100774970
# 100770579
# 100764100
# HTTP Error, retrying with gene 100764100
# 100764100
# Gene 100764100 does not have PICR Ensembl ID
# 100752385
# 100757073
# 100752221
# 100752348
# 100768549
# 100758721
# 100756784
# 100765639
# 100689029
# 100766703
# 100768142
# 100756378
# 100770849
# 103158809
# Gene 103158809 does not have PICR Ensembl ID
# 100752642
# 8287
# 25828
# 100758528
# 100753294
# 100763114
# 100757648
# 100766250
# 100762656
# 103163089
# 100765374
# 100751944
# 100754811
# 100758292
# 100772657
# 100760676
# 158160
# 100757916
# Gene 100757916 does not have PICR Ensembl ID
# 100770431
# 100752129
# 100774485
# 100772770
# 100761854
# 100753131
# 100760312
# 100774580
# 79872
# 100761381
# 113831071
# Gene 113831071 does not have PICR Ensembl ID
# 100752999
# 100772477
# 3176
# 100689389
# 100752202
# 100762813
# 100764834
# 100764359
# 100762645
# Gene 100762645 does not have PICR Ensembl ID
# 100769613
# 60496
# 100756760
# 79868
# 103159649
# 100769140
# 100759393
# 100763780
# 103161868
# Gene 103161868 does not have PICR Ensembl ID
# 100772185
# 100768929
# 100757617
# 100774213
# 100772142
# 100772646
# 100774395
# 100755657
# 100765697
# 100756309
# 100765407
# 100752881
# 100769017
# 100766443
# 60559
# 100760686
# 100773170
# 100773714
# 100769710
# 100761226
# 100761270
# 103162274
# Gene 103162274 does not have PICR Ensembl ID
# 100773441
# 100689435
# 100769025
# 100759020
# 100770977
# 113830649
# 100757074
# 100767503
# 100768055
# 100771594
# 100761532
# Gene 100761532 does not have PICR Ensembl ID
# 100761706
# 100764964
# 100764465
# 100758427
# 100771949
# Gene 100771949 does not have PICR Ensembl ID
# 100757579
# 100762552
# 100753811
# 100758520
# 100750518
# 100752256
# 2651
# 100758694
# 100760469
# 100768395
# 100754386
# 100769146
# 100765343
# 100772443
# 100765356
# 100754706
# 5793
# 100762316
# 100759992
# 56852
# 100761098
# 100758293
# 100754441
# 100768515
# 100770821
# Gene 100770821 does not have PICR Ensembl ID
# 100772527
# 100760824
# 100756962
# 100760777
# 100689314
# Gene 100689314 does not have PICR Ensembl ID
# 100755055
# 100759952
# 100753943
# 118239120
# Gene 118239120 does not have PICR Ensembl ID
# 100754473
# 100769417
# Gene 100769417 does not have PICR Ensembl ID
# 100759620
# 100769250
# 100760589
# 100772592
# Gene 100772592 does not have PICR Ensembl ID
# 100755870
# 100773586
# 100759356
# 100761931
# 103158861
# Gene 103158861 does not have PICR Ensembl ID
# 100760905
# 100771478
# 100756019
# 100753835
# 100753284
# 2679
# 100750776
# 100762677
# 100767301
# 100766858
# 100756528
# 100767419
# 100770750
# 100761973
# 100754688
# 100759100
# Gene 100759100 does not have PICR Ensembl ID
# 100763153
# 100761128
# 100761450
# 100768334
# 100754270
# 100765727
# 100759109
# 100758766
# 9739
# 100774375
# 100768613
# Gene 100768613 does not have PICR Ensembl ID
# 100754421
# 100754324
# Gene 100754324 does not have PICR Ensembl ID
# 100764402
# 100761460
# 100766449
# 100773013
# 100750332
# 100757118
# 100769940
# 1603
# 100750845
# 100761885
# 100762532
# 100767156
# 100689199
# 100773095
# 100755665
# 100764560
# 100772620
# 100763947
# 100766519
# 113830648
# 100754737
# 373856
# Gene 373856 does not have mRNA id and protein id
# 100763928
# 100762119
# 100758814
# 1845
# 100752709
# 100754900
# 100770428
# 4166
# 728419
# 100762260
# 100753439
# 100755985
# 1584
# 100752493
# 100766923
# 100689021
# 100763971
# 100762426
# 100772743
# 100762575
# 100759780
# 100754452
# 100764708
# 100751933
# 107977238
# Gene 107977238 does not have PICR Ensembl ID
# 100771589
# 103162332
# 100761712
# 100766710
# 100756367
# 100757665
# 100767620
# 100750792
# 100768656
# 100751872
# 5277
# 100770995
# 100761511
# 100774671
# 100765841
# 100689318
# 100751939
# 100751027
# 419
# 100768340
# 100753973
# 100759612
# 100689057
# 100757917
# 100775067
# 100760557
# 100754967
# 100754996
# 100750993
# 100765030
# 100769865
# 100753361
# 100774535
# 1579
# 100774930
# 100765877
# Gene 100765877 does not have PICR Ensembl ID
# 441282
# 100761725
# 100754712
# 100758055
# 100751820
# HTTP Error, retrying with gene 100751820
# 100751820
# 5163
# 100760689
# 100771700
# 100756666
# Gene 100756666 does not have PICR Ensembl ID
# 100759544
# 100760822
# Gene 100760822 does not have PICR Ensembl ID
# 100751568
# 100764988
# 100761076
# 100772576
# 100771779
# 100764076
# 100755257
# Gene 100755257 does not have PICR Ensembl ID
# 100767909
# 100772204
# 9943
# 100751653
# 1806
# 100768377
# 107977577
# Gene 107977577 does not have PICR Ensembl ID
# 29124
# 100771308
# 100765046
# 100756143
# 100768481
# 100767633
# 149603
# 100761190
# 100752475
# Gene 100752475 does not have PICR Ensembl ID
# 100754068
# 100768771
# 100762701
# 100750390
# 100765164
# 100750494
# Gene 100750494 does not have PICR Ensembl ID
# 100760447
# 100761111
# 100753549
# 100766004
# Gene 100766004 does not have PICR Ensembl ID
# 100764408
# 113833388
# 100760904
# 100766917
# 100755304
# 100760506
# 100753542
# Gene 100753542 does not have PICR Ensembl ID
# 160287
# 100773570
# 100770730
# 100759648
# 100751503
# 100769764
# 100752038
# 100774657
# HTTP Error, retrying with gene 100774657
# 100774657
# 100752487
# 100765264
# 100772460
# 100754618
# 100767969
# 100769697
# 100761196
# 100753241
# Gene 100753241 does not have PICR Ensembl ID
# 7329
# 100774283
# 100764390
# 100759942
# 126
# 100754740
# 100755145
# 100760459
# 103161923
# Gene 103161923 does not have PICR Ensembl ID
# 100759926
# 100756335
# 100752342
# Gene 100752342 does not have PICR Ensembl ID
# 100767723
# 100762350
# 100762108
# 100767961
# 100766880
# 100771894
# 100757066
# 100765162
# 100758589
# 100766108
# 8732
# 100764843
# 100770521
# 100770734
# 100772590
# 5441
# 100765516
# 100769100
# 103158908
# 100773070
# 100774953
# 100774705
# 100760711
# 100762175
# 100772471
# 100754065
# 100760162
# 100761779
# 100753531
# 100771767
# 103159291
# 100772585
# Gene 100772585 does not have PICR Ensembl ID
# 100769660
# 100769474
# 1178
# 100756404
# 100757472
# 100761349
# 100767060
# 100764842
# 103162776
# 100770630
# 100758989
# 100766006
# 100765763
# Gene 100765763 does not have PICR Ensembl ID
# 100772785
# 100754940
# 100770619
# 1645
# 100767211
# Gene 100767211 does not have PICR Ensembl ID
# 100753508
# 100760375
# 100760802
# 100768506
# 100755392
# 100760595
# 100752125
# Gene 100752125 does not have PICR Ensembl ID
# 100770799
# 100751248
# 100763368
# 100759889
# 100751361
# 100769186
# 64090
# 100752902
# 100769904
# 100752687
# 100761969
# 100770034
# 100755534
# 100755361
# HTTP Error, retrying with gene 100755361
# 100755361
# 100755756
# 100756729
# Gene 100756729 does not have PICR Ensembl ID
# 100766446
# 100759065
# 100752851
# 100774595
# 100761676
# 100768997
# 100763335
# 100752705
# 100762786
# 100758086
# 100769715
# 100760138
# 100774965
# 100760192
# Gene 100760192 does not have PICR Ensembl ID
# 100756945
# 100758921
# 100772148
# 23411
# 2525
# 100755205
# 100760922
# 66002
# 100755684
# Gene 100755684 does not have PICR Ensembl ID
# 100761551
# 100770087
# 100750559
# 124
# 100765772
# 100767370
# 100762619
# 100756769
# 100772118
# 100763633
# 100771275
# 100760683
# 100756336
# 100754771
# 100774416
# 653505
# 100774301
# 100758107
# 100772907
# 100771266
# 100771250
# 100767305
# 100772790
# 100750718
# 56267
# 23318
# 100752729
# 100761747
# 100770363
# 100756929
# 100751979
# 100767638
# 100756958
# 100762089
# 100765874
# 100752094
# 100689242
# 103159960
# Gene 103159960 does not have PICR Ensembl ID
# Gene 103159960 does not have mRNA id and protein id
# 100760691
# Gene 100760691 does not have PICR Ensembl ID
# 100761486
# 100689382
# Gene 100689382 does not have PICR Ensembl ID
# 100757710
# 100689360
# 100771257
# Gene 100771257 does not have PICR Ensembl ID
# 100772304
# 100762326
# 100764171
# 100771287
# 100772409
# 100760215
# Gene 100760215 does not have PICR Ensembl ID
# 100752307
# 79966
# 100772418
# 100756894
# 100752265
# 100767789
# 100751506
# Gene 100751506 does not have PICR Ensembl ID
# 100758176
# Gene 100758176 does not have PICR Ensembl ID
# 100756995
# 100756080
# 100758810
# 100771223
# 100750530
# 1350
# 100759507
# 293
# 100760227
# 100760126
# 100759286
# 100762852
# 100770943
# 100765733
# 100766883
# 100753288
# 100770540
# 100768635
# 23609
# 3979180
# Gene 3979180 does not have PICR Ensembl ID
# Gene 3979180 does not have info on human ortholog description
# 100772970
# 100754751
# 7803
# 100759194
# 100763519
# 100762698
# 100766339
# 100752115
# 100771315
# 100774451
# 100759513
# 100768141
# 100773215
# 103160352
# 100770979
# 100758963
# 100752531
# 100771014
# 100751263
# 100750762
# 100756860
# 100767996
# 100769331
# 100758369
# 100757359
# 100689395
# 100764723
# 100760500
# 100756118
# 100760748
# 100771425
# 100759373
# 100764716
# 100771256
# 100757019
# 100689311
# 100772355
# 100758406
# Gene 100758406 does not have PICR Ensembl ID
# 100763159
# 100774234
# 728386
# 100774815
# Gene 100774815 does not have PICR Ensembl ID
# 100753298
# 100765020
# 100770748
# 100767367
# 100761903
# 100753359
# 100757007
# 100689251
# 100773751
# 100769679
# 100754973
# 100769849
# 100764994
# 100766341
# Gene 100766341 does not have PICR Ensembl ID
# 100766521
# 100766861
# 103163635
# Gene 103163635 does not have PICR Ensembl ID
# 100760327
# 100751938
# 100765198
# 100765172
# 100768667
# 100753458
# 100762944
# 100763298
# Gene 100763298 does not have PICR Ensembl ID
# 100756540
# 100752017
# 100773186
# 100764192
# 100758154
# 100763775
# 100756078
# 100761840
# 100762053
# 100761139
# 3979182
# Gene 3979182 does not have PICR Ensembl ID
# Gene 3979182 does not have info on human ortholog description
# 100769497
# 100759258
# 23430
# 100761968
# 219333
# 100767617
# 100755925
# 100765415
# 100758998
# 100761172
# 5320
# 100757800
# Gene 100757800 does not have PICR Ensembl ID
# 100766524
# 100771401
# Gene 100771401 does not have PICR Ensembl ID
# 100766628
# 100773326
# 100752571
# 100764840
# 100773166
# 100770343
# 100761709
# 100767351
# 100750356
# 100752157
# 100769832
# 100761743
# 100750575
# 2938
# 100754520
# 100753623
# 100757022
# 100763903
# 100773026
# 100771960
# 100772935
# 100754496
# 100774248
# 100766440
# 100763205
# 100751376
# 100755303
# 100758009
# 100751457
# HTTP Error, retrying with gene 100751457
# 100751457
# 388714
# 100762875
# 100772727
# 100771604
# 100770445
# 100768719
# 100689433
# Gene 100689433 does not have PICR Ensembl ID
# 100772511
# 100770570
# 100754604
# 100769372
# 100761683
# 100758980
# 100759107
# 100750407
# Gene 100750407 does not have PICR Ensembl ID
# 100767292
# Gene 100767292 does not have PICR Ensembl ID
# 100758613
# 100757519
# 100760949
# 100767434
# 100765738
# 100689028
# 100755376
# 100755963
# Gene 100755963 does not have PICR Ensembl ID
# 100768120
# 26062
# 100756936
# 100759583
# 100766856
# 112858
# 113836769
# 100769511
# 100772643
# 100756731
# 100751001
# 100757670
# 2352
# 100761765
# Gene 100761765 does not have PICR Ensembl ID
# 100767558
# 100772782
# 100771525
# 118238400
# Gene 118238400 does not have PICR Ensembl ID
# 100774957
# 100761948
# Gene 100761948 does not have PICR Ensembl ID
# 100758981
# 8574
# 100689399
# 100772645
# 100751492
# 100768321
# 100752127
# 100760725
# 100756438
# Gene 100756438 does not have PICR Ensembl ID
# 100529261
# 100771272
# 100774072
# 100774853
# 100764893
# 100752011
# 100760611
# 100772288
# 100769754
# 100761591
# 100767097
# 100757400
# 100750903
# Gene 100750903 does not have PICR Ensembl ID
# 100754505
# 100754031
# 100287513
# 100762250
# 100766643
# 100761116
# 100762028
# 100750736
# 100769222
# 100763004
# 23326
# 100754333
# 100768176
# 10914
# HTTP Error, retrying with gene 10914
# 10914
# 100756878
# 100764967
# 100770125
# Gene 100770125 does not have PICR Ensembl ID
# 100760968
# 100773012
# 100772227
# 100774204
# 100764118
# 100766101
# 100769825
# Gene 100769825 does not have PICR Ensembl ID
# 100769644
# 100773930
# 100772571
# 100756512
# 100762723
# 100770628
# 100771188
# Gene 100771188 does not have PICR Ensembl ID
# 100766725
# 100771488
# 100756678
# 100774144
# 9100754737
# Gene 9100754737 not found
# 100754963
# 100768531
# 100772543
# 100761760
# 100761359
# 100771717
# 2286
# 100759325
# 100755170
# 100760940
# Gene 100760940 does not have PICR Ensembl ID
# 113830741
# Gene 113830741 does not have PICR Ensembl ID
# 100765100
# 760
# 100772003
# 100766993
# 100766192
# 100755324
# 100768281
# 100759365
# 5501
# 100753348
# 100752582
# 100758459
# 100761329
# 100757929
# 100765484
# 100757713
# 100769056
# 100759330
# 100765635
# 67100768098
# Gene 67100768098 not found
# 100756691
# 100754073
# 100761252
# 100770918
# 100762186
# 100761524
# 377630
# 100765055
# 100774650
# 100758075
# 80235
# 100757133
# 100772328
# 100689104
# 103160864
# 100689359
# 100772741
# 100763807
# 100767926
# Gene 100767926 does not have PICR Ensembl ID
# 100752689
# 100771549
# 4353
# 9789
# 100763199
# 100775004
# 100762075
# 100751185
# Gene 100751185 does not have PICR Ensembl ID
# 100774010
# 100762470
# 100756865
# 100759289
# 100758848
# 100753910
# 100763234
# Gene 100763234 does not have PICR Ensembl ID
# 100773953
# 100752205
# Gene 100752205 does not have PICR Ensembl ID
# 2232
# 100753777
# 100759869
# 100751753
# 100765485
# 100759281
# 100759490
# Gene 100759490 does not have PICR Ensembl ID
# 100766433
# 100757510
# 100767869
# 103162266
# 100774277
# 100763278
# 100763079
# 100758776
# 100760867
# 100761455
# 100689187
# 100758668
# 728441
# 100772751
# 100750596
# 100758494
# Gene 100758494 does not have PICR Ensembl ID
# 100773480
# Gene 100773480 does not have PICR Ensembl ID
# 100769769
# 140739
# 100750743
# 100752955
# 100762934
# 100763456
# 100769654
# 100768603
# 100763374
# 100759787
# 100756034
# 100762019
# 100763644
# 100774568
# 10295
# 100761484
# 100770091
# 50484
# 100757101
# 100773768
# 100761392
# Gene 100761392 does not have PICR Ensembl ID
# 100770038
# 100758336
# 100771722
# 100754813
# 100763404
# 100758951
# 100772029
# 100767908
# 100769780
# 100773641
# 8972
# 100773723
# Gene 100773723 does not have PICR Ensembl ID
# 100769040
# 100773236
# 100756456
# 100752710
# Gene 100752710 does not have PICR Ensembl ID
# 100759323
# Gene 100759323 does not have PICR Ensembl ID
# 100769077
# 100764478
# 100768365
# 10105
# 100689176
# 100767978
# 100768258
# 100755692
# 100762811
# 107977589
# Gene 107977589 does not have PICR Ensembl ID
# 100762502
# 100753417
# 100761947
# 100773493
# 100754830
# 100766034
# 100764001
# 100771538
# 100751941
# 100765177
# Gene 100765177 does not have PICR Ensembl ID
# 100689412
# 220074
# 100766800
# Gene 100766800 does not have PICR Ensembl ID
# 100760135
# 100762229
# 100770313
# 100758973
# 100757865
# Gene 100757865 does not have PICR Ensembl ID
# 100764268
# 100760747
# 100766818
# 100751265
# 100756365
# Gene 100756365 does not have PICR Ensembl ID
# 100774411
# 100775069
# 100763206
# 100760812
# 100770120
# 100765460
# 100752502
# 100770013
# 100689328
# 100759274
# 100766150
# 100766982
# 100768271
# Gene 100768271 does not have PICR Ensembl ID
# 79603
# 100754947
# 5440
# 51619
# 100764862
# 8644
# 100761198
# 100752584
# 30
# 100760756
# 100772199
# 85363
# 100758983
# 100754226
# 100756695
# Gene 100756695 does not have PICR Ensembl ID
# 100771088
# 100755982
# 100755464
# 100750866
# 10524
# 100754221
# 100770742
# 100755381
# Gene 100755381 does not have PICR Ensembl ID
# 100757141
# 100754426
# 100753746
# 100763851
# Gene 100763851 does not have PICR Ensembl ID
# 100765904
# 100758335
# 100762222
# 100762397
# 100757464
# 100771238
# 100761465
# 100772244
# 100766487
# Gene 100766487 does not have PICR Ensembl ID
# 100762999
# 1549
# 100759285
# 10714
# 100750589
# 100759733
# 100761596
# 100768991
# 100751671
# 100754655
# 11143
# 100764255
# 100750354
# 100689315
# 100770462
# 100770749
# 100750761
# 100773727
# 100751271
# 100768107
# 100754814
# 100768641
# 100769118
# 4843
# 100682535
# 100765856
# 100771433
# 100752401
# 2524
# 100754626
# 100756400
# Gene 100756400 does not have PICR Ensembl ID
# 100770329
# 100771893
# 100757947
# 100765511
# 100771064
# 100768228
# 100689191
# 100763673
# Gene 100763673 does not have PICR Ensembl ID
# 100770506
# 100764912
# 100772458
# Gene 100772458 does not have PICR Ensembl ID
# 100760271
# 100756840
# 100762955
# 100774284
# 100773935
# 100758803
# 100764866
# 100751194
# 100762975
# 100762480
# 100764538
# 100768251
# 100774594
# 7332
# 100767270
# 100758937
# 100689351
# 100764208
# 2940
# 100754784
# 100753443
# 100754286
# 100774348
# 55089
# 143162
# 100757350
# 8908
# 133688
# 100772776
# Gene 100772776 does not have PICR Ensembl ID
# 9917
# 1735
# 100766128
# 100689076
# 100765660
# 100762297
# 55284
# 100772932
# 100751113
# 29082
# 100753200
# 100764519
# 100751432
# 100765960
# 100773624
# 100773287
# 100770099
# 100753249
# 100766179
# 100755025
# 100755838
# 100765870
# 100752040
# Gene 100752040 does not have PICR Ensembl ID
# 5568
# 3979179
# Gene 3979179 does not have PICR Ensembl ID
# Gene 3979179 does not have info on human ortholog description
# 100758512
# 100770352
# 100752064
# 100769018
# 2280
# 100757349
# 100765193
# 100765192
# 100760513
# 100768067
# 100771156
# 8681
# 100762536
# 100767598
# 100763383
# 100753123
# Gene 100753123 does not have PICR Ensembl ID
# 100773810
# 103159043
# Gene 103159043 does not have PICR Ensembl ID
# 100755521
# 100768978
# 100772999
# 100772985
# 100764792
# 92483
# 100750431
# 100753149
# 100758298
# 100751586
# 100759381
# 5162
# 100772863
# 100762788
# 100762467
# 100766805
# 100770803
# 100766403
# 100765544
# 137902
# 100770936
# 100758939
# 280
# 100689035
# 100756471
# 100756257
# 100758718
# 100763346
# 100758772
# 100772936
# 100757649
# Gene 100757649 does not have PICR Ensembl ID
# 100774702
# 100750732
# 644378
# Gene 644378 does not have mRNA id and protein id
# 100751762
# 100754256
# 100751402
# 100769477
# 100760913
# 100751853
# 100752589
# 100755180
# 100751959
# 100754316
# 100761445
# 100756951
# Gene 100756951 does not have PICR Ensembl ID
# 100689463
# 100772952
# 100768542
# 100758689
# 100751197
# 100757702
# 100761879
# 100771845
# 103164165
# Gene 103164165 does not have PICR Ensembl ID
# 1515
# 100759877
# 100772448
# 100756740
# 170712
# 100689018
# 100771798
# 100761071
# 100774341
# 100756704
# 85320
# 100751099
# 100767730
# 54576
# 100763552
# 100757303
# 1548
# 100762602
# 100755207
# 100764727
# 100758914
# 100772435
# 103164050
# Gene 103164050 does not have PICR Ensembl ID
# 100754103
# 57663
# 100771660
# Gene 100771660 does not have PICR Ensembl ID
# 100756523
# 100760399
# 100770605
# 100759236
# Gene 100759236 does not have PICR Ensembl ID
# 100753655
# 100769436
# 100752449
# 3979190
# Gene 3979190 does not have PICR Ensembl ID
# Gene 3979190 does not have info on human ortholog description
# 100762979
# 100766256
# 100772884
# Gene 100772884 does not have PICR Ensembl ID
# 100760699
# 2952
# 10465
# 8078
# 100771770
# 100760123
# 100758847
# 100772205
# 100762929
# 100751300
# 100758629
# 100756276
# 100757242
# 131890
# 100771896
# 57804
# 100761852
# 100766459
# 100689391
# 100766828
# 100771827
# 100754841
# Gene 100754841 does not have PICR Ensembl ID
# 100769548
# 100761266
# 100766881
# 100765304
# 100765715
# 100773226
# 100770598
# 100757239
# 100758656
# 100769170
# 100772598
# 100765916
# 100766043
# 100755391
# 4677
# 100765466
# Gene 100765466 does not have PICR Ensembl ID
# 100758683
# 100772642
# 100764431
# Gene 100764431 does not have PICR Ensembl ID
# 100763844
# 103158870
# Gene 103158870 does not have PICR Ensembl ID
# 100753258
# 54577
# 100758204
# 100772883
# 100750801
# Gene 100750801 does not have PICR Ensembl ID
# 100753802
# 100756208
# 100759929
# 100765313
# 100770898
# 100773643
# 100762607
# 100689338
# 100754678
# 100765125
# 100751104
# 9420
# 100773351
# 100754832
# 100762233
# 100763175
# 100758551
# 4953
# 100764854
# 100772485
# 100765231
# 55190
# 100762846
# 100767527
# 100774605
# 100758677
# 100759983
# 100759593
# 100772604
# 100761964
# 100751461
# 100757934
# Gene 100757934 does not have PICR Ensembl ID
# 100752954
# Gene 100752954 does not have PICR Ensembl ID
# 100758286
# 1573
# 100760081
# Gene 100760081 does not have PICR Ensembl ID
# 100754772
# 100766714
# 100772184
# Gene 100772184 does not have PICR Ensembl ID
# 100773858
# 100756561
# 100765390
# 10434
# 100754292
# 100765441
# 100765700
# 100774807
# 100761418
# 100756168
# 100767373
# 100758912
# 103160118
# Gene 103160118 does not have PICR Ensembl ID
# 100771587
# 100767468
# 100774155
# 100766442
# 100754677
# 100764620
# 23491
# 55100774605
# Gene 55100774605 not found
# 100755053
# 100754028
# 100757188
# 100766302
# 100768809
# 100750810
# 100753159
# 100754600
# 100767740
# Gene 100767740 does not have PICR Ensembl ID
# 100750622
# Gene 100750622 does not have PICR Ensembl ID
# 100753475
# 100756294
# 100762639
# 276
# 100751435
# 100774614
# 100769931
# 100751500
# 100755690
# 100750954
# 100767136
# 8228
# 100769131
# 100761646
# 100769280
# 100764455
# 100766778
# 103158569
# Gene 103158569 does not have PICR Ensembl ID
# 100761489
# 100774474
# 100771068
# 100767929
# 100767717
# 100763221
# 100752216
# 100773133
# 100769190
# 100752417
# Gene 100752417 does not have PICR Ensembl ID
# 4915
# 100751453
# 107978331
# Gene 107978331 does not have PICR Ensembl ID
# 100768979
# 100758070
# 100756675
# 100758638
# Gene 100758638 does not have PICR Ensembl ID
# 100766418
# 12
# 100767451
# 100689250
# 100761406
# 100771517
# 100757306
# 3283
# 100768315
# 100772330
# 100754361
# 100760696
# 100757212
# 100754006
# Gene 100754006 does not have PICR Ensembl ID
# 100760505
# 100756094
# 100757346
# 100771030
# 100766961
# 100765436
# 100764517
# 100757245
# 2527
# 100764156
# 348158
# 100751269

# %%
genes
# Out:
#      Gene Entrez ID   Gene Symbol  \
# 0         100774298       Slco1b3
# 1         100754260        Hsd3b7
# 2         100769024  LOC100769024
# 3         100756356        Atp2a3
# 4         100774660          Pgls
# ...             ...           ...
# 3226      100757245        Ndufv1
# 3227           2527          FUT5
# 3228      100764156       Slc39a6
# 3229         348158        ACSM2B
# 3230      100751269  LOC100751269
#
#                                               Gene Name  \
# 0     solute carrier organic anion transporter famil...
# 1     hydroxy-delta-5-steroid dehydrogenase, 3 beta-...
# 2                                             aromatase
# 3     ATPase sarcoplasmic/endoplasmic reticulum Ca2+...
# 4                             6-phosphogluconolactonase
# ...                                                 ...
# 3226     NADH:ubiquinone oxidoreductase core subunit V1
# 3227                               fucosyltransferase 5
# 3228                  solute carrier family 39 member 6
# 3229  acyl-CoA synthetase medium chain family member 2B
# 3230                                cytochrome P450 1A1
#
#                                        Gene Description     PICR Ensembl ID  \
# 0     This gene encodes a liver-specific member of t...  ENSCGRG00015012813
# 1     This gene encodes an enzyme which is involved ...  ENSCGRG00015024104
# 2     This gene encodes a member of the cytochrome P...  ENSCGRG00015026385
# 3     This gene encodes one of the SERCA Ca(2+)-ATPa...  ENSCGRG00015000763
# 4     Enables 6-phosphogluconolactonase activity. In...  ENSCGRG00015004513
# ...                                                 ...                 ...
# 3226  The mitochondrial respiratory chain provides e...  ENSCGRG00015019323
# 3227  Enables 3-galactosyl-N-acetylglucosaminide 4-a...     ENSG00000130383
# 3228  Zinc is an essential cofactor for hundreds of ...  ENSCGRG00015022771
# 3229  Enables benzoate-CoA ligase activity. Predicte...     ENSG00000066813
# 3230  This gene, CYP1A1, encodes a member of the cyt...  ENSCGRG00015024903
#
#       CHOK1GS Ensembl ID Transcript ID    Protein ID  \
# 0     ENSCGRG00001021568  XM_035456357  XP_035312248
# 1     ENSCGRG00001010375  XM_003510980  XP_003511028
# 2     ENSCGRG00001015094  XM_003508783  XP_003508831
# 3     ENSCGRG00001017225  XM_035458322  XP_035314213
# 4     ENSCGRG00001024276  XM_027428449  XP_027284250
# ...                  ...           ...           ...
# 3226  ENSCGRG00001015739  XM_003509924  XP_003509972
# 3227                         NM_002034     NP_002025
# 3228  ENSCGRG00001014525  XM_003500808  XP_003500856
# 3229                      NM_001410902  NP_001397831
# 3230  ENSCGRG00001018630  XM_035455835  XP_035311726
#
#                                                GO Terms
# 0     ['GO:0055085', 'GO:0022857', 'GO:0005515', 'GO...
# 1     ['GO:0016020', 'GO:0016491', 'GO:0016616', 'GO...
# 2     ['GO:0016020', 'GO:0046872', 'GO:0016491', 'GO...
# 3     ['GO:0005783', 'GO:0016529', 'GO:0044325', 'GO...
# 4     ['GO:0016787', 'GO:0005975', 'GO:0017057', 'GO...
# ...                                                 ...
# 3226  ['GO:0016020', 'GO:0046872', 'GO:0022900', 'GO...
# 3227
# 3228  ['GO:0005886', 'GO:0005783', 'GO:0005385', 'GO...
# 3229
# 3230  ['GO:0016020', 'GO:0016829', 'GO:0046872', 'GO...
#
# [3231 rows x 9 columns]

# %%
sheet.update_google_sheet(sheet_genes, genes)
print("Google Sheet updated.")
# Out:
# Google Sheet updated.

# %%
for g in tqdm(gene_list):
    if g not in list(genes['Gene Entrez ID']):
        try:
            gene_symbol, gene_name, gene_description, picr_ensembl_id, chok1gs_ensembl_id, mRNA_ncbi_id, protein_ncbi_id, go_terms = get_gene_info(g)
            new_row_data = {'Gene Entrez ID': g, 'Gene Symbol': gene_symbol, 'Gene Name': gene_name, 'Gene Description': gene_description,
                            'PICR Ensembl ID': picr_ensembl_id, 'CHOK1GS Ensembl ID': chok1gs_ensembl_id, 'Transcript ID': mRNA_ncbi_id,
                            'Protein ID': protein_ncbi_id, 'GO Terms': go_terms}
            new_row_df = pd.DataFrame(new_row_data, index=[len(genes)])
            genes = pd.concat([genes, new_row_df])
        except KeyError:
            print(f'Gene {g} not found')
            continue

# %%
# Fetch information from the NIH database


# Complete null or blank information in the already generated "Genes Sheet" dataset
for i,row in genes.iterrows():
    if row['Gene Entrez ID'] == '':
        for g in gene_list:
            gene_sheet_list = [str(x) for x in genes['Gene Entrez ID']]
            if g not in gene_sheet_list:
                gene_symbol, gene_name, gene_description, picr_ensembl_id, chok1gs_ensembl_id, mRNA_ncbi_id, protein_ncbi_id, go_terms = get_gene_info(g)
                row['Gene Entrez ID'] = g
                row['Gene Symbol'] = gene_symbol
                row['Gene Name'] = gene_name
                row['Gene Description'] = gene_description
                row['PICR Ensembl ID'] = picr_ensembl_id
                row['CHOK1GS Ensembl ID'] = chok1gs_ensembl_id
                row['Transcript ID'] = mRNA_ncbi_id
                row['Protein ID'] = protein_ncbi_id
                row['GO Terms'] = go_terms
                break          
    elif row['Gene Entrez ID'] != '' and (row['Gene Symbol'] == '' or row['Gene Name'] == '' or row['PICR Ensembl ID'] == '' or row['Transcript ID'] == '' or row['Protein ID'] == ''):
        row['Gene Symbol'] = gene_symbol
        row['Gene Name'] = gene_name
        row['Gene Description'] = gene_description
        row['PICR Ensembl ID'] = picr_ensembl_id
        row['CHOK1GS Ensembl ID'] = chok1gs_ensembl_id
        row['Transcript ID'] = mRNA_ncbi_id
        row['Protein ID'] = protein_ncbi_id
        row['GO Terms'] = go_terms
'''
# Add genes from the gene_list that are not yet in the "Genes Sheet" dataset
for g in gene_list:
    # the first try/except is to avoid overwritting data in case there already some info in the dataset
    try:
        gene_sheet_list = [str(x) for x in df['Gene Entrez ID']]
        id = max(df['Index']) + 2
    except:
        gene_sheet_list = []
        id = 2
    if gene not in gene_sheet_list:
        try:
            gene_symbol, gene_name, gene_description, picr_ensembl_id, chok1gs_ensembl_id, mRNA_ncbi_id, protein_ncbi_id, go_terms = get_gene_info(gene)
            print(id-1)
            genes_sheet.update_cell(id,1,id-1)
            time.sleep(5)
            genes_sheet.update_cell(id,2,gene)
            time.sleep(5)
            genes_sheet.update_cell(id,3,gene_symbol)
            time.sleep(5)
            genes_sheet.update_cell(id,4,gene_name)
            time.sleep(5)
            genes_sheet.update_cell(id,5,gene_description)
            time.sleep(5)
            genes_sheet.update_cell(id,6,picr_ensembl_id)
            time.sleep(5)
            genes_sheet.update_cell(id,7,chok1gs_ensembl_id)
            time.sleep(5)
            genes_sheet.update_cell(id,8,mRNA_ncbi_id)
            time.sleep(5)
            genes_sheet.update_cell(id,9,protein_ncbi_id)
            time.sleep(5)
            genes_sheet.update_cell(id,10,go_terms)
        except:
            print('Google API quota exceeded')
            time.sleep(5)
            continue
            
'''

# %%
genes

# %%
get_gene_info('100750772')

# %%
from Bio import Entrez
Entrez.email = 'account1@theta-ocean-377718.iam.gserviceaccount.com'
handle = Entrez.efetch(db='gene', id='3979190', retmode='xml')
record = Entrez.read(handle)[0]

#gene_name = record['Entrezgene_gene']['Gene-ref']['Gene-ref_desc']
#gene_symbol = record['Entrezgene_gene']['Gene-ref']['Gene-ref_locus']

human_handle = Entrez.efetch(db='gene', id='3979190', retmode='xml')
human_record = Entrez.read(human_handle)[0]
if 'Entrezgene_comments' in human_record and 'Gene-commentary_comment' in human_record['Entrezgene_comments'][0]:
    human_gene_description = human_record['Entrezgene_comments'][0]['Gene-commentary_comment'][0]['String']
elif 'Entrezgene_summary' in human_record:
    human_gene_description = human_record['Entrezgene_summary']
else:
    human_gene_description = ''
