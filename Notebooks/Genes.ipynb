# %% [markdown]
# # Genes
# The following notebook retrieves all the genes involved in the reactions from the **"Rxns" Sheet** in Google Sheet file. Then, information regarding the genes is retrieved from different databases and a **"Genes" Sheet** is generated and updated.

# %%
import pandas as pd
import numpy as np
import time
from tqdm.notebook import tqdm

from google_sheet import GoogleSheet
from utils import get_gene_info

# %% [markdown]
# ### 1. Generate "rxns" and "genes" datasets
# The "rxns" dataset contains all the reactions with their GPR associations. The "genes" dataset contains all the information of the genes/GPR involved in our reconstruction.

# %%
KEY_FILE_PATH = 'credentials.json'
SPREADSHEET_ID = '1MlBXeHIKw8k8fZyXm-sN__AHTRSunJxar_-bqvukZws'

# Initialize the GoogleSheet object
sheet = GoogleSheet(SPREADSHEET_ID, KEY_FILE_PATH)

# Read data from the Google Sheet
sheet_rxns = 'Rxns'
sheet_genes = 'Genes'

rxns = sheet.read_google_sheet(sheet_rxns)
genes = sheet.read_google_sheet(sheet_genes)

# %%
rxns
# Out:
#       Package Curated      Reaction  \
# 0           7      PD  10FTHF5GLUtl
# 1           7      PD  10FTHF5GLUtm
# 2           7      PD  10FTHF6GLUtl
# 3           7      PD  10FTHF6GLUtm
# 4           7      PD  10FTHF7GLUtl
# ...       ...     ...           ...
# 10513      22                 r2534
# 10514      22                 r2535
# 10515      22                 r2537
# 10516      22                 r2538
# 10517      22                 r2539
#
#                                     Reaction Name  \
# 0          5-glutamyl-10FTHF transport, lysosomal
# 1      5-glutamyl-10FTHF transport, mitochondrial
# 2          6-glutamyl-10FTHF transport, lysosomal
# 3      6-glutamyl-10FTHF transport, mitochondrial
# 4          7-glutamyl-10FTHF transport, lysosomal
# ...                                           ...
# 10513      Major Facilitator(MFS) TCDB:2.A.1.44.1
# 10514      Major Facilitator(MFS) TCDB:2.A.1.44.1
# 10515                          Utilized transport
# 10516                          Utilized transport
# 10517               Postulated transport reaction
#
#                                         Reaction Formula  \
# 0                          10fthf5glu_c --> 10fthf5glu_l
# 1                          10fthf5glu_m --> 10fthf5glu_c
# 2                          10fthf6glu_c --> 10fthf6glu_l
# 3                          10fthf6glu_m --> 10fthf6glu_c
# 4                          10fthf7glu_c --> 10fthf7glu_l
# ...                                                  ...
# 10513                               thr_L_e  <=> thr_L_c
# 10514                                hom_L_e <=> hom_L_c
# 10515                        lnlncgcoa_c <=> lnlncgcoa_r
# 10516                        dlnlcgcoa_c <=> dlnlcgcoa_r
# 10517  L2aadp6sa_c + L2aadp_m <=> L2aadp6sa_m + L2aadp_c
#
#                       Subsystem GPR_hef GPR_fou    GPR_yeo GPR_Recon3D  \
# 0          TRANSPORT, LYSOSOMAL
# 1      TRANSPORT, MITOCHONDRIAL
# 2          TRANSPORT, LYSOSOMAL
# 3      TRANSPORT, MITOCHONDRIAL
# 4          TRANSPORT, LYSOSOMAL
# ...                         ...     ...     ...        ...         ...
# 10513  TRANSPORT, EXTRACELLULAR                  100757617   100757617
# 10514                 TRANSPORT                  100757617   100757617
# 10515                 TRANSPORT    None    None       None        None
# 10516                 TRANSPORT    None    None       None        None
# 10517                 TRANSPORT    None    None       None        None
#
#        GPR_final Conf. Score  \
# 0                          1
# 1                          1
# 2                          1
# 3                          1
# 4                          1
# ...          ...         ...
# 10513  100757617        None
# 10514  100757617        None
# 10515       None        None
# 10516       None        None
# 10517       None        None
#
#                                           Curation Notes References
# 0      No information available in the literature abo...       None
# 1      No information available in the literature abo...       None
# 2      No information available in the literature abo...       None
# 3      No information available in the literature abo...       None
# 4      No information available in the literature abo...       None
# ...                                                  ...        ...
# 10513                                               None       None
# 10514                                               None       None
# 10515                                               None       None
# 10516                                               None       None
# 10517                                               None       None
#
# [10518 rows x 14 columns]

# %% [markdown]
# ### 2. Create the a "gene_list" with all the genes involved in our reconstruction
# We extract the gene IDs from the GPR annotations in the **"rxns" df**. This information is only retrieved from the **GPR_final** column.

# %%
# Generation of gene_list from all the genes in the "Whole Cell Network Reconstruction in CHO Cells" dataset
import re

gene_list = []
for index, row in rxns.iterrows():
    if row['GPR_final'] != '':
        gpr = str(row['GPR_final'])
        num = re.findall(r'\d+', gpr)
        for n in num:
            gene_list.append(n)
        
gene_list = list(set(gene_list))

# %%
gene_list
# Out:
# ['100759929',
#  '100770679',
#  '100760583',
#  '100755602',
#  '100752040',
#  '100764837',
#  '100757439',
#  '100754600',
#  '1645',
#  '100769124',
#  '100766362',
#  '100762222',
#  '100772743',
#  '100753866',
#  '100772319',
#  '100751672',
#  '100767405',
#  '100752689',
#  '100762788',
#  '100753123',
#  '100773215',
#  '100689187',
#  '100754017',
#  '100755384',
#  '100763756',
#  '100773901',
#  '100766256',
#  '100765865',
#  '100760126',
#  '100753294',
#  '100765441',
#  '100774781',
#  '100756257',
#  '100760162',
#  '100772193',
#  '100757273',
#  '100771326',
#  '100759885',
#  '100769516',
#  '100758520',
#  '100774594',
#  '253175',
#  '100752731',
#  '100774957',
#  '100759109',
#  '100767837',
#  '100755154',
#  '100758055',
#  '100767722',
#  '100762475',
#  '92483',
#  '5481',
#  '100752019',
#  '100775017',
#  '100766578',
#  '100771604',
#  '100775000',
#  '100754832',
#  '100761589',
#  '100767978',
#  '100763034',
#  '100762628',
#  '100758629',
#  '100766693',
#  '9588',
#  '100760728',
#  '100765858',
#  '100768097',
#  '100761613',
#  '100765887',
#  '100766128',
#  '100762505',
#  '100756772',
#  '100757328',
#  '100758981',
#  '100751172',
#  '100774025',
#  '100764086',
#  '100759538',
#  '100774121',
#  '100770329',
#  '100762387',
#  '100751402',
#  '100757648',
#  '100772458',
#  '1584',
#  '100773264',
#  '100766715',
#  '100765868',
#  '100762786',
#  '10870',
#  '100760812',
#  '100756898',
#  '100762288',
#  '107978852',
#  '100774650',
#  '100771038',
#  '100758424',
#  '100771767',
#  '100774471',
#  '100759002',
#  '100768951',
#  '100773997',
#  '100751275',
#  '100769417',
#  '100774203',
#  '103163474',
#  '100689463',
#  '100750508',
#  '100774930',
#  '100764834',
#  '100763432',
#  '100758127',
#  '100764351',
#  '100755423',
#  '103160361',
#  '100767410',
#  '100759594',
#  '100751157',
#  '100772477',
#  '100689396',
#  '100766757',
#  '100765055',
#  '100756757',
#  '100767969',
#  '100753802',
#  '100752188',
#  '100774478',
#  '100771420',
#  '728386',
#  '100762593',
#  '100769028',
#  '100758396',
#  '100765292',
#  '100757939',
#  '100768641',
#  '100689282',
#  '100752902',
#  '100772733',
#  '100750655',
#  '2524',
#  '100759194',
#  '100760956',
#  '100751278',
#  '100772576',
#  '54490',
#  '100763456',
#  '100755501',
#  '100766079',
#  '730262',
#  '100772932',
#  '100773722',
#  '100754688',
#  '100767827',
#  '100774705',
#  '100772629',
#  '100768660',
#  '100770630',
#  '100751499',
#  '100750730',
#  '100771315',
#  '100751291',
#  '100764604',
#  '100758810',
#  '100765660',
#  '100763658',
#  '100768417',
#  '100772645',
#  '100751465',
#  '100750718',
#  '100767245',
#  '100755800',
#  '100757141',
#  '100763802',
#  '100774379',
#  '100765460',
#  '100754813',
#  '100765544',
#  '100768412',
#  '100751356',
#  '100764152',
#  '3979181',
#  '100768351',
#  '23326',
#  '100753545',
#  '100765965',
#  '100753531',
#  '100766242',
#  '100769919',
#  '653598',
#  '100750559',
#  '100755812',
#  '100759418',
#  '100774226',
#  '100753124',
#  '100766442',
#  '103158870',
#  '100756523',
#  '100752487',
#  '100754677',
#  '100761879',
#  '100774067',
#  '100759374',
#  '100766778',
#  '100751085',
#  '1109',
#  '100769131',
#  '4836',
#  '100763140',
#  '100750893',
#  '100770431',
#  ...]

# %% [markdown]
# ### 3. Add the genes from the "gene_list" to the genes df
# Using a list of all the genes included in the dataset we can retrieve information from the NIH database regarding Gene Symbol, Gene Name, Gene Ensembl ID, and mRNA ID and protein ID using the function get_gene_info().

# %%
import time
from urllib.error import HTTPError
from Bio.Entrez.Parser import ValidationError

max_retries = 5  # Set the maximum number of retries

for g in tqdm(gene_list):
    if g not in list(genes['Gene Entrez ID']):
        retry = True
        retries = 0
        while retry:
            try:
                print(g)
                organism, gene_symbol, gene_name, gene_description, picr_ensembl_id, chok1gs_ensembl_id, mRNA_ncbi_id, protein_ncbi_id, go_terms = get_gene_info(g)
                if organism == 'Cricetulus griseus':
                    new_row_data = {'Gene Entrez ID': g, 'Gene Symbol': gene_symbol, 'Gene Name': gene_name, 'Gene Description': gene_description,
                                    'PICR Ensembl ID': picr_ensembl_id, 'CHOK1GS Ensembl ID': chok1gs_ensembl_id, 'Transcript ID': mRNA_ncbi_id,
                                    'Protein ID': protein_ncbi_id, 'GO Terms': go_terms}
                    new_row_df = pd.DataFrame(new_row_data, index=[len(genes)])
                    genes = pd.concat([genes, new_row_df])
                    retry = False
                elif organism == 'Homo sapiens':
                    print(f'Gene {g,gene_symbol} is a Human Gene)
                    continue
            except ValidationError:
                print(f'Gene {g} not found')
                retry = False
                continue
            except HTTPError:
                retries += 1
                if retries > max_retries:
                    print(f'HTTP Error, reached maximum retries ({max_retries}) for gene {g}')
                    break
                else:
                    print(f'HTTP Error, retrying with gene {g}')
                    time.sleep(1)
# Out:
#   0%|          | 0/3193 [00:00<?, ?it/s]

# %% [markdown]
# ### 4. Eliminate unwanted genes
# We iterate over the entire dataset to spot **Human genes** in order to eliminate them

# %%
# Make a copy of the DataFrame to avoid changing the original while iterating
genes_copy = genes.copy()

for index, row in tqdm(genes.iterrows(), total=genes.shape[0]):
    g = row['Gene Entrez ID']
    retry = True
    retries = 0
    while retry:
        try:
            organism, gene_symbol, gene_name, gene_description, picr_ensembl_id, chok1gs_ensembl_id, mRNA_ncbi_id, protein_ncbi_id, go_terms = get_gene_info(g)
            if organism == 'Homo sapiens':
                genes_copy = genes_copy.drop(index)
                print(f'Gene {g,gene_symbol} erased from dataset')
                retry = False
            else:
                retry = False
        except ValidationError:
            print(f'Gene {g} not found')
            retry = False
            continue
        except HTTPError:
            retries += 1
            if retries > max_retries:
                print(f'HTTP Error, reached maximum retries ({max_retries}) for gene {g}')
                break
            else:
                print(f'HTTP Error, retrying with gene {g}')
                time.sleep(1)

# Replace the original DataFrame with the updated one
genes = genes_copy
# Out:
#   0%|          | 0/3245 [00:00<?, ?it/s]
# HTTP Error, retrying with gene 100774660
# HTTP Error, retrying with gene 100754978
# Gene 100757367 does not have PICR Ensembl ID
# Gene 100761245 does not have PICR Ensembl ID
# Gene 100761523 does not have PICR Ensembl ID
# Gene 100770009 does not have PICR Ensembl ID
# HTTP Error, retrying with gene 100771661
# Gene 100774679 does not have PICR Ensembl ID
# Gene ('7367', 'UGT2B17') erased from dataset
# HTTP Error, retrying with gene 100774732
# Gene 100771298 does not have PICR Ensembl ID
# Gene 100753222 does not have PICR Ensembl ID
# Gene ('387775', 'SLC22A10') erased from dataset
# Gene ('6697', 'SPR') erased from dataset
# Gene ('3939', 'LDHA') erased from dataset
# HTTP Error, retrying with gene 100768923
# HTTP Error, retrying with gene 100769585
# HTTP Error, retrying with gene 100759906
# HTTP Error, retrying with gene 100752211
# Gene ('6783', 'SULT1E1') erased from dataset
# HTTP Error, retrying with gene 100751305
# Gene 100689294 does not have PICR Ensembl ID
# Gene ('641371', 'ACOT1') erased from dataset
# Gene 100753389 does not have PICR Ensembl ID
# HTTP Error, retrying with gene 100767446
# HTTP Error, retrying with gene 100758117
# Gene ('83549', 'UCK1') erased from dataset
# HTTP Error, retrying with gene 100773187
# Gene 100759231 does not have PICR Ensembl ID
# Gene ('1', 'A1BG') erased from dataset
# Gene 100774864 does not have PICR Ensembl ID
# HTTP Error, retrying with gene 100689468
# HTTP Error, retrying with gene 100769771
# Gene ('1555', 'CYP2B6') erased from dataset
# HTTP Error, retrying with gene 100758958
# Gene ('6579', 'SLCO1A2') erased from dataset
# HTTP Error, retrying with gene 100756717
# Gene ('501', 'ALDH7A1') erased from dataset
# Gene 100760423 does not have PICR Ensembl ID
# HTTP Error, retrying with gene 100759832
# HTTP Error, retrying with gene 100758439
# HTTP Error, retrying with gene 100756126
# Gene 100768920 does not have PICR Ensembl ID
# Gene ('1553', 'CYP2A13') erased from dataset
# Gene ('54658', 'UGT1A1') erased from dataset
# Gene 100757843 does not have PICR Ensembl ID
# HTTP Error, retrying with gene 100750926
# HTTP Error, retrying with gene 54578
# Gene ('54578', 'UGT1A6') erased from dataset
# Gene 100764266 does not have PICR Ensembl ID
# Gene ('54657', 'UGT1A4') erased from dataset
# Gene 100773651 does not have PICR Ensembl ID
# Gene 100758020 does not have PICR Ensembl ID
# HTTP Error, retrying with gene 100757923
# HTTP Error, retrying with gene 100760680
# Gene ('5315', 'PKM') erased from dataset
# Gene 100756470 does not have PICR Ensembl ID
# HTTP Error, retrying with gene 100758091
# Gene ('100526794', 'NT5C1B-RDH14') erased from dataset
# Gene ('226', 'ALDOA') erased from dataset
# Gene ('10870', 'HCST') erased from dataset
# HTTP Error, retrying with gene 100753308
# HTTP Error, retrying with gene 100775005
# Gene ('1558', 'CYP2C8') erased from dataset
# HTTP Error, retrying with gene 103158535
# HTTP Error, retrying with gene 100770348
# Gene 100762572 does not have PICR Ensembl ID
# Gene ('54579', 'UGT1A5') erased from dataset
# Gene 100689310 does not have PICR Ensembl ID
# Gene ('6822', 'SULT2A1') erased from dataset
# HTTP Error, retrying with gene 100771290
# Gene ('57834', 'CYP4F11') erased from dataset
# Gene ('50', 'ACO2') erased from dataset
# Gene 100763432 does not have PICR Ensembl ID
# Gene 100755933 does not have PICR Ensembl ID
# HTTP Error, retrying with gene 100751581
# Gene 100772193 does not have PICR Ensembl ID
# HTTP Error, retrying with gene 100768002
# Gene 100751774 does not have PICR Ensembl ID
# Gene 100774830 does not have PICR Ensembl ID
# HTTP Error, retrying with gene 100758864
# Gene 100757075 does not have PICR Ensembl ID
# HTTP Error, retrying with gene 100765000
# Gene ('1559', 'CYP2C9') erased from dataset
# Gene ('10720', 'UGT2B11') erased from dataset
# Gene 100760248 does not have PICR Ensembl ID
# HTTP Error, retrying with gene 100770660
# Gene ('199974', 'CYP4Z1') erased from dataset
# Gene ('7364', 'UGT2B7') erased from dataset
# Gene ('54659', 'UGT1A3') erased from dataset
# Gene ('9588', 'PRDX6') erased from dataset
# HTTP Error, retrying with gene 100758099
# Gene ('54490', 'UGT2B28') erased from dataset
# Gene ('7366', 'UGT2B15') erased from dataset
# HTTP Error, retrying with gene 100759674
# Gene ('412', 'STS') erased from dataset
# Gene ('3419', 'IDH3A') erased from dataset
# Gene ('10965', 'ACOT2') erased from dataset
# Gene 100769399 does not have PICR Ensembl ID
# HTTP Error, retrying with gene 100757336
# Gene ('145553', 'MDP1') erased from dataset
# HTTP Error, retrying with gene 100773611
# Gene 100771783 does not have PICR Ensembl ID
# Gene ('10455', 'ECI2') erased from dataset
# HTTP Error, retrying with gene 100754135
# Gene ('10715', 'CERS1') erased from dataset
# HTTP Error, retrying with gene 51703
# Gene ('51703', 'ACSL5') erased from dataset
# Gene 100772214 does not have PICR Ensembl ID
# Gene ('7388', 'UQCRH') erased from dataset
# Gene ('11254', 'SLC6A14') erased from dataset
# Gene 103163474 does not have PICR Ensembl ID
# Gene 113833604 does not have PICR Ensembl ID
# Gene 100763642 does not have PICR Ensembl ID
# Gene 107980432 does not have PICR Ensembl ID
# HTTP Error, retrying with gene 100757593
# Gene ('81693', 'AMN') erased from dataset
# Gene ('253175', 'CDY1B') erased from dataset
# Gene 103159036 does not have PICR Ensembl ID
# Gene ('7263', 'TST') erased from dataset
# Gene 100760363 does not have PICR Ensembl ID
# Gene 100757466 does not have PICR Ensembl ID
# Gene ('83844', 'USP26') erased from dataset
# HTTP Error, retrying with gene 100770659
# Gene 100754084 does not have PICR Ensembl ID
# Gene ('0001', 'A1BG') erased from dataset
# Gene ('2287', 'FKBP3') erased from dataset
# Gene 100750797 does not have PICR Ensembl ID
# Gene ('11102', 'RPP14') erased from dataset
# Gene ('100288072', 'SDR42E2') erased from dataset
# Gene ('5604', 'MAP2K1') erased from dataset
# HTTP Error, retrying with gene 100751085
# Gene ('1200', 'TPP1') erased from dataset
# Gene ('1329', 'COX5B') erased from dataset
# Gene 100765573 does not have PICR Ensembl ID
# Gene ('2528', 'FUT6') erased from dataset
# Gene 100755252 does not have PICR Ensembl ID
# Gene ('54575', 'UGT1A10') erased from dataset
# HTTP Error, retrying with gene 100757011
# Gene 100757011 does not have PICR Ensembl ID
# HTTP Error, retrying with gene 100750683
# Gene ('27005', 'USP21') erased from dataset
# Gene 103161867 does not have PICR Ensembl ID
# Gene ('438', 'ASMT') erased from dataset
# Gene ('1557', 'CYP2C19') erased from dataset
# Gene ('2879', 'GPX4') erased from dataset
# Gene ('11128', 'POLR3A') erased from dataset
# Gene ('222', 'ALDH3B2') erased from dataset
# Gene ('1646', 'AKR1C2') erased from dataset
# HTTP Error, retrying with gene 100769144
# Gene 100760749 does not have PICR Ensembl ID
# Gene 100750633 does not have PICR Ensembl ID
# Gene 100767253 does not have PICR Ensembl ID
# Gene 100768175 does not have PICR Ensembl ID
# Gene ('100996939', 'PYURF') erased from dataset
# Gene 100759795 does not have PICR Ensembl ID
# Gene ('2182', 'ACSL4') erased from dataset
# Gene 100754681 does not have PICR Ensembl ID
# Gene 100766632 does not have PICR Ensembl ID
# Gene ('2171', 'FABP5') erased from dataset
# Gene ('5265', 'SERPINA1') erased from dataset
# Gene ('53944', 'CSNK1G1') erased from dataset
# HTTP Error, retrying with gene 100758649
# Gene ('266740', 'MAGEA2B') erased from dataset
# Gene 100760390 does not have PICR Ensembl ID
# Gene ('391627', 'USP17L9P') erased from dataset
# Gene ('200810', 'ALG1L1P') erased from dataset
# Gene 103163165 does not have PICR Ensembl ID
# Gene ('1347', 'COX7A2') erased from dataset
# Gene ('9167', 'COX7A2L') erased from dataset
# Gene ('23563', 'CHST5') erased from dataset
# Gene ('5481', 'PPID') erased from dataset
# Gene ('374875', 'HSD11B1L') erased from dataset
# Gene ('340811', 'AKR1C8') erased from dataset
# Gene ('26227', 'PHGDH') erased from dataset
# Gene ('125', 'ADH1B') erased from dataset
# Gene 100764094 does not have PICR Ensembl ID
# Gene ('3284', 'HSD3B2') erased from dataset
# Gene ('2941', 'GSTA4') erased from dataset
# HTTP Error, retrying with gene 100689440
# Gene 100756709 does not have PICR Ensembl ID
# Gene 100772607 does not have PICR Ensembl ID
# Gene ('5300', 'PIN1') erased from dataset
# Gene 107978852 does not have PICR Ensembl ID
# Gene 3979183 does not have PICR Ensembl ID
# Gene 3979183 does not have info on human ortholog description
# HTTP Error, retrying with gene 100689432
# Gene ('10202', 'DHRS2') erased from dataset
# Gene ('5478', 'PPIA') erased from dataset
# Gene 102724197 does not have PICR Ensembl ID
# Gene ('102724197', 'LOC102724197') erased from dataset
# HTTP Error, retrying with gene 100754861
# Gene ('167127', 'UGT3A2') erased from dataset
# Gene ('81888', 'HYI') erased from dataset
# Gene ('2939', 'GSTA2') erased from dataset
# HTTP Error, retrying with gene 100689402
# Gene ('1734', 'DIO2') erased from dataset
# Gene 100766959 does not have PICR Ensembl ID
# Gene ('5794', 'PTPRH') erased from dataset
# Gene ('7363', 'UGT2B4') erased from dataset
# HTTP Error, retrying with gene 100756277
# Gene 100761051 does not have PICR Ensembl ID
# Gene ('55867', 'SLC22A11') erased from dataset
# Gene ('8418', 'CMAHP') erased from dataset
# Gene ('64219', 'PJA1') erased from dataset
# Gene ('55149', 'MTPAP') erased from dataset
# Gene ('1514', 'CTSL') erased from dataset
# Gene 103164072 does not have PICR Ensembl ID
# HTTP Error, retrying with gene 100754380
# Gene 100754380 does not have PICR Ensembl ID
# Gene 100757365 does not have PICR Ensembl ID
# Gene 100773433 does not have PICR Ensembl ID
# HTTP Error, retrying with gene 100773433
# Gene 100773433 does not have PICR Ensembl ID
# Gene 100757499 does not have PICR Ensembl ID
# Gene ('9085', 'CDY1') erased from dataset
# Gene 100766810 does not have PICR Ensembl ID
# HTTP Error, retrying with gene 100754544
# HTTP Error, retrying with gene 100773134
# Gene 100770231 does not have PICR Ensembl ID
# Gene ('2169', 'FABP2') erased from dataset
# Gene 100762146 does not have PICR Ensembl ID
# Gene 3979178 does not have PICR Ensembl ID
# Gene 3979178 does not have info on human ortholog description
# Gene 100771969 does not have PICR Ensembl ID
# Gene ('4836', 'NMT1') erased from dataset
# Gene 103158988 does not have PICR Ensembl ID
# Gene ('5438', 'POLR2I') erased from dataset
# Gene ('7334', 'UBE2N') erased from dataset
# Gene 100766236 does not have PICR Ensembl ID
# Gene 100762236 does not have PICR Ensembl ID
# HTTP Error, retrying with gene 100764720
# Gene ('2243', 'FGA') erased from dataset
# Gene ('389898', 'UBE2NL') erased from dataset
# Gene ('279', 'AMY2A') erased from dataset
# Gene 100757447 does not have PICR Ensembl ID
# Gene ('170685', 'NUDT10') erased from dataset
# Gene 107977085 does not have PICR Ensembl ID
# Gene 100753214 does not have PICR Ensembl ID
# Gene 100754654 does not have PICR Ensembl ID
# HTTP Error, retrying with gene 100767681
# Gene ('9426', 'CDY2A') erased from dataset
# Gene ('84265', 'POLR3GL') erased from dataset
# HTTP Error, retrying with gene 100764110
# Gene ('6259', 'RYK') erased from dataset
# HTTP Error, retrying with gene 100767615
# Gene ('765', 'CA6') erased from dataset
# Gene 100754527 does not have PICR Ensembl ID
# Gene 100763818 does not have PICR Ensembl ID
# HTTP Error, retrying with gene 107977536
# Gene 107977536 does not have PICR Ensembl ID
# Gene 103158725 does not have PICR Ensembl ID
# Gene 100765792 does not have PICR Ensembl ID
# Gene ('64174', 'DPEP2') erased from dataset
# Gene ('56898', 'BDH2') erased from dataset
# Gene 3979184 does not have PICR Ensembl ID
# Gene 3979184 does not have info on human ortholog description
# Gene ('22977', 'AKR7A3') erased from dataset
# Gene ('52', 'ACP1') erased from dataset
# Gene ('278', 'AMY1C') erased from dataset
# Gene 103160644 does not have PICR Ensembl ID
# Gene 100771510 does not have PICR Ensembl ID
# Gene 103161269 does not have PICR Ensembl ID
# Gene ('653598', 'PPIAL4C') erased from dataset
# HTTP Error, retrying with gene 100757463
# Gene 100765091 does not have PICR Ensembl ID
# Gene ('5728', 'PTEN') erased from dataset
# Gene ('1585', 'CYP11B2') erased from dataset
# HTTP Error, retrying with gene 100767831
# Gene 100689217 does not have PICR Ensembl ID
# Gene 100755382 does not have PICR Ensembl ID
# Gene ('1109', 'AKR1C4') erased from dataset
# Gene 100761399 does not have PICR Ensembl ID
# Gene 100761399 does not have mRNA id and protein id
# Gene ('203611', 'CDY2B') erased from dataset
# Gene 100768993 does not have PICR Ensembl ID
# Gene ('28', 'ABO') erased from dataset
# Gene ('7365', 'UGT2B10') erased from dataset
# Gene ('27233', 'SULT1C4') erased from dataset
# Gene ('5068', 'REG3A') erased from dataset
# Gene 3979181 does not have PICR Ensembl ID
# Gene 3979181 does not have info on human ortholog description
# Gene 103159001 does not have PICR Ensembl ID
# Gene ('277', 'AMY1B') erased from dataset
# Gene ('6419', 'SETMAR') erased from dataset
# Gene ('246', 'ALOX15') erased from dataset
# Gene ('57733', 'GBA3') erased from dataset
# HTTP Error, retrying with gene 100760134
# Gene ('644591', 'PPIAL4G') erased from dataset
# HTTP Error, retrying with gene 100760062
# Gene 100765997 does not have PICR Ensembl ID
# Gene ('51227', 'PIGP') erased from dataset
# Gene 100753522 does not have PICR Ensembl ID
# Gene ('7323', 'UBE2D3') erased from dataset
# Gene ('26001', 'RNF167') erased from dataset
# HTTP Error, retrying with gene 100770704
# Gene ('346606', 'MOGAT3') erased from dataset
# Gene ('55613', 'MTMR8') erased from dataset
# Gene ('56903', 'PAPOLB') erased from dataset
# Gene 100759594 does not have PICR Ensembl ID
# Gene 100759594 does not have mRNA id and protein id
# Gene 100767479 does not have PICR Ensembl ID
# Gene ('7320', 'UBE2B') erased from dataset
# Gene ('8555', 'CDC14B') erased from dataset
# Gene ('158506', 'CBLL2') erased from dataset
# Gene ('2944', 'GSTM1') erased from dataset
# Gene 100755890 does not have PICR Ensembl ID
# Gene 103158536 does not have PICR Ensembl ID
# Gene 100767306 does not have PICR Ensembl ID
# Gene ('344967', 'LOC344967') erased from dataset
# Gene 3979186 does not have PICR Ensembl ID
# Gene 3979186 does not have info on human ortholog description
# Gene ('2350', 'FOLR2') erased from dataset
# Gene ('55454', 'CSGALNACT2') erased from dataset
# Gene 3979185 does not have PICR Ensembl ID
# Gene 3979185 does not have info on human ortholog description
# Gene ('89872', 'AQP10') erased from dataset
# HTTP Error, retrying with gene 100766844
# Gene ('119548', 'PNLIPRP3') erased from dataset
# Gene ('84231', 'TRAF7') erased from dataset
# Gene 100756706 does not have PICR Ensembl ID
# Gene ('5436', 'POLR2G') erased from dataset
# HTTP Error, retrying with gene 100760930
# Gene 100759947 does not have PICR Ensembl ID
# Gene 100756318 does not have PICR Ensembl ID
# Gene ('995', 'CDC25C') erased from dataset
# Gene ('10622', 'POLR3G') erased from dataset
# Gene 100774725 does not have PICR Ensembl ID
# HTTP Error, retrying with gene 100751172
# Gene 107979660 does not have PICR Ensembl ID
# Gene ('373156', 'GSTK1') erased from dataset
# HTTP Error, retrying with gene 100689282
# Gene ('1349', 'COX7B') erased from dataset
# Gene 100766218 does not have PICR Ensembl ID
# Gene 103163420 does not have PICR Ensembl ID
# Gene ('127', 'ADH4') erased from dataset
# Gene 100752767 does not have PICR Ensembl ID
# Gene 100771327 does not have PICR Ensembl ID
# Gene 100767657 does not have PICR Ensembl ID
# HTTP Error, retrying with gene 100768766
# Gene ('11283', 'CYP4F8') erased from dataset
# Gene 100766611 does not have PICR Ensembl ID
# Gene 107980305 does not have PICR Ensembl ID
# Gene 100767712 does not have PICR Ensembl ID
# HTTP Error, retrying with gene 100756446
# Gene 100750935 does not have PICR Ensembl ID
# Gene 100762475 does not have PICR Ensembl ID
# Gene ('4056', 'LTC4S') erased from dataset
# HTTP Error, retrying with gene 100750910
# Gene 103159088 does not have PICR Ensembl ID
# Gene ('7381', 'UQCRB') erased from dataset
# Gene ('5319', 'PLA2G1B') erased from dataset
# Gene ('158584', 'FAAH2') erased from dataset
# Gene 113830817 does not have PICR Ensembl ID
# Gene 100750844 does not have PICR Ensembl ID
# Gene 100759710 does not have PICR Ensembl ID
# HTTP Error, retrying with gene 100768097
# Gene 100753681 does not have PICR Ensembl ID
# Gene 3979189 does not have PICR Ensembl ID
# Gene 3979189 does not have info on human ortholog description
# HTTP Error, retrying with gene 100752374
# Gene 113837643 does not have PICR Ensembl ID
# Gene ('54600', 'UGT1A9') erased from dataset
# Gene 100760127 does not have PICR Ensembl ID
# Gene ('730262', 'PPIAL4E') erased from dataset
# Gene ('10134', 'BCAP31') erased from dataset
# Gene ('873', 'CBR1') erased from dataset
# Gene ('285220', 'EPHA6') erased from dataset
# HTTP Error, retrying with gene 100773684
# Gene ('27338', 'UBE2S') erased from dataset
# Gene 100689202 does not have PICR Ensembl ID
# Gene 107977040 does not have PICR Ensembl ID
# Gene ('440138', 'ALG11') erased from dataset
# HTTP Error, retrying with gene 100768417
# HTTP Error, retrying with gene 100758721
# Gene 103158809 does not have PICR Ensembl ID
# Gene ('8287', 'USP9Y') erased from dataset
# Gene ('25828', 'TXN2') erased from dataset
# HTTP Error, retrying with gene 100757648
# Gene 100762656 does not have PICR Ensembl ID
# Gene 100765374 does not have PICR Ensembl ID
# Gene 100758292 does not have PICR Ensembl ID
# Gene ('158160', 'HSD17B7P2') erased from dataset
# Gene ('79872', 'CBLL1') erased from dataset
# Gene 113831071 does not have PICR Ensembl ID
# Gene ('3176', 'HNMT') erased from dataset
# Gene 100762645 does not have PICR Ensembl ID
# Gene ('60496', 'AASDHPPT') erased from dataset
# Gene ('79868', 'ALG13') erased from dataset
# Gene 103161868 does not have PICR Ensembl ID
# Gene ('60559', 'SPCS3') erased from dataset
# Gene 103162274 does not have PICR Ensembl ID
# Gene 100773441 does not have PICR Ensembl ID
# Gene 100689435 does not have PICR Ensembl ID
# Gene 100761532 does not have PICR Ensembl ID
# Gene ('2651', 'GCNT2') erased from dataset
# HTTP Error, retrying with gene 100769146
# Gene ('5793', 'PTPRG') erased from dataset
# Gene ('56852', 'RAD18') erased from dataset
# HTTP Error, retrying with gene 100768515
# Gene 100770821 does not have PICR Ensembl ID
# Gene 100689314 does not have PICR Ensembl ID
# Gene 100772592 does not have PICR Ensembl ID
# Gene 103158861 does not have PICR Ensembl ID
# Gene 100753835 does not have PICR Ensembl ID
# Gene ('2679', 'GGT3P') erased from dataset
# Gene 100759100 does not have PICR Ensembl ID
# Gene 100759109 does not have PICR Ensembl ID
# Gene ('9739', 'SETD1A') erased from dataset
# Gene ('1603', 'DAD1') erased from dataset
# Gene 100766519 does not have PICR Ensembl ID
# HTTP Error, retrying with gene 100766519
# Gene 100766519 does not have PICR Ensembl ID
# HTTP Error, retrying with gene 113830648
# Gene 373856 does not have mRNA id and protein id
# Gene ('373856', 'USP41P') erased from dataset
# Gene ('1845', 'DUSP3') erased from dataset
# Gene ('4166', 'CHST6') erased from dataset
# Gene ('728419', 'USP17L30') erased from dataset
# Gene ('1584', 'CYP11B1') erased from dataset
# HTTP Error, retrying with gene 100751933
# Gene 107977238 does not have PICR Ensembl ID
# Gene ('5277', 'PIGA') erased from dataset
# Gene ('419', 'ART3') erased from dataset
# HTTP Error, retrying with gene 100769865
# Gene 100774535 does not have PICR Ensembl ID
# Gene ('1579', 'CYP4A11') erased from dataset
# Gene 100765877 does not have PICR Ensembl ID
# Gene ('441282', 'AKR1B15') erased from dataset
# Gene ('5163', 'PDK1') erased from dataset
# HTTP Error, retrying with gene 100756666
# Gene 100756666 does not have PICR Ensembl ID
# HTTP Error, retrying with gene 100760822
# Gene ('9943', 'OXSR1') erased from dataset
# Gene ('1806', 'DPYD') erased from dataset
# Gene 107977577 does not have PICR Ensembl ID
# Gene ('29124', 'LGALS13') erased from dataset
# Gene ('149603', 'RNF187') erased from dataset
# HTTP Error, retrying with gene 100752475
# HTTP Error, retrying with gene 100768771
# Gene 100760904 does not have PICR Ensembl ID
# Gene 100753542 does not have PICR Ensembl ID
# Gene ('160287', 'LDHAL6A') erased from dataset
# Gene 100759648 does not have PICR Ensembl ID
# HTTP Error, retrying with gene 100774657
# Gene ('7329', 'UBE2I') erased from dataset
# HTTP Error, retrying with gene 100774283
# Gene ('126', 'ADH1C') erased from dataset
# Gene 103161923 does not have PICR Ensembl ID
# Gene 100766880 does not have PICR Ensembl ID
# Gene 100766108 does not have PICR Ensembl ID
# Gene ('8732', 'RNGTT') erased from dataset
# HTTP Error, retrying with gene 100770521
# Gene ('5441', 'POLR2L') erased from dataset
# Gene 100769100 does not have PICR Ensembl ID
# Gene 103158908 does not have PICR Ensembl ID
# Gene 100771767 does not have PICR Ensembl ID
# HTTP Error, retrying with gene 100771767
# Gene 100771767 does not have PICR Ensembl ID
# Gene 100772585 does not have PICR Ensembl ID
# Gene ('1178', 'CLC') erased from dataset
# Gene 103162776 does not have PICR Ensembl ID
# Gene ('1645', 'AKR1C1') erased from dataset
# Gene 100767211 does not have PICR Ensembl ID
# Gene ('64090', 'GAL3ST2') erased from dataset
# Gene 100760192 does not have PICR Ensembl ID
# Gene ('23411', 'SIRT1') erased from dataset
# HTTP Error, retrying with gene 2525
# Gene ('2525', 'FUT3') erased from dataset
# Gene ('66002', 'CYP4F12') erased from dataset
# Gene ('124', 'ADH1A') erased from dataset
# HTTP Error, retrying with gene 100772118
# Gene ('653505', 'PPIAL4A') erased from dataset
# Gene ('56267', 'KYAT3') erased from dataset
# Gene ('23318', 'TUT4') erased from dataset
# Gene 103159960 does not have PICR Ensembl ID
# Gene 103159960 does not have mRNA id and protein id
# HTTP Error, retrying with gene 100760691
# Gene 100689360 does not have PICR Ensembl ID
# Gene 100771257 does not have PICR Ensembl ID
# Gene 100760215 does not have PICR Ensembl ID
# Gene ('79966', 'SCD5') erased from dataset
# HTTP Error, retrying with gene 100756894
# Gene 100758176 does not have PICR Ensembl ID
# HTTP Error, retrying with gene 1350
# Gene ('1350', 'COX7C') erased from dataset
# Gene ('293', 'SLC25A6') erased from dataset
# HTTP Error, retrying with gene 100760227
# Gene ('23609', 'MKRN2') erased from dataset
# Gene 3979180 does not have PICR Ensembl ID
# Gene 3979180 does not have info on human ortholog description
# Gene ('7803', 'PTP4A1') erased from dataset
# HTTP Error, retrying with gene 100762698
# Gene 100768141 does not have PICR Ensembl ID
# Gene 100756860 does not have PICR Ensembl ID
# HTTP Error, retrying with gene 100764723
# Gene 100771256 does not have PICR Ensembl ID
# Gene 100689311 does not have PICR Ensembl ID
# Gene ('728386', 'USP17L5') erased from dataset
# HTTP Error, retrying with gene 100757007
# Gene 103163635 does not have PICR Ensembl ID
# Gene 100763298 does not have PICR Ensembl ID
# Gene 100756540 does not have PICR Ensembl ID
# HTTP Error, retrying with gene 100761139
# Gene 100761139 does not have PICR Ensembl ID
# Gene 3979182 does not have PICR Ensembl ID
# Gene 3979182 does not have info on human ortholog description
# Gene ('23430', 'TPSD1') erased from dataset
# HTTP Error, retrying with gene 100761968
# Gene ('219333', 'USP12') erased from dataset
# Gene ('5320', 'PLA2G2A') erased from dataset
# Gene 100757800 does not have PICR Ensembl ID
# Gene ('2938', 'GSTA1') erased from dataset
# Gene ('388714', 'FMO6P') erased from dataset
# Gene 100770445 does not have PICR Ensembl ID
# HTTP Error, retrying with gene 100770570
# Gene 100767292 does not have PICR Ensembl ID
# Gene 100755376 does not have PICR Ensembl ID
# Gene 100755963 does not have PICR Ensembl ID
# Gene ('26062', 'HYAL6P') erased from dataset
# Gene 100756936 does not have PICR Ensembl ID
# Gene ('112858', 'TP53RK') erased from dataset
# Gene ('2352', 'FOLR3') erased from dataset
# Gene ('8574', 'AKR7A2') erased from dataset
# Gene ('100529261', 'CHURC1-FNTB') erased from dataset
# HTTP Error, retrying with gene 100774072
# Gene 100767097 does not have PICR Ensembl ID
# Gene ('100287513', 'USP17L22') erased from dataset
# Gene 100762250 does not have PICR Ensembl ID
# Gene ('23326', 'USP22') erased from dataset
# Gene ('10914', 'PAPOLA') erased from dataset
# Gene 100770125 does not have PICR Ensembl ID
# HTTP Error, retrying with gene 100769825
# Gene 100769825 does not have PICR Ensembl ID
# Gene 100771188 does not have PICR Ensembl ID
# HTTP Error, retrying with gene 100772543
# Gene ('2286', 'FKBP2') erased from dataset
# Gene 113830741 does not have PICR Ensembl ID
# Gene ('760', 'CA2') erased from dataset
# Gene ('5501', 'PPP1CC') erased from dataset
# Gene 100761329 does not have PICR Ensembl ID
# Gene ('377630', 'USP17L2') erased from dataset
# Gene ('80235', 'PIGZ') erased from dataset
# Gene 103160864 does not have PICR Ensembl ID
# HTTP Error, retrying with gene 100772741
# Gene 100767926 does not have PICR Ensembl ID
# Gene ('4353', 'MPO') erased from dataset
# Gene ('9789', 'SPCS2') erased from dataset
# Gene 100751185 does not have PICR Ensembl ID
# Gene 100752205 does not have PICR Ensembl ID
# Gene ('2232', 'FDXR') erased from dataset
# Gene 100759490 does not have PICR Ensembl ID
# Gene 100760867 does not have PICR Ensembl ID
# Gene ('728441', 'GGT2P') erased from dataset
# Gene 100773480 does not have PICR Ensembl ID
# Gene ('140739', 'UBE2F') erased from dataset
# Gene 100763456 does not have PICR Ensembl ID
# HTTP Error, retrying with gene 100756034
# Gene ('10295', 'BCKDK') erased from dataset
# Gene ('50484', 'RRM2B') erased from dataset
# Gene 100757101 does not have PICR Ensembl ID
# Gene 100761392 does not have PICR Ensembl ID
# Gene 100763404 does not have PICR Ensembl ID
# Gene ('8972', 'MGAM') erased from dataset
# Gene 100773723 does not have PICR Ensembl ID
# Gene ('10105', 'PPIF') erased from dataset
# Gene 107977589 does not have PICR Ensembl ID
# Gene 100764001 does not have PICR Ensembl ID
# Gene 100765177 does not have PICR Ensembl ID
# Gene ('220074', 'LRTOMT') erased from dataset
# Gene 100766800 does not have PICR Ensembl ID
# Gene 100757865 does not have PICR Ensembl ID
# HTTP Error, retrying with gene 100759274
# Gene ('79603', 'CERS4') erased from dataset
# Gene ('5440', 'POLR2K') erased from dataset
# Gene ('51619', 'UBE2D4') erased from dataset
# Gene ('8644', 'AKR1C3') erased from dataset
# HTTP Error, retrying with gene 100752584
# Gene ('30', 'ACAA1') erased from dataset
# Gene ('85363', 'TRIM5') erased from dataset
# Gene 100756695 does not have PICR Ensembl ID
# Gene 100755464 does not have PICR Ensembl ID
# Gene ('10524', 'KAT5') erased from dataset
# Gene 100763851 does not have PICR Ensembl ID
# Gene 100766487 does not have PICR Ensembl ID
# Gene ('1549', 'CYP2A7') erased from dataset
# Gene ('10714', 'POLD3') erased from dataset
# Gene ('11143', 'KAT7') erased from dataset
# Gene ('4843', 'NOS2') erased from dataset
# Gene 100682535 does not have PICR Ensembl ID
# Gene 100765856 does not have PICR Ensembl ID
# Gene ('2524', 'FUT2') erased from dataset
# HTTP Error, retrying with gene 100757947
# HTTP Error, retrying with gene 100689191
# HTTP Error, retrying with gene 100762955
# Gene 100758803 does not have PICR Ensembl ID
# Gene ('7332', 'UBE2L3') erased from dataset
# Gene ('2940', 'GSTA3') erased from dataset
# Gene ('55089', 'SLC38A4') erased from dataset
# Gene ('143162', 'FRMPD2') erased from dataset
# Gene ('8908', 'GYG2') erased from dataset
# Gene ('133688', 'UGT3A1') erased from dataset
# Gene 100772776 does not have PICR Ensembl ID
# Gene ('9917', 'FAM20B') erased from dataset
# Gene ('1735', 'DIO3') erased from dataset
# Gene ('55284', 'UBE2W') erased from dataset
# HTTP Error, retrying with gene 29082
# Gene ('29082', 'CHMP4A') erased from dataset
# Gene ('5568', 'PRKACG') erased from dataset
# Gene 3979179 does not have PICR Ensembl ID
# Gene 3979179 does not have info on human ortholog description
# Gene ('2280', 'FKBP1A') erased from dataset
# Gene ('8681', 'JMJD7-PLA2G4B') erased from dataset
# Gene 100753123 does not have PICR Ensembl ID
# Gene 103159043 does not have PICR Ensembl ID
# Gene ('92483', 'LDHAL6B') erased from dataset
# Gene ('5162', 'PDHB') erased from dataset
# Gene 100762788 does not have PICR Ensembl ID
# Gene ('137902', 'PXDNL') erased from dataset
# Gene ('280', 'AMY2B') erased from dataset
# HTTP Error, retrying with gene 100763346
# Gene 644378 does not have mRNA id and protein id
# Gene ('644378', 'GCNT2P1') erased from dataset
# Gene 103164165 does not have PICR Ensembl ID
# Gene ('1515', 'CTSV') erased from dataset
# Gene ('170712', 'COX7B2') erased from dataset
# Gene ('85320', 'ABCC11') erased from dataset
# Gene ('54576', 'UGT1A8') erased from dataset
# Gene 100763552 does not have PICR Ensembl ID
# Gene ('1548', 'CYP2A6') erased from dataset
# Gene 103164050 does not have PICR Ensembl ID
# Gene ('57663', 'USP29') erased from dataset
# Gene 100771660 does not have PICR Ensembl ID
# Gene 100759236 does not have PICR Ensembl ID
# HTTP Error, retrying with gene 100753655
# Gene 3979190 does not have PICR Ensembl ID
# Gene 3979190 does not have info on human ortholog description
# Gene ('2952', 'GSTT1') erased from dataset
# Gene ('10465', 'PPIH') erased from dataset
# Gene ('8078', 'USP5') erased from dataset
# HTTP Error, retrying with gene 100772205
# Gene ('131890', 'GRK7') erased from dataset
# Gene ('57804', 'POLD4') erased from dataset
# Gene 100754841 does not have PICR Ensembl ID
# HTTP Error, retrying with gene 100757239
# HTTP Error, retrying with gene 100769170
# Gene ('4677', 'NARS1') erased from dataset
# Gene 100765466 does not have PICR Ensembl ID
# HTTP Error, retrying with gene 100772642
# Gene 100764431 does not have PICR Ensembl ID
# Gene 103158870 does not have PICR Ensembl ID
# Gene ('54577', 'UGT1A7') erased from dataset
# Gene ('9420', 'CYP7B1') erased from dataset
# HTTP Error, retrying with gene 100762233
# Gene ('4953', 'ODC1') erased from dataset
# Gene ('55190', 'NUDT11') erased from dataset
# Gene 100757934 does not have PICR Ensembl ID
# Gene 100752954 does not have PICR Ensembl ID
# Gene ('1573', 'CYP2J2') erased from dataset
# Gene 100772184 does not have PICR Ensembl ID
# HTTP Error, retrying with gene 100765390
# Gene ('10434', 'LYPLA1') erased from dataset
# Gene 103160118 does not have PICR Ensembl ID
# HTTP Error, retrying with gene 100774155
# Gene ('23491', 'CES3') erased from dataset
# Gene 100766302 does not have PICR Ensembl ID
# Gene 100750810 does not have PICR Ensembl ID
# Gene ('276', 'AMY1A') erased from dataset
# Gene ('8228', 'PNPLA4') erased from dataset
# Gene 100766778 does not have PICR Ensembl ID
# HTTP Error, retrying with gene 100767929
# Gene ('4915', 'NTRK2') erased from dataset
# Gene 107978331 does not have PICR Ensembl ID
# Gene 100758638 does not have PICR Ensembl ID
# Gene ('12', 'SERPINA3') erased from dataset
# Gene ('3283', 'HSD3B1') erased from dataset
# Gene ('2527', 'FUT5') erased from dataset
# Gene ('348158', 'ACSM2B') erased from dataset
# Gene 100759306 does not have PICR Ensembl ID

# %%
genes
# Out:
#      Gene Entrez ID   Gene Symbol  \
# 0         100774298       Slco1b3
# 1         100754260        Hsd3b7
# 2         100769024  LOC100769024
# 3         100756356        Atp2a3
# 4         100774660          Pgls
# ...             ...           ...
# 3240      100759306  LOC100759306
# 3241      100755423  LOC100755423
# 3242      100751278       Slc35d1
# 3243      100770830    Csgalnact2
# 3244      100758724         Lalba
#
#                                               Gene Name  \
# 0     solute carrier organic anion transporter famil...
# 1     hydroxy-delta-5-steroid dehydrogenase, 3 beta-...
# 2                                             aromatase
# 3     ATPase sarcoplasmic/endoplasmic reticulum Ca2+...
# 4                             6-phosphogluconolactonase
# ...                                                 ...
# 3240                            UDP-glucose 4-epimerase
# 3241                    UDP-glucuronosyltransferase 1-6
# 3242                 solute carrier family 35 member D1
# 3243  chondroitin sulfate N-acetylgalactosaminyltran...
# 3244                                  lactalbumin alpha
#
#                                        Gene Description     PICR Ensembl ID  \
# 0     This gene encodes a liver-specific member of t...  ENSCGRG00015012813
# 1     This gene encodes an enzyme which is involved ...  ENSCGRG00015024104
# 2     This gene encodes a member of the cytochrome P...  ENSCGRG00015026385
# 3     This gene encodes one of the SERCA Ca(2+)-ATPa...  ENSCGRG00015000763
# 4     Enables 6-phosphogluconolactonase activity. In...  ENSCGRG00015004513
# ...                                                 ...                 ...
# 3240
# 3241
# 3242
# 3243
# 3244  This gene encodes alpha-lactalbumin, a princip...
#
#       CHOK1GS Ensembl ID Transcript ID    Protein ID  \
# 0     ENSCGRG00001021568  XM_035456357  XP_035312248
# 1     ENSCGRG00001010375  XM_003510980  XP_003511028
# 2     ENSCGRG00001015094  XM_003508783  XP_003508831
# 3     ENSCGRG00001017225  XM_035458322  XP_035314213
# 4     ENSCGRG00001024276  XM_027428449  XP_027284250
# ...                  ...           ...           ...
# 3240                      XM_003515945  XP_003515993
# 3241                      XM_016980970  XP_016836459
# 3242                      XM_007644949  XP_007643139
# 3243                      XM_035457056  XP_035312947
# 3244  ENSCGRG00001004333  XM_003515434  XP_003515482
#
#                                                GO Terms  Uniprot ID
# 0     ['GO:0055085', 'GO:0022857', 'GO:0005515', 'GO...
# 1     ['GO:0016020', 'GO:0016491', 'GO:0016616', 'GO...      G3I7C5
# 2     ['GO:0016020', 'GO:0046872', 'GO:0016491', 'GO...  A0A061IC63
# 3     ['GO:0005783', 'GO:0016529', 'GO:0044325', 'GO...
# 4     ['GO:0016787', 'GO:0005975', 'GO:0017057', 'GO...
# ...                                                 ...         ...
# 3240                                               None        None
# 3241                                               None        None
# 3242                                               None        None
# 3243                                               None        None
# 3244  ['GO:0046872', 'GO:0005509', 'GO:0004461', 'GO...        None
#
# [2952 rows x 10 columns]

# %%
sheet.update_google_sheet(sheet_genes, genes)
print("Google Sheet updated.")
# Out:
# Google Sheet updated.

# %%
for g in tqdm(gene_list):
    if g not in list(genes['Gene Entrez ID']):
        try:
            gene_symbol, gene_name, gene_description, picr_ensembl_id, chok1gs_ensembl_id, mRNA_ncbi_id, protein_ncbi_id, go_terms = get_gene_info(g)
            new_row_data = {'Gene Entrez ID': g, 'Gene Symbol': gene_symbol, 'Gene Name': gene_name, 'Gene Description': gene_description,
                            'PICR Ensembl ID': picr_ensembl_id, 'CHOK1GS Ensembl ID': chok1gs_ensembl_id, 'Transcript ID': mRNA_ncbi_id,
                            'Protein ID': protein_ncbi_id, 'GO Terms': go_terms}
            new_row_df = pd.DataFrame(new_row_data, index=[len(genes)])
            genes = pd.concat([genes, new_row_df])
        except KeyError:
            print(f'Gene {g} not found')
            continue

# %%
# Fetch information from the NIH database


# Complete null or blank information in the already generated "Genes Sheet" dataset
for i,row in genes.iterrows():
    if row['Gene Entrez ID'] == '':
        for g in gene_list:
            gene_sheet_list = [str(x) for x in genes['Gene Entrez ID']]
            if g not in gene_sheet_list:
                gene_symbol, gene_name, gene_description, picr_ensembl_id, chok1gs_ensembl_id, mRNA_ncbi_id, protein_ncbi_id, go_terms = get_gene_info(g)
                row['Gene Entrez ID'] = g
                row['Gene Symbol'] = gene_symbol
                row['Gene Name'] = gene_name
                row['Gene Description'] = gene_description
                row['PICR Ensembl ID'] = picr_ensembl_id
                row['CHOK1GS Ensembl ID'] = chok1gs_ensembl_id
                row['Transcript ID'] = mRNA_ncbi_id
                row['Protein ID'] = protein_ncbi_id
                row['GO Terms'] = go_terms
                break          
    elif row['Gene Entrez ID'] != '' and (row['Gene Symbol'] == '' or row['Gene Name'] == '' or row['PICR Ensembl ID'] == '' or row['Transcript ID'] == '' or row['Protein ID'] == ''):
        row['Gene Symbol'] = gene_symbol
        row['Gene Name'] = gene_name
        row['Gene Description'] = gene_description
        row['PICR Ensembl ID'] = picr_ensembl_id
        row['CHOK1GS Ensembl ID'] = chok1gs_ensembl_id
        row['Transcript ID'] = mRNA_ncbi_id
        row['Protein ID'] = protein_ncbi_id
        row['GO Terms'] = go_terms
'''
# Add genes from the gene_list that are not yet in the "Genes Sheet" dataset
for g in gene_list:
    # the first try/except is to avoid overwritting data in case there already some info in the dataset
    try:
        gene_sheet_list = [str(x) for x in df['Gene Entrez ID']]
        id = max(df['Index']) + 2
    except:
        gene_sheet_list = []
        id = 2
    if gene not in gene_sheet_list:
        try:
            gene_symbol, gene_name, gene_description, picr_ensembl_id, chok1gs_ensembl_id, mRNA_ncbi_id, protein_ncbi_id, go_terms = get_gene_info(gene)
            print(id-1)
            genes_sheet.update_cell(id,1,id-1)
            time.sleep(5)
            genes_sheet.update_cell(id,2,gene)
            time.sleep(5)
            genes_sheet.update_cell(id,3,gene_symbol)
            time.sleep(5)
            genes_sheet.update_cell(id,4,gene_name)
            time.sleep(5)
            genes_sheet.update_cell(id,5,gene_description)
            time.sleep(5)
            genes_sheet.update_cell(id,6,picr_ensembl_id)
            time.sleep(5)
            genes_sheet.update_cell(id,7,chok1gs_ensembl_id)
            time.sleep(5)
            genes_sheet.update_cell(id,8,mRNA_ncbi_id)
            time.sleep(5)
            genes_sheet.update_cell(id,9,protein_ncbi_id)
            time.sleep(5)
            genes_sheet.update_cell(id,10,go_terms)
        except:
            print('Google API quota exceeded')
            time.sleep(5)
            continue
            
'''

# %%
genes

# %%
get_gene_info('100750772')

# %%
from Bio import Entrez
Entrez.email = 'account1@theta-ocean-377718.iam.gserviceaccount.com'
handle = Entrez.efetch(db='gene', id='3979190', retmode='xml')
record = Entrez.read(handle)[0]

#gene_name = record['Entrezgene_gene']['Gene-ref']['Gene-ref_desc']
#gene_symbol = record['Entrezgene_gene']['Gene-ref']['Gene-ref_locus']

human_handle = Entrez.efetch(db='gene', id='3979190', retmode='xml')
human_record = Entrez.read(human_handle)[0]
if 'Entrezgene_comments' in human_record and 'Gene-commentary_comment' in human_record['Entrezgene_comments'][0]:
    human_gene_description = human_record['Entrezgene_comments'][0]['Gene-commentary_comment'][0]['String']
elif 'Entrezgene_summary' in human_record:
    human_gene_description = human_record['Entrezgene_summary']
else:
    human_gene_description = ''
