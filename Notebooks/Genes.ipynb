# %% [markdown]
# # Genes
# The following notebook retrieves all the genes involved in the reactions from the **"Rxns" Sheet** in Google Sheet file. Then, information regarding the genes is retrieved from different databases and a **"Genes" Sheet** is generated and updated.

# %%
import pandas as pd
import numpy as np
import time
from tqdm.notebook import tqdm

from google_sheet import GoogleSheet
from utils import get_gene_info

# %% [markdown]
# ### 1. Generate "rxns" and "genes" datasets
# The "rxns" dataset contains all the reactions with their GPR associations. The "genes" dataset contains all the information of the genes/GPR involved in our reconstruction.

# %%
KEY_FILE_PATH = 'credentials.json'
SPREADSHEET_ID = '1MlBXeHIKw8k8fZyXm-sN__AHTRSunJxar_-bqvukZws'

# Initialize the GoogleSheet object
sheet = GoogleSheet(SPREADSHEET_ID, KEY_FILE_PATH)

# Read data from the Google Sheet
sheet_rxns = 'Rxns'
sheet_genes = 'Genes'

rxns = sheet.read_google_sheet(sheet_rxns)
genes = sheet.read_google_sheet(sheet_genes)

# %% [markdown]
# ### 2. Create the a "gene_list" with all the genes involved in our reconstruction
# We extract the gene IDs from the GPR annotations in the **"rxns" df**. This information is only retrieved from the **GPR_final** column.

# %%
# Generation of gene_list from all the genes in the "Whole Cell Network Reconstruction in CHO Cells" dataset
import re

gene_list = []
human_gene_list = []
for index, row in rxns.iterrows():
    if row['GPR_final'] != '':
        gprs = str(row['GPR_final'])
        gpr = re.findall(r'\b[hH]?\d+\b', gprs)
        for g in gpr:
            if g.lower().startswith('h'):  # we convert to lower case to catch both 'h' and 'H'
                human_gene_list.append(int(g[1:]))  # remove 'h' and convert to int before appending
            else:
                gene_list.append(int(g))  # convert to int before appending

gene_list = list(set(gene_list))
len(gene_list)
# Out:
# 3045

# %% [markdown]
# ### 3. Replace remaining Human Gene IDs in our dataset with CHO Gene IDs
# Using the **cho2human_mapping** file, we replace the Human gene IDs with those of CHO, these IDs were not spotted when we first added the Recon3D reactions.

# %%
# Build a dictionary with human gene IDs as keys and CHO gene IDs as values
orthologs = pd.read_csv('../Data/Orthologs/cho2human_mapping.tsv', sep='\t')
human_to_cho_dict = dict(zip(orthologs['HUMAN_ID'], orthologs['CHO_ID']))

def replace_human_ids_with_cho_ids(s):
    replaced_dict = {}
    if isinstance(s, str):
        genes = re.findall(r'\b[hH]?\d+\b', s)
        for gene in genes:
            if gene.lower().startswith('h'):  # if gene ID starts with 'h' or 'H'
                human_id = int(gene[1:])  # remove 'h' and convert to int
                if human_id in human_to_cho_dict:  # if human gene ID is in the dictionary
                    cho_id = human_to_cho_dict[human_id]  # get corresponding CHO gene ID
                    s = s.replace(gene, str(cho_id))  # replace human gene ID with CHO gene ID in the string
                    replaced_dict[gene] = cho_id
    return s, replaced_dict

# Initialize a dictionary to store replacements
replacements = {}

# Apply the function and update the replacements dictionary
for i in range(len(rxns)):
    rxns.at[i, 'GPR_final'], replacements_dict = replace_human_ids_with_cho_ids(rxns.at[i, 'GPR_final'])
    replacements.update(replacements_dict)

# Now, 'replacements' is a dictionary where keys are the original gene IDs and values are the replaced CHO gene IDs
replacements
# Out:
# {}

# %%
######################################
#### ---------------------------- ####
#### ---- Update Rxns Sheet ----- ####
#### ---------------------------- ####
######################################
if replacements:
    sheet.update_google_sheet(sheet_rxns, rxns)
    print("Google Sheet updated.")
elif not replacements:
    print("No changes to the original Rxns Sheet")
# Out:
# No changes to the original Rxns Sheet

# %% [markdown]
# ### 3. Add the genes from the "gene_list" to the genes df
# Using a list of all the genes included in the dataset we can retrieve information from the NIH database regarding Gene Symbol, Gene Name, Gene Ensembl ID, and mRNA ID and protein ID using the function get_gene_info().

# %%
import time
from urllib.error import HTTPError
from Bio.Entrez.Parser import ValidationError

max_retries = 5  # Set the maximum number of retries
c = 0

for g in tqdm(gene_list):
    if str(g) not in list(genes['Gene Entrez ID']):
        retry = True
        retries = 0
        while retry:
            try:
                print(g)
                organism, gene_symbol, gene_name, gene_description, picr_ensembl_id, chok1gs_ensembl_id, mRNA_ncbi_id, protein_ncbi_id, go_terms = get_gene_info(g)
                if organism == 'Cricetulus griseus':
                    new_row_data = {'Gene Entrez ID': g, 'Gene Symbol': gene_symbol, 'Gene Name': gene_name, 'Gene Description': gene_description,
                                    'PICR Ensembl ID': picr_ensembl_id, 'CHOK1GS Ensembl ID': chok1gs_ensembl_id, 'Transcript ID': mRNA_ncbi_id,
                                    'Protein ID': protein_ncbi_id, 'GO Terms': go_terms}
                    new_row_df = pd.DataFrame(new_row_data, index=[len(genes)])
                    genes = pd.concat([genes, new_row_df])
                    c+=1
                    retry = False
                elif organism != 'Cricetulus griseus':
                    print(f'Gene {g,gene_symbol} is a {organism} Gene')
                    break
            except ValidationError:
                print(f'Gene {g} not found')
                retry = False
                continue
            except HTTPError:
                retries += 1
                if retries > max_retries:
                    print(f'HTTP Error, reached maximum retries ({max_retries}) for gene {g}')
                    break
                else:
                    print(f'HTTP Error, retrying with gene {g}')
                    time.sleep(1)
                    
print(f'A total of {c} Genes were added to the dataset')
# Out:
#   0%|          | 0/3045 [00:00<?, ?it/s]
# 30100754813
# Gene 30100754813 does not have PICR Ensembl ID
# Gene (30100754813, 'ycf15') is a Vitis cinerea Gene
# A total of 0 Genes were added to the dataset

# %%
#######################################
#### ----------------------------- ####
#### ---- Update Genes Sheet ----- ####
#### ----------------------------- ####
#######################################
if c > 0:
    sheet.update_google_sheet(sheet_genes, genes)
    print("Google Sheet updated.")
elif c == 0:
    print("No new genes added.")
    print("No changes to the original Genes Sheet.")
# Out:
# No new genes added.
# No changes to the original Genes Sheet.

# %% [markdown]
# ### 4. Eliminate unwanted genes
# We iterate over the entire dataset to spot **Human genes** in order to eliminate them

# %%
# Make a copy of the DataFrame to avoid changing the original while iterating
erased = 0
genes_copy = genes.copy()

for index, row in tqdm(genes.iterrows(), total=genes.shape[0]):
    g = row['Gene Entrez ID']
    retry = True
    retries = 0
    while retry:
        try:
            organism, gene_symbol, gene_name, gene_description, picr_ensembl_id, chok1gs_ensembl_id, mRNA_ncbi_id, protein_ncbi_id, go_terms = get_gene_info(g)
            if organism == 'Homo sapiens':
                genes_copy = genes_copy.drop(index)
                print(f'Gene {g,gene_symbol} erased from dataset')
                erased+=1
                retry = False
            else:
                retry = False
        except ValidationError:
            print(f'Gene {g} not found')
            retry = False
            continue
        except HTTPError:
            retries += 1
            if retries > max_retries:
                print(f'HTTP Error, reached maximum retries ({max_retries}) for gene {g}')
                break
            else:
                print(f'HTTP Error, retrying with gene {g}')
                time.sleep(1)

# Replace the original DataFrame with the updated one
genes = genes_copy
print(f'A total of {erased} Genes were erased from the original dataset')

# %%
#######################################
#### ----------------------------- ####
#### ---- Update Genes Sheet ----- ####
#### ----------------------------- ####
#######################################
if erased > 0:
    sheet.update_google_sheet(sheet_genes, genes)
    print("Google Sheet updated.")
elif erased == 0:
    print("No erased genes.")
    print("No changes to the original Genes Sheet.")

# %%
for g in tqdm(gene_list):
    if g not in list(genes['Gene Entrez ID']):
        try:
            gene_symbol, gene_name, gene_description, picr_ensembl_id, chok1gs_ensembl_id, mRNA_ncbi_id, protein_ncbi_id, go_terms = get_gene_info(g)
            new_row_data = {'Gene Entrez ID': g, 'Gene Symbol': gene_symbol, 'Gene Name': gene_name, 'Gene Description': gene_description,
                            'PICR Ensembl ID': picr_ensembl_id, 'CHOK1GS Ensembl ID': chok1gs_ensembl_id, 'Transcript ID': mRNA_ncbi_id,
                            'Protein ID': protein_ncbi_id, 'GO Terms': go_terms}
            new_row_df = pd.DataFrame(new_row_data, index=[len(genes)])
            genes = pd.concat([genes, new_row_df])
        except KeyError:
            print(f'Gene {g} not found')
            continue

# %%
# Fetch information from the NIH database


# Complete null or blank information in the already generated "Genes Sheet" dataset
for i,row in genes.iterrows():
    if row['Gene Entrez ID'] == '':
        for g in gene_list:
            gene_sheet_list = [str(x) for x in genes['Gene Entrez ID']]
            if g not in gene_sheet_list:
                gene_symbol, gene_name, gene_description, picr_ensembl_id, chok1gs_ensembl_id, mRNA_ncbi_id, protein_ncbi_id, go_terms = get_gene_info(g)
                row['Gene Entrez ID'] = g
                row['Gene Symbol'] = gene_symbol
                row['Gene Name'] = gene_name
                row['Gene Description'] = gene_description
                row['PICR Ensembl ID'] = picr_ensembl_id
                row['CHOK1GS Ensembl ID'] = chok1gs_ensembl_id
                row['Transcript ID'] = mRNA_ncbi_id
                row['Protein ID'] = protein_ncbi_id
                row['GO Terms'] = go_terms
                break          
    elif row['Gene Entrez ID'] != '' and (row['Gene Symbol'] == '' or row['Gene Name'] == '' or row['PICR Ensembl ID'] == '' or row['Transcript ID'] == '' or row['Protein ID'] == ''):
        row['Gene Symbol'] = gene_symbol
        row['Gene Name'] = gene_name
        row['Gene Description'] = gene_description
        row['PICR Ensembl ID'] = picr_ensembl_id
        row['CHOK1GS Ensembl ID'] = chok1gs_ensembl_id
        row['Transcript ID'] = mRNA_ncbi_id
        row['Protein ID'] = protein_ncbi_id
        row['GO Terms'] = go_terms
'''
# Add genes from the gene_list that are not yet in the "Genes Sheet" dataset
for g in gene_list:
    # the first try/except is to avoid overwritting data in case there already some info in the dataset
    try:
        gene_sheet_list = [str(x) for x in df['Gene Entrez ID']]
        id = max(df['Index']) + 2
    except:
        gene_sheet_list = []
        id = 2
    if gene not in gene_sheet_list:
        try:
            gene_symbol, gene_name, gene_description, picr_ensembl_id, chok1gs_ensembl_id, mRNA_ncbi_id, protein_ncbi_id, go_terms = get_gene_info(gene)
            print(id-1)
            genes_sheet.update_cell(id,1,id-1)
            time.sleep(5)
            genes_sheet.update_cell(id,2,gene)
            time.sleep(5)
            genes_sheet.update_cell(id,3,gene_symbol)
            time.sleep(5)
            genes_sheet.update_cell(id,4,gene_name)
            time.sleep(5)
            genes_sheet.update_cell(id,5,gene_description)
            time.sleep(5)
            genes_sheet.update_cell(id,6,picr_ensembl_id)
            time.sleep(5)
            genes_sheet.update_cell(id,7,chok1gs_ensembl_id)
            time.sleep(5)
            genes_sheet.update_cell(id,8,mRNA_ncbi_id)
            time.sleep(5)
            genes_sheet.update_cell(id,9,protein_ncbi_id)
            time.sleep(5)
            genes_sheet.update_cell(id,10,go_terms)
        except:
            print('Google API quota exceeded')
            time.sleep(5)
            continue
            
'''

# %%
genes

# %%
get_gene_info('100750772')

# %%
from Bio import Entrez
Entrez.email = 'account1@theta-ocean-377718.iam.gserviceaccount.com'
handle = Entrez.efetch(db='gene', id='3979190', retmode='xml')
record = Entrez.read(handle)[0]

#gene_name = record['Entrezgene_gene']['Gene-ref']['Gene-ref_desc']
#gene_symbol = record['Entrezgene_gene']['Gene-ref']['Gene-ref_locus']

human_handle = Entrez.efetch(db='gene', id='3979190', retmode='xml')
human_record = Entrez.read(human_handle)[0]
if 'Entrezgene_comments' in human_record and 'Gene-commentary_comment' in human_record['Entrezgene_comments'][0]:
    human_gene_description = human_record['Entrezgene_comments'][0]['Gene-commentary_comment'][0]['String']
elif 'Entrezgene_summary' in human_record:
    human_gene_description = human_record['Entrezgene_summary']
else:
    human_gene_description = ''

# %% [markdown]
# #### Get the CHO genome and map the IDs

# %%
import pandas as pd
from Bio import Entrez
import math
import time
import ssl
from urllib.error import HTTPError
import socket
from Bio.Entrez.Parser import CorruptedXMLError

def get_uniprot_from_dict(dictionary, uniprotIDs, target_key, target_value1,  target_value2):
    for key, value in dictionary.items():
        if key == target_key and (value == target_value1 or value == target_value2):
            uniprotIDs.append(dictionary.get('Dbtag_tag', {}).get('Object-id', {}).get('Object-id_str'))            
        if isinstance(value, dict):
            get_uniprot_from_dict(value, uniprotIDs, target_key, target_value1, target_value2)
        elif isinstance(value, list):
            for item in value:
                if isinstance(item, dict):
                    get_uniprot_from_dict(item, uniprotIDs, target_key, target_value1, target_value2)        
    return uniprotIDs
def get_human_mouse_orthologs(dictionary, orthologs, target_key, target_value1):
    for key, value in dictionary.items():
        if key == target_key and (value == target_value1):
            orthologs.append(dictionary.get('Dbtag_tag', {}).get('Object-id', {}).get('Object-id_id'))        
        if isinstance(value, dict):
            get_human_mouse_orthologs(value, orthologs, target_key, target_value1)
        elif isinstance(value, list):
            for item in value:
                if isinstance(item, dict):
                    get_human_mouse_orthologs(item, orthologs, target_key, target_value1)        
    return orthologs
    

                    
Entrez.email = "athand01@gmail.com"

u_g = pd.read_excel('../CHO_Genome.xlsx')

ncbi_geneName_list = []
ncbi_geneName_alsoknownas_list = []
ncbi_protein_NP_weirdName = []
ncbi_geneID_list = []
ncbi_gene_exon_size = []
# ncbi_genomic_location = []
uniprot_IDs = []
orthologs_genes = []
orthologs_organism = []
aa_sequences = []

counter = 7999
for ncbi_gene in u_g['NCBI GeneID'][counter:]:

    protein_NP_weirdName = []
    if not math.isnan(ncbi_gene):   
        ncbi_gene = int(ncbi_gene)                  
        max_retries = 3
        retries = 0
        gene_found = True
        while retries < max_retries and gene_found:

            try:

                search_results = Entrez.esearch(db="gene", term=ncbi_gene)            
                record = Entrez.read(search_results)

                # Check if any gene records were found
                if int(record["Count"]) > 0:

                    # Get the Gene ID of the first result
                    gene_id = record["IdList"][0]

                    # Fetch the gene information, maximum 3 tries
                    fetch_tries = 0
                    fetch_found = True
                    while fetch_tries < 3 and fetch_found:

                        gene_info = Entrez.efetch(db="gene", id=gene_id, retmode="xml")           
                        fetch_tries += 1
                        try:
                            gene_record = Entrez.read(gene_info)
                            fetch_found = False
                        except CorruptedXMLError as xml_error:
                            time.sleep(3)
                            fetch_tries += 1

                    # Get the gene name and gene NCBI ID
                    if 'Gene-ref_locus' in gene_record[0]['Entrezgene_gene']['Gene-ref']:
                        gene_name = gene_record[0]['Entrezgene_gene']['Gene-ref']['Gene-ref_locus']                        
                    else:
                        gene_name = gene_record[0]['Entrezgene_gene']['Gene-ref']['Gene-ref_locus-tag']

                    if 'Gene-ref_syn' in gene_record[0]['Entrezgene_gene']['Gene-ref']:
                        gene_name_alsoknownas = gene_record[0]['Entrezgene_gene']['Gene-ref']['Gene-ref_syn']
                    else:
                        gene_name_alsoknownas = []
                    gene_ncbiID = gene_record[0]['Entrezgene_track-info']['Gene-track']['Gene-track_geneid']

                    # Get UniprotIDs
                    gene_uniprotIDs = (get_uniprot_from_dict(gene_record[0], [], 'Dbtag_db', 'UniProtKB/TrEMBL', 'UniProtKB/Swiss-Prot'))

                    # Add sub-cellular localization
                    # Add protein-protein interaction
                    
                    # Get the location in the genome
                    # locus = gene_record[0].get('Entrezgene_locus', {})
                    # start = locus[0]['Gene-commentary_seqs'][0]['Seq-loc_int']['Seq-interval']['Seq-interval_from']
                    # end = locus[0]['Gene-commentary_seqs'][0]['Seq-loc_int']['Seq-interval']['Seq-interval_to']
                    # gene_location = start

                    # Get number of Exons
                    if 'Entrezgene_properties' in gene_record[0]:
                        properties = gene_record[0]['Entrezgene_properties']
                        exon = None
                        for prop in properties:
                            if prop['Gene-commentary_label'] == 'Exon count':
                                exon = prop['Gene-commentary_text']
                                break
                        if exon is None:                        
                            KeyError
                        else:
                            exon = []
                    
                    # Get the gene weird NP name
                    if 'Gene-commentary_products' in gene_record[0]['Entrezgene_locus'][0]:
                        try:
                            protein_NP_weirdName = gene_record[0]['Entrezgene_locus'][0]['Gene-commentary_products'][0]['Gene-commentary_products'][0]['Gene-commentary_accession']
                            
                        except:
                            if 'Gene-commentary_accession' in gene_record[0]['Entrezgene_locus'][0]['Gene-commentary_products'][0]:
                                protein_NP_weirdName = gene_record[0]['Entrezgene_locus'][0]['Gene-commentary_products'][0]['Gene-commentary_accession']
                                
                            else:
                                if 'Gene-commentary_label' in gene_record[0]['Entrezgene_locus'][0]['Gene-commentary_products'][0]:
                                    protein_NP_weirdName = gene_record[0]['Entrezgene_locus'][0]['Gene-commentary_products'][0]['Gene-commentary_label']
                                else:
                                    protein_NP_weirdName = '-----'
                    else:
                        protein_NP_weirdName = '-----'

                    # Get Human and Mouse Orthologs
                    orthologs_organism_list = []
                    orthologs = []     
                    if 'Entrezgene_comments' in gene_record[0]:
                        for Entrezgene_comments_LOOP in gene_record[0]['Entrezgene_comments']:
                            if 'Gene-commentary_comment' in Entrezgene_comments_LOOP:
                                for Gene_commentary_comment_LOOP in Entrezgene_comments_LOOP['Gene-commentary_comment']:
                                    if 'Gene-commentary_source' in Gene_commentary_comment_LOOP:
                                        if 'Object-id_id' in Gene_commentary_comment_LOOP['Gene-commentary_source'][0]['Other-source_src']['Dbtag']['Dbtag_tag']['Object-id']:
                                            orthologs.append(Gene_commentary_comment_LOOP['Gene-commentary_source'][0]['Other-source_src']['Dbtag']['Dbtag_tag']['Object-id']['Object-id_id'])
                                        else:
                                            orthologs.append(Gene_commentary_comment_LOOP['Gene-commentary_source'][0]['Other-source_src']['Dbtag']['Dbtag_tag']['Object-id']['Object-id_str'])
                                        orthologs_organism_list.append(Gene_commentary_comment_LOOP['Gene-commentary_source'][0]['Other-source_anchor'])                    
                    

                    # Get the sequence
                    aa_bool = 'NOT Found AA_Seq'
                    if protein_NP_weirdName != '-----':
                        try:
                            handle = Entrez.efetch(db="protein", id=protein_NP_weirdName, rettype="fasta")
                            record = handle.read()
                            amino_acid_sequence = ''.join(record.split('\n')[1:])
                            aa_bool = 'FOUND AA_Seq'
                        except:
                            handle = Entrez.efetch(db="nucleotide", id=protein_NP_weirdName, rettype="fasta")
                            record = handle.read()
                            amino_acid_sequence = ''.join(record.split('\n')[1:])
                            aa_bool = 'FOUND AA_Seq'

                # If there are no matches for the EntrezID at NCBI then return -----
                else:
                    gene_ncbiID = '-----'
                    gene_name = '-----'
                    gene_name_alsoknownas = '-----'
                    protein_NP_weirdName = '-----'
                    exon = '-----'
                    # gene_location = '-----'                    
                    uniprot_IDs = '-----'
                    amino_acid_sequence = '-----'

                gene_found = False
                search_results.close()
    
            # Handle exceptions
            except HTTPError as e:

                retries += 1
                time.sleep(3)
            except ssl.SSLError as e:

                retries += 1
                time.sleep(3)
            except ConnectionResetError as e:

                retries += 1
                time.sleep(3)
            except socket.error as e:

                retries += 1
                time.sleep(3)
    
        # If the maximum fetch attempts reached, return ------
        if retries >= max_retries:
            gene_name = ncbi_gene
            gene_name_alsoknownas = '-----'
            gene_ncbiID = '-----'
            protein_NP_weirdName = '-----'
            exon = '-----'
            # gene_location = '-----'
            gene_uniprotIDs = '-----'
            orthologs = '-----'
            orthologs_organism_list = '-----'
            amino_acid_sequence = '-----'
    
    # If for some reason the ncbi_gene is nto a number, then return the ncbi_gene for all cases
    else:
        gene_name = ncbi_gene
        gene_name_alsoknownas = ncbi_gene
        gene_ncbiID = ncbi_gene
        protein_NP_weirdName = ncbi_gene
        exon = ncbi_gene
        # gene_location = ncbi_gene
        amino_acid_sequence = ncbi_gene

    ncbi_geneName_list.append(gene_name)
    ncbi_geneName_alsoknownas_list.append(gene_name_alsoknownas)
    ncbi_geneID_list.append(gene_ncbiID)
    ncbi_protein_NP_weirdName.append(protein_NP_weirdName)
    ncbi_gene_exon_size.append(exon)
    # ncbi_genomic_location.append(gene_location)
    uniprot_IDs.append(gene_uniprotIDs)
    orthologs_genes.append(orthologs)
    orthologs_organism.append(orthologs_organism_list)
    aa_sequences.append(amino_acid_sequence)

    print(counter, gene_name, gene_name_alsoknownas, gene_ncbiID, exon, aa_bool, protein_NP_weirdName, gene_uniprotIDs, orthologs, orthologs_organism_list)
    counter += 1
    if counter % 1000 == 0:
        data = {
            'NCBI_ID': ncbi_geneID_list,
            'Gene_Name': ncbi_geneName_list,
            'NP_Name': ncbi_protein_NP_weirdName,
            'Uniprot_ID': uniprot_IDs,
            'Ortholog_Genes': orthologs_genes,
            'Ortholog_Organisms': orthologs_organism,
            'Exon Number': ncbi_gene_exon_size,
            'Sequence': aa_sequences
        }
        df = pd.DataFrame(data)
        file_path = 'GeneIDs_' + str(counter) + '.xlsx'
        df.to_excel(file_path, index=False)
# Out:
# 7999 Mfge8 [] 100774737 [] FOUND AA_Seq XP_003512584 ['G3ICD3', 'A0A8C2LVZ9', 'A0A9J7FMX7', 'A0A8C2LVZ9', 'A0A9J7JJT4', 'A0A8C2LVZ9', 'A0A8C2LXD0', 'A0A8C2LVZ9', 'A0A9J7JJT4', 'A0A8C2LVZ9', 'A0A9J7FMX7', 'A0A8C2LVZ9', 'A0A8C2LXD0'] ['4240', '17304'] ['human', 'mouse']
# 8000 Lonrf1 [] 100774743 [] FOUND AA_Seq XP_035299854 ['A0A061IQS7', 'A0A8C2QLM2', 'A0A9J7F4A8'] ['91694', '244421'] ['human', 'mouse']
# 8001 Etv4 [] 100774750 [] FOUND AA_Seq XP_035294418 ['A0A8C2QNM7', 'A0A9J7K7T7'] ['2118', '18612'] ['human', 'mouse']
# 8002 Dusp16 [] 100774758 [] FOUND AA_Seq XP_003501308 ['A0A8C2MNA8', 'A0A8C2MNA8'] ['80824', '70686', '546747'] ['human', 'mouse', 'Dusp16']
# 8003 Rhob [] 100774759 [] FOUND AA_Seq XP_007640885 ['G3HDJ0', 'G3HDJ0'] ['388', '11852'] ['human', 'mouse']
# 8004 Hyi [] 100774763 [] FOUND AA_Seq XP_007641476 ['A0A8C2MNB5', 'A0A9J7F9V6', 'A0A8C2MNB5', 'A0A9J7F9V6'] ['81888'] ['human']
# 8005 Hspb6 [] 100774774 [] FOUND AA_Seq XP_003505619 ['A0A061HUD1'] ['126393', '243912'] ['human', 'mouse']
# 8006 Capg [] 100774775 [] FOUND AA_Seq XP_007644311 ['A0A8C2LHC8', 'A0A8C2LHC8', 'A0A8C2LHC8', 'A0A8C2LHC8', 'A0A8C2LHC8', 'A0A8C2LHC8', 'A0A8C2LBR7', 'A0A8C2LHC8', 'A0A8C2LBR7', 'A0A8C2LHC8', 'A0A8C2LBR7', 'A0A8C2LHC8', 'A0A8C2LBR7', 'A0A8C2LHC8', 'A0A8C2LBR7', 'A0A8C2LHC8', 'A0A8C2LBR7', 'A0A8C2LHC8'] ['822', '12332'] ['human', 'mouse']
# 8007 Hcfc2 [] 100774776 [] FOUND AA_Seq XP_016832804 ['A0A8C2MYG1', 'A0A8C2N2H6', 'A0A8C2MYG1', 'A0A8C2N2H6'] ['29915', '67933'] ['human', 'mouse']
# 8008 Oxsr1 [] 100774777 [] FOUND AA_Seq XP_027294790 ['A0A061IAY3', 'A0A061IAY3', 'A0A8C2QJ34'] ['9943', '108737'] ['human', 'mouse']
# 8009 Naa10 [] 100774782 [] FOUND AA_Seq XP_016833112 ['G3HSW2', 'A0A9J7K299', 'A0A8C2LYW1', 'A0A9J7K0S3', 'A0A9J7GKM3', 'A0A8C2LZU7'] ['8260', '56292', '413015', '413016', '528303'] ['human', 'mouse', 'REN88217', 'REN88218', 'Naa10']
# 8010 Rnf138 [] 100774783 [] FOUND AA_Seq XP_016833153 ['G3HT45', 'A0A061IE37', 'A0A061IGN3', 'G3HT45'] ['51444', '56515', '219286', '147645'] ['human', 'mouse', 'RH137198', 'D22S309']
# 8011 Pcyox1 [] 100774789 [] FOUND AA_Seq XP_003508024 ['G3HXK8', 'A0A9J7GFS0', 'G3HXK8', 'A0A9J7GFS0'] ['51449', '66881'] ['human', 'mouse']
# 8012 Tedc2 [] 100774795 [] FOUND AA_Seq XP_003509589 ['G3I2T0', 'G3I2T0'] ['80178', '72016'] ['human', 'mouse']
# 8013 Arpc1b [] 100774796 [] FOUND AA_Seq XP_003509730 ['A0A8C2MQF0', 'G3I390', 'A0A8C2MQF0', 'G3I390'] ['10095', '11867'] ['human', 'mouse']
# 8014 Esd [] 100774799 [] FOUND AA_Seq XP_007648742 ['A0A8C2MAB2', 'G3I3W4', 'A0A8C2MAB2', 'G3I3W4', 'A0A8C2MAB2', 'G3I3W4', 'A0A8C2MAB2', 'G3I3W4'] ['2098', '13885'] ['human', 'mouse']
# 8015 Necap1 [] 100774802 [] FOUND AA_Seq XP_007649001 ['A0A8C2MB26', 'A0A8C2MB26', 'A0A9J7K142'] ['25977', '67602'] ['human', 'mouse']
# 8016 Cyth2 [] 100774811 [] FOUND AA_Seq XP_007650866 ['A0A8C2MSH0', 'A0A8C2MSH0', 'A0A9J7G3Y3', 'A0A8C2MSH0', 'A0A9J7G8B7'] ['9266', '19158'] ['human', 'mouse']
# 8017 Timm21 [] 100774814 [] FOUND AA_Seq XP_003512428 ['G3IBV8', 'G3IBV8'] ['29090', '67105'] ['human', 'mouse']
# 8018 Nle1 [] 100774821 [] FOUND AA_Seq XP_003495873 ['A0A8C2LPZ9', 'A0A8C2LQL2', 'A0A8C2LQL2', 'A0A9J7GD12', 'A0A8C2LPZ9', 'A0A8C2LQL2', 'A0A8C2LQL2', 'A0A9J7GD12'] ['54475', '217011'] ['human', 'mouse']
# 8019 Epn2 [] 100774824 [] FOUND AA_Seq XP_007647432 ['A0A8C2LI50', 'A0A8C2LI50', 'A0A8C2LI50', 'A0A8C2LI50', 'A0A8C2LI50', 'A0A9J7H4W5', 'A0A8C2LI50', 'A0A9J7GDY0', 'A0A8C2LI50', 'A0A9J7H5N6', 'A0A8C2LI50', 'A0A8C2LL96', 'A0A8C2LI50', 'A0A9J7H5N6'] ['22905', '13855'] ['human', 'mouse']
# 8020 Nhsl1 [] 100774825 [] FOUND AA_Seq XP_003496602 ['A0A8C2MTJ9', 'A0A9J7FHJ4', 'G3GW55', 'G3GW55', 'A0A9J7GPK6', 'G3GW55', 'A0A9J7GQK3', 'G3GW55', 'A0A8C2MTJ9', 'A0A9J7K3M8', 'A0A8C2MTJ9', 'A0A9J7FHJ4'] ['57224', '215819'] ['human', 'mouse']
# 8021 Wdr77 [] 100774828 [] FOUND AA_Seq XP_007652699 ['A0A8C2QCT8', 'A0A8C2QCT8', 'A0A9J7JBS8'] ['79084', '70465'] ['human', 'mouse']
# 8022 Ddx17 [] 100774831 [] FOUND AA_Seq XP_003514725 ['A0A9J7FKC8', 'G3IJD1', 'A0A9J7FKC8', 'G3IJD1'] ['10521', '67040'] ['human', 'mouse']
# 8023 Szrd1 [] 100774832 [] FOUND AA_Seq XP_007652983 ['A0A8C2QN03'] ['26099', '213491'] ['human', 'mouse']
# 8024 Stx8 ['Syntaxin-8'] 100774833 [] FOUND AA_Seq XP_007606352 ['A0A8C2N0G4', 'A0A8C2N0G4', 'A0A9J7GCN9'] ['9482', '55943', '13512'] ['human', 'mouse', 'GDB:313783']
# 8025 Apip [] 100774834 [] FOUND AA_Seq XP_003497492 ['G3GYY9', 'A0A9J7K8T4', 'G3GYY9', 'A0A9J7K8T4'] ['51074', '56369'] ['human', 'mouse']
# 8026 Fahd2a [] 100774837 [] FOUND AA_Seq XR_004769484 ['G3H030', 'G3H030', 'A0A8C2LPC1', 'G3H030', 'A0A9J7H4Y1', 'G3H030', 'A0A9J7H4Y1', 'G3H030', 'A0A9J7K742', 'G3H030'] ['51011'] ['human']
# 8027 Arhgef4 [] 100774841 [] FOUND AA_Seq XP_035302081 ['A0A8C2N344', 'A0A8C2N344', 'A0A9J7KFR8'] ['50649', '226970'] ['human', 'mouse']
# 8028 Ocrl [] 100774848 [] FOUND AA_Seq XP_035306360 ['A0A8C2M3E6', 'A0A8C2M3E6', 'A0A8C2M3E6', 'A0A9J7GLL9', 'A0A8C2M2J4', 'A0A8C2M3E6'] ['4952', '320634'] ['human', 'mouse']
# 8029 Bora [] 100774852 [] FOUND AA_Seq XP_003499464 ['G3H5A8', 'A0A8C2QND1', 'A0A8C2QND1', 'A0A8C2QND1', 'A0A9J7H9X5'] ['79866', '77744'] ['human', 'mouse']
# 8030 Pdha1 ['PDH-A1'] 100774853 [] FOUND AA_Seq NP_001239228 ['G3H5K6'] ['5160', '18597', '144154'] ['human', 'mouse', 'Pdha1']
# 8031 Hoxb5 [] 100774854 [] FOUND AA_Seq XP_003499601 ['G3H5S8', 'G3H5S8'] ['3215', '15413', '536652'] ['human', 'mouse', 'Hoxb5']
# 8032 Mapk1ip1l [] 100774859 [] FOUND AA_Seq XP_003500094 ['A0A8C2MV52', 'A0A9J7EVD1', 'A0A9J7EVD1', 'A0A8C2MV52'] ['93487', '218975'] ['human', 'mouse']
# 8033 Mgst1 [] 100774867 [] FOUND AA_Seq XP_007639830 ['G3H9Z1', 'G3H9Z1', 'G3H9Z1', 'G3H9Z1', 'G3H9Z1', 'G3H9Z1'] ['4257', '56615'] ['human', 'mouse']
# 8034 Raly [] 100774868 [] FOUND AA_Seq XP_007640003 ['G3HAN3', 'G3HAN3', 'A0A061HXV6', 'G3HAN3', 'G3HAN3', 'A0A061HXV6', 'G3HAN3', 'G3HAN3', 'G3HAN3', 'G3HAN3'] ['22913', '19383', '231240', '231240'] ['human', 'mouse', 'MARC_6533-6534:992007280:1', 'MARC_6533-6534:996689752:1']
# 8035 Cks1b [] 100774870 [] FOUND AA_Seq XP_016830671 [] ['1163', '54124'] ['human', 'mouse']
# 8036 Fst [] 100774874 [] FOUND AA_Seq XP_035311614 ['A0A8C2N6H8', 'G3HE00', 'G3HE00', 'G3HE00', 'A0A9J7FF06', 'G3HE00', 'A0A9J7FGV6', 'G3HE00', 'A0A9J7FI65', 'G3HE00'] ['10468', '14313', '480345'] ['human', 'mouse', 'Fst']
# 8037 Fbxo48 [] 100774875 [] FOUND AA_Seq XP_016831043 ['A0A8C2QJZ5', 'A0A9J7J4H6', 'A0A8C2QJZ5', 'A0A9J7J4H6'] ['554251', '319701'] ['human', 'mouse']
# 8038 Trmt2a [] 100774876 [] FOUND AA_Seq XP_003502502 ['A0A8C2MB74', 'A0A8C2MDI2', 'A0A8C2MDI2', 'G3HEQ2', 'A0A8C2MB74', 'A0A8C2MDI2', 'A0A8C2MDI2', 'G3HEQ2'] ['27037', '15547'] ['human', 'mouse']
# 8039 Pdhb [] 100774878 [] FOUND AA_Seq XP_007641531 ['A0A8C2MC65', 'A0A8C2M8Y5', 'A0A8C2MC65'] ['5162', '68263'] ['human', 'mouse']
# 8040 Zfr [] 100774882 [] FOUND AA_Seq XP_007642423 ['A0A9J7JD48', 'A0A9J7J9L5', 'A0A8C2MA98', 'A0A9J7JFD8', 'A0A9J7JF61'] ['51663', '22763'] ['human', 'mouse']
# 8041 Pde4b [] 100774886 [] FOUND AA_Seq XP_007643161 ['A0A8C2LBP0', 'A0A9J7JA78', 'A0A8C2LBP0', 'A0A9J7JA78', 'A0A8C2LBP0', 'A0A9J7GRP6', 'A0A8C2LBP0', 'A0A9J7GRP6', 'A0A8C2LBP0', 'A0A9J7GRP6', 'A0A8C2LBP0', 'A0A9J7GRW9', 'A0A8C2LB22', 'G3HLA4', 'A0A8C2LB22', 'G3HLA4'] ['5142', '18578', '518826'] ['human', 'mouse', 'Pde4b']
# 8042 Rev3l [] 100774890 [] FOUND AA_Seq XR_003490397 ['A0A8C2LJU1', 'A0A8C2LJU1', 'A0A8C2LJU1', 'A0A9J7FHY3', 'A0A8C2LJU1', 'A0A8C2LLY6', 'A0A8C2LJU1', 'A0A9J7GPJ1', 'A0A8C2LJU1', 'A0A9J7GP27', 'A0A8C2LJU1', 'A0A9J7FHY3'] ['5980', '19714', '243137'] ['human', 'mouse', 'csnprev3l-pcr14-3']
# 8043 Tor3a ['Torsin-3A'] 100774895 [] FOUND AA_Seq XP_003507526 ['G3HW13', 'A0A9J7G3X0', 'G3HW13'] ['64222', '30935', '474275'] ['human', 'mouse', 'D1S3697']
# 8044 Rab2b [] 100774897 [] FOUND AA_Seq XP_003507744 ['A0A8C2MPQ6', 'G3HWS3', 'A0A9J7J3J8', 'A0A8C2MPQ6', 'G3HWS3', 'A0A9J7J3J8'] ['84932', '76338'] ['human', 'mouse']
# 8045 Dele1 ['Kiaa0141'] 100774899 [] FOUND AA_Seq XP_007647006 ['A0A8C2LBQ2', 'A0A9J7FB85', 'A0A8C2LBQ2', 'A0A9J7FB85'] ['9812', '66839'] ['human', 'mouse']
# 8046 Hmgn5 [] 100774904 [] FOUND AA_Seq XP_007647977 ['G3I1P6', 'A0A9J7GPD4', 'A0A061HYC2'] ['79366', '50887'] ['human', 'mouse']
# 8047 Ints2 [] 100774909 [] FOUND AA_Seq XP_007649545 ['A0A8C2LJH1', 'A0A9J7JPD9', 'A0A8C2LJH1', 'A0A9J7JYG9', 'A0A8C2LJH1', 'A0A8C2LMW2', 'A0A061I0S4', 'A0A8C2LJH1', 'A0A8C2LJH1', 'A0A9J7JPD9', 'A0A8C2LJH1', 'A0A9J7JYG9', 'A0A8C2LJH1', 'A0A8C2LMW2', 'A0A061I0S4', 'A0A8C2LJH1'] ['57508', '70422'] ['human', 'mouse']
# 8048 Xpnpep1 [] 100774913 [] FOUND AA_Seq XP_035292500 ['A0A8C2N6H3', 'G3IAG0', 'A0A8C2N6H3', 'G3IAG0', 'A0A9J7FLA3', 'A0A8C2MYB7', 'A0A9J7FPD1', 'A0A9J7FP95', 'A0A9J7JH29'] ['7511', '170750'] ['human', 'mouse']
# 8049 Hsdl1 [] 100774919 [] FOUND AA_Seq XP_007606306 ['A0A9J7FR08', 'A0A9J7FVF4', 'A0A9J7FRG6', 'A0A9J7K794', 'A0A9J7FRG6', 'G3GRY1', 'A0A9J7K794', 'G3GRY1', 'A0A9J7FVF4', 'A0A9J7FR08', 'A0A9J7FRG6', 'A0A9J7FRG6'] ['83693', '72552'] ['human', 'mouse']
# 8050 Nsmce4a [] 100774921 [] FOUND AA_Seq XP_007651782 ['A0A8C2N369', 'A0A8C2N369', 'A0A8C2N369', 'A0A8C2N369'] ['54780', '67872'] ['human', 'mouse']
# 8051 Jade3 [] 100774923 [] FOUND AA_Seq XP_027281455 ['A0A8C2QDT7', 'G3IFQ7', 'A0A8C2QDT7', 'A0A8C2QDT7', 'A0A8C2QDT7', 'A0A8C2QDT7', 'A0A8C2QDT7', 'A0A8C2QDT7', 'A0A8C2QDT7', 'A0A8C2QDT7', 'A0A8C2QDT7', 'A0A8C2QDT7', 'A0A8C2QDT7', 'A0A8C2QDT7', 'A0A8C2QDT7', 'A0A8C2QDT7', 'A0A8C2QDT7'] ['9767', '382207'] ['human', 'mouse']
# 8052 Scaf8 [] 100774924 [] FOUND AA_Seq XP_035313238 ['A0A8C2MQ48', 'A0A9J7FGC2', 'A0A8C2MQ48', 'A0A9J7FGC2', 'A0A8C2MQ48', 'A0A8C2MRV7', 'A0A8C2MQ48', 'A0A9J7FHN1', 'A0A8C2MQ48', 'A0A9J7FGC2', 'A0A8C2MQ48', 'A0A8C2MRV7', 'A0A8C2MQ48', 'A0A9J7FHN1'] ['22828', '106583'] ['human', 'mouse']
# 8053 Ssna1 [] 100774925 [] FOUND AA_Seq XP_007652136 ['G3IG38', 'A0A3L7HDC6', 'G3IG38'] ['8636', '68475'] ['human', 'mouse']
# 8054 Sp3 [] 100774926 [] FOUND AA_Seq XP_035313680 ['A0A8C2LKS7', 'A0A9J7G4N4'] ['6670', '20687', '272552', '271610'] ['human', 'mouse', 'PMC305603P1', 'PMC169877P1']
# 8055 Mthfr [] 100774930 [] FOUND AA_Seq XP_003514213 ['G3IHM4', 'G3IHM4', 'G3IHM4', 'G3IHM4', 'A0A8C2M8F1', 'G3IHM4', 'A0A8C2M8F1', 'G3IHM4', 'A0A8C2M8F1', 'G3IHM4', 'A0A8C2M8F1', 'G3IHM4', 'A0A9J7GT75', 'G3IHM4', 'A0A9J7FBF1', 'G3IHM4', 'A0A061ILA4', 'G3IHM4', 'A0A9J7J7W9', 'G3IHM4'] ['4524', '17769'] ['human', 'mouse']
# 8056 Apba1 [] 100774931 [] FOUND AA_Seq XP_016818954 ['A0A061IBL4', 'A0A8C2MF03', 'A0A8C2QJR6', 'A0A8C2MCA3', 'A0A8C2MF03', 'A0A8C2MF03', 'A0A8C2QJR6'] ['320', '319924'] ['human', 'mouse']
# 8057 Rpusd3 [] 100774934 [] FOUND AA_Seq XP_003496968 ['G3GXA1', 'G3GXA1', 'G3GXA1', 'G3GXA1'] ['285367', '101122'] ['human', 'mouse']
# 8058 Brms1l [] 100774936 [] FOUND AA_Seq XP_003509959 ['A0A8C2MXL6', 'A0A8C2MXL6'] ['84312', '52592'] ['human', 'mouse']
# 8059 Tmem69 [] 100774937 [] FOUND AA_Seq XP_007609404 ['A0A8C2LIH3', 'G3GYP3', 'A0A8C2LIH3', 'G3GYP3', 'A0A8C2LIH3', 'G3GYP3', 'A0A8C2LIH3', 'G3GYP3'] ['51249', '230657'] ['human', 'mouse']
# 8060 Fblim1 [] 100774941 [] FOUND AA_Seq XP_003515340 ['A0A9J7GRC5', 'A0A9J7FB49', 'A0A9J7GRC5', 'A0A9J7GRC5', 'A0A9J7GRC5', 'A0A9J7GRC5'] ['54751', '74202'] ['human', 'mouse']
# 8061 Bco2 [] 100774947 [] FOUND AA_Seq XP_027271778 ['A0A061I8B3', 'A0A9J7JKI2', 'A0A061I8B3', 'G3H2I1', 'A0A061I8B3', 'G3H2I1', 'A0A061I8B3', 'G3H2I1', 'A0A061I8B3', 'G3H2I1', 'A0A061I8B3', 'A0A9J7JKI2'] ['83875', '170752', '547964', '474268'] ['human', 'mouse', 'Bco2', 'D1S3690']
# 8062 Mxra7 [] 100774948 [] FOUND AA_Seq XP_016828082 ['A0A8C2MDD2', 'A0A9J7GB96'] ['439921', '67622'] ['human', 'mouse']
# 8063 Slc27a1 [] 100774950 [] FOUND AA_Seq XP_035307185 ['A0A061IJW5', 'A0A8C2QNR4', 'A0A061IJW5', 'A0A8C2QNR4', 'A0A061IJW5', 'A0A8C2QNR4', 'A0A061IJW5', 'A0A8C2QNR4'] ['376497', '26457'] ['human', 'mouse']
# 8064 Gnptab [] 100774953 [] FOUND AA_Seq XP_016829776 ['A0A8C2MUK7', 'A0A8C2MUK7', 'A0A9J7J9D8', 'A0A8C2MUK7', 'A0A9J7F201'] ['79158', '432486', '267281'] ['human', 'mouse', 'MARC_11919-11920:1003409980:1']
# 8065 Pxdn [] 100774957 [] FOUND AA_Seq XP_007640262 ['A0A9J7JXC5', 'G3HBI1', 'G3HBI1', 'A0A9J7JXC5'] ['7837', '69675', '525566'] ['human', 'mouse', 'Pxdn']
# 8066 Ift140 [] 100774958 [] FOUND AA_Seq XP_007640358 ['A0A9J7G9T3', 'G3HBX9', 'G3HBX9', 'G3HBX9', 'A0A9J7G9T3', 'G3HBX9'] ['9742', '106633', '84581'] ['human', 'mouse', 'RH80350']
# 8067 Polb [] 100774965 [] FOUND AA_Seq XP_003503361 ['G3HHH7', 'G3HHH7'] ['5423', '18970'] ['human', 'mouse']
# 8068 Slc22a15 [] 100774968 [] FOUND AA_Seq XP_003503905 ['A0A061IQS3', 'G3HJE9', 'A0A9J7F3M5', 'A0A061IQS3', 'A0A9J7HCM5', 'A0A061IQS3', 'A0A9J7F7L3', 'A0A061IQS3', 'G3HJE9'] ['55356', '242126'] ['human', 'mouse']
# 8069 Pde1c [] 100774969 [] FOUND AA_Seq XR_482565 ['A0A8C2LY76', 'A0A9J7H608', 'G3HJL0', 'G3HJL0', 'A0A8C2LY76', 'A0A9J7KC99', 'A0A8C2LY76', 'A0A9J7KC99', 'A0A8C2LXA8', 'A0A8C2LXN9', 'A0A8C2LXN9', 'A0A9J7H5A7', 'A0A8C2LXB8', 'A0A8C2LXN9', 'A0A8C2LY76', 'A0A9J7H608', 'A0A8C2LY76', 'A0A9J7KC99', 'A0A8C2LY76', 'A0A9J7KC99'] ['5137', '18575', '268247'] ['human', 'mouse', 'MARC_17193-17194:1021321013:1']
# 8070 Melk [] 100774970 [] FOUND AA_Seq XP_035313236 ['A0A8C2LIV5', 'A0A8C2LIV5', 'G3HME1', 'A0A8C2LIV5', 'A0A9J7FFP6', 'A0A8C2LIV5', 'A0A9J7FKM1'] ['9833', '17279'] ['human', 'mouse']
# 8071 Vasn [] 100774977 [] FOUND AA_Seq XP_003506400 ['G3HS71', 'G3HS71'] ['114990', '246154'] ['human', 'mouse']
# 8072 Dgat2 [] 100774981 [] FOUND AA_Seq XP_003507132 ['G3HUS2', 'G3HUS2'] ['84649', '67800', '461914'] ['human', 'mouse', 'Dgat2']
# 8073 Stam2 [] 100774991 [] FOUND AA_Seq XP_027297832 ['A0A9J7G4L0', 'A0A8C2N070', 'A0A9J7JSW5', 'A0A8C2N070', 'G3I4Z0', 'A0A8C2N070', 'A0A8C2N070', 'A0A9J7JU78', 'A0A8C2N070', 'A0A9J7JSW5', 'A0A9J7G4L0', 'A0A8C2N070', 'A0A9J7KAF5'] ['10254', '56324'] ['human', 'mouse']
# 8074 Gpx8 [] 100775000 [] FOUND AA_Seq XP_016835952 ['A0A9J7FGW2', 'A0A9J7JGT2', 'G3IAX4', 'A0A9J7FGW2', 'A0A9J7JGT2', 'G3IAX4'] ['493869', '69590'] ['human', 'mouse']
# 8075 Ccp110 [] 100775002 [] FOUND AA_Seq XP_003512750 ['A0A8C2LRN1', 'A0A8C2LRN1', 'A0A8C2LRN1', 'A0A8C2LRN1', 'A0A9J7JET1', 'A0A8C2LRN1', 'A0A9J7JL48', 'A0A8C2LRN1', 'A0A9J7FQZ5', 'A0A8C2LRN1', 'A0A9J7JLV6'] ['9738', '101565'] ['human', 'mouse']
# 8076 Slc45a4 [] 100775003 [] FOUND AA_Seq XP_016836290 ['G3IDA5', 'G3IDA5', 'A0A9J7GR22', 'G3IDA5', 'A0A9J7K3X1', 'G3IDA5', 'A0A8C2M6U7', 'G3IDA5', 'A0A8C2M6U7', 'G3IDA5', 'A0A9J7JIC4', 'G3IDA5', 'A0A8C2M6U7', 'G3IDA5'] ['57210', '106068'] ['human', 'mouse']
# 8077 Slc16a1 [] 100775004 [] FOUND AA_Seq XP_003513013 ['G3IDS7', 'G3IDS7'] ['6566', '20501', '461930'] ['human', 'mouse', 'Slc16a1']
# 8078 Fgd5 [] 100775006 [] FOUND AA_Seq XP_027252513 ['A0A8C2QHE9', 'A0A9J7GEY6', 'G3GS21'] ['152273', '232237', '47665'] ['human', 'mouse', 'D8S530']
# 8079 Med23 [] 100775007 [] FOUND AA_Seq XP_003513138 ['A0A8C2QER1', 'G3IE78', 'A0A8C2LNZ0', 'G3IE78', 'A0A8C2QER1', 'G3IE78', 'A0A8C2LNZ0', 'G3IE78'] ['9439', '70208'] ['human', 'mouse']
# 8080 Aamp [] 100775009 [] FOUND AA_Seq XP_003513270 ['A0A8C2MR20', 'G3IEK4', 'A0A9J7F7G5', 'G3IEK4', 'A0A8C2MR20', 'G3IEK4'] ['14', '227290'] ['human', 'mouse']
# 8081 Cdca2 [] 100775015 [] FOUND AA_Seq XP_027296027 ['A0A8C2MZC9', 'A0A9J7F2E3', 'A0A8C2MZC9', 'A0A9J7F2H4', 'A0A8C2MZC9', 'A0A9J7J9D0', 'A0A8C2MZC9', 'G3GV08', 'A0A8C2MZC9', 'A0A9J7F2H4', 'A0A8C2MZC9', 'A0A9J7F2E3', 'A0A8C2MZC9', 'A0A9J7J9D0', 'A0A8C2MZC9', 'G3GV08'] ['157313', '108912'] ['human', 'mouse']
# 8082 Sephs1 [] 100775017 [] FOUND AA_Seq XP_035316616 ['A0A061IA86', 'A0A9J7K7D2', 'A0A061IA86', 'G3GVQ8', 'A0A9J7FLZ5', 'A0A061IA86', 'G3GVQ8', 'A0A061IA86', 'A0A9J7K7D2', 'A0A061IA86', 'G3GVQ8', 'A0A9J7FLZ5'] ['22929', '109079', '86308', '467877'] ['human', 'mouse', 'RH36724', 'SEPHS1_9288']
# 8083 Rhou [] 100775019 [] FOUND AA_Seq XP_035293470 ['A0A8C2QF00'] ['58480', '69581'] ['human', 'mouse']
# 8084 Sec63 [] 100775020 [] FOUND AA_Seq XP_016819356 ['A0A8C2MZU6', 'A0A8C2MZU6', 'A0A8C2MZU6', 'A0A9J7FI81', 'A0A8C2MZU6', 'A0A9J7JHC0'] ['11231', '140740'] ['human', 'mouse']
# 8085 Dazap2 [] 100775021 [] FOUND AA_Seq XP_016819096 ['A0A9J7JC53', 'A0A8C2LWV1', 'A0A8C2LXT9', 'A0A9J7JC53', 'A0A8C2LWV1', 'A0A8C2LXT9'] ['9802', '23994'] ['human', 'mouse']
# 8086 Pelp1 [] 100775022 [] FOUND AA_Seq XP_035295284 ['A0A8C2L9X4', 'A0A8C2LCM9'] ['27043', '75273'] ['human', 'mouse']
# 8087 Zhx1 [] 100775034 [] FOUND AA_Seq XP_003515974 ['G3IP36', 'G3IP36', 'G3IP36'] ['11244', '22770'] ['human', 'mouse']
# 8088 Arhgap10 [] 100775038 [] FOUND AA_Seq XP_035310653 ['A0A8C2M5Z8', 'A0A9J7JJF2', 'A0A8C2M5Z8', 'A0A8C2QIJ0', 'A0A8C2M5Z8', 'A0A8C2M883', 'A0A8C2M5Z8', 'A0A9J7JJF2', 'A0A8C2M5Z8', 'A0A8C2QIJ0', 'A0A8C2M5Z8', 'A0A8C2M883', 'A0A061I662', 'A0A9J7JF10'] ['79658', '78514'] ['human', 'mouse']
# 8089 Reep3 [] 100775039 [] FOUND AA_Seq XP_007639690 ['A0A9J7JB43', 'A0A8C2LWD0'] ['221035', '28193'] ['human', 'mouse']
# 8090 Pum2 [] 100775042 [] FOUND AA_Seq XP_016830922 ['A0A9J7GC91', 'A0A9J7GC90', 'A0A9J7GEY8', 'A0A9J7GAH0', 'G3HDJ2', 'A0A9J7GAH3', 'A0A8C2NCM5', 'A0A9J7GC90', 'A0A9J7KBR4', 'A0A9J7KBR4', 'A0A9J7GC90', 'G3HDJ2', 'A0A9J7GAH0', 'A0A8C2NCM5', 'A0A9J7GC91', 'A0A9J7GEY8', 'A0A9J7GAH3', 'A0A9J7GC90', 'A0A9J7GC90'] ['23369', '80913', '479021'] ['human', 'mouse', 'Pum2']
# 8091 Fam13b [] 100775045 [] FOUND AA_Seq XP_007641336 ['A0A9J7FGY7', 'A0A9J7FG63', 'A0A9J7FFX6', 'A0A9J7FE38', 'A0A9J7JGB4'] ['51306', '225358'] ['human', 'mouse']
# 8092 Sdf2l1 [] 100775047 [] FOUND AA_Seq XP_003502867 ['G3HFY6', 'A0A8C2MYW4', 'G3HFY6'] ['23753', '64136', '212992'] ['human', 'mouse', 'RH129696']
# 8093 Dse [] 100775050 [] FOUND AA_Seq XP_016831897 ['G3HJW4', 'A0A9J7FE04', 'G3HJW4', 'G3HJW4', 'A0A9J7FE04'] ['29940', '212898'] ['human', 'mouse']
# 8094 Ascc2 [] 100775056 [] FOUND AA_Seq XR_003490543 ['A0A061INR1', 'G3HP16', 'A0A061IMU8', 'A0A061INR1', 'A0A061INR1', 'G3HP16', 'A0A061IMU8', 'A0A061INR1'] ['84164', '75452', '515462'] ['human', 'mouse', 'ha1770']
# 8095 Elmod3 [] 100775058 [] FOUND AA_Seq XP_003505681 ['A0A8C2LBN1', 'A0A9J7H484', 'A0A9J7GGU7', 'A0A9J7JX62', 'A0A8C2LBN1', 'A0A9J7H484', 'A0A9J7GGU7', 'A0A9J7JX62'] ['84173', '232089'] ['human', 'mouse']
# 8096 Nt5dc3 [] 100775059 [] FOUND AA_Seq XP_035313900 ['G3HQM9', 'A0A8C2QJT2', 'A0A9J7F5H8'] ['51559', '103466'] ['human', 'mouse']
# 8097 Myd88 [] 100775060 [] FOUND AA_Seq XP_003505968 ['G3HQV3', 'G3HQV3'] ['4615', '17874'] ['human', 'mouse']
# 8098 Fndc3a [] 100775061 [] FOUND AA_Seq XP_016832876 ['G3HR82', 'G3HR82', 'G3HR82', 'G3HR82', 'A0A8C2MMY6', 'G3HR82', 'A0A8C2MMY6', 'G3HR82', 'A0A9J7HBJ1', 'G3HR82', 'A0A9J7HBZ9', 'G3HR82', 'A0A9J7J3B0', 'G3HR82'] ['22862', '319448', '32251'] ['human', 'mouse', 'RH47134']
# 8099 Tex10 ['testis'] 100775062 [] FOUND AA_Seq XP_003506187 ['A0A3L7I311', 'A0A9J7FKI4', 'A0A9J7FFK8', 'A0A3L7I311', 'A0A9J7FKI4', 'A0A9J7FFK8'] ['54881', '269536'] ['human', 'mouse']
# 8100 Cwc15 [] 100775065 [] FOUND AA_Seq XP_035314304 ['A0A061I542', 'G3HSN1', 'A0A061I542', 'G3HSN1', 'A0A061I542', 'G3HSN1', 'A0A061I542', 'G3HSN1'] ['51503', '66070', '159257', '22934'] ['human', 'mouse', 'AU044022', 'WI-11443']
# 8101 Rnf125 [] 100775067 [] FOUND AA_Seq XP_035314402 ['A0A9J7K502', 'A0A9J7K502', 'A0A061IHM3', 'A0A061IJR2'] ['54941', '67664'] ['human', 'mouse']
# 8102 Dusp12 [] 100775069 [] FOUND AA_Seq XP_035314593 ['A0A8C2QH88', 'G3HTZ8', 'A0A9J7JRT1', 'A0A9J7JRT1', 'A0A8C2QH88', 'G3HTZ8', 'A0A9J7JIX5', 'A0A9J7GYU8'] ['11266', '80915'] ['human', 'mouse']
# 8103 Larp4 [] 100775073 [] FOUND AA_Seq XP_007646613 ['A0A8C2LUR7', 'A0A8C2QFK1', 'A0A9J7FB31', 'A0A8C2LUR7', 'A0A9J7F7C6', 'A0A8C2LUR7', 'A0A9J7JC52', 'A0A8C2LUR7', 'A0A8C2QFK1'] ['113251', '207214', '234689'] ['human', 'mouse', 'UniSTS:234689']
# 8104 Tia1 [] 100775074 [] FOUND AA_Seq XR_003491341 ['A0A8C2M2B4', 'A0A9J7JYD9', 'A0A8C2M2B4', 'A0A9J7JQN3', 'A0A8C2M2B4', 'A0A9J7JQN3', 'A0A8C2M2B4', 'A0A9J7JQN3', 'A0A8C2M2B4', 'A0A9J7GFR1', 'A0A8C2M2B4', 'G3HXK9', 'A0A9J7H6B8', 'A0A8C2M2B4', 'A0A9J7JYD9', 'A0A8C2M2B4', 'A0A9J7JQN3', 'A0A8C2M2B4', 'A0A9J7JQN3', 'A0A8C2M2B4', 'A0A9J7JQN3', 'A0A8C2M2B4', 'A0A9J7GFR1', 'A0A8C2M2B4', 'G3HXK9', 'A0A9J7H6B8'] ['7072', '21841'] ['human', 'mouse']
# 8105 Dbp [] 100775076 [] FOUND AA_Seq XP_027296734 ['A0A3L7HHG1', 'A0A8C2MVQ5'] ['1628', '13170'] ['human', 'mouse']
# 8106 Arpc1a [] 100775083 [] FOUND AA_Seq XP_003509731 ['A0A8C2M5D7', 'G3I391', 'A0A8C2M5D7', 'G3I391'] ['10552', '56443', '162457'] ['human', 'mouse', 'RH125677']
# 8107 Phrf1 [] 100775084 [] FOUND AA_Seq XP_007648585 ['A0A061I962', 'G3I3F8', 'A0A061IDR6', 'A0A9J7FP29', 'A0A061IFY1', 'A0A9J7JID7', 'A0A061IAC3', 'A0A9J7JKD0', 'A0A061IFY1', 'A0A9J7FPD6', 'A0A061I962', 'A0A9J7JL10', 'A0A061IDR6', 'A0A9J7FRG8', 'A0A061IDR6', 'A0A9J7FRG8', 'A0A061I962', 'A0A9J7JL10', 'A0A061IDR6', 'A0A9J7FP29', 'A0A061IFY1', 'A0A9J7FPD6', 'A0A061IAC3', 'A0A9J7JKD0', 'A0A061IFY1', 'A0A9J7JID7', 'A0A061I962', 'G3I3F8'] ['57661', '101471'] ['human', 'mouse']
# 8108 Klf10 [] 100775085 [] FOUND AA_Seq XP_035316620 ['A0A8C2M710', 'A0A8C2M710', 'A0A9J7GHS5', 'A0A8C2M710', 'A0A9J7GHJ6', 'A0A8C2M710', 'A0A9J7GHJ6', 'A0A8C2M710', 'A0A9J7GHJ6'] ['7071', '21847'] ['human', 'mouse']
# 8109 Tapbp ['Tapasin'] 100775092 [] FOUND AA_Seq XP_003510879 ['A0A9J7J8I7', 'G3I6W3', 'A0A9J7J8I7', 'G3I6W3'] ['6892', '21356'] ['human', 'mouse']
# 8110 Slc18b1 [] 100775093 [] FOUND AA_Seq XP_007649688 ['G3I738', 'A0A061IGI1', 'A0A9J7JAJ9', 'A0A8C2N2I3', 'A0A9J7FGR2', 'A0A061IGI1', 'A0A9J7JAJ9'] ['116843', '76306'] ['human', 'mouse']
# 8111 Eif5a2 [] 100775097 [] FOUND AA_Seq XP_003511586 ['G3I948', 'G3I948', 'G3I948', 'A0A9J7J925', 'A0A9J7KDU8'] ['56648', '208691'] ['human', 'mouse']
# 8112 Dipk1c ['Fam69c'] 100775103 [] FOUND AA_Seq XP_016836114 ['A0A9J7GQC2', 'G3IBV4', 'A0A8C2LTA9', 'A0A8C2LTA9', 'A0A9J7GQC2', 'G3IBV4'] ['125704', '240479', '515602'] ['human', 'mouse', 'ha2851']
# 8113 Cpeb4 [] 103158539 [] FOUND AA_Seq XP_016830339 ['A0A9J7GB72', 'A0A8C2MTM8', 'A0A9J7GB72', 'A0A8C2MTM8'] ['80315', '67579'] ['human', 'mouse']
# 8114 Msantd3 [] 103158546 [] FOUND AA_Seq XP_007642741 ['A0A3L7I3A3', 'A0A3L7I3A3', 'A0A3L7I3A3', 'A0A3L7I3A3', 'A0A3L7I3A3'] ['91283', '66665'] ['human', 'mouse']
# 8115 Ajuba [] 103158564 [] FOUND AA_Seq XP_007644770 ['A0A8C2M3I3', 'A0A8C2M3I3', 'A0A9J7F3L2', 'A0A9J7F3L2', 'A0A9J7EYE4', 'A0A9J7F3Q3'] ['84962', '16475'] ['human', 'mouse']
# 8116 Znf566 [] 103158574 [] FOUND AA_Seq XP_007644236 ['A0A8C2QKS3', 'A0A9J7H437'] ['84924', '72556'] ['human', 'mouse']
# 8117 Znf286a ['Znf287'] 103158583 [] FOUND AA_Seq XP_016834543 ['A0A9J7JXF3', 'A0A9J7JXF3', 'A0A9J7JXF3'] ['57335'] ['human']
# 8118 Rpl29 [] 103158593 [] FOUND AA_Seq XP_007639262 ['A0A8C2QF85', 'A0A8C2QF85'] ['6159', '19944'] ['human', 'mouse']
# 8119 Prdm2 [] 103158597 [] FOUND AA_Seq XP_007651943 ['A0A8C2MRE7', 'A0A9J7FG26', 'A0A8C2MRE7', 'A0A9J7FG26', 'A0A8C2MRE7', 'A0A9J7FG26', 'A0A8C2MRE7', 'A0A9J7K498', 'A0A8C2MRE7', 'A0A9J7GP31', 'A0A8C2MRE7', 'A0A9J7K2T4', 'A0A8C2MRE7', 'A0A9J7FG26', 'A0A8C2MRE7', 'A0A9J7GP31', 'A0A8C2MRE7', 'A0A9J7FG26', 'A0A8C2MRE7', 'G3IFC0'] ['7799', '110593'] ['human', 'mouse']
# 8120 Cd99 [] 103158690 [] FOUND AA_Seq XP_035294237 ['A0A8C2QI94', 'A0A9J7HCZ2'] ['4267'] ['human']
# 8121 CUNH1orf52 [] 103158713 [] FOUND AA_Seq XP_027242015 ['A0A8C2QIQ8', 'A0A8C2QIQ8', 'A0A9J7FAM7'] ['148423', '66421'] ['human', 'mouse']
# 8122 Rpn2 [] 103158732 [] FOUND AA_Seq XP_007605982 ['A0A8C2QE81', 'A0A8C2LQ00', 'A0A8C2QE81', 'A0A8C2QE81', 'A0A8C2QE81', 'A0A9J7G623', 'A0A8C2QE81', 'A0A9J7JRP5', 'A0A8C2QE81', 'A0A9J7G620'] ['6185', '20014'] ['human', 'mouse']
# 8123 Pdpn [] 103158780 [] FOUND AA_Seq XP_027241611 ['A0A9J7FF17', 'A0A8C2MUM2', 'A0A9J7FF17'] ['10630', '14726'] ['human', 'mouse']
# 8124 Washc5 ['Kiaa0196'] 103158844 [] FOUND AA_Seq XP_007606224 ['G3IPM2', 'A0A9J7K1W0', 'A0A9J7K1W0'] ['9897', '223593'] ['human', 'mouse']
# 8125 Fbxo32 [] 103158884 [] FOUND AA_Seq XP_007606277 ['A0A8C2LKY1', 'A0A9J7K1X1', 'A0A8C2LKY1'] ['114907', '67731'] ['human', 'mouse']
# 8126 Sdf4 ['calumenin'] 103159168 [] FOUND AA_Seq XP_007648815 ['A0A061IE40', 'A0A061IF41', 'A0A061IE40', 'A0A061IF41', 'A0A061IF41', 'A0A9J7FD94', 'A0A061IE40', 'A0A061IF41', 'A0A061IE40', 'A0A061IF41', 'A0A061IE40', 'A0A061IF41', 'A0A061IF41', 'A0A9J7FD94', 'A0A061IE40', 'A0A061IF41'] ['51150', '20318'] ['human', 'mouse']
# 8127 Gadd45a [] 103159266 [] FOUND AA_Seq XP_035317525 ['A0A9J7GHK8', 'P24523', 'A0A9J7GHK8', 'P24523'] ['1647', '13197'] ['human', 'mouse']
# 8128 Shkbp1 [] 103159368 [] FOUND AA_Seq XP_035313541 ['A0A8C2MC29', 'A0A8C2MC29', 'A0A9J7GMA0'] ['92799', '192192'] ['human', 'mouse']
# 8129 Ube2v1 [] 103159460 [] FOUND AA_Seq XP_027292417 ['A0A061HZC1', 'A0A061HZC1', 'A0A8C2QF57'] ['7335', '66589'] ['human', 'mouse']
# 8130 Cdca5 ['Sororin'] 103159496 [] FOUND AA_Seq XP_007652865 ['A0A9J7FR96', 'G3IJ22', 'A0A9J7FR96', 'G3IJ22'] ['113130', '67849'] ['human', 'mouse']
# 8131 Fbxo9 [] 103159530 [] FOUND AA_Seq XP_007649247 ['A0A8C2N0T7', 'A0A9J7JMJ2', 'A0A8C2N0T7', 'A0A9J7K826', 'A0A8C2N0T7', 'A0A9J7K826', 'A0A8C2N0T7', 'A0A9J7JMJ2', 'A0A8C2N432', 'A0A8C2QP81'] ['26268', '71538'] ['human', 'mouse']
# 8132 Timm8a [] 103159709 [] FOUND AA_Seq XP_007638561 ['A0A3L7H2I1', 'A0A3L7H2I1'] ['1678', '30058'] ['human', 'mouse']
# 8133 Esx1 [] 103159745 [] FOUND AA_Seq XP_035316524 ['A0A8C2M2B9', 'A0A9J7K0H6'] ['80712', '13984'] ['human', 'mouse']
# 8134 Zcchc10 [] 103159796 [] FOUND AA_Seq XP_007627150 ['A0A8C2LE59', 'A0A9J7KBU4'] ['54819', '67966'] ['human', 'mouse']
# 8135 Pfdn4 [] 103159810 [] FOUND AA_Seq XP_007643285 ['A0A8C2LU07', 'A0A8C2LU07', 'A0A9J7GC23', 'G3HLQ3'] ['5203', '109054'] ['human', 'mouse']
# 8136 Rnf212 [] 103159853 [] FOUND AA_Seq XP_035311696 ['A0A8C2QHX2', 'A0A8C2QHX2', 'A0A8C2QHX2', 'A0A9J7H6D4', 'A0A8C2QHX2', 'A0A9J7K7U7', 'A0A9J7H3A3'] ['285498', '671564'] ['human', 'mouse']
# 8137 E2f5 [] 103160151 [] FOUND AA_Seq XP_035303879 ['A0A9J7K4H2', 'A0A9J7K4H2'] ['1875', '13559'] ['human', 'mouse']
# 8138 Purb [] 103160160 [] FOUND AA_Seq XP_035313217 ['A0A061IHJ8', 'A0A061IHJ8', 'A0A9J7EW70'] ['5814', '19291'] ['human', 'mouse']
# 8139 Tatdn1 [] 103160193 [] FOUND AA_Seq XP_035294430 ['A0A8C2LS11', 'A0A9J7GJI1', 'A0A8C2LS11', 'A0A9J7GJI1', 'A0A8C2LS11', 'A0A9J7KD77', 'A0A9J7H950'] ['83940', '69694'] ['human', 'mouse']
# 8140 Gtf2h4 [] 103160241 [] FOUND AA_Seq XP_007644551 ['G3HQP3', 'G3HQP3'] ['2968', '14885'] ['human', 'mouse']
# 8141 Churc1 [] 103160311 [] FOUND AA_Seq XP_007640578 ['A0A3L7HIU4', 'A0A3L7HIU4'] ['91612', '211151'] ['human', 'mouse']
# 8142 Rabac1 [] 103160328 [] FOUND AA_Seq XP_016834398 ['A0A8C2MWC7', 'A0A8C2MWC7'] ['10567', '14470'] ['human', 'mouse']
# 8143 Fstl3 [] 103160351 [] FOUND AA_Seq XP_035311863 ['A0A8C2LMQ4', 'A0A8C2LMQ4'] ['10272', '83554'] ['human', 'mouse']
# 8144 Atp5mf ['Atp5j2'] 103160361 [] FOUND AA_Seq XP_007648506 ['A0A8C2MD74', 'A0A8C2MD74'] ['9551', '57423'] ['human', 'mouse']
# 8145 Zkscan5 [] 103160362 [] FOUND AA_Seq XP_007648505 ['A0A8C2QN04', 'A0A9J7JLL5', 'A0A061IC59', 'A0A9J7GUF7', 'A0A9J7GV62', 'A0A9J7GUF7', 'A0A9J7GV62', 'A0A061IC59', 'A0A9J7JLL5', 'A0A8C2QN04'] ['23660', '22757'] ['human', 'mouse']
# 8146 Emc6 [] 103160389 [] FOUND AA_Seq XP_016834534 ['A0A8C2LND8', 'A0A8C2LND8'] ['83460', '66048'] ['human', 'mouse']
# 8147 C1H12orf75 [] 103160432 [] FOUND AA_Seq XP_027296679 ['A0A9J7F5B5'] ['387882', '69784'] ['human', 'mouse']
# 8148 Dcp1b [] 103160459 [] FOUND AA_Seq XP_035310387 ['G3H865', 'G3H865', 'A0A9J7GFD1', 'G3H865', 'A0A9J7KCM1', 'G3H865', 'A0A9J7JYT1', 'G3H865', 'A0A9J7GGJ7', 'G3H865', 'A0A8C2MDD7', 'G3H865', 'A0A9J7GFD1', 'G3H865'] ['196513', '319618'] ['human', 'mouse']
# 8149 Ubfd1 [] 103160474 [] FOUND AA_Seq XP_007652831 ['A0A8C2LSE1', 'A0A8C2LSE1', 'A0A9J7K3H7', 'A0A8C2LSE1', 'A0A9J7JEU5', 'A0A8C2LSE1', 'A0A8C2QFI5', 'A0A8C2LSE1', 'A0A9J7JJ80', 'A0A8C2LSE1', 'A0A9J7JEU5', 'A0A8C2LSE1', 'A0A9J7FQS2', 'A0A8C2LSE1', 'A0A9J7JEU5'] ['56061', '28018'] ['human', 'mouse']
# 8150 Cnih1 [] 103160710 [] FOUND AA_Seq XP_007638978 ['A0A8C2M5B7', 'G3H7C2', 'A0A8C2M5B7', 'G3H7C2'] ['10175', '12793'] ['human', 'mouse']
# 8151 Srp9 [] 103160754 [] FOUND AA_Seq XP_007639027 ['A0A8C2LNB1', 'A0A8C2LNB1'] ['6726', '27058'] ['human', 'mouse']
# 8152 LOC103160763 [] 103160763 [] FOUND AA_Seq XP_016832782 [] [] []
# 8153 Fbxo33 [] 103160846 [] FOUND AA_Seq XP_016835500 ['A0A9J7G2S1'] ['254170', '70611'] ['human', 'mouse']
# 8154 Plcxd3 [] 103160860 [] FOUND AA_Seq XR_004773543 [] ['345557', '239318'] ['human', 'mouse']
# 8155 Hmbox1 [] 103160896 [] FOUND AA_Seq XP_016823980 ['A0A8C2QDR6', 'A0A9J7J7U4', 'A0A8C2QDR6', 'A0A9J7EZ16', 'A0A8C2QDR6', 'A0A9J7J7X1', 'A0A8C2QDR6', 'A0A9J7F350', 'A0A8C2QDR6', 'A0A9J7J7U4', 'A0A8C2QDR6', 'A0A9J7EXZ4', 'A0A8C2LK58', 'A0A8C2QDR6', 'A0A8C2LPS7', 'A0A9J7KF82', 'A0A8C2LPS7', 'A0A9J7F3K7', 'A0A8C2LPS7', 'A0A9J7F2H3', 'A0A8C2LPS7', 'A0A9J7F0B8', 'A0A8C2LPS7', 'A0A9J7F2K4', 'A0A8C2LIW4', 'A0A8C2LMS4'] ['79618', '219150'] ['human', 'mouse']
# 8156 Nmnat3 [] 103160971 [] FOUND AA_Seq XP_035310793 ['A0A9J7GYJ9', 'A0A9J7GZ06', 'A0A9J7K897', 'A0A9J7K897', 'A0A9J7K897', 'A0A9J7K897', 'G3GSW5', 'A0A9J7FRY3', 'A0A9J7GZ06', 'A0A9J7GYJ9', 'A0A9J7K897', 'A0A9J7K897', 'A0A9J7K897', 'G3GSW5', 'A0A9J7K897', 'A0A9J7FRY3'] ['349565', '74080'] ['human', 'mouse']
# 8157 Deptor [] 103160978 [] FOUND AA_Seq XP_035294461 ['A0A8C2LMY9', 'A0A9J7GNN9', 'A0A8C2LMY9', 'A0A9J7GNN9', 'A0A8C2LMY9', 'A0A9J7HAB6'] ['64798', '97998'] ['human', 'mouse']
# 8158 Rnf7 [] 103161028 [] FOUND AA_Seq XP_035310837 ['A0A8C2MV87', 'A0A8C2MV87', 'A0A9J7FR80'] ['9616', '19823'] ['human', 'mouse']
# 8159 Mrps28 [] 103161031 [] FOUND AA_Seq XP_027295820 ['A0A9J7GNH7', 'A0A8C2MIG0'] ['28957', '66230'] ['human', 'mouse']
# 8160 Btbd6 [] 103161198 [] FOUND AA_Seq XP_007631219 ['A0A8C2QF76', 'A0A8C2QF76'] ['90135', '399566'] ['human', 'mouse']
# 8161 Grk6 [] 103161260 [] FOUND AA_Seq XP_007621426 ['A0A8C2MH35', 'A0A9J7FQH7', 'A0A8C2MGB3', 'A0A8C2MH35', 'A0A8C2MH35', 'A0A9J7JKW7', 'A0A8C2MH35', 'A0A9J7FQH7', 'A0A8C2MGB3', 'A0A8C2MH35', 'A0A8C2MH35', 'A0A9J7JKW7', 'A0A8C2MH44', 'A0A9J7JLM1', 'A0A9J7FQ52'] ['2870', '26385'] ['human', 'mouse']
# 8162 Ovca2 [] 103161266 [] FOUND AA_Seq XP_007646031 ['A0A8C2MHB7', 'A0A8C2MHB7'] ['124641', '246257'] ['human', 'mouse']
# 8163 Lmnb1 ['Lamin-L(I)'] 103161362 [] FOUND AA_Seq XP_007622052 ['A0A061IDB2', 'A0A8C2QNY5'] ['4001', '16906'] ['human', 'mouse']
# 8164 Tceal9 ['Wbp5'] 103161413 [] FOUND AA_Seq XP_007646647 ['A0A8C2LGT6'] ['51186', '22381'] ['human', 'mouse']
# 8165 Ier2 [] 103161436 [] FOUND AA_Seq XP_035311404 ['A0A9J7JGH1', 'A0A9J7JGH1'] ['9592', '15936'] ['human', 'mouse']
# 8166 Psenen [] 103161443 [] FOUND AA_Seq XP_007644245 ['A0A061HTR1'] ['55851', '66340'] ['human', 'mouse']
# 8167 Gata6 [] 103161469 [] FOUND AA_Seq XP_035312149 ['A0A8C2QJR3', 'A0A8C2QJR3', 'A0A8C2QJR3'] ['2627', '14465'] ['human', 'mouse']
# 8168 Isy1 [] 103161503 [] FOUND AA_Seq XP_007642356 ['G3HID7', 'G3HID7'] ['57461', '57905'] ['human', 'mouse']
# 8169 Slc39a7 [] 103161516 [] FOUND AA_Seq XP_007644577 ['A0A8C2MX42', 'A0A9J7F0K3'] ['7922', '14977'] ['human', 'mouse']
# 8170 Psmd4 [] 103161668 [] FOUND AA_Seq XP_007629648 ['A0A8C2QBV1', 'G3H2Z7', 'A0A8C2L760', 'A0A8C2QBV1', 'A0A8C2QBV1', 'G3H2Z7', 'A0A8C2L760', 'A0A8C2QBV1'] ['5710', '19185'] ['human', 'mouse']
# 8171 Apln [] 103161730 [] FOUND AA_Seq XP_035306345 ['A0A061HZP9', 'A0A061HZP9'] ['8862', '30878'] ['human', 'mouse']
# 8172 Cbx6 [] 103161880 [] FOUND AA_Seq XP_007648245 ['A0A3L7I2J6', 'A0A9J7GUY3', 'A0A3L7I2J6'] ['23466', '494448'] ['human', 'mouse']
# 8173 Vcp [] 103161970 [] FOUND AA_Seq XP_007643660 ['A0A8C2QP82', 'A0A8C2N386', 'A0A8C2QP82'] ['7415', '269523'] ['human', 'mouse']
# 8174 Tm7sf3 [] 103162299 [] FOUND AA_Seq XP_035316051 ['A0A8C2MB45', 'A0A9J7GHL7', 'A0A8C2MB45', 'A0A9J7JXK6', 'A0A8C2MB45', 'A0A9J7GHM5'] ['51768', '67623'] ['human', 'mouse']
# 8175 Rnf8 [] 103162332 [] FOUND AA_Seq XP_035312872 ['A0A9J7JAN3', 'A0A8C2MSS5', 'A0A9J7F4G4', 'A0A9J7F8C8', 'A0A9J7JAN3', 'A0A9J7F4G4', 'A0A8C2MSS5'] ['9025', '58230'] ['human', 'mouse']
# 8176 Alms1 [] 103162359 [] FOUND AA_Seq XR_001727887 ['A0A9J7KCJ5', 'A0A9J7H6C7', 'A0A9J7KCF5', 'A0A9J7H4R7', 'A0A9J7H8Q2', 'A0A9J7K8Z8', 'A0A9J7KAY5', 'A0A9J7H5L2', 'A0A9J7K1A0', 'A0A9J7H490', 'A0A9J7H387', 'A0A9J7H7L5', 'A0A9J7H7R9'] ['7840', '236266'] ['human', 'mouse']
# 8177 Rpl30 [] 103162454 [] FOUND AA_Seq XP_007642773 ['A0A8C2LIK7', 'A0A8C2MLW9', 'A0A8C2LIK7', 'A0A8C2MLW9'] ['6156', '19946'] ['human', 'mouse']
# 8178 C3H16orf87 [] 103162500 [] FOUND AA_Seq XP_007650061 ['A0A8C2MMU5', 'A0A9J7GSL7', 'A0A8C2MMU5', 'A0A9J7FNE7'] ['388272', '66714'] ['human', 'mouse']
# 8179 Atmin [] 103162505 [] FOUND AA_Seq XP_016834362 ['A0A061IAL8', 'A0A061IAL8', 'A0A8C2M0D9'] ['23300', '234776'] ['human', 'mouse']
# 8180 Gpr27 [] 103162514 [] FOUND AA_Seq XP_035299561 ['A0A8C2LBT0'] ['2850', '14761'] ['human', 'mouse']
# 8181 Ctbs [] 103162615 [] FOUND AA_Seq XP_035313260 ['A0A8C2M7X7', 'A0A9J7H9M8', 'A0A8C2M597', 'A0A8C2M7X7', 'A0A8C2M7X7', 'A0A9J7H9M8', 'A0A8C2M7X7', 'A0A9J7F8U3'] ['1486', '74245'] ['human', 'mouse']
# 8182 Mrps35 [] 103162619 [] FOUND AA_Seq XP_027296930 ['A0A8C2MKH3', 'A0A8C2MKH3', 'A0A9J7GJA5', 'A0A8C2MKH3', 'A0A9J7GJ89'] ['60488', '232536'] ['human', 'mouse']
# 8183 Atp5f1e [] 103162776 [] FOUND AA_Seq XP_027240692 ['A0A8C2QLU2', 'A0A8C2QLU2'] ['514', '67126'] ['human', 'mouse']
# 8184 Plpp6 ['Ppapdc2'] 103162885 [] FOUND AA_Seq XP_016832986 ['A0A061IDV7', 'A0A3L7HYQ7', 'A0A061IDV7', 'A0A3L7HYQ7'] ['403313', '74411'] ['human', 'mouse']
# 8185 Ndufaf6 [] 103162917 [] FOUND AA_Seq XP_035312456 ['A0A8C2MM26', 'A0A9J7JEM0', 'A0A8C2MM26', 'A0A9J7FHE9'] ['137682', '76947'] ['human', 'mouse']
# 8186 Asap1 [] 103162974 [] FOUND AA_Seq XP_035294108 ['A0A8C2MJU3', 'A0A8C2MHP6', 'A0A8C2MIL4', 'A0A9J7GNM9', 'A0A9J7H6Y6', 'A0A8C2MHP6', 'A0A8C2MIL4', 'A0A9J7HA55', 'A0A8C2MK31', 'A0A9J7GJK0', 'A0A8C2MHP6', 'A0A8C2MIL4', 'A0A9J7H614', 'A0A8C2MK31', 'A0A9J7JYI3', 'A0A8C2MJU3', 'A0A9J7GJL5'] ['50807', '13196'] ['human', 'mouse']
# 8187 Nae1 [] 103163014 [] FOUND AA_Seq XP_007638599 ['A0A8C2N4M4', 'A0A9J7FJL3', 'A0A8C2NBZ8', 'A0A9J7FML7', 'A0A8C2N4M4', 'A0A9J7FJL3'] ['8883', '234664'] ['human', 'mouse']
# 8188 Nicn1 ['Nicolin-1'] 103163073 [] FOUND AA_Seq XR_004772880 ['G3H8F5', 'G3H8F5'] ['84276', '66257'] ['human', 'mouse']
# 8189 Ptpn2 [] 103163089 [] FOUND AA_Seq XP_007643632 ['A0A8C2MH98', 'A0A9J7JE38', 'A0A8C2MF81', 'A0A9J7FEZ5', 'A0A8C2MH98', 'A0A9J7JE38'] ['5771', '19255'] ['human', 'mouse']
# 8190 Smim30 [] 103163101 [] FOUND AA_Seq XR_483557 [] ['401397', '66520'] ['human', 'mouse']
# 8191 Fastkd5 [] 103163403 [] FOUND AA_Seq XP_007635264 ['G3H439', 'G3H439', 'G3H439', 'G3H439', 'A0A8C2MRX9', 'A0A8C2MRX9', 'A0A9J7GYE4', 'G3H439', 'A0A9J7GYE4', 'G3H439', 'A0A9J7GYE4', 'G3H439', 'A0A9J7GYE4', 'G3H439', 'A0A8C2MRX9', 'A0A9J7GZP6', 'A0A8C2MRX9', 'A0A9J7GZP6'] ['60493', '380601'] ['human', 'mouse']
# 8192 Tmem185a [] 103163527 [] FOUND AA_Seq XP_035293082 ['A0A061I0D9', 'A0A061I0D9', 'A0A061I0D9', 'A0A8C2N4J2', 'A0A061I0D9', 'A0A8C2N5H3'] ['84548', '236848'] ['human', 'mouse']
# 8193 Prmt6 [] 103163554 [] FOUND AA_Seq XP_035293861 ['A0A3L7ICP4', 'A0A3L7ICP4'] ['55170', '99890'] ['human', 'mouse']
# 8194 Asf1a [] 103163586 [] FOUND AA_Seq XP_007649399 ['A0A8C2M4G9', 'A0A8C2M4G9'] ['25842', '66403'] ['human', 'mouse']
# 8195 Znf274 [] 103163648 [] FOUND AA_Seq XP_016834737 ['G3I2R3', 'A0A9J7GKL5'] ['10782', '65020'] ['human', 'mouse']
# 8196 Nr2f6 [] 103163676 [] FOUND AA_Seq XP_035307256 ['A0A3L7IE88'] ['2063', '13864'] ['human', 'mouse']
# 8197 Twist1 [] 103163738 [] FOUND AA_Seq XP_007640791 ['A0A8C2QFH9', 'A0A9J7JQP0'] ['7291', '22160'] ['human', 'mouse']
# 8198 Ier5 [] 103163864 [] FOUND AA_Seq XP_007639050 ['G3H7H8', 'A0A8C2LQ22'] ['51278', '15939'] ['human', 'mouse']
# 8199 Tmsb10 [] 103164080 [] FOUND AA_Seq XP_007644327 ['A0A8C2MFE2'] ['9168', '19240'] ['human', 'mouse']
# 8200 Camta1 [] 103164264 [] FOUND AA_Seq XP_035316903 [] ['23261', '100072'] ['human', 'mouse']
# 8201 Znf16 [] 103164556 [] FOUND AA_Seq XP_007653237 ['G3IKL6', 'G3IKL6', 'G3IKL6'] ['7564'] ['human']
# 8202 Psmd3 [] 103164599 [] FOUND AA_Seq XP_035294139 ['A0A8C2LBW6', 'A0A9J7G9V4'] ['5709', '22123'] ['human', 'mouse']
# 8203 Por [] 107976996 [] FOUND AA_Seq NP_001231204 ['A0A8C2ML29', 'A0A9J7CH27'] ['5447', '18984'] ['human', 'mouse']
# 8204 Rbbp7 [] 107977000 [] FOUND AA_Seq XP_007648037 ['A0A061HY56', 'A0A061HY56', 'A0A8C2LNG1'] ['5931', '245688'] ['human', 'mouse']
# 8205 F8 [] 107977029 [] FOUND AA_Seq XP_035314877 ['A0A8C2MIP7', 'A0A8C2MIP7', 'A0A9J7GM46', 'A0A8C2MIP7', 'A0A9J7GNS5', 'A0A8C2MIP7', 'A0A9J7GNS5', 'A0A8C2MIP7', 'A0A9J7GM46', 'A0A8C2MIP7', 'A0A9J7GNS5', 'A0A8C2MIP7', 'A0A9J7GIV4', 'A0A8C2MIP7', 'A0A9J7GPL4', 'A0A8C2MIP7', 'A0A9J7GKM6', 'A0A9J7JZ27'] ['2157', '14069'] ['human', 'mouse']
# 8206 Rtl6 ['Ldoc1l'] 107977059 [] FOUND AA_Seq XP_003515345 ['G3ILM7'] ['84247', '223732'] ['human', 'mouse']
# 8207 Cryba1 [] 107977665 [] FOUND AA_Seq XP_016819672 ['A0A8C2L8I9', 'A0A8C2L9S6', 'A0A8C2L8I9', 'A0A8C2L9S6', 'A0A8C2L8I9', 'A0A8C2L9S6', 'A0A8C2L8I9', 'A0A8C2L9S6', 'A0A9J7KB95'] ['1411', '12957'] ['human', 'mouse']
# 8208 Umad1 [] 107978906 [] FOUND AA_Seq XP_016831841 ['G3HJH7', 'G3HJH7'] ['729852', '100036521'] ['human', 'mouse']
# 8209 Ilrun ['C1H6orf106'] 107979433 [] FOUND AA_Seq XP_035314181 ['G3HS03', 'A0A9J7J8J7', 'A0A8C2N1X5', 'A0A8C2QP71'] ['64771', '224647'] ['human', 'mouse']
# 8210 Mtm1 [] 107980426 [] FOUND AA_Seq XP_016836360 ['A0A061HY71', 'A0A8C2N3S9'] ['4534', '17772'] ['human', 'mouse']
# 8211 Actg1 [] 113830633 [] FOUND AA_Seq XP_003496930 ['A0A061IAX8', 'A0A8C2MH88', 'A0A061IAX8', 'A0A8C2MH88', 'A0A061IAX8', 'A0A3L7GSH9'] ['71', '11465'] ['human', 'mouse']
# 8212 Cfap20dc ['C1H3orf67'] 113830637 [] FOUND AA_Seq XP_016835068 ['A0A061ILI6', 'A0A8C2MF75', 'A0A9J7HDE8', 'A0A8C2MF75', 'A0A9J7H9T1', 'A0A8C2MF75', 'A0A9J7HAE7', 'A0A8C2MF75', 'A0A9J7HA59', 'A0A8C2MF75', 'A0A9J7HDK6', 'A0A8C2MF75', 'A0A9J7HCS7', 'A0A061ILI6', 'A0A9J7HAJ2', 'A0A8C2MF75', 'A0A9J7KF12'] ['200844', '74430'] ['human', 'mouse']
# 8213 Polr3h [] 113830647 [] FOUND AA_Seq XP_003514359 ['A0A9J7FLC1', 'G3II49', 'A0A9J7JIJ6', 'G3II49', 'A0A9J7FLC1', 'G3II49', 'A0A9J7FGM6'] ['171568', '78929'] ['human', 'mouse']
# 8214 Ptpn21 [] 113830649 [] FOUND AA_Seq XP_003501441 ['G3HBF6', 'G3HBF6', 'G3HBF6', 'G3HBF6', 'G3HBF6'] ['11099', '24000'] ['human', 'mouse']
# 8215 Spata13 [] 113830662 [] FOUND AA_Seq XP_035310498 ['A0A8C2LMD8', 'A0A8C2LMD8', 'G3H8R5', 'A0A8C2LMD8', 'A0A9J7HCL4', 'A0A8C2LMD8', 'A0A9J7HAC9', 'A0A8C2LLH0'] ['221178', '219140'] ['human', 'mouse']
# 8216 Asnsd1 [] 113830707 [] FOUND AA_Seq XP_027242007 ['G3IMR5', 'G3IMR5'] ['54529', '70396'] ['human', 'mouse']
# 8217 Fmc1 [] 113832846 [] FOUND AA_Seq XP_035312279 ['A0A3L7IJ59', 'A0A3L7IJ59'] ['154791', '66117'] ['human', 'mouse']
# 8218 Cisd2 [] 113833500 [] FOUND AA_Seq XP_035293462 ['A0A9J7J9K5', 'A0A061IL08', 'A0A3L7IDG1'] ['493856', '67006'] ['human', 'mouse']
# 8219 Derpc [] 113834671 [] FOUND AA_Seq XP_027293703 ['A0A8C2LF16', 'A0A8C2LF16', 'A0A9J7FNU4'] ['113455421', '116621581'] ['human', 'mouse']
# 8220 Exosc6 [] 113834673 [] FOUND AA_Seq XP_035293341 ['A0A8C2LEA3', 'A0A8C2LEA3'] ['118460', '72544'] ['human', 'mouse']
# 8221 Sox4 [] 113835005 [] FOUND AA_Seq XP_035313254 ['A0A8C2LGN7', 'A0A8C2LGN7'] ['6659', '20677'] ['human', 'mouse']
# 8222 Ncbp2as2 ['Ncbp2-as2'] 113835342 [] FOUND AA_Seq XP_027290745 ['G3GSK0', 'A0A061I745'] ['152217', '106264'] ['human', 'mouse']
# 8223 Rtl10 [] 113835360 [] FOUND AA_Seq XP_035311792 ['A0A9J7K912'] ['79680'] ['human']
# 8224 CUNH1orf53 [] 113835903 [] FOUND AA_Seq XP_035313156 ['A0A8C2M364', 'A0A9J7JQX9'] ['388722', '69549'] ['human', 'mouse']
# 8225 Mmp24os [] 113836370 [] FOUND AA_Seq XP_027291488 ['A0A8C2M1T1', 'A0A8C2M1T1'] ['101410538', '613262'] ['human', 'mouse']
# 8226 Nbdy [] 113837562 [] FOUND AA_Seq XP_035317648 ['A0A8C2LJR5', 'A0A8C2LJR5'] ['550643'] ['human']
# 8227 Yy2 [] 113837645 [] FOUND AA_Seq XP_027288751 ['A0A061HU80', 'A0A061HU80'] ['404281', '100073351'] ['human', 'mouse']
# 8228 Cyp2a17 [] 100689034 [] FOUND AA_Seq NP_001230951 ['A0A3L7GXW0', 'Q9JM91'] [] []
# 8229 Hmga1 ['HMG-Y', 'HMGIY', 'Hmg-i', 'HMG-I(Y)'] 100689040 [] FOUND AA_Seq XP_027295021 ['Q9QXP2', 'Q9QXP3', 'Q9QXP2', 'Q9QXP3', 'Q9QXP2', 'Q9QXP3', 'Q9QXP3', 'Q9QXP2', 'Q9QXP3', 'Q9QXP3.3'] ['3159', '15361'] ['human', 'mouse']
# 8230 Gnaq [] 100689066 [] FOUND AA_Seq NP_001230981 ['Q3HR10'] [] []
# 8231 Neu3 [] 100689090 [] FOUND AA_Seq NP_001231029 ['A0A061IE66', 'B8Y441'] ['10825', '50877'] ['human', 'mouse']
# 8232 Mapk14 [] 100689104 [] FOUND AA_Seq XP_016834292 ['G3HZU1', 'A0A8C2MSC6', 'A0A9J7F0Z5', 'A0A8C2MSQ2', 'A0A8C2MW48', 'G3HZU1'] ['1432', '26416', '194881'] ['human', 'mouse', 'fd03e12.y1']
# 8233 Cdh2 [] 100689204 [] FOUND AA_Seq XP_035314894 ['A0A8C2MBA0', 'A0A8C2M705', 'A0A8C2MBA0', 'O55075.1'] ['1000', '12558', '455828', '340179'] ['human', 'mouse', 'stSG624273', 'REN15379']
# 8234 Abcc2 [] 100689220 [] FOUND AA_Seq XP_027240278 ['A0A8C2LWX6', 'A0A9J7JH75', 'A0A8C2LWX6', 'A0A9J7JH75'] ['1244', '12780'] ['human', 'mouse']
# 8235 Dao ['DAAO', 'DAMOX'] 100689280 [] FOUND AA_Seq NP_001231338 ['A0A8C2LVI9', 'Q9Z302', 'Q9Z302', 'A0A8C2M1L4', 'Q9Z302.1'] ['1610', '13142'] ['human', 'mouse']
# 8236 Nat2 ['Nat'] 100689282 [] FOUND AA_Seq NP_001231342 ['Q921C9'] [] []
# 8237 Htr1b ['5-ht1b', '5-HT-1B'] 100689321 [] FOUND AA_Seq XP_007646219 ['P46636', 'G3HVW4', 'G3HVW4', 'P46636.1'] ['3351', '15551', '157838', '158176', '271594'] ['human', 'mouse', 'GDB:580603', 'GDB:603580', 'PMC166422P1']
# 8238 Folr1 [] 100689330 [] FOUND AA_Seq NP_001233692 ['G3II15', 'Q9R0D3'] ['2348', '14275'] ['human', 'mouse']
# 8239 LOC100689337 ['GS', 'Glul'] 100689337 [] FOUND AA_Seq NP_001233699 ['P04773', 'P04773', 'P04773.4'] [] []
# 8240 Rbm3 [] 100689372 [] FOUND AA_Seq XP_016832446 ['D5FGC9', 'A0A061HZB0', 'A0A061HZB0', 'D5FGC9', 'D5FGC9'] ['5935', '19652', '230986', '230986', '231245', '231245'] ['human', 'mouse', 'MARC_3075-3076:991936711:1', 'MARC_3075-3076:996678948:1', 'MARC_6565-6566:992007306:2', 'MARC_6565-6566:996689796:1']
# 8241 Lhb [] 100689384 [] FOUND AA_Seq NP_001233739 ['Q2L4U0'] ['3972', '16866'] ['human', 'mouse']
# 8242 St6gal1 ['St6gal'] 100689389 [] FOUND AA_Seq NP_001233744 ['F1SWB0', 'G3HYF9'] ['6480', '20440'] ['human', 'mouse']
# 8243 Pld1 [] 100689404 [] FOUND AA_Seq NP_001233757 ['A0A8C2N642', 'O08684', 'O08684.1'] ['5337', '18805'] ['human', 'mouse']
# 8244 LOC100689426 [] 100689426 [] FOUND AA_Seq AAF71542 [] [] []
# 8245 B4galt6 [] 100689438 [] FOUND AA_Seq NP_001233627 ['A0A8C2MZE9', 'Q812A0'] ['9331', '56386', '508001'] ['human', 'mouse', 'B4galt6']
# 8246 Tex101 ['testis'] 100689441 [] FOUND AA_Seq XP_007647193 ['Q7TQN2', 'A0A8C2LVG9', 'A0A061HU62', 'A0A8C2LVG9', 'Q7TQN2.1'] ['83639', '56746'] ['human', 'mouse']
# 8247 Cga [] 100689452 [] FOUND AA_Seq NP_001233640 ['Q2L4U1'] ['1081', '12640'] ['human', 'mouse']
# 8248 Fshb [] 100689453 [] FOUND AA_Seq NP_001233641 ['A0A8C2QP59', 'Q2L4T9'] ['2488', '14308'] ['human', 'mouse']
# 8249 Meltf ['Mfi2'] 100750333 [] FOUND AA_Seq XP_035310119 ['A0A061IB02', 'A0A8C2LAF7', 'A0A061IB02', 'A0A8C2LAF7'] ['4241', '30060'] ['human', 'mouse']
# 8250 Cd300lb [] 100750336 [] FOUND AA_Seq XP_035311946 ['A0A8C2LRS1', 'A0A9J7H571', 'A0A8C2LRS1', 'A0A9J7H571'] ['124599', '217304'] ['human', 'mouse']
# 8251 Slfn5 [] 100750338 [] FOUND AA_Seq XP_035312533 ['A0A8C2MCI3', 'A0A9J7K8D0', 'A0A8C2MCI3', 'A0A9J7K8D0'] ['162394'] ['human']
# 8252 Ccdc96 [] 100750342 [] FOUND AA_Seq XP_035292432 ['A0A8C2M147', 'A0A8C2M1V6', 'A0A8C2M1V6', 'A0A9J7ETZ7'] ['257236', '66717'] ['human', 'mouse']
# 8253 Tvp23a [] 100750344 [] FOUND AA_Seq XP_027240321 ['A0A8C2M3B4', 'A0A9J7GE06', 'A0A8C2M3B4', 'A0A9J7GE06'] ['780776', '383103'] ['human', 'mouse']
# 8254 Dmc1 [] 100750348 [] FOUND AA_Seq XP_003514726 ['A0A8C2LJC0', 'A0A8C2LJC0', 'A0A9J7K288'] ['11144', '13404'] ['human', 'mouse']
# 8255 Ntn1 ['Netrin-1'] 100750350 [] FOUND AA_Seq XP_007607234 ['A0A8C2MAK1'] ['9423', '18208'] ['human', 'mouse']
# 8256 Frey1 ['CUNH11orf94'] 100750351 [] FOUND AA_Seq XP_003497332 ['A0A8C2MI73', 'A0A9J7G728', 'A0A8C2MI73', 'A0A9J7G728'] ['143678', '75641'] ['human', 'mouse']
# 8257 Gpat2 [] 100750356 [] FOUND AA_Seq XP_035299006 ['A0A8C2M118', 'A0A9J7H4X6', 'A0A8C2M118', 'A0A9J7H4X6'] ['150763', '215456'] ['human', 'mouse']
# 8258 Ssuh2 [] 100750359 [] FOUND AA_Seq XP_003498146 ['A0A8C2M072', 'A0A8C2M072', 'A0A8C2M072', 'A0A9J7GG98', 'A0A8C2M072', 'A0A9J7GF41'] ['51066', '243612'] ['human', 'mouse']
# 8259 Amer3 [] 100750361 [] FOUND AA_Seq XP_007624259 ['A0A8C2LWR2', 'A0A8C2LWR2', 'A0A9J7EYA0'] ['205147', '211383'] ['human', 'mouse']
# 8260 Hoxb4 [] 100750374 [] FOUND AA_Seq XP_003499602 ['A0A8C2MW39', 'A0A9J7G9I7'] ['3214', '15412'] ['human', 'mouse']
# 8261 Tmem54 [] 100750385 [] FOUND AA_Seq XP_027291171 ['A0A9J7FE78', 'G3H931', 'A0A9J7K411', 'G3H931', 'A0A9J7K411', 'G3H931', 'A0A9J7GQD3', 'G3H931', 'A0A9J7FE78', 'G3H931'] ['113452', '66260'] ['human', 'mouse']
# 8262 Slc15a5 [] 100750387 [] FOUND AA_Seq XP_003500957 ['A0A8C2MP87', 'A0A8C2MP87', 'A0A9J7JR98'] ['729025', '277898'] ['human', 'mouse']
# 8263 Madcam1 [] 100750395 [] FOUND AA_Seq XP_003502644 ['G3HF34', 'G3HF34'] ['8174', '17123'] ['human', 'mouse']
# 8264 Col27a1 [] 100750399 [] FOUND AA_Seq XR_004773579 ['A0A9J7FDN1', 'A0A8C2QLS3', 'A0A9J7K1F5', 'A0A9J7GQE6', 'A0A9J7GQJ6', 'A0A9J7FBM2', 'A0A9J7FGP5', 'A0A9J7FFP0', 'A0A9J7JG31', 'A0A9J7JCK2', 'A0A9J7K1F5', 'A0A9J7GQE6', 'A0A9J7GQJ6', 'A0A9J7FBM2', 'A0A9J7FGP5', 'A0A9J7FFP0', 'A0A9J7FDN1', 'A0A8C2QLS3', 'A0A9J7JG31', 'A0A9J7JCK2'] ['85301', '373864', '502775'] ['human', 'mouse', 'Col27a1']
# 8265 Cpne5 [] 100750402 [] FOUND AA_Seq XP_016831984 ['G3HKC8', 'A0A8C2MW28', 'A0A9J7F612', 'A0A8C2MW28', 'A0A9J7F7T7'] ['57699', '240058'] ['human', 'mouse']
# 8266 Nhs [] 100750403 [] FOUND AA_Seq XP_035312902 ['A0A8C2MNL5', 'A0A8C2MNZ3', 'A0A8C2MNL5', 'A0A9J7K0Z5'] ['4810', '195727', '78098'] ['human', 'mouse', 'DXS8019']
# 8267 Myoc [] 100750409 [] FOUND AA_Seq XP_003505570 ['A0A8C2N261', 'G3HPL4', 'A0A8C2N261', 'G3HPL4'] ['4653', '17926'] ['human', 'mouse']
# 8268 Mrgprg [] 100750410 [] FOUND AA_Seq XP_035313794 ['G3HQ61', 'G3HQ61'] ['386746', '381974'] ['human', 'mouse']
# 8269 Cfap65 ['Ccdc108'] 100750413 [] FOUND AA_Seq XP_035315174 ['A0A8C2MSB1', 'A0A8C2MSB1', 'A0A9J7GN16'] ['255101', '241116'] ['human', 'mouse']
# 8270 Chd8 [] 100750414 [] FOUND AA_Seq XP_007646471 ['A0A061IQH7', 'G3HWS4', 'A0A061IQH7', 'A0A9J7EXZ2', 'A0A061IQH7', 'A0A8C2M4F5', 'A0A061IQH7', 'G3HWS4', 'A0A061IQH7', 'A0A8C2M4F5', 'A0A061IQH7', 'A0A9J7EXZ2', 'A0A061IQH7', 'G3HWS4', 'A0A061IQH7', 'G3HWS4'] ['57680', '67772', '218550', '39614'] ['human', 'mouse', 'RH135273', 'WI-14045']
# 8271 Actr3b [] 100750418 [] FOUND AA_Seq XP_016834166 ['A0A9J7KB35', 'G3HYZ9', 'A0A9J7KB35', 'G3HYZ9'] ['57180', '242894'] ['human', 'mouse']
# 8272 Chrdl1 [] 100750419 [] FOUND AA_Seq XP_035315778 ['G3HZH9', 'G3HZH9', 'G3HZH9', 'A0A8C2LSN0', 'G3HZH9', 'A0A9J7GNY7', 'A0A9J7KC54', 'A0A9J7GNR5', 'A0A9J7K3B0', 'A0A9J7KC54'] ['91851', '83453'] ['human', 'mouse']
# 8273 Il17a [] 100750422 [] FOUND AA_Seq XP_003509176 ['G3I1H2', 'G3I1H2'] ['3605', '16171'] ['human', 'mouse']
# 8274 Sypl2 [] 100750429 [] FOUND AA_Seq XP_027298312 ['A0A061ILT8', 'A0A8C2LJA8'] ['284612', '17306'] ['human', 'mouse']
# 8275 Atp4b [] 100750430 [] FOUND AA_Seq XP_003511222 ['A0A061IPC3', 'G3I7Z2', 'A0A061IPC3', 'G3I7Z2'] ['496', '11945'] ['human', 'mouse']
# 8276 Pcdhb14 [] 100750434 [] FOUND AA_Seq XP_016835980 ['A0A8C2QGL6'] ['56122', '93891'] ['human', 'mouse']
# 8277 Slc38a8 [] 100750441 [] FOUND AA_Seq XP_003495171 ['A0A061IC65', 'A0A061IHS5', 'A0A061IC65', 'A0A061IHS5'] ['146167', '234788'] ['human', 'mouse']
# 8278 Tfb1m [] 100750446 [] FOUND AA_Seq XP_003495944 ['A0A8C2MYZ0', 'A0A8C2MYZ0', 'A0A9J7JD04', 'A0A8C2MYZ0', 'A0A9J7FEL3', 'A0A8C2MYZ0', 'A0A9J7FCL2', 'A0A9J7GUT5'] ['51106', '224481'] ['human', 'mouse']
# 8279 Jakmip3 [] 100750449 [] FOUND AA_Seq XP_035293394 ['A0A061I8B8', 'A0A061I8B8', 'A0A061I8B8', 'A0A061I8B8', 'A0A9J7GW67', 'A0A061I8B8', 'A0A9J7K2N0', 'A0A061I8B8', 'A0A061IBX4'] ['282973', '74004'] ['human', 'mouse']
# 8280 Serpinc1 [] 100750462 [] FOUND AA_Seq XP_035298209 ['A0A8C2M0B8', 'A0A9J7GXK3', 'A0A8C2M0B8', 'A0A9J7GXK3'] ['462', '11905', '525942'] ['human', 'mouse', 'Serpinc1']
# ...
# 8945 Gsg1 [] 100752816 [] FOUND AA_Seq XP_027291582 ['A0A9J7JRB2', 'G3HB44', 'A0A8C2QET1', 'A0A9J7GHH2', 'A0A9J7K0S0', 'G3HB44', 'A0A8C2QET1', 'A0A9J7GHH2', 'A0A9J7JRB2', 'G3HB44', 'A0A9J7K0S0', 'G3HB44'] ['83445', '14840'] ['human', 'mouse']
# 8946 Nek5 [] 100752822 [] FOUND AA_Seq XP_027293020 ['A0A9J7F9C4'] ['341676', '330721'] ['human', 'mouse']
# 8947 Foxn4 [] 100752823 [] FOUND AA_Seq XP_003503572 ['A0A061I216', 'G3HI84', 'A0A061I216', 'G3HI84'] ['121643', '116810'] ['human', 'mouse']
# 8948 Relb [] 100752828 [] FOUND AA_Seq XP_007644141 ['A0A8C2LQ82', 'A0A8C2LQ82', 'A0A8C2LQ82', 'A0A8C2QE96', 'A0A8C2LML8', 'A0A8C2LQ82', 'A0A8C2LQ82', 'A0A9J7JRU4', 'A0A8C2LQ82', 'A0A9J7K1A6', 'A0A8C2LQ82', 'A0A9J7JRU4', 'A0A8C2LQ82', 'A0A9J7GIL8', 'A0A8C2LQ82', 'A0A9J7GMS7', 'A0A8C2LQ82', 'A0A9J7K1A6'] ['5971', '19698'] ['human', 'mouse']
# 8949 Eda2r [] 100752833 [] FOUND AA_Seq XR_004774359 ['G3HTK6', 'A0A9J7H6Y9', 'A0A9J7H6Y9', 'A0A9J7H6Y9', 'A0A9J7H6Y9', 'A0A9J7H6Y9', 'A0A9J7H6Y9', 'G3HTK6'] ['60401', '245527'] ['human', 'mouse']
# 8950 Sde2 [] 100752836 [] FOUND AA_Seq XP_016833496 ['A0A8C2MHM9', 'G3HV66', 'A0A8C2MHM9', 'G3HV66', 'A0A9J7G2N1', 'G3HV66'] ['163859', '208768'] ['human', 'mouse']
# 8951 Zbtb10 [] 100752837 [] FOUND AA_Seq XP_027295821 ['A0A8C2QGT4', 'A0A9J7JDP4'] ['65986', '229055'] ['human', 'mouse']
# 8952 Nfam1 [] 100752842 [] FOUND AA_Seq XP_035315953 ['A0A061IJH6', 'A0A9J7K424', 'A0A061IJH6', 'A0A9J7K424'] ['150372', '74039'] ['human', 'mouse']
# 8953 Spata4 [] 100752845 [] FOUND AA_Seq XP_003509597 ['A0A8C2LZM3', 'A0A061IQI7', 'A0A8C2LZM3'] ['132851', '69281'] ['human', 'mouse']
# 8954 Gcat [] 100752849 [] FOUND AA_Seq XP_003510321 ['A0A3L7I2B7', 'A0A8C2MBG2', 'A0A3L7I2B7', 'A0A8C2MBG2'] ['23464', '26912'] ['human', 'mouse']
# 8955 Acrv1 [] 100752850 [] FOUND AA_Seq XP_035317459 ['A0A8C2M144', 'A0A9J7JKJ8', 'A0A8C2M144', 'A0A9J7JKJ8'] ['56', '11451'] ['human', 'mouse']
# 8956 Krt2 [] 100752858 [] FOUND AA_Seq XP_003512368 ['A0A8C2M5K3', 'A0A8C2M5K3'] ['3849', '16681'] ['human', 'mouse']
# 8957 Bcl2l10 [] 100752860 [] FOUND AA_Seq XP_003495102 ['A0A8C2MSB6', 'A0A9J7FRV2', 'A0A8C2MSB6', 'A0A9J7FRV2'] ['10017', '12049'] ['human', 'mouse']
# 8958 Smco1 [] 100752866 [] FOUND AA_Seq XP_003495445 ['A0A8C2QDP8', 'G3GSL4', 'A0A8C2QDP8', 'G3GSL4'] ['255798', '69576'] ['human', 'mouse']
# 8959 Spata19 [] 100752873 [] FOUND AA_Seq XP_035312786 ['A0A8C2M3U5', 'A0A061I6Y4', 'A0A9J7GYZ3', 'A0A8C2M3U5', 'A0A061I6Y4', 'A0A9J7GYZ3'] ['219938', '75469'] ['human', 'mouse']
# 8960 Ak9 [] 100752880 [] FOUND AA_Seq XP_035294322 ['A0A9J7GU92', 'A0A9J7GU92'] ['221264', '633979'] ['human', 'mouse']
# 8961 Pdzrn4 [] 100752883 [] FOUND AA_Seq XP_003515009 ['G3IKE5', 'A0A9J7JU69', 'A0A8C2MZY7', 'A0A9J7K428'] ['29951', '239618'] ['human', 'mouse']
# 8962 Gldn [] 100752888 [] FOUND AA_Seq XP_003497940 ['A0A8C2QFF1', 'A0A8C2QFF1', 'A0A9J7FXV4'] ['342035', '235379'] ['human', 'mouse']
# 8963 Frmd5 [] 100752890 [] FOUND AA_Seq XP_035300526 ['A0A8C2N3T1', 'G3H0T5', 'A0A9J7JZT5', 'A0A8C2N3T1', 'A0A9J7JVL2', 'A0A8C2NAC9', 'G3H0T5', 'A0A8C2N3T1', 'A0A9J7GAE0', 'A0A9J7H2U6', 'G3H0T5', 'A0A9J7JZT5'] ['84978', '228564', '457986'] ['human', 'mouse', 'stSG628009']
# 8964 Rab1a [] 100752891 [] FOUND AA_Seq XP_003498151 ['A0A3L7IMK5', 'A0A8C2LZD7', 'A0A3L7IMK5', 'A0A8C2LZD7'] ['5861', '19324', '466818', '125905'] ['human', 'mouse', 'MARC_33894-33895:1054217168:1', 'Y00094']
# 8965 Kcnu1 [] 100752893 [] FOUND AA_Seq XP_035301762 ['A0A8C2MY73', 'A0A9J7KFK4', 'A0A8C2MY73', 'A0A9J7KFK4'] ['157855', '16532'] ['human', 'mouse']
# 8966 Islr [] 100752905 [] FOUND AA_Seq XP_003502439 ['A0A3L7HNI1', 'A0A3L7HNI1'] ['3671', '26968', '525540'] ['human', 'mouse', 'Islr']
# 8967 Wnt8a [] 100752907 [] FOUND AA_Seq XP_003502580 ['G3HF01', 'A0A8C2MU82', 'A0A9J7FDX9'] ['7478', '20890'] ['human', 'mouse']
# 8968 Fam171b [] 100752911 [] FOUND AA_Seq XP_027293069 ['A0A061I1Q5', 'G3HHR7'] ['165215', '241520'] ['human', 'mouse']
# 8969 Wdr31 [] 100752912 [] FOUND AA_Seq XP_003503508 ['A0A8C2LGV3', 'A0A9J7JCK7', 'A0A8C2LGV3', 'A0A9J7JCK7', 'A0A8C2LGV3', 'A0A9J7FDU5', 'A0A8C2LGV3', 'A0A9J7JCK7', 'A0A8C2LGV3', 'A0A9J7JCK7', 'A0A8C2LGV3', 'A0A9J7FDU5'] ['114987', '71354'] ['human', 'mouse']
# 8970 Sycp1 [] 100752914 [] FOUND AA_Seq XP_007642617 ['A0A8C2LSE8', 'A0A8C2LSE8', 'A0A9J7F6L3'] ['6847', '20957'] ['human', 'mouse']
# 8971 Heatr4 [] 100752922 [] FOUND AA_Seq XP_035313509 ['A0A9J7JYG3', 'A0A9J7GY67', 'A0A9J7GY67', 'A0A9J7GY67', 'A0A9J7GY67', 'A0A8C2LQL0', 'A0A9J7GY67', 'A0A9J7GY67', 'A0A9J7GY67', 'A0A9J7JYG3', 'A0A9J7GY67', 'A0A8C2LQL0', 'A0A9J7GY67', 'A0A9J7GY67'] ['399671', '101055670'] ['human', 'mouse']
# 8972 Htr6 [] 100752934 [] FOUND AA_Seq XP_003506940 ['A0A8C2MUK5', 'G3HU32', 'A0A9J7FBM7'] ['3362', '15565'] ['human', 'mouse']
# 8973 Diaph1 [] 100752938 [] FOUND AA_Seq XP_035315569 ['A0A8C2MW41', 'A0A8C2MWT0', 'A0A9J7JD68', 'A0A8C2MW41', 'A0A9J7J7U5', 'A0A8C2MW41', 'A0A9J7GTZ9', 'A0A8C2MW41', 'A0A9J7GNT7'] ['1729', '13367'] ['human', 'mouse']
# 8974 Plekha4 [] 100752943 [] FOUND AA_Seq XP_027296741 ['A0A8C2LQX0', 'A0A8C2LQX0', 'A0A9J7G6Z6', 'A0A8C2LQX0', 'A0A9J7G6Z6', 'A0A8C2QF87', 'A0A9J7G508'] ['57664', '69217'] ['human', 'mouse']
# 8975 Riox2 ['Mina'] 100752945 [] FOUND AA_Seq XP_016834396 ['A0A061I8U2', 'A0A8C2QMY2', 'A0A061I8U2', 'A0A8C2QMY2', 'A0A061I8U2', 'A0A8C2QMY2'] ['84864', '67014'] ['human', 'mouse']
# 8976 Rgs7bp [] 100752948 [] FOUND AA_Seq XP_003509117 ['A0A8C2QLZ8', 'A0A9J7GQK4', 'A0A8C2QLZ8', 'A0A9J7GQK4'] ['401190', '52882'] ['human', 'mouse']
# 8977 Slc24a4 [] 100752949 [] FOUND AA_Seq XP_035316169 ['A0A8C2QQ33', 'A0A9J7GZQ0', 'A0A8C2QQ33', 'A0A9J7K8C6', 'A0A8C2QQ33', 'A0A9J7GZQ0', 'A0A8C2QQ33', 'A0A9J7K8C6'] ['123041', '238384', '243540', '547029'] ['human', 'mouse', 'BF392535', 'Slc24a4']
# 8978 Gpr68 [] 100752950 [] FOUND AA_Seq XP_035316523 ['A0A061HZW0', 'G3I396', 'A0A061HZW0', 'G3I396'] ['8111', '238377', '498497'] ['human', 'mouse', 'Gpr68']
# 8979 Nrip3 [] 100752951 [] FOUND AA_Seq XP_035316674 ['A0A9J7GTH8'] ['56675', '78593'] ['human', 'mouse']
# 8980 Slc16a14 [] 100752961 [] FOUND AA_Seq XP_035317711 ['A0A9J7GSK8', 'G3I8X4', 'A0A9J7GSK8', 'G3I8X4'] ['151473', '71781'] ['human', 'mouse']
# 8981 Ctrc [] 100752962 [] FOUND AA_Seq XP_035317758 ['A0A8C2MF57', 'A0A8C2MF57', 'A0A9J7GQ46'] ['11330'] ['human']
# 8982 CUNH7orf57 [] 100752964 [] FOUND AA_Seq XP_035292430 ['A0A061IPW1', 'A0A9J7HB53', 'A0A061IPW1', 'A0A9J7HB53'] ['136288', '626870'] ['human', 'mouse']
# 8983 Lcn2 [] 100752966 [] FOUND AA_Seq XP_003512308 ['A0A9J7GCT3', 'G3IBI7', 'A0A9J7GCT3', 'G3IBI7'] ['3934', '16819'] ['human', 'mouse']
# 8984 Zfta ['CUNH11orf95'] 100752967 [] FOUND AA_Seq XP_035292802 ['A0A8C2LH55', 'A0A8C2LH55', 'A0A9J7GSG1'] ['65998', '108899'] ['human', 'mouse']
# 8985 Celf3 [] 100752975 [] FOUND AA_Seq XP_035293444 ['A0A2Z6LPN6', 'A0A2Z6LPN6', 'A0A8C2MM22', 'A0A2Z6LPN6', 'A0A2Z6LPN6', 'A0A8C2MM22'] ['11189', '78784'] ['human', 'mouse']
# 8986 Slc2a9 [] 100752981 [] FOUND AA_Seq XP_003496692 ['A0A8C2QNU5', 'A0A9J7EYD5', 'A0A8C2QNU5', 'A0A9J7EYD5'] ['56606', '117591', '224459'] ['human', 'mouse', 'NoName']
# 8987 Txndc11 [] 100752982 [] FOUND AA_Seq XP_007650748 ['A0A9J7GAJ3', 'A0A8C2QJE5', 'A0A9J7G9Y6', 'A0A9J7K033', 'G3GWL5'] ['51061', '106200'] ['human', 'mouse']
# 8988 Ctc1 [] 100752986 [] FOUND AA_Seq XP_007606426 ['A0A9J7GH86', 'A0A9J7GFH2', 'G3GY53', 'A0A9J7GFI9', 'A0A9J7GD47', 'A0A9J7GH86', 'A0A9J7GFH2', 'G3GY53', 'A0A9J7GFI9', 'A0A9J7GD47'] ['80169', '68964'] ['human', 'mouse']
# 8989 Csn3 [] 100752988 [] FOUND AA_Seq XP_035294024 ['A0A8C2MVL6', 'A0A061IJP4', 'A0A8C2MVL6'] ['1448', '12994'] ['human', 'mouse']
# 8990 Abhd12b [] 100752990 [] FOUND AA_Seq XP_003515292 ['A0A8C2MFU3', 'A0A8C2MI25', 'A0A9J7JSL2', 'A0A8C2MFU3', 'A0A9J7JJH8'] ['145447', '100504285'] ['human', 'mouse']
# 8991 Hoxd12 [] 100752995 [] FOUND AA_Seq XP_003498366 ['G3H1U8', 'G3H1U8'] ['3238', '15432'] ['human', 'mouse']
# 8992 Gpr132 [] 100753002 [] FOUND AA_Seq XR_004771202 ['A0A8C2M5A5', 'G3H3A5', 'A0A9J7JQE2', 'G3H3A5', 'A0A9J7JQE2', 'G3H3A5', 'A0A9J7JQE2', 'G3H3A5', 'A0A061I031', 'A0A9J7JRI9', 'A0A8C2M5A5', 'G3H3A5', 'A0A8C2M5A5', 'G3H3A5', 'A0A9J7JQE2', 'G3H3A5', 'A0A9J7JQE2', 'G3H3A5', 'A0A061I031', 'A0A9J7JRI9', 'A0A8C2M5A5', 'G3H3A5'] ['29933', '56696'] ['human', 'mouse']
# 8993 Prr15l [] 100753008 [] FOUND AA_Seq XP_035309862 ['A0A061I2F5', 'A0A061I2F5'] ['79170', '217138'] ['human', 'mouse']
# 8994 Wnt5b [] 100753017 [] FOUND AA_Seq XP_007639244 ['A0A8C2MYS1', 'G3H870', 'A0A8C2MYS1', 'A0A9J7H4C0', 'A0A8C2MYS1', 'G3H870', 'A0A8C2MYS1', 'A0A9J7H4C0'] ['81029', '22419', '508419', '465423', '471327'] ['human', 'mouse', 'Wnt5b', 'Wnt5b', 'Wnt5b']
# 8995 Fam167b [] 100753020 [] FOUND AA_Seq XP_003500684 ['G3H944', 'A0A9J7FC92'] ['84734', '230766'] ['human', 'mouse']
# 8996 Brinp2 [] 100753022 [] FOUND AA_Seq XP_035310779 ['G3HA02', 'G3HA02'] ['57795', '240843', '505390'] ['human', 'mouse', 'NoName']
# 8997 Colec10 [] 100753023 [] FOUND AA_Seq XP_003501034 ['G3HA91', 'G3HA91'] ['10584', '239447'] ['human', 'mouse']
# 8998 Negr1 [] 100753024 [] FOUND AA_Seq XP_027291639 ['A0A8C2LIS7', 'A0A8C2LL74'] ['257194', '320840', '73225'] ['human', 'mouse', 'D6S1686']
# 8999 S100a16 [] 100753026 [] FOUND AA_Seq XP_003501711 ['G3HC27', 'G3HC27', 'G3HC27', 'G3HC27'] ['140576', '67860', '210195'] ['human', 'mouse', 'RH136200']
# 9000 Col9a2 [] 100753027 [] FOUND AA_Seq XP_003501865 ['A0A8C2M6L8', 'A0A8C2M6L8'] ['1298', '12840'] ['human', 'mouse']
# 9001 Ptger1 [] 100753028 [] FOUND AA_Seq XP_035311422 ['A0A8C2LYI1', 'A0A8C2LYI1', 'A0A9J7JWM0', 'A0A9J7K704'] ['5731', '19216'] ['human', 'mouse']
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\a.antonakoudis\OneDrive - Sartorius Corporate Administration GmbH\Documents\Projects\UCSD Project\Whole-Cell-Network-Reconstruction-for-CHO-cells-2\Notebooks\Genes.ipynb Cell 22 line 7
#      <a href='vscode-notebook-cell:/c%3A/Users/a.antonakoudis/OneDrive%20-%20Sartorius%20Corporate%20Administration%20GmbH/Documents/Projects/UCSD%20Project/Whole-Cell-Network-Reconstruction-for-CHO-cells-2/Notebooks/Genes.ipynb#X30sZmlsZQ%3D%3D?line=73'>74</a> fetch_found = True
#      <a href='vscode-notebook-cell:/c%3A/Users/a.antonakoudis/OneDrive%20-%20Sartorius%20Corporate%20Administration%20GmbH/Documents/Projects/UCSD%20Project/Whole-Cell-Network-Reconstruction-for-CHO-cells-2/Notebooks/Genes.ipynb#X30sZmlsZQ%3D%3D?line=74'>75</a> while fetch_tries < 3 and fetch_found:
# ---> <a href='vscode-notebook-cell:/c%3A/Users/a.antonakoudis/OneDrive%20-%20Sartorius%20Corporate%20Administration%20GmbH/Documents/Projects/UCSD%20Project/Whole-Cell-Network-Reconstruction-for-CHO-cells-2/Notebooks/Genes.ipynb#X30sZmlsZQ%3D%3D?line=76'>77</a>     gene_info = Entrez.efetch(db="gene", id=gene_id, retmode="xml")
#      <a href='vscode-notebook-cell:/c%3A/Users/a.antonakoudis/OneDrive%20-%20Sartorius%20Corporate%20Administration%20GmbH/Documents/Projects/UCSD%20Project/Whole-Cell-Network-Reconstruction-for-CHO-cells-2/Notebooks/Genes.ipynb#X30sZmlsZQ%3D%3D?line=77'>78</a>     fetch_tries += 1
#      <a href='vscode-notebook-cell:/c%3A/Users/a.antonakoudis/OneDrive%20-%20Sartorius%20Corporate%20Administration%20GmbH/Documents/Projects/UCSD%20Project/Whole-Cell-Network-Reconstruction-for-CHO-cells-2/Notebooks/Genes.ipynb#X30sZmlsZQ%3D%3D?line=78'>79</a>     try:
#
# File c:\Users\a.antonakoudis\AppData\Local\anaconda3\envs\UCSD_GEM\lib\site-packages\Bio\Entrez\__init__.py:196, in efetch(db, **keywords)
#     194 variables.update(keywords)
#     195 request = _build_request(cgi, variables)
# --> 196 return _open(request)
#
# File c:\Users\a.antonakoudis\AppData\Local\anaconda3\envs\UCSD_GEM\lib\site-packages\Bio\Entrez\__init__.py:594, in _open(request)
#     592 for i in range(max_tries):
#     593     try:
# --> 594         handle = urlopen(request)
#     595     except HTTPError as exception:
#     596         # Reraise if the final try fails
#     597         if i >= max_tries - 1:
#
# File c:\Users\a.antonakoudis\AppData\Local\anaconda3\envs\UCSD_GEM\lib\urllib\request.py:214, in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     212 else:
#     213     opener = _opener
# --> 214 return opener.open(url, data, timeout)
#
# File c:\Users\a.antonakoudis\AppData\Local\anaconda3\envs\UCSD_GEM\lib\urllib\request.py:517, in OpenerDirector.open(self, fullurl, data, timeout)
#     514     req = meth(req)
#     516 sys.audit('urllib.Request', req.full_url, req.data, req.headers, req.get_method())
# --> 517 response = self._open(req, data)
#     519 # post-process response
#     520 meth_name = protocol+"_response"
#
# File c:\Users\a.antonakoudis\AppData\Local\anaconda3\envs\UCSD_GEM\lib\urllib\request.py:534, in OpenerDirector._open(self, req, data)
#     531     return result
#     533 protocol = req.type
# --> 534 result = self._call_chain(self.handle_open, protocol, protocol +
#     535                           '_open', req)
#     536 if result:
#     537     return result
#
# File c:\Users\a.antonakoudis\AppData\Local\anaconda3\envs\UCSD_GEM\lib\urllib\request.py:494, in OpenerDirector._call_chain(self, chain, kind, meth_name, *args)
#     492 for handler in handlers:
#     493     func = getattr(handler, meth_name)
# --> 494     result = func(*args)
#     495     if result is not None:
#     496         return result
#
# File c:\Users\a.antonakoudis\AppData\Local\anaconda3\envs\UCSD_GEM\lib\urllib\request.py:1389, in HTTPSHandler.https_open(self, req)
#    1388 def https_open(self, req):
# -> 1389     return self.do_open(http.client.HTTPSConnection, req,
#    1390         context=self._context, check_hostname=self._check_hostname)
#
# File c:\Users\a.antonakoudis\AppData\Local\anaconda3\envs\UCSD_GEM\lib\urllib\request.py:1350, in AbstractHTTPHandler.do_open(self, http_class, req, **http_conn_args)
#    1348     except OSError as err: # timeout error
#    1349         raise URLError(err)
# -> 1350     r = h.getresponse()
#    1351 except:
#    1352     h.close()
#
# File c:\Users\a.antonakoudis\AppData\Local\anaconda3\envs\UCSD_GEM\lib\http\client.py:1377, in HTTPConnection.getresponse(self)
#    1375 try:
#    1376     try:
# -> 1377         response.begin()
#    1378     except ConnectionError:
#    1379         self.close()
#
# File c:\Users\a.antonakoudis\AppData\Local\anaconda3\envs\UCSD_GEM\lib\http\client.py:320, in HTTPResponse.begin(self)
#     318 # read until we get a non-100 response
#     319 while True:
# --> 320     version, status, reason = self._read_status()
#     321     if status != CONTINUE:
#     322         break
#
# File c:\Users\a.antonakoudis\AppData\Local\anaconda3\envs\UCSD_GEM\lib\http\client.py:281, in HTTPResponse._read_status(self)
#     280 def _read_status(self):
# --> 281     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     282     if len(line) > _MAXLINE:
#     283         raise LineTooLong("status line")
#
# File c:\Users\a.antonakoudis\AppData\Local\anaconda3\envs\UCSD_GEM\lib\socket.py:704, in SocketIO.readinto(self, b)
#     702 while True:
#     703     try:
# --> 704         return self._sock.recv_into(b)
#     705     except timeout:
#     706         self._timeout_occurred = True
#
# File c:\Users\a.antonakoudis\AppData\Local\anaconda3\envs\UCSD_GEM\lib\ssl.py:1242, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1238     if flags != 0:
#    1239         raise ValueError(
#    1240           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1241           self.__class__)
# -> 1242     return self.read(nbytes, buffer)
#    1243 else:
#    1244     return super().recv_into(buffer, nbytes, flags)
#
# File c:\Users\a.antonakoudis\AppData\Local\anaconda3\envs\UCSD_GEM\lib\ssl.py:1100, in SSLSocket.read(self, len, buffer)
#    1098 try:
#    1099     if buffer is not None:
# -> 1100         return self._sslobj.read(len, buffer)
#    1101     else:
#    1102         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
import pandas as pd
All_Genes = pd.DataFrame()

for i in range(1000, 35000, 1000):
    Genes_temp = pd.read_excel('GeneIDs_' + str(i) + '.xlsx')
    All_Genes = pd.concat([All_Genes, Genes_temp], ignore_index=True)
All_Genes.to_excel('All_Genes.xlsx', index=False)
